# %%
import nltk
import string
import pickle
import numpy as np
from collections import Counter

# %%
import zipfile
content = {}
with zipfile.ZipFile("keyword.zip") as zfile:
    for f in zfile.namelist():
        if f != "keyword/":
            content[f] = zfile.read(f).decode("utf8")
content.keys()
# Out:
# dict_keys(['keyword/automobil_50k.txt', 'keyword/news_text100k.txt', 'keyword/sport_50k.txt', 'keyword/wirtschaft_50k.txt'])

# %%
def clean(text):
    tokenized_sents=[]
    text = text.lower()
    text = nltk.sent_tokenize(text)
    for sent in text:
        sent = nltk.word_tokenize(sent)
        sent = [x for x in sent if x not in string.punctuation]
        sent = [x for x in sent if x not in ["``", "''", "€", "$"]]
        sent = [x for x in sent if x.isalpha()]
        if len(sent) > 1:
            tokenized_sents.append(sent)
        
    
    return tokenized_sents

# %%
for key in content:
    content[key] = clean(content[key])

# %%
def create_bigrams(dic_corpora):
    ngram_dict = {}
    #stopwords = nltk.corpus.stopwords.words("german")
    stopwords =["findbecci","--","..", "§", '”', "rebecca", "freeflorian", "\|lbr\|", "|lbr|"]
   
    for index, key in enumerate(dic_corpora):
        print(key)
        ngram_dict[key] =[]
  
        for sents in dic_corpora[key]:

            ngram_dict[key] += [gram for gram in list(nltk.ngrams(sents,2)) if len(set(stopwords).intersection(set(gram)))== 0]
    
    return ngram_dict

# %%
bigrams = create_bigrams(content)
# Out:
# keyword/automobil_50k.txt
# keyword/news_text100k.txt
# keyword/sport_50k.txt
# keyword/wirtschaft_50k.txt

# %%
def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
hatespeech = load_obj("ngrams_hatespeech_with_stopwords")

# %%
bigrams["keywords/hatespeech"] = hatespeech["2-grams"]

# %%
bigrams["keywords/hatespeech"][:100]
# Out:
# [('rosenmontag', 'ist'),
#  ('ist', 'abgesagt'),
#  ('rapefugees', 'also'),
#  ('also', 'wieder'),
#  ('wieder', 'wie'),
#  ('wie', 'gewohnt'),
#  ('gewohnt', 'ins'),
#  ('ins', 'schwimmbad'),
#  ('schwimmbad', 'gehen'),
#  ('bitte', 'nicht'),
#  ('nicht', 'die'),
#  ('die', 'türkei'),
#  ('türkei', 'zum'),
#  ('zum', 'eu-mitglied'),
#  ('eu-mitglied', 'machen'),
#  ('menschenrechte', 'pressefreiheit'),
#  ('pressefreiheit', 'islamisierung'),
#  ('islamisierung', 'wieso'),
#  ('wieso', 'bekommen'),
#  ('bekommen', 'rapefugees'),
#  ('rapefugees', 'mehr'),
#  ('mehr', 'als'),
#  ('als', 'unsere'),
#  ('unsere', 'hartz'),
#  ('hartz', 'enpfänger'),
#  ('esreicht', 'den'),
#  ('den', 'verfluchten'),
#  ('verfluchten', 'rapefugees'),
#  ('rapefugees', 'den'),
#  ('den', 'krieg'),
#  ('krieg', 'erklären'),
#  ('wasfehlt', 'war'),
#  ('war', 'das'),
#  ('das', 'wochenende'),
#  ('wochenende', 'im'),
#  ('im', 'ruhrpott'),
#  ('ruhrpott', 'unterwegs'),
#  ('überall', 'schwangere'),
#  ('schwangere', 'muslimische'),
#  ('muslimische', 'frauen'),
#  ('frauen', 'mit'),
#  ('mit', 'einem'),
#  ('einem', 'rattenschwanz'),
#  ('rattenschwanz', 'an'),
#  ('an', 'kindern'),
#  ('kindern', 'islamisierung'),
#  ('islamisierung', 'asylanteninvasion'),
#  ('asylanteninvasion', 'wenn'),
#  ('wenn', 'es'),
#  ('es', 'auf'),
#  ('auf', 'unseren'),
#  ('unseren', 'straßen'),
#  ('straßen', 'zu'),
#  ('zu', 'gewaltausbrüchen'),
#  ('gewaltausbrüchen', 'kommt'),
#  ('kommt', 'die'),
#  ('die', 'verantwortlichen'),
#  ('verantwortlichen', 'hierfür'),
#  ('hierfür', 'sitzen'),
#  ('sitzen', 'in'),
#  ('in', 'der'),
#  ('der', 'regierung'),
#  ('regierung', 'merkel'),
#  ('millionen', 'menschen'),
#  ('menschen', 'leben'),
#  ('leben', 'in'),
#  ('in', 'europa'),
#  ('millionen', 'flüchtlinge'),
#  ('flüchtlinge', 'bereiten'),
#  ('bereiten', 'da'),
#  ('da', 'kopfzerbrechen'),
#  ('rassisten', 'sprechen'),
#  ('sprechen', 'von'),
#  ('von', 'islamisierung'),
#  ('tja', 'die'),
#  ('die', 'spd'),
#  ('spd', 'will'),
#  ('will', 'unsere'),
#  ('unsere', 'steuergelder'),
#  ('steuergelder', 'für'),
#  ('für', 'flüchtlinge'),
#  ('flüchtlinge', 'verpassen'),
#  ('refugees', 'refugeesnotwelcome'),
#  ('refugeesnotwelcome', 'refugeesgohome'),
#  ('refugeesgohome', 'abmerkeln'),
#  ('abmerkeln', 'aber'),
#  ('aber', 'für'),
#  ('für', 'die'),
#  ('die', 'kölner'),
#  ('kölner', 'polizei'),
#  ('polizei', 'haben'),
#  ('haben', 'gestiegene'),
#  ('gestiegene', 'anzeigen'),
#  ('anzeigen', 'nur'),
#  ('nur', 'einen'),
#  ('einen', 'grund'),
#  ('grund', 'frauen'),
#  ('frauen', 'seien'),
#  ('seien', 'anzeigefreudiger'),
#  ('anzeigefreudiger', 'als')]

# %%
def transform_ngrams(dic):
    bigrams={}
    for keys in dic:
        tuples = []
        for doc in dic[keys]:
            tuples.append("_".join(doc))
        bigrams[keys] = tuples
    return bigrams

# %%
bigram = transform_ngrams(bigrams)

# %%
bigram
# Out:
# {'keyword/automobil_50k.txt': ['der_soll',
#   'soll_der',
#   'der_konkurrenz',
#   'konkurrenz_von',
#   'von_skoda',
#   'skoda_und',
#   'und_ford',
#   'ford_ordentlich',
#   'ordentlich_einheizen',
#   'mit_dem',
#   'dem_bidirektionalen',
#   'bidirektionalen_schlüssel',
#   'schlüssel_kann',
#   'kann_je',
#   'je_nach',
#   'nach_system',
#   'system_auch',
#   'auch_geprüft',
#   'geprüft_werden',
#   'werden_ob',
#   'ob_das',
#   'das_licht',
#   'licht_noch',
#   'noch_brennt',
#   'brennt_oder',
#   'oder_das',
#   'das_radio',
#   'radio_noch',
#   'noch_spielt',
#   'auch_monatlich',
#   'monatlich_günstiger',
#   'günstiger_die',
#   'die_niedrigeren',
#   'niedrigeren_anschaffungspreise',
#   'anschaffungspreise_der',
#   'der_kastenwagen',
#   'kastenwagen_wirken',
#   'wirken_sich',
#   'sich_auf',
#   'auf_die',
#   'die_monatlichen',
#   'monatlichen_kosten',
#   'kosten_dämpfend',
#   'dämpfend_aus',
#   'bei_aller',
#   'aller_liebe',
#   'liebe_zum',
#   'zum_detail',
#   'detail_haben',
#   'haben_die',
#   'die_entwickler',
#   'entwickler_dennoch',
#   'dennoch_ein',
#   'ein_paar',
#   'paar_kleinigkeiten',
#   'kleinigkeiten_vergessen',
#   'vergessen_die',
#   'die_umgelegten',
#   'umgelegten_sitzlehnen',
#   'sitzlehnen_bilden',
#   'bilden_leider',
#   'leider_keinen',
#   'keinen_komplett',
#   'komplett_ebenen',
#   'ebenen_ladeboden',
#   'doch_statt',
#   'statt_schriller',
#   'schriller_farben',
#   'farben_verrückter',
#   'verrückter_formen',
#   'formen_und',
#   'und_ein',
#   'ein_paar',
#   'paar_frischer',
#   'frischer_funktionen',
#   'funktionen_gibt',
#   'gibt_es',
#   'es_ringsum',
#   'ringsum_nur',
#   'nur_billiges',
#   'billiges_plastik',
#   'recht_hatte',
#   'hatte_se',
#   'das_war',
#   'war_früher',
#   'früher_kaum',
#   'kaum_vorstellbar',
#   'unterstützung_bekommen',
#   'bekommen_sie',
#   'sie_von',
#   'von_bundeskanzlerin',
#   'bundeskanzlerin_angela',
#   'angela_merkel',
#   'merkel_cdu',
#   'der_fc',
#   'fc_bayern',
#   'bayern_spielt',
#   'spielt_gegen',
#   'gegen_den',
#   'den_fc',
#   'fc_aberdeen',
#   'aberdeen_remis',
#   'remis_der',
#   'der_hsv',
#   'hsv_gewinnt',
#   'gewinnt_gegen',
#   'gegen_zürich',
#   'aston_martin',
#   'martin_zeigt',
#   'zeigt_das',
#   'das_neue',
#   'nur_leider',
#   'leider_fahren',
#   'fahren_dann',
#   'dann_alle',
#   'alle_dieselbe',
#   'dieselbe_umleitung',
#   'eigentlich_läge',
#   'läge_es',
#   'es_nahe',
#   'nahe_dass',
#   'dass_smith',
#   'smith_sein',
#   'sein_hobby',
#   'hobby_zum',
#   'zum_beruf',
#   'beruf_macht',
#   'dadurch_verringern',
#   'verringern_sich',
#   'sich_wendekreis',
#   'wendekreis_und',
#   'und_lenkübersetzung',
#   'lenkübersetzung_der',
#   'der_wagen',
#   'wagen_soll',
#   'soll_direkter',
#   'direkter_und',
#   'und_spontaner',
#   'spontaner_reagieren',
#   'das_concept',
#   'concept_car',
#   'car_heißt',
#   'heißt_nicht',
#   'nicht_nur',
#   'nur_wie',
#   'wie_der',
#   'der_prototyp',
#   'prototyp_es',
#   'es_ähnelt',
#   'ähnelt_darüber',
#   'darüber_hinaus',
#   'hinaus_wie',
#   'wie_der',
#   'der_ahne',
#   'ahne_von',
#   'von_auch',
#   'auch_einer',
#   'einer_zigarre',
#   'für_euro',
#   'euro_aufpreis',
#   'aufpreis_gibt',
#   'gibt_es',
#   'es_auch',
#   'auch_einen',
#   'einen_mit',
#   'mit_ps',
#   'ps_der',
#   'der_maximal',
#   'maximal_nm',
#   'nm_entwickelt',
#   'dennoch_brauchts',
#   'brauchts_einen',
#   'einen_moment',
#   'moment_bis',
#   'bis_die',
#   'die_fünf',
#   'fünf_meter',
#   'meter_lange',
#   'lange_und',
#   'und_trotz',
#   'trotz_noch',
#   'noch_tonnen',
#   'tonnen_schwere',
#   'schwere_limousine',
#   'limousine_in',
#   'in_schwung',
#   'schwung_kommt',
#   'das_coupé',
#   'coupé_kostet',
#   'kostet_franken',
#   'franken_das',
#   'das_cabrio',
#   'cabrio_franken',
#   'farbige_applikationen',
#   'applikationen_zeichnen',
#   'zeichnen_das',
#   'das_cockpit',
#   'cockpit_den',
#   'den_sondermodells',
#   'sondermodells_aus',
#   'der_dienstgradhöchste',
#   'dienstgradhöchste_offizier',
#   'offizier_der',
#   'der_streife',
#   'streife_ließ',
#   'ließ_kräftig',
#   'kräftig_dampf',
#   'dampf_ab',
#   'ab_ob',
#   'ob_ich',
#   'ich_denn',
#   'denn_das',
#   'das_schild',
#   'schild_nicht',
#   'nicht_gesehen',
#   'gesehen_hätte',
#   'bekannt_sind',
#   'sind_zwei',
#   'zwei_probleme',
#   'probleme_bei',
#   'bei_einigen',
#   'einigen_autos',
#   'autos_ist',
#   'ist_das',
#   'das_gaspedal',
#   'gaspedal_zu',
#   'zu_lang',
#   'lang_sodass',
#   'sodass_es',
#   'es_sich',
#   'sich_mit',
#   'mit_der',
#   'der_fußmatte',
#   'fußmatte_verhaken',
#   'verhaken_kann',
#   'ich_tue',
#   'tue_das',
#   'das_lange',
#   'lange_nicht',
#   'nicht_mehr',
#   'mehr_und',
#   'und_fahre',
#   'fahre_nur',
#   'nur_sehr',
#   'sehr_wenig',
#   'jedesmal_wird',
#   'wird_auf',
#   'auf_die',
#   'die_autos',
#   'autos_eingedroschen',
#   'eingedroschen_um',
#   'um_das',
#   'das_anzukurbeln',
#   'die_messe',
#   'messe_auto',
#   'auto_china',
#   'china_in',
#   'in_peking',
#   'peking_dauert',
#   'dauert_vom',
#   'vom_april',
#   'april_bis',
#   'bis_mai',
#   'der_mini',
#   'mini_ist',
#   'ist_derzeit',
#   'derzeit_die',
#   'die_wertstabilste',
#   'wertstabilste_marke',
#   'marke_auf',
#   'auf_dem',
#   'dem_deutschen',
#   'deutschen_automarkt',
#   'der_diesel',
#   'diesel_wird',
#   'wird_bald',
#   'bald_ausgedient',
#   'ausgedient_haben',
#   'haben_und',
#   'und_sind',
#   'sind_im',
#   'im_kommen',
#   'befragt_wurden',
#   'wurden_männer',
#   'männer_und',
#   'und_frauen',
#   'frauen_ab',
#   'ab_jahren',
#   'danach_folgt',
#   'folgt_die',
#   'die_niederlande',
#   'niederlande_vor',
#   'vor_dänemark',
#   'die_schätzen',
#   'schätzen_die',
#   'die_hohe',
#   'hohe_und',
#   'und_sitzposition',
#   'sitzposition_und',
#   'und_den',
#   'den_kofferraum',
#   'kofferraum_aber',
#   'aber_wundern',
#   'wundern_sich',
#   'sich_erst',
#   'erst_nach',
#   'nach_dem',
#   'dem_kauf',
#   'kauf_über',
#   'über_den',
#   'den_verbrauch',
#   'verbrauch_der',
#   'der_doch',
#   'doch_deutlich',
#   'deutlich_über',
#   'über_dem',
#   'dem_des',
#   'des_alten',
#   'alten_kombi',
#   'kombi_liegt',
#   'von_diesem',
#   'diesem_kleingedruckten',
#   'kleingedruckten_gibt',
#   'gibt_es',
#   'es_wie',
#   'wie_überall',
#   'überall_auch',
#   'auch_in',
#   'in_den',
#   'den_garantiebedingungen',
#   'garantiebedingungen_von',
#   'von_opel',
#   'opel_reichlich',
#   'nichts_zu',
#   'zu_meckern',
#   'meckern_gibts',
#   'gibts_am',
#   'am_fahrwerk',
#   'auch_hier',
#   'hier_gilt',
#   'gilt_der',
#   'der_grundsatz',
#   'grundsatz_man',
#   'man_kritisiert',
#   'kritisiert_den',
#   'den_bundespräsidenten',
#   'bundespräsidenten_nicht',
#   'nicht_sagte',
#   'sagte_der',
#   'der_stellvertretende',
#   'stellvertretende_am',
#   'am_montag',
#   'montag_in',
#   'in_berlin',
#   'er_würde',
#   'würde_beim',
#   'beim_crash',
#   'crash_zu',
#   'zu_viel',
#   'viel_druck',
#   'druck_auf',
#   'auf_das',
#   'das_ungeborene',
#   'ungeborene_ausüben',
#   'damit_können',
#   'können_die',
#   'die_deutschen',
#   'deutschen_autokäufer',
#   'autokäufer_vorerst',
#   'vorerst_nicht',
#   'nicht_mit',
#   'mit_einer',
#   'einer_einfachen',
#   'einfachen_und',
#   'und_transparenten',
#   'transparenten_verbrauchskennzeichnung',
#   'verbrauchskennzeichnung_für',
#   'für_pkw',
#   'pkw_rechnen',
#   'ein_computer',
#   'computer_übernimmt',
#   'übernimmt_hier',
#   'hier_das',
#   'das_umherkurven',
#   'umherkurven_und',
#   'und_suchen',
#   'fürs_fahrvergnügen',
#   'fahrvergnügen_gibts',
#   'gibts_dazu',
#   'dazu_noch',
#   'noch_ein',
#   'ein_sportfahrwerk',
#   'sportfahrwerk_mit',
#   'mit_millimeter',
#   'millimeter_geringerer',
#   'geringerer_bodenfreiheit',
#   'bodenfreiheit_sowie',
#   'sowie_die',
#   'die_elektronische',
#   'elektronische_differentialsperre',
#   'differentialsperre_xds',
#   'xds_mit',
#   'mit_der',
#   'der_die',
#   'die_kurvengeschwindigkeiten',
#   'kurvengeschwindigkeiten_steigen',
#   'auch_dieses',
#   'dieses_dürfte',
#   'dürfte_daimler',
#   'daimler_interessieren',
#   'als_jemand',
#   'jemand_der',
#   'der_gerne',
#   'gerne_mit',
#   'mit_dem',
#   'dem_auto',
#   'auto_durch',
#   'durch_europa',
#   'europa_goldelt',
#   'goldelt_und',
#   'und_ungerne',
#   'ungerne_fliegt',
#   'fliegt_muss',
#   'muss_ich',
#   'ich_da',
#   'da_schon',
#   'schon_ein',
#   'ein_bisschen',
#   'bisschen_neid',
#   'neid_unterdrücken',
#   'hier_kann',
#   'kann_selbst',
#   'selbst_ich',
#   'ich_mit',
#   'mit_zentimetern',
#   'zentimetern_körpergröße',
#   'körpergröße_von',
#   'von_schier',
#   'schier_unglaublicher',
#   'unglaublicher_beinfreiheit',
#   'beinfreiheit_sprechen',
#   'bei_umdrehungen',
#   'umdrehungen_auf',
#   'auf_dem',
#   'dem_tourenzähler',
#   'tourenzähler_stehen',
#   'stehen_beeindruckende',
#   'beeindruckende_nm',
#   'nm_zur',
#   'zur_verfügung',
#   'die_marke',
#   'marke_will',
#   'will_sich',
#   'sich_aber',
#   'aber_nicht',
#   'nicht_darauf',
#   'darauf_ausruhen',
#   'ausruhen_dass',
#   'dass_sie',
#   'sie_vergleichsweise',
#   'vergleichsweise_glimpflich',
#   'glimpflich_aus',
#   'aus_der',
#   'der_krise',
#   'krise_zu',
#   'zu_steuern',
#   'steuern_scheint',
#   'allerdings_brachte',
#   'brachte_die',
#   'die_tour',
#   'tour_für',
#   'für_alle',
#   'alle_teilnehmer',
#   'teilnehmer_die',
#   'die_erkenntnis',
#   'erkenntnis_mit',
#   'mit_dass',
#   'dass_der',
#   'der_größte',
#   'größte_spritverbraucher',
#   'spritverbraucher_hinter',
#   'hinter_dem',
#   'dem_lenkrad',
#   'lenkrad_sitzt',
#   'besetzt_mit',
#   'mit_drei',
#   'drei_personen',
#   'personen_und',
#   'und_beladen',
#   'beladen_mit',
#   'mit_viel',
#   'viel_gepäck',
#   'gepäck_hat',
#   'hat_er',
#   'er_es',
#   'es_noch',
#   'noch_schwerer',
#   'abstandswarner_und',
#   'und_bremsassistent',
#   'bremsassistent_sind',
#   'sind_in',
#   'in_aller',
#   'aller_regel',
#   'regel_an',
#   'an_den',
#   'den_tempomat',
#   'tempomat_gekoppelt',
#   'joseph_corré',
#   'corré_wird',
#   'wird_das',
#   'das_auto',
#   'auto_am',
#   'am_abend',
#   'abend_des',
#   'des_life',
#   'life_ball',
#   'ball_über',
#   'über_den',
#   'den_roten',
#   'roten_teppich',
#   'teppich_vor',
#   'vor_dem',
#   'dem_wiener',
#   'wiener_rathaus',
#   'rathaus_steuern',
#   'im_september',
#   'september_bringt',
#   'bringt_alfa',
#   'alfa_sein',
#   'sein_neues',
#   'neues_heißes',
#   'heißes_einstiegsmodell',
#   'keine_schlechte',
#   'schlechte_entwicklung',
#   'entwicklung_wenn',
#   'wenn_man',
#   'man_bedenkt',
#   'bedenkt_wie',
#   'wie_anton',
#   'anton_hunger',
#   'hunger_anmerkte',
#   'anmerkte_dass',
#   'dass_zuvor',
#   'zuvor_an',
#   'an_dieser',
#   'dieser_stelle',
#   'stelle_der',
#   'der_frauenparkplatz',
#   'frauenparkplatz_war',
#   'autowachs_oder',
#   'oder_politur',
#   'politur_versprechen',
#   'versprechen_brillianz',
#   'brillianz_und',
#   'und_lackkonservierung',
#   'lackkonservierung_über',
#   'über_wochen',
#   'im_dauerversuch',
#   'dauerversuch_wurden',
#   'wurden_jetzt',
#   'jetzt_sechs',
#   'sechs_produkte',
#   'produkte_getestet',
#   'ford_hinkt',
#   'hinkt_seinem',
#   'seinem_vorjahresabsatz',
#   'vorjahresabsatz_hinterher',
#   'hinterher_mit',
#   'mit_einem',
#   'einem_minus',
#   'minus_von',
#   'von_prozent',
#   'prozent_auf',
#   'auf_millionen',
#   'millionen_autos',
#   'hinderlich_für',
#   'für_den',
#   'den_blick',
#   'blick_nach',
#   'nach_außen',
#   'außen_sind',
#   'sind_auch',
#   'auch_hochgezogene',
#   'hochgezogene_heckpartien',
#   'heckpartien_und',
#   'und_immer',
#   'immer_schräger',
#   'schräger_werdende',
#   'werdende_frontscheiben',
#   'frontscheiben_kritisierten',
#   'kritisierten_die',
#   'selbst_ökolog',
#   'ein_witz',
#   'witz_aber',
#   'aber_fr',
#   'künast_empfiehlt',
#   'empfiehlt_doch',
#   'doch_toyota',
#   'toyota_also',
#   'also_alles',
#   'alles_im',
#   'im_lot',
#   'dazu_gibt',
#   'gibt_es',
#   'es_eine',
#   'eine_und',
#   'und_ein',
#   'ein_besonderes',
#   'besonderes_bremssystem',
#   'fotostrecke_bilder',
#   'bilder_rebmann',
#   'rebmann_je',
#   'je_seltener',
#   'seltener_ein',
#   'ein_wagen',
#   'wagen_ist',
#   'ist_desto',
#   'desto_wertvoller',
#   'wertvoller_ist',
#   'ist_er',
#   'er_meist',
#   'dies_hat',
#   'hat_regierungssprecher',
#   'regierungssprecher_ulrich',
#   'ulrich_wilhelm',
#   'wilhelm_am',
#   'am_montag',
#   'montag_klargestellt',
#   'aber_vorher',
#   'vorher_genau',
#   'genau_prüfen',
#   'das_gilt',
#   'gilt_natürlich',
#   'natürlich_auch',
#   'auch_für',
#   'aus_der',
#   'der_knight',
#   'knight_rider',
#   'rider_mit',
#   'mit_david',
#   'david_hasselhoff',
#   'koblenz_dpa',
#   'dpa_für',
#   'für_schäden',
#   'schäden_an',
#   'an_einem',
#   'einem_fahrzeug',
#   'fahrzeug_das',
#   'das_auf',
#   'auf_abschüssiger',
#   'abschüssiger_straße',
#   'straße_in',
#   'in_einen',
#   'einen_weiher',
#   'weiher_rollt',
#   'rollt_muss',
#   'muss_die',
#   'die_vollkaskoversicherung',
#   'vollkaskoversicherung_zahlen',
#   'ford_will',
#   'will_das',
#   'das_erbe',
#   'erbe_des',
#   'des_boss',
#   'boss_jetzt',
#   'jetzt_ausschlachten',
#   'ausschlachten_und',
#   'und_eine',
#   'eine_neuauflage',
#   'neuauflage_auf',
#   'auf_basis',
#   'basis_des',
#   'des_mustang',
#   'mustang_gt',
#   'gt_anbieten',
#   'im_januar',
#   'januar_war',
#   'war_der',
#   'der_tata',
#   'tata_nano',
#   'nano_zum',
#   'zum_spottpreis',
#   'spottpreis_von',
#   'von_euro',
#   'euro_da',
#   'die_gibt',
#   'gibt_es',
#   'es_nicht',
#   'nicht_zum',
#   'zum_nulltarif',
#   'das_vw',
#   'vw_hat',
#   'hat_immerhin',
#   'immerhin_schon',
#   'schon_lange',
#   'lange_wartezeiten',
#   'die_differenz',
#   'differenz_zwischen',
#   'zwischen_beiden',
#   'beiden_tarifen',
#   'tarifen_verlangte',
#   'verlangte_das',
#   'das_unternehmen',
#   'unternehmen_daraufhin',
#   'daraufhin_vom',
#   'vom_unfallgeschädigten',
#   'unfallgeschädigten_heißt',
#   'heißt_es',
#   'doch_wie',
#   'wie_lange',
#   'lange_die',
#   'die_straßenhüter',
#   'straßenhüter_die',
#   'die_sechs',
#   'sechs_kreisverkehre',
#   'kreisverkehre_und',
#   'und_die',
#   'die_kreuzungen',
#   'kreuzungen_ohne',
#   'ohne_ampeln',
#   'ampeln_den',
#   'den_verkehrsfluss',
#   'verkehrsfluss_noch',
#   'noch_geschmeidig',
#   'geschmeidig_halten',
#   'halten_können',
#   'können_bleibt',
#   'bleibt_abzuwarten',
#   'kein_schlechtes',
#   'schlechtes_paket',
#   'paket_für',
#   'für_einen',
#   'einen_dollar',
#   'dollar_teuren',
#   'teuren_einsteiger',
#   'mutmaßlich_ist',
#   'ist_sogar',
#   'sogar_die',
#   'die_ökobilanz',
#   'ökobilanz_der',
#   'der_luxusclubs',
#   'luxusclubs_in',
#   'in_ordnung',
#   'ordnung_denn',
#   'denn_immerhin',
#   'immerhin_werden',
#   'werden_die',
#   'die_eingesetzten',
#   'eingesetzten_rohstoffe',
#   'rohstoffe_wenigstens',
#   'wenigstens_angemessen',
#   'angemessen_genutzt',
#   'elektroantrieb_alles',
#   'alles_schon',
#   'schon_in',
#   'in_serie',
#   'serie_auf',
#   'auf_der',
#   'der_straße',
#   'die_neue',
#   'neue_steuer',
#   'steuer_könne',
#   'könne_theoretisch',
#   'theoretisch_schon',
#   'schon_am',
#   'am_juli',
#   'juli_in',
#   'in_kraft',
#   'kraft_treten',
#   'treten_heißt',
#   'heißt_es',
#   'für_sprit',
#   'sprit_steuern',
#   'steuern_und',
#   'und_versicherungen',
#   'versicherungen_müssen',
#   'müssen_ab',
#   'ab_dem',
#   'dem_januar',
#   'januar_deutlich',
#   'deutlich_mehr',
#   'mehr_berappen',
#   'von_amsterdam',
#   'amsterdam_über',
#   'über_das',
#   'das_frankfurter',
#   'frankfurter_elternhaus',
#   'elternhaus_zu',
#   'zu_weihnachten',
#   'weihnachten_nach',
#   'nach_wien',
#   'wien_und',
#   'und_dann',
#   'dann_nach',
#   'nach_rumänien',
#   'rumänien_dort',
#   'dort_wurde',
#   'wurde_es',
#   'es_erstmals',
#   'erstmals_richtig',
#   'richtig_kalt',
#   'kalt_und',
#   'und_an',
#   'an_der',
#   'der_grenze',
#   'grenze_haben',
#   'haben_beamte',
#   'beamte_versucht',
#   'versucht_uns',
#   'uns_abzuziehen',
#   'geht_der',
#   'der_energievorrat',
#   'energievorrat_während',
#   'während_der',
#   'der_fahrt',
#   'fahrt_zur',
#   'zur_neige',
#   'neige_gibt',
#   'gibt_es',
#   'es_an',
#   'an_bord',
#   'bord_einen',
#   'einen_kleinen',
#   'kleinen_dreizylinder',
#   'dreizylinder_sagt',
#   'sagt_lutz',
#   'dazu_wird',
#   'wird_alles',
#   'alles_länger',
#   'länger_gemacht',
#   'gemacht_die',
#   'die_verkabelung',
#   'verkabelung_das',
#   'das_bodenblech',
#   'bodenblech_die',
#   'die_antriebswelle',
#   'wirkt_das',
#   'das_auto',
#   'auto_bullig',
#   'bullig_elegant',
#   'elegant_oder',
#   'oder_sportlich',
#   'lange_fuhr',
#   'fuhr_bmw',
#   'bmw_dem',
#   'dem_hauptkonkurrenten',
#   'hauptkonkurrenten_audi',
#   'audi_mit',
#   'mit_seinem',
#   'seinem_mini',
#   'mini_im',
#   'im_kleinwagensegment',
#   'kleinwagensegment_davon',
#   'wir_zeigen',
#   'zeigen_die',
#   'die_perlen',
#   'perlen_im',
#   'im_schilderwald',
#   'die_italiener',
#   'italiener_präsentieren',
#   'präsentieren_den',
#   'den_schmucken',
#   'schmucken_italia',
#   'italia_als',
#   'als_nachfolger',
#   'nachfolger_des',
#   'zunächst_kümmerte',
#   'kümmerte_ich',
#   'ich_mich',
#   'mich_um',
#   'um_die',
#   'die_wie',
#   'wie_beispielsweise',
#   'beispielsweise_die',
#   'die_blinden',
#   'blinden_scheinwerfer',
#   'scheinwerfer_und',
#   'und_die',
#   'die_desaströse',
#   'desaströse_elektrik',
#   'elektrik_die',
#   'die_masseklemmen',
#   'masseklemmen_im',
#   'im_motorraum',
#   'motorraum_waren',
#   'waren_samt',
#   'samt_und',
#   'und_sonders',
#   'sonders_verrottet',
#   'verrottet_und',
#   'und_korrodiert',
#   'natürlich_sprüht',
#   'sprüht_ein',
#   'ein_koreanischer',
#   'koreanischer_kleinwagen',
#   'kleinwagen_in',
#   'in_dieser',
#   'dieser_preisklasse',
#   'preisklasse_nicht',
#   'nicht_vor',
#   'vor_esprit',
#   'esprit_wie',
#   'wie_vielleicht',
#   'vielleicht_ein',
#   'ein_mini',
#   'mini_oder',
#   'oder_ein',
#   'ein_fiat',
#   'fiat_immer',
#   'immer_mehr',
#   'mehr_autos',
#   'autos_werden',
#   'werden_zur',
#   'zur_mogelpackung',
#   'wie_soll',
#   'soll_das',
#   'das_klappen',
#   'klappen_sieben',
#   'sieben_personen',
#   'personen_in',
#   'in_einem',
#   'einem_kompaktvan',
#   'kompaktvan_transportieren',
#   'transportieren_beinfreiheit',
#   'beinfreiheit_vom',
#   'vom_fahrer',
#   'fahrer_bis',
#   'bis_zum',
#   'zum_hinterbänkler',
#   'hinterbänkler_und',
#   'und_dazu',
#   'dazu_noch',
#   'noch_einigermaßen',
#   'einigermaßen_raum',
#   'raum_für',
#   'für_die',
#   'die_wichtigsten',
#   'bei_der',
#   'der_des',
#   'des_iron',
#   'iron_man',
#   'man_im',
#   'im_berliner',
#   'berliner_kino',
#   'kino_cinemaxx',
#   'cinemaxx_lenkte',
#   'lenkte_downey',
#   'downey_den',
#   'den_aus',
#   'aus_ingolstadt',
#   'ingolstadt_selber',
#   'selber_an',
#   'an_den',
#   'den_roten',
#   'roten_teppich',
#   'euro_aufpreis',
#   'aufpreis_kostet',
#   'kostet_das',
#   'das_system',
#   'das_dsg',
#   'dsg_bietet',
#   'bietet_nicht',
#   'nicht_nur',
#   'nur_etwas',
#   'etwas_flottere',
#   'flottere_beschleunigungswerte',
#   'beschleunigungswerte_sondern',
#   'sondern_auch',
#   'auch_weniger',
#   'weniger_verbrauch',
#   'deutlich_besser',
#   'besser_soll',
#   'soll_es',
#   'es_dann',
#   'dann_im',
#   'im_nächsten',
#   'nächsten_frühjahr',
#   'frühjahr_werden',
#   'es_gab',
#   'gab_vor',
#   'vor_ein',
#   'ein_paar',
#   'paar_jahren',
#   'jahren_mal',
#   'mal_eine',
#   'eine_untersuchung',
#   'untersuchung_welche',
#   'welche_autos',
#   'autos_eigentlich',
#   'eigentlich_die',
#   'die_sichersten',
#   'sichersten_seien',
#   'die_a',
#   'a_ist',
#   'ist_ein',
#   'ein_komischer',
#   'komischer_weg',
#   'weg_der',
#   'der_immer',
#   'immer_einsamer',
#   ...],
#  'keyword/news_text100k.txt': ['jahre_arbeiterkammer',
#   'arbeiterkammer_bedeuten',
#   'bedeuten_jahre',
#   'jahre_einsatz',
#   'einsatz_für',
#   'für_soziale',
#   'soziale_gerechtigkeit',
#   'gerechtigkeit_und',
#   'und_solidarität',
#   'im_jahr',
#   'jahr_vor',
#   'vor_dem',
#   'dem_referendum',
#   'referendum_lagen',
#   'lagen_die',
#   'die_bayerischen',
#   'bayerischen_exporte',
#   'exporte_nach',
#   'nach_großbritannien',
#   'großbritannien_bei',
#   'bei_milliarden',
#   'milliarden_euro',
#   'dürfte_das',
#   'das_über',
#   'über_die',
#   'die_big',
#   'big_aggregierte',
#   'aggregierte_spitzenmietpreiswachstum',
#   'spitzenmietpreiswachstum_bei',
#   'bei_liegen',
#   'liegen_und',
#   'und_damit',
#   'damit_mit',
#   'mit_geringer',
#   'geringer_abschwächung',
#   'abschwächung_anhalten',
#   'ist_ein',
#   'ein_wichtiger',
#   'wichtiger_schritt',
#   'schritt_aber',
#   'aber_das',
#   'das_heißt',
#   'heißt_nicht',
#   'nicht_dass',
#   'dass_die',
#   'die_arbeit',
#   'arbeit_dann',
#   'dann_erledigt',
#   'erledigt_ist',
#   'ist_und',
#   'und_alles',
#   'alles_gelöst',
#   'gelöst_sein',
#   'sein_wird',
#   'jahre_sind',
#   'sind_genug',
#   'davis_geht',
#   'geht_angesichts',
#   'angesichts_der',
#   'der_herrschenden',
#   'herrschenden_kapitalistischen',
#   'kapitalistischen_produktionsweise',
#   'produktionsweise_zudem',
#   'zudem_davon',
#   'davon_aus',
#   'aus_dass',
#   'dass_sämtliche',
#   'sämtliche_formen',
#   'formen_unproduktiver',
#   'unproduktiver_arbeit',
#   'arbeit_nur',
#   'nur_durch',
#   'durch_intervention',
#   'intervention_des',
#   'des_staates',
#   'staates_oder',
#   'oder_das',
#   'das_zugeständnis',
#   'zugeständnis_der',
#   'der_herrschenden',
#   'herrschenden_klasse',
#   'klasse_entlohnt',
#   'entlohnt_werden',
#   'werden_können',
#   'aas_as',
#   'as_die',
#   'die_aktuellen',
#   'aktuellen_arbeiten',
#   'arbeiten_an',
#   'an_der',
#   'der_fleher',
#   'fleher_brücke',
#   'brücke_werden',
#   'werden_bis',
#   'bis_ende',
#   'ende_abgeschlossen',
#   'abgeschlossen_sein',
#   'sein_es',
#   'es_stehen',
#   'stehen_wieder',
#   'wieder_zwei',
#   'zwei_spuren',
#   'spuren_pro',
#   'pro_fahrtrichtung',
#   'fahrtrichtung_zur',
#   'zur_verfügung',
#   'a_renzenhof',
#   'renzenhof_zu',
#   'zu_einem',
#   'einem_schweren',
#   'schweren_verkehrsunfall',
#   'verkehrsunfall_mit',
#   'mit_fünf',
#   'fünf_verletzten',
#   'verletzten_darunter',
#   'darunter_ein',
#   'ein_schwerverletzter',
#   'schwerverletzter_ist',
#   'ist_es',
#   'es_am',
#   'am_gestrigen',
#   'gestrigen_sonntagabend',
#   'sonntagabend_auf',
#   'auf_der',
#   'der_azwischen',
#   'azwischen_der',
#   'der_anschlussstelle',
#   'anschlussstelle_und',
#   'und_dem',
#   'dem_autobahnkreuz',
#   'autobahnkreuz_nürnberg',
#   'nürnberg_gekommen',
#   'aachener_gastronomen',
#   'gastronomen_verlieren',
#   'verlieren_bis',
#   'bis_zu',
#   'zu_prozent',
#   'prozent_ihrer',
#   'ihrer_plätze',
#   'aaron_lahl',
#   'lahl_verdeutlicht',
#   'verdeutlicht_in',
#   'in_seinem',
#   'seinem_beitrag',
#   'beitrag_analyzing',
#   'analyzing_queer',
#   'queer_am',
#   'am_beispiel',
#   'beispiel_von',
#   'von_antke',
#   'antke_engel',
#   'engel_inwiefern',
#   'inwiefern_eine',
#   'eine_queere',
#   'queere_psychoanalyse',
#   'psychoanalyse_die',
#   'die_begriffe',
#   'begriffe_der',
#   'der_klassischen',
#   'klassischen_psychoanalyse',
#   'psychoanalyse_komplett',
#   'komplett_entkernt',
#   'entkernt_und',
#   'und_ihr',
#   'ihr_emanzipatorisches',
#   'emanzipatorisches_potential',
#   'potential_in',
#   'in_ihr',
#   'ihr_gegenteil',
#   'gegenteil_verkehrt',
#   'aaron_purschwitz',
#   'purschwitz_m',
#   'm_sicherte',
#   'sicherte_sich',
#   'sich_trotz',
#   'trotz_platz',
#   'platz_zwei',
#   'zwei_im',
#   'im_weitsprung',
#   'weitsprung_meter',
#   'ab_mai',
#   'mai_dürfen',
#   'dürfen_cafés',
#   'cafés_und',
#   'und_restaurants',
#   'restaurants_öffnen',
#   'öffnen_wenn',
#   'wenn_sie',
#   'sie_ihre',
#   'ihre_kundschaft',
#   'kundschaft_ausserhalb',
#   'ausserhalb_bedienen',
#   'ab_uhr',
#   'uhr_soll',
#   'soll_in',
#   'in_der',
#   'der_saalestadt',
#   'saalestadt_für',
#   'für_drei',
#   'drei_minuten',
#   'minuten_das',
#   'das_leben',
#   'leben_ruhen',
#   'ruhen_und',
#   'und_schweigend',
#   'schweigend_der',
#   'der_menschen',
#   'menschen_gedacht',
#   'gedacht_werden',
#   'werden_die',
#   'die_getötet',
#   'getötet_verletzt',
#   'verletzt_und',
#   'und_traumatisiert',
#   'traumatisiert_worden',
#   'worden_sind',
#   'ab_uhr',
#   'uhr_will',
#   'will_die',
#   'die_in',
#   'in_einer',
#   'einer_zuerst',
#   'zuerst_die',
#   'die_oberbürgermeister',
#   'oberbürgermeister_und',
#   'und_landräte',
#   'landräte_über',
#   'über_die',
#   'die_neuen',
#   'neuen_informieren',
#   'ab_dezember',
#   'dezember_sollen',
#   'sollen_die',
#   'die_ausgangsbeschränkungen',
#   'ausgangsbeschränkungen_fallen',
#   'fallen_kinos',
#   'kinos_theater',
#   'theater_und',
#   'und_museen',
#   'museen_wieder',
#   'wieder_öffnen',
#   'ab_juni',
#   'juni_würden',
#   'würden_die',
#   'die_grenzen',
#   'grenzen_zwischen',
#   'zwischen_deutschland',
#   'deutschland_und',
#   'und_österreich',
#   'österreich_wieder',
#   'wieder_komplett',
#   'komplett_offen',
#   'offen_sein',
#   'ab_uhr',
#   'uhr_werden',
#   'werden_mahntafeln',
#   'mahntafeln_übergeben',
#   'ab_galt',
#   'galt_die',
#   'die_und',
#   'und_respective',
#   'respective_in',
#   'in_der',
#   'der_festgelegt',
#   'festgelegt_wurde',
#   'wurde_dass',
#   'dass_sich',
#   'sich_in',
#   'in_jeder',
#   'jeder_quarantänestation',
#   'quarantänestation_ein',
#   'ein_leutnant',
#   'leutnant_und',
#   'und_berittene',
#   'berittene_männer',
#   'männer_drei',
#   'drei_wachen',
#   'wachen_und',
#   'und_ein',
#   'ein_doktor',
#   'doktor_befinden',
#   'befinden_mussten',
#   'ab_uhr',
#   'uhr_stehen',
#   'stehen_die',
#   'die_fohlen',
#   'fohlen_dem',
#   'dem_fk',
#   'fk_shakhtar',
#   'shakhtar_donetsk',
#   'donetsk_gegenüber',
#   'ab_mai',
#   'mai_dürfen',
#   'dürfen_die',
#   'die_gastronomie',
#   'gastronomie_im',
#   'im_und',
#   'und_innenbereich',
#   'innenbereich_sowie',
#   'sowie_die',
#   'die_ferienwohnungen',
#   'ferienwohnungen_und',
#   'und_campingplätze',
#   'campingplätze_wieder',
#   'wieder_schrittweise',
#   'schrittweise_öffnen',
#   'ab_wurden',
#   'wurden_etliche',
#   'etliche_von',
#   'von_ihnen',
#   'ihnen_in',
#   'in_und',
#   'und_konzentrationslager',
#   'konzentrationslager_verschleppt',
#   'ab_bis',
#   'bis_entstand',
#   'entstand_ein',
#   'ein_mehrfamilienhaus',
#   'mehrfamilienhaus_nach',
#   'nach_dem',
#   'dem_andern',
#   'andern_auch',
#   'auch_drei',
#   'drei_stöckige',
#   'stöckige_hochhäuser',
#   'ab_dezember',
#   'dezember_tritt',
#   'tritt_eine',
#   'eine_neue',
#   'neue_verordnung',
#   'verordnung_für',
#   'für_alle',
#   'alle_in',
#   'in_kraft',
#   'kraft_die',
#   'die_nach',
#   'nach_wollen',
#   'ab_uhr',
#   'uhr_liest',
#   'liest_dann',
#   'dann_am',
#   'am_freitag',
#   'freitag_februar',
#   'februar_johannes',
#   'johannes_twaroch',
#   'twaroch_im',
#   'im_gemeindefestsaal',
#   'gemeindefestsaal_von',
#   'von_kirchstetten',
#   'kirchstetten_aus',
#   'aus_seinem',
#   'seinem_anekdotenschatz',
#   'ab_juli',
#   'juli_will',
#   'will_beispielsweise',
#   'beispielsweise_einige',
#   'einige_urlaubsorte',
#   'urlaubsorte_wieder',
#   'wieder_für',
#   'für_touristen',
#   'touristen_öffnen',
#   'ab_juni',
#   'juni_gilt',
#   'gilt_aber',
#   'aber_wieder',
#   'wieder_fürs',
#   'fürs_parken',
#   'parken_muss',
#   'muss_gezahlt',
#   'gezahlt_werden',
#   'ab_mai',
#   'mai_sollen',
#   'sollen_dann',
#   'dann_alle',
#   'alle_anderen',
#   'anderen_geschäfte',
#   'geschäfte_friseure',
#   'friseure_und',
#   'und_einkaufszentren',
#   'einkaufszentren_öffnen',
#   'öffnen_ebenfalls',
#   'ebenfalls_mit',
#   'mit_strengen',
#   'strengen_auflagen',
#   'ab_märz',
#   'märz_senken',
#   'senken_viele',
#   'viele_versicherungen',
#   'versicherungen_die',
#   'die_beiträge',
#   'beiträge_für',
#   'für_die',
#   'die_haftpflicht',
#   'haftpflicht_für',
#   'ab_oktober',
#   'oktober_wird',
#   'wird_auch',
#   'auch_der',
#   'der_coausstoß',
#   'coausstoß_wie',
#   'wie_er',
#   'er_in',
#   'in_den',
#   'den_steht',
#   'steht_bei',
#   'bei_motorrädern',
#   'motorrädern_und',
#   'und_pkw',
#   'pkw_zur',
#   'zur_berechnung',
#   'berechnung_herangezogen',
#   'herangezogen_weiß',
#   'weiß_nikola',
#   'nikola_junick',
#   'ab_september',
#   'september_ziehen',
#   'ziehen_die',
#   'die_ersten',
#   'ersten_bewohner',
#   'bewohner_in',
#   'in_den',
#   'den_neubau',
#   'neubau_in',
#   'in_der',
#   'ab_uhr',
#   'uhr_live',
#   'live_aus',
#   'aus_der',
#   'der_staatsoper',
#   'ab_gibt',
#   'gibt_es',
#   'es_für',
#   'für_rund',
#   'rund_neun',
#   'neun_millionen',
#   'millionen_autofahrer',
#   'autofahrer_neue',
#   'neue_regionalklassen',
#   'regionalklassen_bei',
#   'bei_der',
#   'ab_solle',
#   'solle_unter',
#   'unter_dem',
#   'dem_titel',
#   'titel_dein',
#   'dein_jahr',
#   'jahr_für',
#   'für_deutschland',
#   'deutschland_ein',
#   'ein_neuer',
#   'neuer_dienst',
#   'dienst_eingeführt',
#   'eingeführt_werden',
#   'werden_sagte',
#   'sagte_in',
#   'in_berlin',
#   'berlin_im',
#   'im_rahmen',
#   'rahmen_einer',
#   'einer_virtuellen',
#   'ab_werde',
#   'werde_sich',
#   'sich_der',
#   'der_markt',
#   'markt_langsam',
#   'langsam_erholen',
#   'ab_soll',
#   'soll_dann',
#   'dann_vorwiegend',
#   'vorwiegend_auf',
#   'auf_material',
#   'material_aus',
#   'aus_inländischer',
#   'inländischer_produktion',
#   'produktion_umgestellt',
#   'umgestellt_werden',
#   'ab_uhr',
#   'uhr_erreichte',
#   'erreichte_die',
#   'die_familienserie',
#   'familienserie_um',
#   'um_himmels',
#   'himmels_willen',
#   'willen_dann',
#   'dann_im',
#   'im_ersten',
#   'ersten_millionen',
#   'millionen_prozent',
#   'prozent_die',
#   'die_krankenhausserie',
#   'krankenhausserie_wollten',
#   'wollten_im',
#   'im_anschluss',
#   'anschluss_in',
#   'in_aller',
#   'aller_freundschaft',
#   'freundschaft_millionen',
#   'millionen_prozent',
#   'prozent_sehen',
#   'ab_uhr',
#   'uhr_sahen',
#   'sahen_millionen',
#   'millionen_zuschauer',
#   'zuschauer_die',
#   'die_episode',
#   'episode_leuchtfeuer',
#   'ab_dezember',
#   'dezember_wird',
#   'wird_eine',
#   'eine_teststation',
#   'teststation_mit',
#   'mit_zwei',
#   'zwei_teststraßen',
#   'teststraßen_von',
#   'von_etwa',
#   'etwa_soldatinnen',
#   'soldatinnen_und',
#   'und_soldaten',
#   'soldaten_bis',
#   'bis_dezember',
#   'dezember_am',
#   'am_standort',
#   'standort_linz',
#   'linz_in',
#   'in_oberösterreich',
#   'oberösterreich_betrieben',
#   'ab_februar',
#   'februar_geht',
#   'geht_es',
#   'es_in',
#   'in_die',
#   'die_vergangenheit',
#   'vergangenheit_mit',
#   'mit_und',
#   'und_alias',
#   'alias_meyer',
#   'meyer_offerman',
#   'ab_märz',
#   'märz_läuft',
#   'läuft_immer',
#   'immer_montags',
#   'montags_die',
#   'die_neue',
#   'neue_feuer',
#   'feuer_und',
#   'und_flamme',
#   'ab_uhr',
#   'uhr_dürften',
#   'dürften_restaurants',
#   'restaurants_und',
#   'und_kneipen',
#   'kneipen_dann',
#   'dann_nicht',
#   'nicht_mehr',
#   'mehr_geöffnet',
#   'geöffnet_haben',
#   'ab_mai',
#   'mai_empfängt',
#   'empfängt_die',
#   'die_beliebte',
#   'beliebte_urlaubsregion',
#   'urlaubsregion_auch',
#   'auch_wieder',
#   'wieder_urlauber',
#   'urlauber_aus',
#   'aus_anderen',
#   'anderen_bundesländern',
#   'ab_juli',
#   'juli_werde',
#   'werde_das',
#   'das_vorstandsmitglied',
#   'vorstandsmitglied_renko',
#   'renko_dirksen',
#   'dirksen_die',
#   'die_arbeit',
#   'arbeit_des',
#   'des_vorstands',
#   'vorstands_koordinieren',
#   'koordinieren_teilte',
#   'teilte_das',
#   'das_unternehmen',
#   'unternehmen_am',
#   'am_freitag',
#   'freitag_mit',
#   'ab_september',
#   'september_reist',
#   'reist_oscarpreisträgerin',
#   'oscarpreisträgerin_hilary',
#   'hilary_swank',
#   'swank_million',
#   'million_dollar',
#   'dollar_baby',
#   'baby_ins',
#   'ins_all',
#   'ab_euro',
#   'euro_bei',
#   'bei_alternate',
#   'ab_uhr',
#   'uhr_schunkelten',
#   'schunkelten_sich',
#   'sich_die',
#   'die_klassen',
#   'klassen_auf',
#   'auf_den',
#   'den_tag',
#   'tag_ein',
#   'ab_uhr',
#   'uhr_wird',
#   'wird_der',
#   'der_bahnhof',
#   'bahnhof_köln',
#   'köln_evakuiert',
#   'evakuiert_ab',
#   'ab_dann',
#   'dann_wird',
#   'wird_auch',
#   'auch_der',
#   'der_zugverkehr',
#   'zugverkehr_unterbrochen',
#   'unterbrochen_sein',
#   'ab_anfang',
#   'anfang_übernimmt',
#   'übernimmt_bremen',
#   'ab_april',
#   'april_gilt',
#   'gilt_im',
#   'im_brunauquartier',
#   'brunauquartier_im',
#   'im_kreis',
#   'kreis_tempo',
#   'tempo_für',
#   'für_aussenstehende',
#   'aussenstehende_sind',
#   'sind_das',
#   'das_nur',
#   'nur_ein',
#   'ein_paar',
#   'paar_weitere',
#   'weitere_quartierstrassen',
#   'quartierstrassen_auf',
#   'auf_denen',
#   'denen_die',
#   'die_stadt',
#   'stadt_das',
#   'das_tempo',
#   'tempo_drosselt',
#   'ab_april',
#   'april_plant',
#   'plant_signa',
#   'signa_mit',
#   'mit_vorbereitenden',
#   'vorbereitenden_maßnahmen',
#   'maßnahmen_für',
#   'für_gründung',
#   'gründung_und',
#   'und_aushub',
#   'aushub_der',
#   'der_baugrube',
#   'baugrube_zu',
#   'zu_beginnen',
#   'ab_april',
#   'april_werden',
#   'werden_die',
#   'die_flugabwehrsysteme',
#   'flugabwehrsysteme_einsatzbereit',
#   'einsatzbereit_sein',
#   'abarhoun_bestritt',
#   'bestritt_trotz',
#   'trotz_seiner',
#   'seiner_erkrankung',
#   'erkrankung_partien',
#   'partien_in',
#   'in_der',
#   'der_letzten',
#   'letzten_saison',
#   'saison_und',
#   'und_traf',
#   'traf_dabei',
#   'dabei_zweimal',
#   'ab_august',
#   'august_fährt',
#   'fährt_der',
#   'der_twin',
#   'twin_city',
#   'city_liner',
#   'liner_dann',
#   'dann_wieder',
#   'wieder_nach',
#   'nach_bratislava',
#   'trotz_umsatzeinbussen',
#   'umsatzeinbussen_mit',
#   'mit_hoher',
#   'hoher_flughöhe',
#   'flughöhe_wie',
#   'wie_passt',
#   'passt_das',
#   'das_zusammen',
#   'ab_ca',
#   'uhr_war',
#   'war_eine',
#   'eine_abwanderung',
#   'abwanderung_der',
#   'der_teilnehmer',
#   'teilnehmer_spürbar',
#   'ab_da',
#   'da_konnte',
#   'konnte_der',
#   'der_fc',
#   'fc_die',
#   'die_partie',
#   'partie_offen',
#   'offen_gestalten',
#   'gestalten_bis',
#   'bis_rafael',
#   'rafael_czichos',
#   'czichos_in',
#   'in_einen',
#   'einen_zweikampf',
#   'zweikampf_mit',
#   'mit_baumgartner',
#   'baumgartner_kam',
#   'kam_der',
#   'der_österreicher',
#   'österreicher_fiel',
#   'fiel_und',
#   'und_schrie',
#   'schrie_und',
#   'und_der',
#   'der_referee',
#   'referee_daniel',
#   'daniel_siebert',
#   'siebert_nach',
#   'nach_auf',
#   'auf_falschwerweise',
#   'falschwerweise_strafstoß',
#   'strafstoß_entschied',
#   'abdallah_macht',
#   'macht_sein',
#   'sein_beruf',
#   'beruf_spaß',
#   'spaß_auch',
#   'auch_weil',
#   'weil_er',
#   'er_sich',
#   'sich_wandelt',
#   'ab_dem',
#   'dem_august',
#   'august_steht',
#   'steht_die',
#   'die_anlage',
#   'anlage_den',
#   'den_vereinen',
#   'vereinen_für',
#   'für_trainings',
#   'trainings_und',
#   'und_testspiele',
#   'testspiele_zur',
#   'zur_verfügung',
#   'ab_dem',
#   'dem_mai',
#   'mai_haben',
#   'haben_sportvereine',
#   'sportvereine_zudem',
#   'zudem_die',
#   'die_möglichkeit',
#   'möglichkeit_vereinseigene',
#   'vereinseigene_sporthallen',
#   'sporthallen_bzw',
#   'kursräume_wieder',
#   'wieder_zu',
#   'zu_öffnen',
#   'ab_dem',
#   'dem_november',
#   'november_startet',
#   'startet_ein',
#   'ein_testturnier',
#   'testturnier_mit',
#   'mit_acht',
#   'acht_der',
#   'der_clubs',
#   'clubs_darunter',
#   'darunter_ist',
#   'ist_auch',
#   'auch_der',
#   'der_ehc',
#   'ehc_red',
#   'red_bull',
#   'bull_münchen',
#   'ab_dem',
#   'dem_dezember',
#   'dezember_lockert',
#   'lockert_der',
#   'der_kanton',
#   'kanton_wallis',
#   'wallis_seine',
#   'ab_dem',
#   'dem_mai',
#   'mai_soll',
#   'soll_es',
#   'es_genauso',
#   'genauso_erfolgreich',
#   'erfolgreich_weitergehen',
#   'ab_dem',
#   'dem_märz',
#   'märz_stieg',
#   'stieg_die',
#   'die_zahl',
#   'zahl_der',
#   'der_durchgeführten',
#   'durchgeführten_tests',
#   'tests_stark',
#   'stark_an',
#   'an_in',
#   'in_den',
#   'den_vier',
#   'vier_tagen',
#   'tagen_bis',
#   'bis_zum',
#   'zum_märz',
#   'märz_wurden',
#   'wurden_im',
#   'im_schnitt',
#   'schnitt_menschen',
#   'menschen_getestet',
#   'ab_dem',
#   'dem_juli',
#   'juli_dürfen',
#   'dürfen_kunden',
#   'kunden_geschäfte',
#   'geschäfte_wieder',
#   'wieder_in',
#   'in_begleitung',
#   'begleitung_besuchen',
#   'ab_dem',
#   'dem_märz',
#   'märz_ist',
#   'ist_das',
#   'das_und',
#   'und_ride',
#   'ride_angebot',
#   'angebot_der',
#   'der_stadt',
#   'stadt_kostenlos',
#   'ab_dem',
#   'dem_oktober',
#   'oktober_fällt',
#   'fällt_die',
#   'die_obergrenze',
#   'obergrenze_von',
#   'von_personen',
#   'personen_für',
#   'für_veranstaltungen',
#   'ab_dem',
#   'dem_september',
#   'september_tritt',
#   'tritt_ein',
#   'ein_gesetz',
#   'gesetz_zur',
#   'zur_reform',
#   'reform_der',
#   'der_psychotherapeutenausbildung',
#   'psychotherapeutenausbildung_in',
#   'in_kraft',
#   'ab_dem',
#   'dem_mai',
#   'mai_kommen',
#   'kommen_je',
#   'je_nach',
#   'nach_bundesland',
#   'bundesland_und',
#   'und_region',
#   'region_die',
#   'die_ersten',
#   'ersten_lockerungen',
#   'ab_dem',
#   'dem_bahnhof',
#   'bahnhof_gösing',
#   'gösing_führt',
#   'führt_der',
#   'der_weg',
#   'weg_zum',
#   'zum_erlaufboden',
#   'erlaufboden_und',
#   'und_von',
#   'von_dort',
#   'dort_durch',
#   'durch_die',
#   'die_beeindruckenden',
#   'beeindruckenden_zum',
#   'zum_kraftwerk',
#   'kraftwerk_stierwaschboden',
#   'ab_dem',
#   'dem_heutigen',
#   'heutigen_mittwoch',
#   'mittwoch_dezember',
#   'dezember_gilt',
#   'gilt_für',
#   'für_und',
#   'und_elektronische',
#   'elektronische_zeitschriften',
#   'zeitschriften_der',
#   'der_ermäßigte',
#   'ermäßigte_mehrwertsteuersatz',
#   'mehrwertsteuersatz_von',
#   'von_prozent',
#   'ab_dem',
#   'dem_jahr',
#   'jahr_sollen',
#   'sollen_keine',
#   'keine_neuen',
#   'neuen_ölheizkessel',
#   'ölheizkessel_mehr',
#   'mehr_aufgestellt',
#   'aufgestellt_werden',
#   'ab_dem',
#   'dem_kommenden',
#   'kommenden_jahr',
#   'jahr_wird',
#   'wird_der',
#   'der_spanier',
#   'spanier_carlos',
#   'carlos_sainz',
#   'sainz_anstelle',
#   'anstelle_des',
#   'des_deutschen',
#   'deutschen_für',
#   'für_das',
#   'das_traditionsteam',
#   'traditionsteam_in',
#   'in_der',
#   'der_tätig',
#   'tätig_sein',
#   'sein_bestätigen',
#   'bestätigen_die',
#   'die_italiener',
#   'italiener_am',
#   'am_donnerstag',
#   'ab_dem',
#   'dem_kommenden',
#   'kommenden_januar',
#   'januar_gibt',
#   'gibt_es',
#   'es_pro',
#   'pro_krankheitsfall',
#   'krankheitsfall_drei',
#   'drei_tage',
#   'tage_bezahlten',
#   'bezahlten_urlaub',
#   'ab_dem',
#   'dem_kommenden',
#   'kommenden_montag',
#   'montag_zum',
#   'zum_beispiel',
#   'beispiel_können',
#   'können_studios',
#   'studios_in',
#   'in_wiederum',
#   'wiederum_den',
#   'den_betrieb',
#   'betrieb_aufnehmen',
#   'aufnehmen_in',
#   'in_ist',
#   'ist_das',
#   'das_ab',
#   'ab_pfingsten',
#   'pfingsten_wieder',
#   'wieder_möglich',
#   'möglich_alles',
#   'alles_unter',
#   'unter_bestimmten',
#   'bestimmten_auflagen',
#   'ab_dem',
#   'dem_kommenden',
#   'kommenden_wochenende',
#   'wochenende_fahren',
#   'fahren_nachts',
#   'nachts_bis',
#   'bis_auf',
#   'auf_weiteres',
#   'weiteres_keine',
#   'keine_züge',
#   'züge_und',
#   'und_busse',
#   'busse_mehr',
#   'ab_dem',
#   'dem_nachmittag',
#   'nachmittag_sind',
#   'sind_in',
#   'in_der',
#   'der_südwesthälfte',
#   'südwesthälfte_sowie',
#   'sowie_über',
#   'über_dem',
#   'dem_bergland',
#   'bergland_einzelne',
#   'einzelne_schauer',
#   'schauer_möglich',
#   'ab_dem',
#   'dem_siebten',
#   'siebten_monat',
#   ...],
#  'keyword/sport_50k.txt': ['freitag_ja',
#   'ja_da',
#   'da_sind',
#   'sind_schon',
#   'schon_welche',
#   'es_war',
#   'war_heute',
#   'heute_eine',
#   'eine_fantastische',
#   'fantastische_atmosphäre',
#   'atmosphäre_aber',
#   'aber_wir',
#   'wir_müssen',
#   'müssen_jetzt',
#   'jetzt_ganz',
#   'ganz_schnell',
#   'schnell_aus',
#   'aus_unseren',
#   'unseren_fehlern',
#   'fehlern_lernen',
#   'die_einnahme',
#   'einnahme_des',
#   'des_beliebten',
#   'beliebten_erythropoetin',
#   'erythropoetin_epo',
#   'epo_erhöht',
#   'erhöht_den',
#   'den_blutdruck',
#   'blutdruck_sowie',
#   'sowie_die',
#   'die_zahl',
#   'zahl_der',
#   'der_roten',
#   'roten_blutkörperchen',
#   'blutkörperchen_was',
#   'was_zur',
#   'zur_verdickung',
#   'verdickung_des',
#   'des_blutes',
#   'blutes_führt',
#   'haben_sie',
#   'sie_auch',
#   'auch_reaktionen',
#   'reaktionen_aus',
#   'aus_kanada',
#   'kanada_bekommen',
#   'zwangsabstieg_in',
#   'in_die',
#   'die_serie',
#   'serie_b',
#   'b_in',
#   'in_der',
#   'der_saison',
#   'saison_treu',
#   'treu_und',
#   'und_war',
#   'war_mit',
#   'mit_treffern',
#   'treffern_maßgeblich',
#   'maßgeblich_am',
#   'am_direkten',
#   'direkten_wiederaufstieg',
#   'wiederaufstieg_beteiligt',
#   'wesentlich_effektiver',
#   'effektiver_vor',
#   'vor_dem',
#   'dem_gegenerischen',
#   'gegenerischen_tor',
#   'tor_waren',
#   'waren_die',
#   'die_des',
#   'des_fv',
#   'fv_biberach',
#   'beide_ergebnisse',
#   'ergebnisse_flossen',
#   'flossen_in',
#   'in_das',
#   'das_endklassement',
#   'endklassement_ein',
#   'der_kündigte',
#   'kündigte_an',
#   'an_dass',
#   'dass_karabatic',
#   'karabatic_viele',
#   'viele_jahre',
#   'jahre_für',
#   'für_die',
#   'die_gelbhemden',
#   'gelbhemden_spielen',
#   'spielen_werde',
#   'werde_er',
#   'er_ist',
#   'ist_die',
#   'die_korsettstange',
#   'korsettstange_in',
#   'in_unserem',
#   'unserem_projekt',
#   'projekt_der',
#   'der_weltbeste',
#   'weltbeste_zu',
#   'zu_werden',
#   'sie_halten',
#   'halten_es',
#   'es_anders',
#   'das_sieger',
#   'sieger_hamilton',
#   'hamilton_zwischen',
#   'zwischen_räikkönen',
#   'räikkönen_links',
#   'links_und',
#   'und_heidfeld',
#   'die_wahrscheinlichkeit',
#   'wahrscheinlichkeit_dass',
#   'dass_ich',
#   'ich_in',
#   'in_münchen',
#   'münchen_mehr',
#   'mehr_zu',
#   'zu_tun',
#   'tun_bekomme',
#   'bekomme_als',
#   'als_im',
#   'im_pokal',
#   'pokal_in',
#   'in_hasborn',
#   'hasborn_ist',
#   'ist_groß',
#   'groß_erklärt',
#   'erklärt_er',
#   'er_und',
#   'und_grinst',
#   'mit_einem',
#   'einem_bei',
#   'bei_der',
#   'der_skg',
#   'skg_walldorf',
#   'walldorf_behauptete',
#   'behauptete_sich',
#   'sich_eintracht',
#   'eintracht_rsselsheim',
#   'rsselsheim_nach',
#   'nach_der',
#   'der_winterpause',
#   'winterpause_an',
#   'an_der',
#   'der_spitze',
#   'spitze_der',
#   'der_a',
#   'es_war',
#   'war_definitiv',
#   'definitiv_nicht',
#   'nicht_so',
#   'so_dass',
#   'dass_von',
#   'von_mir',
#   'mir_eine',
#   'eine_mannschaftsbesprechung',
#   'mannschaftsbesprechung_anberaumt',
#   'anberaumt_war',
#   'für_den',
#   'den_fc',
#   'fc_chelsea',
#   'chelsea_der',
#   'der_auf',
#   'auf_diverse',
#   'diverse_verletzte',
#   'verletzte_spieler',
#   'spieler_verzichten',
#   'verzichten_musste',
#   'musste_verkürzte',
#   'verkürzte_salomon',
#   'salomon_kalou',
#   'kalou_zwischenzeitlich',
#   'zwischenzeitlich_auf',
#   'auf_bei',
#   'bei_der',
#   'der_anschließenden',
#   'anschließenden_pressekonferenz',
#   'pressekonferenz_war',
#   'war_es',
#   'es_dann',
#   'dann_aber',
#   'aber_vorbei',
#   'vorbei_mit',
#   'mit_dem',
#   'dem_großen',
#   'großen_schweigen',
#   'nach_jahren',
#   'jahren_wurde',
#   'wurde_der',
#   'der_traum',
#   'traum_wahr',
#   'wahr_russland',
#   'russland_besiegte',
#   'besiegte_im',
#   'im_kanada',
#   'für_den',
#   'den_einstigen',
#   'einstigen_bundestrainer',
#   'bundestrainer_wirkte',
#   'wirkte_der',
#   'der_triumph',
#   'triumph_wie',
#   'wie_eine',
#   'eine_befreiung',
#   'durch_einen',
#   'einen_dritten',
#   'dritten_platz',
#   'platz_bei',
#   'bei_der',
#   'der_rallye',
#   'rallye_japan',
#   'japan_sicherte',
#   'sicherte_sich',
#   'sich_der',
#   'der_jahre',
#   'jahre_alte',
#   'alte_franzose',
#   'franzose_im',
#   'im_citroen',
#   'citroen_in',
#   'in_sapporo',
#   'sapporo_vorzeitig',
#   'vorzeitig_den',
#   'den_titel',
#   'trainer_ottmar',
#   'ottmar_hitzfeld',
#   'hitzfeld_hatte',
#   'hatte_mich',
#   'mich_nach',
#   'nach_barcelona',
#   'barcelona_für',
#   'für_das',
#   'das_in',
#   'in_berlin',
#   'berlin_suspendiert',
#   'dann_kann',
#   'kann_man',
#   'man_hinterher',
#   'hinterher_sagen',
#   'sagen_okay',
#   'okay_das',
#   'das_spiel',
#   'spiel_war',
#   'war_nicht',
#   'nicht_perfekt',
#   'perfekt_aber',
#   'aber_wir',
#   'wir_haben',
#   'haben_immerhin',
#   'immerhin_einen',
#   'einen_weiteren',
#   'weiteren_punkt',
#   'punkt_in',
#   'in_der',
#   'der_champions',
#   'champions_league',
#   'league_geholt',
#   'maria_riesch',
#   'riesch_hat',
#   'hat_im',
#   'im_riesenslalom',
#   'riesenslalom_ihren',
#   'ihren_ersten',
#   'ersten_podestplatz',
#   'podestplatz_eingefahren',
#   'das_wrde',
#   'wrde_den',
#   'den_wettkampf',
#   'wettkampf_erhhen',
#   'erhhen_und',
#   'und_wre',
#   'wre_auch',
#   'auch_aus',
#   'aus_trainingstechnischer',
#   'trainingstechnischer_sicht',
#   'sicht_sinnvoll',
#   'warum_ist',
#   'ist_frau',
#   'frau_meuli',
#   'meuli_mountainbikenatitrainerin',
#   'mountainbikenatitrainerin_obwohl',
#   'obwohl_sie',
#   'sie_ja',
#   'ja_snowboarderin',
#   'snowboarderin_war',
#   'die_klubbesitzer',
#   'klubbesitzer_porcedda',
#   'porcedda_und',
#   'und_alessandro',
#   'alessandro_menarini',
#   'menarini_suchen',
#   'suchen_demnach',
#   'demnach_einen',
#   'einen_käufer',
#   'timo_gebhart',
#   'gebhart_und',
#   'und_alexander',
#   'alexander_hleb',
#   'sicherten_im',
#   'im_mit',
#   'mit_ihren',
#   'ihren_treffern',
#   'treffern_vor',
#   'vor_zuschauern',
#   'zuschauern_den',
#   'den_sieg',
#   'sieg_der',
#   'der_gegen',
#   'gegen_den',
#   'den_harmlosen',
#   'harmlosen_nie',
#   'nie_gefährdet',
#   'gefährdet_war',
#   'wenn_wir',
#   'wir_den',
#   'den_impfstoff',
#   'impfstoff_bekommen',
#   'bekommen_werden',
#   'werden_wir',
#   'wir_ihn',
#   'ihn_den',
#   'den_spielern',
#   'spielern_sicher',
#   'sicher_anbieten',
#   'es_bedeute',
#   'bedeute_ihm',
#   'ihm_sehr',
#   'sehr_viel',
#   'viel_dass',
#   'dass_die',
#   'die_fans',
#   'fans_sein',
#   'sein_trikot',
#   'trikot_kaufen',
#   'kaufen_darum',
#   'darum_habe',
#   'habe_er',
#   'er_diesen',
#   'diesen_vorschlag',
#   'vorschlag_gemacht',
#   'weil_sven',
#   'sven_butenschön',
#   'butenschön_angeschlagen',
#   'angeschlagen_ist',
#   'ist_bauchmuskelprobleme',
#   'bauchmuskelprobleme_könnte',
#   'könnte_neuzugang',
#   'neuzugang_prestin',
#   'prestin_ryan',
#   'ryan_bereits',
#   'bereits_am',
#   'am_sonntag',
#   'sonntag_in',
#   'in_augsburg',
#   'augsburg_zu',
#   'zu_seinem',
#   'seinem_ersten',
#   'ersten_kommen',
#   'bilbao_der',
#   'der_tabellenelfte',
#   'tabellenelfte_der',
#   'der_primera',
#   'primera_division',
#   'division_war',
#   'war_durch',
#   'durch_toquero',
#   'in_führung',
#   'führung_gegangen',
#   'er_hat',
#   'hat_mit',
#   'mit_bayer',
#   'bayer_leverkusen',
#   'leverkusen_das',
#   'das_pokalfinale',
#   'pokalfinale_erreicht',
#   'erreicht_doch',
#   'doch_plötzlich',
#   'plötzlich_hieß',
#   'hieß_es',
#   'es_bei',
#   'bei_einem',
#   'einem_internetanbieter',
#   'internetanbieter_bruno',
#   'bruno_labbadia',
#   'labbadia_würde',
#   'würde_nach',
#   'nach_kaiserslautern',
#   'kaiserslautern_wechseln',
#   'von_anfang',
#   'anfang_an',
#   'an_abwehrspezialist',
#   'abwehrspezialist_werden',
#   'werden_wollte',
#   'wollte_roggisch',
#   'roggisch_dennoch',
#   'dennoch_nicht',
#   'sie_haben',
#   'haben_die',
#   'die_ersten',
#   'ersten_von',
#   'von_rund',
#   'rund_seiten',
#   'seiten_der',
#   'der_ermittlungsakten',
#   'ermittlungsakten_in',
#   'in_der',
#   'der_dopingaffäre',
#   'dopingaffäre_an',
#   'an_die',
#   'die_uci',
#   'uci_weitergeleitet',
#   'mit_jansen',
#   'jansen_und',
#   'und_kevin',
#   'kevin_kuranyi',
#   'kuranyi_den',
#   'den_löw',
#   'löw_in',
#   'in_der',
#   'der_bislang',
#   'bislang_wurde',
#   'wurde_ein',
#   'ein_trio',
#   'trio_bestehend',
#   'bestehend_aus',
#   'aus_gareth',
#   'gareth_barry',
#   'barry_mio',
#   'mio_roque',
#   'roque_santa',
#   'santa_cruz',
#   'cruz_mio',
#   'mio_und',
#   'und_carlos',
#   'carlos_tevez',
#   'tevez_mio',
#   'mio_verpflichtet',
#   'verpflichtet_doch',
#   'doch_die',
#   'die_shoppingtour',
#   'shoppingtour_des',
#   'des_scheichs',
#   'scheichs_ist',
#   'ist_noch',
#   'noch_lange',
#   'lange_nicht',
#   'nicht_beendet',
#   'das_ist',
#   'ist_für',
#   'für_uns',
#   'uns_ein',
#   'ein_großer',
#   'großer_und',
#   'und_wichtiger',
#   'wichtiger_schritt',
#   'innen_fehlt',
#   'fehlt_es',
#   'es_an',
#   'an_der',
#   'der_dichten',
#   'dichten_tennisatmosphäre',
#   'die_gäste',
#   'gäste_drängten',
#   'drängten_die',
#   'die_platzherren',
#   'platzherren_über',
#   'über_weite',
#   'weite_strecken',
#   'strecken_in',
#   'in_die',
#   'die_defensive',
#   'so_zog',
#   'zog_der',
#   'der_dsc',
#   'dsc_im',
#   'im_ersten',
#   'ersten_satz',
#   'satz_von',
#   'von_auf',
#   'auf_entscheidend',
#   'entscheidend_davon',
#   'singh_siegte',
#   'siegte_bei',
#   'bei_dem',
#   'dem_mit',
#   'mit_millionen',
#   'millionen_dotierten',
#   'dotierten_turnier',
#   'turnier_mit',
#   'mit_schlägen',
#   'schlägen_vor',
#   'vor_dem',
#   'dem_australier',
#   'australier_adam',
#   'adam_scott',
#   'scott_und',
#   'und_dem',
#   'dem_südafrikaner',
#   'südafrikaner_trevor',
#   'trevor_immelmann',
#   'hugo_almeida',
#   'almeida_erzielte',
#   'erzielte_in',
#   'in_der',
#   'der_minute',
#   'minute_das',
#   'das_entscheidende',
#   'entscheidende_tor',
#   'damit_war',
#   'war_lancia',
#   'lancia_hinter',
#   'hinter_thomas',
#   'thomas_becker',
#   'becker_nur',
#   'nur_zweitbester',
#   'zweitbester_bonner',
#   'bonner_korbjäger',
#   'bayern_braucht',
#   'braucht_noch',
#   'noch_zeit',
#   'zeit_werder',
#   'werder_ist',
#   'ist_nun',
#   'nun_mal',
#   'mal_keine',
#   'keine_gurkentruppe',
#   'ich_werde',
#   'werde_diese',
#   'diese_abfahrt',
#   'abfahrt_vermissen',
#   'vermissen_erzählt',
#   'erzählt_büchel',
#   'platini_kritisiert',
#   'kritisiert_in',
#   'in_ukraine',
#   'ukraine_eigentlich',
#   'eigentlich_war',
#   'war_die',
#   'die_em',
#   'em_abgehakt',
#   'abgehakt_aber',
#   'aber_ich',
#   'ich_hoffe',
#   'hoffe_dass',
#   'dass_es',
#   'es_noch',
#   'noch_mit',
#   'mit_einem',
#   'einem_einsatz',
#   'einsatz_über',
#   'über_die',
#   'die_klappt',
#   'klappt_sagte',
#   'sagte_der',
#   'der_wieskötter',
#   'wieskötter_potsdam',
#   'potsdam_dem',
#   'dem_sid',
#   'den_siegtreffer',
#   'siegtreffer_besorgte',
#   'besorgte_schließlich',
#   'schließlich_schmidt',
#   'schmidt_der',
#   'der_nach',
#   'nach_einer',
#   'einer_aus',
#   'aus_fünf',
#   'fünf_metern',
#   'metern_einschoss',
#   'die_untersuchungen',
#   'untersuchungen_gegen',
#   'gegen_die',
#   'die_ehemaligen',
#   'ehemaligen_mannschaftsärzte',
#   'mannschaftsärzte_lothar',
#   'lothar_heinrich',
#   'heinrich_und',
#   'und_andreas',
#   'andreas_schmid',
#   'schmid_laufen',
#   'laufen_weiter',
#   'arjen_robben',
#   'robben_macht',
#   'macht_sich',
#   'sich_über',
#   'über_lustig',
#   'lustig_liebt',
#   'liebt_die',
#   'die_familiäre',
#   'familiäre_atmosphäre',
#   'atmosphäre_bei',
#   'bei_den',
#   'den_bayern',
#   'bayern_schätzt',
#   'schätzt_die',
#   'die_spannung',
#   'spannung_in',
#   'in_der',
#   'der_bundesliga',
#   'bundesliga_und',
#   'und_erklärt',
#   'erklärt_wie',
#   'wie_trainer',
#   'trainer_van',
#   'van_gaal',
#   'gaal_wirklich',
#   'wirklich_tickt',
#   'eigentlich_habe',
#   'habe_er',
#   'er_nicht',
#   'nicht_noch',
#   'noch_einmal',
#   'einmal_kandidieren',
#   'kandidieren_wollen',
#   'wollen_sagte',
#   'sagte_der',
#   'der_alte',
#   'alte_und',
#   'und_neue',
#   'neue_vorsitzende',
#   'vorsitzende_gerhard',
#   'gerhard_keul',
#   'keul_steinau',
#   'so_meine',
# ...
#   'claudia_roth',
#   'roth_wer',
#   'wer_sex-attacken',
#   'sex-attacken_von',
#   'von_asylanten',
#   'asylanten_anprangert',
#   'anprangert_ist',
#   'ist_ein',
#   'geistiger_bruder',
#   'der_täter',
#   'fuck_you',
#   'you_from',
#   'from_switzerland',
#   'asylanten_grüne',
#   'grüne_im',
#   'im_februar',
#   'februar_kamen',
#   'kamen_nach',
#   'nach_neusten',
#   'neusten_angaben',
#   'angaben_in',
#   'in_der',
#   'der_ard',
#   'ard_tagesschau',
#   'tagesschau_trotz',
#   'trotz_grenzkontrollen',
#   'grenzkontrollen_auf',
#   'auf_balkanroute',
#   'balkanroute_asylanten',
#   'asylanten_nach',
#   'nach_deutschland',
#   'deutschland_die',
#   'die_unterbringung',
#   'unterbringung_im',
#   'im_gefängnis',
#   'gefängnis_nur',
#   'nur_weil',
#   'weil_man',
#   'man_verbrechen',
#   'verbrechen_begangen',
#   'begangen_hat',
#   'hat_ist',
#   'ist_ein',
#   'ein_verstoß',
#   'verstoß_gegen',
#   'gegen_die',
#   'die_menschenwürde.hungerstreik',
#   'menschenwürde.hungerstreik_rapefugees',
#   'rapefugees_merkel',
#   'merkel_wie',
#   'wie_ist',
#   'ist_diese',
#   'diese_schlampe',
#   'schlampe_eigentlich',
#   'eigentlich_auf',
#   'auf_die',
#   'die_idee',
#   'idee_gekommen',
#   'gekommen_das',
#   'das_land',
#   'land_so',
#   'so_tiefgreifend',
#   'tiefgreifend_zu',
#   'zu_verändern',
#   'merkelmussweg_refugeesnotwelcome',
#   'refugeesnotwelcome_der',
#   'der_weltfrauentag',
#   'weltfrauentag_ist',
#   'ist_eine',
#   'eine_farce',
#   'farce_angesichts',
#   'angesichts_der',
#   'der_durch',
#   'durch_die',
#   'die_merkeldiktatur',
#   'merkeldiktatur_vorangetriebenen',
#   'vorangetriebenen_islamisierung',
#   'islamisierung_europas',
#   'gratis_häuser',
#   'häuser_wohnungen',
#   'wohnungen_handys',
#   'handys_u.',
#   'u._öffitickets',
#   'öffitickets_mindestsicherung',
#   'mindestsicherung_straffreiheit',
#   'straffreiheit_vorreihung',
#   'vorreihung_in',
#   'in_ambulanzen',
#   'ambulanzen_schlaraffenland',
#   'zib_asylanten',
#   'asylanten_beateuhse',
#   'beateuhse_konzern',
#   'konzern_vermarktet',
#   'vermarktet_scharia',
#   'scharia_konforme',
#   'konforme_sexprodukte',
#   'sexprodukte_bitte',
#   'bitte_boykottiert',
#   'boykottiert_diese',
#   'diese_firma',
#   'laut_orban',
#   'orban_wird',
#   'wird_merkel',
#   'merkel_europa',
#   'europa_mit',
#   'mit_neuen',
#   'asylanten_fluten',
#   'fluten_zusätzlich',
#   'zusätzlich_zu',
#   'zu_den',
#   'den_millionen',
#   'millionen_die',
#   'die_sowieso',
#   'sowieso_kommen',
#   'ende_gelände',
#   'nach_den',
#   'den_wahlen',
#   'wahlen_werden',
#   'werden_wir',
#   'wir_griechenland',
#   'griechenland_riesige',
#   'riesige_asylanten-kontingente',
#   'asylanten-kontingente_abnehmen',
#   'wetten_annewill',
#   'annewill_in',
#   'in_diesem',
#   'diesem_moment',
#   'moment_wird',
#   'wird_die',
#   'die_ernst-grube-halle',
#   'ernst-grube-halle_endlich',
#   'endlich_geräumt',
#   'geräumt_leipzig',
#   'leipzig_npd',
#   'npd_jn',
#   'jn_legida',
#   'legida_refugeesnotwelcome',
#   'refugeesnotwelcome_illner',
#   'erst_hieß',
#   'hieß_es',
#   'es_es',
#   'es_kämen',
#   'kämen_nur',
#   'nur_top',
#   'top_arbeitskräfte',
#   'jetzt_lese',
#   'lese_ich',
#   'ich_nur',
#   'nur_von',
#   'von_wichsenden',
#   'wichsenden_vergewaltigenden',
#   'vergewaltigenden_betrügenden',
#   'betrügenden_asylanten',
#   'merkel_die',
#   'die_merkel',
#   'merkel_ist',
#   'ist_sehr',
#   'sehr_ich',
#   'ich_bezogen',
#   'sie_soll',
#   'soll_sich',
#   'sich_um',
#   'um_ihr',
#   'ihr_volk',
#   'volk_kümmern',
#   'annewill_refugees',
#   'refugees_refugeesnotwelcome',
#   'refugeesnotwelcome_slovenien',
#   'slovenien_macht',
#   'macht_die',
#   'die_grenze',
#   'grenze_dicht',
#   'noch_eine',
#   'eine_gute',
#   'gute_nachricht',
#   'merkelmussweg_abmerkeln',
#   'abmerkeln_refugeesnotwelcome',
#   'refugeesnotwelcome_luxushotels',
#   'luxushotels_werden',
#   'werden_in',
#   'in_asylanten',
#   'asylanten_unterkünfte',
#   'unterkünfte_umfunktioniert',
#   'umfunktioniert_deutsche',
#   'deutsche_müssen',
#   'müssen_in',
#   'in_primitiven',
#   'primitiven_heruntergekommenen',
#   'heruntergekommenen_slums',
#   'slums_leben.annewill',
#   'leben.annewill_ard',
#   'ard_niemand',
#   'niemand_hat',
#   'hat_mich',
#   'mich_gefragt',
#   'gefragt_ob',
#   'ob_ich',
#   'ich_das',
#   'das_schaffen',
#   'schaffen_will',
#   'asylwahn_rapefugees',
#   'rapefugees_volksentscheid',
#   'volksentscheid_zu',
#   'zu_asylrecht',
#   'asylrecht_grenzen',
#   'grenzen_dicht',
#   'dicht_merkel',
#   'merkel_muss',
#   'muss_weg',
#   'ausnahmen_beim',
#   'beim_mindestlohn',
#   'mindestlohn_sind',
#   'sind_auch',
#   'auch_überhaupt',
#   'überhaupt_nicht',
#   'nicht_mit',
#   'mit_der',
#   'der_scharia',
#   'scharia_vereinbar',
#   'vereinbar_wenn',
#   'wenn_moslems',
#   'moslems_betroffen',
#   'betroffen_sind',
#   'spd_cdu',
#   'cdu_deutschland',
#   'deutschland_pöbelnde',
#   'pöbelnde_asylanten',
#   'asylanten_zeigen',
#   'zeigen_kopf-ab-gesten',
#   'kopf-ab-gesten_und',
#   'und_stinkefinger',
#   'stinkefinger_in',
#   'in_clausnitz',
#   'laut_im',
#   'im_ulbig',
#   'ulbig_keine',
#   'keine_ermittlungen',
#   'ermittlungen_gg',
#   'asylanten_nur',
#   'nur_gg',
#   'geld_aus',
#   'aus_der',
#   'der_portokasse',
#   'portokasse_von',
#   'von_merkel',
#   'merkel_oder',
#   'oder_doch',
#   'doch_steuergeld',
#   'euro_für',
#   'für_un',
#   'un_flüchtlingshilfe',
#   'flüchtlingshilfe_asylanten',
#   'asylanten_es',
#   'es_nicht',
#   'nicht_die',
#   'die_angst',
#   'angst_vor',
#   'vor_asylanten',
#   'asylanten_sondern',
#   'sondern_die',
#   'die_überfremdung',
#   'überfremdung_deutschlands',
#   'und_ihr',
#   'ihr_politiker',
#   'politiker_wisst',
#   'wisst_dieses',
#   'dieses_auch',
#   'auch_ganz',
#   'ganz_genau',
#   'es_reicht',
#   'reicht_stopp',
#   'spahn_von',
#   'von_cdu',
#   'cdu_will',
#   'will_wegfall',
#   'wegfall_von',
#   'von_mindestlohn',
#   'mindestlohn_für',
#   'für_asylanten',
#   'klare_schlechterstellunf',
#   'schlechterstellunf_von',
#   'von_einheimischen',
#   'wenn_sich',
#   'sich_der',
#   'der_hass',
#   'hass_in',
#   'in_deutschland',
#   'deutschland_mal',
#   'mal_seinen',
#   'seinen_weg',
#   'weg_gebahnt',
#   'gebahnt_hat',
#   'hat_wen',
#   'wen_wird',
#   'wird_er',
#   'er_eigentlich',
#   'eigentlich_treffen',
#   'rapefugees_politiker',
#   'politiker_ossis',
#   'ossis_journalisten',
#   'd-radio_millionen',
#   'millionen_menschen',
#   'menschen_fluechtlinge',
#   'fluechtlinge_migranten',
#   'migranten_asylanten',
#   'asylanten_in',
#   'in_der',
#   'der_tuerkei',
#   'tuerkei_verhandlungen',
#   'verhandlungen_mit',
#   'mit_der',
#   'der_eu',
#   'eu_was',
#   'was_nützt',
#   'nützt_mir',
#   'mir_der',
#   'der_erde',
#   'erde_geld',
#   'kein_kranker',
#   'kranker_mensch',
#   'mensch_genießt',
#   'genießt_die',
#   'die_welt',
#   'goethe_deutschland',
#   'deutschland_hartziv',
#   'hartziv_merkel',
#   'merkel_fluechtlinge',
#   'fluechtlinge_asylanten',
#   'asylanten_vor',
#   'vor_einem',
#   'einem_jahr',
#   'jahr_mussten',
#   'mussten_eltern',
#   'eltern_wenn',
#   'wenn_töchter',
#   'töchter_ins',
#   'ins_schwimmbad',
#   'schwimmbad_gingen',
#   'gingen_nur',
#   'nur_überlegen',
#   'überlegen_ob',
#   'ob_sie',
#   'sie_schon',
#   'schon_schwimmen',
#   'schwimmen_können',
#   'rapefugees_hartaberfair',
#   'hartaberfair_andere',
#   'andere_eu',
#   'eu_länder',
#   'länder_sind',
#   'sind_land',
#   'land_und',
#   'und_bürger',
#   'bürger_wichtiger',
#   'wichtiger_als',
#   'als_asylanten',
#   'moralisch_ethisch',
#   'ethisch_und',
#   'und_finanziell',
#   'finanziell_verständlich',
#   'verständlich_besorgtegutmenschen',
#   'besorgtegutmenschen_regen',
#   'regen_sich',
#   'sich_auf',
#   'auf_khaled',
#   'khaled_von',
#   'von_asylanten',
#   'asylanten_getötet',
#   'lageso-toter_moabithilft',
#   'moabithilft_ente',
#   'ente_handgranate',
#   'handgranate_warfen',
#   'warfen_migranten',
#   'migranten_das',
#   'das_was',
#   'was_im',
#   'im_swr',
#   'swr_radio',
#   'radio_momentan',
#   'momentan_an',
#   'an_werbung',
#   'werbung_pro',
#   'pro_asylanten',
#   'asylanten_gemacht',
#   'gemacht_wird',
#   'wird_ist',
#   'ist_so',
#   'so_penetrant',
#   'penetrant_wie',
#   'wie_phase',
#   'phase_der',
#   'der_weihnachtssongs',
#   'weihnachtssongs_fastnachts-seeligkeit',
#   'fastnachts-seeligkeit_idee',
#   'idee_hartzer',
#   'hartzer_vs',
#   'vs_asylanten',
#   'asylanten_im',
#   'im_einzelkampf',
#   'wer_schneller',
#   'schneller_nen',
#   'nen_arbeits/ausbildungsplatz',
#   'arbeits/ausbildungsplatz_findet',
#   'findet_und',
#   'und_deutsch',
#   'deutsch_lernt/kann',
#   'lernt/kann_darf',
#   'darf_bleiben',
#   'schweden_in',
#   'in_bürgerkriegsartigen',
#   'bürgerkriegsartigen_zuständen',
#   'eine_lasche',
#   'lasche_konservative',
#   'konservative_und',
#   'und_eine',
#   'eine_irre',
#   'irre_sozialistische',
#   'sozialistische_regierung',
#   'regierung_fluten',
#   'fluten_das',
#   'das_land',
#   'land_mit',
#   'mit_asylanten',
#   'asylanten_utter',
#   'utter_zbale',
#   'zbale_in',
#   'in_this',
#   'this_hashtag',
#   'hashtag_rapefugees',
#   'rapefugees_gestern',
#   'gestern_kamen',
#   'kamen_die',
#   'die_asylanten',
#   'heute_nacht',
#   'nacht_wurde',
#   'wurde_versucht',
#   'versucht_einzubrechen',
#   'erschreckend_daß',
#   'daß_es',
#   'es_frauen',
#   'frauen_sind',
#   'sind_die',
#   'die_jahre',
#   'jahre_emanzipation',
#   'emanzipation_zugunsten',
#   'zugunsten_islamistischer',
#   'islamistischer_vergewaltiger',
#   'vergewaltiger_in',
#   'in_die',
#   'die_tonne',
#   'tonne_treten',
#   'rapefugees_afd',
#   'afd_deutschland',
#   'deutschland_übt',
#   'übt_karneval',
#   'karneval_nach',
#   'nach_den',
#   'den_regeln',
#   'regeln_der',
#   'der_scharia',
#   'scharia_weil',
#   'weil_da',
#   'da_eh',
#   'eh_bald',
#   'bald_nur',
#   'nur_noch',
#   'noch_moslems',
#   'moslems_feiern',
#   'feiern_werden',
#   'deutsche_frauen',
#   'frauen_aus',
#   'aus_angst',
#   'angst_zuhause',
#   'zuhause_wenn',
#   'wenn_ich',
#   'ich_mir',
#   'mir_den',
#   'den_mond',
#   'mond_gerade',
#   'gerade_so',
#   'so_anschaue',
#   'anschaue_die',
#   'die_islamisierung',
#   'islamisierung_des',
#   'des_abendlandes',
#   'abendlandes_ist',
#   'ist_doch',
#   'doch_schon',
#   'schon_längst',
#   'längst_durch',
#   'fakt_auf',
#   'auf_ard',
#   'ard_asylanten',
#   'asylanten_fahren',
#   'fahren_mit',
#   'mit_taxi',
#   'taxi_herum',
#   'herum_auf',
#   'auf_steuerzahlerkosten',
#   'merkel_macht',
#   'macht_es',
#   'es_möglich',
#   'asylanten_man',
#   'man_kann',
#   'kann_nicht',
#   'nicht_einf',
#   'einf_verschiedene',
#   'verschiedene_menschen',
#   'menschen_bzw',
#   'bzw_völker/kulturen',
#   'völker/kulturen_zusammenleg',
#   'zusammenleg_sagen',
#   'sagen_nun',
#   'nun_seit',
#   'seit_ma',
#   'ma_glückl',
#   'glückl_miteinander+versteht',
#   'miteinander+versteht_euch',
#   'euch_idomeni',
#   'idomeni_asylanten',
#   'asylanten_fluechtlinge',
#   'fluechtlinge_schöne',
#   'schöne_vorstellung',
#   'vorstellung_für',
#   'für_die',
#   'die_kameras',
#   'blanke_gewalt',
#   'merkel_drückt',
#   'drückt_daheim',
#   'daheim_krokodilstränen',
#   'krokodilstränen_ins',
#   'ins_kissen',
#   'keine_schnittmenge',
#   'schnittmenge_zwischen',
#   'zwischen_npd',
#   'npd_und',
#   'und_afd',
#   'es_gibt',
#   'gibt_die',
#   'die_schnittmenge',
#   'schnittmenge_die',
#   'die_afd',
#   'afd_gibt',
#   'gibt_sie',
#   'sie_nicht',
#   'nicht_zu',
#   'zu_arabisch',
#   'arabisch_als',
#   'als_schulsprache',
#   'schulsprache_islamisierung',
#   'islamisierung_deutschlands',
#   'deutschlands_in',
#   'in_vollem',
#   'vollem_gange',
#   'gange_stelle',
#   'stelle_mir',
#   'mir_gerade',
#   'gerade_vor',
#   'vor_wie',
#   'wie_es',
#   'es_wäre',
#   'wäre_wenn',
#   'wenn_die',
#   'die_saudis',
#   'saudis_in',
#   'in_deutschland',
#   'deutschland_einmarschieren',
#   'einmarschieren_würden',
#   'würden_scharia',
#   'scharia_krieg',
#   'krieg_in',
#   'in_syrien',
#   'syrien_wer',
#   'wer_hat',
#   'hat_uns',
#   'uns_verraten',
#   'die_sozialdemokraten',
#   'werner_faymann',
#   'faymann_ist',
#   'ist_derzeit',
#   'derzeit_eine',
#   'eine_paradebeispiel',
#   'paradebeispiel_dafür',
#   'kontingent_refugeesnotwelcome',
#   'refugeesnotwelcome_traurig',
#   'traurig_lieber',
#   'lieber_horst',
#   'horst_seehofer',
#   'seehofer_der',
#   'der_bayerische',
#   'bayerische_staat',
#   'staat_braucht',
#   'braucht_eine',
#   'eine_strategie',
#   'strategie_die',
#   'die_der',
#   'der_islamisierung',
#   'islamisierung_bayerns',
#   'bayerns_einen',
#   'einen_riegel',
#   'riegel_vorschiebt',
#   'sz_faz',
#   'faz_die',
#   'die_haben',
#   'haben_nix',
#   'nix_mehr',
#   'mehr_die',
#   'die_leute',
#   'leute_in',
#   'in_den',
#   'den_asylanten-heimen',
#   'gut_außer',
#   'außer_denen',
#   'denen_mit',
#   'mit_den',
#   'den_geklauten',
#   'geklauten_handys.maischberger',
#   'handys.maischberger_man',
#   'man_stelle',
#   'stelle_sich',
#   'sich_vor',
#   'vor_es',
#   'es_käme',
#   'käme_zum',
#   'zum_frieden',
#   'frieden_und',
#   'und_alle',
#   'alle_asylanten',
#   'asylanten_mit',
#   'mit_syrischen',
#   'syrischen_pässen',
#   'pässen_würden',
#   'würden_dorthin',
#   'dorthin_ausgeflogen',
#   'wir_von',
#   'von_der',
#   'der_cdu',
#   'cdu_schaffen',
#   'schaffen_es',
#   'es_weitere',
#   'weitere_millionen',
#   'millionen_asylanten',
#   'asylanten_nach',
#   'zu_locken',
#   'locken_und',
#   'und_die',
#   'die_dumme',
#   'dumme_bevölkerung',
#   'bevölkerung_zu',
#   'zu_melken',
#   'maischberger_fratscher',
#   'fratscher_geld',
#   'geld_für',
#   'für_migranten',
#   'migranten_als',
#   'als_investition.bis',
#   'investition.bis_dahin',
#   'dahin_weiterhin',
#   'weiterhin_rapefugees',
#   'rapefugees_islamisierung',
#   'islamisierung_und',
#   'und_is',
#   'is_terroristen',
#   'abmerkeln_egal',
#   'egal_welche',
#   'welche_partei',
#   'partei_man',
#   'man_wählt',
#   'wählt_nur',
#   'nur_orange',
#   'orange_oder',
#   'oder_apfelsine',
#   'annewill_einprozent',
#   'einprozent_grenzendicht',
#   'grenzendicht_refugees',
#   'refugees_refugeesnotwelcome',
#   'refugeesnotwelcome_deutschland',
#   'deutschland_das',
#   'das_griechenland',
#   'griechenland_das',
#   'das_jetzt',
#   'jetzt_alle',
#   'alle_beschlüsse',
#   'beschlüsse_zu',
#   'zu_asylanten',
#   'asylanten_blockieren',
#   'blockieren_will',
#   'will_is',
#   'is_aber',
#   'aber_nicht',
#   'nicht_das',
#   'das_land',
#   'land_das',
#   'das_quartalsweise',
#   'quartalsweise_milliarden',
#   'milliarden_schnorrt',
#   'schnorrt_oder',
#   'reker_beugt',
#   'beugt_sich',
#   'sich_islam',
#   'islam_und',
#   'und_scharia',
#   'scharia_schafft',
#   'schafft_für',
#   'für_frauen',
#   'frauen_sicherheitszonen',
#   'sicherheitszonen_=fluchtpunkte',
#   '=fluchtpunkte_flüchtlinge',
#   'flüchtlinge_köln',
#   'köln_massenvergewaltigungen',
#   'massenvergewaltigungen_maischberger',
#   'maischberger_liefers',
#   'liefers_wir',
#   'wir_achten',
#   'achten_frauen',
#   'frauen_für',
#   'für_viele',
#   'viele_von',
#   'von_den',
#   'den_rapefugees',
#   'rapefugees_ist',
#   'ist_das',
#   'das_wie',
#   'wie_ein',
#   'ein_paradies',
#   'paradies_hier.lasche',
#   'hier.lasche_strafen',
#   'strafen_bei',
#   'bei_vergewaltigungen',
#   'vergewaltigungen_perlen',
#   'perlen_aus',
#   'aus_der',
#   'der_redaktionskonferenz',
#   'redaktionskonferenz_heute',
#   'heute_idee',
#   'idee_für',
#   'für_buchtitel',
#   'buchtitel_das',
#   'das_wunder',
#   'wunder_von',
#   'von_dresden',
#   'dresden_islamisierung',
#   'islamisierung_ohne',
#   'ohne_muslime',
#   'muslime_nopegida',
#   'nopegida_nolegida',
#   'nolegida_wir',
#   'wir_werden',
#   'werden_noch',
#   'noch_gemeinsam',
#   'gemeinsam_auf',
#   'auf_pegida',
#   'pegida_stehen',
#   'stehen_schulter',
#   'schulter_an',
#   'an_schulter',
#   'schulter_bis',
#   'bis_zu',
#   'zu_den',
#   'den_zähnen',
#   'zähnen_bewaffnet',
#   'bewaffnet_im',
#   'im_bürgerkrieg',
#   'bürgerkrieg_gegen',
#   'gegen_rapefugees',
#   'rapefugees_schauhin',
#   'schauhin_merkel',
#   'merkel_rechnet',
#   'rechnet_mit',
#   'mit_mio',
#   'mio_neuen',
#   'neuen_asylanten',
#   'asylanten_in',
#   'zum_vergleich',
#   'vergleich_schätzung',
#   'schätzung_war',
#   'war_gekommen',
#   'gekommen_sind',
#   'sind_mio',
#   'dank_cdu',
#   'cdu_ich',
#   'ich_habe',
#   'habe_bis',
#   'bis_heute',
#   'heute_nicht',
#   'nicht_verstanden',
#   'verstanden_was',
#   'was_an',
#   'an_dunkelhäutigen',
#   'dunkelhäutigen_in',
#   'in_schwarzen',
#   'schwarzen_burkas',
#   'burkas_mit',
#   'mit_dunkler',
#   'bunt_sein',
#   'sein_soll',
#   'soll_islamisierung',
#   'islamisierung_dieser',
#   'dieser_sommer',
#   'sommer_wird',
#   'wird_der',
#   'der_sommer',
#   'sommer_der',
#   'der_rapefugees',
#   'rapefugees_schade',
#   'schade_das',
#   'das_die',
#   'die_wahlen',
#   'wahlen_nicht',
#   'nicht_im',
#   'im_herbst',
#   'herbst_sind',
#   'die_gedanken',
#   'gedanken_sind',
#   'sind_frei',
#   'frei_-nicht',
#   '-nicht_mehr',
#   'mehr_in',
#   'in_europa',
#   'europa_deutschland',
#   'deutschland_sophienhof',
#   'sophienhof_koelnbhf',
#   'koelnbhf_merkelmussweg',
#   ...]}

# %%
vocab = nltk.FreqDist(sum(bigram.values(),[]))

# %%
vocab = sorted(list(vocab.items()),key= lambda x: x[1], reverse=True)

# %%
vocab = [x[0] for x in vocab]

# %%
vocab[:100]
# Out:
# ['in_der',
#  'in_den',
#  'für_die',
#  'mit_dem',
#  'auf_den',
#  'bei_der',
#  'in_die',
#  'für_den',
#  'auf_die',
#  'und_die',
#  'auf_der',
#  'mit_einem',
#  'mit_der',
#  'auf_dem',
#  'an_der',
#  'von_der',
#  'bei_den',
#  'aus_dem',
#  'sich_die',
#  'auch_die',
#  'und_der',
#  'mehr_als',
#  'nach_dem',
#  'gibt_es',
#  'dass_die',
#  'ist_der',
#  'nicht_mehr',
#  'das_ist',
#  'in_deutschland',
#  'vor_allem',
#  'über_die',
#  'an_den',
#  'ist_die',
#  'um_die',
#  'für_das',
#  'aus_der',
#  'mit_den',
#  'vor_dem',
#  'an_die',
#  'in_einem',
#  'nicht_nur',
#  'es_ist',
#  'ist_das',
#  'gegen_die',
#  'nach_der',
#  'mit_einer',
#  'durch_die',
#  'gegen_den',
#  'sich_der',
#  'ist_ein',
#  'und_das',
#  'auch_in',
#  'hat_sich',
#  'in_einer',
#  'in_diesem',
#  'zu_den',
#  'um_prozent',
#  'millionen_euro',
#  'sind_die',
#  'von_den',
#  'noch_nicht',
#  'bis_zu',
#  'aber_auch',
#  'auch_der',
#  'dass_der',
#  'hat_die',
#  'wenn_sie',
#  'milliarden_euro',
#  'ist_es',
#  'wie_die',
#  'und_den',
#  'der_deutschen',
#  'den_usa',
#  'sich_in',
#  'vor_der',
#  'nur_noch',
#  'um_den',
#  'prozent_auf',
#  'die_in',
#  'über_den',
#  'der_in',
#  'dass_es',
#  'es_in',
#  'haben_die',
#  'für_eine',
#  'es_gibt',
#  'zu_einem',
#  'bis_zum',
#  'aber_nicht',
#  'bei_einem',
#  'sagte_der',
#  'nach_einem',
#  'auf_das',
#  'hat_der',
#  'in_dem',
#  'können_sie',
#  'die_deutsche',
#  'am_sonntag',
#  'am_freitag',
#  'sie_auf']

# %%
term_freq = {genre: nltk.FreqDist(text) for genre, text in bigram.items()}

# %%
term_freq
# Out:
# {'keyword/automobil_50k.txt': FreqDist({'in_der': 2134, 'in_den': 1487, 'mit_dem': 1478, 'für_die': 1275, 'auf_der': 1198, 'für_den': 1048, 'gibt_es': 972, 'auf_den': 962, 'ist_der': 936, 'auf_dem': 895, ...}),
#  'keyword/news_text100k.txt': FreqDist({'in_der': 2692, 'in_den': 1382, 'für_die': 1299, 'bei_der': 875, 'mit_dem': 839, 'auf_die': 810, 'und_die': 733, 'auf_der': 731, 'in_die': 696, 'an_der': 672, ...}),
#  'keyword/sport_50k.txt': FreqDist({'in_der': 4728, 'für_die': 1626, 'in_den': 1156, 'in_die': 1097, 'mit_dem': 1091, 'auf_den': 1086, 'nach_dem': 1052, 'bei_der': 899, 'für_den': 887, 'gegen_den': 857, ...}),
#  'keyword/wirtschaft_50k.txt': FreqDist({'in_der': 2147, 'in_den': 1934, 'für_die': 1730, 'bei_der': 915, 'um_prozent': 868, 'und_die': 855, 'milliarden_euro': 831, 'dass_die': 798, 'auf_den': 775, 'mit_der': 768, ...}),
#  'keywords/hatespeech': FreqDist({'in_der': 566, 'das_ist': 432, 'in_den': 339, 'in_deutschland': 327, 'und_die': 312, 'nicht_mehr': 306, 'für_die': 296, 'in_die': 246, 'auf_die': 216, 'ist_das': 211, ...})}

# %%
def create_dtm(dictionary,vocab):
    matrix=[]

    for value in dictionary.values():
        array=[]
        for word in vocab: 
            array.append(value.get(word, 0))
        matrix.append(array)    
    return np.array(matrix)

# %%
def tfidf(matrix, terms, voc,n):
    
    
    y=matrix.sum(axis=1)
    
    
    y=y[:,np.newaxis]
    tm= (np.divide(matrix,y)) * np.log(matrix.shape[0]/((matrix>0).sum(0)))
   
    idf_list=[]
   
    for i in range(tm.shape[0]):
        
        idf_list.append(tm[i].argsort()[::-1])
        
    docs={}
    doc_list=[]
    
 
    for index, key in enumerate(terms.keys()):
        for i in range(n):
            doc_list.append(voc[idf_list[index][i]])
        
        docs[key]= doc_list
        doc_list=[]
    return docs

# %%
dtm=create_dtm(term_freq,vocab)

# %%
results = tfidf(dtm, term_freq, vocab,1000)

# %%
result_list= results["keywords/hatespeech"]

# %%
for index, value in enumerate(result_list):
    result_list[index]= " ".join(value.split("_"))

# %%
result_list
# Out:
# ['die afd',
#  'der islam',
#  'der afd',
#  'bla bla',
#  'die flüchtlinge',
#  'die asylanten',
#  'le pen',
#  'den islam',
#  'die fresse',
#  'dem islam',
#  "geht 's",
#  'den arsch',
#  'afd wählen',
#  'pädophile und',
#  'die islamisierung',
#  'die gutmenschen',
#  'zum kotzen',
#  'ach du',
#  'schmarotzer pädophile',
#  'im erika',
#  'islam ist',
#  'frau petry',
#  'muss weg',
#  'für flüchtlinge',
#  'die moslems',
#  'die lügenpresse',
#  "gibt 's",
#  'partei deutschlands',
#  'und denunzianten',
#  'unsere politiker',
#  'den flüchtlingen',
#  'asylanten in',
#  'den knast',
#  'volk und',
#  'unsere regierung',
#  'islam gehört',
#  'spd schmarotzer',
#  'ein nazi',
#  'flüchtlinge sind',
#  'armes deutschland',
#  'die merkel',
#  'den asylanten',
#  'dem pack',
#  'lügenpresse und',
#  'von pegida',
#  'die muslime',
#  'der abgefuckten',
#  'sein volk',
#  'die grünen',
#  'das volk',
#  'eigene volk',
#  'die uno',
#  'für asylanten',
#  'die scharia',
#  'schaut euch',
#  'marine le',
#  'das pack',
#  'flüchtlinge nicht',
#  'gt am',
#  'wollte bescheid',
#  'frau le',
#  'fordern das',
#  'das misstrauensvotum',
#  'gegen herr',
#  'herr sigmar',
#  'gabriel bitte',
#  'twitter teilen',
#  'der ekelwilfred',
#  'sundance justnobody',
#  'von asylanten',
#  'so dumm',
#  'von flüchtlingen',
#  'flüchtlinge und',
#  'und kinder',
#  'beim herumsurfen',
#  'islam und',
#  'pfui teufel',
#  'ein flüchtling',
#  'maas und',
#  'liebe freunde',
#  'den koran',
#  'herumsurfen gesehen',
#  'du scheisse',
#  'merkel und',
#  'der merkel',
#  'teufel jagen',
#  'deutschen volkes',
#  'der islamisierung',
#  'keine flüchtlinge',
#  'und asylanten',
#  'asylanten zu',
#  'in d.',
#  'eigene bevölkerung',
#  'diesen abschaum',
#  'abschaum der',
#  'scheinheilgste partei',
#  'fettigen haaren',
#  'jagen und',
#  'seit ihr',
#  'grüße aus',
#  'sucht endlich',
#  'und co.',
#  'danke frau',
#  'knast mit',
#  'lasst uns',
#  'zum teufel',
#  'flüchtlinge die',
#  'grenzen dicht',
#  'saudi arabien',
#  'dieses pack',
#  'nein dies',
#  'wie krank',
#  'zur einschleusung',
#  'vorsätzliche beihilfe',
#  'deutsche bürger',
#  'die is',
#  'ist vorsätzliche',
#  'so ne',
#  'sofort raus',
#  'flüchtlinge aus',
#  'lach mich',
#  'die altparteien',
#  'ein jähriges',
#  'der lügenpresse',
#  'einschleusung von',
#  'ihr ja',
#  'hier her',
#  'die -jährige',
#  'erpressern gewalttätern',
#  'brandstiftern und',
#  'und nötigern',
#  'den sicherheitskräften',
#  'völker regiert',
#  'unterstützen ob',
#  'regiert zum',
#  'notre dame',
#  'schwager schwagerwars',
#  'selbe gilt',
#  'lebenslang und',
#  'zwar lebenslang',
#  'grundgesetzes also',
#  ' geld  ein',
#  'deine tweets',
#  'erfolg löschung',
#  'und gewaltverherlichern',
#  'gewalttätern und',
#  'die juden',
#  'in 🇩🇪',
#  'o. wilke',
#  'nötigern erpressern',
#  'tweets bei',
#  'würden bürgerkriegsflüchtlingen',
#  'bürgerkriegsflüchtlingen helfen',
#  'in syrien',
#  'von merkel',
#  'bei euch',
#  'afd in',
#  'afd ist',
#  'der flüchtlinge',
#  'flüchtlinge in',
#  'ihr land',
#  'seid ihr',
#  'kein nazi',
#  'verstand verloren',
#  'pegida aufdiestraße',
#  'ihr es',
#  'unsere kanzlerin',
#  'du nur',
#  'lasst sie',
#  'arsch vorbei',
#  'sagen da',
#  'kriminelle ausländer',
#  'im grenzdienst',
#  'der asylanten',
#  'ein -jähriger',
#  'bei annewill',
#  'ein scheiß',
#  'gutmenschen die',
#  'is doch',
#  'der scharia',
#  'die menschenwürde',
#  'asylanten und',
#  'und linke',
#  'keine rechte',
#  'die sklaven',
#  'eigenen volk',
#  'u. ihre',
#  'haaren wdr',
#  'vasallen merkels',
#  'merkel vasallen',
#  'besten blockieren',
#  'rot grün',
#  ' geld die',
#  'der afd-fraktion',
#  'danke merkel',
#  'a. merkel',
#  'unsere rentner',
#  'mit waffengewalt',
#  'ihr macht',
#  'flüchtlingen in',
#  'hetze gegen',
#  'also hochverrat',
#  'soviel zum',
#  'man man',
#  'wenn merkel',
#  'ich glaub',
#  'den moslems',
#  'volker beck',
#  'das maul',
#  'ihr alle',
#  'die migranten',
#  'die wahrheit',
#  'bescheid sagen',
#  'die denn',
#  'die moderatorin',
#  'lasst euch',
#  'alice schwarzer',
#  'euch nicht',
#  'ihr habt',
#  'unsere beide',
#  'beide völker',
#  'land zurück',
#  'ep europawahl',
#  'im koran',
#  'eine islamisierung',
#  'durch flüchtlinge',
#  "wär 's",
#  'flüchtlinge auf',
#  'migranten aus',
#  'der altparteien',
#  'ursula haverbeck',
#  'das kopftuch',
#  'koran und',
#  'sitzen geblieben',
#  'von redaktion',
#  'papa wilberg',
#  'flüchtlinge zu',
#  'schwagerwars gebtdenschwagerfrei',
#  'den schwager',
#  'twittersupport melden',
#  'löschung od',
#  'mit hetzlichendank',
#  'schulz ist',
#  'ohne rückgrat',
#  'für ne',
#  'refugees refugeesnotwelcome',
#  'dumme deutsche',
#  'hoffe es',
#  'islamisierung in',
#  'eigenen bürger',
#  'alle raus',
#  'noch ne',
#  'afd zu',
#  'von moslems',
#  'aufdiestraße montagistpegidatag',
#  'die zensur',
#  'mich warum',
#  'is ja',
#  'euch doch',
#  'mit euch',
#  'ihre frauen',
#  'den untergang',
#  'volk die',
#  'her kommen',
#  'über merkel',
#  'vergewaltigt und',
#  'kein psychoanalytiker',
#  'unser deutschland',
#  'scheisse auf',
#  'auf asyl',
#  'land gelassen',
#  'gehören nicht',
#  'dann gnade',
#  'vom volke',
#  'deutsche frauen',
#  'jähriges mädchen',
#  'der capitol',
#  'und merkel',
#  'als nazis',
#  'politiker sind',
#  'misstrauensvotum gegen',
#  'bei erfolg',
#  'euch mal',
#  'dieses video',
#  'und twitter',
#  'unsere kosten',
#  'wir fordern',
#  'des islam',
#  'claudia roth',
#  'recht hat',
#  'könnt ihr',
#  'als nazi',
#  'neue seite',
#  'der muslime',
#  'uns diesen',
#  'zu dumm',
#  'kommt mir',
#  'auf euch',
#  'gegen trump',
#  'merkel das',
#  'die schnauze',
#  'stellt euch',
#  'eine partei',
#  'ich hasse',
#  'afd und',
#  'heiko maas',
#  'na dann',
#  'meinen augen',
#  'unsere kinder',
#  'so sehe',
#  'merken das',
#  'ihr dummen',
#  'herr baumgartner',
#  'hungerstreik rapefugees',
#  'dieses ganze',
#  'gender studies',
#  "'s ja",
#  'strasse gehen',
#  'flüchtlinge ein',
#  'na wenn',
#  'ich lach',
#  'warum hört',
#  'wohle des',
#  'merkel muß',
#  'asyl zu',
#  'millionen asylanten',
#  'gegen flüchtlinge',
#  'gegen pegida',
#  'land geholt',
#  'was bist',
#  'diese verbrecher',
#  "'s noch",
#  'der koran',
#  'muss was',
#  'ich scheisse',
#  'nicht abgeschoben',
#  'muslime die',
#  'soviel zur',
#  'leute ihr',
#  'macht endlich',
#  'ach ne',
#  'psychoanalytiker sein',
#  'herr maas',
#  'mal bitte',
#  'euch schon',
#  'nur ne',
#  'und gutmenschen',
#  'mit eurer',
#  'alle es',
#  'bei pegida',
#  'unsere kultur',
#  'unsere gesetze',
#  'afd wähler',
#  'denn sowas',
#  'wehrt euch',
#  'krimigranten rapefugees',
#  'asylbewerber in',
#  'alle flüchtlinge',
#  'islam zu',
#  'von syrien',
#  'ne menge',
#  'der sozis',
#  'politische gegner',
#  'flüchtlinge als',
#  'ein linker',
#  'bin patriot',
#  'frau schwarzer',
#  'das merkel',
#  'die raute',
#  'religion des',
#  'multi kulti',
#  'roth ist',
#  'wie frau',
#  'er jahren',
#  'fresse halten',
#  'lande sind',
#  'islamisierung deutschlands',
#  'abgefuckten spd',
#  'read more',
#  'europawahl euelections',
#  'betroffen futschi',
#  ' geld und',
#  'endlich sucht',
#  'wilberg von',
#  'cc by-sa',
#  'wikimedia cc',
#  'die hetze',
#  'der arsch',
#  'video wurde',
#  'kahane funktioniert',
#  'stasifrau kahane',
#  'afd mit',
#  'dem niger',
#  'die europawahl',
#  'europawahl ep',
#  'euch kann',
#  'herr orban',
#  'sowas unterstützen',
#  'yvonne willicks',
#  'jaxxon sundance',
#  'justnobody deine',
#  'bin gerade',
#  'pegida und',
#  'die abgefuckte',
#  'merkels vasallen',
#  'die bundes',
#  'bundes regierung',
#  'von östereich',
#  'östereich noch',
#  'deutschland sagen',
#  'hoch kriminellen',
#  'der abschaum',
#  'kriminellen brandstiftern',
#  'dieser parteien',
#  'parteien michboche',
#  'ein hurensohn',
#  'michboche und',
#  'vor lachen',
#  'der spd',
#  'schande für',
#  'dieses land',
#  'von frau',
#  'merkel macht',
#  'moderatorin der',
#  'der flüchtlingskrise',
#  'nach syrien',
#  'von migranten',
#  'hetze und',
#  'ohne gnade',
#  'sie recht',
#  'justiz oder',
#  'gegen merkel',
#  'na da',
#  'volk zu',
#  'des islamischen',
#  'deutschen bürger',
#  'wie merkel',
#  'gefällt mir',
#  'geld da',
#  'wir schaffen',
#  'wo ist',
#  'martin schulz',
#  'merkel will',
#  'na und',
#  'einer lebenden',
#  'politiker in',
#  'anschließend bei',
#  'der brd',
#  'den verstand',
#  'gestern kann',
#  'aus syrien',
#  'ein kopftuch',
#  'spd cdu',
#  'sexuelle belästigung',
#  'sollte mal',
#  'wer bezahlt',
#  'oh mann',
#  'etablierten parteien',
#  'deutschen volk',
#  'unsere polizei',
#  'da könnt',
#  'die scheiße',
#  'mit hetze',
#  'warum kommt',
#  'mir schlecht',
#  'euch ihr',
#  'in eurem',
#  'solche idioten',
#  'spricht mir',
#  'unsere neuen',
#  'ausländer und',
#  'den scheiß',
#  'wahrheit sagt',
#  'ausländer raus',
#  'was dagegen',
#  'die invasoren',
#  'mir echt',
#  'gespannt wann',
#  'lied wenn',
#  'medien schweigen',
#  'sag nur',
#  'euch zusagt',
#  'verrecken lassen',
#  'teilt dieses',
#  'zu spühren',
#  'kampfansage gegen',
#  'song von',
#  'hip-hop song',
#  'ein hip-hop',
#  'einwanderung in',
#  'wie z.b',
#  "für 's",
#  'politiker haben',
#  'lügen lügen',
#  'zur meinungsfreiheit',
#  'hört doch',
#  'diktatur und',
#  'bitte euch',
#  'meine fresse',
#  'von rapefugees',
#  'die herkommen',
#  'na super',
#  'glaubst du',
#  'schützt uns',
#  'ich ziehe',
#  'grenzen sichern',
#  'schluss damit',
#  'das ns-regime',
#  'religion ist',
#  'scharia in',
#  'asylanten werden',
#  'euer land',
#  'islamisierung ist',
#  'afd deutschland',
#  'mit asylanten',
#  'merkel oder',
#  'in clausnitz',
#  'asylanten nach',
#  'es hören',
#  'einwanderung und',
#  'bei lanz',
#  'mal selber',
#  'afd nicht',
#  'ihr grünen',
#  'frau dr.',
#  'diese idioten',
#  'politisch korrekt',
#  'frauke petry',
#  'euch in',
#  'migranten und',
#  'nicht benehmen',
#  'sofort abgeschoben',
#  'mir kommt',
#  'simone peter',
#  'hat jemand',
#  'grüne wollen',
#  'eigenen landsleute',
#  'bei merkel',
#  'wer schützt',
#  'mutti merkel',
#  'zusagt damit',
#  'auf grundeis',
#  'traurig was',
#  'nicht spenden',
#  'liebe bessermenschen',
#  'sylvia stolz',
#  'im bt',
#  'cdu afd',
#  'mit messer',
#  'zur euwahl',
#  'oesterreich neuwahlen',
#  "'das ist",
#  'in roßlau',
#  'wünsche den',
#  'mit religion',
#  'wünsche euch',
#  'des korans',
#  '-unterschreiben und',
#  'bürger wehren',
#  'frau will',
#  'uno ist',
#  'hetze der',
#  'auf demos',
#  'muß weg',
#  'der pegida',
#  'der burka',
#  'der notredame',
#  'afd sachsen',
#  'freie meinung',
#  'frau nahles',
#  'die nahles',
#  'ein sozi',
#  'deutsche botschaft',
#  'abgefuckte spd',
#  'laßt doch',
#  'diese volksverräterin',
#  'grün versiffte',
#  'merkel vasall',
#  'justnobody dich',
#  'bei twittersupport',
#  'döner mehr',
#  ' geld das',
#  ' junge mdl die',
#  ' k  de',
#  'oder o.',
#  'wiltewka oder',
#  'ekelwilfred wiltewka',
#  'mit kopftuch',
#  'auswärtigen amtes',
#  'oh je',
#  'wisst ihr',
#  'ganzes land',
#  'frau steinbach',
#  'bitte mal',
#  'keine altparteien',
#  'ich lachen',
#  'ne gute',
#  'wählt keine',
#  'lug und',
#  'die flüchtlingskrise',
#  'oh mein',
#  'am volk',
#  'hat frau',
#  'der asylpolitik',
#  'meine hochachtung',
#  'unseren medien',
#  'unserer kultur',
#  'alle was',
#  'ihr da',
#  'unsere heimat',
#  'offenen augen',
#  'zu ddr',
#  'das allerletzte',
#  'so ihr',
#  'ne neue',
#  'noch frei',
#  'der de',
#  'volk nicht',
#  'das geschrei',
#  'sie herkommen',
#  'merkel so',
#  'ach nee',
#  'so verblödet',
#  'unsere freiheit',
#  'oder saudi',
#  'turkei oder',
#  'dumm sind',
#  'nicht integrieren',
#  'kein asyl',
#  'was merkel',
#  'albert schweitzer',
#  'festung europa',
#  'arsch in',
#  'belogen und',
#  'hab gerade',
#  'eine -jährige',
#  'aber wehe',
#  'meinungsfreiheit in',
#  'die sed',
#  'taschen voll',
#  'klasse rede',
#  'merkel sie',
#  'deutsche volk',
#  'schaffen das',
#  'ha ha',
#  'am arsch',
#  'unserem land',
#  'wird zeit',
#  'raus mit',
#  'ihr seid',
#  'ja die',
#  'ich dir',
#  'die sowas',
#  'afd als',
#  'zu nichts',
#  'im arsch',
#  'und flüchtlinge',
#  'muslime in',
#  'afd hat',
#  'meine lieben',
#  'guten morgen',
#  'das arme',
#  'von linken',
#  'sie halt',
#  'werden dich',
#  'doch gerne',
#  'sexuelle übergriffe',
#  'frag mich',
#  'schäme mich',
#  'unserer regierung',
#  'gegen deutsche',
#  'merkel für',
#  'der meinungsfreiheit',
#  'land kommen',
#  'verraten und',
#  'traurig aber',
#  'des friedens',
#  'danke an',
#  'hass und',
#  'den nachrichten',
#  'wacht endlich',
#  'selber schuld',
#  'angst haben',
#  'der täter',
#  'hoffe das',
#  'der hose',
#  'der krieg',
#  'da sieht',
#  'des grundgesetzes',
#  'der staat',
#  'der ddr',
#  'der cdu',
#  'danke für',
#  'meine meinung',
#  'das selbe',
#  'bitte auf',
#  'euch die',
#  'junge männer',
#  'im bundestag',
#  'von bundes-',
#  'weitergehen in',
#  'zentralrat der',
#  'afd an',
#  'ibizagate oesterreich',
#  'meuthen euwahl',
#  'europawahl meuthen',
#  'strache ep',
#  ' meuthen bei',
#  'afd-spitzenkandidat  meuthen',
#  'böhmermann ist',
#  'afd ➡️',
#  'friday for',
#  'via  news',
#  'polizei amp',
#  'der eu-wahl',
#  'hofgarten von',
#  'dem -jährigen',
#  "'allahu akbar",
#  'dem koran',
#  'altparteien und',
#  'dreck am',
#  'robert habeck',
#  'in rheinland-pfalz',
#  'christen werden',
#  'weilesreicht dankespd',
#  'moslems und',
#  'so machen',
#  'ein erbärmlicher',
#  'und heuchler',
#  'zur europawahl',
#  'und missbraucht',
#  'hallo frau',
#  'syrer und',
#  'matteo salvini',
#  'moslems in',
#  'illegal eingereiste',
#  'deutsches mädchen',
#  'ernst cran',
#  'daniel cohn-bendit',
#  'deutschland 🇩🇪',
#  'terroristen und',
#  'afd stärkste',
#  'ein verbrecher',
#  'mdl köbberling',
#  'lachen oder',
#  'moslems sind',
#  'diese scheiß',
#  'invasoren die',
#  'alle zurück',
#  'keine religion',
#  'bitte eine',
#  'ihr lieben',
#  'und helft',
#  'wer denkt',
#  'fragt mal',
#  'und glaube',
#  'euch werden',
#  'raus raus',
#  'mit sowas',
#  'ironie aus',
#  'einfach aktiv',
#  'werdet einfach',
#  'kommunalpolitiker werdet',
#  'euren kommunalpolitiker',
#  'schreibt euren',
#  'demos schreibt',
#  'politik anzugehen',
#  'helft unser',
#  'wie wahr',
#  'sind nazis',
#  'arsch auf',
#  'die ideologie',
#  'bravo tschechien',
#  'interessanter artikel',
#  'anderer religionen',
#  'zum plan',
#  'unseres herrn',
#  'der hetze',
#  'wahrheit gesagt',
#  'diesen verlogenen',
#  'land wo',
#  'krieg ist',
#  'merkel der',
#  'ihre partei',
#  'herrn jesus',
#  'in turkei',
#  'kräftige männer',
#  'die scheiß',
#  'junge kräftige',
#  'ddr hat',
#  'kriminelle asylbewerber',
#  'ja nix',
#  'aufzustehen und',
#  'landesaufgaben die',
#  'absatz bezeichneten',
#  'bezeichneten personen',
#  'dem grenzdienst',
#  'grenzdienst übertragen',
#  'flüchtlinge jetzt',
#  'die schwedendemokraten',
#  'will flüchtlinge',
#  'unseren grenzen',
#  'doch nix',
#  'den ern',
#  'des grauens',
#  'mehrfach geld',
#  'dieses dreckspack',
#  'alle gutmenschen',
#  'doch super',
#  'diesen verbrechern',
#  'drecks pack',
#  'garnicht erst',
#  'hab mich',
#  'in absatz',
#  'und landesaufgaben',
#  'dummes gelaber',
#  'bundes- und',
#  'eine religiöse',
#  'und fettigen',
#  'die scheinheilgste',
#  'hundert stimmen',
#  'lieber hundert',
#  'alten schmoddrigen',
#  'schmoddrigen schwarzen',
#  'servicezeit wdr',
#  'den fettigen',
#  'abgefuckte hühnerscheisse',
#  'axel stoll',
#  'arsch von',
#  'dreck verrecken',
#  'spd politiker',
#  'wie strunzdumm',
#  'sklaven der',
#  'abgefuckten altparteien',
#  'vor menschenverachtung',
#  'der rache',
#  'der pfaffe',
#  'keine moslems',
#  'minderheit in',
#  'rebeccas verschwinden',
#  'war vorherzusehen',
#  'der schwager',
#  'richtigen orten',
#  'alias ekelwilfred',
#  'medien presse',
#  'alias der',
#  'jetzt hört',
#  'tages folge',
#  'ich afd',
#  'dich zerstören.',
#  'dich fressen',
#  'gleichgestellte akzeptieren',
#  'sozial gleichgestellte',
#  'als sozial',
#  'nie sie',
#  'afrikanische herrenrasse…',
#  'schweitzer über',
#  'horst mahler',
#  'blöd sind',
#  'vor rebeccas',
#  ' junge mdl der',
#  'im schland',
#  ' geld was',
#  'gehirn prothesen',
#  'die öffentlich-rechtlichen',
#  'wie dämlich',
#  'wand gestanden',
#  'schaukel als',
#  'vasall merkels',
#  'hölle mit',
#  'sitzengeblieben und',
#  'rassistische ideologie',
#  'uns juden',
#  'und schulz',
#  'linken anarchisten',
#  'tweets von',
#  'dich od',
#  'hetzlichendank abklatschen',
#  'twitter-support melden',
#  'euelections ep',
#  'diese schmarotzer',
#  ' geld der',
#  'aktuelle politik',
#  'endlich aufzustehen',
#  'als grenzdienst',
#  'islamischen staates',
#  'dann fragen',
#  'mehr tragbar',
#  'diese massen',
#  'deutschland da',
#  'scheisse ist',
#  'deutschen volke',
#  'länder nicht',
#  'illegale einwanderer',
#  'regierung mal',
#  'invasoren zu',
#  'gewollt ist',
#  'doch bloß',
#  'gute frau',
#  'afd auch',
#  "'s aus",
#  'liebe leute',
#  "sieht 's",
#  'tolle frau',
#  'vergessen das',
#  'kim jong',
#  'wir habens',
#  'danke herr',
#  'ein schwachsinn',
#  'dich mal',
#  'wenigstens einer',
#  'vollkommen recht',
#  'hat vollkommen',
#  'millionen flüchtlingen',
#  'mehr hören',
#  'an flüchtlinge',
#  'den salat',
#  'jetzt habt',
#  'volk da',
#  'ihr sie',
#  'wenn europa',
#  'bestimmt was',
#  'straße leben',
#  'weg weg',
#  'merkel denn',
#  'dummen deutschen',
#  'realität verloren',
#  'wo waren',
#  'flüchtlinge bekommen',
#  'dummes deutschland',
#  'würdet ihr',
#  'kriminalität durch',
#  'geht alle',
#  'ddr zeiten',
#  'hab ne',
#  'so denkt',
#  'deutschland schafft',
#  'glaubt wird',
#  'der waffel',
#  'unsere meinung',
#  'heuchler und',
#  'zu vk',
#  'bitte einen',
#  'macht ne',
#  'du was',
#  'die islamisten',
#  'partei für',
#  'polizei lässt',
#  'sie erkennen',
#  'teilen teilen',
#  'gibt genug',
#  'keinen pass',
#  'wandern fälle',
#  'seh ich',
#  'hasse die',
#  'an recht',
#  'deutsche rentner',
#  'zur gewalt',
#  'die made',
#  'habt es',
#  'zugeben das',
#  'radio gehört',
#  'merkel du',
#  'leute geht',
#  'ihrem volk',
#  'interessieren was',
#  'bitte auch',
#  'des teufels',
#  'migranten da',
#  'zu regieren',
#  'glauben ab',
#  'angst macht',
#  'folgen ihr',
#  'dem mob',
#  'mich gerade',
#  'sollen flüchtlinge',
#  'bitten endlich',
#  'ein arschloch',
#  'wer wählt',
#  'doch gesagt',
#  'rechts- und',
#  'denen sowas',
#  'bin dafür',
#  'sowas zu',
#  'wir frauen',
#  'ihr eigentlich',
#  'diese kultur',
#  'merkel kann',
#  "war 's",
#  'das bitte',
#  'jeden montag',
#  'ist euch',
#  'seid die',
#  'zustrom von',
#  'sogar ihre',
#  'sind eh',
#  'wie wär',
#  'vernichtung deutschlands',
#  "'s in",
#  'menschen aufnehmen']

# %%
np.savetxt("bigram_keywords_tf_idf_with_news_with_stopwords.csv", result_list, delimiter =",",fmt ='% s')
