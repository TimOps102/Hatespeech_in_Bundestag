# %%
import nltk
import string
import pickle
import numpy as np

# %%
import zipfile
content = {}
with zipfile.ZipFile("keyword.zip") as zfile:
    for f in zfile.namelist():
        if f != "keyword/":
            content[f] = zfile.read(f).decode("utf8")
content.keys()
# Out:
# dict_keys(['keyword/automobil_50k.txt', 'keyword/news_text100k.txt', 'keyword/sport_50k.txt', 'keyword/wirtschaft_50k.txt'])

# %%
def clean(text):
    tokenized_sents=[]
    text = text.lower()
    text = nltk.sent_tokenize(text)
    for sent in text:
        sent = nltk.word_tokenize(sent)
        sent = [x for x in sent if x not in string.punctuation]
        sent = [x for x in sent if x not in ["``", "''", "€", "$"]]
        sent = [x for x in sent if x.isalpha()]
        if len(sent) > 1:
            tokenized_sents.append(sent)
        
    
    return tokenized_sents

# %%
for key in content:
    content[key] = clean(content[key])

# %%
def create_trigrams(dic_corpora):
    ngram_dict = {}
    #stopwords = nltk.corpus.stopwords.words("german")
    stopwords=["findbecci","--","..", "§", '”', "rebecca", "freeflorian", "\|lbr\|", "|lbr|"]
   
    for index, key in enumerate(dic_corpora):
        print(key)
        ngram_dict[key] =[]
  
        for sents in dic_corpora[key]:

            ngram_dict[key] += [gram for gram in list(nltk.ngrams(sents,3)) if len(set(stopwords).intersection(set(gram)))== 0 and (len(gram[0])>1) and (len(gram[1])>1)]
    
    return ngram_dict

# %%
trigrams = create_trigrams(content)
# Out:
# keyword/automobil_50k.txt
# keyword/news_text100k.txt
# keyword/sport_50k.txt
# keyword/wirtschaft_50k.txt

# %%
def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
hatespeech = load_obj("ngrams_hatespeech_with_stopwords")

# %%
trigrams["keywords/hatespeech"] = hatespeech["3-grams"]

# %%
trigrams["keywords/hatespeech"][:100]
# Out:
# [('rosenmontag', 'ist', 'abgesagt'),
#  ('rapefugees', 'also', 'wieder'),
#  ('also', 'wieder', 'wie'),
#  ('wieder', 'wie', 'gewohnt'),
#  ('wie', 'gewohnt', 'ins'),
#  ('gewohnt', 'ins', 'schwimmbad'),
#  ('ins', 'schwimmbad', 'gehen'),
#  ('bitte', 'nicht', 'die'),
#  ('nicht', 'die', 'türkei'),
#  ('die', 'türkei', 'zum'),
#  ('türkei', 'zum', 'eu-mitglied'),
#  ('zum', 'eu-mitglied', 'machen'),
#  ('menschenrechte', 'pressefreiheit', 'islamisierung'),
#  ('pressefreiheit', 'islamisierung', 'wieso'),
#  ('islamisierung', 'wieso', 'bekommen'),
#  ('wieso', 'bekommen', 'rapefugees'),
#  ('bekommen', 'rapefugees', 'mehr'),
#  ('rapefugees', 'mehr', 'als'),
#  ('mehr', 'als', 'unsere'),
#  ('als', 'unsere', 'hartz'),
#  ('unsere', 'hartz', 'enpfänger'),
#  ('esreicht', 'den', 'verfluchten'),
#  ('den', 'verfluchten', 'rapefugees'),
#  ('verfluchten', 'rapefugees', 'den'),
#  ('rapefugees', 'den', 'krieg'),
#  ('den', 'krieg', 'erklären'),
#  ('wasfehlt', 'war', 'das'),
#  ('war', 'das', 'wochenende'),
#  ('das', 'wochenende', 'im'),
#  ('wochenende', 'im', 'ruhrpott'),
#  ('im', 'ruhrpott', 'unterwegs'),
#  ('überall', 'schwangere', 'muslimische'),
#  ('schwangere', 'muslimische', 'frauen'),
#  ('muslimische', 'frauen', 'mit'),
#  ('frauen', 'mit', 'einem'),
#  ('mit', 'einem', 'rattenschwanz'),
#  ('einem', 'rattenschwanz', 'an'),
#  ('rattenschwanz', 'an', 'kindern'),
#  ('an', 'kindern', 'islamisierung'),
#  ('kindern', 'islamisierung', 'asylanteninvasion'),
#  ('islamisierung', 'asylanteninvasion', 'wenn'),
#  ('asylanteninvasion', 'wenn', 'es'),
#  ('wenn', 'es', 'auf'),
#  ('es', 'auf', 'unseren'),
#  ('auf', 'unseren', 'straßen'),
#  ('unseren', 'straßen', 'zu'),
#  ('straßen', 'zu', 'gewaltausbrüchen'),
#  ('zu', 'gewaltausbrüchen', 'kommt'),
#  ('gewaltausbrüchen', 'kommt', 'die'),
#  ('kommt', 'die', 'verantwortlichen'),
#  ('die', 'verantwortlichen', 'hierfür'),
#  ('verantwortlichen', 'hierfür', 'sitzen'),
#  ('hierfür', 'sitzen', 'in'),
#  ('sitzen', 'in', 'der'),
#  ('in', 'der', 'regierung'),
#  ('der', 'regierung', 'merkel'),
#  ('millionen', 'menschen', 'leben'),
#  ('menschen', 'leben', 'in'),
#  ('leben', 'in', 'europa'),
#  ('millionen', 'flüchtlinge', 'bereiten'),
#  ('flüchtlinge', 'bereiten', 'da'),
#  ('bereiten', 'da', 'kopfzerbrechen'),
#  ('rassisten', 'sprechen', 'von'),
#  ('sprechen', 'von', 'islamisierung'),
#  ('tja', 'die', 'spd'),
#  ('die', 'spd', 'will'),
#  ('spd', 'will', 'unsere'),
#  ('will', 'unsere', 'steuergelder'),
#  ('unsere', 'steuergelder', 'für'),
#  ('steuergelder', 'für', 'flüchtlinge'),
#  ('für', 'flüchtlinge', 'verpassen'),
#  ('refugees', 'refugeesnotwelcome', 'refugeesgohome'),
#  ('refugeesnotwelcome', 'refugeesgohome', 'abmerkeln'),
#  ('refugeesgohome', 'abmerkeln', 'aber'),
#  ('abmerkeln', 'aber', 'für'),
#  ('aber', 'für', 'die'),
#  ('für', 'die', 'kölner'),
#  ('die', 'kölner', 'polizei'),
#  ('kölner', 'polizei', 'haben'),
#  ('polizei', 'haben', 'gestiegene'),
#  ('haben', 'gestiegene', 'anzeigen'),
#  ('gestiegene', 'anzeigen', 'nur'),
#  ('anzeigen', 'nur', 'einen'),
#  ('nur', 'einen', 'grund'),
#  ('einen', 'grund', 'frauen'),
#  ('grund', 'frauen', 'seien'),
#  ('frauen', 'seien', 'anzeigefreudiger'),
#  ('seien', 'anzeigefreudiger', 'als'),
#  ('anzeigefreudiger', 'als', 'noch'),
#  ('rapefugees', 'offenes', 'freies'),
#  ('offenes', 'freies', 'wlan'),
#  ('freies', 'wlan', 'im'),
#  ('wlan', 'im', 'sophienhof'),
#  ('im', 'sophienhof', 'kiel'),
#  ('mit', 'ein', 'grund'),
#  ('ein', 'grund', 'für'),
#  ('grund', 'für', 'die'),
#  ('für', 'die', 'vorfälle'),
#  ('die', 'vorfälle', 'von'),
#  ('vorfälle', 'von', 'gestern')]

# %%
def transform_ngrams(dic):
    trigrams={}
    for keys in dic:
        tuples = []
        for doc in dic[keys]:
            tuples.append("_".join(doc))
        trigrams[keys] = tuples
    return trigrams

# %%
trigram = transform_ngrams(trigrams)

# %%
trigram
# Out:
# {'keyword/automobil_50k.txt': ['der_soll_der',
#   'soll_der_konkurrenz',
#   'der_konkurrenz_von',
#   'konkurrenz_von_skoda',
#   'von_skoda_und',
#   'skoda_und_ford',
#   'und_ford_ordentlich',
#   'ford_ordentlich_einheizen',
#   'mit_dem_bidirektionalen',
#   'dem_bidirektionalen_schlüssel',
#   'bidirektionalen_schlüssel_kann',
#   'schlüssel_kann_je',
#   'kann_je_nach',
#   'je_nach_system',
#   'nach_system_auch',
#   'system_auch_geprüft',
#   'auch_geprüft_werden',
#   'geprüft_werden_ob',
#   'werden_ob_das',
#   'ob_das_licht',
#   'das_licht_noch',
#   'licht_noch_brennt',
#   'noch_brennt_oder',
#   'brennt_oder_das',
#   'oder_das_radio',
#   'das_radio_noch',
#   'radio_noch_spielt',
#   'auch_monatlich_günstiger',
#   'monatlich_günstiger_die',
#   'günstiger_die_niedrigeren',
#   'die_niedrigeren_anschaffungspreise',
#   'niedrigeren_anschaffungspreise_der',
#   'anschaffungspreise_der_kastenwagen',
#   'der_kastenwagen_wirken',
#   'kastenwagen_wirken_sich',
#   'wirken_sich_auf',
#   'sich_auf_die',
#   'auf_die_monatlichen',
#   'die_monatlichen_kosten',
#   'monatlichen_kosten_dämpfend',
#   'kosten_dämpfend_aus',
#   'bei_aller_liebe',
#   'aller_liebe_zum',
#   'liebe_zum_detail',
#   'zum_detail_haben',
#   'detail_haben_die',
#   'haben_die_entwickler',
#   'die_entwickler_dennoch',
#   'entwickler_dennoch_ein',
#   'dennoch_ein_paar',
#   'ein_paar_kleinigkeiten',
#   'paar_kleinigkeiten_vergessen',
#   'kleinigkeiten_vergessen_die',
#   'vergessen_die_umgelegten',
#   'die_umgelegten_sitzlehnen',
#   'umgelegten_sitzlehnen_bilden',
#   'sitzlehnen_bilden_leider',
#   'bilden_leider_keinen',
#   'leider_keinen_komplett',
#   'keinen_komplett_ebenen',
#   'komplett_ebenen_ladeboden',
#   'doch_statt_schriller',
#   'statt_schriller_farben',
#   'schriller_farben_verrückter',
#   'farben_verrückter_formen',
#   'verrückter_formen_und',
#   'formen_und_ein',
#   'und_ein_paar',
#   'ein_paar_frischer',
#   'paar_frischer_funktionen',
#   'frischer_funktionen_gibt',
#   'funktionen_gibt_es',
#   'gibt_es_ringsum',
#   'es_ringsum_nur',
#   'ringsum_nur_billiges',
#   'nur_billiges_plastik',
#   'recht_hatte_se',
#   'das_war_früher',
#   'war_früher_kaum',
#   'früher_kaum_vorstellbar',
#   'unterstützung_bekommen_sie',
#   'bekommen_sie_von',
#   'sie_von_bundeskanzlerin',
#   'von_bundeskanzlerin_angela',
#   'bundeskanzlerin_angela_merkel',
#   'angela_merkel_cdu',
#   'der_fc_bayern',
#   'fc_bayern_spielt',
#   'bayern_spielt_gegen',
#   'spielt_gegen_den',
#   'gegen_den_fc',
#   'den_fc_aberdeen',
#   'fc_aberdeen_remis',
#   'aberdeen_remis_der',
#   'remis_der_hsv',
#   'der_hsv_gewinnt',
#   'hsv_gewinnt_gegen',
#   'gewinnt_gegen_zürich',
#   'aston_martin_zeigt',
#   'martin_zeigt_das',
#   'zeigt_das_neue',
#   'nur_leider_fahren',
#   'leider_fahren_dann',
#   'fahren_dann_alle',
#   'dann_alle_dieselbe',
#   'alle_dieselbe_umleitung',
#   'eigentlich_läge_es',
#   'läge_es_nahe',
#   'es_nahe_dass',
#   'nahe_dass_smith',
#   'dass_smith_sein',
#   'smith_sein_hobby',
#   'sein_hobby_zum',
#   'hobby_zum_beruf',
#   'zum_beruf_macht',
#   'dadurch_verringern_sich',
#   'verringern_sich_wendekreis',
#   'sich_wendekreis_und',
#   'wendekreis_und_lenkübersetzung',
#   'und_lenkübersetzung_der',
#   'lenkübersetzung_der_wagen',
#   'der_wagen_soll',
#   'wagen_soll_direkter',
#   'soll_direkter_und',
#   'direkter_und_spontaner',
#   'und_spontaner_reagieren',
#   'das_concept_car',
#   'concept_car_heißt',
#   'car_heißt_nicht',
#   'heißt_nicht_nur',
#   'nicht_nur_wie',
#   'nur_wie_der',
#   'wie_der_prototyp',
#   'der_prototyp_es',
#   'prototyp_es_ähnelt',
#   'es_ähnelt_darüber',
#   'ähnelt_darüber_hinaus',
#   'darüber_hinaus_wie',
#   'hinaus_wie_der',
#   'wie_der_ahne',
#   'der_ahne_von',
#   'ahne_von_auch',
#   'von_auch_einer',
#   'auch_einer_zigarre',
#   'für_euro_aufpreis',
#   'euro_aufpreis_gibt',
#   'aufpreis_gibt_es',
#   'gibt_es_auch',
#   'es_auch_einen',
#   'auch_einen_mit',
#   'einen_mit_ps',
#   'mit_ps_der',
#   'ps_der_maximal',
#   'der_maximal_nm',
#   'maximal_nm_entwickelt',
#   'dennoch_brauchts_einen',
#   'brauchts_einen_moment',
#   'einen_moment_bis',
#   'moment_bis_die',
#   'bis_die_fünf',
#   'die_fünf_meter',
#   'fünf_meter_lange',
#   'meter_lange_und',
#   'lange_und_trotz',
#   'und_trotz_noch',
#   'trotz_noch_tonnen',
#   'noch_tonnen_schwere',
#   'tonnen_schwere_limousine',
#   'schwere_limousine_in',
#   'limousine_in_schwung',
#   'in_schwung_kommt',
#   'das_coupé_kostet',
#   'coupé_kostet_franken',
#   'kostet_franken_das',
#   'franken_das_cabrio',
#   'das_cabrio_franken',
#   'farbige_applikationen_zeichnen',
#   'applikationen_zeichnen_das',
#   'zeichnen_das_cockpit',
#   'das_cockpit_den',
#   'cockpit_den_sondermodells',
#   'den_sondermodells_aus',
#   'der_dienstgradhöchste_offizier',
#   'dienstgradhöchste_offizier_der',
#   'offizier_der_streife',
#   'der_streife_ließ',
#   'streife_ließ_kräftig',
#   'ließ_kräftig_dampf',
#   'kräftig_dampf_ab',
#   'dampf_ab_ob',
#   'ab_ob_ich',
#   'ob_ich_denn',
#   'ich_denn_das',
#   'denn_das_schild',
#   'das_schild_nicht',
#   'schild_nicht_gesehen',
#   'nicht_gesehen_hätte',
#   'bekannt_sind_zwei',
#   'sind_zwei_probleme',
#   'zwei_probleme_bei',
#   'probleme_bei_einigen',
#   'bei_einigen_autos',
#   'einigen_autos_ist',
#   'autos_ist_das',
#   'ist_das_gaspedal',
#   'das_gaspedal_zu',
#   'gaspedal_zu_lang',
#   'zu_lang_sodass',
#   'lang_sodass_es',
#   'sodass_es_sich',
#   'es_sich_mit',
#   'sich_mit_der',
#   'mit_der_fußmatte',
#   'der_fußmatte_verhaken',
#   'fußmatte_verhaken_kann',
#   'ich_tue_das',
#   'tue_das_lange',
#   'das_lange_nicht',
#   'lange_nicht_mehr',
#   'nicht_mehr_und',
#   'mehr_und_fahre',
#   'und_fahre_nur',
#   'fahre_nur_sehr',
#   'nur_sehr_wenig',
#   'jedesmal_wird_auf',
#   'wird_auf_die',
#   'auf_die_autos',
#   'die_autos_eingedroschen',
#   'autos_eingedroschen_um',
#   'eingedroschen_um_das',
#   'um_das_anzukurbeln',
#   'die_messe_auto',
#   'messe_auto_china',
#   'auto_china_in',
#   'china_in_peking',
#   'in_peking_dauert',
#   'peking_dauert_vom',
#   'dauert_vom_april',
#   'vom_april_bis',
#   'april_bis_mai',
#   'der_mini_ist',
#   'mini_ist_derzeit',
#   'ist_derzeit_die',
#   'derzeit_die_wertstabilste',
#   'die_wertstabilste_marke',
#   'wertstabilste_marke_auf',
#   'marke_auf_dem',
#   'auf_dem_deutschen',
#   'dem_deutschen_automarkt',
#   'der_diesel_wird',
#   'diesel_wird_bald',
#   'wird_bald_ausgedient',
#   'bald_ausgedient_haben',
#   'ausgedient_haben_und',
#   'haben_und_sind',
#   'und_sind_im',
#   'sind_im_kommen',
#   'befragt_wurden_männer',
#   'wurden_männer_und',
#   'männer_und_frauen',
#   'und_frauen_ab',
#   'frauen_ab_jahren',
#   'danach_folgt_die',
#   'folgt_die_niederlande',
#   'die_niederlande_vor',
#   'niederlande_vor_dänemark',
#   'die_schätzen_die',
#   'schätzen_die_hohe',
#   'die_hohe_und',
#   'hohe_und_sitzposition',
#   'und_sitzposition_und',
#   'sitzposition_und_den',
#   'und_den_kofferraum',
#   'den_kofferraum_aber',
#   'kofferraum_aber_wundern',
#   'aber_wundern_sich',
#   'wundern_sich_erst',
#   'sich_erst_nach',
#   'erst_nach_dem',
#   'nach_dem_kauf',
#   'dem_kauf_über',
#   'kauf_über_den',
#   'über_den_verbrauch',
#   'den_verbrauch_der',
#   'verbrauch_der_doch',
#   'der_doch_deutlich',
#   'doch_deutlich_über',
#   'deutlich_über_dem',
#   'über_dem_des',
#   'dem_des_alten',
#   'des_alten_kombi',
#   'alten_kombi_liegt',
#   'von_diesem_kleingedruckten',
#   'diesem_kleingedruckten_gibt',
#   'kleingedruckten_gibt_es',
#   'gibt_es_wie',
#   'es_wie_überall',
#   'wie_überall_auch',
#   'überall_auch_in',
#   'auch_in_den',
#   'in_den_garantiebedingungen',
#   'den_garantiebedingungen_von',
#   'garantiebedingungen_von_opel',
#   'von_opel_reichlich',
#   'nichts_zu_meckern',
#   'zu_meckern_gibts',
#   'meckern_gibts_am',
#   'gibts_am_fahrwerk',
#   'auch_hier_gilt',
#   'hier_gilt_der',
#   'gilt_der_grundsatz',
#   'der_grundsatz_man',
#   'grundsatz_man_kritisiert',
#   'man_kritisiert_den',
#   'kritisiert_den_bundespräsidenten',
#   'den_bundespräsidenten_nicht',
#   'bundespräsidenten_nicht_sagte',
#   'nicht_sagte_der',
#   'sagte_der_stellvertretende',
#   'der_stellvertretende_am',
#   'stellvertretende_am_montag',
#   'am_montag_in',
#   'montag_in_berlin',
#   'er_würde_beim',
#   'würde_beim_crash',
#   'beim_crash_zu',
#   'crash_zu_viel',
#   'zu_viel_druck',
#   'viel_druck_auf',
#   'druck_auf_das',
#   'auf_das_ungeborene',
#   'das_ungeborene_ausüben',
#   'damit_können_die',
#   'können_die_deutschen',
#   'die_deutschen_autokäufer',
#   'deutschen_autokäufer_vorerst',
#   'autokäufer_vorerst_nicht',
#   'vorerst_nicht_mit',
#   'nicht_mit_einer',
#   'mit_einer_einfachen',
#   'einer_einfachen_und',
#   'einfachen_und_transparenten',
#   'und_transparenten_verbrauchskennzeichnung',
#   'transparenten_verbrauchskennzeichnung_für',
#   'verbrauchskennzeichnung_für_pkw',
#   'für_pkw_rechnen',
#   'ein_computer_übernimmt',
#   'computer_übernimmt_hier',
#   'übernimmt_hier_das',
#   'hier_das_umherkurven',
#   'das_umherkurven_und',
#   'umherkurven_und_suchen',
#   'fürs_fahrvergnügen_gibts',
#   'fahrvergnügen_gibts_dazu',
#   'gibts_dazu_noch',
#   'dazu_noch_ein',
#   'noch_ein_sportfahrwerk',
#   'ein_sportfahrwerk_mit',
#   'sportfahrwerk_mit_millimeter',
#   'mit_millimeter_geringerer',
#   'millimeter_geringerer_bodenfreiheit',
#   'geringerer_bodenfreiheit_sowie',
#   'bodenfreiheit_sowie_die',
#   'sowie_die_elektronische',
#   'die_elektronische_differentialsperre',
#   'elektronische_differentialsperre_xds',
#   'differentialsperre_xds_mit',
#   'xds_mit_der',
#   'mit_der_die',
#   'der_die_kurvengeschwindigkeiten',
#   'die_kurvengeschwindigkeiten_steigen',
#   'auch_dieses_dürfte',
#   'dieses_dürfte_daimler',
#   'dürfte_daimler_interessieren',
#   'als_jemand_der',
#   'jemand_der_gerne',
#   'der_gerne_mit',
#   'gerne_mit_dem',
#   'mit_dem_auto',
#   'dem_auto_durch',
#   'auto_durch_europa',
#   'durch_europa_goldelt',
#   'europa_goldelt_und',
#   'goldelt_und_ungerne',
#   'und_ungerne_fliegt',
#   'ungerne_fliegt_muss',
#   'fliegt_muss_ich',
#   'muss_ich_da',
#   'ich_da_schon',
#   'da_schon_ein',
#   'schon_ein_bisschen',
#   'ein_bisschen_neid',
#   'bisschen_neid_unterdrücken',
#   'hier_kann_selbst',
#   'kann_selbst_ich',
#   'selbst_ich_mit',
#   'ich_mit_zentimetern',
#   'mit_zentimetern_körpergröße',
#   'zentimetern_körpergröße_von',
#   'körpergröße_von_schier',
#   'von_schier_unglaublicher',
#   'schier_unglaublicher_beinfreiheit',
#   'unglaublicher_beinfreiheit_sprechen',
#   'bei_umdrehungen_auf',
#   'umdrehungen_auf_dem',
#   'auf_dem_tourenzähler',
#   'dem_tourenzähler_stehen',
#   'tourenzähler_stehen_beeindruckende',
#   'stehen_beeindruckende_nm',
#   'beeindruckende_nm_zur',
#   'nm_zur_verfügung',
#   'die_marke_will',
#   'marke_will_sich',
#   'will_sich_aber',
#   'sich_aber_nicht',
#   'aber_nicht_darauf',
#   'nicht_darauf_ausruhen',
#   'darauf_ausruhen_dass',
#   'ausruhen_dass_sie',
#   'dass_sie_vergleichsweise',
#   'sie_vergleichsweise_glimpflich',
#   'vergleichsweise_glimpflich_aus',
#   'glimpflich_aus_der',
#   'aus_der_krise',
#   'der_krise_zu',
#   'krise_zu_steuern',
#   'zu_steuern_scheint',
#   'allerdings_brachte_die',
#   'brachte_die_tour',
#   'die_tour_für',
#   'tour_für_alle',
#   'für_alle_teilnehmer',
#   'alle_teilnehmer_die',
#   'teilnehmer_die_erkenntnis',
#   'die_erkenntnis_mit',
#   'erkenntnis_mit_dass',
#   'mit_dass_der',
#   'dass_der_größte',
#   'der_größte_spritverbraucher',
#   'größte_spritverbraucher_hinter',
#   'spritverbraucher_hinter_dem',
#   'hinter_dem_lenkrad',
#   'dem_lenkrad_sitzt',
#   'besetzt_mit_drei',
#   'mit_drei_personen',
#   'drei_personen_und',
#   'personen_und_beladen',
#   'und_beladen_mit',
#   'beladen_mit_viel',
#   'mit_viel_gepäck',
#   'viel_gepäck_hat',
#   'gepäck_hat_er',
#   'hat_er_es',
#   'er_es_noch',
#   'es_noch_schwerer',
#   'abstandswarner_und_bremsassistent',
#   'und_bremsassistent_sind',
#   'bremsassistent_sind_in',
#   'sind_in_aller',
#   'in_aller_regel',
#   'aller_regel_an',
#   'regel_an_den',
#   'an_den_tempomat',
#   'den_tempomat_gekoppelt',
#   'joseph_corré_wird',
#   'corré_wird_das',
#   'wird_das_auto',
#   'das_auto_am',
#   'auto_am_abend',
#   'am_abend_des',
#   'abend_des_life',
#   'des_life_ball',
#   'life_ball_über',
#   'ball_über_den',
#   'über_den_roten',
#   'den_roten_teppich',
#   'roten_teppich_vor',
#   'teppich_vor_dem',
#   'vor_dem_wiener',
#   'dem_wiener_rathaus',
#   'wiener_rathaus_steuern',
#   'im_september_bringt',
#   'september_bringt_alfa',
#   'bringt_alfa_sein',
#   'alfa_sein_neues',
#   'sein_neues_heißes',
#   'neues_heißes_einstiegsmodell',
#   'keine_schlechte_entwicklung',
#   'schlechte_entwicklung_wenn',
#   'entwicklung_wenn_man',
#   'wenn_man_bedenkt',
#   'man_bedenkt_wie',
#   'bedenkt_wie_anton',
#   'wie_anton_hunger',
#   'anton_hunger_anmerkte',
#   'hunger_anmerkte_dass',
#   'anmerkte_dass_zuvor',
#   'dass_zuvor_an',
#   'zuvor_an_dieser',
#   'an_dieser_stelle',
#   'dieser_stelle_der',
#   'stelle_der_frauenparkplatz',
#   'der_frauenparkplatz_war',
#   'autowachs_oder_politur',
#   'oder_politur_versprechen',
#   'politur_versprechen_brillianz',
#   'versprechen_brillianz_und',
#   'brillianz_und_lackkonservierung',
#   'und_lackkonservierung_über',
#   'lackkonservierung_über_wochen',
#   'im_dauerversuch_wurden',
#   'dauerversuch_wurden_jetzt',
#   'wurden_jetzt_sechs',
#   'jetzt_sechs_produkte',
#   'sechs_produkte_getestet',
#   'ford_hinkt_seinem',
#   'hinkt_seinem_vorjahresabsatz',
#   'seinem_vorjahresabsatz_hinterher',
#   'vorjahresabsatz_hinterher_mit',
#   'hinterher_mit_einem',
#   'mit_einem_minus',
#   'einem_minus_von',
#   'minus_von_prozent',
#   'von_prozent_auf',
#   'prozent_auf_millionen',
#   'auf_millionen_autos',
#   'hinderlich_für_den',
#   'für_den_blick',
#   'den_blick_nach',
#   'blick_nach_außen',
#   'nach_außen_sind',
#   'außen_sind_auch',
#   'sind_auch_hochgezogene',
#   'auch_hochgezogene_heckpartien',
#   'hochgezogene_heckpartien_und',
#   'heckpartien_und_immer',
#   'und_immer_schräger',
#   'immer_schräger_werdende',
#   'schräger_werdende_frontscheiben',
#   'werdende_frontscheiben_kritisierten',
#   'frontscheiben_kritisierten_die',
#   'ein_witz_aber',
#   'witz_aber_fr',
#   'künast_empfiehlt_doch',
#   'empfiehlt_doch_toyota',
#   'doch_toyota_also',
#   'toyota_also_alles',
#   'also_alles_im',
#   'alles_im_lot',
#   'dazu_gibt_es',
#   'gibt_es_eine',
#   'es_eine_und',
#   'eine_und_ein',
#   'und_ein_besonderes',
#   'ein_besonderes_bremssystem',
#   'fotostrecke_bilder_rebmann',
#   'bilder_rebmann_je',
#   'rebmann_je_seltener',
#   'je_seltener_ein',
#   'seltener_ein_wagen',
#   'ein_wagen_ist',
#   'wagen_ist_desto',
#   'ist_desto_wertvoller',
#   'desto_wertvoller_ist',
#   'wertvoller_ist_er',
#   'ist_er_meist',
#   'dies_hat_regierungssprecher',
#   'hat_regierungssprecher_ulrich',
#   'regierungssprecher_ulrich_wilhelm',
#   'ulrich_wilhelm_am',
#   'wilhelm_am_montag',
#   'am_montag_klargestellt',
#   'aber_vorher_genau',
#   'vorher_genau_prüfen',
#   'das_gilt_natürlich',
#   'gilt_natürlich_auch',
#   'natürlich_auch_für',
#   'aus_der_knight',
#   'der_knight_rider',
#   'knight_rider_mit',
#   'rider_mit_david',
#   'mit_david_hasselhoff',
#   'koblenz_dpa_für',
#   'dpa_für_schäden',
#   'für_schäden_an',
#   'schäden_an_einem',
#   'an_einem_fahrzeug',
#   'einem_fahrzeug_das',
#   'fahrzeug_das_auf',
#   'das_auf_abschüssiger',
#   'auf_abschüssiger_straße',
#   'abschüssiger_straße_in',
#   'straße_in_einen',
#   'in_einen_weiher',
#   'einen_weiher_rollt',
#   'weiher_rollt_muss',
#   'rollt_muss_die',
#   'muss_die_vollkaskoversicherung',
#   'die_vollkaskoversicherung_zahlen',
#   'ford_will_das',
#   'will_das_erbe',
#   'das_erbe_des',
#   'erbe_des_boss',
#   'des_boss_jetzt',
#   'boss_jetzt_ausschlachten',
#   'jetzt_ausschlachten_und',
#   'ausschlachten_und_eine',
#   'und_eine_neuauflage',
#   'eine_neuauflage_auf',
#   'neuauflage_auf_basis',
#   'auf_basis_des',
#   'basis_des_mustang',
#   'des_mustang_gt',
#   'mustang_gt_anbieten',
#   'im_januar_war',
#   'januar_war_der',
#   'war_der_tata',
#   'der_tata_nano',
#   'tata_nano_zum',
#   'nano_zum_spottpreis',
#   'zum_spottpreis_von',
#   'spottpreis_von_euro',
#   'von_euro_da',
#   'die_gibt_es',
#   'gibt_es_nicht',
#   'es_nicht_zum',
#   'nicht_zum_nulltarif',
#   'das_vw_hat',
#   'vw_hat_immerhin',
#   'hat_immerhin_schon',
#   'immerhin_schon_lange',
#   'schon_lange_wartezeiten',
#   'die_differenz_zwischen',
#   'differenz_zwischen_beiden',
#   'zwischen_beiden_tarifen',
#   'beiden_tarifen_verlangte',
#   'tarifen_verlangte_das',
#   'verlangte_das_unternehmen',
#   'das_unternehmen_daraufhin',
#   'unternehmen_daraufhin_vom',
#   'daraufhin_vom_unfallgeschädigten',
#   'vom_unfallgeschädigten_heißt',
#   'unfallgeschädigten_heißt_es',
#   'doch_wie_lange',
#   'wie_lange_die',
#   'lange_die_straßenhüter',
#   'die_straßenhüter_die',
#   'straßenhüter_die_sechs',
#   'die_sechs_kreisverkehre',
#   'sechs_kreisverkehre_und',
#   'kreisverkehre_und_die',
#   'und_die_kreuzungen',
#   'die_kreuzungen_ohne',
#   'kreuzungen_ohne_ampeln',
#   'ohne_ampeln_den',
#   'ampeln_den_verkehrsfluss',
#   'den_verkehrsfluss_noch',
#   'verkehrsfluss_noch_geschmeidig',
#   'noch_geschmeidig_halten',
#   'geschmeidig_halten_können',
#   'halten_können_bleibt',
#   'können_bleibt_abzuwarten',
#   'kein_schlechtes_paket',
#   'schlechtes_paket_für',
#   'paket_für_einen',
#   'für_einen_dollar',
#   'einen_dollar_teuren',
#   'dollar_teuren_einsteiger',
#   'mutmaßlich_ist_sogar',
#   'ist_sogar_die',
#   'sogar_die_ökobilanz',
#   'die_ökobilanz_der',
#   'ökobilanz_der_luxusclubs',
#   'der_luxusclubs_in',
#   'luxusclubs_in_ordnung',
#   'in_ordnung_denn',
#   'ordnung_denn_immerhin',
#   'denn_immerhin_werden',
#   'immerhin_werden_die',
#   'werden_die_eingesetzten',
#   'die_eingesetzten_rohstoffe',
#   'eingesetzten_rohstoffe_wenigstens',
#   'rohstoffe_wenigstens_angemessen',
#   'wenigstens_angemessen_genutzt',
#   'elektroantrieb_alles_schon',
#   'alles_schon_in',
#   'schon_in_serie',
#   'in_serie_auf',
#   'serie_auf_der',
#   'auf_der_straße',
#   'die_neue_steuer',
#   'neue_steuer_könne',
#   'steuer_könne_theoretisch',
#   'könne_theoretisch_schon',
#   'theoretisch_schon_am',
#   'schon_am_juli',
#   'am_juli_in',
#   'juli_in_kraft',
#   'in_kraft_treten',
#   'kraft_treten_heißt',
#   'treten_heißt_es',
#   'für_sprit_steuern',
#   'sprit_steuern_und',
#   'steuern_und_versicherungen',
#   'und_versicherungen_müssen',
#   'versicherungen_müssen_ab',
#   'müssen_ab_dem',
#   'ab_dem_januar',
#   'dem_januar_deutlich',
#   'januar_deutlich_mehr',
#   'deutlich_mehr_berappen',
#   'von_amsterdam_über',
#   'amsterdam_über_das',
#   'über_das_frankfurter',
#   'das_frankfurter_elternhaus',
#   'frankfurter_elternhaus_zu',
#   'elternhaus_zu_weihnachten',
#   'zu_weihnachten_nach',
#   'weihnachten_nach_wien',
#   'nach_wien_und',
#   'wien_und_dann',
#   'und_dann_nach',
#   'dann_nach_rumänien',
#   'nach_rumänien_dort',
#   'rumänien_dort_wurde',
#   'dort_wurde_es',
#   'wurde_es_erstmals',
#   'es_erstmals_richtig',
#   'erstmals_richtig_kalt',
#   'richtig_kalt_und',
#   'kalt_und_an',
#   'und_an_der',
#   'an_der_grenze',
#   'der_grenze_haben',
#   'grenze_haben_beamte',
#   'haben_beamte_versucht',
#   'beamte_versucht_uns',
#   'versucht_uns_abzuziehen',
#   'geht_der_energievorrat',
#   'der_energievorrat_während',
#   'energievorrat_während_der',
#   'während_der_fahrt',
#   'der_fahrt_zur',
#   'fahrt_zur_neige',
#   'zur_neige_gibt',
#   'neige_gibt_es',
#   'gibt_es_an',
#   'es_an_bord',
#   'an_bord_einen',
#   'bord_einen_kleinen',
#   'einen_kleinen_dreizylinder',
#   'kleinen_dreizylinder_sagt',
#   'dreizylinder_sagt_lutz',
#   'dazu_wird_alles',
#   'wird_alles_länger',
#   'alles_länger_gemacht',
#   'länger_gemacht_die',
#   'gemacht_die_verkabelung',
#   'die_verkabelung_das',
#   'verkabelung_das_bodenblech',
#   'das_bodenblech_die',
#   'bodenblech_die_antriebswelle',
#   'wirkt_das_auto',
#   'das_auto_bullig',
#   'auto_bullig_elegant',
#   'bullig_elegant_oder',
#   'elegant_oder_sportlich',
#   'lange_fuhr_bmw',
#   'fuhr_bmw_dem',
#   'bmw_dem_hauptkonkurrenten',
#   'dem_hauptkonkurrenten_audi',
#   'hauptkonkurrenten_audi_mit',
#   'audi_mit_seinem',
#   'mit_seinem_mini',
#   'seinem_mini_im',
#   'mini_im_kleinwagensegment',
#   'im_kleinwagensegment_davon',
#   'wir_zeigen_die',
#   'zeigen_die_perlen',
#   'die_perlen_im',
#   'perlen_im_schilderwald',
#   'die_italiener_präsentieren',
#   'italiener_präsentieren_den',
#   'präsentieren_den_schmucken',
#   'den_schmucken_italia',
#   'schmucken_italia_als',
#   'italia_als_nachfolger',
#   'als_nachfolger_des',
#   'zunächst_kümmerte_ich',
#   'kümmerte_ich_mich',
#   'ich_mich_um',
#   'mich_um_die',
#   'um_die_wie',
#   'die_wie_beispielsweise',
#   'wie_beispielsweise_die',
#   'beispielsweise_die_blinden',
#   'die_blinden_scheinwerfer',
#   'blinden_scheinwerfer_und',
#   'scheinwerfer_und_die',
#   'und_die_desaströse',
#   'die_desaströse_elektrik',
#   'desaströse_elektrik_die',
#   'elektrik_die_masseklemmen',
#   'die_masseklemmen_im',
#   'masseklemmen_im_motorraum',
#   'im_motorraum_waren',
#   'motorraum_waren_samt',
#   'waren_samt_und',
#   'samt_und_sonders',
#   'und_sonders_verrottet',
#   'sonders_verrottet_und',
#   'verrottet_und_korrodiert',
#   'natürlich_sprüht_ein',
#   'sprüht_ein_koreanischer',
#   'ein_koreanischer_kleinwagen',
#   'koreanischer_kleinwagen_in',
#   'kleinwagen_in_dieser',
#   'in_dieser_preisklasse',
#   'dieser_preisklasse_nicht',
#   'preisklasse_nicht_vor',
#   'nicht_vor_esprit',
#   'vor_esprit_wie',
#   'esprit_wie_vielleicht',
#   'wie_vielleicht_ein',
#   'vielleicht_ein_mini',
#   'ein_mini_oder',
#   'mini_oder_ein',
#   'oder_ein_fiat',
#   'ein_fiat_immer',
#   'fiat_immer_mehr',
#   'immer_mehr_autos',
#   'mehr_autos_werden',
#   'autos_werden_zur',
#   'werden_zur_mogelpackung',
#   'wie_soll_das',
#   'soll_das_klappen',
#   'das_klappen_sieben',
#   'klappen_sieben_personen',
#   'sieben_personen_in',
#   'personen_in_einem',
#   'in_einem_kompaktvan',
#   'einem_kompaktvan_transportieren',
#   'kompaktvan_transportieren_beinfreiheit',
#   'transportieren_beinfreiheit_vom',
#   'beinfreiheit_vom_fahrer',
#   'vom_fahrer_bis',
#   'fahrer_bis_zum',
#   'bis_zum_hinterbänkler',
#   'zum_hinterbänkler_und',
#   'hinterbänkler_und_dazu',
#   'und_dazu_noch',
#   'dazu_noch_einigermaßen',
#   'noch_einigermaßen_raum',
#   'einigermaßen_raum_für',
#   'raum_für_die',
#   'für_die_wichtigsten',
#   'bei_der_des',
#   'der_des_iron',
#   'des_iron_man',
#   'iron_man_im',
#   'man_im_berliner',
#   'im_berliner_kino',
#   'berliner_kino_cinemaxx',
#   'kino_cinemaxx_lenkte',
#   'cinemaxx_lenkte_downey',
#   'lenkte_downey_den',
#   'downey_den_aus',
#   'den_aus_ingolstadt',
#   'aus_ingolstadt_selber',
#   'ingolstadt_selber_an',
#   'selber_an_den',
#   'an_den_roten',
#   'den_roten_teppich',
#   'euro_aufpreis_kostet',
#   'aufpreis_kostet_das',
#   'kostet_das_system',
#   'das_dsg_bietet',
#   'dsg_bietet_nicht',
#   'bietet_nicht_nur',
#   'nicht_nur_etwas',
#   'nur_etwas_flottere',
#   'etwas_flottere_beschleunigungswerte',
#   'flottere_beschleunigungswerte_sondern',
#   'beschleunigungswerte_sondern_auch',
#   'sondern_auch_weniger',
#   'auch_weniger_verbrauch',
#   'deutlich_besser_soll',
#   'besser_soll_es',
#   'soll_es_dann',
#   'es_dann_im',
#   'dann_im_nächsten',
#   'im_nächsten_frühjahr',
#   'nächsten_frühjahr_werden',
#   'es_gab_vor',
#   'gab_vor_ein',
#   'vor_ein_paar',
#   'ein_paar_jahren',
#   'paar_jahren_mal',
#   'jahren_mal_eine',
#   'mal_eine_untersuchung',
#   'eine_untersuchung_welche',
#   'untersuchung_welche_autos',
#   'welche_autos_eigentlich',
#   'autos_eigentlich_die',
#   'eigentlich_die_sichersten',
#   'die_sichersten_seien',
#   'ist_ein_komischer',
#   'ein_komischer_weg',
#   'komischer_weg_der',
#   'weg_der_immer',
#   'der_immer_einsamer',
#   'immer_einsamer_und',
#   'einsamer_und_stiller',
#   'und_stiller_wird',
#   'stiller_wird_je',
#   'wird_je_nördlicher',
#   'je_nördlicher_man',
#   'nördlicher_man_kommt',
#   'weitere_motorisierungen_sind',
#   'motorisierungen_sind_die',
#   'sind_die_benziner',
#   'die_benziner_tfsi',
#   'benziner_tfsi_mit',
#   'tfsi_mit_ps',
#   'mit_ps_und',
#   'ps_und_fsi',
#   'und_fsi_mit',
#   'fsi_mit_ps',
#   'mit_ps_sowie',
#   'ps_sowie_der',
#   'sowie_der_tdi',
#   'der_tdi_mit',
#   'tdi_mit_ps',
#   'die_dichtung_muss',
#   'dichtung_muss_hitzebeständig',
#   'muss_hitzebeständig_sein',
#   'hitzebeständig_sein_um',
#   'sein_um_die',
#   'um_die_hohen',
#   'die_hohen_temperaturen',
#   'hohen_temperaturen_des',
#   'temperaturen_des_brennraums',
#   'des_brennraums_verkraften',
#   'brennraums_verkraften_zu',
#   'verkraften_zu_können',
#   'zu_können_erläutert',
#   'können_erläutert_der',
#   'erläutert_der_tüv',
#   'der_tüv_nord',
#   'tüv_nord_in',
#   'nord_in_hannover',
#   'doch_während_einige',
#   'während_einige_argumentieren',
#   'einige_argumentieren_dass',
#   'argumentieren_dass_die',
#   'dass_die_besseren',
#   'die_besseren_reifen',
#   'besseren_reifen_zur',
#   'reifen_zur_übertragung',
#   'zur_übertragung_der',
#   'übertragung_der_lenkkräfte',
#   'der_lenkkräfte_vorne',
#   'lenkkräfte_vorne_sein',
#   'vorne_sein_sollten',
#   'sein_sollten_raten',
#   'sollten_raten_die',
#   'raten_die_experten',
#   'die_experten_anderes',
#   'experten_anderes_besseren',
#   'anderes_besseren_reifen',
#   'besseren_reifen_werden',
#   'reifen_werden_hinten',
#   'werden_hinten_montiert',
#   'hinten_montiert_sagt',
#   'montiert_sagt_maximilian',
#   'sagt_maximilian_maurer',
#   'maximilian_maurer_in',
#   'maurer_in_münchen',
#   'da_lässt_sich',
#   'lässt_sich_der',
#   'sich_der_betreiber',
#   'der_betreiber_eines',
#   'betreiber_eines_fischrestaurants',
#   'eines_fischrestaurants_im',
#   'fischrestaurants_im_vorort',
#   'im_vorort_qurum',
#   'vorort_qurum_von',
#   'qurum_von_seiner',
#   'von_seiner_bedienung',
#   'seiner_bedienung_den',
#   'bedienung_den_mit',
#   'den_mit_schlauch',
#   'mit_schlauch_und',
#   'schlauch_und_zuber',
#   'und_zuber_von',
#   'zuber_von_staub',
#   'von_staub_und',
#   'staub_und_dreck',
#   'und_dreck_befreien',
#   'jetzt_hat_ihm',
#   ...],
#  'keyword/news_text100k.txt': ['jahre_arbeiterkammer_bedeuten',
#   'arbeiterkammer_bedeuten_jahre',
#   'bedeuten_jahre_einsatz',
#   'jahre_einsatz_für',
#   'einsatz_für_soziale',
#   'für_soziale_gerechtigkeit',
#   'soziale_gerechtigkeit_und',
#   'gerechtigkeit_und_solidarität',
#   'im_jahr_vor',
#   'jahr_vor_dem',
#   'vor_dem_referendum',
#   'dem_referendum_lagen',
#   'referendum_lagen_die',
#   'lagen_die_bayerischen',
#   'die_bayerischen_exporte',
#   'bayerischen_exporte_nach',
#   'exporte_nach_großbritannien',
#   'nach_großbritannien_bei',
#   'großbritannien_bei_milliarden',
#   'bei_milliarden_euro',
#   'dürfte_das_über',
#   'das_über_die',
#   'über_die_big',
#   'die_big_aggregierte',
#   'big_aggregierte_spitzenmietpreiswachstum',
#   'aggregierte_spitzenmietpreiswachstum_bei',
#   'spitzenmietpreiswachstum_bei_liegen',
#   'bei_liegen_und',
#   'liegen_und_damit',
#   'und_damit_mit',
#   'damit_mit_geringer',
#   'mit_geringer_abschwächung',
#   'geringer_abschwächung_anhalten',
#   'ist_ein_wichtiger',
#   'ein_wichtiger_schritt',
#   'wichtiger_schritt_aber',
#   'schritt_aber_das',
#   'aber_das_heißt',
#   'das_heißt_nicht',
#   'heißt_nicht_dass',
#   'nicht_dass_die',
#   'dass_die_arbeit',
#   'die_arbeit_dann',
#   'arbeit_dann_erledigt',
#   'dann_erledigt_ist',
#   'erledigt_ist_und',
#   'ist_und_alles',
#   'und_alles_gelöst',
#   'alles_gelöst_sein',
#   'gelöst_sein_wird',
#   'jahre_sind_genug',
#   'davis_geht_angesichts',
#   'geht_angesichts_der',
#   'angesichts_der_herrschenden',
#   'der_herrschenden_kapitalistischen',
#   'herrschenden_kapitalistischen_produktionsweise',
#   'kapitalistischen_produktionsweise_zudem',
#   'produktionsweise_zudem_davon',
#   'zudem_davon_aus',
#   'davon_aus_dass',
#   'aus_dass_sämtliche',
#   'dass_sämtliche_formen',
#   'sämtliche_formen_unproduktiver',
#   'formen_unproduktiver_arbeit',
#   'unproduktiver_arbeit_nur',
#   'arbeit_nur_durch',
#   'nur_durch_intervention',
#   'durch_intervention_des',
#   'intervention_des_staates',
#   'des_staates_oder',
#   'staates_oder_das',
#   'oder_das_zugeständnis',
#   'das_zugeständnis_der',
#   'zugeständnis_der_herrschenden',
#   'der_herrschenden_klasse',
#   'herrschenden_klasse_entlohnt',
#   'klasse_entlohnt_werden',
#   'entlohnt_werden_können',
#   'aas_as_die',
#   'as_die_aktuellen',
#   'die_aktuellen_arbeiten',
#   'aktuellen_arbeiten_an',
#   'arbeiten_an_der',
#   'an_der_fleher',
#   'der_fleher_brücke',
#   'fleher_brücke_werden',
#   'brücke_werden_bis',
#   'werden_bis_ende',
#   'bis_ende_abgeschlossen',
#   'ende_abgeschlossen_sein',
#   'abgeschlossen_sein_es',
#   'sein_es_stehen',
#   'es_stehen_wieder',
#   'stehen_wieder_zwei',
#   'wieder_zwei_spuren',
#   'zwei_spuren_pro',
#   'spuren_pro_fahrtrichtung',
#   'pro_fahrtrichtung_zur',
#   'fahrtrichtung_zur_verfügung',
#   'renzenhof_zu_einem',
#   'zu_einem_schweren',
#   'einem_schweren_verkehrsunfall',
#   'schweren_verkehrsunfall_mit',
#   'verkehrsunfall_mit_fünf',
#   'mit_fünf_verletzten',
#   'fünf_verletzten_darunter',
#   'verletzten_darunter_ein',
#   'darunter_ein_schwerverletzter',
#   'ein_schwerverletzter_ist',
#   'schwerverletzter_ist_es',
#   'ist_es_am',
#   'es_am_gestrigen',
#   'am_gestrigen_sonntagabend',
#   'gestrigen_sonntagabend_auf',
#   'sonntagabend_auf_der',
#   'auf_der_azwischen',
#   'der_azwischen_der',
#   'azwischen_der_anschlussstelle',
#   'der_anschlussstelle_und',
#   'anschlussstelle_und_dem',
#   'und_dem_autobahnkreuz',
#   'dem_autobahnkreuz_nürnberg',
#   'autobahnkreuz_nürnberg_gekommen',
#   'aachener_gastronomen_verlieren',
#   'gastronomen_verlieren_bis',
#   'verlieren_bis_zu',
#   'bis_zu_prozent',
#   'zu_prozent_ihrer',
#   'prozent_ihrer_plätze',
#   'aaron_lahl_verdeutlicht',
#   'lahl_verdeutlicht_in',
#   'verdeutlicht_in_seinem',
#   'in_seinem_beitrag',
#   'seinem_beitrag_analyzing',
#   'beitrag_analyzing_queer',
#   'analyzing_queer_am',
#   'queer_am_beispiel',
#   'am_beispiel_von',
#   'beispiel_von_antke',
#   'von_antke_engel',
#   'antke_engel_inwiefern',
#   'engel_inwiefern_eine',
#   'inwiefern_eine_queere',
#   'eine_queere_psychoanalyse',
#   'queere_psychoanalyse_die',
#   'psychoanalyse_die_begriffe',
#   'die_begriffe_der',
#   'begriffe_der_klassischen',
#   'der_klassischen_psychoanalyse',
#   'klassischen_psychoanalyse_komplett',
#   'psychoanalyse_komplett_entkernt',
#   'komplett_entkernt_und',
#   'entkernt_und_ihr',
#   'und_ihr_emanzipatorisches',
#   'ihr_emanzipatorisches_potential',
#   'emanzipatorisches_potential_in',
#   'potential_in_ihr',
#   'in_ihr_gegenteil',
#   'ihr_gegenteil_verkehrt',
#   'aaron_purschwitz_m',
#   'sicherte_sich_trotz',
#   'sich_trotz_platz',
#   'trotz_platz_zwei',
#   'platz_zwei_im',
#   'zwei_im_weitsprung',
#   'im_weitsprung_meter',
#   'ab_mai_dürfen',
#   'mai_dürfen_cafés',
#   'dürfen_cafés_und',
#   'cafés_und_restaurants',
#   'und_restaurants_öffnen',
#   'restaurants_öffnen_wenn',
#   'öffnen_wenn_sie',
#   'wenn_sie_ihre',
#   'sie_ihre_kundschaft',
#   'ihre_kundschaft_ausserhalb',
#   'kundschaft_ausserhalb_bedienen',
#   'ab_uhr_soll',
#   'uhr_soll_in',
#   'soll_in_der',
#   'in_der_saalestadt',
#   'der_saalestadt_für',
#   'saalestadt_für_drei',
#   'für_drei_minuten',
#   'drei_minuten_das',
#   'minuten_das_leben',
#   'das_leben_ruhen',
#   'leben_ruhen_und',
#   'ruhen_und_schweigend',
#   'und_schweigend_der',
#   'schweigend_der_menschen',
#   'der_menschen_gedacht',
#   'menschen_gedacht_werden',
#   'gedacht_werden_die',
#   'werden_die_getötet',
#   'die_getötet_verletzt',
#   'getötet_verletzt_und',
#   'verletzt_und_traumatisiert',
#   'und_traumatisiert_worden',
#   'traumatisiert_worden_sind',
#   'ab_uhr_will',
#   'uhr_will_die',
#   'will_die_in',
#   'die_in_einer',
#   'in_einer_zuerst',
#   'einer_zuerst_die',
#   'zuerst_die_oberbürgermeister',
#   'die_oberbürgermeister_und',
#   'oberbürgermeister_und_landräte',
#   'und_landräte_über',
#   'landräte_über_die',
#   'über_die_neuen',
#   'die_neuen_informieren',
#   'ab_dezember_sollen',
#   'dezember_sollen_die',
#   'sollen_die_ausgangsbeschränkungen',
#   'die_ausgangsbeschränkungen_fallen',
#   'ausgangsbeschränkungen_fallen_kinos',
#   'fallen_kinos_theater',
#   'kinos_theater_und',
#   'theater_und_museen',
#   'und_museen_wieder',
#   'museen_wieder_öffnen',
#   'ab_juni_würden',
#   'juni_würden_die',
#   'würden_die_grenzen',
#   'die_grenzen_zwischen',
#   'grenzen_zwischen_deutschland',
#   'zwischen_deutschland_und',
#   'deutschland_und_österreich',
#   'und_österreich_wieder',
#   'österreich_wieder_komplett',
#   'wieder_komplett_offen',
#   'komplett_offen_sein',
#   'ab_uhr_werden',
#   'uhr_werden_mahntafeln',
#   'werden_mahntafeln_übergeben',
#   'ab_galt_die',
#   'galt_die_und',
#   'die_und_respective',
#   'und_respective_in',
#   'respective_in_der',
#   'in_der_festgelegt',
#   'der_festgelegt_wurde',
#   'festgelegt_wurde_dass',
#   'wurde_dass_sich',
#   'dass_sich_in',
#   'sich_in_jeder',
#   'in_jeder_quarantänestation',
#   'jeder_quarantänestation_ein',
#   'quarantänestation_ein_leutnant',
#   'ein_leutnant_und',
#   'leutnant_und_berittene',
#   'und_berittene_männer',
#   'berittene_männer_drei',
#   'männer_drei_wachen',
#   'drei_wachen_und',
#   'wachen_und_ein',
#   'und_ein_doktor',
#   'ein_doktor_befinden',
#   'doktor_befinden_mussten',
#   'ab_uhr_stehen',
#   'uhr_stehen_die',
#   'stehen_die_fohlen',
#   'die_fohlen_dem',
#   'fohlen_dem_fk',
#   'dem_fk_shakhtar',
#   'fk_shakhtar_donetsk',
#   'shakhtar_donetsk_gegenüber',
#   'ab_mai_dürfen',
#   'mai_dürfen_die',
#   'dürfen_die_gastronomie',
#   'die_gastronomie_im',
#   'gastronomie_im_und',
#   'im_und_innenbereich',
#   'und_innenbereich_sowie',
#   'innenbereich_sowie_die',
#   'sowie_die_ferienwohnungen',
#   'die_ferienwohnungen_und',
#   'ferienwohnungen_und_campingplätze',
#   'und_campingplätze_wieder',
#   'campingplätze_wieder_schrittweise',
#   'wieder_schrittweise_öffnen',
#   'ab_wurden_etliche',
#   'wurden_etliche_von',
#   'etliche_von_ihnen',
#   'von_ihnen_in',
#   'ihnen_in_und',
#   'in_und_konzentrationslager',
#   'und_konzentrationslager_verschleppt',
#   'ab_bis_entstand',
#   'bis_entstand_ein',
#   'entstand_ein_mehrfamilienhaus',
#   'ein_mehrfamilienhaus_nach',
#   'mehrfamilienhaus_nach_dem',
#   'nach_dem_andern',
#   'dem_andern_auch',
#   'andern_auch_drei',
#   'auch_drei_stöckige',
#   'drei_stöckige_hochhäuser',
#   'ab_dezember_tritt',
#   'dezember_tritt_eine',
#   'tritt_eine_neue',
#   'eine_neue_verordnung',
#   'neue_verordnung_für',
#   'verordnung_für_alle',
#   'für_alle_in',
#   'alle_in_kraft',
#   'in_kraft_die',
#   'kraft_die_nach',
#   'die_nach_wollen',
#   'ab_uhr_liest',
#   'uhr_liest_dann',
#   'liest_dann_am',
#   'dann_am_freitag',
#   'am_freitag_februar',
#   'freitag_februar_johannes',
#   'februar_johannes_twaroch',
#   'johannes_twaroch_im',
#   'twaroch_im_gemeindefestsaal',
#   'im_gemeindefestsaal_von',
#   'gemeindefestsaal_von_kirchstetten',
#   'von_kirchstetten_aus',
#   'kirchstetten_aus_seinem',
#   'aus_seinem_anekdotenschatz',
#   'ab_juli_will',
#   'juli_will_beispielsweise',
#   'will_beispielsweise_einige',
#   'beispielsweise_einige_urlaubsorte',
#   'einige_urlaubsorte_wieder',
#   'urlaubsorte_wieder_für',
#   'wieder_für_touristen',
#   'für_touristen_öffnen',
#   'ab_juni_gilt',
#   'juni_gilt_aber',
#   'gilt_aber_wieder',
#   'aber_wieder_fürs',
#   'wieder_fürs_parken',
#   'fürs_parken_muss',
#   'parken_muss_gezahlt',
#   'muss_gezahlt_werden',
#   'ab_mai_sollen',
#   'mai_sollen_dann',
#   'sollen_dann_alle',
#   'dann_alle_anderen',
#   'alle_anderen_geschäfte',
#   'anderen_geschäfte_friseure',
#   'geschäfte_friseure_und',
#   'friseure_und_einkaufszentren',
#   'und_einkaufszentren_öffnen',
#   'einkaufszentren_öffnen_ebenfalls',
#   'öffnen_ebenfalls_mit',
#   'ebenfalls_mit_strengen',
#   'mit_strengen_auflagen',
#   'ab_märz_senken',
#   'märz_senken_viele',
#   'senken_viele_versicherungen',
#   'viele_versicherungen_die',
#   'versicherungen_die_beiträge',
#   'die_beiträge_für',
#   'beiträge_für_die',
#   'für_die_haftpflicht',
#   'die_haftpflicht_für',
#   'ab_oktober_wird',
#   'oktober_wird_auch',
#   'wird_auch_der',
#   'auch_der_coausstoß',
#   'der_coausstoß_wie',
#   'coausstoß_wie_er',
#   'wie_er_in',
#   'er_in_den',
#   'in_den_steht',
#   'den_steht_bei',
#   'steht_bei_motorrädern',
#   'bei_motorrädern_und',
#   'motorrädern_und_pkw',
#   'und_pkw_zur',
#   'pkw_zur_berechnung',
#   'zur_berechnung_herangezogen',
#   'berechnung_herangezogen_weiß',
#   'herangezogen_weiß_nikola',
#   'weiß_nikola_junick',
#   'ab_september_ziehen',
#   'september_ziehen_die',
#   'ziehen_die_ersten',
#   'die_ersten_bewohner',
#   'ersten_bewohner_in',
#   'bewohner_in_den',
#   'in_den_neubau',
#   'den_neubau_in',
#   'neubau_in_der',
#   'ab_uhr_live',
#   'uhr_live_aus',
#   'live_aus_der',
#   'aus_der_staatsoper',
#   'ab_gibt_es',
#   'gibt_es_für',
#   'es_für_rund',
#   'für_rund_neun',
#   'rund_neun_millionen',
#   'neun_millionen_autofahrer',
#   'millionen_autofahrer_neue',
#   'autofahrer_neue_regionalklassen',
#   'neue_regionalklassen_bei',
#   'regionalklassen_bei_der',
#   'ab_solle_unter',
#   'solle_unter_dem',
#   'unter_dem_titel',
#   'dem_titel_dein',
#   'titel_dein_jahr',
#   'dein_jahr_für',
#   'jahr_für_deutschland',
#   'für_deutschland_ein',
#   'deutschland_ein_neuer',
#   'ein_neuer_dienst',
#   'neuer_dienst_eingeführt',
#   'dienst_eingeführt_werden',
#   'eingeführt_werden_sagte',
#   'werden_sagte_in',
#   'sagte_in_berlin',
#   'in_berlin_im',
#   'berlin_im_rahmen',
#   'im_rahmen_einer',
#   'rahmen_einer_virtuellen',
#   'ab_werde_sich',
#   'werde_sich_der',
#   'sich_der_markt',
#   'der_markt_langsam',
#   'markt_langsam_erholen',
#   'ab_soll_dann',
#   'soll_dann_vorwiegend',
#   'dann_vorwiegend_auf',
#   'vorwiegend_auf_material',
#   'auf_material_aus',
#   'material_aus_inländischer',
#   'aus_inländischer_produktion',
#   'inländischer_produktion_umgestellt',
#   'produktion_umgestellt_werden',
#   'ab_uhr_erreichte',
#   'uhr_erreichte_die',
#   'erreichte_die_familienserie',
#   'die_familienserie_um',
#   'familienserie_um_himmels',
#   'um_himmels_willen',
#   'himmels_willen_dann',
#   'willen_dann_im',
#   'dann_im_ersten',
#   'im_ersten_millionen',
#   'ersten_millionen_prozent',
#   'millionen_prozent_die',
#   'prozent_die_krankenhausserie',
#   'die_krankenhausserie_wollten',
#   'krankenhausserie_wollten_im',
#   'wollten_im_anschluss',
#   'im_anschluss_in',
#   'anschluss_in_aller',
#   'in_aller_freundschaft',
#   'aller_freundschaft_millionen',
#   'freundschaft_millionen_prozent',
#   'millionen_prozent_sehen',
#   'ab_uhr_sahen',
#   'uhr_sahen_millionen',
#   'sahen_millionen_zuschauer',
#   'millionen_zuschauer_die',
#   'zuschauer_die_episode',
#   'die_episode_leuchtfeuer',
#   'ab_dezember_wird',
#   'dezember_wird_eine',
#   'wird_eine_teststation',
#   'eine_teststation_mit',
#   'teststation_mit_zwei',
#   'mit_zwei_teststraßen',
#   'zwei_teststraßen_von',
#   'teststraßen_von_etwa',
#   'von_etwa_soldatinnen',
#   'etwa_soldatinnen_und',
#   'soldatinnen_und_soldaten',
#   'und_soldaten_bis',
#   'soldaten_bis_dezember',
#   'bis_dezember_am',
#   'dezember_am_standort',
#   'am_standort_linz',
#   'standort_linz_in',
#   'linz_in_oberösterreich',
#   'in_oberösterreich_betrieben',
#   'ab_februar_geht',
#   'februar_geht_es',
#   'geht_es_in',
#   'es_in_die',
#   'in_die_vergangenheit',
#   'die_vergangenheit_mit',
#   'vergangenheit_mit_und',
#   'mit_und_alias',
#   'und_alias_meyer',
#   'alias_meyer_offerman',
#   'ab_märz_läuft',
#   'märz_läuft_immer',
#   'läuft_immer_montags',
#   'immer_montags_die',
#   'montags_die_neue',
#   'die_neue_feuer',
#   'neue_feuer_und',
#   'feuer_und_flamme',
#   'ab_uhr_dürften',
#   'uhr_dürften_restaurants',
#   'dürften_restaurants_und',
#   'restaurants_und_kneipen',
#   'und_kneipen_dann',
#   'kneipen_dann_nicht',
#   'dann_nicht_mehr',
#   'nicht_mehr_geöffnet',
#   'mehr_geöffnet_haben',
#   'ab_mai_empfängt',
#   'mai_empfängt_die',
#   'empfängt_die_beliebte',
#   'die_beliebte_urlaubsregion',
#   'beliebte_urlaubsregion_auch',
#   'urlaubsregion_auch_wieder',
#   'auch_wieder_urlauber',
#   'wieder_urlauber_aus',
#   'urlauber_aus_anderen',
#   'aus_anderen_bundesländern',
#   'ab_juli_werde',
#   'juli_werde_das',
#   'werde_das_vorstandsmitglied',
#   'das_vorstandsmitglied_renko',
#   'vorstandsmitglied_renko_dirksen',
#   'renko_dirksen_die',
#   'dirksen_die_arbeit',
#   'die_arbeit_des',
#   'arbeit_des_vorstands',
#   'des_vorstands_koordinieren',
#   'vorstands_koordinieren_teilte',
#   'koordinieren_teilte_das',
#   'teilte_das_unternehmen',
#   'das_unternehmen_am',
#   'unternehmen_am_freitag',
#   'am_freitag_mit',
#   'ab_september_reist',
#   'september_reist_oscarpreisträgerin',
#   'reist_oscarpreisträgerin_hilary',
#   'oscarpreisträgerin_hilary_swank',
#   'hilary_swank_million',
#   'swank_million_dollar',
#   'million_dollar_baby',
#   'dollar_baby_ins',
#   'baby_ins_all',
#   'ab_euro_bei',
#   'euro_bei_alternate',
#   'ab_uhr_schunkelten',
#   'uhr_schunkelten_sich',
#   'schunkelten_sich_die',
#   'sich_die_klassen',
#   'die_klassen_auf',
#   'klassen_auf_den',
#   'auf_den_tag',
#   'den_tag_ein',
#   'ab_uhr_wird',
#   'uhr_wird_der',
#   'wird_der_bahnhof',
#   'der_bahnhof_köln',
#   'bahnhof_köln_evakuiert',
#   'köln_evakuiert_ab',
#   'evakuiert_ab_dann',
#   'ab_dann_wird',
#   'dann_wird_auch',
#   'wird_auch_der',
#   'auch_der_zugverkehr',
#   'der_zugverkehr_unterbrochen',
#   'zugverkehr_unterbrochen_sein',
#   'ab_anfang_übernimmt',
#   'anfang_übernimmt_bremen',
#   'ab_april_gilt',
#   'april_gilt_im',
#   'gilt_im_brunauquartier',
#   'im_brunauquartier_im',
#   'brunauquartier_im_kreis',
#   'im_kreis_tempo',
#   'kreis_tempo_für',
#   'tempo_für_aussenstehende',
#   'für_aussenstehende_sind',
#   'aussenstehende_sind_das',
#   'sind_das_nur',
#   'das_nur_ein',
#   'nur_ein_paar',
#   'ein_paar_weitere',
#   'paar_weitere_quartierstrassen',
#   'weitere_quartierstrassen_auf',
#   'quartierstrassen_auf_denen',
#   'auf_denen_die',
#   'denen_die_stadt',
#   'die_stadt_das',
#   'stadt_das_tempo',
#   'das_tempo_drosselt',
#   'ab_april_plant',
#   'april_plant_signa',
#   'plant_signa_mit',
#   'signa_mit_vorbereitenden',
#   'mit_vorbereitenden_maßnahmen',
#   'vorbereitenden_maßnahmen_für',
#   'maßnahmen_für_gründung',
#   'für_gründung_und',
#   'gründung_und_aushub',
#   'und_aushub_der',
#   'aushub_der_baugrube',
#   'der_baugrube_zu',
#   'baugrube_zu_beginnen',
#   'ab_april_werden',
#   'april_werden_die',
#   'werden_die_flugabwehrsysteme',
#   'die_flugabwehrsysteme_einsatzbereit',
#   'flugabwehrsysteme_einsatzbereit_sein',
#   'abarhoun_bestritt_trotz',
#   'bestritt_trotz_seiner',
#   'trotz_seiner_erkrankung',
#   'seiner_erkrankung_partien',
#   'erkrankung_partien_in',
#   'partien_in_der',
#   'in_der_letzten',
#   'der_letzten_saison',
#   'letzten_saison_und',
#   'saison_und_traf',
#   'und_traf_dabei',
#   'traf_dabei_zweimal',
#   'ab_august_fährt',
#   'august_fährt_der',
#   'fährt_der_twin',
#   'der_twin_city',
#   'twin_city_liner',
#   'city_liner_dann',
#   'liner_dann_wieder',
#   'dann_wieder_nach',
#   'wieder_nach_bratislava',
#   'trotz_umsatzeinbussen_mit',
#   'umsatzeinbussen_mit_hoher',
#   'mit_hoher_flughöhe',
#   'hoher_flughöhe_wie',
#   'flughöhe_wie_passt',
#   'wie_passt_das',
#   'passt_das_zusammen',
#   'uhr_war_eine',
#   'war_eine_abwanderung',
#   'eine_abwanderung_der',
#   'abwanderung_der_teilnehmer',
#   'der_teilnehmer_spürbar',
#   'ab_da_konnte',
#   'da_konnte_der',
#   'konnte_der_fc',
#   'der_fc_die',
#   'fc_die_partie',
#   'die_partie_offen',
#   'partie_offen_gestalten',
#   'offen_gestalten_bis',
#   'gestalten_bis_rafael',
#   'bis_rafael_czichos',
#   'rafael_czichos_in',
#   'czichos_in_einen',
#   'in_einen_zweikampf',
#   'einen_zweikampf_mit',
#   'zweikampf_mit_baumgartner',
#   'mit_baumgartner_kam',
#   'baumgartner_kam_der',
#   'kam_der_österreicher',
#   'der_österreicher_fiel',
#   'österreicher_fiel_und',
#   'fiel_und_schrie',
#   'und_schrie_und',
#   'schrie_und_der',
#   'und_der_referee',
#   'der_referee_daniel',
#   'referee_daniel_siebert',
#   'daniel_siebert_nach',
#   'siebert_nach_auf',
#   'nach_auf_falschwerweise',
#   'auf_falschwerweise_strafstoß',
#   'falschwerweise_strafstoß_entschied',
#   'abdallah_macht_sein',
#   'macht_sein_beruf',
#   'sein_beruf_spaß',
#   'beruf_spaß_auch',
#   'spaß_auch_weil',
#   'auch_weil_er',
#   'weil_er_sich',
#   'er_sich_wandelt',
#   'ab_dem_august',
#   'dem_august_steht',
#   'august_steht_die',
#   'steht_die_anlage',
#   'die_anlage_den',
#   'anlage_den_vereinen',
#   'den_vereinen_für',
#   'vereinen_für_trainings',
#   'für_trainings_und',
#   'trainings_und_testspiele',
#   'und_testspiele_zur',
#   'testspiele_zur_verfügung',
#   'ab_dem_mai',
#   'dem_mai_haben',
#   'mai_haben_sportvereine',
#   'haben_sportvereine_zudem',
#   'sportvereine_zudem_die',
#   'zudem_die_möglichkeit',
#   'die_möglichkeit_vereinseigene',
#   'möglichkeit_vereinseigene_sporthallen',
#   'vereinseigene_sporthallen_bzw',
#   'kursräume_wieder_zu',
#   'wieder_zu_öffnen',
#   'ab_dem_november',
#   'dem_november_startet',
#   'november_startet_ein',
#   'startet_ein_testturnier',
#   'ein_testturnier_mit',
#   'testturnier_mit_acht',
#   'mit_acht_der',
#   'acht_der_clubs',
#   'der_clubs_darunter',
#   'clubs_darunter_ist',
#   'darunter_ist_auch',
#   'ist_auch_der',
#   'auch_der_ehc',
#   'der_ehc_red',
#   'ehc_red_bull',
#   'red_bull_münchen',
#   'ab_dem_dezember',
#   'dem_dezember_lockert',
#   'dezember_lockert_der',
#   'lockert_der_kanton',
#   'der_kanton_wallis',
#   'kanton_wallis_seine',
#   'ab_dem_mai',
#   'dem_mai_soll',
#   'mai_soll_es',
#   'soll_es_genauso',
#   'es_genauso_erfolgreich',
#   'genauso_erfolgreich_weitergehen',
#   'ab_dem_märz',
#   'dem_märz_stieg',
#   'märz_stieg_die',
#   'stieg_die_zahl',
#   'die_zahl_der',
#   'zahl_der_durchgeführten',
#   'der_durchgeführten_tests',
#   'durchgeführten_tests_stark',
#   'tests_stark_an',
#   'stark_an_in',
#   'an_in_den',
#   'in_den_vier',
#   'den_vier_tagen',
#   'vier_tagen_bis',
#   'tagen_bis_zum',
#   'bis_zum_märz',
#   'zum_märz_wurden',
#   'märz_wurden_im',
#   'wurden_im_schnitt',
#   'im_schnitt_menschen',
#   'schnitt_menschen_getestet',
#   'ab_dem_juli',
#   'dem_juli_dürfen',
#   'juli_dürfen_kunden',
#   'dürfen_kunden_geschäfte',
#   'kunden_geschäfte_wieder',
#   'geschäfte_wieder_in',
#   'wieder_in_begleitung',
#   'in_begleitung_besuchen',
#   'ab_dem_märz',
#   'dem_märz_ist',
#   'märz_ist_das',
#   'ist_das_und',
#   'das_und_ride',
#   'und_ride_angebot',
#   'ride_angebot_der',
#   'angebot_der_stadt',
#   'der_stadt_kostenlos',
#   'ab_dem_oktober',
#   'dem_oktober_fällt',
#   'oktober_fällt_die',
#   'fällt_die_obergrenze',
#   'die_obergrenze_von',
#   'obergrenze_von_personen',
#   'von_personen_für',
#   'personen_für_veranstaltungen',
#   'ab_dem_september',
#   'dem_september_tritt',
#   'september_tritt_ein',
#   'tritt_ein_gesetz',
#   'ein_gesetz_zur',
#   'gesetz_zur_reform',
#   'zur_reform_der',
#   'reform_der_psychotherapeutenausbildung',
#   'der_psychotherapeutenausbildung_in',
#   'psychotherapeutenausbildung_in_kraft',
#   'ab_dem_mai',
#   'dem_mai_kommen',
#   'mai_kommen_je',
#   'kommen_je_nach',
#   'je_nach_bundesland',
#   'nach_bundesland_und',
#   'bundesland_und_region',
#   'und_region_die',
#   'region_die_ersten',
#   'die_ersten_lockerungen',
#   'ab_dem_bahnhof',
#   'dem_bahnhof_gösing',
#   'bahnhof_gösing_führt',
#   'gösing_führt_der',
#   'führt_der_weg',
#   'der_weg_zum',
#   'weg_zum_erlaufboden',
#   'zum_erlaufboden_und',
#   'erlaufboden_und_von',
#   'und_von_dort',
#   'von_dort_durch',
#   'dort_durch_die',
#   'durch_die_beeindruckenden',
#   'die_beeindruckenden_zum',
#   'beeindruckenden_zum_kraftwerk',
#   'zum_kraftwerk_stierwaschboden',
#   'ab_dem_heutigen',
#   'dem_heutigen_mittwoch',
#   'heutigen_mittwoch_dezember',
#   'mittwoch_dezember_gilt',
#   'dezember_gilt_für',
#   'gilt_für_und',
#   'für_und_elektronische',
#   'und_elektronische_zeitschriften',
#   'elektronische_zeitschriften_der',
#   'zeitschriften_der_ermäßigte',
#   'der_ermäßigte_mehrwertsteuersatz',
#   'ermäßigte_mehrwertsteuersatz_von',
#   'mehrwertsteuersatz_von_prozent',
#   'ab_dem_jahr',
#   'dem_jahr_sollen',
#   'jahr_sollen_keine',
#   'sollen_keine_neuen',
#   'keine_neuen_ölheizkessel',
#   'neuen_ölheizkessel_mehr',
#   'ölheizkessel_mehr_aufgestellt',
#   'mehr_aufgestellt_werden',
#   'ab_dem_kommenden',
#   'dem_kommenden_jahr',
#   'kommenden_jahr_wird',
#   'jahr_wird_der',
#   'wird_der_spanier',
#   'der_spanier_carlos',
#   'spanier_carlos_sainz',
#   'carlos_sainz_anstelle',
#   'sainz_anstelle_des',
#   'anstelle_des_deutschen',
#   'des_deutschen_für',
#   'deutschen_für_das',
#   'für_das_traditionsteam',
#   'das_traditionsteam_in',
#   'traditionsteam_in_der',
#   'in_der_tätig',
#   'der_tätig_sein',
#   'tätig_sein_bestätigen',
#   'sein_bestätigen_die',
#   'bestätigen_die_italiener',
#   'die_italiener_am',
#   'italiener_am_donnerstag',
#   'ab_dem_kommenden',
#   'dem_kommenden_januar',
#   'kommenden_januar_gibt',
#   'januar_gibt_es',
#   'gibt_es_pro',
#   'es_pro_krankheitsfall',
#   'pro_krankheitsfall_drei',
#   'krankheitsfall_drei_tage',
#   'drei_tage_bezahlten',
#   'tage_bezahlten_urlaub',
#   'ab_dem_kommenden',
#   'dem_kommenden_montag',
#   'kommenden_montag_zum',
#   'montag_zum_beispiel',
#   'zum_beispiel_können',
#   'beispiel_können_studios',
#   'können_studios_in',
#   'studios_in_wiederum',
#   'in_wiederum_den',
#   'wiederum_den_betrieb',
#   'den_betrieb_aufnehmen',
#   'betrieb_aufnehmen_in',
#   'aufnehmen_in_ist',
#   'in_ist_das',
#   'ist_das_ab',
#   'das_ab_pfingsten',
#   'ab_pfingsten_wieder',
#   'pfingsten_wieder_möglich',
#   'wieder_möglich_alles',
#   'möglich_alles_unter',
#   'alles_unter_bestimmten',
#   'unter_bestimmten_auflagen',
#   'ab_dem_kommenden',
#   'dem_kommenden_wochenende',
#   'kommenden_wochenende_fahren',
#   'wochenende_fahren_nachts',
#   'fahren_nachts_bis',
#   'nachts_bis_auf',
#   'bis_auf_weiteres',
#   'auf_weiteres_keine',
#   'weiteres_keine_züge',
#   'keine_züge_und',
#   'züge_und_busse',
#   'und_busse_mehr',
#   'ab_dem_nachmittag',
#   'dem_nachmittag_sind',
#   'nachmittag_sind_in',
#   'sind_in_der',
#   'in_der_südwesthälfte',
#   'der_südwesthälfte_sowie',
#   'südwesthälfte_sowie_über',
#   'sowie_über_dem',
#   'über_dem_bergland',
#   'dem_bergland_einzelne',
#   'bergland_einzelne_schauer',
#   'einzelne_schauer_möglich',
#   'ab_dem_siebten',
#   'dem_siebten_monat',
#   'siebten_monat_in',
#   'monat_in_kurzarbeit',
#   'in_kurzarbeit_soll',
# ...
#   'nicht_die_angst',
#   'die_angst_vor',
#   'angst_vor_asylanten',
#   'vor_asylanten_sondern',
#   'asylanten_sondern_die',
#   'sondern_die_überfremdung',
#   'die_überfremdung_deutschlands',
#   'und_ihr_politiker',
#   'ihr_politiker_wisst',
#   'politiker_wisst_dieses',
#   'wisst_dieses_auch',
#   'dieses_auch_ganz',
#   'auch_ganz_genau',
#   'es_reicht_stopp',
#   'spahn_von_cdu',
#   'von_cdu_will',
#   'cdu_will_wegfall',
#   'will_wegfall_von',
#   'wegfall_von_mindestlohn',
#   'von_mindestlohn_für',
#   'mindestlohn_für_asylanten',
#   'klare_schlechterstellunf_von',
#   'schlechterstellunf_von_einheimischen',
#   'wenn_sich_der',
#   'sich_der_hass',
#   'der_hass_in',
#   'hass_in_deutschland',
#   'in_deutschland_mal',
#   'deutschland_mal_seinen',
#   'mal_seinen_weg',
#   'seinen_weg_gebahnt',
#   'weg_gebahnt_hat',
#   'gebahnt_hat_wen',
#   'hat_wen_wird',
#   'wen_wird_er',
#   'wird_er_eigentlich',
#   'er_eigentlich_treffen',
#   'rapefugees_politiker_ossis',
#   'politiker_ossis_journalisten',
#   'd-radio_millionen_menschen',
#   'millionen_menschen_fluechtlinge',
#   'menschen_fluechtlinge_migranten',
#   'fluechtlinge_migranten_asylanten',
#   'migranten_asylanten_in',
#   'asylanten_in_der',
#   'in_der_tuerkei',
#   'der_tuerkei_verhandlungen',
#   'tuerkei_verhandlungen_mit',
#   'verhandlungen_mit_der',
#   'mit_der_eu',
#   'der_eu_was',
#   'eu_was_nützt',
#   'was_nützt_mir',
#   'nützt_mir_der',
#   'mir_der_erde',
#   'der_erde_geld',
#   'kein_kranker_mensch',
#   'kranker_mensch_genießt',
#   'mensch_genießt_die',
#   'genießt_die_welt',
#   'goethe_deutschland_hartziv',
#   'deutschland_hartziv_merkel',
#   'hartziv_merkel_fluechtlinge',
#   'merkel_fluechtlinge_asylanten',
#   'fluechtlinge_asylanten_vor',
#   'asylanten_vor_einem',
#   'vor_einem_jahr',
#   'einem_jahr_mussten',
#   'jahr_mussten_eltern',
#   'mussten_eltern_wenn',
#   'eltern_wenn_töchter',
#   'wenn_töchter_ins',
#   'töchter_ins_schwimmbad',
#   'ins_schwimmbad_gingen',
#   'schwimmbad_gingen_nur',
#   'gingen_nur_überlegen',
#   'nur_überlegen_ob',
#   'überlegen_ob_sie',
#   'ob_sie_schon',
#   'sie_schon_schwimmen',
#   'schon_schwimmen_können',
#   'rapefugees_hartaberfair_andere',
#   'hartaberfair_andere_eu',
#   'andere_eu_länder',
#   'eu_länder_sind',
#   'länder_sind_land',
#   'sind_land_und',
#   'land_und_bürger',
#   'und_bürger_wichtiger',
#   'bürger_wichtiger_als',
#   'wichtiger_als_asylanten',
#   'moralisch_ethisch_und',
#   'ethisch_und_finanziell',
#   'und_finanziell_verständlich',
#   'finanziell_verständlich_besorgtegutmenschen',
#   'verständlich_besorgtegutmenschen_regen',
#   'besorgtegutmenschen_regen_sich',
#   'regen_sich_auf',
#   'sich_auf_khaled',
#   'auf_khaled_von',
#   'khaled_von_asylanten',
#   'von_asylanten_getötet',
#   'lageso-toter_moabithilft_ente',
#   'moabithilft_ente_handgranate',
#   'ente_handgranate_warfen',
#   'handgranate_warfen_migranten',
#   'warfen_migranten_das',
#   'migranten_das_was',
#   'das_was_im',
#   'was_im_swr',
#   'im_swr_radio',
#   'swr_radio_momentan',
#   'radio_momentan_an',
#   'momentan_an_werbung',
#   'an_werbung_pro',
#   'werbung_pro_asylanten',
#   'pro_asylanten_gemacht',
#   'asylanten_gemacht_wird',
#   'gemacht_wird_ist',
#   'wird_ist_so',
#   'ist_so_penetrant',
#   'so_penetrant_wie',
#   'penetrant_wie_phase',
#   'wie_phase_der',
#   'phase_der_weihnachtssongs',
#   'der_weihnachtssongs_fastnachts-seeligkeit',
#   'weihnachtssongs_fastnachts-seeligkeit_idee',
#   'fastnachts-seeligkeit_idee_hartzer',
#   'idee_hartzer_vs',
#   'hartzer_vs_asylanten',
#   'vs_asylanten_im',
#   'asylanten_im_einzelkampf',
#   'wer_schneller_nen',
#   'schneller_nen_arbeits/ausbildungsplatz',
#   'nen_arbeits/ausbildungsplatz_findet',
#   'arbeits/ausbildungsplatz_findet_und',
#   'findet_und_deutsch',
#   'und_deutsch_lernt/kann',
#   'deutsch_lernt/kann_darf',
#   'lernt/kann_darf_bleiben',
#   'schweden_in_bürgerkriegsartigen',
#   'in_bürgerkriegsartigen_zuständen',
#   'eine_lasche_konservative',
#   'lasche_konservative_und',
#   'konservative_und_eine',
#   'und_eine_irre',
#   'eine_irre_sozialistische',
#   'irre_sozialistische_regierung',
#   'sozialistische_regierung_fluten',
#   'regierung_fluten_das',
#   'fluten_das_land',
#   'das_land_mit',
#   'land_mit_asylanten',
#   'mit_asylanten_utter',
#   'asylanten_utter_zbale',
#   'utter_zbale_in',
#   'zbale_in_this',
#   'in_this_hashtag',
#   'this_hashtag_rapefugees',
#   'hashtag_rapefugees_gestern',
#   'rapefugees_gestern_kamen',
#   'gestern_kamen_die',
#   'kamen_die_asylanten',
#   'heute_nacht_wurde',
#   'nacht_wurde_versucht',
#   'wurde_versucht_einzubrechen',
#   'erschreckend_daß_es',
#   'daß_es_frauen',
#   'es_frauen_sind',
#   'frauen_sind_die',
#   'sind_die_jahre',
#   'die_jahre_emanzipation',
#   'jahre_emanzipation_zugunsten',
#   'emanzipation_zugunsten_islamistischer',
#   'zugunsten_islamistischer_vergewaltiger',
#   'islamistischer_vergewaltiger_in',
#   'vergewaltiger_in_die',
#   'in_die_tonne',
#   'die_tonne_treten',
#   'rapefugees_afd_deutschland',
#   'afd_deutschland_übt',
#   'deutschland_übt_karneval',
#   'übt_karneval_nach',
#   'karneval_nach_den',
#   'nach_den_regeln',
#   'den_regeln_der',
#   'regeln_der_scharia',
#   'der_scharia_weil',
#   'scharia_weil_da',
#   'weil_da_eh',
#   'da_eh_bald',
#   'eh_bald_nur',
#   'bald_nur_noch',
#   'nur_noch_moslems',
#   'noch_moslems_feiern',
#   'moslems_feiern_werden',
#   'deutsche_frauen_aus',
#   'frauen_aus_angst',
#   'aus_angst_zuhause',
#   'angst_zuhause_wenn',
#   'zuhause_wenn_ich',
#   'wenn_ich_mir',
#   'ich_mir_den',
#   'mir_den_mond',
#   'den_mond_gerade',
#   'mond_gerade_so',
#   'gerade_so_anschaue',
#   'so_anschaue_die',
#   'anschaue_die_islamisierung',
#   'die_islamisierung_des',
#   'islamisierung_des_abendlandes',
#   'des_abendlandes_ist',
#   'abendlandes_ist_doch',
#   'ist_doch_schon',
#   'doch_schon_längst',
#   'schon_längst_durch',
#   'fakt_auf_ard',
#   'auf_ard_asylanten',
#   'ard_asylanten_fahren',
#   'asylanten_fahren_mit',
#   'fahren_mit_taxi',
#   'mit_taxi_herum',
#   'taxi_herum_auf',
#   'herum_auf_steuerzahlerkosten',
#   'merkel_macht_es',
#   'macht_es_möglich',
#   'asylanten_man_kann',
#   'man_kann_nicht',
#   'kann_nicht_einf',
#   'nicht_einf_verschiedene',
#   'einf_verschiedene_menschen',
#   'verschiedene_menschen_bzw',
#   'menschen_bzw_völker/kulturen',
#   'bzw_völker/kulturen_zusammenleg',
#   'völker/kulturen_zusammenleg_sagen',
#   'zusammenleg_sagen_nun',
#   'sagen_nun_seit',
#   'nun_seit_ma',
#   'seit_ma_glückl',
#   'ma_glückl_miteinander+versteht',
#   'glückl_miteinander+versteht_euch',
#   'miteinander+versteht_euch_idomeni',
#   'euch_idomeni_asylanten',
#   'idomeni_asylanten_fluechtlinge',
#   'asylanten_fluechtlinge_schöne',
#   'fluechtlinge_schöne_vorstellung',
#   'schöne_vorstellung_für',
#   'vorstellung_für_die',
#   'für_die_kameras',
#   'merkel_drückt_daheim',
#   'drückt_daheim_krokodilstränen',
#   'daheim_krokodilstränen_ins',
#   'krokodilstränen_ins_kissen',
#   'keine_schnittmenge_zwischen',
#   'schnittmenge_zwischen_npd',
#   'zwischen_npd_und',
#   'npd_und_afd',
#   'es_gibt_die',
#   'gibt_die_schnittmenge',
#   'die_schnittmenge_die',
#   'schnittmenge_die_afd',
#   'die_afd_gibt',
#   'afd_gibt_sie',
#   'gibt_sie_nicht',
#   'sie_nicht_zu',
#   'nicht_zu_arabisch',
#   'zu_arabisch_als',
#   'arabisch_als_schulsprache',
#   'als_schulsprache_islamisierung',
#   'schulsprache_islamisierung_deutschlands',
#   'islamisierung_deutschlands_in',
#   'deutschlands_in_vollem',
#   'in_vollem_gange',
#   'vollem_gange_stelle',
#   'gange_stelle_mir',
#   'stelle_mir_gerade',
#   'mir_gerade_vor',
#   'gerade_vor_wie',
#   'vor_wie_es',
#   'wie_es_wäre',
#   'es_wäre_wenn',
#   'wäre_wenn_die',
#   'wenn_die_saudis',
#   'die_saudis_in',
#   'saudis_in_deutschland',
#   'in_deutschland_einmarschieren',
#   'deutschland_einmarschieren_würden',
#   'einmarschieren_würden_scharia',
#   'würden_scharia_krieg',
#   'scharia_krieg_in',
#   'krieg_in_syrien',
#   'in_syrien_wer',
#   'syrien_wer_hat',
#   'wer_hat_uns',
#   'hat_uns_verraten',
#   'werner_faymann_ist',
#   'faymann_ist_derzeit',
#   'ist_derzeit_eine',
#   'derzeit_eine_paradebeispiel',
#   'eine_paradebeispiel_dafür',
#   'kontingent_refugeesnotwelcome_traurig',
#   'refugeesnotwelcome_traurig_lieber',
#   'traurig_lieber_horst',
#   'lieber_horst_seehofer',
#   'horst_seehofer_der',
#   'seehofer_der_bayerische',
#   'der_bayerische_staat',
#   'bayerische_staat_braucht',
#   'staat_braucht_eine',
#   'braucht_eine_strategie',
#   'eine_strategie_die',
#   'strategie_die_der',
#   'die_der_islamisierung',
#   'der_islamisierung_bayerns',
#   'islamisierung_bayerns_einen',
#   'bayerns_einen_riegel',
#   'einen_riegel_vorschiebt',
#   'sz_faz_die',
#   'faz_die_haben',
#   'die_haben_nix',
#   'haben_nix_mehr',
#   'nix_mehr_die',
#   'mehr_die_leute',
#   'die_leute_in',
#   'leute_in_den',
#   'in_den_asylanten-heimen',
#   'gut_außer_denen',
#   'außer_denen_mit',
#   'denen_mit_den',
#   'mit_den_geklauten',
#   'den_geklauten_handys.maischberger',
#   'geklauten_handys.maischberger_man',
#   'handys.maischberger_man_stelle',
#   'man_stelle_sich',
#   'stelle_sich_vor',
#   'sich_vor_es',
#   'vor_es_käme',
#   'es_käme_zum',
#   'käme_zum_frieden',
#   'zum_frieden_und',
#   'frieden_und_alle',
#   'und_alle_asylanten',
#   'alle_asylanten_mit',
#   'asylanten_mit_syrischen',
#   'mit_syrischen_pässen',
#   'syrischen_pässen_würden',
#   'pässen_würden_dorthin',
#   'würden_dorthin_ausgeflogen',
#   'wir_von_der',
#   'von_der_cdu',
#   'der_cdu_schaffen',
#   'cdu_schaffen_es',
#   'schaffen_es_weitere',
#   'es_weitere_millionen',
#   'weitere_millionen_asylanten',
#   'millionen_asylanten_nach',
#   'asylanten_nach_d',
#   'zu_locken_und',
#   'locken_und_die',
#   'und_die_dumme',
#   'die_dumme_bevölkerung',
#   'dumme_bevölkerung_zu',
#   'bevölkerung_zu_melken',
#   'maischberger_fratscher_geld',
#   'fratscher_geld_für',
#   'geld_für_migranten',
#   'für_migranten_als',
#   'migranten_als_investition.bis',
#   'als_investition.bis_dahin',
#   'investition.bis_dahin_weiterhin',
#   'dahin_weiterhin_rapefugees',
#   'weiterhin_rapefugees_islamisierung',
#   'rapefugees_islamisierung_und',
#   'islamisierung_und_is',
#   'und_is_terroristen',
#   'abmerkeln_egal_welche',
#   'egal_welche_partei',
#   'welche_partei_man',
#   'partei_man_wählt',
#   'man_wählt_nur',
#   'wählt_nur_orange',
#   'nur_orange_oder',
#   'orange_oder_apfelsine',
#   'annewill_einprozent_grenzendicht',
#   'einprozent_grenzendicht_refugees',
#   'grenzendicht_refugees_refugeesnotwelcome',
#   'refugees_refugeesnotwelcome_deutschland',
#   'refugeesnotwelcome_deutschland_das',
#   'deutschland_das_griechenland',
#   'das_griechenland_das',
#   'griechenland_das_jetzt',
#   'das_jetzt_alle',
#   'jetzt_alle_beschlüsse',
#   'alle_beschlüsse_zu',
#   'beschlüsse_zu_asylanten',
#   'zu_asylanten_blockieren',
#   'asylanten_blockieren_will',
#   'blockieren_will_is',
#   'will_is_aber',
#   'is_aber_nicht',
#   'aber_nicht_das',
#   'nicht_das_land',
#   'das_land_das',
#   'land_das_quartalsweise',
#   'das_quartalsweise_milliarden',
#   'quartalsweise_milliarden_schnorrt',
#   'milliarden_schnorrt_oder',
#   'reker_beugt_sich',
#   'beugt_sich_islam',
#   'sich_islam_und',
#   'islam_und_scharia',
#   'und_scharia_schafft',
#   'scharia_schafft_für',
#   'schafft_für_frauen',
#   'für_frauen_sicherheitszonen',
#   'frauen_sicherheitszonen_=fluchtpunkte',
#   'sicherheitszonen_=fluchtpunkte_flüchtlinge',
#   '=fluchtpunkte_flüchtlinge_köln',
#   'flüchtlinge_köln_massenvergewaltigungen',
#   'köln_massenvergewaltigungen_maischberger',
#   'massenvergewaltigungen_maischberger_liefers',
#   'maischberger_liefers_wir',
#   'liefers_wir_achten',
#   'wir_achten_frauen',
#   'achten_frauen_für',
#   'frauen_für_viele',
#   'für_viele_von',
#   'viele_von_den',
#   'von_den_rapefugees',
#   'den_rapefugees_ist',
#   'rapefugees_ist_das',
#   'ist_das_wie',
#   'das_wie_ein',
#   'wie_ein_paradies',
#   'ein_paradies_hier.lasche',
#   'paradies_hier.lasche_strafen',
#   'hier.lasche_strafen_bei',
#   'strafen_bei_vergewaltigungen',
#   'bei_vergewaltigungen_perlen',
#   'vergewaltigungen_perlen_aus',
#   'perlen_aus_der',
#   'aus_der_redaktionskonferenz',
#   'der_redaktionskonferenz_heute',
#   'redaktionskonferenz_heute_idee',
#   'heute_idee_für',
#   'idee_für_buchtitel',
#   'für_buchtitel_das',
#   'buchtitel_das_wunder',
#   'das_wunder_von',
#   'wunder_von_dresden',
#   'von_dresden_islamisierung',
#   'dresden_islamisierung_ohne',
#   'islamisierung_ohne_muslime',
#   'ohne_muslime_nopegida',
#   'muslime_nopegida_nolegida',
#   'nopegida_nolegida_wir',
#   'nolegida_wir_werden',
#   'wir_werden_noch',
#   'werden_noch_gemeinsam',
#   'noch_gemeinsam_auf',
#   'gemeinsam_auf_pegida',
#   'auf_pegida_stehen',
#   'pegida_stehen_schulter',
#   'stehen_schulter_an',
#   'schulter_an_schulter',
#   'an_schulter_bis',
#   'schulter_bis_zu',
#   'bis_zu_den',
#   'zu_den_zähnen',
#   'den_zähnen_bewaffnet',
#   'zähnen_bewaffnet_im',
#   'bewaffnet_im_bürgerkrieg',
#   'im_bürgerkrieg_gegen',
#   'bürgerkrieg_gegen_rapefugees',
#   'gegen_rapefugees_schauhin',
#   'rapefugees_schauhin_merkel',
#   'schauhin_merkel_rechnet',
#   'merkel_rechnet_mit',
#   'rechnet_mit_mio',
#   'mit_mio_neuen',
#   'mio_neuen_asylanten',
#   'neuen_asylanten_in',
#   'asylanten_in_d',
#   'zum_vergleich_schätzung',
#   'vergleich_schätzung_war',
#   'schätzung_war_gekommen',
#   'war_gekommen_sind',
#   'gekommen_sind_mio',
#   'dank_cdu_ich',
#   'cdu_ich_habe',
#   'ich_habe_bis',
#   'habe_bis_heute',
#   'bis_heute_nicht',
#   'heute_nicht_verstanden',
#   'nicht_verstanden_was',
#   'verstanden_was_an',
#   'was_an_dunkelhäutigen',
#   'an_dunkelhäutigen_in',
#   'dunkelhäutigen_in_schwarzen',
#   'in_schwarzen_burkas',
#   'schwarzen_burkas_mit',
#   'burkas_mit_dunkler',
#   'mit_dunkler_“',
#   'bunt_sein_soll',
#   'sein_soll_islamisierung',
#   'soll_islamisierung_dieser',
#   'islamisierung_dieser_sommer',
#   'dieser_sommer_wird',
#   'sommer_wird_der',
#   'wird_der_sommer',
#   'der_sommer_der',
#   'sommer_der_rapefugees',
#   'der_rapefugees_schade',
#   'rapefugees_schade_das',
#   'schade_das_die',
#   'das_die_wahlen',
#   'die_wahlen_nicht',
#   'wahlen_nicht_im',
#   'nicht_im_herbst',
#   'im_herbst_sind',
#   'die_gedanken_sind',
#   'gedanken_sind_frei',
#   'sind_frei_-nicht',
#   'frei_-nicht_mehr',
#   '-nicht_mehr_in',
#   'mehr_in_europa',
#   'in_europa_deutschland',
#   'europa_deutschland_sophienhof',
#   'deutschland_sophienhof_koelnbhf',
#   'sophienhof_koelnbhf_merkelmussweg',
#   'koelnbhf_merkelmussweg_islamisierung',
#   'merkelmussweg_islamisierung_flüchtlingskrise',
#   'islamisierung_flüchtlingskrise_wer',
#   'flüchtlingskrise_wer_für',
#   'wer_für_deutsche',
#   'für_deutsche_arbeitslose',
#   'deutsche_arbeitslose_und',
#   'arbeitslose_und_obdachlose',
#   'und_obdachlose_die',
#   'obdachlose_die_selben',
#   'die_selben_finanz',
#   'mittel_fordert_wie',
#   'fordert_wie_sie',
#   'wie_sie_asylanten',
#   'sie_asylanten_zukommen',
#   'asylanten_zukommen_wird',
#   'zukommen_wird_beschimpft',
#   'wieso_haben_diese',
#   'haben_diese_gutmenschen',
#   'diese_gutmenschen_vegetarier',
#   'gutmenschen_vegetarier_veganer',
#   'vegetarier_veganer_und',
#   'veganer_und_tierschützer',
#   'und_tierschützer_eigentlich',
#   'tierschützer_eigentlich_nichts',
#   'eigentlich_nichts_gegen',
#   'nichts_gegen_halal',
#   'gegen_halal_-schlachtung',
#   'asylanten_flüchtlinge_ein',
#   'flüchtlinge_ein_soldat',
#   'ein_soldat_der',
#   'soldat_der_gegen',
#   'der_gegen_flüchtlinge',
#   'gegen_flüchtlinge_ist',
#   'flüchtlinge_ist_und',
#   'ist_und_u.a',
#   'rapefugees_nutzt_kritisiert',
#   'nutzt_kritisiert_meine',
#   'kritisiert_meine_tweets',
#   'meine_tweets_zu',
#   'tweets_zu_inthebox',
#   'zu_inthebox_patridiot',
#   'inthebox_patridiot_mit',
#   'patridiot_mit_gewehr',
#   'manche_sagen_die',
#   'sagen_die_afd',
#   'die_afd_wähler',
#   'afd_wähler_sollen',
#   'wähler_sollen_sich',
#   'sollen_sich_schämen',
#   'ich_finde_die',
#   'finde_die_jungs',
#   'die_jungs_von',
#   'jungs_von_koelnhbf',
#   'von_koelnhbf_haben',
#   'koelnhbf_haben_viel',
#   'haben_viel_mehr',
#   'viel_mehr_grund',
#   'mehr_grund_sich',
#   'grund_sich_zu',
#   'sich_zu_schämen',
#   'rapefugees_maischberger_laschet',
#   'maischberger_laschet_pegida',
#   'laschet_pegida_gibts',
#   'pegida_gibts_im',
#   'gibts_im_westen',
#   'im_westen_nicht.leute',
#   'westen_nicht.leute_trauen',
#   'nicht.leute_trauen_sich',
#   'trauen_sich_nicht',
#   'sich_nicht_mitzulaufen',
#   'nicht_mitzulaufen_wegen',
#   'mitzulaufen_wegen_ächtung',
#   'wegen_ächtung_aber',
#   'ächtung_aber_islamisierung',
#   'aber_islamisierung_ist',
#   'islamisierung_ist_umso',
#   'ist_umso_realer',
#   'umso_realer_dor',
#   'realer_dor_beateuhse',
#   'dor_beateuhse_fördert',
#   'beateuhse_fördert_scharia',
#   ...]}

# %%
vocab = nltk.FreqDist(sum(trigram.values(),[]))

# %%
vocab = sorted(list(vocab.items()),key= lambda x: x[1], reverse=True)

# %%
vocab = [x[0] for x in vocab]

# %%
vocab[:100]
# Out:
# ['in_den_usa',
#  'sie_auf_den',
#  'wenn_sie_auf',
#  'auf_den_artikel',
#  'können_sie_einfach',
#  'verlinken_möchten_können',
#  'möchten_können_sie',
#  'sie_einfach_und',
#  'einfach_und_kostenfrei',
#  'und_kostenfrei_den',
#  'kostenfrei_den_unten',
#  'den_unten_stehenden',
#  'unten_stehenden_link',
#  'stehenden_link_verwenden',
#  'in_diesem_jahr',
#  'in_den_vergangenen',
#  'die_zahl_der',
#  'um_prozent_auf',
#  'im_vergangenen_jahr',
#  'in_den_letzten',
#  'nach_wie_vor',
#  'auch_in_der',
#  'auf_den_markt',
#  'im_vergleich_zum',
#  'in_der_ersten',
#  'in_höhe_von',
#  'in_der_minute',
#  'in_den_kommenden',
#  'es_in_der',
#  'in_den_nächsten',
#  'in_den_ersten',
#  'in_der_schweiz',
#  'vor_allem_die',
#  'in_der_zweiten',
#  'sich_in_der',
#  'es_sich_um',
#  'von_millionen_euro',
#  'prozent_auf_euro',
#  'die_in_der',
#  'davon_aus_dass',
#  'nicht_nur_die',
#  'von_milliarden_euro',
#  'auch_für_die',
#  'nach_angaben_des',
#  'den_vergangenen_jahren',
#  'zum_ersten_mal',
#  'dass_sich_die',
#  'und_in_der',
#  'auf_dem_weg',
#  'in_dieser_saison',
#  'das_ist_ein',
#  'blick_auf_die',
#  'mit_blick_auf',
#  'in_der_regel',
#  'vor_allem_in',
#  'der_in_der',
#  'der_champions_league',
#  'auf_der_straße',
#  'in_der_vergangenen',
#  'der_jahre_alte',
#  'auf_jeden_fall',
#  'im_kommenden_jahr',
#  'von_bis_zu',
#  'handelt_es_sich',
#  'auf_den_ersten',
#  'bis_zu_prozent',
#  'an_der_spitze',
#  'von_mehr_als',
#  'in_der_bundesliga',
#  'in_der_vergangenheit',
#  'an_den_start',
#  'und_vor_allem',
#  'prozent_auf_punkte',
#  'gegen_den_fc',
#  'in_der_nacht',
#  'nach_angaben_der',
#  'sich_in_den',
#  'es_ist_ein',
#  'auch_in_den',
#  'die_in_den',
#  'im_ersten_quartal',
#  'heißt_es_in',
#  'auf_die_straße',
#  'fc_bayern_münchen',
#  'das_ist_eine',
#  'im_vergleich_zu',
#  'nach_eigenen_angaben',
#  'so_gut_wie',
#  'in_der_stadt',
#  'unter_berufung_auf',
#  'in_new_york',
#  'auf_milliarden_euro',
#  'das_ist_der',
#  'bundeskanzlerin_angela_merkel',
#  'auf_der_autobahn',
#  'bei_der_wm',
#  'die_deutsche_bank',
#  'auch_bei_den',
#  'in_der_lage',
#  'in_erster_linie']

# %%
term_freq = {genre: nltk.FreqDist(text) for genre, text in trigram.items()}

# %%
term_freq
# Out:
# {'keyword/automobil_50k.txt': FreqDist({'in_den_usa': 291, 'auf_den_markt': 233, 'in_diesem_jahr': 141, 'die_zahl_der': 112, 'auf_der_straße': 102, 'mit_ps_und': 101, 'in_den_vergangenen': 92, 'auf_der_autobahn': 89, 'unter_der_haube': 89, 'auf_dem_genfer': 86, ...}),
#  'keyword/news_text100k.txt': FreqDist({'die_zahl_der': 211, 'in_den_vergangenen': 138, 'in_diesem_jahr': 138, 'es_sich_um': 103, 'in_den_usa': 85, 'mit_dem_coronavirus': 76, 'auch_in_der': 69, 'handelt_es_sich': 69, 'es_in_der': 67, 'in_den_letzten': 65, ...}),
#  'keyword/sport_50k.txt': FreqDist({'sie_auf_den': 346, 'wenn_sie_auf': 343, 'auf_den_artikel': 343, 'verlinken_möchten_können': 340, 'möchten_können_sie': 340, 'können_sie_einfach': 340, 'sie_einfach_und': 340, 'einfach_und_kostenfrei': 340, 'und_kostenfrei_den': 340, 'kostenfrei_den_unten': 340, ...}),
#  'keyword/wirtschaft_50k.txt': FreqDist({'um_prozent_auf': 399, 'in_den_usa': 348, 'sie_auf_den': 275, 'wenn_sie_auf': 271, 'auf_den_artikel': 270, 'verlinken_möchten_können': 270, 'möchten_können_sie': 270, 'können_sie_einfach': 270, 'sie_einfach_und': 270, 'einfach_und_kostenfrei': 270, ...}),
#  'keywords/hatespeech': FreqDist({'das_ist_doch': 48, 'auf_die_straße': 35, 'wir_schaffen_das': 32, 'was_für_ein': 29, 'das_deutsche_volk': 29, 'was_für_eine': 27, 'in_unserem_land': 27, 'frauen_und_kinder': 26, 'in_den_knast': 26, 'ich_frage_mich': 24, ...})}

# %%
def create_dtm(dictionary,vocab):
    matrix=[]

    for value in dictionary.values():
        array=[]
        for word in vocab: 
            array.append(value.get(word, 0))
        matrix.append(array)    
    return np.array(matrix)

# %%
def tfidf(matrix, terms, voc,n):
    
    
    y=matrix.sum(axis=1)
    
    
    y=y[:,np.newaxis]
    tm= (np.divide(matrix,y)) * np.log(matrix.shape[0]/((matrix>0).sum(0)))
   
    idf_list=[]
   
    for i in range(tm.shape[0]):
        
        idf_list.append(tm[i].argsort()[::-1])
        
    docs={}
    doc_list=[]
    
 
    for index, key in enumerate(terms.keys()):
        for i in range(n):
            doc_list.append(voc[idf_list[index][i]])
        
        docs[key]= doc_list
        doc_list=[]
    return docs

# %%
dtm=create_dtm(term_freq,vocab)

# %%
results = tfidf(dtm, term_freq, vocab,1000)

# %%
result_list= results["keywords/hatespeech"]

# %%
for index, value in enumerate(result_list):
    result_list[index]= " ".join(value.split("_"))

# %%
result_list
# Out:
# ['in den arsch',
#  'wir schaffen das',
#  'in unser land',
#  'sind das volk',
#  'schmarotzer pädophile und',
#  'bla bla bla',
#  'raus aus deutschland',
#  'pädophile und denunzianten',
#  'in den knast',
#  'frauen und kinder',
#  'der islam ist',
#  'spd schmarotzer pädophile',
#  'gefahr für deutschland',
#  'raus mit dem',
#  'wir fordern das',
#  'marine le pen',
#  'das misstrauensvotum gegen',
#  'mit dem pack',
#  'frau le pen',
#  'misstrauensvotum gegen herr',
#  'der islam gehört',
#  'fordern das misstrauensvotum',
#  'gegen herr sigmar',
#  'wollte bescheid sagen',
#  'bitte auf facebook',
#  'gabriel bitte auf',
#  'und twitter teilen',
#  'herr sigmar gabriel',
#  'sigmar gabriel bitte',
#  'ach du scheisse',
#  'beim herumsurfen gesehen',
#  'sie wird nicht',
#  'merkel und ihre',
#  'merkel und co',
#  'scheinheilgste partei deutschlands',
#  'des deutschen volkes',
#  'zum teufel jagen',
#  'den knast mit',
#  'frau merkel und',
#  'wir sind das',
#  'das eigene volk',
#  'gegen die afd',
#  'selbe gilt für',
#  'der justiz oder',
#  'justiz oder bei',
#  'bei den sicherheitskräften',
#  'lasst uns diesen',
#  'uns diesen abschaum',
#  'diesen abschaum der',
#  'abschaum der unsere',
#  'völker regiert zum',
#  'regiert zum teufel',
#  'teufel jagen und',
#  'jagen und zwar',
#  'zwar ohne gnade',
#  'nach einer lebenden',
#  'deine tweets bei',
#  'anschließend bei erfolg',
#  'bei erfolg löschung',
#  'gt am besten',
#  'ich beim herumsurfen',
#  'herumsurfen gesehen habe',
#  'die moderatorin der',
#  'unterstützen ob in',
#  'das selbe gilt',
#  'zur einschleusung von',
#  'und das selbe',
#  'auf die fresse',
#  'danke frau merkel',
#  'gestern kann weder',
#  'kann weder die',
#  'sagen sie würden',
#  'sie würden bürgerkriegsflüchtlingen',
#  'würden bürgerkriegsflüchtlingen helfen',
#  'nein dies ist',
#  'dies ist vorsätzliche',
#  'vorsätzliche beihilfe zur',
#  'beihilfe zur einschleusung',
#  'ist vorsätzliche beihilfe',
#  'brandstiftern und nötigern',
#  'ein bruch des',
#  'lebenslang und das',
#  'zwar lebenslang und',
#  'und nötigern erpressern',
#  'des grundgesetzes also',
#  'bruch des grundgesetzes',
#  'und zwar lebenslang',
#  'dazu ein bruch',
#  'gewalttätern und gewaltverherlichern',
#  'erpressern gewalttätern und',
#  'nötigern erpressern gewalttätern',
#  'an der macht',
#  'eine schande für',
#  'fettigen haaren wdr',
#  'am besten blockieren',
#  'sie werden dich',
#  'grundgesetzes also hochverrat',
#  'das volk und',
#  'am deutschen volk',
#  'wird zeit dass',
#  'die eigene bevölkerung',
#  'den verstand verloren',
#  'hier nichts zu',
#  'flüchtlinge und asylanten',
#  'merkel muss weg',
#  'die sollen sich',
#  'am arsch vorbei',
#  'es wird zeit',
#  'sagen da ich',
#  'bescheid sagen da',
#  'erfolg löschung od',
#  'wo soll das',
#  'schwager schwagerwars gebtdenschwagerfrei',
#  'von der capitol',
#  'beide völker regiert',
#  'unsere beide völker',
#  'der unsere beide',
#  'wir das volk',
#  'merkel und konsorten',
#  'die flüchtlinge die',
#  'am eigenen volk',
#  'merkel und co.',
#  'islam gehört nicht',
#  'die schnauze voll',
#  'für die flüchtlinge',
#  'nicht sie ist',
#  'da ich beim',
#  'auf facebook und',
#  'das sind doch',
#  'da sieht man',
#  'auf unsere kosten',
#  'facebook und twitter',
#  'ist doch alles',
#  'in meinen augen',
#  'die afd als',
#  'von deutschland sagen',
#  'dieser parteien michboche',
#  'mit dieser parteien',
#  'knast mit dieser',
#  'kriminellen brandstiftern und',
#  'hoch kriminellen brandstiftern',
#  'von hoch kriminellen',
#  'einschleusung von hoch',
#  'deutschland sagen sie',
#  'noch von deutschland',
#  'michboche und zwar',
#  'östereich noch von',
#  'von östereich noch',
#  'regierung von östereich',
#  'bundes regierung von',
#  'die bundes regierung',
#  'weder die bundes',
#  'nicht ob ich',
#  'kein recht auf',
#  'parteien michboche und',
#  'die sowas unterstützen',
#  'alle die sowas',
#  'aus dem niger',
#  'die afd und',
#  'die strasse gehen',
#  'sind die grünen',
#  'stasifrau kahane funktioniert',
#  'kahane funktioniert nicht',
#  'eine stimme für',
#  'wikimedia cc by-sa',
#  'papa wilberg von',
#  'wilberg von der',
#  'jaxxon sundance justnobody',
#  'sundance justnobody deine',
#  'justnobody deine tweets',
#  'melden sich anschließend',
#  'sich anschließend bei',
#  'botschaft in manila',
#  'der abgefuckten spd',
#  'sowas unterstützen ob',
#  'ich lach mich',
#  'die afd in',
#  'ich hoffe es',
#  'mal eine frage',
#  'gegen die menschenwürde',
#  'ist die afd',
#  'schande für deutschland',
#  'schafft sich ab',
#  'das waren noch',
#  'auf euch auf',
#  'das sie die',
#  'ein hoch auf',
#  'hier in europa',
#  'was wollen die',
#  'jetzt in deutschland',
#  'was bist du',
#  'ins land gelassen',
#  'schon lange eine',
#  'soviel zum thema',
#  'und das bekommen',
#  'volk und das',
#  'ein jähriges mädchen',
#  'ich scheisse auf',
#  'noch zum kotzen',
#  'kein psychoanalytiker sein',
#  'soll das noch',
#  'nicht zu deutschland',
#  'kein geld da',
#  'wird zeit das',
#  'in der justiz',
#  'für die afd',
#  'oder bei den',
#  'sie ist schon',
#  'seit gestern kann',
#  "geht 's noch",
#  'so sehe ich',
#  'oh mein gott',
#  'die frau ist',
#  'wenn die flüchtlinge',
#  'na wenn das',
#  'wo sie herkommen',
#  'sind doch alles',
#  'mal jemand der',
#  'arsch in der',
#  'das die afd',
#  'die taschen voll',
#  'alle es hören',
#  'und die afd',
#  'recht hat sie',
#  'recht hat hat',
#  'und wer bezahlt',
#  'unsere politiker sind',
#  'mit offenen augen',
#  'ne neue seite',
#  'wird ja immer',
#  'damit alle es',
#  'zusagt damit alle',
#  'euch zusagt damit',
#  'es euch zusagt',
#  'hat sie recht',
#  'endlich nach einer',
#  'oder saudi arabien',
#  'sucht endlich nach',
#  'oder o. wilke',
#  'dieses lied wenn',
#  'tweets bei twittersupport',
#  'bei twittersupport melden',
#  'gesehen habe daß',
#  'moderatorin der mit',
#  'claudia roth ist',
#  'deutsche botschaft in',
#  'scheisse auf die',
#  'rot grün versiffte',
#  'ekelwilfred wiltewka oder',
#  'mehr zu ertragen',
#  'möchte nicht wissen',
#  'er hat recht',
#  'ist zum kotzen',
#  'bereits gegen diese',
#  'sich bereits gegen',
#  'wehren sich bereits',
#  'bürger wehren sich',
#  'nicht nach europa',
#  'religion des friedens',
#  'das alles was',
#  'auf uns zu',
#  'macht die grenzen',
#  'lied wenn es',
#  'es bei euch',
#  'teilt dieses lied',
#  'nach europa zu',
#  'traurig aber wahr',
#  'auf den sack',
#  'jetzt zu spühren',
#  'in die fresse',
#  'ist die wahrheit',
#  'mich nicht wundern',
#  'wird mir schlecht',
#  'auch nur noch',
#  'den er jahren',
#  'wo die herkommen',
#  'da könnt ihr',
#  'die eigenen bürger',
#  'ich bin patriot',
#  'sie durch einen',
#  'die flucht zu',
#  'passt auf euch',
#  'für flüchtlinge und',
#  'und gut ist',
#  'deutschland den deutschen',
#  'sundance justnobody dich',
#  'stellt euch mal',
#  'lach mich kaputt',
#  'nur hoffen das',
#  'ein hip-hop song',
#  'bekommen die jetzt',
#  'das bekommen die',
#  'gegen die bundesregierung',
#  'kampfansage gegen die',
#  'eine kampfansage gegen',
#  'gehört zu deutschland',
#  'von mir für',
#  'song von mir',
#  'hip-hop song von',
#  'mir für euch',
#  'wenn ich so',
#  'für deutschland und',
#  'unser land kommen',
#  'hier im land',
#  'lange eine gefahr',
#  'sind doch keine',
#  'ich bitte euch',
#  'wird nicht sie',
#  'sie sich mal',
#  'in den nachrichten',
#  'eier in der',
#  'wacht endlich auf',
#  'war doch klar',
#  'von der afd',
#  'ist sie schon',
#  'wer sich nicht',
#  'ist eine gefahr',
#  'doch nur ein',
#  'wir brauchen keine',
#  'in der hose',
#  'das deutsche volk',
#  'eine religiöse fanatikerin',
#  'frage mich warum',
#  'mit unserem land',
#  'im radio gehört',
#  'hat die schnauze',
#  'muss weg und',
#  'doch eh alles',
#  'das volk ist',
#  'es gibt genug',
#  'recht auf asyl',
#  'frau merkel das',
#  'und so was',
#  'durch flüchtlinge nicht',
#  'da haben sie',
#  'das alles so',
#  'damit man auch',
#  'deutschland schafft sich',
#  'die wahrheit nicht',
#  'wie zu ddr',
#  'zu ddr zeiten',
#  'wenn ich da',
#  'ihr habt es',
#  'ihre frauen und',
#  'wie heißt die',
#  'ich verstehe die',
#  'die den geist',
#  'die wollen doch',
#  'ins land geholt',
#  'auch schon so',
#  'kinder im krieg',
#  'weil sie ihre',
#  'wird das volk',
#  'nur ne frage',
#  'mir leid aber',
#  'euch schon mal',
#  'soviel zur meinungsfreiheit',
#  'das war mal',
#  'freund und helfer',
#  'man kein psychoanalytiker',
#  'ich sag nur',
#  'schon eine gefahr',
#  'nicht mehr tragbar',
#  'und die flüchtlinge',
#  'doch klar das',
#  'wir werden doch',
#  'kriminalität durch flüchtlinge',
#  'flüchtlinge nicht gestiegen',
#  'knast mit diesen',
#  'das volk die',
#  'fasse es nicht',
#  'ist der hammer',
#  'warum hört man',
#  'doch alles nicht',
#  'habe ein video',
#  'und jetzt sind',
#  'nur die afd',
#  'wie die merkel',
#  'die wollen alle',
#  'zum wohle des',
#  'zu dumm zum',
#  'wo sie recht',
#  'hat frau merkel',
#  'eine stadt für',
#  'wird es nie',
#  'nur noch lächerlich',
#  'millionen menschen aufnehmen',
#  'werden nicht weniger',
#  'regt euch nicht',
#  "wie wär 's",
#  'ich fasse es',
#  'hat vollkommen recht',
#  'da sie ja',
#  'vor der afd',
#  'anders kann ich',
#  'vom glauben ab',
#  'lesen und schreiben',
#  'geld da aber',
#  'für die asylanten',
#  'er recht hat',
#  'gegen die eigene',
#  "so sieht 's",
#  'dem islam und',
#  'dem deutschen volke',
#  'die dieses land',
#  'auch gut so',
#  'für unsere kinder',
#  'des islamischen staates',
#  'dafür das die',
#  'und fettigen haaren',
#  'lug und trug',
#  'jetzt habt ihr',
#  'nicht mehr hören',
#  'wählt keine altparteien',
#  'kinder und frauen',
#  'die fresse halten',
#  'pegida und afd',
#  'ist keine religion',
#  'können im grenzdienst',
#  'im grenzdienst schußwaffen',
#  'grenzdienst schußwaffen auch',
#  'schußwaffen auch gegen',
#  'gegen personen gebrauchen',
#  'personen gebrauchen die',
#  'gebrauchen die sich',
#  'sich der wiederholten',
#  'der wiederholten weisung',
#  'wiederholten weisung zu',
#  'weisung zu halten',
#  'halten oder die',
#  'oder die überprüfung',
#  'die überprüfung ihrer',
#  'überprüfung ihrer person',
#  'ihrer person oder',
#  'person oder der',
#  'oder der etwa',
#  'der etwa mitgeführten',
#  'etwa mitgeführten beförderungsmittel',
#  'mitgeführten beförderungsmittel und',
#  'vollzugsbeamten können im',
#  'genannten vollzugsbeamten können',
#  'und genannten vollzugsbeamten',
#  'islam gehört zu',
#  'regeln und gesetze',
#  'sind ein verstoß',
#  'ist ein verstoß',
#  'den schwanz ein',
#  'gegen die islamisierung',
#  'make rape legal',
#  'doch nur das',
#  'schützt uns vor',
#  'auf uns zukommt',
#  'sind viel zu',
#  'grenzdienst die in',
#  'werden wir von',
#  'ist und jetzt',
#  'wo sind wir',
#  'hier das video',
#  'waren noch zeiten',
#  'ein prozent für',
#  'prozent für unser',
#  'schußwaffengebrauch im grenzdienst',
#  'im grenzdienst die',
#  'beförderungsmittel und gegenstände',
#  'und gegenstände zu',
#  'gegenstände zu dulden',
#  'warum muss ich',
#  'die den in',
#  'den in absatz',
#  'in absatz bezeichneten',
#  'absatz bezeichneten personen',
#  'bezeichneten personen im',
#  'personen im zusammenhang',
#  'mit dem grenzdienst',
#  'dem grenzdienst übertragen',
#  'grenzdienst übertragen sind',
#  'an unseren grenzen',
#  'und landesaufgaben die',
#  'die haben doch',
#  'raus mit denen',
#  'ab nach hause',
#  'ist doch super',
#  'in der flüchtlingsfrage',
#  'die wahrheit sagt',
#  'unseres herrn jesus',
#  'herrn jesus christus',
#  'benehmen sich wie',
#  'landesaufgaben die den',
#  'bundes- und landesaufgaben',
#  'zu dulden durch',
#  'weisung nicht verstanden',
#  'dulden durch die',
#  'durch die flucht',
#  'flucht zu entziehen',
#  'zu entziehen versuchen',
#  'ist anzunehmen daß',
#  'anzunehmen daß die',
#  'daß die mündliche',
#  'die mündliche weisung',
#  'mündliche weisung nicht',
#  'nicht verstanden wird',
#  'von bundes- und',
#  'verstanden wird so',
#  'wird so kann',
#  'kann sie durch',
#  'durch einen warnschuß',
#  'einen warnschuß ersetzt',
#  'warnschuß ersetzt werden',
#  'als grenzdienst gilt',
#  'grenzdienst gilt auch',
#  'durchführung von bundes-',
#  'deutschland hat nur',
#  'der straße leben',
#  'von den flüchtlingen',
#  'für immer in',
#  'das ich das',
#  'aus dem nahen',
#  'die wahrheit gesagt',
#  'wieder so ein',
#  'mit dem islam',
#  'la la la',
#  'merkel ist der',
#  'gegen diese regierung',
#  'islam ist eine',
#  ' meuthen bei annewill',
#  'ep europawahl meuthen',
#  'ibizagate oesterreich neuwahlen',
#  'für die europawahl',
#  'ist der islam',
#  'ursula haverbeck –',
#  'albert schweitzer über',
#  'schweitzer über die',
#  'über die afrikanische',
#  'die afrikanische herrenrasse…',
#  'nie sie als',
#  'sie als sozial',
#  'als sozial gleichgestellte',
#  'sozial gleichgestellte akzeptieren',
#  'würde diejenigen unter',
#  'akzeptieren oder sie',
#  'werden dich fressen',
#  'werden dich zerstören.',
#  'junge kräftige männer',
#  'arsch auf grundeis',
#  'des tages folge',
#  'der arsch auf',
#  'unter euch die',
#  'euch die denken',
#  'die denken so',
#  'alle nach deutschland',
#  'denken so kann',
#  'nicht weitergehen in',
#  'weitergehen in unserem',
#  'unserem land bitten',
#  'land bitten endlich',
#  'bitten endlich aufzustehen',
#  'endlich aufzustehen und',
#  'aufzustehen und gegen',
#  'gegen die aktuelle',
#  'die aktuelle politik',
#  'aktuelle politik anzugehen',
#  'geht auf demos',
#  'auf demos schreibt',
#  'demos schreibt euren',
#  'schreibt euren kommunalpolitiker',
#  'euren kommunalpolitiker werdet',
#  'kommunalpolitiker werdet einfach',
#  'werdet einfach aktiv',
#  'einfach aktiv und',
#  'aktiv und helft',
#  'und helft unser',
#  'helft unser land',
#  'land zu retten',
#  'dich zerstören. “',
#  'gleichgestellte akzeptieren oder',
#  'auf die spd',
#  'alle ich bitte',
#  'afd als eine',
#  'als eine stimme',
#  'die scheinheilgste partei',
#  'ich würde diejenigen',
#  'aufgenommen in hannover',
#  'heute aufgenommen in',
#  'wurde heute aufgenommen',
#  'video wurde heute',
#  'dieses video wurde',
#  'dieses video anzusehen',
#  'euch dieses video',
#  'euch euch dieses',
#  'bitte euch euch',
#  'an alle ich',
#  'lieber hundert stimmen',
#  'hallo an alle',
#  'ein hallo an',
#  'wohle des deutschen',
#  "gibt 's ja",
#  'merkel muß weg',
#  'die hetze gegen',
#  'ein ganzes land',
#  'der typ ist',
#  'so jetzt sind',
#  'und kinder in',
#  'jetzt ist schluss',
#  'frage mich nur',
#  'frage mich wie',
#  'hundert stimmen für',
#  'diejenigen unter euch',
#  'den fettigen haaren',
#  'schaukel als kind',
#  'alias der ekelwilfred',
#  'wiltewka oder o.',
#  'den richtigen orten',
#  'sucht und findet',
#  'war vor rebeccas',
#  'vor rebeccas verschwinden',
#  ' junge mdl die spd',
#  'familie in ruhe',
#  'sperrung mit hetzlichendank',
#  'mit hetzlichendank abklatschen',
#  'dreck verrecken lassen',
#  'justnobody dich od',
#  'gesehen habe dass',
#  'als kind zu',
#  'im dreck verrecken',
#  'roth ist eine',
#  'der wand gestanden',
#  'der dumme deutsche',
#  'die lügenpresse und',
#  'und merkel vasallen',
#  'tag der rache',
#  'die abgefuckte spd',
#  'unser land und',
#  'die grenzen dicht',
#  'für ihr land',
#  'dann sind sie',
#  'nur ein einzelfall',
#  'wer das nicht',
#  'nur noch zum',
#  'die jetzt zu',
#  'ich hoffe das',
#  'was für eine',
#  'in unserem land',
#  'ist eine schande',
#  'ist das denn',
#  'ist in meinen',
#  'die linken und',
#  'ist am ende',
#  'die afd ist',
#  'die so etwas',
#  'man stelle sich',
#  'weg mit der',
#  'zu spät ist',
#  'hab und gut',
#  'unser land zu',
#  'muss man kein',
#  'das ist mal',
#  'die afd hat',
#  'funktioniert nicht mehr',
#  'wenn die das',
#  'mehr zu sagen',
#  'lasst euch nicht',
#  'was habt ihr',
#  'von frau merkel',
#  'sie ist es',
#  'ich schäme mich',
#  'wenn es euch',
#  'die da oben',
#  'ich sage nur',
#  'in diesem land',
#  'wie bei uns',
#  'europa die aufnehmen',
#  'direkt zu uns',
#  'wasserkopf- arbeits -plätzen',
#  'flüchtlinge in die',
#  'und unsere kanzlerin',
#  'ihr land zurück',
#  'die flüchtlinge zu',
#  'der fdp in',
#  'der nächste bürgerkrieg',
#  'geschafft haben schafft',
#  'fdp in merseburg',
#  'gefällt mir nicht',
#  'unsere kanzlerin will',
#  'die kanzlerin hat',
#  'kanzlerin will sie',
#  'diktatoren nicht geschafft',
#  'jetzt alle direkt',
#  'und diktatoren nicht',
#  'alle direkt zu',
#  'kaiser und diktatoren',
#  'zu uns bringen',
#  'nicht mehr herr',
#  'wohlstandskokon zurückzieht handelt',
#  'sie machen sich',
#  'letzten in europa',
#  'heutigen verhältnisse bestritten',
#  'die brd ist',
#  'was unsere politiker',
#  'da sind ja',
#  'ich an deutschland',
#  'an deutschland in',
#  'bin ich um',
#  'ich um den',
#  'um den schlaf',
#  'den schlaf gebracht',
#  'nach deutschland will',
#  'ich wünsche euch',
#  'was haben wir',
#  'meine güte was',
#  'von unserer regierung',
#  'denn der islam',
#  'ins gelobte land',
#  'nicht anders verdient',
#  'der menschheit haben',
#  'und dem irak',
#  'nicht mehr nachkommen',
#  'die letzten in',
#  'nix mit dem',
#  'im lande sind',
#  'was man den',
#  'die welt hinaus',
#  'seinen noch vorhandenen',
#  'ich bin gerade',
#  'glaube das alles',
#  'hab ich schon',
#  'noch vorhandenen wohlstandskokon',
#  'vorhandenen wohlstandskokon zurückzieht',
#  'montag in dresden',
#  'schäme mich für',
#  "wär 's denn",
#  'in ihr land',
#  'wären in der',
#  'mich warum die',
#  'haben kurze beine',
#  'lügen haben kurze',
#  'nur frauen und',
#  'wir endlich die',
#  'so dumm wie',
#  'geht der arsch',
#  'den nachfolgenden generationen',
#  'und den nachfolgenden',
#  'wie krank ist',
#  'in seinen noch',
#  'und wasserkopf- arbeits',
#  'neu programmieren kann',
#  'und der islam',
#  'keine religion sondern',
#  'religion sondern eine',
#  'wahre gesicht des',
#  'nach dem islam',
#  'junge männer die',
#  'soll sich mal',
#  'gegenüber seinen kindern',
#  'die sozialen und',
#  'sich nicht integrieren',
#  'immigranten sind eben',
#  'sind eben keine',
#  'eben keine maschinen',
#  'keine maschinen die',
#  'maschinen die man',
#  'die man durch',
#  'durch das aufspielen',
#  'das aufspielen von',
#  'aufspielen von integrationssoftware',
#  'von integrationssoftware neu',
#  'integrationssoftware neu programmieren',
#  'klingt komisch ist',
#  'menschen gehören nicht',
#  'die heutigen verhältnisse',
#  'beatrix von storch',
#  'ja nur die',
#  'der cdu der',
#  'mit voller härte',
#  'so ein quatsch',
#  'gehören nicht in',
#  'gnade euch gott',
#  'gerade im radio',
#  'was sie sind',
#  'meinungsfreiheit in deutschland',
#  'wenn wir alle',
#  'können sich dann',
#  'kommt als nächstes',
#  'was kommt als',
#  'flüchtlingen in der',
#  'von flüchtlingen in',
#  'spricht mir aus',
#  'merkel in der',
#  'schande für das',
#  'belogen und betrogen',
#  'die stimmung kippt',
#  'doch mal ein',
#  'von frau le',
#  'hat hat sie',
#  'sie recht hat',
#  'nimmt sich die',
#  'schaut euch die',
#  'madame le pen',
#  'was für ne',
#  'da können sich',
#  'frau merkel sie',
#  'für ein freies',
#  'jetzt zu uns',
#  'die merkel hat',
#  'die dummen deutschen',
#  'was hast du',
#  'eigenen land nicht',
#  'unterstützen sie die',
#  'recht zum widerstand',
#  'deutschen das recht',
#  'alle deutschen das',
#  'haben alle deutschen',
#  'sind immer die',
#  'wenigstens einer der',
#  'der fette gabriel',
#  'land aufgebaut haben',
#  'dieses land aufgebaut',
#  'und unsere rentner',
#  'kein geld fuer',
#  'der deutsche bürger',
#  'nach hause mit',
#  'für merkel und',
#  'für sein volk',
#  'die hat doch',
#  'das recht zum',
#  'zum widerstand wenn',
#  'das noch hinführen',
#  'widerstand wenn andere',
#  'ja ich bin',
#  'sowas gibt es',
#  'alle nach berlin',
#  'hat doch den',
#  'sehe ich nur',
#  'also das ist',
#  'sind das problem',
#  'was zu sagen',
#  'würde ich sagen',
#  'ich jetzt auch',
#  'und es gäbe',
#  'so ganz ohne',
#  'abhilfe nicht möglich',
#  'andere abhilfe nicht',
#  'wenn andere abhilfe',
#  'bitte unterstützen sie',
#  'sie die petition',
#  'demograf die heutigen',
#  'sollte dann kann',
#  'jahre beibehalten sollte',
#  'nächsten jahre beibehalten',
#  'willkommenskultur die nächsten',
#  'seine willkommenskultur die',
#  'deutschland seine willkommenskultur',
#  'und islamismus geprägt',
#  'durch chaos streit',
#  'jahrhunderten durch chaos',
#  'seit jahrhunderten durch',
#  'ist seit jahrhunderten',
#  'welt ist seit',
#  'arabische welt ist',
#  'die arabische welt',
#  'welt werden nicht',
#  'dieser welt werden',
#  'beibehalten sollte dann',
#  'sich jeder ausrechnen',
#  'die krisen dieser',
#  'jeder ausrechnen wie',
#  'jeder demograf die',
#  'hätte jeder demograf',
#  'jahr hätte jeder',
#  'einem jahr hätte',
#  'gehen noch vor',
#  'schnell gehen noch',
#  'kann schnell gehen',
#  'überfremdung kann schnell',
#  'diesem lande sind',
#  'minderheit in diesem',
#  'die minderheit in',
#  'wir die minderheit',
#  'schnell wir die',
#  'wie schnell wir',
#  'ausrechnen wie schnell',
#  'krisen dieser welt',
#  'zahl noch vervielfachen',
#  'was auf uns',
#  'dieser welt wird',
#  'kein problem dieser',
#  'wird so etwas',
#  'saudi arabien oder',
#  'turkei oder saudi',
#  'sind araber und',
#  'dumm sind die',
#  'so dumm sind',
#  'ich das lese',
#  'den arsch offen',
#  'nicht integrieren will',
#  'ich glaub die',
#  'eine ganze stadt',
#  'so eine stadt',
#  'wird wenn sie',
#  'was merkel und',
#  'problem dieser welt',
#  'welt wird durch',
#  'wird sich diese',
#  'aufnahme von millionen',
#  'nachzug wird sich',
#  'den nachzug wird',
#  'durch den nachzug',
#  'inklusive fast millionen',
#  'jahres inklusive fast',
#  'dieses jahres inklusive',
#  'deutschland wird bis',
#  'ihrer jungen menschen',
#  'ländern ihrer jungen',
#  'den ländern ihrer',
#  'berauben den ländern',
#  'wir berauben den',
#  'gelöst im gegenteil',
#  'menschen gelöst im',
#  'von menschen gelöst',
#  'dann gnade euch',
#  'endlich und holt',
#  'man nichts von',
#  'täter und lasst',
#  'daten mehr speichern',
#  'mit dem twingo',
#  'dem twingo war',
#  'twingo war vor',
#  'seid ihr alle',
#  'fällt mir nur',
#  ' geld das ist',
#  'gegen all die',
#  'es wird der',
#  'und lasst die',
#  'sucht endlich den',
#  'endlich den richtigen',
#  'den richtigen tatort',
#  'video zu einer',
#  'von notre dame',
#  'zu einer -playlist',
#  'einer -playlist hinzugefügt',
#  'der islam in',
#  'kommt davon wenn',
#  'alltag in deutschland',
#  'europawahl euelections ep',
#  'bescheid sagen beim',
#  'nowehrmuc jaxxon sundance',
#  'tweets bei twitter-support',
#  'bei twitter-support melden',
#  'twitter-support melden sich',
#  'habe dass sundance',
#  'dass sundance justnobody',
#  'überhaupt keine daten',
#  'dürfen überhaupt keine',
#  'telefonanbieter dürfen überhaupt',
#  'anmelden telefonanbieter dürfen',
#  'us-präsident donald trump',
#  'unter strafe gestellt',
#  'wisst ihr was',
#  'die grünen den',
#  'am tag von',
#  'cdu spd fdp',
#  'wie ich schon',
#  'der capitol alias',
#  'der ekelwilfred wiltewka',
#  'neue reihe damit',
#  'reihe damit man',
#  'mal was über',
#  'was über berlin',
#  'über berlin zum',
#  'berlin zum lachen',
#  'und kinder zu',
#  'und findet endlich',
#  'und zwar an',
#  'zwar an den',
#  'instagram snapchat drogenszene',
#  'snapchat drogenszene hennigsdorf/oranienburg',
#  'router in standardeinstellung',
#  'in standardeinstellung speichert',
#  'standardeinstellung speichert nur',
#  'speichert nur das',
#  'nur das anmelden',
#  'das anmelden telefonanbieter',
#  'habe daß sundance',
#  'daß sundance justnobody',
#  'tweets von dir',
#  'afd an die',
#  'ein merkel vasall',
#  'ein vasall merkels',
#  'der krieg ist',
#  'was hat eine',
#  'nur und ausschließlich',
#  'den arsch treten',
#  'laßt doch endlich',
#  'doch endlich mal',
#  'bei mir verschissen',
#  'in manila strotzt',
#  'manila strotzt vor',
#  'strotzt vor menschenverachtung',
#  'sehen zu müssen',
#  'pädophile und dummköpfe',
#  'jung und schön']

# %%
np.savetxt("triigram_keywords_tf_idf_with_news_with_stopwords.csv", result_list, delimiter =",",fmt ='% s')
