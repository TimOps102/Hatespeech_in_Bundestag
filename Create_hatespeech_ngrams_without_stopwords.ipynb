# %%
import csv
import nltk
import string
import re
import numpy as np
import pickle

# %%
def clean(text):
    tokenized_sents=[]
    text = nltk.sent_tokenize(text)
    for sent in text:
        sent = nltk.word_tokenize(sent)
        sent = [x for x in sent if x not in string.punctuation]
        sent = [x for x in sent if x not in ["``", "''", "€", "$"]]
        
        if len(sent) > 1:
            tokenized_sents.append(sent)
        
    
    return tokenized_sents

# %%
def remove_emoji(string):   ## from https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
hatespeech=""

with open("hatespeech/refugees.csv") as csvdatei:
    csv_reader_object = csv.reader(csvdatei, delimiter=",")
    csv_hate = list(csv_reader_object)[1:]
    for row in csv_hate:
        x = row[0].replace("#", "")
        x = re.sub(r"http\S+|\.\.+|\S+\/\/+|www\S+|\d+|@[A-Za-z0-9]+|[``''€$]","", x)
        x = x.lower()
        hatespeech += " " + x

# %%
hatespeech =clean(hatespeech)

# %%
hatespeech
# Out:
# [['rosenmontag', 'ist', 'abgesagt'],
#  ['rapefugees',
#   'also',
#   'wieder',
#   'wie',
#   'gewohnt',
#   'ins',
#   'schwimmbad',
#   'gehen'],
#  ['bitte', 'nicht', 'die', 'türkei', 'zum', 'eu-mitglied', 'machen'],
#  ['menschenrechte',
#   'pressefreiheit',
#   'islamisierung',
#   'wieso',
#   'bekommen',
#   'rapefugees',
#   'mehr',
#   'als',
#   'unsere',
#   'hartz',
#   'enpfänger'],
#  ['esreicht', 'den', 'verfluchten', 'rapefugees', 'den', 'krieg', 'erklären'],
#  ['wasfehlt', 'war', 'das', 'wochenende', 'im', 'ruhrpott', 'unterwegs'],
#  ['überall',
#   'schwangere',
#   'muslimische',
#   'frauen',
#   'mit',
#   'einem',
#   'rattenschwanz',
#   'an',
#   'kindern',
#   'islamisierung',
#   'asylanteninvasion',
#   'wenn',
#   'es',
#   'auf',
#   'unseren',
#   'straßen',
#   'zu',
#   'gewaltausbrüchen',
#   'kommt',
#   'die',
#   'verantwortlichen',
#   'hierfür',
#   'sitzen',
#   'in',
#   'der',
#   'regierung',
#   'merkel'],
#  ['millionen', 'menschen', 'leben', 'in', 'europa'],
#  ['millionen', 'flüchtlinge', 'bereiten', 'da', 'kopfzerbrechen'],
#  ['rassisten', 'sprechen', 'von', 'islamisierung'],
#  ['tja',
#   'die',
#   'spd',
#   'will',
#   'unsere',
#   'steuergelder',
#   'für',
#   'flüchtlinge',
#   'verpassen'],
#  ['refugees',
#   'refugeesnotwelcome',
#   'refugeesgohome',
#   'abmerkeln',
#   'aber',
#   'für',
#   'die',
#   'kölner',
#   'polizei',
#   'haben',
#   'gestiegene',
#   'anzeigen',
#   'nur',
#   'einen',
#   'grund',
#   'frauen',
#   'seien',
#   'anzeigefreudiger',
#   'als',
#   'noch'],
#  ['rapefugees', 'offenes', 'freies', 'wlan', 'im', 'sophienhof', 'kiel'],
#  ['mit',
#   'ein',
#   'grund',
#   'für',
#   'die',
#   'vorfälle',
#   'von',
#   'gestern',
#   'nachmittag'],
#  ['zurück', 'nach', 'kabul', 'mit', 'den', 'rapefugees'],
#  ['unterdenlinden',
#   'petry',
#   'fordert',
#   'bessere',
#   'regelung',
#   'gesetze',
#   'für',
#   'asylanten',
#   'und',
#   'migranten'],
#  ['richtig', 'warum', 'wird', 'es', 'nicht', 'getan'],
#  ['regeln',
#   'und',
#   'gesetze',
#   'der',
#   'einheimischen',
#   'sind',
#   'ein',
#   'verstoß',
#   'gegen',
#   'die',
#   'menschenwürde'],
#  ['hungerstreik',
#   'rapefugees',
#   'blutrache',
#   'zwangsbekehrung',
#   'scharia',
#   'kinderbräute',
#   'vielehe',
#   'genitalverstümmelung',
#   'kann',
#   'nicht',
#   'erkennen',
#   'was',
#   'davon',
#   'zu',
#   'uns',
#   'gehören',
#   'soll'],
#  ['worin',
#   'liegt',
#   'der',
#   'sinn',
#   'für',
#   'die',
#   'bierindustrie',
#   'die',
#   'islamisierung',
#   'zu',
#   'beschleunigen',
#   'indem',
#   'sie',
#   'deutsche',
#   'biertrinker',
#   'mit',
#   'glyphosat',
#   'dezimieren'],
#  ['claudia',
#   'roth',
#   'wer',
#   'sex-attacken',
#   'von',
#   'asylanten',
#   'anprangert',
#   'ist',
#   'ein',
#   '„',
#   'geistiger',
#   'bruder',
#   '“',
#   'der',
#   'täter'],
#  ['fuck', 'you', 'from', 'switzerland'],
#  ['asylanten',
#   'grüne',
#   'im',
#   'februar',
#   'kamen',
#   'nach',
#   'neusten',
#   'angaben',
#   'in',
#   'der',
#   'ard',
#   'tagesschau',
#   'trotz',
#   'grenzkontrollen',
#   'auf',
#   'balkanroute',
#   'asylanten',
#   'nach',
#   'deutschland',
#   'die',
#   'unterbringung',
#   'im',
#   'gefängnis',
#   'nur',
#   'weil',
#   'man',
#   'verbrechen',
#   'begangen',
#   'hat',
#   'ist',
#   'ein',
#   'verstoß',
#   'gegen',
#   'die',
#   'menschenwürde.hungerstreik',
#   'rapefugees',
#   'merkel',
#   'wie',
#   'ist',
#   'diese',
#   'schlampe',
#   'eigentlich',
#   'auf',
#   'die',
#   'idee',
#   'gekommen',
#   'das',
#   'land',
#   'so',
#   'tiefgreifend',
#   'zu',
#   'verändern'],
#  ['merkelmussweg',
#   'refugeesnotwelcome',
#   'der',
#   'weltfrauentag',
#   'ist',
#   'eine',
#   'farce',
#   'angesichts',
#   'der',
#   'durch',
#   'die',
#   'merkeldiktatur',
#   'vorangetriebenen',
#   'islamisierung',
#   'europas'],
#  ['gratis',
#   'häuser',
#   'wohnungen',
#   'handys',
#   'u.',
#   'öffitickets',
#   'mindestsicherung',
#   'straffreiheit',
#   'vorreihung',
#   'in',
#   'ambulanzen',
#   'schlaraffenland',
#   'ö',
#   'zib',
#   'asylanten',
#   'beateuhse',
#   'konzern',
#   'vermarktet',
#   'scharia',
#   'konforme',
#   'sexprodukte',
#   'bitte',
#   'boykottiert',
#   'diese',
#   'firma'],
#  ['laut', 'orban', 'wird', 'merkel', 'europa', 'mit', 'neuen'],
#  ['asylanten',
#   'fluten',
#   'zusätzlich',
#   'zu',
#   'den',
#   'millionen',
#   'die',
#   'sowieso',
#   'kommen'],
#  ['ende',
#   'gelände',
#   'd',
#   'nach',
#   'den',
#   'wahlen',
#   'werden',
#   'wir',
#   'griechenland',
#   'riesige',
#   'asylanten-kontingente',
#   'abnehmen'],
#  ['wetten',
#   'annewill',
#   'in',
#   'diesem',
#   'moment',
#   'wird',
#   'die',
#   'ernst-grube-halle',
#   'endlich',
#   'geräumt',
#   'leipzig',
#   'npd',
#   'jn',
#   'legida',
#   'refugeesnotwelcome',
#   'illner'],
#  ['erst', 'hieß', 'es', 'es', 'kämen', 'nur', 'top', 'arbeitskräfte'],
#  ['jetzt',
#   'lese',
#   'ich',
#   'nur',
#   'von',
#   'wichsenden',
#   'vergewaltigenden',
#   'betrügenden',
#   'asylanten'],
#  ['merkel', 'die', 'merkel', 'ist', 'sehr', 'ich', 'bezogen'],
#  ['sie', 'soll', 'sich', 'um', 'ihr', 'volk', 'kümmern'],
#  ['annewill',
#   'refugees',
#   'refugeesnotwelcome',
#   'slovenien',
#   'macht',
#   'die',
#   'grenze',
#   'dicht'],
#  ['noch', 'eine', 'gute', 'nachricht'],
#  ['merkelmussweg',
#   'abmerkeln',
#   'refugeesnotwelcome',
#   'luxushotels',
#   'werden',
#   'in',
#   'asylanten',
#   'unterkünfte',
#   'umfunktioniert',
#   'deutsche',
#   'müssen',
#   'in',
#   'primitiven',
#   'heruntergekommenen',
#   'slums',
#   'leben.annewill',
#   'ard',
#   'niemand',
#   'hat',
#   'mich',
#   'gefragt',
#   'ob',
#   'ich',
#   'das',
#   'schaffen',
#   'will'],
#  ['asylwahn',
#   'rapefugees',
#   'volksentscheid',
#   'zu',
#   'asylrecht',
#   'grenzen',
#   'dicht',
#   'merkel',
#   'muss',
#   'weg'],
#  ['ausnahmen',
#   'beim',
#   'mindestlohn',
#   'sind',
#   'auch',
#   'überhaupt',
#   'nicht',
#   'mit',
#   'der',
#   'scharia',
#   'vereinbar',
#   'wenn',
#   'moslems',
#   'betroffen',
#   'sind'],
#  ['spd',
#   'cdu',
#   'deutschland',
#   'pöbelnde',
#   'asylanten',
#   'zeigen',
#   'kopf-ab-gesten',
#   'und',
#   'stinkefinger',
#   'in',
#   'clausnitz'],
#  ['laut', 'im', 'ulbig', 'keine', 'ermittlungen', 'gg'],
#  ['asylanten', 'nur', 'gg'],
#  ['geld',
#   'aus',
#   'der',
#   'portokasse',
#   'von',
#   'merkel',
#   'oder',
#   'doch',
#   'steuergeld'],
#  ['..',
#   'euro',
#   'für',
#   'un',
#   'flüchtlingshilfe',
#   'asylanten',
#   'es',
#   'nicht',
#   'die',
#   'angst',
#   'vor',
#   'asylanten',
#   'sondern',
#   'die',
#   'überfremdung',
#   'deutschlands'],
#  ['und', 'ihr', 'politiker', 'wisst', 'dieses', 'auch', 'ganz', 'genau'],
#  ['es', 'reicht', 'stopp'],
#  ['spahn',
#   'von',
#   'cdu',
#   'will',
#   'wegfall',
#   'von',
#   'mindestlohn',
#   'für',
#   'asylanten'],
#  ['klare', 'schlechterstellunf', 'von', 'einheimischen'],
#  ['wenn',
#   'sich',
#   'der',
#   'hass',
#   'in',
#   'deutschland',
#   'mal',
#   'seinen',
#   'weg',
#   'gebahnt',
#   'hat',
#   'wen',
#   'wird',
#   'er',
#   'eigentlich',
#   'treffen'],
#  ['rapefugees', 'politiker', 'ossis', 'journalisten'],
#  ['d-radio',
#   'millionen',
#   'menschen',
#   'fluechtlinge',
#   'migranten',
#   'asylanten',
#   'in',
#   'der',
#   'tuerkei',
#   'verhandlungen',
#   'mit',
#   'der',
#   'eu',
#   'was',
#   'nützt',
#   'mir',
#   'der',
#   'erde',
#   'geld'],
#  ['kein', 'kranker', 'mensch', 'genießt', 'die', 'welt'],
#  ['goethe',
#   'deutschland',
#   'hartziv',
#   'merkel',
#   'fluechtlinge',
#   'asylanten',
#   'vor',
#   'einem',
#   'jahr',
#   'mussten',
#   'eltern',
#   'wenn',
#   'töchter',
#   'ins',
#   'schwimmbad',
#   'gingen',
#   'nur',
#   'überlegen',
#   'ob',
#   'sie',
#   'schon',
#   'schwimmen',
#   'können'],
#  ['rapefugees',
#   'hartaberfair',
#   'andere',
#   'eu',
#   'länder',
#   'sind',
#   'land',
#   'und',
#   'bürger',
#   'wichtiger',
#   'als',
#   'asylanten'],
#  ['moralisch',
#   'ethisch',
#   'und',
#   'finanziell',
#   'verständlich',
#   'besorgtegutmenschen',
#   'regen',
#   'sich',
#   'auf',
#   'khaled',
#   'von',
#   'asylanten',
#   'getötet'],
#  ['lageso-toter',
#   'moabithilft',
#   'ente',
#   'handgranate',
#   'warfen',
#   'migranten',
#   'das',
#   'was',
#   'im',
#   'swr',
#   'radio',
#   'momentan',
#   'an',
#   'werbung',
#   'pro',
#   'asylanten',
#   'gemacht',
#   'wird',
#   'ist',
#   'so',
#   'penetrant',
#   'wie',
#   'phase',
#   'der',
#   'weihnachtssongs',
#   'fastnachts-seeligkeit',
#   'idee',
#   'hartzer',
#   'vs',
#   'asylanten',
#   'im',
#   'einzelkampf'],
#  ['wer',
#   'schneller',
#   'nen',
#   'arbeits/ausbildungsplatz',
#   'findet',
#   'und',
#   'deutsch',
#   'lernt/kann',
#   'darf',
#   'bleiben'],
#  ['schweden', 'in', 'bürgerkriegsartigen', 'zuständen'],
#  ['eine',
#   'lasche',
#   'konservative',
#   'und',
#   'eine',
#   'irre',
#   'sozialistische',
#   'regierung',
#   'fluten',
#   'das',
#   'land',
#   'mit',
#   'asylanten',
#   'utter',
#   'zbale',
#   'in',
#   'this',
#   'hashtag',
#   'rapefugees',
#   'gestern',
#   'kamen',
#   'die',
#   'asylanten'],
#  ['heute', 'nacht', 'wurde', 'versucht', 'einzubrechen'],
#  ['erschreckend',
#   'daß',
#   'es',
#   'frauen',
#   'sind',
#   'die',
#   'jahre',
#   'emanzipation',
#   'zugunsten',
#   'islamistischer',
#   'vergewaltiger',
#   'in',
#   'die',
#   'tonne',
#   'treten'],
#  ['rapefugees',
#   'afd',
#   'deutschland',
#   'übt',
#   'karneval',
#   'nach',
#   'den',
#   'regeln',
#   'der',
#   'scharia',
#   'weil',
#   'da',
#   'eh',
#   'bald',
#   'nur',
#   'noch',
#   'moslems',
#   'feiern',
#   'werden'],
#  ['deutsche',
#   'frauen',
#   'aus',
#   'angst',
#   'zuhause',
#   'wenn',
#   'ich',
#   'mir',
#   'den',
#   'mond',
#   'gerade',
#   'so',
#   'anschaue',
#   'die',
#   'islamisierung',
#   'des',
#   'abendlandes',
#   'ist',
#   'doch',
#   'schon',
#   'längst',
#   'durch'],
#  ['fakt',
#   'auf',
#   'ard',
#   'asylanten',
#   'fahren',
#   'mit',
#   'taxi',
#   'herum',
#   'auf',
#   'steuerzahlerkosten'],
#  ['merkel', 'macht', 'es', 'möglich'],
#  ['asylanten',
#   'man',
#   'kann',
#   'nicht',
#   'einf',
#   'verschiedene',
#   'menschen',
#   'bzw',
#   'völker/kulturen',
#   'zusammenleg',
#   'sagen',
#   'nun',
#   'seit',
#   'ma',
#   'glückl',
#   'miteinander+versteht',
#   'euch',
#   'idomeni',
#   'asylanten',
#   'fluechtlinge',
#   'schöne',
#   'vorstellung',
#   'für',
#   'die',
#   'kameras'],
#  ['blanke', 'gewalt'],
#  ['merkel', 'drückt', 'daheim', 'krokodilstränen', 'ins', 'kissen'],
#  ['keine', 'schnittmenge', 'zwischen', 'npd', 'und', 'afd'],
#  ['funny', '…', 'euro'],
#  ['es',
#   'gibt',
#   'die',
#   'schnittmenge',
#   'die',
#   'afd',
#   'gibt',
#   'sie',
#   'nicht',
#   'zu',
#   'arabisch',
#   'als',
#   'schulsprache',
#   'islamisierung',
#   'deutschlands',
#   'in',
#   'vollem',
#   'gange',
#   'stelle',
#   'mir',
#   'gerade',
#   'vor',
#   'wie',
#   'es',
#   'wäre',
#   'wenn',
#   'die',
#   'saudis',
#   'in',
#   'deutschland',
#   'einmarschieren',
#   'würden',
#   'scharia',
#   'krieg',
#   'in',
#   'syrien',
#   'wer',
#   'hat',
#   'uns',
#   'verraten'],
#  ['die', 'sozialdemokraten'],
#  ['werner', 'faymann', 'ist', 'derzeit', 'eine', 'paradebeispiel', 'dafür'],
#  ['kontingent',
#   'refugeesnotwelcome',
#   'traurig',
#   'lieber',
#   'horst',
#   'seehofer',
#   'der',
#   'bayerische',
#   'staat',
#   'braucht',
#   'eine',
#   'strategie',
#   'die',
#   'der',
#   'islamisierung',
#   'bayerns',
#   'einen',
#   'riegel',
#   'vorschiebt'],
#  ['sz',
#   'faz',
#   'die',
#   'haben',
#   'nix',
#   'mehr',
#   'die',
#   'leute',
#   'in',
#   'den',
#   'asylanten-heimen'],
#  ['gut',
#   'außer',
#   'denen',
#   'mit',
#   'den',
#   'geklauten',
#   'handys.maischberger',
#   'man',
#   'stelle',
#   'sich',
#   'vor',
#   'es',
#   'käme',
#   'zum',
#   'frieden',
#   'und',
#   'alle',
#   'asylanten',
#   'mit',
#   'syrischen',
#   'pässen',
#   'würden',
#   'dorthin',
#   'ausgeflogen'],
#  ['wir',
#   'von',
#   'der',
#   'cdu',
#   'schaffen',
#   'es',
#   'weitere',
#   'millionen',
#   'asylanten',
#   'nach',
#   'd',
#   'zu',
#   'locken',
#   'und',
#   'die',
#   'dumme',
#   'bevölkerung',
#   'zu',
#   'melken'],
#  ['maischberger',
#   'fratscher',
#   'geld',
#   'für',
#   'migranten',
#   'als',
#   'investition.bis',
#   'dahin',
#   'weiterhin',
#   'rapefugees',
#   'islamisierung',
#   'und',
#   'is',
#   'terroristen'],
#  ['abmerkeln',
#   'egal',
#   'welche',
#   'partei',
#   'man',
#   'wählt',
#   'nur',
#   'orange',
#   'oder',
#   'apfelsine'],
#  ['annewill',
#   'einprozent',
#   'grenzendicht',
#   'refugees',
#   'refugeesnotwelcome',
#   'deutschland',
#   'das',
#   'griechenland',
#   'das',
#   'jetzt',
#   'alle',
#   'beschlüsse',
#   'zu',
#   'asylanten',
#   'blockieren',
#   'will',
#   'is',
#   'aber',
#   'nicht',
#   'das',
#   'land',
#   'das',
#   'quartalsweise',
#   'milliarden',
#   'schnorrt',
#   'oder'],
#  ['reker',
#   'beugt',
#   'sich',
#   'islam',
#   'und',
#   'scharia',
#   'schafft',
#   'für',
#   'frauen',
#   'sicherheitszonen',
#   '=fluchtpunkte',
#   'flüchtlinge',
#   'köln',
#   'massenvergewaltigungen',
#   'maischberger',
#   'liefers',
#   'wir',
#   'achten',
#   'frauen',
#   'für',
#   'viele',
#   'von',
#   'den',
#   'rapefugees',
#   'ist',
#   'das',
#   'wie',
#   'ein',
#   'paradies',
#   'hier.lasche',
#   'strafen',
#   'bei',
#   'vergewaltigungen',
#   'perlen',
#   'aus',
#   'der',
#   'redaktionskonferenz',
#   'heute',
#   'idee',
#   'für',
#   'buchtitel',
#   'das',
#   'wunder',
#   'von',
#   'dresden',
#   'islamisierung',
#   'ohne',
#   'muslime',
#   'nopegida',
#   'nolegida',
#   'wir',
#   'werden',
#   'noch',
#   'gemeinsam',
#   'auf',
#   'pegida',
#   'stehen',
#   'schulter',
#   'an',
#   'schulter',
#   'bis',
#   'zu',
#   'den',
#   'zähnen',
#   'bewaffnet',
#   'im',
#   'bürgerkrieg',
#   'gegen',
#   'rapefugees',
#   'schauhin',
#   'merkel',
#   'rechnet',
#   'mit',
#   'mio',
#   'neuen',
#   'asylanten',
#   'in',
#   'd',
#   'bis'],
#  ['zum', 'vergleich', 'schätzung', 'war', 'gekommen', 'sind', 'mio'],
#  ['dank',
#   'cdu',
#   'ich',
#   'habe',
#   'bis',
#   'heute',
#   'nicht',
#   'verstanden',
#   'was',
#   'an',
#   'dunkelhäutigen',
#   'in',
#   'schwarzen',
#   'burkas',
#   'mit',
#   'dunkler',
#   '“',
#   'kultur',
#   '“',
#   'bunt',
#   'sein',
#   'soll',
#   'islamisierung',
#   'dieser',
#   'sommer',
#   'wird',
#   'der',
#   'sommer',
#   'der',
#   'rapefugees',
#   'schade',
#   'das',
#   'die',
#   'wahlen',
#   'nicht',
#   'im',
#   'herbst',
#   'sind'],
#  ['die',
#   'gedanken',
#   'sind',
#   'frei',
#   '-nicht',
#   'mehr',
#   'in',
#   'europa',
#   'deutschland',
#   'sophienhof',
#   'koelnbhf',
#   'merkelmussweg',
#   'islamisierung',
#   'flüchtlingskrise',
#   'wer',
#   'für',
#   'deutsche',
#   'arbeitslose',
#   'und',
#   'obdachlose',
#   'die',
#   'selben',
#   'finanz'],
#  ['mittel',
#   'fordert',
#   'wie',
#   'sie',
#   'asylanten',
#   'zukommen',
#   'wird',
#   'beschimpft'],
#  ['wieso',
#   'haben',
#   'diese',
#   'gutmenschen',
#   'vegetarier',
#   'veganer',
#   'und',
#   'tierschützer',
#   'eigentlich',
#   'nichts',
#   'gegen',
#   'halal',
#   '-schlachtung'],
#  ['asylanten',
#   'flüchtlinge',
#   'ein',
#   'soldat',
#   'der',
#   'gegen',
#   'flüchtlinge',
#   'ist',
#   'und',
#   'u.a'],
#  ['rapefugees',
#   'nutzt',
#   'kritisiert',
#   'meine',
#   'tweets',
#   'zu',
#   'inthebox',
#   'patridiot',
#   'mit',
#   'gewehr'],
#  ['na', 'toll'],
#  ['manche', 'sagen', 'die', 'afd', 'wähler', 'sollen', 'sich', 'schämen'],
#  ['ich',
#   'finde',
#   'die',
#   'jungs',
#   'von',
#   'koelnhbf',
#   'haben',
#   'viel',
#   'mehr',
#   'grund',
#   'sich',
#   'zu',
#   'schämen'],
#  ['rapefugees',
#   'maischberger',
#   'laschet',
#   'pegida',
#   'gibts',
#   'im',
#   'westen',
#   'nicht.leute',
#   'trauen',
#   'sich',
#   'nicht',
#   'mitzulaufen',
#   'wegen',
#   'ächtung',
#   'aber',
#   'islamisierung',
#   'ist',
#   'umso',
#   'realer',
#   'dor',
#   'beateuhse',
#   'fördert',
#   'scharia',
#   'über',
#   'internet-sexshop',
#   'el',
#   'asira',
#   'aus',
#   'den',
#   'niederlanden',
#   'danke',
#   'clausnitz',
#   'für',
#   'euren',
#   'widerstand'],
#  ['ihr', 'seid', 'helden'],
#  ['sos',
#   'rapefugees',
#   'koelnhbf',
#   'cologne',
#   'islamisierung',
#   'aus',
#   'westdeutschland',
#   'danke'],
#  ['wie',
#   'bei',
#   'hartaberfair',
#   'gesagt',
#   'brechen',
#   'der',
#   'asylanten',
#   'die',
#   'ausbildung',
#   'ab.afd',
#   'asylanten',
#   'betteln',
#   'jetzt',
#   'auch',
#   'in',
#   'den',
#   'nachbardörfern'],
#  ['wie', 'lange', 'wird', 'diese', 'kriminalität', 'noch', 'versteckt'],
#  ['asylbewerber',
#   'fluechtlinge',
#   'asylum',
#   'nur',
#   'weils',
#   'mal',
#   'gesagt',
#   'wurde',
#   'ist',
#   'es',
#   'nicht',
#   'falsch',
#   'ab',
#   'der',
#   'türkei',
#   'sind',
#   'syrer',
#   'u',
#   'iraker',
#   'keine',
#   'flüchtlinge',
#   'mehr'],
#  ['refugeesnotwelcome',
#   'flüchtlingen',
#   'nicht',
#   'sofort',
#   'gratis',
#   'villen',
#   'autos',
#   'auszuhändigen',
#   'ist',
#   'ein',
#   'verstoß',
#   'gegen',
#   'die',
#   'menschenwürde'],
#  ['hungerstreik',
#   'rapefugees',
#   'könnten',
#   'wir',
#   'schmarotzer',
#   'und',
#   'kriminelle',
#   'loswerden',
#   'würde',
#   'die',
#   'asylanten-schwemme',
#   'auf',
#   'beherrschbare',
#   'zahlen',
#   'runtergehen'],
#  ['ob',
#   'asylanten',
#   'wohl',
#   'mitbekommen',
#   'daß',
#   'linke',
#   'gutmenschen',
#   'antifa',
#   'die',
#   'deutsche',
#   'nation',
#   'zerstören',
#   'wollen'],
#  ['angst', 'vor', 'islamisierung'],
#  ['die',
#   'deutsche',
#   'europäische',
#   'geschichte',
#   'tradition',
#   'bräuche',
#   'sprache',
#   'leben',
#   'lehren',
#   'und',
#   'vermitteln'],
#  ['hartaberfair',
#   'oecd',
#   'schätzt',
#   'wachstum',
#   'von',
#   'd',
#   'in',
#   'den',
#   'nächsten',
#   'jahren',
#   'viel',
#   'schwächer',
#   'ein',
#   'als',
#   'erwartet'],
#  ['wo',
#   'ist',
#   'der',
#   'boom',
#   'durch',
#   'asylanten',
#   'außer',
#   'bei',
#   'schulden'],
#  ['mecklenburg-vorpommern',
#   '..',
#   'spd',
#   'afd',
#   '..',
#   'spd',
#   'afd',
#   'bereicherung',
#   'flüchtlinge',
#   'spd',
#   'islamisierung',
#   'in',
#   'deutschlandradio',
#   'kultur',
#   'erfahren',
#   'wir',
#   'gerade',
#   'dass',
#   'der',
#   'islam',
#   'gg',
#   'dem',
#   'christentum',
#   'die',
#   'frauenfreundlichere',
#   'relion',
#   'ist'],
#  ['islamisierung', 'pegida', 'ca'],
#  ['syrer', 'fliehen', 'vor', 'kämpfen'],
#  ['warum', 'kämpft', 'ihr', 'nicht', 'endlich', 'für', 'euer', 'land'],
#  ['refugeesnotwelcome',
#   'fluechtlinge',
#   'jetzt',
#   'warte',
#   'ich',
#   'auf',
#   'den',
#   'brennpunkt',
#   'der',
#   'ard',
#   '+ein',
#   'zdfspezial',
#   'zum',
#   'thema',
#   'handgranate',
#   'mit',
#   'maas',
#   'kretschmann',
#   'asylanten',
#   'integrierte',
#   'werden',
#   'abgeschoben',
#   'illegale',
#   'täter',
#   'dürfen',
#   'bleiben'],
#  ['wieso', 'läuft', 'hier', 'so', 'viel', 'falsch'],
#  ['refugeescrisis',
#   'islam',
#   'rapefugees',
#   'liebe',
#   'gutmenschen',
#   'eure',
#   'einzelfall',
#   'asylanten',
#   'werden',
#   'immer',
#   'mehr.kiel',
#   'sophienhof',
#   'da',
#   'sieht',
#   'man',
#   'was',
#   'schlummert',
#   'in',
#   'den',
#   'armen',
#   'asylanten.afd',
#   'frankreich',
#   'sagt',
#   'sie',
#   'werden',
#   'nur',
#   't',
#   'asylanten',
#   'aufnehmenund',
#   'wir',
#   'haben',
#   'seit',
#   'jahresbeginn',
#   'schon',
#   't',
#   'aufgenommen'],
#  ['merkel', 'verpiss', 'dich'],
#  ['warum',
#   'spendet',
#   'hoaxmap',
#   'die',
#   'werbeeinnahmen',
#   'nicht',
#   'den',
#   'opferfamilien',
#   'die',
#   'durch',
#   'vergewaltigung',
#   'von',
#   'flüchtlinge',
#   'und',
#   'asylanten',
#   'passiert',
#   'sind',
#   'die',
#   'islamisierung',
#   'des',
#   'abendlandes',
#   'ist',
#   'die',
#   'schlimmste',
#   'krise',
#   'der',
#   'gegenwart',
#   'die',
#   'zu',
#   'lösen',
#   'ist',
#   'durch',
#   'zürückdrängung',
#   'des',
#   'islam',
#   'in',
#   'die',
#   'wüste'],
#  ['wenn',
#   'ihr',
#   'deutschland',
#   'so',
#   'scheiße',
#   'findet',
#   'warum',
#   'wollt',
#   'ihr',
#   'dann',
#   'möglichst',
#   'vielen',
#   'asylanten',
#   'zumuten',
#   'hier',
#   'zu',
#   'leben'],
#  ['geflüchtete',
#   'aus',
#   'den',
#   'ländern',
#   'mit',
#   'der',
#   'totalitären',
#   'ideologie',
#   'des',
#   'islam',
#   'um',
#   'hier',
#   'islamisierung',
#   'der',
#   'gesellschaft',
#   'anzuheizen',
#   'taqqiya',
#   'abmerkeln',
#   'deutschland',
#   'will',
#   'den',
#   'europäern',
#   'eine',
#   'islamisierung',
#   'und',
#   'zwangsmigration',
#   'aufzwingen.das',
#   'geht',
#   'nicht',
#   'afd',
#   'hartaberfair',
#   'ich',
#   'brauche',
#   'einen',
#   'blog',
#   'glaube',
#   'ich',
#   'zeichen',
#   'sind',
#   'zu',
#   'wenig'],
#  ['get',
#   'rid',
#   'of',
#   'islam',
#   'muslims',
#   'rapefugees',
#   'deutschland',
#   'hat',
#   'seine',
#   'staatlichkeit',
#   'aufgegeben'],
#  ['das', 'gg', 'ist', 'aus', 'den', 'fugen', 'gehoben'],
#  ['es',
#   'herrscht',
#   'der',
#   'irrsinn',
#   'islamisierung',
#   'cdu',
#   'hartaberfair',
#   'ifo-chef',
#   'sinn',
#   'warnt',
#   'jeder',
#   'flüchtling',
#   'kostet',
#   'deutschland'],
#  ['asylanten',
#   'warum',
#   'wurde',
#   'der',
#   'mob',
#   'in',
#   'clausnitz',
#   'nicht',
#   'von',
#   'der',
#   'polizei',
#   'aufgelöst',
#   'um',
#   'die',
#   'situation',
#   'zu',
#   'beruhigen'],
#  ['flüchtlinge',
#   'flüchtlingskrise',
#   'asylanten',
#   'ungarn',
#   'will',
#   'volksabstimmung',
#   'durchführen',
#   'so',
#   'macht',
#   'man',
#   'das'],
#  ['refugeesnotwelcome',
#   'seit',
#   'beginn',
#   'der',
#   'asylflut',
#   'sprunghafter',
#   'anstieg',
#   'von',
#   'vergewaltigungen',
#   'um',
#   'fast'],
#  ['wehrt', 'euch'],
#  ['grenzendicht',
#   'rapefugees',
#   'nrw',
#   'duisburg-marxloh',
#   'ist',
#   'erst',
#   'der',
#   'anfangder',
#   'rest',
#   'ist',
#   'in',
#   'arbeit',
#   'abmerkeln',
#   'islamisierung',
#   'migranten',
#   'sind',
#   'in',
#   'clausnitz',
#   'anzeigen',
#   'wg'],
#  ['körperlicher', 'angriffe+diebstahl', 'eingegangen'],
#  ['kölnhbf',
#   'polizei',
#   'rapefugees',
#   'handgranate',
#   'asyl',
#   'merkel',
#   'kiel',
#   'wer',
#   'jetzt',
#   'immer',
#   'noch',
#   'die',
#   'blockparteien',
#   'wählt',
#   'macht',
#   'sich',
#   'mitschuldig',
#   'an',
#   'kommenden',
#   'verbrechen'],
#  ['abmerkeln', 'rapefugees', 'afd', 'wählen'],
#  ['deutsche', 'frauen', 'an', 'rapefugees', 'opfern'],
#  ['wasistlinks', 'illner'],
#  ['deutsche',
#   'wirtschaft',
#   'hat',
#   'sich',
#   'vor',
#   'freude',
#   'auf',
#   'asylanten',
#   'überschlagen'],
#  ['jetzt', 'ziehen', 'alle', 'den', 'schwanz', 'ein'],
#  ['warum', 'nur'],
#  ['was', 'tun', 'gegen', 'clausnitz'],
#  ['keine',
#   'neuen',
#   'asylanten',
#   'kampf',
#   'gegen',
#   'asylmafia',
#   'merkel',
#   'vor',
#   'gericht',
#   'stellen',
#   'cdu',
#   'abwählen',
#   'überall'],
#  ['asyl-befürworter',
#   'die',
#   'nie',
#   'einen',
#   'asylanten',
#   'bei',
#   'sich',
#   'zuhause',
#   'aufgenommen',
#   'habenkann',
#   'ich',
#   'nicht',
#   'ernst',
#   'nehmen'],
#  ['man',
#   'kann',
#   'nicht',
#   'mio',
#   'arbeitslose',
#   'muslimische',
#   'asylanten',
#   'gegen',
#   'die',
#   'deutsche',
#   'mehrheit',
#   'ins',
#   'land',
#   'lassen',
#   'die',
#   'mehrheit',
#   'als',
#   'nazis',
#   'beschimpfen',
#   'cdu'],
#  ['gegen',
#   'multikulti',
#   'hab',
#   'ich',
#   'eigentlich',
#   'nichts',
#   'gegen',
#   'islamisierung',
#   'schon'],
#  ['die', 'heutige', 'tagesscheisse', 'heist', 'hoaxmap'],
#  ['die',
#   'tätsächlichen',
#   'vergewaltigungen',
#   'durch',
#   'flüchtlinge',
#   'und',
#   'asylanten',
#   'werden',
#   'nicht',
#   'erwähnt'],
#  ['ja',
#   'die',
#   'realität',
#   'ist',
#   'wirklich',
#   'unbequem',
#   'man',
#   'sollte',
#   'sie',
#   'ignorieren'],
#  ['islam',
#   'scharia',
#   'salafismus',
#   'multikulti',
#   'wenn',
#   'nicht',
#   'aus',
#   'überzeugung',
#   'dann',
#   'aus',
#   'notwehr',
#   'afd',
#   'wählen',
#   'bei',
#   'landtagswahlen',
#   'd',
#   'sonst',
#   'kaputt',
#   'abmaasen',
#   'regsprecher',
#   'krimigranten',
#   'rapefugees',
#   'wenn',
#   'sie',
#   'gesagt',
#   'hätte',
#   'domian´',
#   'ich',
#   'hasse',
#   'dich',
#   'hätten',
#   'sie',
#   'alle',
#   'abgefeiert',
#   'gez',
#   'wdr',
#   'live',
#   'koelnhbf',
#   'rapefugees',
#   'bezeichnend',
#   'musl.verbände',
#   'schließen',
#   'sich',
#   'der',
#   'allianz',
#   'für',
#   'weltoffenheit',
#   'an.hinterher',
#   'aber',
#   'nur',
#   'weil',
#   'es',
#   'ihnen',
#   'hilft',
#   'islamisierung',
#   'abmerkeln',
#   'gerüchten',
#   'zufolge',
#   'finden',
#   'sich',
#   'in',
#   'den',
#   'netzen',
#   'der',
#   'fischer',
#   'im',
#   'mittelmeer',
#   'inzwischen',
#   'mehr',
#   'pässe',
#   'als',
#   'fische'],
#  ['flüchtlinge',
#   'asylanten',
#   'merkel',
#   'ich',
#   'würde',
#   'gern',
#   'mal',
#   'eine',
#   'sondersendung',
#   'zur',
#   'täglichen',
#   'inländerfeindlichkeit',
#   'sehen'],
#  ['refugeesnotwelcome',
#   'brdregime',
#   'volksverräter',
#   'unrecht',
#   'was',
#   'die',
#   'allermeisten',
#   'immer',
#   'noch',
#   'nicht',
#   'begriffen',
#   'haben',
#   'der',
#   'islam',
#   'hat',
#   'seine',
#   'eigenen',
#   'menschenrechte',
#   'scharia-basiert'],
#  ['ihr', 'deppen'],
#  ['neue', 'asylanten', 'kamen', 'im', 'januar'],
#  ['und', 'bamf', 'geht', 'von'],
#  ['fürs', 'gesamte', 'jahr', 'aus'],
#  ['können', 'die', 'nicht', 'mal', 'rechnen'],
#  ['meinen',
#   'manche',
#   'kandidaten',
#   'eigentlich',
#   'mit',
#   'hashtags',
#   'wie',
#   'rapefugees',
#   'oder',
#   'krimigranten',
#   'würden',
#   'sie',
#   'sich',
#   'glaubwürdiger',
#   'und/oder',
#   'seriöser',
#   'machen'],
#  ['in',
#   'jeder',
#   'stadt',
#   'sind',
#   'jetzt',
#   'tausende',
#   'neue',
#   'muslime',
#   'millionen',
#   'muslime',
#   'brauchen',
#   'gebetsräume',
#   'bald',
#   'werden',
#   'tausende',
#   'moscheen',
#   'gebaut'],
#  ['krimmigranten', 'zu', 'behandeln', 'wie', 'hinlänglich', 'berichtet'],
#  ['wenn',
#   'sich',
#   'diese',
#   'militärs',
#   'nur',
#   'annähernd',
#   'so',
#   'abartig',
#   'verhalten',
#   'haben',
#   'und',
#   'davon',
#   'muß',
#   'flüchtlinge',
#   'zwangsweise',
#   'in',
#   'privathaushalten',
#   'einzuquartieren',
#   'ist',
#   'kein',
#   'thema',
#   'vor',
#   'den',
#   'landtagswahlen'],
#  ['merkel',
#   'rapefugees',
#   'vorhersagetweet',
#   'heimleiter',
#   'von',
#   'asylanten',
#   'heim',
#   'in',
#   'clausnitz',
#   'entlassen',
#   'weil',
#   'afd',
#   'mitgliedsoviel',
#   'zu',
#   'demokratie',
#   'diskriminierung',
#   'von',
#   'höchster',
#   'stelle'],
#  ['warum',
#   'ist',
#   'deutschland',
#   'nicht',
#   'solidarisch',
#   'mit',
#   'dem',
#   'rest',
#   'von',
#   'europa'],
#  ['also',
#   'keine',
#   'weiteren',
#   'langzeitarbeitslosen',
#   'oder',
#   'vergewaltigenden',
#   'asylanten',
#   'asylanten',
#   'kommen',
#   'aus',
#   'erbärmlichsten',
#   'zuständen',
#   'wir',
#   'bringen',
#   'sie',
#   'in',
#   'hotels',
#   'unter',
#   'mit',
#   'taschengeld',
#   'all',
#   'incl',
#   'merkel',
#   'denkt',
#   'die',
#   'gehen',
#   'wieder'],
#  ['schwulenhilfe',
#   'berlin',
#   'richtet',
#   'für',
#   'schwule',
#   'asylanten',
#   'schwulen-unterkünfte',
#   'ein',
#   'gekoppelt',
#   'mit',
#   'einem',
#   'schw.puff',
#   'könnten',
#   'asylanten',
#   'dort',
#   'arbeiten',
#   'alles',
#   'recht',
#   'ominös',
#   'mit',
#   'dem',
#   'zugunglück'],
#  ['wüsste',
#   'gerne',
#   'ob',
#   'die',
#   'lokführer',
#   'hassan',
#   'ali',
#   'oder',
#   'mohammed',
#   'hießen',
#   'fluechtlingskrise',
#   'islamisierung',
#   'dürfen',
#   'in',
#   'stuttgart',
#   'flüchtlinge',
#   'und',
#   'rapefugees',
#   'immer',
#   'noch',
#   'kostenlos',
#   'ins',
#   'stadion'],
#  ['vfbbvb',
#   'frau',
#   'm',
#   'türkischen',
#   'wurzeln',
#   'erzählt',
#   'sie',
#   'ist',
#   'beunruhigt',
#   'weil',
#   'direkt',
#   'neben',
#   'der',
#   'schule',
#   'ihrer',
#   'tochter',
#   'asylanten-heim',
#   'aufmacht'],
#  ['fiese',
#   'rassistin',
#   'flüchtlinsheime',
#   'in',
#   'denen',
#   'nicht',
#   'jeden',
#   'tag',
#   'gratis',
#   'rinderfilet',
#   'serviert',
#   'wird',
#   'sind',
#   'ein',
#   'verstoß',
#   'gegen',
#   'die',
#   'menschenwürde.hungerstreik',
#   'rapefugees',
#   'mir',
#   'hat',
#   'vorhin',
#   'jemand',
#   'erzählt',
#   'dass',
#   'die',
#   'handgranate',
#   'evtl'],
#  ['von', 'den', 'asylanten', 'selber', 'kam'],
#  ['weiß', 'da', 'jemand', 'was'],
#  ['ich', 'bin', 'für', 'die', 'schweinefleischpflicht'],
#  ['hilft', 'gegen', 'die', 'islamisierung'],
#  ['europa', 'ist', 'groß', 'weil', 'es', 'nie', 'islamisch', 'war'],
#  ['und', 'das', 'muss', 'so', 'bleiben'],
#  ['nein', 'zur', 'islamisierung', 'europas'],
#  ['sie',
#   'traut',
#   'sich',
#   'nicht',
#   'zu',
#   'sagen',
#   'was',
#   'wirklich',
#   'läuft',
#   'da',
#   'muss',
#   'man',
#   'nur',
#   'mal',
#   'samstag',
#   'früh',
#   'im',
#   'pott',
#   'zur',
#   'arbeit',
#   'fahren',
#   'asylanten',
#   'domian',
#   'merkel',
#   'will',
#   '.e',
#   'asylanten',
#   'nach',
#   'spanien',
#   'abschieben',
#   'wo',
#   'überall',
#   'gespart',
#   'wird',
#   'arbeitslos',
#   'sind.das',
#   'ist',
#   'ihre',
#   'solidarität',
#   'heuchlerin',
#   'in',
#   'zeiten',
#   'in',
#   'der',
#   'rotherham',
#   'möglich',
#   'ist',
#   'muss',
#   'jeder',
#   'einsehen',
#   'dass',
#   'die',
#   'islamisierung',
#   'bereits',
#   'stattgefunden',
#   'hat'],
#  ['griechenland',
#   'grenze',
#   'mazedonien',
#   'man',
#   'muß',
#   'diesen',
#   'radikalen',
#   'migranten',
#   'klar',
#   'machen',
#   'sie',
#   'sind',
#   'keine',
#   'flüchtlinge',
#   'mehr',
#   'krimigranten',
#   'rapefugees',
#   'deutschebank',
#   'sagt',
#   'asylanten',
#   'helfen',
#   'der',
#   'wirtschaft.die',
#   'kompetenz',
#   'von',
#   'denen',
#   'kann',
#   'man',
#   'übrigens',
#   'an',
#   'ihren',
#   'geschäftszahlen',
#   'ablesen'],
#  ['warum',
#   'lädt',
#   'man',
#   'eigentlich',
#   'nicht',
#   'mal',
#   'einen',
#   'normalen',
#   'bürger',
#   'zu',
#   'maischberger',
#   'ein',
#   'wenn',
#   'es',
#   'um',
#   'das',
#   'thema',
#   'asylanten',
#   'geht'],
#  ['nicht', 'alle', 'sachsen', 'wollen', 'keine', 'asylanten'],
#  ['bitte', 'nicht', 'pauschalisieren'],
#  ['schuld',
#   'ist',
#   'die',
#   'cdu',
#   'regiert',
#   'in',
#   'land+bund',
#   'hartaberfair',
#   'schwahn',
#   '.das',
#   'problem',
#   'ist',
#   'aber',
#   'nicht',
#   'nur',
#   'das',
#   'fehlende',
#   'geld',
#   'sondern',
#   'die',
#   'angst',
#   'vor',
#   'einer',
#   'islamisierung',
#   'in',
#   'allen',
#   'ländern',
#   'der',
#   'eu'],
#  ['liebe',
#   'gemeinden',
#   'in',
#   'bayern',
#   'wir',
#   'legen',
#   'asylanten',
#   'obergrenzen',
#   'fest',
#   'und',
#   'setzen',
#   'sie',
#   'notfalls',
#   'vor',
#   'gericht',
#   'durch'],
#  ['sz',
#   'faz',
#   'zeit',
#   'nzz',
#   'worauf',
#   'warten',
#   'flüchtlinge',
#   'und',
#   'asylanten',
#   'eigendlich'],
#  ['griechenland',
#   'europa',
#   'also',
#   'kein',
#   'kriegsland',
#   'und',
#   'damit',
#   'asyl',
#   'in',
#   'griechenland'],
#  ['nach',
#   'den',
#   'landtagswahlen',
#   'wird',
#   'am',
#   '..',
#   'sicher',
#   'die',
#   'benzinabgabe',
#   'eingeführt'],
#  ['deutsche',
#   'zahlen',
#   'rekordsteuern',
#   'für',
#   'asylanten',
#   'in',
#   'hängematte'],
#  ['kostenloses',
#   'aber',
#   'zu',
#   'langsames',
#   'internet',
#   'in',
#   'flüchtlinsheimen',
#   'ist',
#   'ein',
#   'verstoß',
#   'gegen',
#   'die',
#   'menschenwürde'],
#  ['hungerstreik',
#   'rapefugees',
#   'gutmenschen',
#   'die',
#   'den',
#   'islam',
#   'unterstützen',
#   'werden',
#   'sich',
#   'noch',
#   'wundern',
#   'wenn',
#   'bald',
#   'immer',
#   'aggressiver',
#   'die',
#   'barbarei',
#   'der',
#   'scharia',
#   'in',
#   'd',
#   'gefordert',
#   'wird'],
#  ['orf',
#   'zib',
#   'vergewaltigung',
#   'durch',
#   'irak.asylanten',
#   'an',
#   'kind',
#   'hallenbad',
#   'wien',
#   'keine',
#   'informationen',
#   'wg',
#   'opferschutz'],
#  ['wer', 'glaubt', 'das', 'denn'],
#  ['griechenland',
#   'will',
#   'milliarden',
#   'für',
#   'asylanten',
#   'um',
#   'griechische',
#   'rentner',
#   'zu',
#   'bezahlen'],
#  ['die',
#   'griechische',
#   'marine',
#   'soll',
#   'migranten',
#   'in',
#   'die',
#   'türkei',
#   'bringen',
#   'an',
#   'der',
#   'schule',
#   'meiner',
#   'nichte',
#   'wurde',
#   'eltern',
#   'jetzt',
#   'gesagt',
#   'mädchen',
#   'sollen',
#   'nicht',
#   'mehr',
#   'in',
#   'miniröcken',
#   'zum',
#   'unterricht',
#   'kommen'],
#  ['islamisierung',
#   'merkel',
#   'will',
#   'dass',
#   'die',
#   'von',
#   'ihr',
#   'hergeholten',
#   'kulturbereicherer',
#   'cdu',
#   'wählen'],
#  ['aber', 'was', 'wenn', 'die', 'ihre', 'eigene', 'scharia-partei', 'gründen'],
#  ['abmerkeln',
#   'amnestyinternational',
#   'heult',
#   'h',
#   'wie',
#   'schrecklich',
#   'd',
#   'ist',
#   'um',
#   'dann',
#   'alle',
#   'asylanten',
#   'der',
#   'welt',
#   'zu',
#   'uns',
#   'zu',
#   'bringen'],
#  ['ist', 'das', 'kein', 'linksfaschismus'],
#  ['nicht',
#   'in',
#   'schwimmbäder',
#   'scheissen',
#   'zu',
#   'dürfen',
#   'ist',
#   'ein',
#   'verstoß',
#   'gegen',
#   'die',
#   'menschenwürde'],
#  ['hungerstreik',
#   'rapefugees',
#   'im',
#   'freilichtmuseum',
#   'hessenpark',
#   'mit',
#   'asylanten',
#   'nein',
#   'danke',
#   'armlaenge',
#   'jetzt',
#   'zerreißen',
#   'sie',
#   'sich',
#   'wieder',
#   'das',
#   'maul',
#   'über',
#   'rapefugees'],
#  ['aber', 'wo', 'war', 'der', 'aufschrei', 'bei', 'make', 'rape', 'legal'],
#  ['gabs',
#   'nicht',
#   'landtagswahlen',
#   'afd',
#   'muss',
#   '-stellig',
#   'abschließen',
#   'sonst',
#   'm',
#   'kaiserin-wählt',
#   'afd',
#   'aus',
#   'notwehr',
#   'nichtwähler',
#   'nichtwählen',
#   'krimigranten',
#   'rapefugees',
#   'karneval',
#   'hat',
#   'merkel',
#   'jetzt',
#   'anscheinend',
#   'auch',
#   'versaut'],
#  ['frauen', 'fühlen', 'sich', 'unsicher'],
#  ['weiberfastnacht',
#   'rapefugees',
#   'cameron',
#   'bringt',
#   'viel',
#   'mit',
#   'nach',
#   'großbritannien',
#   'und',
#   'merkel'],
#  ['nichts',
#   'außer',
#   'asylanten',
#   'chaos',
#   'regierung',
#   'spd',
#   'fordert',
#   'auch',
#   'unterstützung',
#   'für',
#   'arme',
#   'deutsche',
#   'und',
#   'nicht',
#   'nur',
#   'für',
#   'asylanten'],
#  ['das', 'ist', 'die', 'cdu', 'von', 'heute'],
#  ['köln', 'wieder', 'sexuelle', 'übergriffe', 'in', 'köln'],
#  ['asylanten',
#   'attakieren',
#   'in',
#   'schwimmbad',
#   'jugendliche',
#   'mädchen',
#   'und',
#   'bekommen',
#   'daraufhin',
#   'hausverbot',
#   'die',
#   'steuererhöhungen',
#   'wegen',
#   'der',
#   'fachkräfte',
#   'kommen',
#   'erst',
#   'nach',
#   'der',
#   'bundestagswahl'],
#  ['wirschaffendas',
#   'merkel',
#   'integration',
#   'rapefugees',
#   'spd',
#   'cdu',
#   'religion',
#   'ist',
#   'doof',
#   'aber',
#   'wir',
#   'haben',
#   'doofheitsfreiheit',
#   'wo',
#   'ist',
#   'das',
#   'problem',
#   'mit',
#   'der',
#   'islamisierung',
#   'katholischemissionare',
#   'gnargh',
#   'gegner',
#   'von',
#   'asylanten',
#   'mit',
#   'nazis',
#   'gleichzusetzen',
#   'ist',
#   'einfach',
#   'falsch'],
#  ['das',
#   'verharmlost',
#   'doch',
#   'nur',
#   'das',
#   'ns-regime',
#   'clausnitz',
#   'bautzen',
#   'deutschland',
#   'räumung',
#   'in',
#   'calais'],
#  ['refugeesnotwelcome',
#   'leyen',
#   'erklärt',
#   'deutschland',
#   'wird',
#   'fluechtlinge',
#   'asylanten',
#   'zu',
#   'soldaten',
#   'ausbilden',
#   'um',
#   'die',
#   'situation',
#   'in',
#   'syrien',
#   'nach',
#   'dem',
#   'krieg',
#   'zu',
#   'sichern',
#   'nichtwähler'],
#  ['macht',
#   'briefwahl',
#   'ist',
#   'einfach',
#   'und',
#   'schnell',
#   'krimigranten',
#   'rapefugees',
#   'stegner',
#   'augstein',
#   'simonepeter',
#   'gabriel',
#   'roth',
#   'künast',
#   'bei',
#   'allem',
#   'was',
#   'rechte',
#   'ausfressen',
#   'ist',
#   'die',
#   'afd',
#   'schuldsind',
#   'groko',
#   'u',
#   'grüne',
#   'dann',
#   'net',
#   'auch',
#   'für',
#   'die',
#   'verbrechen',
#   'ihrer',
#   'asylanten',
#   'verantwortlich'],
#  ['dank',
#   'merkel',
#   'mehr',
#   'asylanten',
#   'mehr',
#   'türken',
#   'mehr',
#   'ausgaben',
#   'türkei',
#   'kommt',
#   'in',
#   'eu'],
#  ['wir', 'verlieren', 'nur', 'noch', 'mit', 'merkel'],
#  ['cdu', 'abwahl'],
#  ['was',
#   'wurde',
#   'eigentlich',
#   'aus',
#   'der',
#   'geschichte',
#   'mit',
#   'den',
#   'syrischen',
#   'ärzten'],
#  ['die',
#   'rapefugees',
#   'sind',
#   'ja',
#   'wohl',
#   'wahrlich',
#   'keine',
#   'gynäkologen'],
#  ['der',
#   'deutsche',
#   'wurde',
#   'jahre',
#   'lang',
#   'dazu',
#   'erzogen',
#   'den',
#   'mund',
#   'zu',
#   'halten'],
#  ['schluss',
#   'damit',
#   'refugeesnotwelcome',
#   'wir',
#   'sind',
#   'das',
#   'volk',
#   'afd',
#   'merkelmussweg',
#   'pseudo',
#   'sturmwarnung',
#   'in',
#   'nrw',
#   'zum',
#   'schutz',
#   'deutscher',
#   'frauen',
#   'vor',
#   'rapefugees',
#   'um',
#   'jäger',
#   'den',
#   'arsch',
#   'zu',
#   'retten'],
#  ['düsseldorf',
#   'karneval',
#   'morgenmagazin',
#   'läßt',
#   'asylanten',
#   'auf',
#   'berlinale',
#   'israelfeindlichen',
#   'film',
#   'anschauen',
#   'und',
#   'die',
#   'finden',
#   'das',
#   'toll'],
#  ['einer', 'davon', 'lernt', 'schreiben', 'mit'],
#  ['betreuung',
#   'für',
#   'alle',
#   'der',
#   'rechtsanspruch',
#   'auf',
#   'einen',
#   'kitaplatz',
#   'gilt',
#   'auch',
#   'für',
#   'flüchtlingskinder',
#   'fluechtlingskrise',
#   'asylanten',
#   'fluechtlinge',
#   'hayali',
#   'will',
#   'asylanten',
#   'nach',
#   'spanien',
#   'abschieben',
#   'wo',
#   'über',
#   'arbeitslose',
#   'sind',
#   'und',
#   'eine',
#   'riesige',
#   'verschuldung'],
#  ['mein', 'tipp', 'grenzen', 'sichern'],
#  ['warum',
#   'spenden',
#   'grüne',
#   'cdu',
#   'und',
#   'spd',
#   'nicht',
#   'ihr',
#   'einkommen',
#   'für',
#   'asylanten'],
#  ['weil',
#   'sich',
#   'das',
#   'geld',
#   'anderer',
#   'menschen',
#   'leichter',
#   'ausgeben',
#   'läßt'],
#  ['schönborn', 'ist', 'eine', 'schande'],
#  ['er',
#   'huldigt',
#   'invasoren',
#   'welche',
#   'uns',
#   'christen',
#   'erbarmungslos',
#   'ermorden',
#   'wollen'],
#  ['rapefugees',
#   'christen',
#   'kirche',
#   'fpoe',
#   'wir',
#   'brauchen',
#   'einen',
#   'aufstand',
#   'der',
#   'anständigen',
#   'in',
#   'deutschland'],
#  ['abmerkeln',
#   'abschieben',
#   'grenzkontrollen',
#   'islamisierung',
#   'stoppen',
#   'ich',
#   'ziehe',
#   'revolution',
#   'dem',
#   'krieg',
#   'vor',
#   'zumindest',
#   'nehmen',
#   'an',
#   'der',
#   'revolution',
#   'nur',
#   'die',
#   'teil',
#   'die',
#   'wollen'],
#  ['marcel',
#   'proust',
#   'wehrdich',
#   'ia',
#   'stehauf',
#   'srfarena',
#   'svp',
#   'logik',
#   'minarette',
#   'in',
#   'der',
#   'schweiz',
#   'sind',
#   'gefährlich',
#   'waffen',
#   'für',
#   'den',
#   'scharia-staat',
#   'saudi-arabien',
#   'unbedenklich'],
#  ['diese',
#   'regierung',
#   'schützt',
#   'uns',
#   'vor',
#   'angeblichen',
#   'sturm',
#   'beim',
#   'rosenmontagszug',
#   'aber',
#   'nicht',
#   'vor',
#   'gang-rape',
#   'rapefugees',
#   'abmerkeln',
#   'fluechtlingskrise',
#   'die',
#   'anfängl.motivation',
#   'der',
#   'asylanten',
#   'sich',
#   'zu',
#   'integrieren',
#   'und',
#   'beruf',
#   'zu',
#   'lernen',
#   'wird',
#   'bald',
#   'nachlassen',
#   'wenn',
#   'sie',
#   'die',
#   'hohen',
#   'anforderungen',
#   'kennen'],
#  ['warum',
#   'sollten',
#   'weibliche',
#   'eindringlinge',
#   'eigentlich',
#   'in',
#   'ordnung',
#   'sein'],
#  ['irgendjemand', 'muss', 'die', 'brut', 'doch', 'aufgezogen', 'haben'],
#  ['rapefugees',
#   'verhaftungen',
#   'von',
#   'vergewaltigern',
#   'als',
#   'erfolg',
#   'zu',
#   'verkaufen',
#   'ist',
#   'das',
#   'aufmerksamkeitswinseln',
#   'einer',
#   'armseligen',
#   'behörde'],
#  ['polizei',
#   'köln',
#   'rapefugees',
#   'mit',
#   'jedem',
#   'tag',
#   'an',
#   'dem',
#   'anhänger',
#   'des',
#   'islam',
#   'nach',
#   'deutschland',
#   'strömen',
#   'ist',
#   'eine',
#   'weitere',
#   'etappe',
#   'der',
#   'islamisierung',
#   'erfolgt',
#   'islamistheproblem',
#   'afd',
#   'herrlich',
#   'deutsche',
#   'medien',
#   'berichten',
#   'der',
#   'hamburger',
#   'karnevalumzug',
#   'wurde',
#   'nicht',
#   'wegem',
#   'sturm',
#   'abgesagt',
#   'sondern',
#   'wegen',
#   'den',
#   'rapefugees',
#   'straftaten',
#   'gegen',
#   'asylanten',
#   'in',
#   'deutschland'],
#  ['straftaten', 'von', 'asylanten', 'in', 'einer', 'nacht', 'in', 'koeln'],
#  ['das',
#   'deutsche',
#   'nazi',
#   'pack',
#   'muss',
#   'sich',
#   'irgendwann',
#   'entscheiden'],
#  ['klappehalten',
#   'oder',
#   'mal',
#   'ernsthaften',
#   'widerstand',
#   'leisten.wirschaffendas',
#   'rapefugees',
#   'ich',
#   'dachte',
#   'dass',
#   'asylbewerber',
#   'in',
#   'deutschland',
#   'alle',
#   'kriegsflüchtlinge',
#   'sind'],
#  ['jeden',
#   'tag',
#   'stehen',
#   'algerier',
#   'marokkaner',
#   'und',
#   'afghanen',
#   'asylanten',
#   'sterntv',
#   'zeigt',
#   'die',
#   'realität',
#   'der',
#   'rente'],
#  ['manche',
#   'asylanten',
#   'lehnen',
#   'arbeit',
#   'ab',
#   'weil',
#   'sie',
#   'keine',
#   'netto',
#   'verdienen',
#   'wie',
#   'versprochen'],
#  ['stimmt', 'führen', 'wir', 'doch', 'die', 'scharia', 'ein'],
#  ['gäbe', 'bald', 'keine', 'wiederholungstäter', 'mehr', 'bei', 'diebstahl'],
#  ['srfarena',
#   'dsi',
#   'handab',
#   'unsere',
#   'regierung',
#   'hat',
#   'den',
#   'rotkäppchenkomplex',
#   'fütter',
#   'lieber',
#   'den',
#   'wolf',
#   'kriminelle',
#   'asylanten',
#   'als',
#   'die',
#   'großmutter',
#   'das',
#   'eigene',
#   'volk',
#   'merkel',
#   'cdu',
#   'friedlicher',
#   'karneval',
#   'und',
#   'nach',
#   'wie',
#   'vor',
#   'keine',
#   'islamisierung'],
#  ['läuft', 'bei', 'uns', 'mit', 'der', 'integration'],
#  ['da', 'erblassen', 'andere', 'länder', 'vor', 'neid'],
#  ['zib',
#   'wolf',
#   'heute',
#   'in',
#   'opernballmilde',
#   'keine',
#   'einzige',
#   'zeile',
#   'über',
#   'den',
#   'supervorteil',
#   'von',
#   'asylanten',
#   'schweinefleisch',
#   'für',
#   'alle',
#   'flüchtlinge',
#   'und',
#   'asylanten'],
#  ['wer',
#   'saufen',
#   'kann',
#   'und',
#   'kinder',
#   'vergewaltigen',
#   'braucht',
#   'keine',
#   'extra',
#   'wurst',
#   'fuck',
#   'refugges',
#   'asylpaket',
#   'endlich',
#   'beschlossene',
#   'sache',
#   'wir',
#   'werden',
#   'sehen',
#   'ob',
#   'damit',
#   'die',
#   'asylflut',
#   'eingedämmt',
#   'wird',
#   'flüchtlinge',
#   'flüchtlingspolitik',
#   'asylanten',
#   'islamisierung',
#   'wollen',
#   'wir',
#   'eigentlich',
#   'die',
#   'unübersehbar',
#   'stattfindende',
#   'islamisierung',
#   'deutschlands'],
#  ['oder', 'hat', 'pegida', 'nicht', 'doch', 'recht'],
#  ['bereicherung', 'durch', 'asylanten'],
#  ['sicherheitslage',
#   'in',
#   'deutschland',
#   'katastrophal',
#   'schlecht',
#   'asylchaos',
#   'abmerkeln',
#   'annewill',
#   'islamisierung',
#   'ist',
#   'gar',
#   'nicht',
#   'so',
#   'schlimm'],
#  ['habe',
#   'gerade',
#   'unterwerfung',
#   'gelesen',
#   'als',
#   'asylant',
#   'verkleidet',
#   'an',
#   'die',
#   'fasnacht',
#   'frauen',
#   'begrabschen',
#   'gehen'],
#  ['gesellschaftssatire', 'pur'],
#  ['fasnacht',
#   'satire',
#   'asylanten',
#   'wie',
#   'jetzt',
#   'gemäßigte',
#   'opposition',
#   'in',
#   'syrien',
#   'besteht',
#   'auch',
#   'aus',
#   'fudamentalisten',
#   'die',
#   'einen',
#   'gottesstaat',
#   'und',
#   'die',
#   'scharia',
#   'wollen'],
#  ['pestcholera', 'kinderfickende', 'schächtende', 'rapefugees'],
#  ['wer',
#   'kinder-',
#   'frauen-',
#   'oder',
#   'tierrechte',
#   'verteidigt',
#   'darf',
#   'nicht',
#   'gruene',
#   'spd',
#   'oder',
#   'cdu',
#   'wählen'],
#  ['ltwbw',
#   'in',
#   'baden-württemberg',
#   'gibts',
#   'jetzt',
#   'ne',
#   'extra',
#   'asylanten',
#   '-polizei'],
#  ['bisher',
#   'zu',
#   'viele',
#   'anzeigen/straftaten',
#   'zu',
#   'wenig',
#   'verhaftungen'],
#  ['asylantenheime',
#   'anzünden=verbrecherisch',
#   '-aber',
#   'einziges',
#   'augenmerk',
#   'auf',
#   'deutsche',
#   'straftäter',
#   '+nicht',
#   'auch',
#   'krimigranten',
#   'rapefugees',
#   '=nogo',
#   'merkel',
#   'läßt',
#   'deutschen',
#   'steuerzahler',
#   'bluten',
#   'für',
#   'syrien',
#   'algerien',
#   'marokko',
#   'tunesien',
#   'etc'],
#  ['und', 'bietet', 'mio', 'asylanten', 'all', 'incl'],
#  ['grandios',
#   'dumm',
#   'wann',
#   'stoppen',
#   'faymann',
#   'spö',
#   'und',
#   'mikl-leitner',
#   'övp',
#   'endlich',
#   'das',
#   'durchwinken',
#   'und',
#   'weiterschicken',
#   'von',
#   'asylanten',
#   'und',
#   'wirtschaftsflüchtlingen'],
#  ['scharia', 'in', 'deutschland'],
#  ['werden', 'die', 'kölner', 'kulturtänzer', 'demnächst', 'handlos'],
#  ['dann', 'berufsunfähige', 'frührentner'],
#  ['fragen',
#   'über',
#   'fragen',
#   'bei',
#   'aldi',
#   'verkaufen',
#   'sie',
#   'lachs',
#   'der',
#   'morgen',
#   'abläuft.im',
#   'asylanten-heim',
#   'gäbe',
#   'es',
#   'sowas',
#   'nicht'],
#  ['kinder', 'im', 'schwimmbad', 'edathy', 'gefällt', 'das'],
#  ['rapefugees', 'in', 'kölnbad', 'auch'],
#  ['die',
#   'linksgrün-versiffte',
#   'mischpoke',
#   'in',
#   'berlin',
#   'wird',
#   'sich',
#   'noch',
#   'wundern',
#   'wenn',
#   'die',
#   'rapefugees',
#   'im',
#   'sommer',
#   'so',
#   'richtig',
#   'abgehen'],
#  ['deustche',
#   'mädels',
#   'wird',
#   'sophienhof',
#   'wieder',
#   'zensiert',
#   'aus',
#   'den',
#   'twitter',
#   'trends'],
#  ['bloß',
#   'wieder',
#   'nicht',
#   'ansprechen',
#   'was',
#   'für',
#   'ein',
#   'scheiß',
#   'problem',
#   'auf',
#   'uns',
#   'zukommt',
#   'rapefugees',
#   'rapefugees',
#   'wieder',
#   'in',
#   'köln',
#   'aktiv'],
#  ['übergriffe', 'im', 'schwimmbad', 'in', 'zündorf'],
#  ['der',
#   'sommer',
#   'kann',
#   'kommen',
#   'koelnhbf',
#   'nolegida',
#   'flüchten',
#   'wo',
#   'andere',
#   'urlaub',
#   'machen'],
#  ['idomeni',
#   'refugeesnotwelcome',
#   'wie',
#   'kann',
#   'ich',
#   'wenn',
#   'alle',
#   'gegen',
#   'mich',
#   'sind',
#   'von',
#   'denen',
#   'verlangen',
#   'dass',
#   'sie',
#   'tun',
#   'was',
#   'ich',
#   'will'],
#  ['merkel',
#   'europäische',
#   'lösung',
#   'asylanten',
#   'asyl',
#   'schade',
#   'dass',
#   'heute',
#   'nicht',
#   'wahl',
#   'ist',
#   'sonst',
#   'würde',
#   'ich',
#   'nämluch',
#   'direkt',
#   'die',
#   'afd',
#   'wählen'],
#  ['refugeesnotwelcome',
#   'widerstand',
#   'rapefugees',
#   'laufen',
#   'sich',
#   'langsam',
#   'warm'],
#  ['kölnerin', 'wird', 'von', 'flüchtling', 'vergewaltigt'],
#  ['obergrenze',
#   'armlänge',
#   'alaaf',
#   'karneval',
#   'annewill',
#   'warum',
#   'gibt',
#   'es',
#   'in',
#   'europa',
#   'nicht',
#   'einheitliche',
#   'standarts',
#   'so',
#   'das',
#   'alle',
#   'asylanten',
#   'überall',
#   'selbe',
#   'leistung',
#   'bekommen'],
#  ['zu', 'einfach'],
#  ['stellt',
#   'lügenpresse',
#   'eigentl',
#   'schon',
#   'überlegungen',
#   'in',
#   'münchen',
#   'an',
#   'zur',
#   'nacktbadesaison',
#   'an',
#   'der',
#   'isar',
#   'und',
#   'flüchtlinge',
#   'primaten'],
#  ['hahahaha',
#   'rapefugees',
#   'frauen',
#   'die',
#   'sich',
#   'nicht',
#   'freiwillig',
#   'von',
#   'flüchtlingen',
#   'ficken',
#   'lassen',
#   'sind',
#   'sind',
#   'ein',
#   'verstoß',
#   'gegen',
#   'die',
#   'menschenwürde'],
#  ['hungerstreik',
#   'rapefugees',
#   'aller',
#   'asylanten',
#   'wollen',
#   'nur',
#   'deshalb',
#   'nach',
#   'd',
#   'weil',
#   'sie',
#   'nirgends',
#   'auf',
#   'der',
#   'welt',
#   'mehr',
#   'geld',
#   'bekommen'],
#  ['nebenbei', 'islamisieren'],
#  ['lanz',
#   'ihr',
#   'sollt',
#   'nicht',
#   'alle',
#   'nazis',
#   'an',
#   'den',
#   'taten',
#   'einiger',
#   'weniger',
#   'nazis',
#   'beurteilen',
#   'sagte',
#   'niemand'],
#  ['appeseament',
#   'islamisierung',
#   'taqqiya',
#   'viele',
#   'menschen',
#   'in',
#   'europa',
#   'fürchten',
#   'eine',
#   'islamisierung',
#   'berichtet',
#   'hartaberfair'],
#  ['migranten',
#   'deutschland',
#   'wird',
#   'asylanten',
#   'zu',
#   'sicherheitsbeamten',
#   'ausbilden',
#   'um',
#   'eine',
#   'perspektive',
#   'für',
#   'syrien',
#   'zu',
#   'schaffen',
#   'msc',
#   'fluechtlinge',
#   'beim',
#   'lasttweet',
#   'aufgefallen',
#   'dass',
#   'zuerst',
#   'refugeesnotwelcome',
#   'nicht',
#   'refugeeswelcome',
#   'vorgeschlagen',
#   'wird'],
#  ['könn', 'wir', 'das', 'ändern'],
#  ['followerpower',
#   'wer',
#   'die',
#   'islamisierung',
#   'bestreitet',
#   'dem',
#   'sei',
#   'ein',
#   'trip',
#   'in',
#   'arabisch',
#   'dominierte',
#   'viertel',
#   'in',
#   'london',
#   'empfohlen'],
#  ['hartaberfair',
#   'wer',
#   'will',
#   'überhaupt',
#   'immer',
#   'noch',
#   'kriminelle',
#   'asylanten',
#   'in',
#   'europa',
#   'aufnehmen'],
#  ['passverfälschung',
#   'schleuser',
#   'wo',
#   'ist',
#   'der',
#   'aufschrei',
#   'ausgruenden',
#   'belästigung',
#   'von',
#   'flüchtlingsfrauen',
#   'in',
#   'flüchtlingsheimen'],
#  ['könnt', 'wohl', 'nur', 'koelnhbf', 'u', 'rapefugees'],
#  ['städte-', 'und', 'gemeindebund', 'erwartet', 'mio', 'asylanten', 'in'],
#  ['es', 'wird', 'zeit', 'für', 'grenzsoldaten'],
#  ['merkel', 'amtsenthebung'],
#  ['die',
#   'frage',
#   'ist',
#   'warum',
#   'sehen',
#   'die',
#   'menschen',
#   'in',
#   'd',
#   'die',
#   'millionen',
#   'muslimischen',
#   'migranten',
#   'nicht',
#   'als',
#   'gefahr',
#   'im',
#   'sinne',
#   'einer',
#   'islamisierung',
#   'an'],
#  ['lanz',
#   'ich',
#   'staune',
#   'auch',
#   'mit',
#   'welcher',
#   'leidenschaft',
#   'die',
#   'islamisierung',
#   'in',
#   'deutschland',
#   'verteidigt',
#   'wird'],
#  ['langsam',
#   'nähern',
#   'sich',
#   'auch',
#   'die',
#   'cdu/spd-nahen',
#   'wirtschaftsinstitute',
#   'seriösen',
#   'prognosen',
#   'an',
#   'wonach',
#   'die',
#   'asylanten',
#   'mrd'],
#  ['pro', 'jahr', 'kosten'],
#  ['groko-regierung',
#   'hat',
#   'die',
#   'bürgerliche',
#   'mitte',
#   'schon',
#   'lange',
#   'verlassen'],
#  ['islamisierung',
#   'umerziehung',
#   'migrantenstadel',
#   'merkelmussweg',
#   'die',
#   'laufende',
#   'islamisierung',
#   'deutschlands',
#   'und',
#   'europas',
#   'macht',
#   'deutlich',
#   'wie',
#   'viel',
#   'wir',
#   'an',
#   'deutschland',
#   'und',
#   'europa',
#   'wirklich',
#   'hatten'],
#  ['wer',
#   'glaubst',
#   'du',
#   'finanziert',
#   'das',
#   'durchfüttern',
#   'zelte',
#   'bekleidung',
#   'der',
#   'armen',
#   'rapefugees',
#   'an',
#   'den',
#   'grenzen'],
#  ['glaubst', 'du', 'die', 'zahlen', 'für', 'irgend', 'was'],
#  ['wenn',
#   'leute',
#   'die',
#   'deutschland',
#   'hassen',
#   'immer',
#   'mehr',
#   'flüchtlinge',
#   'dorthin',
#   'holen',
#   'wollen',
#   'sind',
#   'das',
#   'dann',
#   'nicht',
#   'asylanten-hasser'],
#  ['alle', 'fluechtlinge', 'nach', 'gg', 'illegal', 'nach', 'art'],
#  ['a', 'nur', 'asylanten', 'eu', 'sichere', 'drittstaaten'],
#  ['naherosten',
#   'afrika',
#   'nicht',
#   'lieber',
#   'horst',
#   'seehofer',
#   'gibt',
#   'es',
#   'asylanten',
#   'die',
#   'besser',
#   'im',
#   'tierasyl',
#   'aufgehoben',
#   'wären'],
#  ['sz',
#   'faz',
#   'zeit',
#   'nzz',
#   'worauf',
#   'warten',
#   'diese',
#   'scheiss',
#   'flüchtlinge',
#   'und',
#   'asylanten',
#   'eigendlich'],
#  ['griechenland', 'europa', 'kein', 'kriegsland'],
#  ['stop', 'refugges', 'merkel', 'und', 'co', 'erwarten', 'flüchtlinge', 'in'],
#  ['am', 'anfang', 'waren', 'es'],
#  ['die', 'v', 'werden', 'ihr', 'druck', 'machen'],
#  ['islamisierung',
#   'nein',
#   'besser',
#   'als',
#   'schreckschusswaffe',
#   'gegen',
#   'rapefugees',
#   'wasserspritzpistole',
#   'gefüllt',
#   'mit',
#   'schweineblut',
#   '^^',
#   'extraunterkünfte',
#   'für',
#   'frauen',
#   'u',
#   'christen',
#   'um',
#   'sie',
#   'vor',
#   'den',
#   'asylanten',
#   'zu',
#   'schützen.wärs',
#   'net',
#   'besser',
#   'die',
#   'anderen',
#   'zu',
#   'separieren',
#   'im',
#   'flieger',
#   'nachhause',
#   'asylanten',
#   'eu',
#   'gipfel',
#   'ist',
#   'das',
#   'eine',
#   'merkel',
#   'show',
#   'die',
#   'nun',
#   'millarden',
#   'an',
#   'd.türkei',
#   'anweisen',
#   'will',
#   'u.',
#   'die',
#   'visumpflicht',
#   'auch',
#   'gleich',
#   'abschafft'],
#  ['annewill',
#   'wir',
#   'bekommen',
#   'keine',
#   'weimarer',
#   'republik',
#   'sondern',
#   'islamisierung',
#   'siehe',
#   'schweden',
#   'dt'],
#  ['kultur', 'weg', 'geldverschwendung'],
#  ['deutschland', 'den', 'deutschen'],
#  ['flüchtlinge',
#   'illegale',
#   'überfremdung',
#   'islamisierung',
#   'antigermanismus',
#   'widerstand',
#   'abmerkeln',
#   'remigration'],
#  ['klöckner', 'biegt', 'sich', 'die', 'wahrheit', 'zurecht'],
#  ['dank',
#   'merkel',
#   'haben',
#   'wir',
#   'millionen',
#   'asylanten',
#   'in',
#   'd.',
#   'auch',
#   'marokkaner'],
# ...
#   'd',
#   'beschleunigte+sozialsysteme',
#   'ruinierte'],
#  ['asylanten',
#   'wirtschaftsverbände',
#   'stehen',
#   'hinter',
#   'merkel-klar-pro',
#   'jahr+',
#   'mio',
#   'konsumenten.arbeit',
#   'billig.die',
#   'kasse',
#   'klingelt'],
#  ['bezahlung',
#   'garantiert',
#   'flüchtlinge',
#   '´asylanten',
#   'sind',
#   'perverse',
#   'kinderschänder',
#   'die',
#   'jeden',
#   'tag',
#   'in',
#   'deutschland',
#   'skrupelos',
#   'frauen',
#   'kinder',
#   'vergewaltigen'],
#  ['ist',
#   'eine',
#   'klare',
#   'aussage',
#   'und',
#   'bedarf',
#   'weder',
#   'einer',
#   'erklärung',
#   'noch',
#   'einer',
#   'begründung'],
#  ['rapefugees',
#   'köln',
#   'hamburg',
#   'kiel',
#   'visafreiheit',
#   'mit',
#   'türkei',
#   'bringt',
#   'uns',
#   'hunderttausende',
#   'neue',
#   'asylanten.erdogan',
#   'zerbombt',
#   'kurdengebiete',
#   'damit',
#   'sie',
#   'nach',
#   'd',
#   'fliehen.merkel',
#   'versagt',
#   'dt'],
#  ['umfrage',
#   'machen',
#   'und',
#   'fragen',
#   'was',
#   'pegida',
#   'heißt.wie',
#   'wissen',
#   'was',
#   'es',
#   'und',
#   'gegen',
#   'islamisierung',
#   'heißt'],
#  ['deutsche', 'aufwachen'],
#  ['bei',
#   'jedem',
#   'auftritt',
#   'eines',
#   'asylanten',
#   'oder',
#   'migranten',
#   'kommt',
#   'diese',
#   'gespielte',
#   'hysterie',
#   'der',
#   'sozis'],
#  ['die', 'realisieren', 'so', 'langsam', 'ihren', 'machtverlust'],
#  ['gesetzesvorschlag',
#   'vasektomie',
#   'als',
#   'strafe',
#   'für',
#   'vergewaltiger',
#   'rapefugees',
#   'refugees',
#   'vergewaltigung',
#   'rape',
#   'hartaberfair',
#   'oh',
#   'mann',
#   'ich',
#   'glaubs',
#   'einfach',
#   'nicht.wann',
#   'wacht',
#   'd',
#   'endlich',
#   'auf'],
#  ['völlig', 'isoliert.alle', 'habens', 'kapiert', 'islamisierung', 'stoppen'],
#  ['hallo', 'hessen'],
#  ['geht',
#   'zur',
#   'kommunalwahl',
#   'stimmt',
#   'für',
#   'eure',
#   'heimat',
#   'deutschland',
#   'afd',
#   'widerstand',
#   'fluechtlinge',
#   'stoppt',
#   'merkel',
#   'islamisierung',
#   'die',
#   'nato',
#   'das',
#   'militärbündnis',
#   'prüft',
#   'einen',
#   'einsatz',
#   'gegen',
#   'schlepper'],
#  ['flüchtlinge',
#   'rapefugees',
#   'einzelfall',
#   'krimigranten',
#   'whitegenocide',
#   'annewill',
#   'die',
#   'merkel',
#   'schafft',
#   'sich',
#   'ab'],
#  ['sie', 'labert', 'nur', 'mist'],
#  ['refugees',
#   'refugeesnotwelcome',
#   'refugeesgohome',
#   'merkelmussweg',
#   'rapefugees',
#   'raus',
#   'aus',
#   'preußen'],
#  ['von',
#   'einem',
#   'turkmenen',
#   'sexuell',
#   'missbraucht',
#   'x-mal',
#   'minderjährige',
#   'mädchen',
#   'von',
#   'rapefugees',
#   'sexuell',
#   'belästigt'],
#  ['islam',
#   'sophienhof',
#   'hjartaberfair',
#   'österreich',
#   'will',
#   'sozialsysteme',
#   'mit',
#   'asylanten',
#   'nicht',
#   'überlasten'],
#  ['korrekt',
#   'was',
#   'd',
#   'nicht',
#   'begreift',
#   'und',
#   'bürgern',
#   'schadet',
#   'diebstahl',
#   'einbruch',
#   'sexuelle',
#   'übergriffe',
#   'v.',
#   'migranten',
#   '-wird',
#   'verschwiegen',
#   'nicht',
#   'bestraft',
#   '-bei',
#   'scharia',
#   'wird',
#   'bei',
#   'diebstahl',
#   'hand',
#   'abschlagen',
#   'bayern',
#   'droht',
#   'imamen',
#   'bei',
#   'werbung',
#   'für',
#   'scharia',
#   'und',
#   'gegen',
#   'verfassung',
#   'bis',
#   'euro',
#   'bußgeld'],
#  ['csu',
#   'fluechtlinge',
#   'gute',
#   'opfer',
#   'von',
#   'krimigranten',
#   'rapefugees',
#   'zeigen',
#   'straftaten',
#   'nicht',
#   'an'],
#  ['das', 'würde', 'nur', 'den', 'rechten', 'nützen'],
#  ['nur', 'als', 'tip', 'für', 'die', 'gutmenschen'],
#  ['wer', 'millionen', 'asylanten', 'will', 'wählt', 'links'],
#  ['wer', 'nicht', 'afd'],
#  ['und', 'cdu'],
#  ['hm',
#   'kann',
#   'man',
#   'millionen',
#   'asylanten',
#   'gleichzeitig',
#   'wollen',
#   'und',
#   'nicht',
#   'wollen'],
#  ['kaum',
#   'kommen',
#   'weniger',
#   'invasoren',
#   'über',
#   'die',
#   'balkanroute',
#   'schon',
#   'dürfen',
#   'mio',
#   'muslime',
#   'aus',
#   'der',
#   'türkei',
#   'ohne',
#   'visum',
#   'rein',
#   'in',
#   'die',
#   'eu'],
#  ['islamisierung',
#   'fluechtling',
#   'was',
#   'macht',
#   'eigentlich',
#   'der',
#   'araber',
#   'in',
#   'der',
#   'sache'],
#  ['er', 'will', 'die', 'asylanten', 'nicht', 'haben'],
#  ['aber', 'wir', 'sollen', 'sie', 'sollen', 'wir', 'aufnehmen'],
#  ['ab',
#   'jetzt',
#   'heißt',
#   'es',
#   'nicht',
#   'mehr',
#   'leben',
#   'sondern',
#   'überleben',
#   'köln',
#   'kiel',
#   'rapefugees',
#   'es',
#   'scheint',
#   'als',
#   'steigt',
#   'die',
#   'zahl',
#   'patriotischer',
#   'europäer',
#   'die',
#   'keinen',
#   'bock',
#   'auf',
#   'islamisierung',
#   'haben'],
#  ['eigentlich', 'alle', 'außer', 'merkel-deutschland'],
#  ['bestätigte',
#   'sexualdelikte',
#   'von',
#   'rapefugees',
#   'sind',
#   'viel',
#   'zu',
#   'brisant',
#   'siehe',
#   'vergewaltigungsrate',
#   'schweden',
#   'deswegen',
#   'lieber',
#   'hoax',
#   'für',
#   'honks'],
#  ['abmerkeln',
#   'is-sympathisant',
#   'aus',
#   'darmstadt',
#   'werbe-video',
#   'für',
#   'terrormiliz',
#   '-für',
#   'derart',
#   'gnadenlose',
#   'mitbürger',
#   'd.v'],
#  ['ihnen',
#   'gewünschte',
#   'scharia',
#   'anwenden',
#   'immer',
#   'sehr',
#   'lustig',
#   'wenn',
#   'pegida',
#   'als',
#   'fremdenfeindlich',
#   'dargestellt',
#   'wird'],
#  ['für',
#   'alle',
#   'linken',
#   'steinewerfer',
#   'pegida',
#   'ist',
#   'gegen',
#   'die',
#   'islamisierung'],
#  ['asylanten',
#   'wollen',
#   'die',
#   'eu',
#   'fluten.und',
#   'ich',
#   'bin',
#   'sicher',
#   'alle',
#   'flüchtlinge',
#   'auf',
#   'der',
#   'welt',
#   'machen',
#   'sich',
#   'stück',
#   'für',
#   'stück',
#   'auf',
#   'den',
#   'weg'],
#  ['mio.afd',
#   'cdu',
#   'also',
#   'die',
#   'fasnacht',
#   'in',
#   'diesem',
#   'jahr',
#   'geht',
#   'in',
#   'die',
#   'geschichtsbücher',
#   'ein',
#   'soviele',
#   'rapefugees',
#   'wie',
#   'noch',
#   'nie',
#   'gehören',
#   'alle',
#   'kastriert',
#   'wer',
#   'mit',
#   'dem',
#   'begriff',
#   'rapefugees',
#   'hetze',
#   'gleichsetzt',
#   'will',
#   'einfach',
#   'nur',
#   'realität',
#   'verdrängen',
#   'oder',
#   'bewusst',
#   'totschweigen'],
#  ['solidaritätmitkolja',
#   'clausnitz',
#   'erinnert',
#   'immer',
#   'mehr',
#   'an',
#   'handgranate',
#   'u',
#   'lageso-toten.asylanten',
#   'provozieren',
#   'niemand',
#   'kommt',
#   'zu',
#   'schaden',
#   'besorgtegutmenschen',
#   'heulen',
#   'wer',
#   'spd',
#   'und',
#   'grüne',
#   'wählt',
#   'bekommt',
#   'islam',
#   'und',
#   'scharia',
#   'in',
#   'deutschland',
#   'und',
#   'islamisten',
#   'tolerieren',
#   'keine',
#   'minderheiten',
#   'daher',
#   'afd',
#   'liebe',
#   'frau',
#   'merkel',
#   'die',
#   'aufforderung',
#   'asylanten',
#   'unbegrenzt',
#   'aufnehmen',
#   'zu',
#   'wollen',
#   'wird',
#   'sich',
#   'im',
#   'laufe',
#   'der',
#   'zeit',
#   'rächennee',
#   'nicht',
#   'mit',
#   'mir',
#   'war',
#   'grade',
#   'wieder',
#   'ein',
#   'hart',
#   'verdienten',
#   'kaffee',
#   'an',
#   'ner',
#   'tankstelle',
#   'trinken',
#   'da',
#   'kamen',
#   'gut',
#   'gebaute',
#   'asylanten',
#   'rein',
#   'und',
#   'kauften',
#   'bier',
#   'und',
#   'zigaretten',
#   'w',
#   'i',
#   'd',
#   'e',
#   'r',
#   's',
#   't',
#   'a',
#   'n',
#   'd',
#   'g',
#   'e',
#   'g',
#   'e',
#   'n',
#   'i',
#   's',
#   'l',
#   'a',
#   'm',
#   'i',
#   's',
#   'i',
#   'e',
#   'r',
#   'u',
#   'n',
#   'g',
#   'bautzen',
#   'clausnitz',
#   'rapefugees',
#   'cologne',
#   'koelnhbf',
#   'germany',
#   'noislam',
#   'sos',
#   'was',
#   'würden',
#   'gutmenschen',
#   'sagen',
#   'wenn',
#   'christen/europäer',
#   'massenweise',
#   'nach',
#   'arabien',
#   'einwandern',
#   'würden'],
#  ['islamisierung',
#   'koelnhbf',
#   'gab',
#   'es',
#   'opferbashing',
#   'clausnitz',
#   'gibt',
#   'es',
#   'mitleid',
#   'und',
#   'clausnitz',
#   'schöne',
#   'wohnungen',
#   'für',
#   'asylanten'],
#  ['das',
#   'ist',
#   'deutschland',
#   'eu-kommission',
#   'wertet',
#   'die',
#   'asylanten-obergrenzen',
#   'österreichs',
#   'als',
#   'illegal'],
#  ['spö-övp-bundesregierung', 'ignoriert', 'eu-recht'],
#  ['bevölkerung', 'arbeitet', 'für', 'die', 'musl.migr.', 'damit', 'dt'],
#  ['wirtschaft',
#   'druck',
#   'auf',
#   'reallöhne',
#   'aufrechterhalten',
#   'kann.islamisierung',
#   'wird',
#   'akzeptiert'],
#  ['bin',
#   'gester',
#   'asylanten',
#   'begegnet',
#   'beide',
#   'voll',
#   'bis',
#   'oben',
#   'hin',
#   'kamen',
#   'aus',
#   'afghanistan',
#   'saufen',
#   'scheinbar',
#   'täglich',
#   'gegen',
#   'die',
#   'langeweile',
#   'fluechtlinge',
#   'und',
#   'ich',
#   'garantiere',
#   'man',
#   'kann',
#   'auf',
#   'dauer',
#   'keine',
#   'wohnortpflicht',
#   'für',
#   'asylanten',
#   'in',
#   'deutschland',
#   'vorschreiben.völliger',
#   'unsinn',
#   'und',
#   'nur',
#   'kosmetik.afd',
#   'tränengas',
#   'gegen',
#   'flüchtlinge',
#   'ob',
#   'man',
#   'es',
#   'in',
#   'imzentrum',
#   'oder',
#   'hier',
#   'benutzt',
#   'dank',
#   'rapefugees',
#   'da',
#   'gibts',
#   'keinen',
#   'unterschied',
#   'benehmen',
#   'sich',
#   'nicht',
#   'in',
#   'deutschland',
#   'kostet',
#   'die',
#   'betreuung',
#   'eines',
#   'unbegleiteten',
#   'minderjährigen',
#   'asylanten',
#   'je',
#   'nach',
#   'bundesland',
#   'zwischen'],
#  ['im',
#   'jahr',
#   'ltwbw',
#   'die',
#   '..',
#   'einheimischen',
#   'die',
#   'in',
#   'österreich',
#   'an',
#   'der',
#   'armutsgrenze',
#   'leben',
#   'dürfen',
#   'nicht',
#   'durch',
#   'die',
#   'integration',
#   'der',
#   'asylanten',
#   'geopfert',
#   'werden'],
#  ['die', 'tussi', 'war', 'voll', 'naiv'],
#  ['nimmt',
#   'südländische',
#   'männer',
#   'im',
#   'auto',
#   'über',
#   'die',
#   'grenze',
#   'wundert',
#   'sich',
#   'dann',
#   'das',
#   'es',
#   'illegale',
#   'asylanten',
#   'sind'],
#  ['domian', 'cdu', 'will', 'mindestlohn', 'für', 'asylanten', 'aussetzen'],
#  ['dann',
#   'nehmen',
#   'asylanten',
#   'deutschen',
#   'arbeit',
#   'weg',
#   'weil',
#   'sie',
#   'billig',
#   'sind'],
#  ['afd', 'wählen'],
#  ['merkelmussweg',
#   'asylanten',
#   'sonntagsstammtisch',
#   'stückl',
#   'wir',
#   'müssen',
#   'das',
#   'schaffen'],
#  ['frage', 'was', 'und', 'warum', 'ist', 'zu', 'schaffen'],
#  ['islamisierung', 'der', 'brd', 'oder', 'was'],
#  ['ahaa',
#   'jetzt',
#   'auf',
#   'einmal',
#   'sind',
#   'flüchtlinge',
#   'doch',
#   'ein',
#   'potentielles',
#   'risiko',
#   'für',
#   'die',
#   'wirtschaft',
#   'neben',
#   'dem',
#   'brexit',
#   'eudssr',
#   'brddr',
#   'rapefugees',
#   'merkel',
#   'hat',
#   'keinen',
#   'plan',
#   'b',
#   'sagt',
#   'sie',
#   'bei',
#   'annewill'],
#  ['vielleicht',
#   'wäre',
#   'plan',
#   'b',
#   'endlich',
#   'mal',
#   'realpolitik',
#   'in',
#   'fragen',
#   'asylanten',
#   'flüchtlinge',
#   'zu',
#   'machen',
#   'eu',
#   'grüne',
#   'wollen',
#   'europa',
#   'mit',
#   'asylanten',
#   'fluten',
#   'und',
#   'steuerzahler',
#   'ausbluten',
#   'lassen'],
#  ['diese', 'partei', 'gehört', 'verboten'],
#  ['kein',
#   'fußball',
#   'den',
#   'faschisten',
#   'aber',
#   'auch',
#   'keine',
#   'regierung',
#   'für',
#   'idioten.kritiker',
#   'einer',
#   'islamisierung',
#   'als',
#   'nazis',
#   'diffamieren',
#   'ist',
#   'linksfaschismus',
#   'anstatt',
#   'man',
#   'milliarden',
#   'gegen',
#   'die',
#   'armut',
#   'in',
#   'deutschland',
#   'einsetzt',
#   'steckt',
#   'man',
#   'lieber',
#   'den',
#   'asylanten',
#   'und',
#   'd.türkei',
#   'das',
#   'geld',
#   'in',
#   'den',
#   'arsch'],
#  ['schuldige',
#   'an',
#   'dem',
#   '„',
#   'flüchtlingsdrama',
#   '“',
#   'konnte',
#   'endlich',
#   'identifiziert',
#   'werden',
#   'die',
#   'russen',
#   'sind',
#   'schuld',
#   'sagt',
#   'merkel'],
#  ['asylanten',
#   'merkel',
#   'brd',
#   'flüchtlinge',
#   'asylanten',
#   'stop',
#   'köln',
#   'vergewaltigungen',
#   'aufschrei',
#   'kriminalität',
#   'cdu',
#   'spd',
#   'merkel',
#   'weg',
#   'wahl',
#   'afd',
#   'grenzen',
#   'zu',
#   'lügenpresse',
#   'asylpaket',
#   'alles',
#   'pseudo',
#   'vorschläge',
#   'um',
#   'die',
#   'kommenden',
#   'wahlen',
#   'zu',
#   'beeinflussenmerkel',
#   'mehr',
#   'schein',
#   'als',
#   'sein'],
#  ['asylanten', 'sterntv', '..', 'soeben', 'sofort', 'weggezappt'],
#  ['lügensendung', 'hoch'],
#  ['sachsen', 'wissen', 'was', 'sie', 'tun'],
#  ['refugeesnotwelcome', 'es', 'gibt', 'keine', 'alternative', 'zur', 'afd'],
#  ['die', 'afd', 'ist', 'die', 'einzige', 'alternative'],
#  ['fluechtlinge',
#   'koelnhbf',
#   'islamisierung',
#   'die',
#   'industrie',
#   'hofft',
#   'ja',
#   'immer',
#   'noch',
#   'auf',
#   'den',
#   'facharbeiter',
#   'unter',
#   'den',
#   'refugees'],
#  ['ja', 'die', 'hoffnung', 'stirbt', 'zuletzt'],
#  ['refugeesnotwelcome',
#   'annewill',
#   'ja',
#   'kriminalität',
#   'von',
#   'rapefugees',
#   'wird',
#   'natürlich',
#   'mit',
#   'einem',
#   'satz',
#   'behandelt'],
#  ['thema', 'erledigt.kriminalität', 'ist', 'ja', 'auch', 'nur', 'explodiert'],
#  ['altparteien', 'kommt', 'sturm', 'an', 'rosenmontag', 'wie', 'gerufen'],
#  ['lässt',
#   'sich',
#   'gut',
#   'als',
#   'vorwand',
#   'verkaufen',
#   'da',
#   'es',
#   'sonst',
#   'weitere',
#   'rapefugees',
#   'fälle',
#   'gäbe'],
#  ['afd',
#   'eine',
#   'alte',
#   'schachtel',
#   'zeigt',
#   'freundliches',
#   'gesicht',
#   'damit',
#   'horden',
#   'von',
#   'rapefugees',
#   'ihre',
#   'hässlichen',
#   'gesichter',
#   '-oder',
#   'andere',
#   'körperteile-',
#   'zeigen.kiel',
#   'die',
#   'geschichte',
#   'wird',
#   'merkel',
#   'recht',
#   'geben',
#   'falsch',
#   'die',
#   'geschichte',
#   'wird',
#   'über',
#   'merkel',
#   'richten'],
#  ['abferkeln',
#   'refugeesnotwelcome',
#   'die',
#   'täter',
#   'des',
#   'kieler-mobs',
#   'haben',
#   'die',
#   'bisherige',
#   'höchststrafe',
#   'bekommen',
#   'hausverbot'],
#  ['kiel', 'rapefugees', 'flüchtlinge', 'dasduell'],
#  ['göring-eckardt', 'will', 'mio', 'neue', 'asylanten'],
#  ['kauder', 'auch'],
#  ['schwarz', 'grün', 'im', 'vormarsch'],
#  ['prost', 'mahlzeit'],
#  ['afd',
#   'wirkt',
#   'sexuallkunde',
#   'für',
#   'flüchtlinge',
#   'und',
#   'migranten',
#   'mama',
#   'merkel',
#   'bringt',
#   'asylanten',
#   'das',
#   'ficken',
#   'bei',
#   'vergewaltigungen',
#   'funktionieren',
#   'bereits',
#   'zwei',
#   'dutzend',
#   'männer',
#   'eine',
#   'übliche',
#   'anzahl',
#   'für',
#   'muslimische',
#   'rape',
#   'gangs',
#   'über',
#   'ungläubige',
#   'schlampen',
#   'herzufallen.rapejihad',
#   'rotherham',
#   'rapefugees',
#   'vorhin',
#   'hat',
#   'jemand',
#   'gefragt',
#   'wie',
#   'es',
#   'mit',
#   'der',
#   'islamisierung',
#   'deutschlands',
#   'wohl',
#   'noch',
#   'weitergeht'],
#  ['na', 'erdogan', 'wird', 'auch', 'noch', 'bundeskanzler'],
#  ['schweizer',
#   'firmenchefin',
#   'verlangt',
#   'das',
#   'man',
#   'asylanten',
#   'einstellt'],
#  ['klar',
#   'auf',
#   'schweizer',
#   'mit',
#   'chf',
#   'lohn',
#   'kann',
#   'man',
#   'asylanten',
#   'für',
#   'k',
#   'anstellen',
#   'merkel',
#   'lässt',
#   'sich',
#   'heute',
#   'wieder',
#   'von',
#   'annewill',
#   'i.d'],
#  ['ard', 'präsentieren'],
#  ['unwidersprochen',
#   'darf',
#   'sie',
#   'ihre',
#   'verfehlte',
#   'asylanten-poltik',
#   'verbreiten'],
#  ['also',
#   'ich',
#   'finde',
#   'europa',
#   'ist',
#   'sich',
#   'einig',
#   'wie',
#   'noch',
#   'nie',
#   'refugeesnotwelcome',
#   'eine',
#   'tanzt',
#   'dabei',
#   'aus',
#   'der',
#   'reihe',
#   'und',
#   'merkelt',
#   'sich',
#   'gerade',
#   'ab'],
#  ['dieanstalt',
#   'flüchtlinge',
#   'und',
#   'asylanten',
#   'benötigen',
#   'schwimmpass',
#   'bei',
#   'grenzübertritt',
#   'rückführung',
#   'übers',
#   'mittelmeer',
#   'geplant',
#   'muhaaaa',
#   'die',
#   'regierung',
#   'hat',
#   'nichts',
#   'im',
#   'griff'],
#  ['das',
#   'gibt',
#   'hoffentlich',
#   'ein',
#   'denkzettel',
#   'bei',
#   'den',
#   'nächsten',
#   'wahlen'],
#  ['refugees',
#   'refugeesnotwelcome',
#   'abmerkeln',
#   'das',
#   'gerechte',
#   'in',
#   'deutschland',
#   'ist',
#   'ja',
#   'dass',
#   'nicht',
#   'nur',
#   'juden',
#   'sondern',
#   'auch',
#   'christen',
#   'verfolgt',
#   'werden'],
#  ['wirschaffendas',
#   'merkel',
#   'islamisierung',
#   'radikaler',
#   'imam',
#   'in',
#   'dänemark',
#   'ruft',
#   'z',
#   'steinigung',
#   'v',
#   'frauen',
#   'auf',
#   '-was',
#   'wäre',
#   'riefen',
#   'wir',
#   'auf',
#   'alle',
#   'imame',
#   'in',
#   'europa',
#   'nach',
#   'scharia',
#   'zu',
#   'steinigen'],
#  ['wo', 'ist', 'das', 'problem'],
#  ['für',
#   'moslems',
#   'ist',
#   'es',
#   'doch',
#   'schon',
#   'legal',
#   'makerapelegal',
#   'rapefugees',
#   'simone',
#   'peter',
#   'hat',
#   'seit',
#   'monaten',
#   'und',
#   'weit',
#   'über',
#   'mio'],
#  ['asylanten',
#   'noch',
#   'keinerlei',
#   'konzept',
#   'wie',
#   'der',
#   'zuzug',
#   'begrenzt',
#   'werden',
#   'kann'],
#  ['berlindirekt', 'bin', 'gespannt', 'auf', 'onebillionrising'],
#  ['hoffentlich',
#   'hat',
#   'den',
#   'rapefugees',
#   'keiner',
#   'gesteckt',
#   'daß',
#   'es',
#   'dort',
#   'ordentlich',
#   'grabschmaterial',
#   'gibt'],
#  ['kipping', 'ist', 'so', 'dumm'],
#  ['wenn',
#   'asylanten',
#   'wohnungen',
#   'kriegen',
#   'verpflegung',
#   'all',
#   'incl',
#   'taschengeld',
#   'krankenkarte',
#   'für',
#   'umme',
#   'kommen',
#   'immer',
#   'mehr'],
#  ['cdu',
#   'wähler',
#   'aus',
#   'mea',
#   'marodieren',
#   'auf',
#   'merkels',
#   'wunsch',
#   'mordend',
#   'u',
#   'vergewaltigend',
#   'durchs',
#   'land',
#   'aber',
#   'eine',
#   'islamisierung',
#   'findet',
#   'nicht',
#   'statt']]

# %%
hatespeech2=""

with open("hatespeech/posts.csv") as csvdatei:
    csv_reader_object = csv.reader(csvdatei, delimiter=",")
    csv_hate = list(csv_reader_object)[1:]
    for row in csv_hate:
        x = row[2]
        x = re.sub(r"http\S+|\.\.+|\S+\/\/+|www\S+|\d+|@[A-Za-z0-9]+","", x)
        x+="."
        x = x.lower()
       
        hatespeech2 += " " + x

# %%
hatespeech2 = clean(hatespeech2)

# %%
hatespeech2
# Out:
# [['tja', 'das', 'ergebniss', 'ungebremsten', 'zuzug'],
#  ['-jähriger', 'tschetschene', 'bei', 'der', 'ein', '-jähriger', 'tja'],
#  ['zu',
#   'wilden',
#   'straßenkämpfen',
#   'zwischen',
#   'volksgruppen',
#   'aus',
#   'afghanistan',
#   'und',
#   'tschetschenien',
#   'ausgetragen',
#   'mit',
#   'messern',
#   'sowie',
#   'autos',
#   'als',
#   'rammböcken'],
#  ['manche',
#   'sünden',
#   'bestraft',
#   'der',
#   'herrgott',
#   'sofort',
#   'lol',
#   'heissts'],
#  ['genau', 'lesen'],
#  ['hmmmmmm', 'und', 'die', 'wollen', 'nach', 'europa/christliches', 'land'],
#  ['anführer', 'des', 'inneren', 'kerns', 'war', 'ein', 'jähriger', 'russe'],
#  ['stellt', 'euch', 'vor', 'es', 'wären', 'eure', 'eltern'],
#  ['fünf', 'serben', 'ein', 'mazedonier'],
#  ['von', 'wo', 'kommt', 'der', 'blos', 'her'],
#  ['tippt', 'mal'],
#  ['acht',
#   'jahre',
#   'lang',
#   'soll',
#   'er',
#   'bezog',
#   'notstandshilfe',
#   'als',
#   'türkisch-',
#   'österreichischen',
#   'kulturverein',
#   'ja',
#   'wehe',
#   'man',
#   'sagt',
#   'was',
#   'dann',
#   'ist',
#   'man',
#   'gleich',
#   'ausländerfeindlich',
#   'nazi',
#   'und',
#   'sonnstige',
#   'blödheiten',
#   'bekommt',
#   'man',
#   'an',
#   'den',
#   'kopf',
#   'geworfen'],
#  ['türkische',
#   'bande',
#   'verübte',
#   'einbrüche',
#   'tschetschenische',
#   'bande',
#   'ging',
#   'auf',
#   'wehrlose',
#   'opfer',
#   'los',
#   '/das',
#   'ist',
#   'arbeitsteilung',
#   'nochwas',
#   'dazu',
#   'typisch',
#   'für',
#   'ein',
#   'marxistisches',
#   'system',
#   'ist',
#   'es',
#   'kriminelle',
#   'zu',
#   'schonen',
#   'aber',
#   'politische',
#   'gegner',
#   'als',
#   'kriminelle',
#   'zu',
#   'behandeln',
#   'zitat',
#   'alexander',
#   'solschenizyn'],
#  ['gehen',
#   'wir',
#   'mal',
#   'nen',
#   'halbmond',
#   'runterreissen',
#   'na',
#   'da',
#   'wär',
#   'was',
#   'los'],
#  ['zum',
#   'posting',
#   'von',
#   'vor',
#   'tagen',
#   'um',
#   'die',
#   'immer',
#   'weiter',
#   'voranschreitende',
#   'islamisierung',
#   'seiner',
#   'stadt',
#   'zu',
#   'dokumentieren',
#   'ließ',
#   'ein',
#   'französischer',
#   'bürgermeister',
#   'den',
#   'moslemanteil',
#   'an',
#   'den',
#   'schulkindern',
#   'zählen'],
#  ['und', 'er', 'kam', 'dabei', 'auf'],
#  ['dafür',
#   'wird',
#   'er',
#   'nun',
#   'von',
#   'der',
#   'politischen',
#   'und',
#   'medialen',
#   'elite',
#   'als',
#   'rassist',
#   'gescholten',
#   'und',
#   'muss',
#   'mit',
#   'einer',
#   'anklage',
#   'rechnen'],
#  ['merke', 'das', 'dokumentieren', 'der', 'islamisierung', 'ist'],
#  ['der', 'täter', 'semun', 'a'],
#  ['†',
#   'ein',
#   'türkischstämmiger',
#   'schweizer',
#   'aus',
#   'reichenburg',
#   'die',
#   'linken',
#   'medien',
#   'schreiben',
#   'schweizer',
#   'tssss'],
#  ['eigenen',
#   'aussagen',
#   'in',
#   'der',
#   'praxis',
#   'studiert',
#   'und',
#   'hält',
#   'deshalb',
#   'die',
#   'heimischen',
#   'integrationspolitik',
#   'für',
#   'gescheitert',
#   'dritte',
#   'generation',
#   'schlechter',
#   'integriert',
#   'als',
#   'erste',
#   'seine',
#   'erfahrungen',
#   'mit',
#   'den',
#   'jungen',
#   'klienten',
#   'hätten',
#   'gezeigt',
#   'dass',
#   'die',
#   'von',
#   'sozialromantikern',
#   'vertretene',
#   'these',
#   'dass',
#   'sich',
#   'die',
#   'menschen',
#   'von',
#   'generation',
#   'zu',
#   'generation',
#   'automatisch',
#   'besser',
#   'integrieren',
#   'nicht',
#   'stimme'],
#  ['wer',
#   'das',
#   'heute',
#   'behauptet',
#   'sei',
#   'naiv',
#   'und',
#   'lebensfremd',
#   'so',
#   'mayer'],
#  ['die',
#   'alten',
#   'gastarbeiter',
#   'die',
#   'ihr',
#   'ganzes',
#   'leben',
#   'für',
#   'ihre',
#   'kinder',
#   'gehackelt',
#   'haben',
#   'das',
#   'sind',
#   'die',
#   'vorzeigemigranten'],
#  ['so',
#   'mancher',
#   'enkel',
#   'fährt',
#   'trotzdem',
#   'nach',
#   'syrien',
#   'kämpfen',
#   'oder',
#   'geht',
#   'rauben',
#   'weil',
#   'der',
#   'kodex',
#   'von',
#   'ehre',
#   'stolz',
#   'und',
#   'kampf',
#   'der',
#   'in',
#   'den',
#   'parks',
#   'gepredigt',
#   'wird',
#   'wichtiger',
#   'ist',
#   'als',
#   'das',
#   'wort',
#   'seiner',
#   'mutter',
#   'oder',
#   'seines',
#   'großvaters'],
#  ['ich',
#   'erlebe',
#   'die',
#   'dritte',
#   'generation',
#   'als',
#   'schlechter',
#   'integriert',
#   'als',
#   'die',
#   'erste'],
#  ['und',
#   'wenn',
#   'sich',
#   'nur',
#   'ein',
#   'prozent',
#   'radikalisiert',
#   'haben',
#   'wir',
#   'ein',
#   'riesiges',
#   'problem',
#   'so',
#   'der',
#   'jurist',
#   'im',
#   'gespräch',
#   'mit',
#   'der',
#   'wiener',
#   'zeitung'],
#  ['und',
#   'er',
#   'warnt',
#   'wenn',
#   'wir',
#   'es',
#   'uns',
#   'weiter',
#   'so',
#   'leicht',
#   'machen',
#   'werden',
#   'wir',
#   'von',
#   'der',
#   'problematik',
#   'erdrückt'],
#  ['was', 'passiert', 'nun', 'mit', 'dem'],
#  ['zu',
#   'dem',
#   'nur',
#   'männer',
#   'und',
#   'wo',
#   'haben',
#   'all',
#   'die',
#   'armen',
#   'das',
#   'geld',
#   'zum',
#   'flüchten',
#   'her'],
#  ['es', 'stinkt', 'alles'],
#  ['wie', 'kommen', 'die', 'an', 'dieses', 'geld'],
#  ['angeblich',
#   'haben',
#   'sie',
#   'nichst',
#   'mehr',
#   'nur',
#   'ncoh',
#   'das',
#   'was',
#   'am',
#   'körper',
#   'tragen',
#   'sagt',
#   'man',
#   'immer',
#   'wieder'],
#  ['ich',
#   'geh',
#   'davon',
#   'aus',
#   'das',
#   'nur',
#   'kriminelle',
#   'her',
#   'kommen',
#   'die',
#   'geld',
#   'haben',
#   'und',
#   'es',
#   'sich',
#   'leisten',
#   'können',
#   '..',
#   'was',
#   'da',
#   'wohl',
#   'gelehrt',
#   'wurde'],
#  ['ein',
#   'in',
#   'der',
#   'kosovo-',
#   'hauptstadt',
#   'pristina',
#   'geborenes',
#   'brüderpaar',
#   'das',
#   'in',
#   'österreich',
#   'asyl',
#   'beantragt',
#   'den',
#   'asylantrag',
#   'verbrennen',
#   'und',
#   'einreiseverbot',
#   'für',
#   'immer'],
#  ['serbe',
#   'wollte',
#   'einen',
#   'gleichaltrigen',
#   'landsmann',
#   'mit',
#   'dem',
#   'auto',
#   'über',
#   'den',
#   'haufen',
#   'fahren',
#   'der',
#   'tägliche',
#   'wahnsinn'],
#  ['wann', 'ist', 'endlich', 'schluß'],
#  ['wien',
#   'ist',
#   'tatsächlich',
#   'anders',
#   'tschetschenen',
#   'serben',
#   'albaner',
#   'türken',
#   'usw',
#   'und',
#   'so',
#   'fort',
#   'üben',
#   'sich',
#   'in',
#   'beinahe',
#   'täglichen',
#   'schießereien'],
#  ['chikago', 'ist', 'da', 'im', 'vergleich', 'ein', 'harmloses', 'kuhdorf'],
#  ['jahre',
#   'alter',
#   'mann',
#   'ist',
#   'am',
#   'mittwoch',
#   'am',
#   'landesgericht',
#   'klagenfurt',
#   'zu',
#   'jahren',
#   'haft',
#   'verurteilt',
#   'worden',
#   'es',
#   'tut',
#   'mir',
#   'leid',
#   'was',
#   'passiert',
#   'ist',
#   'sagte',
#   'der',
#   'aus',
#   'bosnien',
#   'stammende',
#   'mann',
#   'zu',
#   'beginn',
#   'der',
#   'verhandlung',
#   'am',
#   'mittwoch',
#   'hier',
#   'wurde',
#   'beim',
#   'urteil',
#   'sicher',
#   'wieder',
#   'das',
#   'südländische',
#   'temperament',
#   'berücksichtigt'],
#  ['trauriges', 'österreich'],
#  ['mir', 'kommt', 'das', 'kotzen'],
#  ['drei', 'moldawier', 'tsss', 'schöne', 'gäste'],
#  ['es',
#   'ist',
#   'noch',
#   'ärger',
#   'den',
#   'die',
#   'die',
#   'inlandspassträger',
#   'mit',
#   'migriationshintergrund',
#   'wurden',
#   'noch',
#   'gar',
#   'nicht',
#   'berückstichtigt'],
#  ['was',
#   'neues',
#   'zu',
#   'wie',
#   'ermittler',
#   'inoffiziell',
#   'bestätigen',
#   'hatte',
#   'alen',
#   'r.',
#   'auf',
#   'der',
#   'social-',
#   'media-',
#   'plattform',
#   'twitter'],
#  ['followerfazit',
#   'so',
#   'wie',
#   'ich',
#   'das',
#   'sehe',
#   'vorsatz',
#   'zu',
#   'dem',
#   'politisch',
#   'bzw',
#   'religös',
#   'motiviert',
#   'war',
#   'das',
#   'ganze',
#   'der',
#   'terroakt',
#   'in',
#   'graz',
#   '..',
#   'niemand',
#   'nahm',
#   'unsere',
#   'ängste',
#   'und',
#   'warnungen',
#   'ernst',
#   'eine',
#   'familie',
#   'gegen',
#   'die',
#   'wir',
#   'nie',
#   'ankamen',
#   'sagen',
#   'nun',
#   'viele',
#   'kalsdorfer',
#   'seit',
#   'jahren',
#   'machten',
#   'wir',
#   'anzeigen',
#   'gegen',
#   'alen',
#   'r.',
#   'und',
#   'seine',
#   'eltern'],
#  ['aber', 'niemand', 'nahm', 'unsere', 'ängste', 'und', 'warnungen', 'ernst'],
#  ['familie',
#   'r.',
#   'führte',
#   'schreckensherrschaft',
#   'ohne',
#   'jemals',
#   'ernsthaft',
#   'von',
#   'der',
#   'justiz',
#   'verfolgt',
#   'zu',
#   'werden',
#   'führte',
#   'die',
#   'familie',
#   'hier',
#   'eine',
#   'schreckensherrschaft'],
#  ['der',
#   'hund',
#   'eines',
#   'nachbarn',
#   'sei',
#   'von',
#   'den',
#   'r.s',
#   'mit',
#   'messern',
#   'attackiert',
#   'worden',
#   'ziegen',
#   'und',
#   'schweine',
#   'die',
#   'sie',
#   'auf',
#   'ihrem',
#   'anwesen',
#   'unter',
#   'miserablen',
#   'bedingungen',
#   'hielten',
#   'öffentlich',
#   'abgeschlachtet'],
#  ['alen',
#   'r.',
#   'schoss',
#   'wiederholt',
#   'mit',
#   'einem',
#   'gewehr',
#   'aus',
#   'seinem',
#   'haus',
#   'jetzt',
#   'kommt',
#   'das',
#   'totalversagen',
#   'der',
#   'behörden',
#   'und',
#   'vor',
#   'allem',
#   'der',
#   'politiker',
#   'die',
#   'gesetze',
#   'erstellen'],
#  ['na',
#   'das',
#   'hätten',
#   'wir',
#   'aber',
#   'nicht',
#   'gewusst',
#   'wenn',
#   'die',
#   'das',
#   'nicht',
#   'gesagt',
#   'hätten'],
#  ['hat',
#   'man',
#   'da',
#   'noch',
#   'worten',
#   'ab',
#   'in',
#   'seine',
#   'heimat',
#   'dann',
#   'erlebt',
#   'er',
#   'wie',
#   'man',
#   'mit',
#   'solch',
#   'einen',
#   'umgehen',
#   'muss'],
#  ['is',
#   'schon',
#   'eigenartig',
#   'das',
#   'man',
#   'nur',
#   'in',
#   'alternativen',
#   'medien',
#   'was',
#   'darüber',
#   'liest'],
#  ['siehe',
#   'da',
#   'von',
#   'wo',
#   'der',
#   'nun',
#   'ist',
#   'diverse',
#   'medien',
#   'haben',
#   'damals',
#   'vor',
#   'tagen',
#   'kein',
#   'wort',
#   'geschrieben',
#   'von',
#   'wo',
#   'der',
#   'ist',
#   'und',
#   'jetzt'],
#  ['sicher', 'alles', 'einheimische', 'ig', 'i', 'schwöre'],
#  ['und', 'nun', 'jahre', 'reha', 'in', 'der', 'kuranstalt', 'stein'],
#  ['mit',
#   'drei',
#   'mahlzeiten',
#   'täglich',
#   'fitnessraum',
#   'und',
#   'satellitenfernseher'],
#  ['solche',
#   'typen',
#   'haben',
#   'nichts',
#   'zu',
#   'verlieren',
#   'und',
#   'so',
#   'erkläre',
#   'ich',
#   'mir',
#   'diese',
#   'brutalität'],
#  ['alles',
#   'besser',
#   'als',
#   'in',
#   'der',
#   'heimatx',
#   'auf',
#   'die',
#   'finger',
#   'klopfen',
#   'x',
#   'du',
#   'du',
#   'du',
#   'das',
#   'darf',
#   'man',
#   'nicht',
#   'und',
#   'dann',
#   'einen',
#   'therapeuten',
#   'so',
#   'streng',
#   'und',
#   'abschreckend',
#   'läuft',
#   'das',
#   'bei',
#   'uns'],
#  ['erstaufnahmeeinrichtung', 'für', 'asylbewerber', 'in', 'erfurt'],
#  ['bericht',
#   'eines',
#   'gesundheitsaufsehers',
#   'der',
#   'bundeswehrs',
#   '„',
#   'die',
#   'hallen',
#   'werden',
#   '-mal',
#   'am',
#   'tag',
#   'gereinigt'],
#  ['trotzdem',
#   'ist',
#   'der',
#   'reinigungszustand',
#   'der',
#   'böden',
#   'aus',
#   'meiner',
#   'sicht',
#   'nicht',
#   'in',
#   'ordnung',
#   'da',
#   'immer',
#   'wieder',
#   'müll',
#   'auf',
#   'den',
#   'fußboden',
#   'geworfen',
#   'wird'],
#  ['das', 'urinieren', 'in', 'irgendwelchen', 'ecken', 'ist', 'routine'],
#  ['in',
#   'den',
#   'unterkunftsbereichen',
#   'werden',
#   'alleinstehende',
#   'frauen',
#   'von',
#   'anderen',
#   'männlichen',
#   'personen',
#   'aus',
#   'anderen',
#   'ländern',
#   'anuriniert',
#   'auch',
#   'wenn',
#   'die',
#   'frauen',
#   'schlafen'],
#  ['sexuelle', 'belästigungen', 'sind', 'an', 'der', 'tagesordnung.', '“'],
#  ['es',
#   'könne',
#   'doch',
#   'nicht',
#   'sein',
#   'dass',
#   'polizeibeamte',
#   'kaum',
#   'noch',
#   'rechte',
#   'hätten',
#   'und',
#   'dass',
#   'menschen',
#   'die',
#   'das',
#   'grundgesetz',
#   'nicht',
#   'achten',
#   'und',
#   'eine',
#   'illegale',
#   'parallelgesellschaft',
#   'geschaffen',
#   'haben',
#   'hier',
#   'tun',
#   'und',
#   'lassen',
#   'können',
#   'was',
#   'sie',
#   'wollen'],
#  ['wo', 'sind', 'wir', 'mittlerweile', 'gelandet'],
#  ['fragte', 'kambouri', 'in', 'ihrem', 'schreiben'],
#  ['ist',
#   'es',
#   'schon',
#   'so',
#   'weit',
#   'gekommen',
#   'dass',
#   'die',
#   'deutsche',
#   'polizei',
#   'bzw'],
#  ['der',
#   'staat',
#   'sich',
#   'negativ',
#   'anpassen',
#   'muss',
#   'und',
#   'wir',
#   'unsere',
#   'demokratische',
#   'vorstellung',
#   'in',
#   'gewissen',
#   'lebens-',
#   '/einsatzsituationen',
#   'einschränken',
#   'und',
#   'aufgeben',
#   'müssen'],
#  ['zu', 'auf', 'österreich', 'übertragbar'],
#  ['der',
#   'jährige',
#   'afghane',
#   'jährigen',
#   'tschetschenischen',
#   'und',
#   'beie',
#   'tschüß',
#   'verlasst',
#   'unser',
#   'land',
#   'für',
#   'immer'],
#  ['warum',
#   'könne',
#   'wir',
#   'diesen',
#   'flüchtlingskinder',
#   'und',
#   'flüchtlingsfrauen',
#   'nicht',
#   'helfen'],
#  ['irgendwann', 'wird', 'es', 'unsere', 'frauen', 'und', 'kinder', 'treffen'],
#  ['dieser', 'irrsinn', 'muss', 'ein', 'ende', 'haben'],
#  ['..',
#   'otterndorf',
#   'bei',
#   'cuxhaven',
#   'pakistaner',
#   'vergewaltigt',
#   'ein',
#   'jähriges',
#   'kind',
#   'letzte',
#   'woche',
#   'gleiche',
#   'flüchtlingsheim',
#   'ähnlicher',
#   'vorfall'],
#  ['..',
#   'gestern',
#   'hamburg',
#   'zwei',
#   'tage',
#   'hintereinander',
#   'gleiche',
#   'flüchtlingsheim',
#   'massenschlägerei',
#   'pakistaner',
#   'gegen',
#   'albaner',
#   'und',
#   'afganen'],
#  ['..',
#   'niedersachsen',
#   'in',
#   'friedland',
#   'massenschlägerei',
#   'pakistaner',
#   'gegen',
#   'afganen'],
#  ['usw', 'usw'],
#  ['quelle', 'stellt', 'euch', 'nicht', 'so', 'dumm', 'an', 'und', 'googlet'],
#  ['hier', 'das', 'video'],
#  ['ja', 'es', 'reicht'],
#  ['speziell',
#   'min',
#   'etwa',
#   'wie',
#   'man',
#   'mit',
#   'kriminelle',
#   'umgehen',
#   'sollte'],
#  ['ein',
#   'whistleblower',
#   'aus',
#   'der',
#   'op-abteilung',
#   'des',
#   'klever',
#   'krankenhauses',
#   'berichtet',
#   'folgendes',
#   'in',
#   'einem',
#   'relativen',
#   'kurzen',
#   'zeitraum',
#   'sind',
#   'fünf',
#   'mädchen',
#   'zwischen',
#   'acht',
#   'und',
#   'zehn',
#   'jahren',
#   'mit',
#   'schweren',
#   'verletzungen',
#   'in',
#   'das',
#   'krankenhauses',
#   'kleve',
#   'eingeliefert',
#   'worden',
#   'nachdem',
#   'sie',
#   'auf',
#   'ihrem',
#   'schulweg',
#   'entführt',
#   'und',
#   'brutal',
#   'vergewaltigt',
#   'worden',
#   'sind'],
#  ['zur',
#   'zeit',
#   'werden',
#   'diese',
#   'mädchen',
#   'abgeschottet',
#   'und',
#   'sind',
#   'in',
#   'psychiatrischer',
#   'behandlung'],
#  ['warum',
#   'darf',
#   'die',
#   'öffentlichkeit',
#   'darüber',
#   'nichts',
#   'erfahren',
#   'fragt',
#   'lothar',
#   'schulze',
#   'in',
#   'seinem',
#   'blog',
#   'zurecht'],
#  ['die', 'antwort', 'ist', 'so', 'einfach', 'wie', 'grausam'],
#  ['für',
#   'die',
#   'schlafschafe',
#   'müssen',
#   'die',
#   '“',
#   'flüchtlinge',
#   '”',
#   'ganz',
#   'liebe',
#   'menschen',
#   'bleiben',
#   '..',
#   'anscheinend',
#   'macht',
#   'sich',
#   'refugees',
#   'welcome',
#   'bonn',
#   'wesentlich',
#   'mehr',
#   'sorgen',
#   'um',
#   'den',
#   'ruf',
#   'der',
#   'flüchtlinge',
#   'als',
#   'um',
#   'die',
#   'sexuell',
#   'belästigten',
#   'mädchen'],
#  ['und',
#   'ich',
#   'dachte',
#   'das',
#   'sind',
#   'nur',
#   'lügen',
#   'der',
#   'fremdenfeindlichen',
#   'rechten',
#   'userkom'],
#  ['so',
#   'ist',
#   'es',
#   'villeicht',
#   'betraf',
#   'es',
#   'eh',
#   'nur',
#   'linke',
#   'kampf',
#   'emanzen',
#   'd',
#   'lol',
#   'dies',
#   'ist',
#   'der',
#   'gebührende',
#   'lohn',
#   'für',
#   'ihre',
#   'arbeit',
#   'die',
#   'wir',
#   'steuerzahler',
#   'mit',
#   'zig',
#   'förderungen',
#   'zahlen'],
#  ['so',
#   'ist',
#   'es',
#   'von',
#   'anfang',
#   'an',
#   'hat',
#   'kar',
#   'sich',
#   'für',
#   'strenge',
#   'kontrollen',
#   'bei',
#   'den',
#   'flüchtlingen',
#   'ausgesprochen',
#   'kriminelle',
#   'ausländer',
#   'sollen',
#   'sofort',
#   'ausgewiesen',
#   'werden',
#   'inkl',
#   'aufendhaltsverbot',
#   'für',
#   'die',
#   'ganze',
#   'eu'],
#  ['der', 'aussage', 'bleiben', 'wir', 'jetzt', 'treu'],
#  ['zu',
#   'den',
#   'franzosen',
#   'haben',
#   'die',
#   'nicht',
#   'sarkosi',
#   'mit',
#   'seiner',
#   'harten',
#   'ausländerpolitik',
#   'in',
#   'die',
#   'wüste',
#   'geschickt'],
#  ['war',
#   'nicht',
#   'sarkosi',
#   'ein',
#   'freund',
#   'gadafis',
#   'der',
#   'den',
#   'flüchtlingsansturm',
#   'abwährte'],
#  ['die',
#   'franzosen',
#   'haben',
#   'ihn',
#   'abgewählt',
#   'und',
#   'der',
#   'französische',
#   'geheimdienst',
#   'hat',
#   'den',
#   'arabischen',
#   'frühling',
#   'mitinziniert',
#   'nun',
#   'erntet',
#   'man',
#   'die',
#   'früchte',
#   'dieser',
#   'politik'],
#  ['zum',
#   'schluß',
#   'ein',
#   'video',
#   'wenns',
#   'nach',
#   'mir',
#   'geht',
#   'personen',
#   'ausforschen',
#   'und',
#   'ausweisen'],
#  ['die',
#   'vier',
#   'afghanischen',
#   'staatsangehörigen',
#   'gingen',
#   'auf',
#   'einen',
#   '-jährigen',
#   'asylwerber',
#   'aus',
#   'marokko',
#   'los',
#   'und',
#   'verletzten',
#   'diesen',
#   'im',
#   'gesicht'],
#  ['die',
#   'verdächtigen',
#   'werden',
#   'angezeigt',
#   'wie',
#   'die',
#   'polizei',
#   'in',
#   'einer',
#   'aussendung',
#   'mitteilt'],
#  ['warum',
#   'nicht',
#   'sofort',
#   'abgeschoben',
#   'warum',
#   'gibts',
#   'nicht',
#   'endlich',
#   'so',
#   'ein',
#   'gesetz',
#   'das',
#   'besagt',
#   'tschüß',
#   'wir',
#   'wollen',
#   'euch',
#   'net',
#   'mehr',
#   'da',
#   'haben'],
#  ['sicher',
#   'nur',
#   'ein',
#   'einzelfall',
#   'denn',
#   'all',
#   'die',
#   'männer',
#   'die',
#   'nun',
#   'rein',
#   'kamen',
#   'haben',
#   'sicher',
#   'keinen',
#   'samenstau',
#   'nee',
#   'siche',
#   'rnicht',
#   'sind',
#   'alle',
#   'gaaanz',
#   'brav'],
#  ['wie',
#   'die',
#   'medein',
#   'das',
#   'bis',
#   'jetzt',
#   'verschwiegen',
#   'unglaublich'],
#  ['der', 'arme', 'is', 'nur', 'a', 'einzelfall', 'und', 'traumatisiert'],
#  ['bestimmt',
#   'der',
#   'weis',
#   'ja',
#   'noch',
#   'nicht',
#   'das',
#   'man',
#   'hier',
#   'niemanden',
#   'ausrauben',
#   'darf'],
#  ['gut',
#   'das',
#   'er',
#   'nun',
#   'auf',
#   'die',
#   'richtige',
#   'traf',
#   'die',
#   'ihm',
#   'das',
#   'schmerzhaft',
#   'bei',
#   'brachte',
#   '..',
#   'und',
#   'noch',
#   'zwei',
#   'videos'],
#  ['das',
#   'ist',
#   'das',
#   'falsche',
#   'signal',
#   'des',
#   'staates',
#   'anstelle',
#   'volle',
#   'härte',
#   'zu',
#   'zeigen',
#   'wird',
#   'ein',
#   'skandalurteil',
#   'gefällt',
#   '..',
#   'und',
#   'tschüß',
#   'wer',
#   'sich',
#   'nicht',
#   'benehmen',
#   'kann',
#   'muss',
#   'gehen'],
#  ['der',
#   'soll',
#   'unten',
#   'bleiben',
#   'und',
#   'ein',
#   'einreise',
#   'verbot',
#   'verhängt',
#   'werden'],
#  ['alltag',
#   'in',
#   'schweden',
#   'dank',
#   'unverbesserlicher',
#   'gutmenschen',
#   'und',
#   'realitätsverweigerer',
#   'auch',
#   'bald',
#   'bei',
#   'uns'],
#  ['die',
#   'schwedische',
#   'polizei',
#   'hält',
#   'kriminalität',
#   'im',
#   'zusammenhang',
#   'mit',
#   'flüchtlingen',
#   'laut',
#   'einem',
#   'medienbericht',
#   'geheim'],
#  ['informationen',
#   'über',
#   'straftaten',
#   'bei',
#   'denen',
#   'täter',
#   'oder',
#   'opfer',
#   'asylbewerber',
#   'sind',
#   'werden',
#   'nach',
#   'einem',
#   'bericht',
#   'der',
#   'zeitung',
#   'dagens',
#   'nyheter',
#   'mit',
#   'dem',
#   'geheimhaltungscode',
#   'versehen'],
#  ['klingt', 'komisch', 'ist', 'aber', 'so'],
#  ['berlin', 'um', 'in', 'farbe'],
#  ['und',
#   'keine',
#   'frau',
#   'muss',
#   'auf',
#   'die',
#   'armlänge',
#   'abstand',
#   'achten',
#   'das',
#   'waren',
#   'noch',
#   'zeiten'],
#  ['ehemals', 'verschwörungstheorie', 'in', 'schweden'],
#  ['jetzt',
#   'scheinbar',
#   'bewiesen.polizei',
#   'regierung',
#   'und',
#   'medien',
#   'verweigern',
#   'der',
#   'bevölkerung',
#   'die',
#   'wahrheit',
#   'wenn',
#   'es',
#   'um',
#   'die',
#   'migranten',
#   'und',
#   'ihre',
#   'straftaten',
#   'geht',
#   '..',
#   'schluss',
#   'mit',
#   'dem',
#   'zerreden'],
#  ['patrioten',
#   'müssen',
#   'gerade',
#   'jetzt',
#   'in',
#   'größter',
#   'not',
#   'mit',
#   'authentischen',
#   'taten',
#   'überzeugen'],
#  ['guter',
#   'beitrag',
#   'von',
#   'pierre',
#   'aronnax',
#   '..',
#   'das',
#   'schlimmste',
#   'wäre',
#   'es',
#   'jetzt',
#   'wenn',
#   'pseudo-asylhardliner',
#   'wie',
#   'sigmar',
#   'gabriel',
#   'und',
#   'horst',
#   'seehofer',
#   'das',
#   'ruder',
#   'übernehmen'],
#  ['dann',
#   'geht',
#   'die',
#   'masseneinwanderung',
#   'nämlich',
#   'weiter',
#   'nur',
#   'etwas',
#   'langsamer'],
#  ['von',
#   'daher',
#   'lasst',
#   'angela',
#   'merkel',
#   'die',
#   'bundesrepublik',
#   'ruhig',
#   'noch',
#   'ein',
#   'paar',
#   'monate',
#   'länger',
#   'regieren',
#   'und',
#   'so',
#   'richtig',
#   'gegen',
#   'die',
#   'wand',
#   'fahren'],
#  ['erst',
#   'dann',
#   'kann',
#   'es',
#   'zu',
#   'einem',
#   'großen',
#   'umbruch',
#   'kommen',
#   '..',
#   'patriotismus',
#   'und',
#   'weltoffenheit',
#   'sind',
#   'keine',
#   'gegensätze',
#   'sie',
#   'bedingen',
#   'einander'],
#  ['nur', 'wer', 'sich', 'selbst', 'achtet', 'achtet', 'auch', 'andere'],
#  ['-horst', 'köhler'],
#  ['franzosen',
#   'müssen',
#   'ihr',
#   'haus',
#   'in',
#   'calais',
#   'vor',
#   'marodierenden',
#   'fachkräften',
#   'und',
#   'deren',
#   'linksextremen',
#   'unterstützern',
#   'verteidigen'],
#  ['deutsche', 'schaut', 'euch', 'diese', 'bilder', 'an'],
#  ['bereitet', 'euch', 'vor'],
#  ['raf-methoden',
#   'sind',
#   'nun',
#   'offenbar',
#   'auch',
#   'legitim',
#   'um',
#   'politische',
#   'gegner',
#   'auszuschalten'],
#  ['leute', 'passt', 'auf', 'euch', 'auf'],
#  ['mir',
#   'ist',
#   'in',
#   'der',
#   'tat',
#   'vor',
#   'kurzem',
#   'etwas',
#   'irrwitziges',
#   'passiert'],
#  ['es',
#   'beweist',
#   'einmal',
#   'mehr',
#   'dass',
#   'sich',
#   'der',
#   'politische',
#   'wind',
#   'im',
#   'lande',
#   'gedreht',
#   'hat'],
#  ['ein',
#   'kollege',
#   'kam',
#   'mir',
#   'kürzlich',
#   'entgegen',
#   'und',
#   'trug',
#   'nichts',
#   'weiter',
#   'als',
#   'ein',
#   'normales',
#   't-shirt'],
#  ['nichts', 'ungewöhnliches', 'könnte', 'man', 'meinen'],
#  ['nun',
#   'vor',
#   'wenigen',
#   'wochen',
#   'hatte',
#   'ich',
#   'ihn',
#   'noch',
#   'stets',
#   'mit',
#   'einem',
#   '„',
#   'refugees-welcome',
#   '“',
#   'shirt',
#   'herum',
#   'stolzieren',
#   'sehen'],
#  ['eine', 'klare', 'aussage', 'wie', 'ich', 'finde'],
#  ['obwohl',
#   'ich',
#   'natürlich',
#   'kein',
#   'verfechter',
#   'von',
#   'einem',
#   'generellen',
#   '„',
#   'refugees-unwelcome',
#   '“',
#   'bin',
#   'muss',
#   'ich',
#   'doch',
#   'anmerken',
#   'dass',
#   'jener',
#   'kollege',
#   'dem',
#   'menschenschlag',
#   'der',
#   'salongutmenschen',
#   'angehört'],
#  ['oder',
#   'vielleicht',
#   'eher',
#   'dem',
#   'typus',
#   'des',
#   'dumpfen',
#   'mitläufers'],
#  ['denn',
#   'seit',
#   'kurzer',
#   'zeit',
#   'trägt',
#   'er',
#   'schließlich',
#   'das',
#   'shirt',
#   'nicht',
#   'mehr'],
#  ['ja',
#   'auf',
#   'die',
#   'frage',
#   'hin',
#   'warum',
#   'er',
#   'denn',
#   'das',
#   'hemd',
#   'nicht',
#   'mehr',
#   'anzieht',
#   'und',
#   'ob',
#   'er',
#   'jetzt',
#   'seine',
#   'meinung',
#   'etwa',
#   'geändert',
#   'hat',
#   'bekam',
#   'ich',
#   'sinngemäß',
#   'folgende',
#   'antwort'],
#  ['„',
#   'also',
#   'nee…ich',
#   'war',
#   'immer',
#   'schon',
#   'skeptisch',
#   'bei',
#   'dieser',
#   'flüchtlingsgeschichte.',
#   '“',
#   'einen',
#   'schei…warst',
#   'du'],
#  ['vor',
#   'nur',
#   'ein',
#   'paar',
#   'wochen',
#   'hätte',
#   'dieser',
#   'junge',
#   'der',
#   'körper',
#   'eines',
#   'erwachsenen',
#   'macht',
#   'einen',
#   'mann',
#   'noch',
#   'nicht',
#   'zum',
#   'mann',
#   'jeden',
#   'menschen',
#   'als',
#   'nazi',
#   'tituliert',
#   'der',
#   'auch',
#   'nur',
#   'zu',
#   'leiser',
#   'vorsicht',
#   'bei',
#   'der',
#   'migrationswelle',
#   'gemahnt',
#   'hätte'],
#  ['dieser',
#   'ungeheuerliche',
#   'und',
#   'dennoch',
#   'vorhersehbare',
#   'fall',
#   'von',
#   'mitläufertum',
#   'erinnerte',
#   'mich',
#   'jedoch',
#   'an',
#   'das',
#   'ende',
#   'der',
#   'nazis',
#   'oder',
#   'vielleicht',
#   'gar',
#   'das',
#   'ende',
#   'der',
#   'ddr',
#   'bzw'],
#  ['jedes', 'regimes'],
#  ['als',
#   'der',
#   'zweite',
#   'weltkrieg',
#   'vorbei',
#   'war',
#   'zogen',
#   'viele',
#   'nazi-funktionäre',
#   'darunter',
#   'auch',
#   'etliche',
#   'kriegsverbrecher',
#   'ihre',
#   'uniform',
#   'wieder',
#   'aus',
#   'und',
#   'versuchten',
#   'sich',
#   'unter',
#   'das',
#   'volk',
#   'zu',
#   'mischen'],
#  ['nach',
#   'dem',
#   'ende',
#   'jedes',
#   'regimes',
#   'will',
#   'es',
#   'keiner',
#   'gewesen',
#   'sein'],
#  ['dann',
#   'wollte',
#   'keiner',
#   'gewusst',
#   'haben',
#   'wie',
#   'es',
#   'zu',
#   'all',
#   'dem',
#   'kommen',
#   'konnte'],
#  ['„',
#   'ich',
#   'war',
#   'niemals',
#   'nazi/kommunist/sozialist/unterstützerjener-oder',
#   'dieser',
#   'partei',
#   'und',
#   'so',
#   'weiter.',
#   '“',
#   'so',
#   'taten',
#   'auch',
#   'viele',
#   'stasi-mitarbeiter',
#   'einfach',
#   'ihren',
#   'mantel',
#   'ablegen',
#   'und',
#   'so',
#   'tun',
#   'als',
#   'sei',
#   'nichts',
#   'geschehen'],
#  ['genauso', 'könnte', 'es', 'wieder', 'verlaufen'],
#  ['sollten',
#   'wir',
#   'gewinnen',
#   'und',
#   'die',
#   'verhältnisse',
#   'sich',
#   'grundlegend',
#   'ändern',
#   'erleben',
#   'wir',
#   'vielleicht',
#   'den',
#   'spontanen',
#   'und',
#   'überraschenden',
#   'wandel',
#   'von',
#   'etlichen',
#   'persönlichkeiten',
#   'denen',
#   'man',
#   'das',
#   'niemals',
#   'zugetraut',
#   'hätte'],
#  ['„',
#   'ich',
#   'war',
#   'doch',
#   'schon',
#   'immer',
#   'patriot',
#   '“',
#   '–',
#   'das',
#   'werden',
#   'einige',
#   'heraus',
#   'posaunen'],
#  ['„',
#   'also',
#   'ich',
#   'habe',
#   'euch',
#   'natürlich',
#   'heimlich',
#   'immer',
#   'unterstützt…',
#   '“',
#   '–',
#   'werden',
#   'viele',
#   'behaupten'],
#  ['die',
#   'wechselbälger',
#   'der',
#   'neuen',
#   'zeit',
#   'mögen',
#   'uns',
#   'in',
#   'der',
#   'masse',
#   'nicht',
#   'interessieren'],
#  ['wichtig',
#   'ist',
#   'nur',
#   'dass',
#   'wir',
#   'jene',
#   'nicht',
#   'vergessen',
#   'die',
#   'jetzt',
#   'und',
#   'in',
#   'der',
#   'vergangenheit',
#   'die',
#   'macht',
#   'haben',
#   'oder',
#   'hatten'],
#  ['zeichnet', 'alles', 'auf'],
#  ['nicht',
#   'um',
#   'den',
#   'nachbarn',
#   'zu',
#   'denunzieren',
#   'sondern',
#   'um',
#   'die',
#   'machthaber',
#   'und',
#   'ihre',
#   'lakaien',
#   'nicht',
#   'vor',
#   'ihrer',
#   'verantwortung',
#   'entkommen',
#   'zu',
#   'lassen'],
#  ['damit',
#   'wir',
#   'dank',
#   'moderner',
#   'technik',
#   'auch',
#   'in',
#   'zehn',
#   'jahren',
#   'noch',
#   'wissen',
#   'wer',
#   'sich',
#   'über',
#   'den',
#   'tod',
#   'des',
#   'deutschen',
#   'volkes',
#   'gefreut',
#   'hat',
#   'wer',
#   'eine',
#   'armlänge',
#   'abstand',
#   'gefordert',
#   'hat',
#   'und',
#   'wer',
#   'aktiv',
#   'bei',
#   'der',
#   'abschaffung',
#   'des',
#   'landes',
#   'mitgeholfen',
#   'hat'],
#  ['wie',
#   'viele',
#   'journalisten',
#   'und',
#   'politiker',
#   'agieren',
#   'schon',
#   'seit',
#   'jahrzehnten',
#   'gegen',
#   'das',
#   'eigene',
#   'volk',
#   'die',
#   'nation',
#   'und',
#   'alles',
#   'was',
#   'uns',
#   'heilig',
#   'ist'],
#  ['wie',
#   'viele',
#   'haben',
#   'sich',
#   'mit',
#   'namen',
#   'und',
#   'rang',
#   'an',
#   'der',
#   'vertuschungs-',
#   'und',
#   'verleugnungspolitik',
#   'beteiligt'],
#  ['diese',
#   'menschen',
#   'dürfen',
#   'ihre',
#   'uniform',
#   'am',
#   'ende',
#   'nicht',
#   'einfach',
#   'ausziehen',
#   'und',
#   'dann',
#   'so',
#   'weitermachen',
#   'als',
#   'wäre',
#   'nichts',
#   'gewesen'],
#  ['die',
#   'dürfen',
#   'nicht',
#   'einfach',
#   'in',
#   'das',
#   'zivile',
#   'leben',
#   'zurückkehren',
#   'und',
#   'die',
#   'biedermeier-gemütlichkeit',
#   'ihrer',
#   'privatwohnungen',
#   'konsumieren'],
#  ['mal',
#   'wieder',
#   'zur',
#   'erinnerung',
#   'aufkleber',
#   'für',
#   'den',
#   'patriotischen',
#   'umbruch'],
#  ['hier', 'holen'],
#  ['merkel',
#   'leidet',
#   'wie',
#   'viele',
#   'mächtige',
#   'an',
#   'selbstüberschätzung',
#   'die',
#   'sie',
#   'mittlerweile',
#   'immun',
#   'für',
#   'kritik',
#   'macht'],
#  ['wir', 'alle', 'zahlen', 'sanierung', 'von', 'facharbeiter-gebissen'],
#  ['denkt',
#   'daran',
#   'wenn',
#   'ihr',
#   'die',
#   'nächste',
#   'behandlung',
#   'selbst',
#   'zahlen',
#   'müsst',
#   'oder',
#   'die',
#   'beiträge',
#   'steigen'],
#  ['da', 'zahlt', 'man', 'doch', 'gerne', 'ein', 'solidargemeinschaft'],
#  ['damit', 'ihr', 'immer', 'unsere', 'meldungen', 'seht'],
#  ['mordversuch', 'auf', 'afd-mitglied'],
#  ['ein',
#   '-jähriger',
#   'ist',
#   'beim',
#   'aufstellen',
#   'von',
#   'wahlplakaten',
#   'für',
#   'die',
#   'alternative',
#   'für',
#   'deutschland',
#   'afd',
#   'in',
#   'karlsruhe',
#   'von',
#   'einem',
#   'unbekannten',
#   'beschossen',
#   'worden'],
#  ['der',
#   'mit',
#   'einem',
#   'schal',
#   'vermummte',
#   'angreifer',
#   'hatte',
#   'den',
#   'plakatierer',
#   'zuvor',
#   'angesprochen',
#   'wie',
#   'die',
#   'polizei',
#   'am',
#   'sonntag',
#   'mitteilte'],
#  ['laut',
#   'darstellung',
#   'des',
#   'kreisverbands',
#   'der',
#   'rechtskonservativen',
#   'afd',
#   'forderte',
#   'der',
#   'mann',
#   'den',
#   '-jährigen',
#   'auf',
#   'zu',
#   'verschwinden'],
#  ['nach',
#   'erkenntnis',
#   'der',
#   'polizei',
#   'setzte',
#   'sich',
#   'der',
#   'plakatierer',
#   'daraufhin',
#   'in',
#   'seinen',
#   'lieferwagen',
#   'um',
#   'loszufahren',
#   'doch',
#   'der',
#   'unbekannte',
#   'zog',
#   'eine',
#   'pistole',
#   'aus',
#   'einer',
#   'tasche',
#   'und',
#   'schoss',
#   'von',
#   'außen',
#   'durch',
#   'das',
#   'geschlossene',
#   'beifahrerfenster'],
#  ['dabei',
#   'verfehlte',
#   'er',
#   'den',
#   'fahrer',
#   'der',
#   'unverletzt',
#   'davonfuhr'],
#  ['nach',
#   'dem',
#   'vorfall',
#   'am',
#   'samstagabend',
#   'suchte',
#   'die',
#   'polizei',
#   'zunächst',
#   'vergebens',
#   'nach',
#   'dem',
#   'schützen'],
#  ['ein', 'vorstoß', 'der', 'facebook-seite', 'faktislam'],
#  ['hmm',
#   'ob',
#   'das',
#   'auch',
#   'für',
#   'die',
#   'christen',
#   'in',
#   'syrien',
#   'saudi-arabien',
#   'und',
#   'der',
#   'türkei',
#   'gilt'],
#  ['was', 'haltet', 'ihr', 'von', 'einer', 'verfassungsbeschwerde'],
#  ['die',
#   'plattform',
#   'einprozent',
#   'hat',
#   'angekündigt',
#   'dass',
#   'der',
#   'bekannte',
#   'staatsrechtler',
#   'prof.',
#   'schachtschneider',
#   'beauftragt',
#   'wurde',
#   'eine',
#   'solche',
#   'beschwerde',
#   'vorzubereiten'],
#  ['finanziert', 'wird', 'diese', 'beschwerde', 'von', 'einprozent'],
#  ['es', 'bleibt', 'spannend'],
#  ['geht', 'es', 'noch', 'erbärmlicher'],
#  ['eil', 'meldung'],
#  ['rund',
#   'millionen',
#   'schüler',
#   'im',
#   'alter',
#   'zwischen',
#   'sechs',
#   'und',
#   'jahren',
#   'bekommen',
#   'nachhilfeunterricht',
#   'obwohl',
#   'ein',
#   'drittel',
#   'von',
#   'ihnen',
#   'befriedigende',
#   'bis',
#   'sehr',
#   'gute',
#   'noten',
#   'hat'],
#  ['das',
#   'ist',
#   'das',
#   'ergebnis',
#   'einer',
#   'repräsentativen',
#   'elternbefragung',
#   'im',
#   'auftrag',
#   'der',
#   'bertelsmann',
#   'stiftung',
#   '..',
#   'patrioten'],
#  ['leider', 'haben', 'wir', 'keine', 'guten', 'nachrichten', 'für', 'euch'],
#  ['mit',
#   'einer',
#   'fadenscheinigen',
#   'begründung',
#   'hat',
#   'facebook',
#   'uns',
#   'für',
#   'das',
#   'posten',
#   'von',
#   'medien',
#   'bilder',
#   'videos',
#   'gesperrt'],
#  ['die',
#   'meldung',
#   'lautete',
#   'dass',
#   'wegen',
#   'vieler',
#   'urheberrechtsverletzungen',
#   'diese',
#   'entscheidung',
#   'getroffen',
#   'wurde'],
#  ['dazu',
#   'stellen',
#   'wir',
#   'folgendes',
#   'fest',
#   'wurde',
#   'nicht',
#   'ein',
#   'einziger',
#   'inhalt',
#   'wegen',
#   'urheberrechtsverletzungen',
#   'entfernt'],
#  ['kann',
#   'eine',
#   'person',
#   'nachweisen',
#   'dass',
#   'sie',
#   'urheber',
#   'einer',
#   'grafik',
#   'ist',
#   'wird',
#   'diese',
#   'immer',
#   'von',
#   'facebook',
#   'entfernt'],
#  ['dies', 'war', 'also', 'bei', 'uns', 'nicht', 'der', 'fall'],
#  ['daraus',
#   'resultiert',
#   'dass',
#   'die',
#   'begründung',
#   'glatt',
#   'gelogen',
#   'ist'],
#  ['wir',
#   'stellen',
#   'zudem',
#   'fest',
#   'dass',
#   'andere',
#   'patriotische',
#   'seiten',
#   'mit',
#   'der',
#   'gleichen',
#   'begründung',
#   'für',
#   'das',
#   'posten',
#   'von',
#   'medien',
#   'gesperrt',
#   'wurden'],
#  ['fakt',
#   'ist',
#   'dass',
#   'facebook',
#   'und',
#   'die',
#   'bundesregierung',
#   'mit',
#   'der',
#   'stiftung',
#   'der',
#   'ehemaligen',
#   'stasi-spionin',
#   'frau',
#   'anetta',
#   'kahane',
#   'der',
#   'amadeu',
#   'antonio',
#   'stiftung',
#   'zusammen',
#   'arbeitet'],
#  ['zusammen',
#   'will',
#   'diese',
#   'personengruppe',
#   'hasskommentare',
#   'bei',
#   'facebook',
#   'bekämpfen'],
#  ['wer',
#   'genau',
#   'dort',
#   'welche',
#   'aufgabe',
#   'hat',
#   'ist',
#   'absolut',
#   'undurchsichtig',
#   'und',
#   'nicht',
#   'nachvollziehbar'],
#  ['kurz',
#   'nach',
#   'dem',
#   'beginn',
#   'dieser',
#   'zusammenarbeit',
#   'wurden',
#   'viele',
#   'bilder',
#   'von',
#   'unserer',
#   'seite',
#   'gelöscht',
#   'weil',
#   'sie',
#   'angeblich',
#   'gegen',
#   'die',
#   'facebook',
#   'gemeinschaftsstandards',
#   'verstoßen',
#   'zufall'],
#  ['wir',
#   'fühlen',
#   'uns',
#   'zum',
#   'ersten',
#   'mal',
#   'machtlos',
#   'und',
#   'unterdrückt'],
#  ['die', 'zensur', 'ist', 'in', 'deutschland', 'nun', 'alltag'],
#  ['die',
#   'bundesregierung',
#   'will',
#   'verhindern',
#   'dass',
#   'wir',
#   'unsere',
#   'kräfte',
#   'bündeln',
#   'und',
#   'uns',
#   'organisieren'],
#  ['wir',
#   'geben',
#   'jedoch',
#   'nicht',
#   'auf',
#   'und',
#   'werden',
#   'weiter',
#   'posten'],
#  ['allerdings',
#   'haben',
#   'bilder',
#   'und',
#   'videos',
#   'die',
#   'höchste',
#   'reichweite',
#   'weshalb',
#   'wir',
#   'vermutlich',
#   'nicht',
#   'mehr',
#   'wöchentlich',
#   'millionen',
#   'user',
#   'erreichen',
#   'werden'],
#  ['wir',
#   'prüfen',
#   'zudem',
#   'rechtliche',
#   'schritte',
#   'auch',
#   'wenn',
#   'das',
#   'vermutlich',
#   'keinen',
#   'erfolg',
#   'haben',
#   'wird',
#   'da',
#   'nicht',
#   'deutsches',
#   'recht',
#   'ausschlaggebend',
#   'ist'],
#  ['mit', 'lieben', 'grüßen', 'euer', 'admin-team'],
#  ['typisch', 'linke', 'presse'],
#  ['jeder',
#   'der',
#   'sich',
#   'für',
#   'sein',
#   'vaterland',
#   'einsetzt',
#   'ist',
#   'rechts',
#   'reaktionär',
#   'gar',
#   'ein',
#   'schlimmer',
#   'nazi'],
#  ['diesmal',
#   'hat',
#   'es',
#   'die',
#   'vernetzungsplattform',
#   'einprozent',
#   'erwischt'],
#  ['derzeit',
#   'können',
#   'wir',
#   'dank',
#   'willkürlicher',
#   'facebook-zensur',
#   'weder',
#   'bilder',
#   'noch',
#   'videos',
#   'verbreiten'],
#  ['doch', 'wir', 'lassen', 'uns', 'nicht', 'den', 'mund', 'verbieten'],
#  ['daher', 'wieso', 'nicht', 'einen', 'guten', 'textbeitrag', 'verbreiten'],
#  ['wir', 'erleben', 'die', "'jahre", 'der', 'entscheidung'],
#  ['es', 'geht', 'um', 'unser', 'land', 'unser', 'volk', 'um', 'europa'],
#  ['nicht', 'weniger', 'und', 'nicht', 'mehr'],
#  ['dringende', 'leseempfehlung'],
#  ['heute',
#   'haben',
#   'sich',
#   'alle',
#   'großen',
#   'online-medien',
#   'der',
#   'bundesrepublik',
#   'mächtig',
#   'blamiert'],
#  ['sie',
#   'meldeten',
#   'ohne',
#   'überprüfung',
#   'ein',
#   'syrer',
#   'sei',
#   'in',
#   'berlin',
#   'aufgrund',
#   'unmenschlicher',
#   'behandlung',
#   'durch',
#   'die',
#   'behörden',
#   'gestorben'],
#  ['nun',
#   'hat',
#   'sich',
#   'herausgestellt',
#   'ein',
#   'linker',
#   'flüchtlingshelfer',
#   'hat',
#   'den',
#   'tod',
#   'des',
#   'syrers',
#   'erfunden',
#   '..',
#   'kulturelle',
#   'bereicherung',
#   'in',
#   'schweden',
#   'schweden',
#   'ist',
#   'für',
#   'frauen',
#   'das',
#   'gefährlichste',
#   'land',
#   'außerhalb',
#   'afrikas',
#   'geworden',
#   'mit',
#   'einer',
#   'vergewaltigungshäufigkeit',
#   'die',
#   'zehnmal',
#   'höher',
#   'liegt',
#   'als',
#   'bei',
#   'seinen',
#   'europäischen',
#   'nachbarn'],
#  ['david', 'goldman', 'asia', 'tones'],
#  ['daimler', 'konnte', 'bis', 'jetzt', 'flüchtlinge', 'einstellen'],
#  ['für', 'praktika'],
#  ['superüberfachkräfte', 'halt'],
#  ['sehr',
#   'treffend',
#   'in',
#   'wahrheit',
#   'ist',
#   'den',
#   'politikern',
#   'das',
#   'volk',
#   'vollkommen',
#   'egal'],
#  ['es',
#   'gibt',
#   'bis',
#   'jetzt',
#   'nicht',
#   'das',
#   'allergeringste',
#   'abkommen',
#   'von',
#   'der',
#   'bisherigen',
#   'autogenozidalen',
#   'einwanderungs-politik'],
#  ['wenn',
#   'ein',
#   'partei-apparatschik',
#   'wirklich',
#   'von',
#   'den',
#   'schrecklichen',
#   'ereignissen',
#   'betroffen',
#   'wäre',
#   'so',
#   'müsste',
#   'er',
#   'ja',
#   'einsehen',
#   'dass',
#   'diese',
#   'politik',
#   'falsch',
#   'ist'],
#  ['er',
#   'müsste',
#   'eine',
#   'radikale',
#   'kehrtwende',
#   'machen',
#   'und',
#   'sich',
#   'beim',
#   'volk',
#   'entschuldigen',
#   'er',
#   'müsste',
#   'um',
#   'verzeihung',
#   'betteln',
#   'weil',
#   'ihn',
#   'seine',
#   'schuld',
#   'so',
#   'sehr',
#   'bedrückt'],
#  ['doch', 'nichts', 'dergleichen', 'geschieht'],
#  ['die',
#   'politische',
#   'klasse',
#   'befiehlt',
#   'die',
#   'derzeitigen',
#   'verbrechen',
#   'weil',
#   'sie',
#   'sie',
#   'nicht',
#   'verhindert',
#   'obwohl',
#   'sie',
#   'könnte',
#   'wenn',
#   'sie',
#   'nur',
#   'wollte'],
#  ['diese',
#   'heuchelei',
#   'ist',
#   'absolut',
#   'widerlich',
#   'und',
#   'wir',
#   'sollten',
#   'ihr',
#   'vor',
#   'allem',
#   'mit',
#   'einem',
#   'begegnen',
#   'zorn'],
#  ['die',
#   'verfassungsbeschwerde',
#   'von',
#   'ein',
#   'prozent',
#   'für',
#   'unser',
#   'land',
#   'und',
#   'prof.',
#   'schachtschneider',
#   'startet'],
#  ['besorgte',
#   'bürger',
#   'klagen',
#   'gegen',
#   'einen',
#   'staat',
#   'der',
#   'mit',
#   'seiner',
#   'asylpolitik',
#   'unser',
#   'aller',
#   'zukunft',
#   'gefährdet'],
#  ['merkel', 'muss', 'weg'],
#  ['grenzen', 'dicht'],
#  ['viele',
#   'branchen',
#   'verdienen',
#   'gut',
#   'an',
#   'der',
#   'flüchtlingskrise',
#   'und',
#   'der',
#   'deutsche',
#   'steuerzahler',
#   'zahlt'],
#  ['teilweise',
#   'fahren',
#   'flüchtlinge',
#   'für',
#   'ein',
#   'paar',
#   'hundert',
#   'meter',
#   'zum',
#   'arztbesuch',
#   'mit',
#   'dem',
#   'taxi'],
#  ['schaut', 'euch', 'das', 'video', 'in', 'dem', 'beitrag', 'an'],
#  ['hammerpost', 'von', 'felix', 'baumgarter'],
#  ['die',
#   'kurzfassung',
#   'der',
#   'verfassungsbeschwerde',
#   'von',
#   'professor',
#   'schachtschneider',
#   'und',
#   'ein',
#   'ein',
#   'prozent',
#   'für',
#   'unser',
#   'land',
#   'ist',
#   'nun',
#   'online',
#   'und',
#   'kann',
#   'eingesehen',
#   'werden'],
#  ['ein',
#   'ziel',
#   'die',
#   'amtsenthebung',
#   'von',
#   'angela',
#   'merkel',
#   'und',
#   'sigmar',
#   'gabriel'],
#  ['diese',
#   'aussage',
#   'petrys',
#   'treibt',
#   'den',
#   'hochleistungs-gutmenschen',
#   'den',
#   'schaum',
#   'vor',
#   'den',
#   'mund'],
#  ['doch',
#   'merke',
#   '§',
#   'schußwaffengebrauch',
#   'im',
#   'grenzdienst',
#   'die',
#   'in',
#   '§',
#   'nr'],
#  ['und',
#   'genannten',
#   'vollzugsbeamten',
#   'können',
#   'im',
#   'grenzdienst',
#   'schußwaffen',
#   'auch',
#   'gegen',
#   'personen',
#   'gebrauchen',
#   'die',
#   'sich',
#   'der',
#   'wiederholten',
#   'weisung',
#   'zu',
#   'halten',
#   'oder',
#   'die',
#   'überprüfung',
#   'ihrer',
#   'person',
#   'oder',
#   'der',
#   'etwa',
#   'mitgeführten',
#   'beförderungsmittel',
#   'und',
#   'gegenstände',
#   'zu',
#   'dulden',
#   'durch',
#   'die',
#   'flucht',
#   'zu',
#   'entziehen',
#   'versuchen'],
#  ['ist',
#   'anzunehmen',
#   'daß',
#   'die',
#   'mündliche',
#   'weisung',
#   'nicht',
#   'verstanden',
#   'wird',
#   'so',
#   'kann',
#   'sie',
#   'durch',
#   'einen',
#   'warnschuß',
#   'ersetzt',
#   'werden'],
#  ['als',
#   'grenzdienst',
#   'gilt',
#   'auch',
#   'die',
#   'durchführung',
#   'von',
#   'bundes-',
#   'und',
#   'landesaufgaben',
#   'die',
#   'den',
#   'in',
#   'absatz',
#   'bezeichneten',
#   'personen',
#   'im',
#   'zusammenhang',
#   'mit',
#   'dem',
#   'grenzdienst',
#   'übertragen',
#   'sind',
#   '..',
#   'sie',
#   'müssen',
#   'alle',
#   'an',
#   'der',
#   'grenze',
#   'abgewiesen',
#   'werden'],
#  ['compact-magazin',
#   'hat',
#   'die',
#   'gestrige',
#   'pressekonferenz',
#   'in',
#   'berlin',
#   'zur',
#   'verfassungsbeschwerde',
#   'von',
#   'prof.',
#   'schachtschneider',
#   'und',
#   'ein',
#   'prozent',
#   'für',
#   'unser',
#   'land',
#   'in',
#   'voller',
#   'länge',
#   'aufgezeichnet'],
#  ['hier', 'das', 'video'],
#  ['es', 'schmerzt'],
#  ['es', 'beängstigt'],
#  ['es', 'kränkt'],
#  ['warum',
#   'warum',
#   'frage',
#   'ich',
#   'mich',
#   'muss',
#   'ich',
#   'mich',
#   'gegen',
#   'meine',
#   'freunde',
#   'stellen',
#   'warum',
#   'jenen',
#   'widersprechen',
#   'die',
#   'mir',
#   'nahe',
#   'sind'],
#  ['warum',
#   'muss',
#   'ich',
#   'fürchten',
#   'nicht',
#   'verstanden',
#   'zu',
#   'werden',
#   'warum',
#   'muss',
#   'ich',
#   'fürchten',
#   'zu',
#   'verlieren',
#   'was',
#   'mir',
#   'lieb',
#   'und',
#   'recht',
#   'ist'],
#  ['gewiss',
#   'kennt',
#   'ihr',
#   'das',
#   'brennende',
#   'nagende',
#   'gefühl',
#   'der',
#   'inneren',
#   'zerissenheit',
#   'die',
#   'zu',
#   'beiden',
#   'seiten',
#   'nach',
#   'euch',
#   'zerrt',
#   'und',
#   'euch',
#   'in',
#   'ketten',
#   'legt'],
#  ['die',
#   'eine',
#   'kette',
#   'zerrend',
#   'hin',
#   'zum',
#   'recht',
#   'hin',
#   'zu',
#   'den',
#   'eigenen',
#   'idealen',
#   'hin',
#   'zu',
#   'dem',
#   'was',
#   'man',
#   'als',
#   'gut',
#   'und',
#   'richtig',
#   'vor',
#   'allem',
#   'als',
#   'notwendig',
#   'erkannt',
#   'hat',
#   'die',
#   'andere',
#   'zerrend',
#   'hin',
#   'zur',
#   'gemeinschaft',
#   'zur',
#   'bequemlichkeit',
#   'zur',
#   'vermeintlichen',
#   'sicherheit',
#   'dem',
#   'sozialen',
#   'auffangbecken',
#   'das',
#   'einen',
#   'schützt',
#   'vor',
#   'dem',
#   'sturm',
#   'des',
#   'politischen',
#   'kampfes',
#   'das',
#   'einen',
#   'bequem',
#   'einlullt',
#   'mit',
#   'musik',
#   'feiern',
#   'und',
#   'viel',
#   'zu',
#   'lachen'],
#  ['wer',
#   'will',
#   'denn',
#   'durch',
#   'die',
#   'tür',
#   'treten',
#   'alleine',
#   'in',
#   'den',
#   'kalten',
#   'regen',
#   'hinaus',
#   'der',
#   'einem',
#   'stürmisch',
#   'ins',
#   'gesicht',
#   'schlägt',
#   'während',
#   'alle',
#   'anderen',
#   'noch',
#   'in',
#   'der',
#   'warmen',
#   'stube',
#   'hocken',
#   'und',
#   'ihre',
#   'gesellschaft',
#   'bei',
#   'gutem',
#   'getränk',
#   'genießen',
#   'und',
#   'das',
#   'leben',
#   'feiern'],
#  ['das',
#   'unwetter',
#   'ist',
#   'schließlich',
#   'nur',
#   'draußen',
#   'warum',
#   'sollte',
#   'man',
#   'sich',
#   'dem',
#   'also',
#   'stellen'],
#  ['flüchtlinge', 'kosten', 'deutschland', 'bis', 'rund', 'milliarden', 'euro'],
#  ['das',
#   'ist',
#   'jetzt',
#   'die',
#   'stunde',
#   'wo',
#   'wir',
#   'uns',
#   'mit',
#   'der',
#   'juristischen',
#   'potenz',
#   'von',
#   'professor',
#   'schachtschneider',
#   'entschlossen',
#   'haben',
#   'die',
#   'dinge',
#   'selbst',
#   'ins',
#   'rollen',
#   'zu',
#   'bringen',
#   'und',
#   'aufzuzeigen',
#   'das',
#   'vertrauen',
#   'in',
#   'die',
#   'politik',
#   'ist',
#   'jetzt',
#   'am',
#   'ende'],
#  ['jetzt', 'muss', 'der', 'bürger', 'selbst', 'handeln'],
#  ['ein',
#   'prozent',
#   'für',
#   'unser',
#   'land',
#   'hat',
#   'die',
#   'wichtigsten',
#   'aussagen',
#   'der',
#   'pressekonferenz',
#   'mit',
#   'prof.',
#   'schachtschneider',
#   'zusammengefasst'],
#  ['singles', 'und', 'fachkräfte', 'mit', 'niveau'],
#  ['deutschland',
#   'ist',
#   'ein',
#   'merkwürdiges',
#   'land',
#   'wer',
#   'die',
#   'gültige',
#   'rechtslage',
#   'zitiert',
#   'macht',
#   'sich',
#   'verdächtig',
#   'radikal',
#   'zu',
#   'sein'],
#  ['polizei',
#   'findet',
#   'brandsatz',
#   'an',
#   'ice-strecke',
#   'zwischen',
#   'berlin',
#   'und',
#   'hannover'],
#  ['die',
#   'strafverfolgungsbehörden',
#   'vermuten',
#   'die',
#   'hintermänner',
#   'in',
#   'der',
#   'linksextremen',
#   'szene'],
#  ['der',
#   'berliner',
#   'senat',
#   'verhandelt',
#   'mit',
#   'einer',
#   'hotelkette',
#   'über',
#   'die',
#   'längerfristige',
#   'anmietung',
#   'von'],
#  ['hotelplätzen', 'für', 'flüchtlinge'],
#  ['da',
#   'der',
#   'senat',
#   'dem',
#   'vernehmen',
#   'nach',
#   'interesse',
#   'an',
#   'einer',
#   'mehrjährigen',
#   'laufzeit',
#   'des',
#   'mietvertrags',
#   'hat',
#   'liefe',
#   'es',
#   'auf',
#   'ein',
#   'volumen',
#   'von',
#   'mindestens',
#   'millionen',
#   'euro',
#   'hinaus'],
#  ['die', 'krise', 'ist', 'gelöst'],
#  ['statt',
#   'unsere',
#   'werte',
#   'zu',
#   'lernen',
#   'kriegen',
#   'flüchtlinge',
#   'jetzt',
#   'erstmal',
#   'neue',
#   'scheisshäuser'],
#  ['in',
#   'den',
#   'letzten',
#   'tagen',
#   'konnten',
#   'wir',
#   'mal',
#   'wieder',
#   'eine',
#   'enorme',
#   'mediale',
#   'hetzjagd',
#   'gegen',
#   'die',
#   'afd',
#   'mitverfolgen'],
#  ['grund',
#   'dafür',
#   'war',
#   'die',
#   'äußerung',
#   'von',
#   'frauke',
#   'petry',
#   'in',
#   'der',
#   'sie',
#   'den',
#   'gebrauch',
#   'von',
#   'schusswaffen',
#   'zur',
#   'verteidigung',
#   'der',
#   'außengrenzen',
#   'ansprach',
#   'und',
#   'somit',
#   'nur',
#   'an',
#   'geltendes',
#   'recht',
#   'erinnerte'],
#  ['man',
#   'muss',
#   'hier',
#   'nochmal',
#   'klar',
#   'betonen',
#   'dass',
#   'dies',
#   'kein',
#   'neuer',
#   'vorstoß',
#   'seitens',
#   'der',
#   'afd',
#   'war',
#   'sondern',
#   'nur',
#   'an',
#   'geltendes',
#   'recht',
#   'erinnert',
#   'wurde'],
#  ['nun',
#   'ist',
#   'uns',
#   'ein',
#   'anderer',
#   'bericht',
#   'in',
#   'die',
#   'hände',
#   'gefallen',
#   'in',
#   'den',
#   'ein',
#   'cdu',
#   'abgeordneter',
#   'einen',
#   'tatsächlich',
#   'vorstoß',
#   'wagt'],
#  ['und',
#   'zwar',
#   'möchte',
#   'er',
#   'gerne',
#   'die',
#   'rechte',
#   'der',
#   'polizei',
#   'ausweiten',
#   'dass',
#   'auch',
#   'schneller',
#   'schusswaffen',
#   'eingesetzt',
#   'werden',
#   'dürfen'],
#  ['und', 'was', 'passiert'],
#  ['ein',
#   'niedersächsischer',
#   'landtagsabgeordneter',
#   'fordert',
#   'eine',
#   'drastische',
#   'ausweitung',
#   'der',
#   'rechte',
#   'für',
#   'polizeibeamte',
#   'bei',
#   'ausschreitungen',
#   'wie',
#   'in',
#   'der',
#   'silvesternacht',
#   'in',
#   'köln',
#   'sollen',
#   'sie',
#   'auch',
#   'schusswaffen',
#   'einsetzen',
#   'dürfen'],
#  ['die', 'polizei', 'ist', 'jedoch', 'wenig', 'begeistert'],
#  ['schweizer',
#   'schule',
#   'führt',
#   'deutsch-pflicht',
#   'auf',
#   'dem',
#   'pausen-hof',
#   'ein',
#   'eine',
#   'schweizer',
#   'primarschule',
#   'führt',
#   'eine',
#   'strenge',
#   'sprachregelung',
#   'ein',
#   'auf',
#   'dem',
#   'schul-gelände',
#   'muss',
#   'deutsch',
#   'gesprochen',
#   'werden'],
#  ['wer',
#   'sich',
#   'nicht',
#   'daran',
#   'hält',
#   'dem',
#   'drohen',
#   'strafen',
#   'bis',
#   'zu',
#   'franken',
#   '..',
#   'heiko',
#   'maas',
#   'hat',
#   'seine',
#   'task',
#   'force',
#   'gegen',
#   'hetze',
#   'im',
#   'internet',
#   'sprich',
#   'die',
#   'denunziantentruppe',
#   'um',
#   'den',
#   'ehemaligen',
#   'stasi',
#   'spitzel',
#   'anetta',
#   'kahane',
#   'von',
#   'der',
#   'leine',
#   'gelassen'],
#  ['maas',
#   'truppe',
#   'gegen',
#   'die',
#   'meinungsfreiheit',
#   'hat',
#   'sich',
#   'sogleich',
#   'an',
#   'die',
#   'arbeit',
#   'gemacht',
#   'und',
#   'auch',
#   'unsere',
#   'seite',
#   'mit',
#   'kindischen',
#   'schikanen',
#   'belegt',
#   'tage',
#   'langen',
#   'dürften',
#   'wir',
#   'keine',
#   'bilder',
#   'mehr',
#   'posten',
#   'oder',
#   'videos',
#   'hochladen'],
#  ['also',
#   'wer',
#   'sich',
#   'nicht',
#   'politisch',
#   'korrekt',
#   'äußert',
#   'wird',
#   'mundtot',
#   'gemacht'],
#  ['denkt',
#   'daran',
#   'unsere',
#   'ersatzseite',
#   'ich',
#   'bin',
#   'patriot',
#   'und',
#   'kein',
#   'nazi',
#   'zu',
#   'liken'],
#  ['eine',
#   'löschung',
#   'dieser',
#   'und',
#   'auch',
#   'anderer',
#   'patriotischer',
#   'seiten',
#   'wird',
#   'jedenfalls',
#   'immer',
#   'wahrscheinlicher'],
#  ['deswegen',
#   'vernetzt',
#   'euch',
#   'helft',
#   'euch',
#   'gegenseitig',
#   'geht',
#   'auf',
#   'die',
#   'straße',
#   'und',
#   'nehmt',
#   'bei',
#   'den',
#   'nächsten',
#   'drei',
#   'landtagswahlen',
#   'größtmöglichen',
#   'einfluss'],
#  ['vielen',
#   'dank',
#   'bis',
#   'hierhin',
#   'für',
#   'eure',
#   'großartige',
#   'unterstützung',
#   'über',
#   'jahre',
#   'hinweg'],
#  ['wir', 'schaffen', 'das'],
#  ['-p.',
#   'im',
#   'schleswig-holsteinischen',
#   'kiel',
#   'wurde',
#   'montag',
#   'ein',
#   'jähriger',
#   'turkmene',
#   'verhaftet'],
#  ['er',
#   'hatte',
#   'am',
#   'sonntag',
#   'ein',
#   'jahre',
#   'altes',
#   'mädchen',
#   'von',
#   'einem',
#   'spielplatz',
#   'gelockt',
#   'und',
#   'anschließend',
#   'in',
#   'seiner',
#   'wohnung',
#   'schwer',
#   'sexuell',
#   'missbraucht'],
#  ['anschließend',
#   'ließ',
#   'er',
#   'das',
#   'kind',
#   'frei',
#   'welches',
#   'sich',
#   'dann',
#   'der',
#   'mutter',
#   'anvertraute'],
#  ['die',
#   'mediziner',
#   'der',
#   'polizei',
#   'stellten',
#   'schwere',
#   'verletzungen',
#   'fest'],
#  ['warum', 'berichten', 'wir', 'von', 'diesen', 'menschlichen', 'abgründen'],
#  ['weil', 'der', 'täter', 'bereits', 'verdächtigt', 'wurde', 'am'],
#  ['januar',
#   'ein',
#   'jahre',
#   'altes',
#   'mädchen',
#   'sexuell',
#   'bedrängt',
#   'zu',
#   'haben'],
#  ['unsere', 'justiz', 'ist', 'ein', 'witz'],
#  ['selbst',
#   'cdu-topmann',
#   'wolfgang',
#   'bosbach',
#   'nimmt',
#   'die',
#   'afd',
#   'in',
#   'schutz',
#   '..',
#   'seehofer',
#   'macht',
#   'viel',
#   'wind',
#   'lässt',
#   'aber',
#   'keine',
#   'taten',
#   'folgen'],
#  ['typisch', 'für', 'unsere', 'bundesdeutsche', 'politikerkaste'],
#  ['die',
#   'bürgerinitiative',
#   'einprozent',
#   'hat',
#   'diesen',
#   'betrug',
#   'am',
#   'wähler',
#   'zusammengefasst',
#   'und',
#   'ein',
#   'interessantes',
#   'fazit',
#   'gezogen',
#   'fast',
#   'jeder',
#   'zweite',
#   'deutsche',
#   'könnte',
#   'sich',
#   'potenziell',
#   'auch',
#   'schachtschneiders',
#   'verfassungsbeschwerde',
#   'anschließen'],
#  ['die',
#   'voraussichtlichen',
#   'kosten',
#   'der',
#   'asylkrise',
#   'wird',
#   'dem',
#   'deutschen',
#   'steuerzahler',
#   'knapp',
#   'milliarden',
#   'euro',
#   'bis',
#   'ende',
#   'kosten'],
#  ['geld',
#   'dass',
#   'wir',
#   'anscheinend',
#   'im',
#   'überfluss',
#   'besitzen',
#   'da',
#   'trotz',
#   'allen',
#   'dem',
#   'herr',
#   'schäuble',
#   'an',
#   'der',
#   'schwarzen',
#   'null',
#   'festhalten',
#   'und',
#   'somit',
#   'die',
#   'ausgaben',
#   'effizienter',
#   'gestalten',
#   'möchte'],
#  ['aha',
#   'jahrzehntelang',
#   'war',
#   'es',
#   'nicht',
#   'möglich',
#   'unseren',
#   'alten',
#   'oder',
#   'kranken',
#   'mehr',
#   'geld',
#   'für',
#   'ein',
#   'menschenwürdiges',
#   'zu',
#   'geben',
#   'aber',
#   'jetzt',
#   'gibt',
#   'es',
#   'augenscheinlich',
#   'geld',
#   'im',
#   'überfluss'],
#  ['in',
#   'den',
#   'letzten',
#   'jahren',
#   'hat',
#   'deutschen',
#   'mehrere',
#   'hunderte',
#   'milliarden',
#   'in',
#   'griechenland',
#   'und',
#   'in',
#   'die',
#   'eu',
#   'gepumpt'],
#  ['jetzt',
#   'werden',
#   'weitere',
#   'milliarden',
#   'in',
#   'die',
#   'verpflegung',
#   'und',
#   'unterbringung',
#   'von',
#   'asylanten',
#   'gesteckt'],
#  ['ich',
#   'frage',
#   'mich',
#   'wissen',
#   'diese',
#   'idioten',
#   'eigentlich',
#   'dass',
#   'wir',
#   'dieses',
#   'geld',
#   'ran',
#   'schaffen'],
#  ['das',
#   'diese',
#   'idioten',
#   'mit',
#   'unserem',
#   'geld',
#   'umgehen',
#   'als',
#   'wäre',
#   'es',
#   'denen',
#   'ihres'],
#  ['fassungslos',
#   'und',
#   'wir',
#   'sind',
#   'weiterhin',
#   'so',
#   'blöd',
#   'und',
#   'stecken',
#   'denen',
#   'abermilliarden',
#   'in',
#   'den',
#   'rachen'],
#  ['wenn', 'die', 'deutschen', 'zusammenhalten', 'dann'],
#  ['voll', 'endet', 'diesen', 'satz'],
#  ['eil', 'meldung'],
#  ['marine',
#   'le',
#   'pen',
#   'vorsitzende',
#   'der',
#   'französischen',
#   'partei',
#   'front',
#   'national',
#   'und',
#   'eine',
#   'von',
#   'fraktionsvorsitzenden',
#   'der',
#   'fraktion',
#   'enf',
#   'europa',
#   'der',
#   'nationen',
#   'und',
#   'der',
#   'freiheit',
#   'im',
#   'europäischen',
#   'parlament',
#   'mit',
#   'klartext',
# ...
#   'durch',
#   'den',
#   'salafismus',
#   'und',
#   'über',
#   'die',
#   'zu',
#   'erwartenden',
#   'veränderungen',
#   'in',
#   'unserer',
#   'gesellschaft',
#   'die',
#   'hunderttausende',
#   'von',
#   'männlichen',
#   'muslimischen',
#   'asylbewerbern',
#   'verursachen',
#   'werden'],
#  ['im',
#   'gegenteil',
#   'diese',
#   'diskussionen',
#   'werden',
#   'in',
#   'deutschland',
#   'unterdrückt',
#   'der',
#   'zorn',
#   'unseres',
#   'establishments',
#   'richtet',
#   'sich',
#   'gegen',
#   'die',
#   'eigenen',
#   'bürger',
#   'gegen',
#   'diejenigen',
#   'die',
#   'in',
#   'patriotischer',
#   'liebe',
#   'zu',
#   'ihrem',
#   'land',
#   'stehen'],
#  ['in',
#   'einer',
#   'angeblich',
#   'demokratischen',
#   'gesellschaft',
#   'muss',
#   'es',
#   'ja',
#   'wohl',
#   'möglich',
#   'sein',
#   'einen',
#   'offenen',
#   'diskurs',
#   'über',
#   'die',
#   'gefahren',
#   'der',
#   'unkontrollierten',
#   'asyl-flutung',
#   'zu',
#   'führen'],
#  ['stattdessen',
#   'versuchen',
#   'diese',
#   'linken',
#   'keine',
#   'grenze',
#   'keine',
#   'nation',
#   'ideologen',
#   'jede',
#   'debatte',
#   'zu',
#   'verhindern'],
#  ['aber',
#   'ist',
#   'es',
#   'nicht',
#   'ganz',
#   'natürlich',
#   'dass',
#   'die',
#   'menschen',
#   'besorgt',
#   'sind',
#   'über',
#   'den',
#   'verlust',
#   'ihrer',
#   'heimat',
#   'ihrer',
#   'werte',
#   'ihrer',
#   'kultur',
#   'und',
#   'letztendlich',
#   'auch',
#   'ihrer',
#   'freiheit'],
#  ['es',
#   'gibt',
#   'nicht',
#   'einmal',
#   'eine',
#   'politische',
#   'partei',
#   'in',
#   'deutschland',
#   'die',
#   'sich',
#   'diesen',
#   'sorgen',
#   'der',
#   'deutschen',
#   'ernsthaft',
#   'annimmt'],
#  ['pegida', 'aufdiestraße', 'montagistpegidatag', 'dresdnerthesen'],
#  ['wir',
#   'sind',
#   'in',
#   'der',
#   'lage',
#   'tag',
#   'für',
#   'tag',
#   'woche',
#   'für',
#   'woche',
#   'und',
#   'monat',
#   'für',
#   'monat',
#   'tausende',
#   'menschen',
#   'an',
#   'flughäfen',
#   'zu',
#   'registrieren',
#   'und',
#   'zu',
#   'kontrollieren'],
#  ['aber',
#   'wir',
#   'sind',
#   'nicht',
#   'im',
#   'stande',
#   'dazu',
#   'dies',
#   'auch',
#   'an',
#   'unseren',
#   'grenzen',
#   'durchzuführen'],
#  ['merkteuchdienamen',
#   'lügenpresse',
#   'linksfaschistenstoppen',
#   'keinfussbreitlinkenfaschisten',
#   'santifa',
#   'antifanten',
#   'montagistpegidatag'],
#  ['wann',
#   'begreifen',
#   'die',
#   'journalistischen',
#   'tiefflieger',
#   'dass',
#   'weder',
#   'thügida',
#   'noch',
#   'dügida',
#   'glaub',
#   'm.',
#   'dittmer',
#   'macht',
#   'das'],
#  ['zu', 'pegida', 'gehören'],
#  ['alle',
#   'offiziellen',
#   'ableger',
#   'von',
#   'pegida',
#   'haben',
#   'sich',
#   'zum',
#   'positionspapier',
#   'von',
#   'pegida',
#   'den',
#   'dresdner',
#   'thesen',
#   'und',
#   'der',
#   'demokratischen',
#   'grundordnung',
#   'bekannt',
#   'und',
#   'führen',
#   'den',
#   'namen',
#   'pegida',
#   '+region',
#   'im',
#   'namen'],
#  ['auch',
#   'ist',
#   'in',
#   'den',
#   'satzungen',
#   'der',
#   'offiziellen',
#   'pegida-vereine',
#   'jeweils',
#   'ganz',
#   'fest',
#   'eine',
#   'extremismus-klausel',
#   'verankert',
#   'welche',
#   'ein',
#   'abdriften',
#   'in',
#   'richtung',
#   'links-',
#   'oder',
#   'rechtsextremismus',
#   'unmöglich',
#   'macht'],
#  ['unfassbar',
#   'wie',
#   'die',
#   'breit',
#   'aufgestellte',
#   'bürgerbewegung',
#   'diffamiert',
#   'wird',
#   'wegen',
#   'leuten',
#   'die',
#   'unseren',
#   'namen',
#   'missbrauchen',
#   'indem',
#   'sie',
#   'sich',
#   'irgendwie',
#   'als',
#   'x-gida',
#   'benennen'],
#  ['beste',
#   'beispiele',
#   'für',
#   'missbrauch',
#   'sind',
#   'gida-regional',
#   'thügida',
#   'dügida',
#   'hh-gida',
#   'usw'],
#  ['einzig',
#   'legida',
#   'ist',
#   'aufgrund',
#   'der',
#   'hervorragenden',
#   'arbeit',
#   'des',
#   'teams',
#   'um',
#   'markus',
#   'in',
#   'leipzig',
#   'und',
#   'da',
#   'es',
#   'mittlerweile',
#   'eine',
#   'echte',
#   'marke',
#   'und',
#   'institution',
#   'geworden',
#   'ist',
#   'berechtigt',
#   'den',
#   'mittlerweile',
#   'weithin',
#   'bekannten',
#   'namen',
#   'zu',
#   'behalten',
#   'und',
#   'sich',
#   'nicht',
#   'in',
#   'pegida-leipzig',
#   'umbenennen'],
#  ['eine',
#   'liste',
#   'der',
#   'offiziellen',
#   'ableger',
#   'findet',
#   'ihr',
#   'auf',
#   'der',
#   'facebookseite',
#   'pegida',
#   'deutschland'],
#  ['pegida',
#   'montagistpegidatag',
#   'pegidadieechtealternative',
#   'pegidadieeinzigealternative'],
#  ['uno',
#   'tschechien',
#   'ist',
#   'islamfeindlich',
#   'und',
#   'behandelt',
#   'die',
#   'migranten',
#   'schlecht',
#   'durchhalten',
#   'solidarität',
#   'mit',
#   'tschechien'],
#  ['y',
#   'die',
#   'uno',
#   'wirft',
#   'tschechien',
#   'eine',
#   'systematische',
#   'verletzung',
#   'der',
#   'menschenrechte',
#   'und',
#   'eine',
#   'abschreckungspolitik',
#   'gegen',
#   'flüchtlinge',
#   'vor'],
#  ['die', 'regierung', 'wies', 'die', 'kritik', 'umgehend', 'zurück'],
#  ['präsident',
#   'zeman',
#   'warnt',
#   'weiterhin',
#   'vor',
#   'islamischem',
#   'fundamentalismus'],
#  ['pegida',
#   'tschechien',
#   'czech',
#   'aufdiestraße',
#   'montagistpegidatag',
#   'direktedemokratiejetzt',
#   'grenzendicht'],
#  ['verheimlicht', 'die', 'polizei', 'brisante', 'straftaten'],
#  ['ach',
#   'quatsch',
#   'die',
#   'traumatisierten',
#   'ärzte',
#   'ingenieure',
#   'und',
#   'raketenwissenschaftler',
#   'machen',
#   'doch',
#   'nix',
#   'und',
#   'daher',
#   'ist',
#   'das',
#   'bestimmt',
#   'nur',
#   'stimmungsmache',
#   'gegen',
#   'asylforderer',
#   'oder'],
#  ['nein', 'ist', 'es', 'nicht'],
#  ['es',
#   'wird',
#   'systematisch',
#   'versucht',
#   'die',
#   'menschen',
#   'für',
#   'dumm',
#   'zu',
#   'verkaufen',
#   'es',
#   'werden',
#   'statistiken',
#   'gefälscht',
#   'und',
#   'die',
#   'neueste',
#   'masche',
#   'ist',
#   'das',
#   'sogenannte',
#   'anonymisieren',
#   'von',
#   'einsatzprotokollen',
#   'und',
#   'strafanzeigen'],
#  ['so',
#   'wird',
#   'versucht',
#   'das',
#   'bild',
#   'der',
#   'armen',
#   'hilfsbedürftigen',
#   'menschen',
#   'aufrecht',
#   'zu',
#   'erhalten',
#   'solang',
#   'es',
#   'geht'],
#  ['und',
#   'so',
#   'können',
#   'teile',
#   'von',
#   'ihnen',
#   'weiter',
#   'stehlend',
#   'raubend',
#   'vergewaltigend',
#   'und',
#   'mordend',
#   'durch',
#   'europa',
#   'ziehen',
#   'während',
#   'die',
#   'wirklich',
#   'hilfsbedürftigen',
#   'im',
#   'kriegsgebiet',
#   'sitzen',
#   'und',
#   'für',
#   'ihre',
#   'länder',
#   'kämpfen',
#   'ohne',
#   'das',
#   'die',
#   'europäische',
#   'bevölkerung',
#   'vom',
#   'wahren',
#   'ausmaß',
#   'erfährt'],
#  ['aus',
#   'dem',
#   'artikel',
#   'viele',
#   'dieser',
#   'fälle',
#   'die',
#   'als',
#   'relevante',
#   'ereignisse',
#   'erachtet',
#   'werden',
#   'sind',
#   'der',
#   'öffentlichkeit',
#   'vorenthalten',
#   'worden',
#   'und',
#   'keine',
#   'pressemeldungen',
#   'gab',
#   'es',
#   'zur',
#   'besetzung',
#   'einer',
#   'arztpraxis',
#   'der',
#   'bedrohung',
#   'einer',
#   'augenärztin',
#   'oder',
#   'tumultartigen',
#   'szenen',
#   'in',
#   'einer',
#   'lübecker',
#   'erstaufnahmeeinrichtung',
#   'mit',
#   'mindestens',
#   'beteiligten'],
#  ['aus',
#   'internen',
#   'aufzeichnungen',
#   'geht',
#   'hervor',
#   'dass',
#   'letzterer',
#   'vorfall',
#   'nicht',
#   'ohne',
#   'das',
#   'mitwirken',
#   'zufällig',
#   'anwesender',
#   'bundeswehrsoldaten',
#   'hätte',
#   'bewältigt',
#   'werden',
#   'können'],
#  ['der',
#   'regionalchef',
#   'der',
#   'kieler',
#   'nachrichten',
#   'michael',
#   'kluth',
#   'berichtet',
#   'von',
#   'politikmaulkorb',
#   'für',
#   'sein',
#   'blatt',
#   'sei',
#   'die',
#   'redaktion',
#   'am',
#   'donnerstagnachmittag',
#   'von',
#   'der',
#   'landespolizei',
#   'aufgefordert',
#   'worden',
#   'auf',
#   'eine',
#   'berichterstattung',
#   'über',
#   'die',
#   'lagebilder',
#   'flüchtlingsthematik',
#   'zu',
#   'verzichten'],
#  ['das',
#   'blatt',
#   'würde',
#   'mit',
#   'dem',
#   'heiklen',
#   'text',
#   'zündeln',
#   'er',
#   'sagt',
#   'dazu',
#   'der',
#   'mut',
#   'zur',
#   'realität',
#   'hat',
#   'sich',
#   'in',
#   'polizei',
#   'und',
#   'politik',
#   'offenbar',
#   'noch',
#   'nicht',
#   'hinreichend',
#   'durchgesetzt'],
#  ['die',
#   'presse',
#   'zündelt',
#   'also',
#   'wenn',
#   'sie',
#   'die',
#   'wahrheit',
#   'über',
#   'die',
#   'flüchtlingsthematik',
#   'veröffentlicht'],
#  ['es',
#   'entwickelt',
#   'sich',
#   'immer',
#   'mehr',
#   'zum',
#   'totalitären',
#   'regime',
#   'und',
#   'imerika',
#   'sich',
#   'zur',
#   'diktatorin'],
#  ['wer',
#   'hier',
#   'keine',
#   'übereinstimmungen',
#   'mit',
#   'den',
#   'ern',
#   'und',
#   'ern',
#   'erkennt',
#   'dem',
#   'ist',
#   'nicht',
#   'zu',
#   'helfen'],
#  ['merkteuchdienamen',
#   'merkelmussweg',
#   'fastsonderschülersigmar',
#   'claudiafatimaroth',
#   'mischpokecem',
#   'göringeckardt',
#   'bundesgauckler',
#   'bundesinnenmisere',
#   'ausdenpalästenjagen',
#   'volksverräter'],
#  ['orban',
#   'einmarsch',
#   'einer',
#   'invasionsarmee',
#   'orbán',
#   'viktor',
#   'mal',
#   'wieder',
#   'mit',
#   'klartext',
#   'dieses',
#   'mal',
#   'auf',
#   'dem',
#   'kongress',
#   'der',
#   'europäischen',
#   'konservativen',
#   'in',
#   'madrid',
#   'an',
#   'dem',
#   'auch',
#   'unsere',
#   'bunte',
#   'kanzlerin',
#   'frau',
#   'dr.',
#   'angela',
#   'die',
#   'raute',
#   'des',
#   'grauens',
#   'merkel',
#   'teilnahm'],
#  ['y',
#   'vielleicht',
#   'hat',
#   'sie',
#   'ja',
#   'was',
#   'verstandennee',
#   'war',
#   'spaß'],
#  ['der',
#   'ungarische',
#   'staatschef',
#   'viktor',
#   'orban',
#   'hat',
#   'wieder',
#   'einmal',
#   'mit',
#   'einem',
#   'markigen',
#   'sager',
#   'zur',
#   'flüchtlingskrise',
#   'für',
#   'aufregung',
#   'gesorgt'],
#  ['bei',
#   'einem',
#   'parteikongress',
#   'in',
#   'madrid',
#   'erklärte',
#   'er',
#   'dass',
#   'es',
#   'sich',
#   'bei',
#   'dem',
#   'zustrom',
#   'nach',
#   'europa',
#   'um',
#   'den',
#   'einmarsch',
#   'einer',
#   'invasionsarmee',
#   'handle',
#   'und',
#   'nicht',
#   'um',
#   'kriegsflüchtlinge'],
#  ['orban',
#   'rief',
#   'dazu',
#   'auf',
#   'das',
#   'erbe',
#   'europas',
#   'gegenüber',
#   'einer',
#   'vorwiegend',
#   'männlichen',
#   'migrationsbewegung',
#   'zu',
#   'verteidigen'],
#  ['wir',
#   'stehen',
#   'nicht',
#   'einer',
#   'flüchtlingskrise',
#   'gegenüber',
#   'sagte',
#   'orban',
#   'am',
#   'donnerstag',
#   'beim',
#   'kongress',
#   'der',
#   'europäischen',
#   'konservativen',
#   'in',
#   'madrid'],
#  ['das',
#   'ist',
#   'eine',
#   'migrationsbewegung',
#   'bestehend',
#   'aus',
#   'wirtschaftsmigranten',
#   'flüchtlingen',
#   'und',
#   'ausländischen',
#   'kämpfern'],
#  ['alle',
#   'menschen',
#   'hätten',
#   'ein',
#   'recht',
#   'auf',
#   'sicherheit',
#   'und',
#   'würde',
#   'nicht',
#   'aber',
#   'auf',
#   'ein',
#   'leben',
#   'wie',
#   'in',
#   'ungarn',
#   'oder',
#   'deutschland'],
#  ['prozent',
#   'der',
#   'ankömmlinge',
#   'seien',
#   'männer',
#   'die',
#   'den',
#   'anschein',
#   'einer',
#   'armee',
#   'haben',
#   'so',
#   'orban'],
#  ['an',
#   'dem',
#   'kongress',
#   'nahmen',
#   'auch',
#   'andere',
#   'europäische',
#   'spitzenpolitiker',
#   'teil',
#   'so',
#   'etwa',
#   'deutschlands',
#   'bundeskanzlerin',
#   'angela',
#   'merkel',
#   'und',
#   'eu-',
#   'ratspräsident',
#   'donald',
#   'tusk'],
#  ['letzterer',
#   'beklagte',
#   'dabei',
#   'europa',
#   'habe',
#   'die',
#   'fähigkeit',
#   'verloren',
#   'seine',
#   'grenzen',
#   'zu',
#   'verteidigen'],
#  ['pegida',
#   'orban',
#   'fidesz',
#   'aufdiestraße',
#   'ungarn',
#   'hungary',
#   'grenzendicht'],
#  ['kinderbräute',
#   'wenn',
#   'die',
#   '-jährige',
#   'ehefrau',
#   'asyl',
#   'beantragt',
#   'wie',
#   'diverse',
#   'sicherheitsdienste',
#   'aus',
#   'den',
#   'heimen',
#   'unter',
#   'der',
#   'hand',
#   'berichten',
#   'ist',
#   'nicht',
#   'alles',
#   'eine',
#   'familie',
#   'was',
#   'nach',
#   'einer',
#   'familie',
#   'aussieht',
#   'wir',
#   'finden',
#   'auf',
#   'dieses',
#   'spezielle',
#   'und',
#   'äusserst',
#   'widerliche',
#   'thema',
#   'sollte',
#   'im',
#   'öffentlichen',
#   'diskurs',
#   'intensiver',
#   'eingegangen',
#   'werden'],
#  ['kinderheirat', 'ist', 'ein', 'weltweites', 'problem'],
#  ['auch',
#   'unter',
#   'den',
#   'syrischen',
#   'flüchtlingen',
#   'steigt',
#   'die',
#   'zahl',
#   'der',
#   'minderjährigen',
#   'die',
#   'verheiratet',
#   'werden'],
#  ['was', 'passiert', 'wenn', 'diese', 'mädchen', 'in', 'europa', 'ankommen'],
#  ['august',
#   'verschwand',
#   'in',
#   'der',
#   'erstaufnahmeeinrichtung',
#   'in',
#   'ter',
#   'apel',
#   'im',
#   'norden',
#   'der',
#   'niederlande',
#   'ein',
#   'kind'],
#  ['fatema', 'alkasem', 'jahre', 'alt', 'syrerin'],
#  ['ihr',
#   'foto',
#   'wurde',
#   'landesweit',
#   'verbreitet',
#   'auch',
#   'die',
#   'deutsche',
#   'polizei',
#   'half',
#   'bei',
#   'der',
#   'suche'],
#  ['doch', 'alle', 'anstrengungen', 'waren', 'vergebens'],
#  ['das', 'kind', 'blieb', 'verschwunden'],
#  ['fatema', 'ist', 'hochschwanger'],
#  ['die',
#   'anhänger',
#   'der',
#   'religion',
#   'des',
#   'friedens™',
#   'können',
#   'ja',
#   'ihrem',
#   'propheten',
#   'nacheifern',
#   'aber',
#   'dann',
#   'bitte',
#   'nur',
#   'in',
#   'ihren',
#   'ländern',
#   'derartige',
#   'mittelalterliche',
#   'zustände',
#   'möchten',
#   'wir',
#   'im',
#   'zivilisierten',
#   'europa',
#   'nicht',
#   'haben'],
#  ["ʿā'ischa",
#   'bint',
#   'abī',
#   'bakr',
#   'arabisch',
#   'عائشة',
#   'بنت',
#   'أَبي',
#   'بكر',
#   'dmg',
#   'ʿāʾiša',
#   'bint',
#   'abī',
#   'bakr',
#   'geb'],
#  ['oder', 'gest'],
#  ['in',
#   'medina',
#   'war',
#   'die',
#   'dritte',
#   'und',
#   'jüngste',
#   'der',
#   'zehn',
#   'frauen',
#   'des',
#   'islamischen',
#   'propheten',
#   'mohammed'],
#  ['den',
#   'islamischen',
#   'überlieferungen',
#   'zufolge',
#   'war',
#   'aischa',
#   'beim',
#   'eheschließungsvertrag',
#   'mit',
#   'mohammed',
#   'sechs',
#   'und',
#   'beim',
#   'vollzug',
#   'der',
#   'ehe',
#   'neun',
#   'jahre',
#   'alt'],
#  ['pegida', 'aufdiestraße', 'islamisierung', 'aufschrei', 'mundaufmachen'],
#  ['saarland-ministerpräsidentin',
#   'müssen',
#   'verhindern',
#   'das',
#   'migranten',
#   'mehrfach',
#   'geld',
#   'beziehen',
#   'in',
#   'einem',
#   'aktuellen',
#   'hilferuf',
#   'erklärte',
#   'die',
#   'saarländische',
#   'ministerpräsidentin',
#   'annegret',
#   'kramp-karrenbauer',
#   'cdu',
#   'wie',
#   'es',
#   'möglich',
#   'ist',
#   'dass',
#   'asylbewerber',
#   'mehrfach',
#   'geld',
#   'vom',
#   'staat',
#   'beziehen'],
#  ['einmal',
#   'mit',
#   'profis',
#   'arbeiten',
#   'wir',
#   'zitieren',
#   'mal',
#   'wieder',
#   'unseren',
#   'horst',
#   'und',
#   'erweitern',
#   'seine',
#   'aussage',
#   'wir',
#   'werden',
#   'von',
#   'wahnsinnigen',
#   'und',
#   'dilettanten',
#   'regiert'],
#  ['viele',
#   'der',
#   'sozialtouristen',
#   'die',
#   'nach',
#   'germoney',
#   'kommen',
#   'wissen',
#   'ganz',
#   'genau',
#   'wie',
#   'sie',
#   'aus',
#   'der',
#   'beutegesellschaft',
#   'so',
#   'viel',
#   'wie',
#   'möglich',
#   'herausholen',
#   'simsalabim',
#   'das',
#   'fällt',
#   'frau',
#   'kk',
#   'ja',
#   'verdammt',
#   'zeitig',
#   'auf'],
#  ['weil',
#   'die',
#   'registrierung',
#   'ein',
#   'einziges',
#   'chaos',
#   'sei',
#   'und',
#   'die',
#   'behörden',
#   'verschiedene',
#   'systeme',
#   'benutzen',
#   'könnten',
#   'sich',
#   'migranten',
#   'mehrfach',
#   'anmelden',
#   'und',
#   'abkassieren',
#   'beschrieb',
#   'die',
#   'regierungschefin',
#   'des',
#   'saarlands',
#   'gegenüber',
#   'dem',
#   'focus'],
#  ['im',
#   'saarland',
#   'würden',
#   'fingerabdrücke',
#   'genommen',
#   '„',
#   'so',
#   'dass',
#   'wir',
#   'sehen',
#   'wer',
#   'schon',
#   'mal',
#   'bei',
#   'uns',
#   'aufgetaucht',
#   'ist',
#   '“',
#   'so',
#   'die',
#   'politikerin'],
#  ['„',
#   'leider',
#   'aber',
#   'können',
#   'wir',
#   'dies',
#   'nicht',
#   'abgleichen',
#   'mit',
#   'anderen',
#   'systemen',
#   'in',
#   'deutschland',
#   'geschweige',
#   'denn',
#   'in',
#   'europa.',
#   '“',
#   'mehrfach',
#   'anträge',
#   'sind',
#   'möglich'],
#  ['die',
#   'daten',
#   'aller',
#   'leistungsbezieher',
#   'müssten',
#   'miteinander',
#   'vernetzt',
#   'werden',
#   'schlägt',
#   'sie',
#   'vor'],
#  ['„',
#   'dies',
#   'verhindert',
#   'dass',
#   'jemand',
#   'doppelt',
#   'leistungen',
#   'erhält'],
#  ['so',
#   'haben',
#   'wir',
#   'im',
#   'saarland',
#   'bei',
#   'der',
#   'erstaufnahme',
#   'von',
#   'flüchtlingen',
#   'beispielsweise',
#   'festgestellt',
#   'dass',
#   'manche',
#   'sich',
#   'aus',
#   'der',
#   'warteschlange',
#   'verabschiedet',
#   'haben',
#   'weil',
#   'wir',
#   'fingerabdrücke',
#   'nehmen.',
#   '“',
#   'pegida',
#   'simsalabim',
#   'aufdiestraße',
#   'montagistpegidatag',
#   'absurdistan'],
#  ['passend',
#   'zum',
#   'letzten',
#   'beitrag',
#   'habt',
#   'einen',
#   'schönen',
#   'samstagabend'],
#  ['y',
#   'ach',
#   'ja',
#   'dass',
#   'neue',
#   'motto',
#   'für',
#   'montag',
#   'lautet',
#   'jeder',
#   'bringt',
#   'mit'],
#  ['y',
#   'hetze',
#   'stimmungsmache',
#   'und',
#   'hasser',
#   'das',
#   'kampfvokabular',
#   'der',
#   'gesinnungsethik'],
#  ['pegida',
#   'wiedenroth',
#   'aufdiestraße',
#   'montagistpegidatag',
#   'jederbringtmit'],
#  ['helfen', 'pflicht'],
#  ['bitte', 'teilen'],
#  ['stammzellengesucht', 'help', 'pegidawirkt', 'pegida', 'montagistpegidatag']]

# %%
hatespeech3=""

with open("hatespeech/comments.csv") as csvdatei:
    csv_reader_object = csv.reader(csvdatei, delimiter=",")
    csv_hate = list(csv_reader_object)[1:]
    for row in csv_hate:
        x = row[3]
        x = re.sub(r"http\S+|\.\.+|\S+\/\/+|www\S+|\d+|@[A-Za-z0-9]+","", x)
        x+="."
        x = x.lower()
     
     
        hatespeech3 += " " + x

# %%
hatespeech3 = clean(hatespeech3)

# %%
hatespeech3
# Out:
# [['gleich', 'an', 'die', 'wand', 'stellen', 'und', 'erschiessen'],
#  ['nicht',
#   'dass',
#   'ich',
#   'der',
#   'grundbotschaft',
#   'dieses',
#   'post',
#   "'s",
#   'widersprechen',
#   'würde',
#   'aber',
#   'rechtschreib-',
#   'und',
#   'grammatikfehler',
#   'in',
#   'einer',
#   'so',
#   'kurzen',
#   'beschreibung',
#   'stärkt',
#   'leider',
#   'nur',
#   'das',
#   'clichee',
#   'blau-wähler',
#   'haben',
#   'nichts',
#   'im',
#   'hirn',
#   'bei',
#   'dem',
#   'politischen',
#   'gegenüber',
#   '..',
#   'das',
#   'mit',
#   'dem',
#   'an',
#   'die',
#   'wand',
#   'stellen',
#   'und',
#   'erschiessen'],
#  ['seit',
#   'dem',
#   'an',
#   'die',
#   'wand',
#   'stellen',
#   'und',
#   'erschiessen',
#   'sind',
#   'in',
#   'deutschland',
#   'nun',
#   'etwa',
#   'jahre',
#   'her',
#   '..',
#   'ja',
#   'ja',
#   'die',
#   'kriminelle',
#   'heimatpartei',
#   'fpö',
#   'von',
#   'kinderpornografie',
#   'beim',
#   'orts',
#   'chef',
#   'von',
#   'burgenlabd',
#   'bis',
#   'waffenhandel',
#   'von',
#   'betrug',
#   'verhetzung',
#   'bis',
#   'körperverletzung',
#   'von',
#   'falscher',
#   'zeugenaussage',
#   'bis',
#   'mord',
#   'bei',
#   'rfjbezirksleiter',
#   'schießt',
#   'jährige',
#   'über',
#   'den',
#   'haufen',
#   'bundesrat',
#   'wegen',
#   'wiederbetätigung',
#   'verurteilt'],
#  ['ihr', 'seids', 'empfindlich'],
#  ['is',
#   'beste',
#   'wos',
#   'uns',
#   'passieren',
#   'kann',
#   'is',
#   'das',
#   'sie',
#   'die',
#   'herrschaften',
#   'selbst',
#   'niederfeiln'],
#  ['und', 'ihr', 'grünen'],
#  ['euch', 'wollte', 'ich', 'danken'],
#  ['euch',
#   'hurenkinder',
#   'können',
#   'wir',
#   'den',
#   'ganzen',
#   'scheiß',
#   'verdanken',
#   '..',
#   'mei',
#   'bitte',
#   'sie',
#   'sollen',
#   'sich',
#   'alle',
#   'gegenseitig',
#   'abstechen'],
#  ['problem', 'gelöst'],
#  ['alles', 'nur', 'traumatisierte', 'kindlein'],
#  ['die',
#   'von',
#   'den',
#   'grünen',
#   'bezahlten',
#   'anwälte',
#   'werden',
#   'es',
#   'schon',
#   'richten'],
#  ['fachkräfte', 'bei', 'der', 'arbeit'],
#  ['ein', 'hirnchirurg', 'und', 'ein', 'atomphysiker'],
#  ['unglaublich',
#   'was',
#   'für',
#   'ausländerfeindliche',
#   'kommentare',
#   'man',
#   'immer',
#   'wieder',
#   'zu',
#   'lesen',
#   'bekommt',
#   'und',
#   'unglaublich',
#   'wieviel',
#   'nazi',
#   'noch',
#   'in',
#   'vielen',
#   'deutschen',
#   'drinsteckt',
#   '..',
#   'ich',
#   'staune',
#   'nur',
#   'daß',
#   'in',
#   'österreich',
#   'dieses',
#   'problem',
#   'so',
#   'rasch',
#   'ankam'],
#  ['eigentlich', 'sin', 'die', 'doch', 'immer', 'so', 'jahre', 'danach'],
#  ['das', 'ist', 'multi', 'kulti'],
#  ['es',
#   'soll',
#   'doch',
#   'jeder',
#   'in',
#   'sein',
#   'eigenen',
#   'land',
#   'bleiben',
#   'da',
#   'können',
#   'sie',
#   'sich',
#   'untereinander',
#   'von',
#   'mir',
#   'aus',
#   'totschlagen'],
#  ['sie', 'löschen', 'sich', 'gegenseitig', 'aus'],
#  ['hoffentlich', 'bald'],
#  ['jagt',
#   'dieses',
#   'dreckspack',
#   'raus',
#   '..',
#   'die',
#   'regierung',
#   'will',
#   'es',
#   'doch',
#   'so',
#   'polizei',
#   'schaut',
#   'bitte',
#   'nur',
#   'zu',
#   'lass',
#   'die',
#   'sich',
#   'mal',
#   'selber',
#   'dezimieren',
#   'schont',
#   'euch'],
#  ['weiter', 'so', 'freut', 'mich', 'das', 'alle', 'gutmenschen', 'aufwachen'],
#  ['beide',
#   'volksgruppen',
#   'sofort',
#   'ausweisen',
#   'das',
#   'eizige',
#   'legitime',
#   'mittel'],
#  ['warum',
#   'hauen',
#   'die',
#   'ösis',
#   'nicht',
#   'drauf',
#   'die',
#   'könnens',
#   'doch',
#   'die',
#   'haben',
#   'doch',
#   'keine',
#   'geschichte',
#   'die',
#   'ihnen',
#   'dauernd',
#   'ungerechtugterweise',
#   'vorgehalten',
#   'wird'],
#  ['andere',
#   'länder',
#   'hatten',
#   'auch',
#   'schlechte',
#   'machthaber',
#   'da',
#   'spricht',
#   'keiner',
#   'drüber',
#   'immer',
#   'nur',
#   'wir',
#   'und',
#   'die',
#   'frau',
#   'kriegt',
#   'den',
#   'mund',
#   'nicht',
#   'auf'],
#  ['alle',
#   'raus',
#   'da',
#   'wo',
#   'die',
#   'herkommen',
#   'aber',
#   'alle',
#   'und',
#   'das',
#   'problem',
#   'ist',
#   'gelöst'],
#  ['damit', 'müssen', 'wir', 'laut', 'der', 'merkel', 'leben'],
#  ['ich',
#   'sage',
#   'raus',
#   'mit',
#   'denen',
#   'und',
#   'die',
#   'sollen',
#   'die',
#   'merkel',
#   'direkt',
#   'mit',
#   'nehmen'],
#  ['dreckspack',
#   'entsorgen',
#   '..',
#   'r',
#   'a',
#   'u',
#   's',
#   'mit',
#   'dem',
#   'p',
#   'a',
#   'c',
#   'k.',
#   'hat',
#   'mit',
#   'volksgruppen',
#   'nichts',
#   'zu',
#   'tun',
#   'findet',
#   'unter',
#   'deutschen',
#   'ständig',
#   'statt',
#   'rockergruppen',
#   'hooligans',
#   'usw',
#   '..',
#   'ab',
#   'nach',
#   'hause',
#   'und',
#   'gibt',
#   'ihnen',
#   'genug',
#   'waffen',
#   'mit',
#   'um',
#   'sich',
#   'zu',
#   'killen'],
#  ['problem', 'gelöst'],
#  ['warum',
#   'hat',
#   'niemand',
#   'der',
#   'frau',
#   'geholfen',
#   'den',
#   'verbrecher',
#   'sollte',
#   'man',
#   'verrecken',
#   'lassen',
#   'anstatt',
#   'ihm',
#   'zu',
#   'helfen'],
#  ['supa', 'gail'],
#  ['hoffentlich', 'tut', 'es', 'ihm', 'ordentlich', 'weh'],
#  ['schade', 'das', 'er', 'es', 'überlebte'],
#  ['hoffentlich',
#   'verbleibt',
#   'er',
#   'ö',
#   'nicht',
#   'lebenslang',
#   'als',
#   'pflegefall'],
#  ['die',
#   'rübe',
#   'hätte',
#   'ihm',
#   'die',
#   'garnitur',
#   'abfahren',
#   'sollen',
#   'dem',
#   'arsch',
#   '..',
#   'müßten',
#   'vielmehr',
#   'züge',
#   'fahren',
#   'so',
#   'mit',
#   'nem',
#   'kleinen',
#   'bajonett',
#   'vorn',
#   'dran'],
#  ['klar', 'von', 'steuergelder', 'auch', 'noch', 'notoperiert'],
#  ['hätte', 'gleich', 'noch', 'ne', 'u-bahn', 'losgeschickt'],
#  ['einpacken',
#   'und',
#   'ticket',
#   'nach',
#   'algerien',
#   'auf',
#   'die',
#   'stirn',
#   'drücken'],
#  ['selbst',
#   'schuld',
#   'ich',
#   'bin',
#   'durchaus',
#   'kein',
#   'feind',
#   'gegen',
#   'ausländer',
#   'denn',
#   'unser',
#   'freund',
#   'ist',
#   'aus',
#   'pakistan',
#   'abere',
#   'der',
#   'typ',
#   'gehört',
#   'nicht',
#   'ins',
#   'krankenhaus',
#   'sondern',
#   'auf',
#   'den',
#   'gleisen',
#   'müsste',
#   'man',
#   'den',
#   'liegenlassen'],
#  ['richtig',
#   'so',
#   'alle',
#   'krimos',
#   'raus',
#   'aus',
#   'deutschland',
#   'natürlich',
#   'auch',
#   'die',
#   'deutschen',
#   'krimos'],
#  ['einer', 'weniger'],
#  ['hoffentlich', 'verreckt', 'er', 'der', 'facharbeiter'],
#  ['wer',
#   'bezahlt',
#   'den',
#   'hubschraubereinsatz',
#   'für',
#   'diesen',
#   'verbrecher'],
#  ['gleich',
#   'bestaft',
#   'ist',
#   'doch',
#   'super',
#   'brauchen',
#   'wir',
#   'kei',
#   'gericht'],
#  ['so', 'viel', 'gesindel', 'bei', 'uns'],
#  ['mir',
#   'tut',
#   'er',
#   'nicht',
#   'leid',
#   '..',
#   'auf',
#   'den',
#   'gleisen',
#   'sterben',
#   'lassen',
#   'das',
#   'wäre',
#   'ein',
#   'fall',
#   'von',
#   'absoluter',
#   'gerechtigkeit'],
#  ['ich', 'muss', 'mal', 'eben', 'auf', 'die', 'kommentare', 'bzw'],
#  ['deren', 'verfasser', '..'],
#  ['politiker',
#   'bekommen',
#   'personenschutz',
#   'und',
#   'wer',
#   'schützt',
#   'unsere',
#   'bevölkerung',
#   'vor',
#   'diesen',
#   'verbrechern',
#   'und',
#   'abschaum'],
#  ['das', 'ja', 'den', 'grossen', 'nichts', 'passiert'],
#  ['haben', 'angst', 'um', 'ihr', 'bisschen', 'leben'],
#  ['was',
#   'ist',
#   'mit',
#   'der',
#   'angst',
#   'die',
#   'diese',
#   'alte',
#   'frau',
#   'jetzt',
#   'hat'],
#  ['die',
#   'sollte',
#   'schmerzensgeld',
#   'von',
#   'der',
#   'bundesregierung',
#   'einklagen',
#   'die',
#   'dieses',
#   'unrat',
#   'in',
#   'unser',
#   'land',
#   'holt'],
#  ['hätten', 'das', 'kriminelle', 'ausländer', 'liegen', 'lassen', 'solln'],
#  ['dumm', 'gelaufen', 'für', 'das', 'arschloch'],
#  ['als', 'rein', 'ins', 'ländle', 'mit', 'dem', 'gesocks'],
#  ['wir', 'haben', 'noch', 'platz'],
#  ['raus', 'damit'],
#  ['top', 'noch', 'mehr', 'von', 'dem', 'gesöcks'],
#  ['raus', 'mit', 'dem', 'rattenpack'],
#  ['raus', 'aber', 'sofort', 'der', 'krieg', 'fängt', 'schon', 'an'],
#  ['lasst', 'uns', 'schiffe', 'versenken'],
#  ['wieso', 'festgenommen', 'gleich', 'nachschmeißen', 'ins', 'meer'],
#  ['drecks', 'pack'],
#  ['spielen', 'wir', 'bimbos', 'versenken'],
#  ['tja',
#   'dann',
#   'doch',
#   'mal',
#   'herzlich',
#   'willkommen',
#   'im',
#   'christlichen',
#   'land',
#   'bei',
#   'den',
#   'bescheuerten',
#   'gutmenschen'],
#  ['alles', 'nur', 'hetze'],
#  ['dafür', 'gibts', 'torpetos'],
#  ['gebt', 'mir', 'schnell', 'einen', 'bohrer'],
#  ['ihr', 'nazistraurig'],
#  ['die',
#   'ganze',
#   'bereicherung',
#   'verdanken',
#   'wir',
#   'nur',
#   'christlich',
#   'verblödeten',
#   'vollpfosten'],
#  ['kardinal',
#   'francesco',
#   'montenegro',
#   'zu',
#   'dessen',
#   'sizilianischer',
#   'erzdiözese',
#   'agrigent',
#   'die',
#   'flüchtlingsinsel',
#   'lampedusa',
#   'zählt',
#   'appellierte',
#   'an',
#   'die',
#   'italiener',
#   'sich',
#   'vor',
#   'dem',
#   'flüchtlingsnotstand',
#   'nicht',
#   'zu',
#   'verschließen'],
#  ['ganze',
#   'bevölkerungen',
#   'würden',
#   'sich',
#   'derzeit',
#   'in',
#   'bewegung',
#   'setzen',
#   'man',
#   'könne',
#   'nicht',
#   'wegschauen',
#   '..',
#   'manchmal',
#   'macht',
#   'es',
#   'eben',
#   'die',
#   'richtige',
#   'mischung'],
#  ['warum',
#   'schleppt',
#   'man',
#   'dieseschiffe',
#   'nicht',
#   'zurück',
#   'nach',
#   'afrika'],
#  ['na',
#   'vielleicht',
#   'merken',
#   'jetz',
#   'der',
#   'vielen',
#   'gutis',
#   'den',
#   'wahren',
#   'grund',
#   'dieser',
#   'aktionen'],
#  ['die',
#   'sollte',
#   'man',
#   'alle',
#   'wieder',
#   'zurück',
#   'schicken',
#   'garnicht',
#   'erst',
#   'in',
#   'unser',
#   'land',
#   'lassen'],
#  ['genug', 'ist', 'genug', 'wir', 'brauchen', 'keine', 'teppichbrüder'],
#  ['und',
#   'die',
#   'roth',
#   'ist',
#   'für',
#   'noch',
#   'mehr',
#   'flüchtlinge',
#   'lief',
#   'gerade',
#   'im',
#   'tv',
#   'alle',
#   'bei',
#   'roth',
#   'einziehen',
#   'das',
#   'ist',
#   'doch',
#   'eine',
#   'lösung'],
#  ['meine', 'fresse', 'labert', 'ihr', 'alle', 'eine', 'scheisse'],
#  ['echt',
#   'zum',
#   'kotzen',
#   'hier',
#   'andauernd',
#   'werden',
#   'meine',
#   'kommentare',
#   'gelöscht'],
#  ['sicher', 'doch'],
#  ['nur',
#   'schade',
#   'ist',
#   'dass',
#   'es',
#   'nicht',
#   'jedem',
#   'deutschen',
#   'möglich',
#   'ist',
#   'd',
#   'zu',
#   'verlassen'],
#  ['wäre',
#   'interessant',
#   'wie',
#   'sich',
#   'diese',
#   'unfägigen',
#   'politiker',
#   'sich',
#   'dann',
#   'hinstellen',
#   'um',
#   'das',
#   'pack',
#   'zu',
#   'bereichern'],
#  ['ich',
#   'sags',
#   'ja',
#   'immer',
#   'wieder',
#   'gerne',
#   'die',
#   'die',
#   'am',
#   'lautesten',
#   'nach',
#   'toleranz',
#   'schreien',
#   'sind',
#   'doch',
#   'die',
#   'intolerantesten'],
#  ['nur',
#   'rein',
#   'ins',
#   'land',
#   'mit',
#   'dem',
#   'ganzen',
#   'gesocks',
#   '..',
#   'demnächst',
#   'in',
#   'deutschlands',
#   'moschen',
#   'und',
#   'auf',
#   'salafistenveranstaltungen',
#   'auf',
#   'unseren',
#   'straßen'],
#  ['ein',
#   'hoch',
#   'auf',
#   'unsere',
#   'politiker',
#   '..',
#   'schiff',
#   'entern',
#   'und',
#   'zurück',
#   'schleppen',
#   'oder',
#   'versenken'],
#  ['so',
#   'kennt',
#   'man',
#   'die',
#   'musels.ist',
#   'halt',
#   'ein',
#   'hinterhältiges',
#   'pack',
#   '..',
#   'tjaman',
#   'konnt',
#   'gestern',
#   'wieder',
#   'die',
#   'fatima',
#   'roth',
#   'im',
#   'zdf',
#   'bewundern',
#   'wie',
#   'sie',
#   'wieder',
#   'alle',
#   'leute',
#   'zu',
#   'nazis',
#   'macht',
#   'die',
#   'nicht',
#   'in',
#   'der',
#   'flüchtlingsfrage',
#   'mit',
#   'ihr',
#   'einer',
#   'meinung',
#   'sinddie',
#   'dame',
#   'von',
#   'der',
#   'afd',
#   'hat',
#   'es',
#   'auf',
#   'den',
#   'punkt',
#   'gebrachtwir',
#   'haben',
#   'hier',
#   'in',
#   'deutschland',
#   'gesetze',
#   'die',
#   'für',
#   'das',
#   'asyl',
#   'zuständig',
#   'sindda',
#   'soll',
#   'nun',
#   'geprüft',
#   'werden',
#   'ob',
#   'jemand',
#   'politisch',
#   'verfolgt',
#   'wird',
#   'oder',
#   'einer',
#   'minderheit',
#   'in',
#   'seiner',
#   'heimat',
#   'angehört',
#   'die',
#   'verfolgt',
#   'wirduswda',
#   'tauchen',
#   'für',
#   'mich',
#   'nun',
#   'fragen',
#   'auf',
#   'wer',
#   'prüft',
#   'denn',
#   'eigentlich',
#   'den',
#   'wahrheitsgehalt',
#   'der',
#   'menschen',
#   'die',
#   'hier',
#   'her',
#   'kommen'],
#  ['der', 'kleine', 'scheiss', 'beamte'],
#  ['der', 'froh', 'ist', 'wenn'],
#  ['uhr', 'ist'],
#  ['nächte',
#   'frage',
#   'wärewozu',
#   'gibt',
#   'es',
#   'denn',
#   'über',
#   'haupt',
#   'die',
#   'gesetze',
#   'wenn',
#   'sie',
#   'dann',
#   'nicht',
#   'mal',
#   'durchgesetzt',
#   'werden'],
#  ['hier', 'in', 'deutschlan', 'leben', 'offiziell', 'ca'],
#  ['menschen',
#   'deren',
#   'asylantrag',
#   'abgelehnt',
#   'wurdewas',
#   'bitte',
#   'machen',
#   'die',
#   'dann',
#   'noch',
#   'hier'],
#  ['an',
#   'den',
#   'haken',
#   'nehmen',
#   'und',
#   'in',
#   'den',
#   'ausgangshafen',
#   'zurückschleppen'],
#  ['immer',
#   'wenn',
#   'man',
#   'einen',
#   'weißen',
#   'hai',
#   'braucht',
#   'ist',
#   'keiner',
#   'in',
#   'der',
#   'nähe'],
#  ['da', 'hilft', 'nur', 'eins', 'die', 'boote', 'von', 'unten', 'anbohren'],
#  ['man',
#   'die',
#   'werden',
#   'hier',
#   'nicht',
#   'gebraucht',
#   'und',
#   'nicht',
#   'gewollt'],
#  ['zurück', 'mit', 'denen'],
#  ['der',
#   'islam',
#   'gehört',
#   'unter',
#   'strafe',
#   'verboten',
#   '..',
#   'selbst',
#   'in',
#   'der',
#   'grössten',
#   'not',
#   'tun',
#   'sich',
#   'die',
#   'menschen',
#   'grausames',
#   'an'],
#  ['pfui', 'teufel'],
#  ['ich',
#   'habe',
#   'viele',
#   'dieser',
#   'kommentare',
#   'gelesen',
#   'und',
#   'muss',
#   'feststellen',
#   'dass',
#   'genau',
#   'diese',
#   'unüberlegte',
#   'aussagen',
#   'die',
#   'politiker',
#   'aufschreckt',
#   'aber',
#   'nicht',
#   'zum',
#   'nachdenken',
#   'animiert'],
#  ['man',
#   'kann',
#   'auch',
#   'mit',
#   'ausgewählten',
#   'worten',
#   'politik',
#   'beeinflussen'],
#  ['mit',
#   'hass',
#   'predigten',
#   'erreicht',
#   'man',
#   'gerade',
#   'mal',
#   'das',
#   'gegenteil'],
#  ['und', 'zu', 'wahlen', 'parteidemokratoren', 'abstrafen'],
#  ['richtig',
#   'wäre',
#   'es',
#   'so',
#   'wie',
#   'frau',
#   'petri',
#   'afd',
#   'zu',
#   'argumentieren',
#   'dass',
#   'asylanten',
#   'immer',
#   'ein',
#   'übergangsbleiberecht',
#   'beantragen',
#   'können'],
#  ['dies', 'sind', 'ca'],
#  ['der', 'ankommenden'],
#  ['und', 'die', 'anderen', 'sollten', 'sofort', 'zurückgewiesen', 'werden'],
#  ['wenn',
#   'der',
#   'kommentar',
#   'muslime',
#   'warfen',
#   'christen',
#   'ins',
#   'meer',
#   'der',
#   'wahrheit',
#   'entspricht',
#   'sollte',
#   'doch',
#   'die',
#   'kirche',
#   'stellung',
#   'beziehen'],
#  ['aber', 'die', 'ist', 'wiederum', 'von', 'staatszuschüssen', 'abhängig'],
#  ['wer',
#   'das',
#   'assylantenheim',
#   'in',
#   'tröglitz',
#   'anzündete',
#   'ist',
#   'ja',
#   'immer',
#   'noch',
#   'nicht',
#   'nachgewiesen',
#   'aber',
#   'die',
#   'medien',
#   'machen',
#   'damit',
#   'stimmung',
#   'und',
#   'zerstören',
#   'die',
#   'gesellschaft'],
#  ['die',
#   'eigentliche',
#   'schuldfrage',
#   'für',
#   'diesen',
#   'fremdenhass',
#   'muss',
#   'sich',
#   'die',
#   'bundesregierung',
#   'mit',
#   'ihren',
#   'steigbügelhaltern',
#   'landesregierungen',
#   'landratsämter',
#   'usw'],
#  ['zuschreiben', 'lassen'],
#  ['die',
#   'alle',
#   'haben',
#   'keinen',
#   'a',
#   'in',
#   'der',
#   'hose',
#   '..',
#   'warum',
#   'schützt',
#   'die',
#   'italienische',
#   'küstenwache',
#   'uns',
#   'nicht',
#   'vor',
#   'diesen',
#   'verbrechern'],
#  ['wenn',
#   'die',
#   'ersten',
#   'boote',
#   'versenkt',
#   'wurden',
#   'ist',
#   'esw',
#   'vorbei',
#   'mit',
#   'diesem',
#   'spuk'],
#  ['sofort',
#   'an',
#   'ort',
#   'und',
#   'stelle',
#   'einfach',
#   'versenken',
#   'wenn',
#   'sich',
#   'das',
#   'rum',
#   'spricht',
#   'werden',
#   'es',
#   'auch',
#   'nicht',
#   'mehr',
#   'so',
#   'viele',
#   'versuchen',
#   'um',
#   'nach',
#   'europa',
#   'zu',
#   'kommen',
#   '..',
#   'was',
#   'ist',
#   'man',
#   'von',
#   'moslems',
#   'anders',
#   'gewöhnt.das',
#   'pack',
#   'kann',
#   'mitlerweile',
#   'nur',
#   'noch',
#   'morden',
#   'und',
#   'hinterhältig',
#   'töten',
#   '..',
#   'die',
#   'neonazis',
#   'haben',
#   'schon',
#   'recht',
#   'mit',
#   'dem',
#   'was',
#   'sie',
#   'machen',
#   'diese',
#   'drecksausländer',
#   'gehören',
#   'vergaast',
#   'man',
#   'kann',
#   'nicht',
#   'mal',
#   'mer',
#   'mit',
#   'seiner',
#   'freundin',
#   'einkaufen',
#   'gehen',
#   'ohne',
#   'das',
#   'dreckstürken',
#   'einen',
#   'am',
#   'eingang',
#   'dumm',
#   'anmachen',
#   'asozial',
#   'ist',
#   'sowas',
#   'un',
#   'der',
#   'staat',
#   'macht',
#   'nix',
#   'ausländer',
#   'raus'],
#  ['sobald',
#   'die',
#   'muslime',
#   'in',
#   'der',
#   'mehrzahl',
#   'sind',
#   'fangen',
#   'sie',
#   'automatisch',
#   'damit',
#   'an',
#   'ihren',
#   'gottesstaat',
#   'zu',
#   'errichten'],
#  ['der',
#   'terror',
#   'nimmt',
#   'dann',
#   'seinen',
#   'lauf',
#   '..',
#   'das',
#   'ganze',
#   'schiff',
#   'versenken',
#   'die',
#   'bundeswehr',
#   'sollte',
#   'jagd',
#   'auf',
#   'die',
#   'machen',
#   'und',
#   'versenken'],
#  ['na', 'meine', 'güte', '.traumatisierte', 'kindlein', 'halt'],
#  ['große', 'worte', 'jugendbande', 'zerschlagen'],
#  ['macht',
#   'mal',
#   'was',
#   'gegen',
#   'die',
#   'banden',
#   'in',
#   'den',
#   'großstädten',
#   'ihr',
#   'versager',
#   'drogen',
#   'menschenhandel',
#   'und',
#   'und',
#   'und'],
#  ['scheis', 'nazis'],
#  ['wir', 'wollen', 'keine', 'russen', 'hier'],
#  ['sind', 'das', 'unser', 'facharbeier'],
#  ['aber',
#   'man',
#   'darf',
#   'ja',
#   'nix',
#   'sagen',
#   'wirst',
#   'gleich',
#   'zu',
#   'den',
#   'rechten',
#   'in',
#   'die',
#   'ecke',
#   'gestellt',
#   '..',
#   'ich',
#   'bin',
#   'nach',
#   'geboren',
#   'und',
#   'ich',
#   'schulde',
#   'dem',
#   'rest',
#   'der',
#   'welt',
#   'einen',
#   'scheissdreck',
#   'wenn',
#   'dieses',
#   'dreckspack',
#   'bei',
#   'mir',
#   'einbrechen',
#   'würde-ich',
#   'würde',
#   'nicht',
#   'die',
#   'bullen',
#   'rufen-aber',
#   'die-garantiert'],
#  ['schöne',
#   'kommis',
#   'das',
#   'geht',
#   'runter',
#   'wie',
#   'ein',
#   'schweineschnitzel',
#   'weiter',
#   'so'],
#  ['was',
#   'ist',
#   'daran',
#   'so',
#   'schlimm',
#   'zu',
#   'den',
#   'rechten',
#   'gestellt',
#   'zu',
#   'werden',
#   'also',
#   'ich',
#   'sage',
#   'immer',
#   'offen',
#   'meine',
#   'meinung',
#   'zu',
#   'diesen',
#   'scheiß',
#   'ausländern',
#   'mir',
#   'egal',
#   'was',
#   'die',
#   'andren',
#   'denken',
#   'oder',
#   'sagen',
#   'und',
#   'ich',
#   'finde',
#   'das',
#   'sollten',
#   'noch',
#   'viel',
#   'mehr',
#   'machen',
#   'sonst',
#   'endert',
#   'der',
#   'staat',
#   'nie',
#   'was',
#   'es',
#   'gibt',
#   'viel',
#   'zu',
#   'wenige',
#   'neonazis',
#   'sagt',
#   'eure',
#   'meinung',
#   'offen',
#   'diese',
#   'scheiß',
#   'kanacken',
#   'solln',
#   'raus',
#   'aus',
#   'unserem',
#   'land'],
#  ['kriminelle', 'ausländer', 'sollte', 'man', 'hinrichten'],
#  ['an',
#   'den',
#   'eiern',
#   'aufhängen',
#   'und',
#   'die',
#   'ganze',
#   'familie',
#   'auspeitschen',
#   'und',
#   'ausweisen.an',
#   'der',
#   'grenze',
#   'solange',
#   'mit',
#   'einem',
#   'knüppel',
#   'auf',
#   'dem',
#   'kopf',
#   'hauen',
#   'das',
#   'sie',
#   'bei',
#   'dem',
#   'gedanken',
#   'an',
#   'deutschland',
#   'sich',
#   'dauernt',
#   'vor',
#   'angst',
#   'in',
#   'die',
#   'hose',
#   'scheißen'],
#  ['meine',
#   'eltern',
#   'wohnen',
#   'bei',
#   'mir',
#   'zu',
#   'mir',
#   'können',
#   'sie',
#   'kommen',
#   'alle',
#   'zwei',
#   'meter',
#   'hab',
#   'ich',
#   'en',
#   'schlagring',
#   'einen',
#   'baser',
#   'oder',
#   'totschläger',
#   'gebunkert',
#   'die',
#   'polizei',
#   'wird',
#   'erst',
#   'gerufen',
#   'wenn',
#   'die',
#   'invasoren',
#   'tot',
#   'sind'],
#  ['ich', 'möchte', 'mein', 'altes', 'deutschland', 'wieder'],
#  ['ich', 'würde', 'sie', 'finden', 'und', 'sehr', 'schwer', 'verletzen'],
#  ['möglicherweise',
#   'könnte',
#   'ich',
#   'das',
#   'sogar',
#   'hinkriegen',
#   'ohne',
#   'selbst',
#   'erwischt',
#   'zu',
#   'werden'],
#  ['meine', 'eltern', 'sind'],
#  ['wer',
#   'die',
#   'anfasst',
#   'ist',
#   'erledigt',
#   '..',
#   'eines',
#   'fällt',
#   'mir',
#   'hier',
#   'auf',
#   'niemand',
#   'hat',
#   'etwas',
#   'von',
#   'fremdländern',
#   'gesagt'],
#  ['aber',
#   'na',
#   'ja',
#   'zu',
#   'ist',
#   'es',
#   'warscheinlich',
#   'dass',
#   'das',
#   'keine',
#   'österreichische',
#   'buben',
#   'waren',
#   '-/'],
#  ['scheiß',
#   'drauf',
#   'was',
#   'das',
#   'grüne',
#   'gesox',
#   'von',
#   'mir',
#   'denkt',
#   'vor',
#   'ein',
#   'paar',
#   'tagen',
#   'hat',
#   'in',
#   'berlin',
#   'eine',
#   'unterkunft',
#   'für',
#   'kriminelle',
#   'asylbewerber',
#   'gebrannt'],
#  ['kriminelle',
#   'asylbewerber',
#   'doppelt',
#   'nichtsnutzig',
#   'hätte',
#   'man',
#   'ruhig',
#   'noch',
#   'etwas',
#   'benzin',
#   'ins',
#   'feuer',
#   'gießen',
#   'können',
#   '..',
#   'aber',
#   'man',
#   'darf',
#   'sowas',
#   'ja',
#   'nicht',
#   'beim',
#   'namen',
#   'nennen-herr',
#   'pleitgen',
#   'hat',
#   'was',
#   'dagegen',
#   'das',
#   'die',
#   'ausländer',
#   'benannt',
#   'werden'],
#  ['früher',
#   'wurden',
#   'denen',
#   'die',
#   'hände',
#   'abgehackt',
#   'das',
#   'waren',
#   'noch',
#   'zeiten',
#   'jetzt',
#   'werden',
#   'diese',
#   'gestreichelt'],
#  ['in',
#   'einer',
#   'wirtschaftskrise',
#   'macht',
#   'man',
#   'die',
#   'grenzen',
#   'dicht',
#   '..',
#   'fachkräfte'],
#  ['alles',
#   'fachkräfte',
#   'die',
#   'wir',
#   'so',
#   'dringend',
#   'brauchen',
#   'frau',
#   'merkel',
#   'und',
#   'das',
#   'andere',
#   'gesocks'],
#  ['und',
#   'wieso',
#   'sind',
#   'die',
#   'noch',
#   'in',
#   'deutschland',
#   'sofort',
#   'abschiebung',
#   'samt',
#   'familie.und',
#   'kriegen',
#   'noch',
#   'geld',
#   'von',
#   'deutschland',
#   'damit',
#   'sie',
#   'hier',
#   'klauen',
#   'können',
#   'widerliches',
#   'deutschland',
#   'tut',
#   'entlich',
#   'was'],
#  ['gleich', 'erschiessen'],
#  ['leute', 'klauen', 'fahrräder'],
#  ['es',
#   'gibt',
#   'auch',
#   'deutsche',
#   'die',
#   'sowas',
#   'machen',
#   'leute',
#   'd.',
#   'für',
#   'solche',
#   'wichser',
#   'täterschutz'],
#  ['ich',
#   'hoffe',
#   'das',
#   'die',
#   'asylbeführworter',
#   'mal',
#   'besuch',
#   'von',
#   'solchen',
#   'leuten',
#   'kriegen',
#   '..',
#   'gleich',
#   'erschiessen'],
#  ['facharbeiter', 'ganz', 'klar'],
#  ['sieht',
#   'wien',
#   'scheiß',
#   'kosovoalbaner',
#   'aus',
#   'wie',
#   'auch',
#   'immer',
#   'sofort',
#   'raus',
#   'mit',
#   'dem',
#   'pack'],
#  ['rumänischer',
#   'bettler',
#   '..',
#   'aber',
#   'ohne',
#   'rückfahrkarte',
#   '..',
#   'ich',
#   'erkenne',
#   'ihn'],
#  ['der', 'egon', 'war', 'es', 'wieder'],
#  ['hat',
#   'sicher',
#   'wieder',
#   'mit',
#   'ralf',
#   'und',
#   'klaus',
#   'die',
#   'gegend',
#   'unsicher',
#   'gemacht'],
#  ['aceafdf',
#   'aber',
#   'deutsche',
#   'sind',
#   'auch',
#   'auslaender',
#   'noch',
#   'dazu',
#   'die',
#   'groesste',
#   'einwanderungsgruppesagt',
#   'man'],
#  ['kommt', 'der', 'aus', 'der', 'uckermark'],
#  ['lasst',
#   'diese',
#   'leute',
#   'mal',
#   'schwer',
#   'arbeiten',
#   'std./tag',
#   'um',
#   'den',
#   'aufenthalt',
#   'im',
#   'antragsstaat',
#   'zu',
#   'bezahlen',
#   'dann',
#   'vergeht',
#   'ihnen',
#   'die',
#   'pöbelei',
#   'schlägerei',
#   'und',
#   'und',
#   'und'],
#  ['vieleicht',
#   'wollen',
#   'sie',
#   'dann',
#   'wieder',
#   'nach',
#   'hause',
#   '..',
#   'albaner',
#   'oder',
#   'tschetsche',
#   'die',
#   'sau',
#   'haben',
#   'wir',
#   'ja',
#   'genug',
#   'davon'],
#  ['zeit',
#   'diesen',
#   'islamisten',
#   'das',
#   'licht',
#   'aus',
#   'zu',
#   'knipsen',
#   '..',
#   'lol',
#   'es',
#   'gibt',
#   'doch',
#   'nicht',
#   'nur',
#   'ausländer',
#   'die',
#   'mist',
#   'bauen'],
#  ['xd', 'd.', 'tja', 'das', 'ist', 'einfallsreichtum'],
#  ['von',
#   'den',
#   'ausländern/migranten',
#   'lernen',
#   'heißt',
#   'siegen',
#   'lernen',
#   '..',
#   'na',
#   'servus'],
#  ['diese', 'einzelfälle'],
#  ['der', 'menschenschrott', 'darf', 'alles'],
#  ['ja',
#   'und',
#   'unsere',
#   'dicken',
#   'minister',
#   'waren',
#   'mitglieder',
#   'heidiebummsvallera'],
#  ['da', 'gab', 'es', 'dann', 'bestimmt', 'auch'],
#  ['nach', 'so', 'langer', 'zeit'],
#  ['das', 'kommt', 'mir', 'schon', 'fragwürdig', 'vor'],
#  ['niemand', 'hat', 'in', 'jahren', 'was', 'mitbekomm'],
#  ['alles',
#   'klar',
#   'wers',
#   'glaubt',
#   '…',
#   'europa',
#   'ist',
#   'infiltriert',
#   'bzw'],
#  ['das',
#   'wird',
#   'gerade',
#   'in',
#   'diesen',
#   'tagen',
#   'immer',
#   'deutlicher',
#   '..',
#   'alle',
#   'raus',
#   'und',
#   'dann',
#   'die',
#   'mauer',
#   'wieder',
#   'aufbauen'],
#  ['war', 'nur', 'ein', 'irrtum', 'klar', 'i', 'schwörre'],
#  ['scheiss', 'gsindl'],
#  ['einen', 'schuss', 'ins', 'knie', 'laufe', 'um', 'dein', 'leben'],
#  ['und', 'so', 'etwas', 'wollen', 'linke', 'und', 'grüne'],
#  ['aufhängen', 'so', 'kosten', 'sie', 'nur', 'steuergeld', 'verschwendung'],
#  ['na',
#   'geh',
#   'das',
#   'machen',
#   'die',
#   'ja',
#   'nur',
#   'weil',
#   'sie',
#   'zu',
#   'wenig',
#   'unterstützung',
#   'von',
#   'uns',
#   'erhalten'],
#  ['das',
#   'sind',
#   '.sicher',
#   'menschen',
#   'die',
#   'gebildeter',
#   'als',
#   'wir',
#   'sind',
#   'und',
#   '.der',
#   'übliche',
#   'bedauerliche',
#   'einzelfall',
#   'kotz'],
#  ['tod', 'durch', 'den', 'strang'],
#  ['ich',
#   'sag',
#   'es',
#   'immer',
#   'wieder',
#   'raus',
#   'aus',
#   'deutschland',
#   'mit',
#   'dem',
#   'dreckspack'],
#  ['und',
#   'dann',
#   'fragt',
#   'man',
#   'mich',
#   'warum',
#   'ich',
#   'religion',
#   'nicht',
#   'leiden',
#   'kann'],
#  ['scheiß', 'islam'],
#  ['wer',
#   'solche',
#   'leute',
#   'rein',
#   'lässt',
#   'und',
#   'sich',
#   'dann',
#   'wundert',
#   'dass',
#   'sie',
#   'sich',
#   'benehmen',
#   'wie',
#   'in',
#   'der',
#   'heimat'],
#  ['der',
#   'hat',
#   'die',
#   'gründe',
#   'nicht',
#   'verstanden',
#   'warum',
#   'organisationen',
#   'wie',
#   'pegida',
#   'auf',
#   'die',
#   'straße',
#   'gehen'],
#  ['wacht',
#   'endlich',
#   'auf',
#   '..',
#   'soweit',
#   'ist',
#   'es',
#   'jetzt',
#   'gekommen',
#   'das',
#   'wir',
#   'angst',
#   'im',
#   'eigenen',
#   'land',
#   'haben',
#   'müssen',
#   'armes',
#   'armes',
#   'deutschland.raus',
#   'mit',
#   'dieser',
#   'bande',
#   'die',
#   'haben',
#   'hier',
#   'nichts',
#   'verloren',
#   '..',
#   'das',
#   'pack',
#   'muss',
#   'tag',
#   'und',
#   'nacht',
#   'gejagt',
#   'werden',
#   'ehe',
#   'sie',
#   'es',
#   'mit',
#   'den',
#   'deutschen',
#   'machen'],
#  ['gesindel', '..', 'das', 'dreckspack', 'gehört', 'sofort', 'raus'],
#  ['solche', 'idioten', 'braucht', 'doch', 'kein', 'schwein'],
#  ['dieses',
#   'unsägliche',
#   'islamisten',
#   'pack',
#   'gehört',
#   'sofort',
#   'abgeschoben'],
#  ['wir',
#   'pegidaner',
#   'gehen',
#   'nicht',
#   'umsonst',
#   'jede',
#   'woche',
#   'auf',
#   'die',
#   'straße'],
#  ['diese',
#   'bückbeter',
#   'haben',
#   'sich',
#   'ihr',
#   'image',
#   'selbst',
#   'zu',
#   'zuschreiben',
#   'dafür',
#   'haben',
#   'die',
#   'selbst',
#   'über',
#   'jahrzehnte',
#   'hier',
#   'in',
#   'europa',
#   'gesorgt'],
#  ['ich',
#   'sehe',
#   'schon',
#   'die',
#   'güterzüge',
#   'rollen',
#   'aber',
#   'diesmal',
#   'nicht',
#   'in',
#   'die',
#   'kz',
#   "'s",
#   'sondern',
#   'gen',
#   'nahen',
#   'osten',
#   '..',
#   'ihr',
#   'seid',
#   'einfach',
#   'die',
#   'sorte',
#   'von',
#   'menschen',
#   'die',
#   'alle',
#   'in',
#   'einen',
#   'sack',
#   'packen',
#   'man',
#   'merkt',
#   'innerlich',
#   'in',
#   'euch',
#   'lebt',
#   'der',
#   'adolf'],
#  ['am', 'besten', 'schon', 'gestern'],
#  ['illegal',
#   'die',
#   'wirklichkeit',
#   'zu',
#   'untersuchen',
#   'auf',
#   'so',
#   'eine',
#   'perverse',
#   'unterdrückung',
#   'spezialisierten',
#   'sich',
#   'früher',
#   'besonders',
#   'gut',
#   'die',
#   'religioten',
#   'aller',
#   'art',
#   'heute',
#   'speziell',
#   'noch',
#   'die',
#   'moslems',
#   'und',
#   'unsere',
#   'etablierten',
#   'politschweine',
#   'in',
#   'brd',
#   'und',
#   'eu',
#   'sowie',
#   'ihre',
#   'lügenpresse',
#   '..',
#   'da',
#   'muss',
#   'ich',
#   'dir',
#   'recht',
#   'geben',
#   '..',
#   'es',
#   'sollten',
#   'lieber',
#   'die',
#   'angeklagt',
#   'werden',
#   'die',
#   'den',
#   'ganz',
#   'mulm',
#   'nach',
#   'europa',
#   'holen'],
#  ['ich',
#   'sag',
#   'ja',
#   'immer',
#   'die',
#   'franzosen',
#   'sind',
#   'uns',
#   'ähnlicher',
#   'als',
#   'man',
#   'denkt',
#   'sie',
#   'sind',
#   'sozusagen',
#   'das',
#   'westlichste',
#   'bundesland',
#   '..',
#   'wer',
#   'die',
#   'wahrheit',
#   'sagt',
#   'wird',
#   'angeklagt'],
#  ['habt', 'ihr', 'alle', 'lust', 'mit', 'ein', 'zu', 'blasen'],
#  ['ja',
#   'egal',
#   'was',
#   'wir',
#   'sagen',
#   'immer',
#   'werden',
#   'wir',
#   'als',
#   'nazis',
#   'dargestellt'],
#  ['ich',
#   'habe',
#   'einfach',
#   'nur',
#   'angst',
#   'und',
#   'zwar',
#   'große',
#   'angst',
#   'vor',
#   'dieser',
#   'kultur'],
#  ['da', 'treffen', 'welten', 'aufeinander'],
#  ['ich',
#   'bin',
#   'gestern',
#   'an',
#   'einer',
#   'gruppe',
#   'von',
#   'den',
#   'ausländern',
#   'vorbei',
#   'und',
#   'die',
#   'haben',
#   'dumme',
#   'bemerkungen',
#   'gemacht',
#   'weil',
#   'ich',
#   'kein',
#   'kopftuch',
#   'trug'],
#  ['ich',
#   'habe',
#   'mir',
#   'pfefferspray',
#   'gekauft',
#   'denn',
#   'ich',
#   'sehe',
#   'nicht',
#   'ein',
#   'dass',
#   'ich',
#   'mich',
#   'nicht',
#   'wehren',
#   'darf'],
#  ['wir',
#   'leben',
#   'noch',
#   'in',
#   'einem',
#   'freien',
#   'land',
#   'und',
#   'ich',
#   'habe',
#   'ein',
#   'recht',
#   'meine',
#   'meinung',
#   'zu',
#   'sagen',
#   '..',
#   'bestes',
#   'beispiel',
#   'mein',
#   'auto',
#   'wurde',
#   'geklaut',
#   'und',
#   'zu',
#   'schrottgefahren'],
#  ['postet',
#   'doch',
#   'mal',
#   'was',
#   'die',
#   'deutschen',
#   'kriminellen',
#   'so',
#   'machen'],
#  ['oder',
#   'wie',
#   'findet',
#   'ihr',
#   'es',
#   'mal',
#   'so',
#   'wen',
#   'man',
#   'schreiben',
#   'würde',
#   'ein',
#   'deutscher',
#   'mit',
#   'christlichen',
#   'hintergründen',
#   'hat',
#   'dies',
#   'und',
#   'jenes',
#   'gemacht'],
#  ['der', 'rechtsverdreher', 'der', 'unteren'],
#  ['kennt',
#   'sich',
#   'eben',
#   'aus',
#   '..',
#   'was',
#   'wollen',
#   'wir',
#   'uns',
#   'noch',
#   'gefallen',
#   'lassen',
#   'es',
#   'ist',
#   'genug',
#   'es',
#   'reicht',
#   'wen',
#   'reden',
#   'nichts',
#   'bringt',
#   'muß',
#   'es',
#   'eben',
#   'anders',
#   'gehenich',
#   'will',
#   'keine',
#   'asylanten',
#   'mehr',
#   'und',
#   'schwarze',
#   'kriminelle',
#   'schon',
#   'garnicht',
#   'raus',
#   'aus',
#   'deutschland',
#   'mit',
#   'den',
#   'pack'],
#  ['das', 'sind', 'tausende', 'taliban', 'is', 'oder', 'sonst', 'wer'],
#  ['lassen', 'sich', 'ausbilden', 'dann', 'boom'],
#  ['mann',
#   'brauch',
#   'kein',
#   'einzigen',
#   'davon',
#   'in',
#   'deutschland',
#   'europa'],
#  ['die',
#   'richtigen',
#   'flüchtlinge',
#   'lassen',
#   'alles',
#   'zurück',
#   'und',
#   'geben',
#   'alles',
#   'auf',
#   'um',
#   'mit',
#   'ten',
#   'von',
#   'anderen',
#   'auf',
#   'nem',
#   'boot',
#   'zu',
#   'treiben'],
#  ['überleben', 'fast', 'unmöglich'],
#  ['denk', 'mal', 'jetzt', 'nach', 'warum', 'man', 'trzd', 'flüchten', 'will'],
#  ['du', 'stinks', 'ja', 'wohl', 'selber'],
#  ['der', 'gehört', 'an', 'die', 'nächste', 'laterne', 'geknüpft'],
#  ['genau', 'diese', 'fachkräfte', 'braucht', 'und', 'will', 'unser', 'staat'],
#  ['na',
#   'super',
#   'dann',
#   'müssen',
#   'wir',
#   'wohl',
#   'auch',
#   'um',
#   'unsere',
#   'köpfe',
#   'fürchten',
#   '..',
#   'na',
#   'was',
#   'denkt',
#   'ihr',
#   'wie',
#   'viele',
#   'von',
#   'diesem',
#   'abschaum',
#   'schon',
#   'bei',
#   'uns',
#   'sind'],
#  ['aber',
#   'die',
#   'linken',
#   'und',
#   'grünen',
#   'sagen',
#   'ja',
#   'es',
#   'sind',
#   'harmlose',
#   'flüchtlinge'],
#  ['was', 'passiert'],
#  ['denn',
#   'die',
#   'sogenannten',
#   'guten',
#   'deutschen',
#   'müssen',
#   'erst',
#   'diskutieren',
#   'ob',
#   'seine',
#   'menschewnrechte',
#   'nicht',
#   'verletzt',
#   'werden/wurden'],
#  ['dann',
#   'kriegt',
#   'er',
#   'eine',
#   'tolle',
#   'bleibe',
#   'freie',
#   'krankenversorgung',
#   'freien',
#   'busausweis',
#   'und',
#   'was',
#   'immer',
#   'er',
#   'sonst',
#   'noch',
#   'auf',
#   'seinem',
#   'wqunschzettel',
#   'hat'],
#  ['das',
#   'ist',
#   'das',
#   'selbe',
#   'wie',
#   'damals',
#   '´mit',
#   'unserer',
#   'elterngeneration'],
#  ['die',
#   'haben',
#   'auch',
#   'gedacht',
#   'sie',
#   'bekommen',
#   'im',
#   'westen',
#   'das',
#   'goldene',
#   'kalb',
#   'serviert',
#   'und',
#   'haben',
#   'alles',
#   'hab',
#   'und',
#   'gut',
#   'auf',
#   'den',
#   'kopf',
#   'gehauen',
#   'um',
#   'rüber',
#   'zu',
#   'können',
#   'wie',
#   'es',
#   'uns',
#   'kindern',
#   'damit',
#   'ging',
#   'und',
#   'denen',
#   'die',
#   'sie',
#   'in',
#   'der',
#   'zone',
#   'zurückgelassen',
#   'haben',
#   'hat',
#   'doch',
#   'keine',
#   'blöde',
#   'sau',
#   'interessiert'],
#  ['nur',
#   'um',
#   'dann',
#   'festzustellen',
#   'das',
#   'hier',
#   'auch',
#   'nicht',
#   'alles',
#   'gold',
#   'ist',
#   'was',
#   'glänzt'],
#  ['övp/spö', 'es', 'reicht', 'die', 'grünen', 'österreichs', 'nein', 'danke'],
#  ['raus', 'mit', 'den', 'drecks', 'pack'],
#  ['die', 'eu', 'holt', 'den', 'terror', 'hier', 'her'],
#  ['sind', 'die', 'total', 'bescheuert', 'oder', 'was'],
#  ['weg', 'mit', 'den', 'müll'],
#  ['es', 'reicht', 'langsam'],
#  ['das', 'wird', 'nicht', 'der', 'einzige', 'sein', 'und', 'bleiben'],
#  ['steht', 'nie', 'in', 'der', 'bildzeitung', 'so', 'etwas'],
#  ['und', 'was', 'passiert', 'jetzt', 'mit', 'der', 'ratte'],
#  ['wir', 'lassen', 'die', 'pest', 'ins', 'land'],
#  ['na',
#   'wie',
#   'bei',
#   'der',
#   'is',
#   'kopf',
#   'ab',
#   '..',
#   'zwischen',
#   'und',
#   'euro',
#   'für',
#   'eine',
#   'flucht'],
#  ['soviel',
#   'geld',
#   'hab',
#   'ich',
#   'noch',
#   'nie',
#   'in',
#   'der',
#   'hand',
#   'gehabt'],
#  ['damit',
#   'könnte',
#   'sich',
#   'ein',
#   'tüchtiger',
#   'mensch',
#   'wie',
#   'ich',
#   'überall',
#   'ein',
#   'neues',
#   'leben',
#   'aufbauen'],
#  ['auch', 'oder', 'gerade', 'in', 'afrika'],
#  ['er',
#   'wird',
#   'fest',
#   'genommen',
#   'verhört',
#   'und',
#   'dann',
#   'für',
#   'immer',
#   'eingesperrt'],
#  ['nein',
#   'spaß',
#   'xd',
#   'er',
#   'kommt',
#   'in',
#   'ein',
#   'schönes',
#   'flüchtlingsquartier',
#   'mit',
#   'viel',
#   'platz',
#   'und',
#   'technick',
#   'gegenüber',
#   'ist',
#   'ein',
#   'kindergarten',
#   'mit',
#   'angrenzenden',
#   'spielplatz',
#   'wo',
#   'er',
#   'dann',
#   'immer',
#   'lang',
#   'gehn',
#   'kann',
#   '..',
#   'woher',
#   'nehmen',
#   'die',
#   'nur',
#   'das',
#   'geld'],
#  ['ins', 'boot', 'zurück', 'und', 'ab'],
#  ['wenn',
#   'ich',
#   'bei',
#   'einer',
#   'keuzfahrt',
#   'kabine',
#   'mit',
#   'fenster',
#   'und',
#   'balkon',
#   'buche',
#   'muß',
#   'ich',
#   'auch',
#   'mehr',
#   'bezahlen.würde',
#   'mich',
#   'noch',
#   'interresieren',
#   'was',
#   'ein',
#   'butler',
#   'kostet',
#   '..',
#   'alle',
#   'wieder',
#   'zurückschicken'],
#  ['v', 'hallo', 'freunde'],
#  ['“',
#   'zeig',
#   'mir',
#   'doch',
#   'was',
#   'mohammed',
#   'neues',
#   'gebracht',
#   'hat',
#   'und',
#   'da',
#   'wirst',
#   'du',
#   'nur',
#   'schlechtes',
#   'und',
#   'inhumanes',
#   'finden',
#   'wie',
#   'dies',
#   'daß',
#   'er',
#   'vorgeschrieben',
#   'hat',
#   'den',
#   'glauben',
#   'den',
#   'er',
#   'predigte',
#   'durch',
#   'das',
#   'schwert',
#   'zu',
#   'verbreiten.',
#   '”',
#   'zeig',
#   'mir',
#   'doch',
#   'was',
#   'mohammed',
#   'neues',
#   'gebracht',
#   'hat',
#   'und',
#   'da',
#   'wirst',
#   'du',
#   'nur',
#   'schlechtes',
#   'und',
#   'unmenschlich',
#   'wie',
#   'sein',
#   'befehl',
#   'durch',
#   'das',
#   'schwert',
#   'zu',
#   'verbreiten',
#   'den',
#   'glauben',
#   'den',
#   'er',
#   'predigte',
#   'zu',
#   'finden'],
#  ['+++',
#   '☩papst',
#   'benedikt',
#   'xvi☩',
#   'unter',
#   'berufung',
#   'auf',
#   'die',
#   'byzantinischen',
#   'christian',
#   'kaiser',
#   'dem',
#   'xiv',
#   'jahrhundert',
#   'manuel',
#   'ii',
#   'palaiologos',
#   'in',
#   '“',
#   'aula',
#   'magna',
#   '”',
#   'der',
#   'universität',
#   'regensburg',
#   'ratisbona',
#   'deutschland',
#   'im',
#   'jahr'],
#  ['lasst',
#   'uns',
#   'auch',
#   'beten',
#   'zur',
#   'umwandlung',
#   'von',
#   'franziskus',
#   'oder',
#   'kardinal',
#   'bergoglio'],
#  ['wie',
#   'und',
#   'oder',
#   'teilen',
#   'auch',
#   '“',
#   'genießen',
#   '”',
#   'und',
#   '/oder',
#   '“',
#   'aktie',
#   '”',
#   'zu',
#   'himmelfahrt',
#   'unseres',
#   'herrn',
#   'jesus',
#   'christus'],
#  ['christi',
#   'himmelfahrt',
#   '+++',
#   'unser',
#   'herr',
#   'von',
#   'bonfim',
#   'ein',
#   'sehr',
#   'berühmter',
#   'hingabe',
#   'an',
#   'den',
#   'bundesstaat',
#   'bahia',
#   'brasilien'],
#  ['“', 'in', 'hoc', 'signo', 'vinces', '”'],
#  ['haben',
#   'wenigstens',
#   'die',
#   'schlepper',
#   'was',
#   'davon',
#   'und',
#   'wenn',
#   'die',
#   'sich',
#   'das',
#   'leisten',
#   'können',
#   'kann',
#   'es',
#   'ja',
#   'nicht',
#   'sein',
#   'das',
#   'die',
#   'geld',
#   'von',
#   'uns',
#   'brauchen',
#   'also',
#   'merkel',
#   'und',
#   'co',
#   'ihr',
#   'müßt',
#   'nur',
#   'mal',
#   'ganz',
#   'kurz',
#   'darüber',
#   'nachdenken',
#   'was',
#   'da',
#   'zu',
#   'tun',
#   'ist',
#   'um',
#   'unser',
#   'steuergeld',
#   'zu',
#   'sparen'],
#  ['wie',
#   'kommt',
#   'die',
#   'zeitung',
#   'zu',
#   'solchen',
#   'preisen.waren',
#   'die',
#   'persönlich',
#   'vorort',
#   'um',
#   'nach',
#   'zu',
#   'fragen'],
#  ['überlegt',
#   'doch',
#   'einmal',
#   'was',
#   'eine',
#   'mutter',
#   'balg',
#   'uns',
#   'steuerzahlern',
#   'kostet'],
#  ['macht', 'die', 'augen', 'auf'],
#  ['schlechte', 'und', 'maximal', 'hetzende', 'bericht', 'erstattung'],
#  ['noch',
#   'weniger',
#   'wie',
#   'der',
#   'journalist',
#   'haben',
#   'die',
#   'menschen',
#   'im',
#   'kopf',
#   'die',
#   'es',
#   'glauben'],
#  ['schließen',
#   'und',
#   'die',
#   'ganze',
#   'familie',
#   'und',
#   'verwanten',
#   'sofort',
#   'abschieben-jeder',
#   'kriminelle',
#   'ausländer',
#   'wird',
#   'gleich',
#   'mit',
#   'der',
#   'ganzen',
#   'familie',
#   'abgeschoben',
#   'so',
#   'passen',
#   'die',
#   'ältern',
#   'fieleicht',
#   'auf',
#   'die',
#   'jüngern',
#   'auf'],
#  ['mütter', 'sind', 'um', 'einiges', 'schlimmer'],
#  ['ihr', 'scheiss', 'nazis'],
#  ['ihr', 'wixxer', 'ihr', 'nazi', 'haltet', 'die', 'fresse'],
#  ['als',
#   'was',
#   'kann',
#   'man',
#   'die',
#   'scheiß',
#   'islamisten',
#   'eigentlich',
#   'bezeichnen'],
#  ['restmüll', 'oder', 'sondermüll'],
#  ['jawol', 'direkt', 'raus', 'mit', 'kriminellen'],
#  ['bedauerlicher', 'einzelfall'],
#  ['das', 'gute', 'daran', 'dieses', 'pack', 'legt', 'sich', 'selber', 'um'],
#  ['egal', 'woher', 'sie', 'kommen'],
#  ['straffällige', 'ausländer', 'gehören', 'raus', 'ohne', 'ausnahme'],
#  ['ein', 'nicht', 'mehr', 'wegzudenkender', 'facharbeiter'],
#  ['diese', 'drecks', 'albaner'],
#  ['vor',
#   'zwei',
#   'jahren',
#   'haben',
#   'dieses',
#   'mist',
#   'schweine',
#   'ficker',
#   'von',
#   'albaner',
#   'einen',
#   'freund',
#   'von',
#   'mir',
#   'erschossen',
#   'wegen',
#   'nichts'],
#  ['die',
#   'sollen',
#   'sich',
#   'alle',
#   'zurück',
#   'nach',
#   'albanien',
#   'verpissen',
#   'und',
#   'sich',
#   'dort',
#   'gegenseitig',
#   'abknallen'],
#  ['drecks', 'volk'],
#  ['raus', 'mit', 'dem', 'pack'],
#  ['sofort', 'abschieben'],
#  ['sofort', 'raus'],
#  ['weg', 'damit'],
#  ['der',
#   'polizist',
#   'schaut',
#   'als',
#   'hätte',
#   'er',
#   'nen',
#   'geist',
#   'gesehn',
#   'd.',
#   'die',
#   'fehden',
#   'werden',
#   'hier',
#   'ausgetragen',
#   'weil',
#   'die',
#   'autos',
#   'dort',
#   'noch',
#   'nicht',
#   'zusammengeschraubt',
#   'sind'],
#  ['drecks', 'pack'],
#  ['wenigstens', 'machen', 'sie', 'sich', 'gegenseitig', 'alle'],
#  ['was', 'solls', 'wenns', 'dadurch', 'weniger', 'vom', 'pack', 'wird'],
#  ['schade', 'war', 'das', 'auto', 'wohl', 'leider', 'zu', 'langsam'],
#  ['ihr', 'nervt', 'langsam', 'mit', 'den', 'scheiß'],
#  ['den', 'zirkus', 'sollen', 'sie', 'in', 'ihrem', 'land', 'veranstalten'],
#  ['warum',
#   'hat',
#   'die',
#   'polizei',
#   'die',
#   'beiden',
#   'serben',
#   'denn',
#   'ihren',
#   'streit',
#   'nicht',
#   'zu',
#   'ende',
#   'führen',
#   'lassen'],
#  ['dann',
#   'hätten',
#   'wir',
#   'heute',
#   'zwei',
#   'probleme',
#   'weniger',
#   '..',
#   'wie',
#   'wärs',
#   'wenn',
#   'ihr',
#   'euch',
#   'um',
#   'euren',
#   'eigenen',
#   'scheiß',
#   'kümmert'],
#  ['d.', 'gut', 'gemacht', 'ihr', 'super', 'regierungspolitiker'],
#  ['wenn',
#   'der',
#   'staat',
#   'nicht',
#   'mehr',
#   'für',
#   'die',
#   'sicherheit',
#   'seiner',
#   'bürger',
#   'sorgen',
#   'kann',
#   'dann',
#   'werden',
#   'sie',
#   'es',
#   'irgendwann',
#   'selbst',
#   'in',
#   'die',
#   'hand',
#   'nehmen'],
#  ['ihr',
#   'seid',
#   'schuld',
#   'daran',
#   'dass',
#   'die',
#   'staatsbürger',
#   'in',
#   'diesem',
#   'land',
#   'immer',
#   'radikaler',
#   'werden'],
#  ['das',
#   'ist',
#   'in',
#   'deutschland',
#   'auch',
#   'so',
#   'aber',
#   'nur',
#   'einzeltäter',
#   'lächerlich',
#   'unsere',
#   'politiker'],
#  ['warum', 'beschweren', 'die', 'sich'],
#  ['war', 'doch', 'so', 'gewollt', 'wir', 'brauchen', 'doch', 'facharbeiter'],
#  ['ich',
#   'finde',
#   'die',
#   'ausländer',
#   'die',
#   'aus',
#   'süd-osteuropa',
#   'kommen',
#   'ganz',
#   'nett'],
#  ['ich',
#   'mag',
#   'wenn',
#   'die',
#   'ein',
#   'bisschen',
#   'action',
#   'auf',
#   'der',
#   'straße',
#   'bringen'],
#  ['so',
#   'hat',
#   'man',
#   'keine',
#   'langeweile',
#   'mehr',
#   '..',
#   'wieso',
#   'nicht',
#   'jahre',
#   'war',
#   'doch',
#   'mord'],
#  ['siebeneinhalb', 'jahre', 'für', 'ein', 'menschenleben'],
#  ['bedauerlicher',
#   'einzelfall-wie',
#   'immer',
#   '..',
#   'todesstrafe',
#   'wäre',
#   'besser',
#   'sollte',
#   'wieder',
#   'eigeführt',
#   'werden'],
#  ['in',
#   'jahren',
#   'ist',
#   'der',
#   'wieder',
#   'raus',
#   '..',
#   'a',
#   'witz',
#   'nach',
#   'draussen'],
#  ['abartige', 'justiz'],
#  ['die',
#   'südländer',
#   'sind',
#   'alles',
#   'kinder',
#   'daher',
#   'milderne',
#   'umstände',
#   'die',
#   'südis',
#   'wissen',
#   'wann',
#   'die',
#   'trännendüse',
#   'aktiviert',
#   'werden',
#   'muss',
#   '..',
#   'ein',
#   'moslem',
#   'hat',
#   'das',
#   'recht',
#   'seine',
#   'alte',
#   'kalt',
#   'zu',
#   'machen',
#   'minderwertig',
#   'für',
#   'die',
#   'es',
#   'ist',
#   'nur',
#   'eine',
#   'gebährmaschine',
#   'für',
#   'die',
#   'typen',
#   '..',
#   'lol',
#   'ja',
#   'das',
#   'böse',
#   'böse',
#   'kiffen',
#   'aber',
#   'so',
#   'leute',
#   'kommen',
#   'auf',
#   'freien',
#   'fuß',
#   'kann',
#   'mir',
#   'keiner',
#   'erzählen',
#   'daß',
#   'der',
#   'solange',
#   'einsitzt',
#   '..',
#   'mord',
#   'sollte',
#   'lebenslang',
#   'geben',
#   'scheissegal',
#   'wo',
#   'der',
#   'freggel',
#   'herkommt'],
#  ['deutsches',
#   'land',
#   'deutsche',
#   'gesetze',
#   '..',
#   'ach',
#   'ist',
#   'doch',
#   'nur',
#   'ein',
#   'einzelfall',
#   'aber',
#   'warum',
#   'nicht',
#   'lebenslänglich'],
#  ['aus', 'bosnien', 'moslem'],
#  ['betimmt', '..', 'viel', 'zu', 'wenig'],
#  ['ihr',
#   'affen',
#   'seit',
#   'untergebildet',
#   'doch',
#   'es',
#   'reicht',
#   'aus',
#   'um',
#   'mich',
#   'beim',
#   'schlagen',
#   'eurer',
#   'väter',
#   'zu',
#   'filmen',
#   'ihr',
#   'pedos'],
#  ['ich', 'bin', 'tierschützer'],
#  ['aber', 'dieses', 'gesochs', 'muss', 'raus'],
#  ['die', 'neuen', 'facharbeiter', 'eben'],
#  ['warum', 'hängt', 'man', 'abschaum', 'nicht', 'auf'],
#  ['ausländer', 'sind', 'alle', 'dreck'],
#  ['raus', 'aus', 'deutschland', 'mit', 'diesen', 'dreckfressen'],
#  ['raus', 'mit', 'das', 'pack'],
#  ['da', 'wäre', 'ich', 'auch', 'dafür'],
#  ['warum',
#   'ist',
#   'das',
#   'so',
#   'mit',
#   'den',
#   'kreaturen',
#   'ganz',
#   'einfach',
#   'weil',
#   'das',
#   'im',
#   'deutschen',
#   'knast',
#   'wie',
#   'ein',
#   'sterne-hotel',
#   'zu',
#   'vergleichen',
#   'ist',
#   'die',
#   'müssten',
#   'so',
#   'behandelt',
#   'weren',
#   'wo',
#   'se',
#   'herkommen',
#   'ganz',
#   'einfach'],
#  ['ja',
#   'da',
#   'sind',
#   'deutsche',
#   'polizisten',
#   'und',
#   'deutsche',
#   'kampfflieger',
#   'und',
#   'deutsche',
#   'raketenstationen',
#   'mitten',
#   'in',
#   'tirol',
#   'das',
#   'ist',
#   'ausläderkriminalität'],
#  ['ebenso',
#   'die',
#   'aus',
#   'meiner',
#   'sicht',
#   'kriminellen',
#   'tagungen',
#   'die',
#   'dieser',
#   'tage',
#   'diese',
#   'ausländerkriminalität',
#   'bedingen'],
#  ['deutschland', 'den', 'deutschen', 'ganz', 'einfach'],
#  ['wie',
#   'hießen',
#   'die',
#   'deutschen',
#   'straftäter',
#   'in',
#   'der',
#   'österreichischen',
#   'kriminalstatistik'],
#  ['etwa', 'murat', 'ali', 'chem', 'und', 'aiche'],
#  ['was', 'für', 'hurensöhne'],
#  ['zum', 'thema'],
#  ['die',
#   'frau',
#   'gab',
#   'den',
#   'beamten',
#   'zu',
#   'protokoll',
#   'dass',
#   'sie',
#   'von',
#   'ihrem',
#   'gatten',
#   'wiederholt',
#   'geschlagen',
#   'gewürgt',
#   'und',
#   'eingesperrt',
#   'worden',
#   'sei'],
#  ['er',
#   'soll',
#   'sie',
#   'mit',
#   'schlägen',
#   'gezwungen',
#   'haben',
#   '--',
#   '--',
#   '--',
#   '--',
#   '-ein',
#   'kopftuch',
#   'zu',
#   'tragen',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--'],
#  ['daher', 'weht', 'der'],
#  ['follower', 'was', 'ist', 'das'],
#  ['erklaert', 'einiges'],
#  ['na',
#   'da',
#   'sind',
#   'jetzt',
#   'einige',
#   'sehr',
#   'stumm',
#   'geworden',
#   'die',
#   'dies',
#   'als',
#   'hetze',
#   'gesehen',
#   'haben',
#   'traurig'],
#  ['wo', 'bleiben', 'die', 'lichterketten', 'und', 'demonstrationen'],
#  ['oder', 'gibt', 'es', 'das', 'nicht', 'fuer', 'diese', 'opfer'],
#  ['ihr',
#   'affen',
#   'seit',
#   'untergebildet',
#   'doch',
#   'es',
#   'reicht',
#   'aus',
#   'um',
#   'mich',
#   'beim',
#   'schlagen',
#   'eurer',
#   'väter',
#   'zu',
#   'filmen'],
#  ['ja',
#   'und',
#   'in',
#   'drei',
#   'jahren',
#   'stellt',
#   'im',
#   'ein',
#   'sogenannter',
#   'psychologe',
#   'eine',
#   'freifahrtschein',
#   'und',
#   'er',
#   'kann',
#   'wieder',
#   'durch',
#   'drehen'],
#  ['sowas', 'wegsperren', 'und', 'zubetonieren'],
#  ['kein',
#   'kommentar',
#   'benehmen',
#   'sich',
#   'wie',
#   'schwein',
#   'begehen',
#   'straftaten',
#   'bekommen',
#   'keinerlei',
#   'konsequenzen',
#   'unmöglich',
#   'o.o'],
#  ['mir',
#   'gefällt',
#   'nur',
#   'dass',
#   'auch',
#   'der',
#   'ehemalige',
#   'rote',
#   'bürgermeister',
#   'von',
#   'graz',
#   'nagl',
#   'hautnah',
#   'miterlebt',
#   'hat',
#   'wie',
#   'das',
#   'gesindel',
#   'das',
#   'er',
#   'nach',
#   'graz',
#   'geholt',
#   'hat',
#   'und',
#   'gegen',
#   'das',
#   'man',
#   'nicht',
#   'einmal',
#   'was',
#   'sagen',
#   'darf',
#   'sich',
#   'verhält'],
#  ['multikulti', 'ist', 'nicht', 'so', 'super', 'oder', 'genosse', 'nagl'],
#  ['die',
#   'asoziale',
#   'familie',
#   'ganz',
#   'einfach',
#   'ausrotten',
#   '..',
#   'typisches',
#   'balkangehabe',
#   'erschuettert',
#   'mich',
#   'wenig-ist',
#   'deren',
#   'kultur',
#   'die',
#   'sie',
#   'stur',
#   'beibehalten'],
#  ['der',
#   'haette',
#   'auch',
#   'nie',
#   'die',
#   'sissi',
#   'aus',
#   'dem',
#   'dorf',
#   'heiraten',
#   'wollen',
#   'nein',
#   'da',
#   'fahr',
#   'ma',
#   'in',
#   'die',
#   'so',
#   'schlechte',
#   'heimat',
#   'die',
#   'man',
#   'ja',
#   'verlassen',
#   'musste',
#   'und',
#   'importiert',
#   'gleich',
#   'wieder',
#   'eine',
#   'unfassbar',
#   'das',
#   'hier',
#   'zugesehen',
#   'wird'],
#  ['ist', 'm.e'],
#  ['ein', 'verbrechen', 'was', 'die', 'behoerden', 'auffuehren'],
#  ['ein',
#   'durchgeknallter',
#   'ausländer',
#   'rechtfertigt',
#   'keinen',
#   'pauschalen',
#   'ausländerhass',
#   '..',
#   'ihr',
#   'affen',
#   'seit',
#   'untergebildet',
#   'doch',
#   'es',
#   'reicht',
#   'aus',
#   'um',
#   'mich',
#   'beim',
#   'schlagen',
#   'eurer',
#   'väter',
#   'zu',
#   'filmen'],
#  ['wer', 'kommt', 'den', 'noch', 'nach', 'deutschland'],
#  ['immer',
#   'schön',
#   'aufpassen',
#   'und',
#   'sehr',
#   'wachsam',
#   'sein',
#   '..',
#   'was',
#   "für'n",
#   'religiöser',
#   'extremismus'],
#  ['islam',
#   'ist',
#   'keine',
#   'religion',
#   'und',
#   'hört',
#   'endlich',
#   'auf',
#   'den',
#   'wie',
#   'eine',
#   'religion',
#   'zu',
#   'behandeln'],
#  ['erkennt',
#   'dem',
#   'endlich',
#   'den',
#   'religionsstatus',
#   'ab',
#   'das',
#   'macht',
#   'vieles',
#   'einfacher'],
#  ['das',
#   'ist',
#   'wie',
#   'bei',
#   'den',
#   'kreuzzügen',
#   'nur',
#   'da',
#   'haben',
#   'die',
#   'muselmanen',
#   'eins',
#   'auf',
#   'die',
#   'eier',
#   'bekommen'],
#  ['man',
#   'sollten',
#   'denen',
#   'bei',
#   'der',
#   'geburt',
#   'die',
#   'klöten',
#   'gleich',
#   'abschneiden'],
#  ['oh', 'das', 'ist', 'aber', 'was', 'ganz', 'neues'],
#  ['keinglaube', 'wer', 'besser'],
#  ['es',
#   'ist',
#   'unglaublich',
#   'wie',
#   'das',
#   'gutdeutschentum',
#   'immer',
#   'wieder',
#   'noch',
#   'kriminell',
#   'gewordene',
#   'ausländer',
#   'und',
#   'migranten',
#   'beschützt'],
#  ['dieser',
#   'dreck',
#   'gehört',
#   'abgeschoben',
#   'notfalls',
#   'mit',
#   'harter',
#   'hand',
#   'und',
#   'eiserner',
#   'faust',
#   'koste',
#   'es',
#   'was',
#   'es',
#   'wolle',
#   '..',
#   'mal',
#   'kurz',
#   'aufm',
#   'punkt',
#   'gebracht',
#   'ohne',
#   'aggressivität',
#   'etc',
#   'wenn',
#   'wir',
#   'gehen'],
#  ['dann',
#   'nehmen',
#   'wir',
#   'alles',
#   'mit',
#   'ihr',
#   'dürft',
#   'nich',
#   'in',
#   'den',
#   'ausland',
#   'denn',
#   'da',
#   'seit',
#   'ihr',
#   'die',
#   'ausländer',
#   'ihr',
#   'habt',
#   'kein',
#   'eis',
#   'döner',
#   'ferrari',
#   'lamborghini',
#   'kein',
#   'spaghetti',
#   'kein',
#   'vodka',
#   'kein',
#   'obst',
#   'oder',
#   'gemüse',
#   'das',
#   'aus',
#   'dem',
#   'ausland',
#   'kommt',
#   'kein',
#   'i',
#   'phone',
#   'ihr',
#   'habt',
#   'dann',
#   'so',
#   'gut',
#   'wie',
#   'gar',
#   'nix'],
#  ['schon',
#   'krass',
#   'wie',
#   'menschen',
#   'alles',
#   'glauben',
#   'was',
#   'ihnen',
#   'gesagt',
#   'wird'],
#  ['wow',
#   'wie',
#   'erwachsen',
#   'ihr',
#   'doch',
#   'alle',
#   'seit',
#   'ihr',
#   'scheiss',
#   'nazis',
#   '..',
#   'in',
#   'dänemark',
#   'gabs',
#   'ne',
#   'demonstration',
#   'für',
#   'den',
#   'is',
#   'von',
#   'der',
#   'politik',
#   'erlaubt',
#   'zu',
#   'en',
#   'sinds',
#   'mit',
#   'schwarzen',
#   'fahnen',
#   'durch',
#   'die',
#   'stadt',
#   'gezogen',
#   'und',
#   'haben',
#   'allahuakbar',
#   'gerufen',
#   'ich',
#   'bin',
#   'auch',
#   'der',
#   'meinung',
#   'dass',
#   'es',
#   'bürgerkrieg',
#   'geben',
#   'wird'],
#  ['nur', 'halt', 'nicht', 'in', 'jahren', 'ich', 'tippe', 'so', 'auf'],
#  ['kinderficker',
#   'sei',
#   'dank',
#   'werde',
#   'ich',
#   'da',
#   'meine',
#   'heimat',
#   'schon',
#   'verlassen',
#   'haben'],
#  ['ps',
#   'die',
#   'gesamte',
#   'asiatische',
#   'welt',
#   'lacht',
#   'über',
#   'uns',
#   'und',
#   'das',
#   'ist',
#   'kein',
#   'witz'],
#  ['hust', 'kreuzzüge', 'hust', 'hab', 'ich', 'grad', 'kreuzzüge', 'gesagt'],
#  ['hm', 'immer', 'dieser', 'husten'],
#  ['diese', 'seite', 'wird', 'immer', 'rechter'],
#  ['ob', 'sich', 'bei', 'so', 'einem', 'noch', 'der', 'transport', 'lohnt'],
#  ['ruhig',
#   'stellen',
#   'bahngleis',
#   'setzen',
#   'lokführer',
#   'ablenken',
#   'oder',
#   'warnen',
#   '..',
#   'sowas',
#   'vor',
#   'jahre',
#   'da',
#   'wäre',
#   'ein',
#   'rollkommando',
#   'in',
#   'die',
#   'zelle',
#   'gekommen',
#   'und',
#   'ruhe',
#   'war.heute',
#   'ist',
#   'die',
#   'jva',
#   'ein',
#   'kindergarten',
#   '..',
#   'wenn',
#   'ich',
#   'es',
#   'aussuchen',
#   'dürfte',
#   'der',
#   'würde',
#   'sein',
#   'verhalten',
#   'bis',
#   'ans',
#   'ende',
#   'seiner',
#   'tage',
#   'zutiefst',
#   'bereuen'],
#  ['nun', 'da', 'gehen', 'kinder', 'schänden', 'mit', 'bewährung'],
#  ['oder',
#   'geld',
#   'strafe',
#   'nach',
#   'hause',
#   'was',
#   'willst',
#   'du',
#   'denn',
#   'von',
#   'diesen',
#   'korrupten',
#   'statt',
#   'noch',
#   'erwarten'],
#  ['ich',
#   'werde',
#   'massiv',
#   'von',
#   'abaadf',
#   'bedrohtmuss',
#   'ich',
# ...
#   'frage'],
#  ['ich',
#   'empfinde',
#   'die',
#   'flüchtlinge',
#   'als',
#   'eine',
#   'bedrohung',
#   'aber',
#   'gleichzeitig',
#   'empfinde',
#   'ich',
#   'eine',
#   'starke',
#   'apathie',
#   'gegenüber',
#   'der',
#   'glorifizierung',
#   'von',
#   'schwulen',
#   'lesben',
#   'und',
#   'anderen',
#   'minderheiten',
#   'weil',
#   'sowas',
#   'ein',
#   'land',
#   'nur',
#   'schwächt',
#   'und',
#   'es',
#   'der',
#   'lächerlichkeit',
#   'preisgibt'],
#  ['wo', 'stehe', 'ich'],
#  ['meine',
#   'es',
#   'ernst',
#   'und',
#   'würde',
#   'gern',
#   'eine',
#   'sachliche',
#   'diskussion',
#   'führen',
#   '..',
#   'die',
#   'zeit',
#   'der',
#   'eigenen',
#   'jugend-',
#   'und',
#   'kindertage',
#   'ist',
#   'immer',
#   'die',
#   'schönste'],
#  ['das', 'leben', 'war', 'unbeschwehrt'],
#  ['wir',
#   'sollten',
#   'zurück',
#   'in',
#   'die',
#   'vor',
#   'merkel',
#   'zeit',
#   'dann',
#   'würde',
#   'sie',
#   'nie',
#   'mehr',
#   'kanzlerin',
#   'werden',
#   '..',
#   'deutschland',
#   'war',
#   'und',
#   'ist',
#   'ein',
#   'land',
#   'der',
#   'extreme'],
#  ['dichter', 'und', 'denker', 'oder', 'richter', 'und', 'henker'],
#  ['ein', 'normales', 'dazwischen', 'gibt', 'es', 'wohl', 'nicht'],
#  ['im',
#   'augenblick',
#   'befürchtete',
#   'ich',
#   'daß',
#   'die',
#   'übertrieben',
#   'liberale',
#   'haltung',
#   'ein',
#   'erstarken',
#   'der',
#   'extreme',
#   'begünstigt',
#   'übrigens',
#   'rechts',
#   'wie',
#   'links',
#   'und',
#   'auch',
#   'reich',
#   'wie',
#   'arm'],
#  ['einwanderung',
#   'ja',
#   'aber',
#   'streng',
#   'kontrolliert',
#   'kriminelle',
#   'migranten',
#   'sofort',
#   'raus'],
#  ['auch', 'in', 'kriegsgebiete'],
#  ['caadaeb', 'das', 'ist', 'doch', 'deine', 'zeit', 'oder'],
#  ['kann', 'mir', 'einer', 'das', 'beantworten'],
#  ['hat',
#   'jemand',
#   'von',
#   'euch',
#   'familie',
#   'kinder',
#   'noch',
#   'eur',
#   'am',
#   'jahresende',
#   'zur',
#   'verfügung'],
#  ['auf',
#   'jeden',
#   'fall',
#   'kein',
#   'multi',
#   'kulti',
#   'keine',
#   'paralelgesellschaften',
#   'keine',
#   'stadtteile',
#   'wo',
#   'die',
#   'polizei',
#   'sich',
#   'nicht',
#   'rein',
#   'traut',
#   'keine',
#   'ausländichen',
#   'gebetshäuser',
#   'keine',
#   'grabscher',
#   'zur',
#   'jahreswende',
#   'keine',
#   'mit',
#   'ausländer',
#   'überfüllten',
#   'schulklassen',
#   'kein',
#   'asylheim',
#   'keine',
#   'scheinasylanten'],
#  ['na',
#   'ja',
#   'damals',
#   'waren',
#   'die',
#   'heutigen',
#   'kulturbereicherer',
#   'auch',
#   'nur',
#   'haushaltshilfen',
#   'oder',
#   'straßenkehrerfalls',
#   'es',
#   'überhaupt',
#   'welche',
#   'gab',
#   'in',
#   'deutschland',
#   'zu',
#   'der',
#   'zeit'],
#  ['macht',
#   'schon',
#   'nachdenklich',
#   'wie',
#   'die',
#   'welt',
#   'sich',
#   'verändert',
#   'hat'],
#  ['und', 'es', 'gab', 'nicht', 'wenige', 'nicht-berliner', 'vor', 'ort'],
#  ['jahren', 'nach', 'islam'],
#  ['wunderschöner', 'film'],
#  ['kein',
#   'wahlrecht',
#   'für',
#   'frauen',
#   'miserable',
#   'jobs',
#   'keine',
#   'freie',
#   'berufswahl',
#   'für',
#   'frauen',
#   'usw'],
#  ['wo', 'seit', 'ihr', 'eigentlich', 'stehen', 'geblieben'],
#  ['ich',
#   'mag',
#   'zwar',
#   'auch',
#   'luftige',
#   'kleider',
#   'und',
#   'miniröcke',
#   'aber',
#   'diese',
#   'zeit',
#   'hatte',
#   'einen',
#   'tollen',
#   'kleidungsstil'],
#  ['orientiere', 'mich', 'ab', 'und', 'an', 'selbst', 'heute', 'noch', 'daran'],
#  ['schöne', 'heile', 'welt'],
#  ['das', 'ist', 'doch', 'münchen'],
#  ['da',
#   'laufen',
#   'die',
#   'polizisten',
#   'auch',
#   'noch',
#   'mit',
#   'säbel',
#   'rum',
#   'und',
#   'würden',
#   'einem',
#   'die',
#   'hand',
#   'abhacken',
#   '✌️'],
#  ['wo', 'deutschland', 'noch', 'deutsch', 'war'],
#  ['ich',
#   'hoffe',
#   'doch',
#   'das',
#   'es',
#   'frau',
#   'petry',
#   'besser',
#   'macht',
#   'wenn',
#   'es',
#   'so',
#   'sein',
#   'sollte'],
#  ['jajadie',
#   'gute',
#   'alten',
#   'zeiten',
#   'sagt',
#   'manich',
#   'bin',
#   'jetzt',
#   'dann',
#   'waren',
#   'meine',
#   'guten',
#   'alten',
#   'zeiten',
#   'wohl',
#   'die',
#   'vor',
#   'der',
#   'angie',
#   'm',
#   '..',
#   'das',
#   'waren',
#   'noch',
#   'richtige',
#   'männer'],
#  ['und',
#   'dieser',
#   'hiphop',
#   'und',
#   'techno',
#   'scheissdreck',
#   'hat',
#   'auch',
#   'nicht',
#   'die',
#   'ohren',
#   'der',
#   'leute',
#   'verpestet'],
#  ['da',
#   'war',
#   'die',
#   'zeit',
#   'noch',
#   'in',
#   'ordnung',
#   '..',
#   'da',
#   'gab',
#   'es',
#   'noch',
#   'das',
#   'große',
#   'kaiserreich',
#   'und',
#   'es',
#   'gab',
#   'sehr',
#   'sehr',
#   'viele',
#   'deutsche'],
#  ['die',
#   'wurden',
#   'so',
#   'langsam',
#   'vernichtet',
#   'und',
#   'day',
#   'land',
#   'wurde',
#   'immer',
#   'kleiner'],
#  ['die',
#   'poitik',
#   'wurde',
#   'weiter',
#   'so',
#   'geführt',
#   'day',
#   'deutsche',
#   'immer',
#   'weniger',
#   'kinder',
#   'bekommen',
#   'konnten'],
#  ['und',
#   'nun',
#   'wird',
#   'der',
#   'rest',
#   'erledigt',
#   'da',
#   'deutschland',
#   'komplett',
#   'von',
#   'der',
#   'landkarte',
#   'verschwindet',
#   '..',
#   'diese',
#   'kultur',
#   'darf',
#   'und',
#   'kann',
#   'man',
#   'nicht',
#   'kaputt',
#   'machen',
#   '..',
#   'ich',
#   'würde',
#   'lieber',
#   'in',
#   'der',
#   'zeit',
#   'leben',
#   'als',
#   'in',
#   'der',
#   'jetzigen'],
#  ['dort', 'gab', 'es', 'noch', 'ordnung'],
#  ['sehr', 'interessant'],
#  ['wollen', 'wir', 'unseren', 'alten', 'kaiser', 'wilhelm', 'wieder', 'ham'],
#  ['um', 'hatten', 'frauen', 'in', 'deutschland', 'keine', 'rechte'],
#  ['weder',
#   'ein',
#   'wahlrecht',
#   'noch',
#   'eine',
#   'möglichkeit',
#   'zu',
#   'studieren',
#   'sie',
#   'wurden',
#   'verhairatet',
#   'und',
#   'waren',
#   'zu',
#   'hause',
#   'für',
#   'mann',
#   'und',
#   'kinder',
#   'da'],
#  ['wenn',
#   'eine',
#   'frau',
#   'sich',
#   'nicht',
#   'so',
#   'benahm',
#   'wie',
#   'man',
#   'es',
#   'erwartete',
#   'wurde',
#   'sie',
#   'wie',
#   'viele',
#   'tausende',
#   'leidensgefährtinen',
#   'in',
#   'psychatrischen',
#   'anstalten',
#   'weggeschlossen'],
#  ['lebenslang', 'ohne', 'chance', 'auf', 'selbstbestimmung'],
#  ['wenn',
#   'ihr',
#   'euch',
#   'für',
#   'frauen',
#   'einsetzt',
#   'dann',
#   'bitte',
#   'erst',
#   'mal',
#   'nachdeken',
#   'und',
#   'recherchieren'],
#  ['ihr',
#   'hast',
#   'die',
#   'moslime',
#   'weil',
#   'sie',
#   'ihre',
#   'frauen',
#   'keine',
#   'rechte',
#   'gewähren',
#   'und',
#   'wünscht',
#   'euch',
#   'eine',
#   'zeit',
#   'in',
#   'der',
#   'es',
#   'für',
#   'eine',
#   'west',
#   'europäischer',
#   'frau',
#   'genauso',
#   'war',
#   '..',
#   'zu',
#   'der',
#   'zeit',
#   'war',
#   'deutschland',
#   'kaum',
#   'anders',
#   'als',
#   'saudi',
#   'arabien',
#   'eine',
#   'frau',
#   'in',
#   'leggins',
#   'würde',
#   'in',
#   'den',
#   'knast',
#   'gesteckt',
#   'zu',
#   'der',
#   'zeit'],
#  ['schon',
#   'witzig',
#   'wie',
#   'hier',
#   'einige',
#   'denken',
#   'das',
#   'diese',
#   'zeit',
#   'toll',
#   'für',
#   'eine',
#   'frau',
#   'gewesen',
#   'is'],
#  ['vom',
#   'mann',
#   'beherrscht',
#   'und',
#   'zwangsverheiratet',
#   'sexueller',
#   'missbrauch',
#   'danach',
#   'normal'],
#  ['das',
#   'waren',
#   'die',
#   'zeiten',
#   'vor',
#   'jahren',
#   'und',
#   'nicht',
#   'anders',
#   '..',
#   'da',
#   'gab',
#   'es',
#   'noch',
#   'keine',
#   'ausländer'],
#  ['ich',
#   'will',
#   'nicht',
#   'mehr',
#   'in',
#   'dieser',
#   'zeit',
#   'leben',
#   'in',
#   'der',
#   'es',
#   'nur',
#   'noch',
#   'fb',
#   'und',
#   'lauter',
#   'horrornachrichten',
#   'gibt'],
#  ['früher', 'was', 'doch', 'alles', 'viel', 'besser'],
#  ['abcacbcad',
#   'du',
#   'hättest',
#   'damals',
#   'in',
#   'der',
#   'zeit',
#   'ein',
#   'auf',
#   'die',
#   'fresse',
#   'bekommen',
#   'wenn',
#   'das',
#   'wort',
#   'geil',
#   'ausgeprochen',
#   'hätte'],
#  ['das',
#   'war',
#   'ja',
#   'auch',
#   'bevor',
#   'überhaupt',
#   'das',
#   'erste',
#   'mal',
#   'über',
#   'eine',
#   'armlänge',
#   'in',
#   'deutschland',
#   'gesprochen',
#   'wurde',
#   '..',
#   'sehnsucht',
#   'nach',
#   'der',
#   'guten',
#   'alten',
#   'zeit'],
#  ['nee', 'nur', 'nach', 'frieden'],
#  ['ja',
#   'wir',
#   'haben',
#   'auch',
#   'eine',
#   'andere',
#   'wertschätzung',
#   'und',
#   'kultur'],
#  ['unseren', 'neuen', 'evtl'],
#  ['neuen', 'bundesbürger', 'haben', 'das', 'nicht'],
#  ['deutsche', 'geschichte', 'sehr', 'interessant'],
#  ['damals', 'war', 'echt', 'alles', 'besser'],
#  ['nur',
#   'ein',
#   'paar',
#   'beispiele',
#   'um',
#   'lag',
#   'die',
#   'lebenserwartung',
#   'bei',
#   'durchschnittlich',
#   'jahren',
#   'lag',
#   'man',
#   'starb',
#   'an',
#   'einer',
#   'blinddarmentzündung',
#   'und',
#   'jeder'],
#  ['säugling', 'überlebte', 'den', 'geburtsvorgang', 'nicht'],
#  ['und',
#   'zuviel',
#   'smartphone',
#   'würden',
#   'die',
#   'kinder',
#   'damals',
#   'wohl',
#   'als',
#   'luxusproblem',
#   'einschätzen',
#   'da',
#   'sie',
#   'stunden',
#   'täglich',
#   'ab',
#   'einem',
#   'alter',
#   'von'],
#  ['jahren', 'in', 'textilfabriken', 'arbeiteten'],
#  ['na',
#   'ja',
#   'wenn',
#   'sie',
#   'adelig',
#   'waren',
#   'war',
#   "'s",
#   'natürlich',
#   'besser',
#   'echt',
#   'hohler',
#   'geht',
#   "'s",
#   'nimmer'],
#  ['ist',
#   'euch',
#   'aufgefallen',
#   'wie',
#   'viele',
#   'uniformierte',
#   'auf',
#   'der',
#   'strasse',
#   'zu',
#   'sehen',
#   'sind'],
#  ['und',
#   'die',
#   'uniform',
#   'wurde',
#   'auch',
#   'noch',
#   'respektiertkein',
#   'respekt',
#   'dann',
#   'gab',
#   'es',
#   'mit',
#   'dem',
#   'knüppel',
#   'auf',
#   'die',
#   '..',
#   'schön',
#   'und',
#   'anscheinend',
#   'ein',
#   'ganz',
#   'friedliches',
#   'zusammen',
#   'leben',
#   '..',
#   'aber',
#   'warewn',
#   'echt',
#   'kacke',
#   'angezogen',
#   'die',
#   'leute'],
#  ['es', 'ist', 'schön', 'mal', 'zurück', 'zu', 'schauen'],
#  ['ihr', 'werdet', 'für', 'jedes', 'verfickte', 'wort', 'bezahlen'],
#  ['ihr', 'seid', 'die', 'wahren', 'volksverräter'],
#  ['spätestens',
#   'wenn',
#   'wir',
#   'bahnhofwinker',
#   'nicht',
#   'mehr',
#   'mit',
#   'teddybären',
#   'werfen',
#   'könnt',
#   'ihr',
#   'beweisen',
#   'was',
#   'für',
#   'krasse',
#   'typen',
#   'ihr',
#   'seid',
#   'scheiß',
#   'stammtischpatrioten',
#   '..',
#   'das',
#   'ist',
#   'propaganda',
#   'für',
#   'ungebildete',
#   'aber',
#   'von',
#   'den',
#   'kommentaren',
#   'ist',
#   'schon',
#   'abzulesen',
#   'das',
#   'es',
#   'schief',
#   'geht',
#   'und',
#   'die',
#   'meisten',
#   'ahnung',
#   'von',
#   'geschichte',
#   'haben'],
#  ['ja',
#   'die',
#   'gute',
#   'alte',
#   'zeit',
#   'enge',
#   'feuchte',
#   'wohnungen',
#   'dunkle',
#   'unhygienische',
#   'hinterhöfe',
#   'verwahrloste',
#   'sich',
#   'selbst',
#   'überlassene',
#   'kinder'],
#  ['vor',
#   'jahren',
#   'hatten',
#   'wir',
#   'frauen',
#   'auch',
#   'oft',
#   'nix',
#   'zu',
#   'lachen'],
#  ['wir', 'wurden', 'von', 'männern', 'belächelt'],
#  ['egal', 'wie', 'geistreich', 'wir', 'waren'],
#  ['wir',
#   'sollten',
#   'heiraten',
#   'und',
#   'kinder',
#   'kriegen.der',
#   'ehemann',
#   'hatte',
#   'das',
#   'sagen.genau',
#   'wie',
#   'es',
#   'heute',
#   'noch',
#   'in',
#   'vielen',
#   'muslimischen',
#   'gegenden',
#   'ist',
#   '..',
#   'wir',
#   'wollen',
#   'unsern',
#   'kaiser',
#   'wilhelm',
#   'wieder',
#   'haben'],
#  ['sensationelle', 'aufnahmen'],
#  ['da', 'gab', 'es', 'noch', 'sitte', 'und', 'antstand'],
#  ['köln', 'was', 'war', 'das', 'schön'],
#  ['und',
#   'nur',
#   'weil',
#   'nazis',
#   'und',
#   'solche',
#   'die',
#   'angeblich',
#   'keine',
#   'sein',
#   'wollten',
#   'immer',
#   'mehr',
#   'hass',
#   'und',
#   'ängste',
#   'gegen',
#   'eine',
#   'minderheit',
#   'verbreiteten'],
#  ['manche', 'menschen', 'so', 'kleingeistig'],
#  ['stimmt',
#   'damals',
#   'hatten',
#   'die',
#   'frauen',
#   'keine',
#   'rechte',
#   'deswegen',
#   'mussten',
#   'se',
#   'auf',
#   'nix',
#   'achten'],
#  ['das', 'is', 'doch', 'münchen', 'feldherrenhalle', 'und', 'theatinerkirche'],
#  ['zumindest', 'bei'],
#  ['ah',
#   'wie',
#   'schön',
#   'das',
#   'war',
#   'als',
#   'es',
#   'noch',
#   'sowas',
#   'wie',
#   'zucht',
#   'und',
#   'ordnung',
#   'aber',
#   'vorallem',
#   'menschlichkeit',
#   'und',
#   'nächstenliebe',
#   'gabnaja',
#   'aus',
#   'der',
#   'traum'],
#  ['hurra', 'diese', 'welt', 'geht', 'unter'],
#  ['sehr', 'schön', 'und', 'der', 'marienplatz', 'und', 'der', 'odeonsplatz'],
#  ['das',
#   'ist',
#   'wohl',
#   'wahr‼️',
#   'da',
#   'waren',
#   'die',
#   'menschen',
#   'noch',
#   'menschen',
#   'und',
#   'keine',
#   'bestien'],
#  ['febca',
#   'das',
#   'ist',
#   'doch',
#   'quatsch',
#   '‼️‼️',
#   'gewiss',
#   'es',
#   'gab',
#   'mehr',
#   'strenge',
#   'mehr',
#   'indoktrination',
#   'aber',
#   'ich',
#   'glaube',
#   'unter',
#   'dem',
#   'strich',
#   'war',
#   'es',
#   'dennoch',
#   'die',
#   'friedliche',
#   'und',
#   'schönere',
#   'zeit',
#   'und',
#   'wenn',
#   'du',
#   'menschen',
#   'jenseits',
#   'der',
#   'fragst',
#   'wie',
#   'das',
#   'leben',
#   'früher',
#   'war',
#   'so',
#   'hörst',
#   'du',
#   'unisono',
#   'da',
#   'war',
#   'das',
#   'leben',
#   'noch',
#   'schön',
#   '..',
#   'die',
#   'guuute',
#   'alte',
#   'zeit'],
#  ['wenn',
#   'man',
#   'bedenkt',
#   'was',
#   'danach',
#   'passiert',
#   'ist',
#   'dann',
#   'sehe',
#   'ich',
#   'das',
#   'nicht',
#   'so',
#   'bunt',
#   'und',
#   'friedlich'],
#  ['ihr',
#   'hast',
#   'die',
#   'moslime',
#   'weil',
#   'sie',
#   'ihre',
#   'frauen',
#   'keine',
#   'rechte',
#   'gewähren',
#   'und',
#   'wünscht',
#   'euch',
#   'eine',
#   'zeit',
#   'in',
#   'der',
#   'es',
#   'für',
#   'eine',
#   'west',
#   'europäischer',
#   'frau',
#   'genauso',
#   'war',
#   '..',
#   'schöne',
#   'bilder'],
#  ['da', 'gab', 'es', 'ja', 'auch', 'noch', 'keine', 'einwanderer'],
#  ['meine',
#   'großmutter',
#   'hatte',
#   'kinder',
#   'und',
#   'so',
#   'oft',
#   'ich',
#   'auch',
#   'nachfragte',
#   'sie',
#   'wollte',
#   'es',
#   'nicht',
#   'ändern',
#   'sie',
#   'war',
#   'glücklich',
#   'hatte',
#   'keine',
#   'not',
#   'alles',
#   'war',
#   'friedlich',
#   'und',
#   'geschlagen',
#   'wurde',
#   'sie',
#   'von',
#   'niemanden'],
#  ['übrigens',
#   'minirock',
#   'und',
#   'implantate',
#   'gab',
#   'es',
#   'noch',
#   'nicht',
#   'was',
#   'es',
#   'nicht',
#   'gibt',
#   'kann',
#   'einen',
#   'auch',
#   'nicht',
#   'fehlen'],
#  ['wie', 'weit', 'damals', 'schon', 'entwickelt', 'wahnsinn'],
#  ['achja',
#   'weil',
#   'es',
#   'da',
#   'auch',
#   'so',
#   'viele',
#   'frauenrechte',
#   'im',
#   'allgemeinen',
#   'gab',
#   'd.',
#   'fcdbfd',
#   'da',
#   'sahen',
#   'die',
#   'frauen',
#   'noch',
#   'aus',
#   'wie',
#   'frauen',
#   'und',
#   'bei',
#   'den',
#   'männern',
#   'das',
#   'gleiche'],
#  ['da',
#   'könnt',
#   'ihr',
#   'erzählen',
#   'was',
#   'ihr',
#   'wollt',
#   'das',
#   'war',
#   'eine',
#   'schöne',
#   'zeit',
#   'wäre',
#   'der',
#   'erste',
#   'weltkrieg',
#   'nicht',
#   'passiert',
#   'beziehungsweise',
#   'hätten',
#   'sie',
#   'ihn',
#   'uns',
#   'nicht',
#   'aufs',
#   'auge',
#   'gedrückt',
#   'wäre',
#   'der',
#   'zweite',
#   'auch',
#   'nicht',
#   'passiert',
#   'vielleicht',
#   'wären',
#   'wir',
#   'dann',
#   'heute',
#   'eine',
#   'moderne',
#   'monarchie',
#   'mit',
#   'dem',
#   'kaiser',
#   'der',
#   'zu',
#   'seinem',
#   'deutschen',
#   'volk',
#   'steht',
#   'das',
#   'wäre',
#   'glaube',
#   'ich',
#   'wunderschön'],
#  ['träumträumträum', 'schluuuchz'],
#  ['also', 'wie', 'in', 'deutschland'],
#  ['ist',
#   'doch',
#   'in',
#   'deutschland',
#   'nicht',
#   'anders',
#   '..',
#   'was',
#   'bringt',
#   'es',
#   'sowas',
#   'zu',
#   'vertuschen'],
#  ['macht', 'doch', 'alles', 'nur', 'schlimmer', 'wo', 'ist', 'der', 'sinn'],
#  ['es',
#   'ist',
#   'überall',
#   'das',
#   'selbe',
#   'früher',
#   'war',
#   'indonesien',
#   'auch',
#   'christlich',
#   'und',
#   'heute',
#   'sind',
#   'sie',
#   'in',
#   'der',
#   'minderheit',
#   'nur',
#   'lslamismus',
#   'und',
#   'das',
#   'passiert',
#   'mit',
#   'europa',
#   'auch',
#   'wenn',
#   'unsere',
#   'politiker',
#   'und',
#   'gutmenschen',
#   'nicht',
#   'endlich',
#   'wach',
#   'werden'],
#  ['bin',
#   'ja',
#   'richtig',
#   'froh',
#   'das',
#   'nicht',
#   'nur',
#   'wir',
#   'deutschen',
#   'fuer',
#   'dumm',
#   'verkauft',
#   'werden'],
#  ['na', 'was', 'solls', 'ist', 'doch', 'bei', 'uns', 'genauso'],
#  ['das', 'ist', 'doch', 'schon', 'immer', 'so'],
#  ['vor',
#   'über',
#   'jahren',
#   'wurden',
#   'die',
#   'zahlen',
#   'der',
#   'ausländischen',
#   'verbrecher',
#   'schon',
#   'geschönt'],
#  ['bei',
#   'uns',
#   'in',
#   'bedeutet',
#   'der',
#   'code',
#   'männer',
#   'mit',
#   'dunkler',
#   'hauttyp'],
#  ['erzählt', 'doch', 'mal', 'was', 'neues'],
#  ['genau', 'das', 'gleiche', 'auch', 'in', 'deutschland'],
#  ['die',
#   'sind',
#   'ja',
#   'genauso',
#   'doof',
#   ',es',
#   'kommt',
#   'doch',
#   'irgendwann',
#   'raus'],
#  ['ist', 'doch', 'hier', 'genauso', 'pro'],
#  ['durch',
#   'diesen',
#   'flüchtlings-strom',
#   'hatt',
#   'europa',
#   'angst',
#   'dass',
#   'es',
#   'zu',
#   'grunde',
#   'geht',
#   'und',
#   'deshalb',
#   'wierd',
#   'alles',
#   'verschwiegen.es',
#   'sind',
#   'unsere',
#   'politiker',
#   'die',
#   'alles',
#   'verschweigen',
#   'und',
#   'vertuschen',
#   'wollen',
#   'doch',
#   'die',
#   'wahrheit',
#   'kommt',
#   'trotzdem',
#   'ans',
#   'licht'],
#  ['überall', 'werden', 'die', 'bürger', 'nur', 'noch', 'verdummt'],
#  ...]

# %%
hatespeech4=""

with open("hatespeech/german_dataset.tsv") as csvdatei:
    csv_reader_object = csv.reader(csvdatei, delimiter="\t")
    csv_hate = list(csv_reader_object)[1:]
    for row in csv_hate:
        x = row[1]
        x = x.replace("#", "")
        x = re.sub(r"http\S+|\.\.+|\S+\/\/+|www\S+|\d+|@[A-Za-z0-9]+","", x)
        x+="."
        x = x.lower()
        hatespeech4 += " " + x

# %%
hatespeech4 = clean(hatespeech4)

# %%
hatespeech4
# Out:
# [['frank', 'rennicke', '–', 'ich', 'bin', 'stolz'],
#  ['ansehenund', 'danach', 'bitte', 'teilenteilenteilen'],
#  ['koeln',
#   'mohamed',
#   'erkennt',
#   'kein',
#   'deutsches',
#   'recht',
#   'sondern',
#   'nur',
#   'die',
#   'scharia',
#   'an'],
#  ['das',
#   'er',
#   'den',
#   'kölner',
#   'dom',
#   'kaputt',
#   'machen',
#   'wollte',
#   'war',
#   'nur',
#   'ein',
#   'scherz',
#   'aber',
#   'wenn',
#   'er',
#   'aus',
#   'dem',
#   'knast',
#   'rauskommt',
#   'hat',
#   'er',
#   'kein',
#   'mitleid',
#   'mehr'],
#  ['saudiarabien',
#   'ist',
#   'eine',
#   'brutale',
#   'islamische',
#   'diktatur',
#   'und',
#   'richtete',
#   'kürzlich',
#   'fünf',
#   'männer',
#   'wegen',
#   'ihre',
#   'homosexualität',
#   'hin'],
#  ['welche',
#   'konsequenzen',
#   'hat',
#   'das',
#   'für',
#   'das',
#   'verhältnis',
#   'zu',
#   'saudi-arabien',
#   'nach',
#   'meinung',
#   'der',
#   'bundesregierung'],
#  ['die', 'antwort', 'im', 'video'],
#  ['bundespolizei', 'münchen', 'hat', 'im'],
#  ['quartal', 'rund'],
#  ['illegale',
#   'einreisen',
#   'registriert',
#   'die',
#   'migranten',
#   'stammten',
#   'v.',
#   'a.',
#   'aus',
#   'nigeria',
#   'afghanistan',
#   'serbien',
#   'albanien',
#   'und',
#   'der',
#   'türkei',
#   'je',
#   'ein',
#   'drittel',
#   'kam',
#   'mit',
#   'pkw',
#   'bzw'],
#  ['per', 'bahn', 'ein', 'viertel', 'mit', 'dem', 'bus', 'einreise'],
#  ['europafueralle',
#   'oder',
#   'wie',
#   'es',
#   'die',
#   'spd',
#   'heute',
#   'noch',
#   'bildhafteter',
#   'formuliert',
#   'hat',
#   'und',
#   'willst',
#   'du',
#   'nicht',
#   'mein',
#   'bruder',
#   'sein',
#   'so',
#   'schlage',
#   'ich',
#   'dir',
#   'denn',
#   'schädel',
#   'ein'],
#  ['jusos', 'nospd', 'baseballschläger', 'niewiedersozialismus'],
#  ['hannover',
#   'weil',
#   'ihm',
#   'die',
#   'freizeitgestaltung',
#   'und',
#   'ihr',
#   'umgang',
#   'mit',
#   'männern',
#   'nicht',
#   'passt',
#   'tritt',
#   'und',
#   'schlägt',
#   'mustafa',
#   'f.',
#   'auf',
#   'seine',
#   'ehemalige',
#   '-nach',
#   'islamischem',
#   'recht-',
#   'ehefrau',
#   'alina',
#   'ein',
#   'rasiert',
#   'ihr',
#   'den',
#   'schädel',
#   'kahl',
#   'bruder',
#   'wegen',
#   'ähnlicher',
#   'tat',
#   'vor',
#   'gericht'],
#  ['deutschland',
#   'ort',
#   'für',
#   'die',
#   'eu-wahlparty',
#   'der',
#   'afd',
#   'wurde',
#   'gerade',
#   'gekündigt'],
#  ['vermieter',
#   'und',
#   'mieter',
#   'wurden',
#   'massiv',
#   'von',
#   'linksextremisten',
#   'bedroht'],
#  ['das',
#   'gebäude',
#   'wurde',
#   'bereits',
#   'am',
#   'letzten',
#   'wochenende',
#   'beschmiert',
#   'und',
#   'es',
#   'wurde',
#   'damit',
#   'gedroht',
#   'das',
#   'gebäude',
#   'zu',
#   'beschädigen',
#   'und',
#   'autos',
#   'anzuzünden',
#   '..',
#   'innsbruck',
#   'tirolerin',
#   'und',
#   'türke',
#   'knacken',
#   'zahlreiche',
#   'automaten',
#   'bei',
#   'auto-waschanlagen',
#   'und',
#   'tankstellen',
#   'anhand',
#   'dort',
#   'gefundener',
#   'dna',
#   'kommt',
#   'heraus',
#   'dass',
#   'der',
#   'türke',
#   'auch',
#   'für',
#   'vergewaltigung',
#   'einer',
#   'frau',
#   'in',
#   'innsbruck',
#   'in',
#   'der',
#   'silvesternacht',
#   'verantwortlich',
#   'ist'],
#  ['wien',
#   'vier',
#   'nigerianer',
#   'bestellen',
#   'teils',
#   'hochpreisige',
#   'produkte',
#   'unter',
#   'falschen',
#   'namen',
#   'holen',
#   'sie',
#   'in',
#   'paketshops',
#   'ab',
#   'und',
#   'behalten',
#   'sie',
#   'ohne',
#   'zu',
#   'bezahlen',
#   'bei',
#   'einem',
#   'afrikaner',
#   'werden',
#   'teils',
#   'originalverpackte',
#   'produkte',
#   'handys',
#   'laptops',
#   'bekleidung',
#   'usw'],
#  ['offenburg',
#   'somalier',
#   'greift',
#   'nachts',
#   'auf',
#   'der',
#   'straße',
#   'einen',
#   'senioren',
#   'an',
#   'tritt',
#   'derart',
#   'massiv',
#   'auf',
#   'den',
#   'am',
#   'boden',
#   'liegenden',
#   '-jährigen',
#   'ein',
#   'dass',
#   'er',
#   'mit',
#   'schweren',
#   'kopfverletzungen',
#   'ins',
#   'krankenhaus',
#   'gebracht',
#   'wird'],
#  ['offenburg',
#   'die',
#   'attacke',
#   'des',
#   'nach',
#   'd',
#   'gekommen',
#   'somaliers',
#   'auf',
#   'den',
#   '-jährigen',
#   'war',
#   'ein',
#   'solcher',
#   'gewaltexzess',
#   'dass',
#   'das',
#   'opfer',
#   'noch',
#   'nicht',
#   'vernehmungsfähig',
#   'und',
#   'wohl',
#   'auf',
#   'einem',
#   'auge',
#   'erblindet',
#   'ist',
#   'laut',
#   'einem',
#   'zeugen',
#   'rief',
#   'der',
#   'täter',
#   'bei',
#   'der',
#   'tat',
#   "'allahu",
#   'akbar'],
#  ['kapazitäten',
#   'im',
#   'zdf',
#   'und',
#   'zur',
#   'eurowahl',
#   'den',
#   'islam',
#   'gibt',
#   'es',
#   'erst',
#   'seit',
#   'dem'],
#  ['jahrhundert',
#   'aber',
#   'frans',
#   'timmermans',
#   'der',
#   'kommissionspräsident',
#   'werden',
#   'will',
#   'meint',
#   'dass',
#   'der',
#   'islam',
#   'seit',
#   'jahre',
#   'zu',
#   'europa',
#   'gehört'],
#  ['keinen', 'stört', "'s", 'das', 'publikum', 'klatscht'],
#  ['mdr', 'umfrage', "'gehört", 'der', 'islam', 'zu', 'deutschland'],
#  ['beteiligten',
#   'sich',
#   'und',
#   'hier',
#   'zeigt',
#   'sich',
#   'der',
#   'unterschied',
#   'zwischen',
#   'propaganda',
#   'und',
#   'realem',
#   'empfinden',
#   'der',
#   'menschen'],
#  ['da',
#   'musste',
#   'der',
#   'moderator',
#   'wohl',
#   'mal',
#   'hinschauen',
#   'bei',
#   'dem',
#   'ergebnis'],
#  ['immerhin',
#   'wird',
#   'im',
#   'mdr',
#   'wohl',
#   'nicht',
#   'gefälscht',
#   'zumindest',
#   'bei',
#   'der',
#   'umfrage',
#   'nicht'],
#  ['eu-kommissar',
#   'frans',
#   'timmermans',
#   'sagt',
#   'der',
#   'islam',
#   'gehört',
#   'seit'],
#  ['jahren', 'zu', 'europa'],
#  ['interessant',
#   '–',
#   'demnach',
#   'war',
#   'der',
#   'prophet',
#   'mohammed',
#   'also',
#   'ein',
#   'zeitgenosse',
#   'von',
#   'jesus',
#   'und',
#   'augustus'],
#  ['bildungsdesaster', 'geschichtsklitterung'],
#  ['wenn',
#   'ein',
#   'syrer',
#   'den',
#   '_gruenen',
#   'erzählt',
#   'dass',
#   'er',
#   'sich',
#   'wegen',
#   'kriminellen',
#   'flüchtlingen',
#   'in',
#   'deutschland',
#   'unsicher',
#   'fühlt',
#   'wird',
#   'er',
#   'von',
#   'den',
#   'gruenen',
#   'als',
#   'afd',
#   'propagandist',
#   'und',
#   'rechter',
#   'hetzer',
#   'verunglimpft'],
#  ['ein', 'syrer'],
#  ['berlin',
#   'ibrahima',
#   'd.',
#   'von',
#   'der',
#   'elfenbeinküste',
#   'überfällt',
#   'an',
#   'einem',
#   'abend',
#   'vier',
#   'frauen',
#   'in',
#   'kreuzberg',
#   'brutal',
#   'raubt',
#   'ihnen',
#   'geld',
#   'und',
#   'handys',
#   'vor',
#   'gericht',
#   'rechtfertigt',
#   'er',
#   'sich',
#   'mit',
#   '“',
#   'andere',
#   'machen',
#   'viel',
#   'schlimmeres',
#   '”'],
#  ['is-terror-verdächtiger', 'salafist', 'in', 'koeln', 'festgenommen'],
#  ['der',
#   'deutsch-tunesier',
#   'sabri',
#   'ben',
#   'a.',
#   'gilt',
#   'als',
#   'größe',
#   'im',
#   'produzieren',
#   'von',
#   'propagandavideos'],
#  ['er',
#   'soll',
#   'mehrfach',
#   'nach',
#   'syrien',
#   'gereist',
#   'und',
#   'ein',
#   'terrorcamp',
#   'mit',
#   'gegenständen',
#   'im',
#   'wert',
#   'von',
#   '.€',
#   'ausgerüstet',
#   'haben'],
#  ['einreise',
#   'per',
#   'flugzeug',
#   'regierung',
#   'erklärt',
#   'flüchtlingszahlen',
#   'zur',
#   'geheimsache',
#   'afd',
#   'prüft',
#   'rechtliche',
#   'schritte'],
#  ['wegen',
#   'volksverhetzung',
#   'kann',
#   'nach',
#   'derzeitiger',
#   'rechtslage',
#   'nicht',
#   'bestraft',
#   'werden',
#   'wer',
#   'seine',
#   'hetze',
#   'gegen',
#   'deutsche',
#   'richtet',
#   'um',
#   'diese',
#   'ungleichbehandlung',
#   'zu',
#   'ändern',
#   'hat',
#   'afd',
#   'gesetzentwurf',
#   'vorgelegt',
#   'aber',
#   'rechtsausschuss',
#   'lehnt',
#   'afd-antrag',
#   'auf',
#   'anhörung',
#   'von',
#   'experten',
#   'ab'],
#  ['dass',
#   'deutsche',
#   'durch',
#   "'flüchtling/schutzsuchende",
#   'brutal',
#   'ermordert',
#   'wurden',
#   'seit',
#   'oder',
#   'in',
#   'einem',
#   'jahr',
#   'ist',
#   'natürlich',
#   'im',
#   'vergleich',
#   'zum',
#   'zerreissen',
#   'koran',
#   'nichts',
#   'man',
#   'man',
#   'diese',
#   'journalie',
#   'ist',
#   'nicht',
#   'zum',
#   'aushalten',
#   '..',
#   'jetzt',
#   'stellt',
#   'euch',
#   'mal',
#   'vor',
#   'ein',
#   'deutscher',
#   'hätte',
#   'das',
#   'jährige',
#   'mädchen',
#   'vergewaltigt',
#   'und',
#   'wäre',
#   'durch',
#   'syrische',
#   'flüchtlinge',
#   'gestellt',
#   'worden'],
#  ['sondersendungen',
#   'der',
#   'dankbarkeit',
#   'von',
#   'maischberger',
#   'bis',
#   'illner',
#   'plus',
#   'staatsbürgerschaft',
#   'und',
#   'bundesverdienstkreuz',
#   'wäre',
#   'die',
#   'folge',
#   '..',
#   'weil',
#   'in',
#   'bremen',
#   'korane',
#   'zerrissen',
#   'wurden',
#   'sendet',
#   'das',
#   'minuten',
#   'lang',
#   'einen',
#   'bericht',
#   'der',
#   'empörung'],
#  ['das',
#   'in',
#   'dessauroßlau',
#   'ein',
#   'jähriges',
#   'mädchen',
#   'von',
#   'einem',
#   'flüchtling',
#   'vergewaltigt',
#   'und',
#   'von',
#   'zeugen',
#   'gestellt',
#   'wurde',
#   'darüber',
#   'schweigt',
#   'das'],
#  ['_zmd',
#   'reden',
#   'sie',
#   'lieber',
#   'einmal',
#   'davon',
#   'wieviel',
#   'kirchen',
#   'und',
#   'christliche',
#   'symbole',
#   'hier',
#   'in',
#   'europa',
#   'vom',
#   'ihren',
#   'glaubensideologen',
#   'geschändet',
#   'wurden'],
#  ['dem',
#   'bundestag',
#   'ist',
#   'es',
#   'wichtiger',
#   'gegen',
#   'rechts',
#   'zu',
#   'hetzen',
#   'anstatt',
#   'wichtige',
#   'anliegen',
#   'zu',
#   'bearbeiten'],
#  ['machen',
#   'die',
#   'überhaupt',
#   'noch',
#   'etwas',
#   'anderes',
#   'ausser',
#   'gegen',
#   'die',
#   'afd',
#   'kämpfen'],
#  ['alle',
#   'müssen',
#   'etwas',
#   'mehr',
#   'tun❗',
#   'sonst',
#   'wird',
#   'es',
#   'viel',
#   'leid',
#   'geben'],
#  ['mehr', 'als'],
#  ['viel', 'mehr❗', 'und', 'in', 'jeder', 'hinsicht❗'],
#  ['in',
#   'berlin',
#   'werden',
#   'künftig',
#   'auch',
#   'studienabbrecher',
#   'an',
#   'öffentlichen',
#   'schulen',
#   'kinder',
#   'unterrichten'],
#  ['läuft',
#   'in',
#   'der',
#   'bildungsrepublik',
#   'deutschland',
#   '..',
#   'ich',
#   'persönlich',
#   'finde',
#   'dass',
#   'die',
#   'toilette',
#   'der',
#   'geeignete',
#   'platz',
#   'für',
#   'dieses',
#   'buch',
#   'ist'],
#  ['besser',
#   'ist',
#   'es',
#   'allerdings',
#   'es',
#   'nicht',
#   'zu',
#   'kaufen',
#   'und',
#   'einbrechen',
#   'geht',
#   'zu',
#   'weit'],
#  ['ermittelt',
#   'der',
#   'staatschutz',
#   'eigentlich',
#   'auch',
#   'bei',
#   'der',
#   'schändung',
#   'christlicher',
#   'kirchen',
#   'und',
#   'friedhöfe'],
#  ['afd', 'in', 'brandenburg', 'jetzt', 'nummer'],
#  ['die',
#   'wahlen',
#   'im',
#   'herbst',
#   'werden',
#   'das',
#   'politische',
#   'gefüge',
#   'in',
#   'ganz',
#   '🇩🇪',
#   'erschüttern',
#   'und',
#   'vllt'],
#  ['auch', 'die', 'groko', 'sprengen'],
#  ['ich', 'freue', 'mich', 'drauf'],
#  ['+++',
#   'heimatschatzkiste',
#   'ein',
#   'schritt',
#   'in',
#   'die',
#   'richtige',
#   'richtung',
#   '+++',
#   'dazu',
#   'erklärt',
#   'der',
#   'sozialpolitische',
#   'sprecher',
#   'der',
#   'afd-fraktion',
#   'ltmv',
#   'mv'],
#  ['nein',
#   'uns',
#   'ostdeutschen',
#   'fehlt',
#   'nicht',
#   'der',
#   'kontakt',
#   'zu',
#   'ausländern',
#   'sondern',
#   'den',
#   'westdeutschen',
#   'fehlt',
#   'eher',
#   'das',
#   'selbstbewusstsein',
#   'und',
#   'der',
#   'mut',
#   'kriminellen',
#   'einen',
#   'riegel',
#   'vorzuschieben',
#   'afd',
#   'afdimbundestag'],
#  ['wir', 'können', 'sie', 'nicht', 'zwingen', 'mit', 'uns', 'zu', 'regieren'],
#  ['wir',
#   'können',
#   'sie',
#   'aber',
#   'dazu',
#   'zwingen',
#   'immer',
#   'dreistere',
#   'dem',
#   'wählerwillen',
#   'widersprechende',
#   'verliererkoalitionen',
#   'bilden',
#   'zu',
#   'müssen'],
#  ['nach',
#   'suboptimalem',
#   'fahrverhalten',
#   'zweier',
#   'autofahrer',
#   'in',
#   'bahrenfeld',
#   'und',
#   'altenwerder',
#   'wurden',
#   'ihre',
#   'hochwertigen',
#   'fahrzeuge',
#   'und',
#   'die',
#   'führerscheine',
#   'sichergestellt'],
#  ['geplünderte',
#   'mittelschicht',
#   'die',
#   'freude',
#   'bei',
#   'einer',
#   'gehaltserhöhung',
#   'währt',
#   'nur',
#   'kurz',
#   'denn',
#   'der',
#   'staat',
#   'kassiert',
#   'deutschlands',
#   'durchschnittsverdiener',
#   'gnadenlos',
#   'ab'],
#  ['von',
#   'euro',
#   'mehr',
#   'bleibt',
#   'am',
#   'ende',
#   'weniger',
#   'als',
#   'die',
#   'hälfte'],
#  ['afd', 'bundestag', '➡️'],
#  ['nebenbei',
#   'nicht',
#   'nur',
#   'um',
#   'ihre',
#   'familien',
#   'zu',
#   'ernähren',
#   'sondern',
#   'auch',
#   'um',
#   'diesen',
#   'staat',
#   'zwangsweise',
#   'zu',
#   'finanzieren',
#   '..',
#   '„',
#   'wurde',
#   'in',
#   'den',
#   'letzten',
#   'jahren',
#   'vonseiten',
#   'der',
#   'politik',
#   'auf',
#   'verteilen',
#   'statt',
#   'schaffen',
#   'von',
#   'wohlstand',
#   'gesetzt',
#   'steht',
#   'uns',
#   'ein',
#   'noch',
#   'radikalerer',
#   'weg',
#   'bevor.',
#   '“',
#   'klasse',
#   'fundierter',
#   'und',
#   'bedrückender',
#   'lagebericht',
#   'von'],
#  ['wenn',
#   'der',
#   'staat',
#   'damit',
#   'wenigstens',
#   'für',
#   'die',
#   'zukunft',
#   'sorgen',
#   'würde'],
#  ['bildung',
#   'innovation',
#   'infrastruktur',
#   'stattdessen',
#   'sozialstaat',
#   'für',
#   'alle',
#   '..',
#   "💩👉'cohn-bendit",
#   'ist',
#   'kein',
#   'altersverwirrter',
#   'spinner',
#   'sondern',
#   'ein',
#   'knallharter',
#   'machtgeiler',
#   'kaderschmied',
#   'der',
#   'modernen',
#   'herrschsucht'],
#  ['kein',
#   'mythos',
#   'sondern',
#   'realität',
#   'in',
#   'deutschland',
#   'muss',
#   'ein',
#   'durchschnittsverdiener',
#   'mehr',
#   'als',
#   'die',
#   'hälfte',
#   'von',
#   'jedem',
#   'zusätzlich',
#   'verdienten',
#   'euro',
#   'an',
#   'den',
#   'staat',
#   'abführen'],
#  ['bei',
#   'der',
#   'veranstaltung',
#   'sind',
#   'auch',
#   'alle',
#   "'öffentlichen",
#   'leute',
#   'herzlich',
#   'willkommen',
#   'fl'],
#  ['ist',
#   'dass',
#   'nur',
#   'für',
#   'die',
#   'akademie',
#   'oder',
#   'auch',
#   'für',
#   'öffentliche',
#   'leute'],
#  ['seid', 'auch', 'mit', 'dabei'],
#  ['activecityday',
#   'wir',
#   'sind',
#   'es',
#   'schon',
#   'amp',
#   'tage',
#   'im',
#   'jahr',
#   'aktiv',
#   'in',
#   'unserer',
#   'stadt'],
#  ['hamburgactivecity',
#   'kommt',
#   'zum',
#   'training',
#   'für',
#   'das',
#   'deutsche',
#   'sportabzeichen',
#   'mit',
#   'unserer',
#   'polizeiakademie'],
#  ['juni', 'uhr', 'leichtathletikhalle', 'in', 'winterhude'],
#  ['spendentour🚴\u200d♂️🚴\u200d♂️🚴\u200d♂️',
#   'vier',
#   'unserer',
#   'kollegen',
#   'mit',
#   'streckenweise',
#   'weiteren',
#   "'mitfahrern",
#   'sind',
#   'seit',
#   'freitag',
#   'mit',
#   'dem',
#   'fahrrad',
#   'auf',
#   'deutschlandtour',
#   'durch',
#   'die',
#   'hauptstädte',
#   'aller',
#   'bundesländer',
#   'und',
#   'sammeln',
#   'spenden'],
#  ['helfernhelfen', 'mehr', 'infos'],
#  ['spendentour',
#   'helfernhelfen🚴\u200d♂️🚴\u200d♂️🚴\u200d♂️',
#   'am',
#   'sonntag',
#   'haben',
#   'unsere',
#   'radler',
#   'nach',
#   'höhenmetern',
#   'amp',
#   'km',
#   'weimar',
#   'erreicht'],
#  ['heute',
#   'sind',
#   'sie',
#   'in',
#   'berlin',
#   'und',
#   'machen',
#   'sich',
#   'auf',
#   'den',
#   'weg',
#   'zur',
#   'kattenstiegsmühle',
#   'um',
#   'morgen',
#   'schwerin',
#   'zu',
#   'erreichen'],
#  ['mehr', 'infos'],
#  ['ich',
#   'drücke',
#   'jetzt',
#   'erst',
#   'recht',
#   'die',
#   'daumen',
#   'dafür',
#   'dass',
#   'er',
#   'als',
#   'erster',
#   'afd-politiker',
#   'das',
#   'amt',
#   'des',
#   'oberbürgermeisters',
#   'bekleidet'],
#  ['dass',
#   'er',
#   'dies',
#   'im',
#   'sinne',
#   'der',
#   'bürger',
#   'von',
#   'görlitz',
#   'ausüben',
#   'wird',
#   'daran',
#   'besteht',
#   'nicht',
#   'der',
#   'geringste',
#   'zweifel'],
#  ['wippel', '➡️'],
#  ["👍💪👍💪👍💪👍💪'es",
#   'reiche',
#   'aus',
#   'wenn',
#   'die',
#   'aktion',
#   'grundsätzlich',
#   'geeignet',
#   'gewesen',
#   'sei',
#   'jemanden',
#   'einzuschüchtern',
#   'befand',
#   'der',
#   'bgh'],
#  ['das',
#   'landgericht',
#   'hat',
#   'dies',
#   'nun',
#   'mit',
#   'der',
#   'verurteilung',
#   'bejaht'],
#  ['einige',
#   'verteidiger',
#   'kündigten',
#   'bereits',
#   'an',
#   'revision',
#   'einzulegen'],
#  ['diese',
#   'art',
#   'und',
#   'weise',
#   'menschen',
#   'zu',
#   'verteufeln',
#   'die',
#   'anders',
#   'leben',
#   'oder',
#   'denken',
#   'als',
#   'man',
#   'selbst',
#   'das',
#   'macht',
#   'mich',
#   'echt',
#   'wütend'],
#  ['leute',
#   'fahren',
#   'mit',
#   'dem',
#   'auto',
#   'zur',
#   'arbeit',
#   'um',
#   'ihre',
#   'familien',
#   'zu',
#   'ernähren'],
#  ['jürgen', 'trittin', 'lässt', 'sich', 'fahren'],
#  ['isdn',
#   'verbieten',
#   'glasfaserkabel',
#   'verbieten',
#   'kabelfernsehen',
#   'verbieten',
#   'digitalisierung',
#   'der',
#   'telefonie',
#   'verbieten',
#   'sogar',
#   'computer',
#   'wollten',
#   'die',
#   'grünen',
#   'nicht'],
#  ['ein',
#   'blick',
#   'in',
#   'frühere',
#   'parteiprogramme',
#   'zeigt',
#   'die',
#   'tradition',
#   'von',
#   '_gruenen',
#   'als',
#   'verbotspartei',
#   'quelle'],
#  ['die',
#   'afd',
#   'warnt',
#   'schon',
#   'lange',
#   'davor',
#   'dass',
#   'die',
#   'schule',
#   'von',
#   'links-grünen',
#   'lehrern',
#   'unter',
#   'missachtung',
#   'des',
#   'beutelsbacher_konsens',
#   'zur',
#   'politischen',
#   'beeinflussung',
#   'der',
#   'schüler',
#   'missbraucht',
#   'wird'],
#  ['man', 'fühlt', 'sich', 'in', 'schlimmste', 'ddr-zeiten', 'zurückversetzt'],
#  ['nichts', 'ist', 'in', 'deutschland', 'mehr', 'unmöglich👎'],
#  ['görlitzistschlaugörlitzwähltblau',
#   '🇩🇪',
#   'ein',
#   'klares',
#   'ja',
#   'für',
#   'bundesweit',
#   'starten',
#   'migranten',
#   'juden',
#   'und',
#   'homosexuelle',
#   'einen',
#   'gegenprotest'],
#  ['zuvor',
#   'hatte',
#   "'hollywood",
#   'dazu',
#   'aufgerufen',
#   'den',
#   'afd',
#   'ob.-kandidaten',
#   'nicht',
#   'zu',
#   'wählen'],
#  ["'ein",
#   'video',
#   'von',
#   'illegalen',
#   'migranten',
#   'auf',
#   'einem',
#   'schiff',
#   'in',
#   'zarzis',
#   'sorgte',
#   'für',
#   'aufregung'],
#  ['die',
#   'vorwiegend',
#   'jungen',
#   'männer',
#   'skandierten',
#   'ihre',
#   'forderung',
#   'nach',
#   'einreise',
#   'in',
#   'd',
#   'eu'],
#  ['die',
#   'tunesische',
#   'regierung',
#   'hat',
#   'jetzt',
#   'beschlossen',
#   'die',
#   'männer',
#   'müssen',
#   'in',
#   'ihre',
#   'heimat',
#   'zurück'],
#  ['geldern',
#   'zwei',
#   'mit',
#   'osteuropäischem',
#   'akzent',
#   'sprechende',
#   'jugendliche',
#   'überfallen',
#   'morgens',
#   'zwei',
#   'geschwisterkinder',
#   'auf',
#   'dem',
#   'schulweg',
#   'und',
#   'fordern',
#   'geld',
#   'treten',
#   'dem',
#   '-jährigen',
#   'in',
#   'den',
#   'bauch',
#   'schlagen',
#   'die',
#   'köpfe',
#   'der',
#   'brüder',
#   'zusammen',
#   'die',
#   'kein',
#   'geld',
#   'dabei',
#   'haben'],
#  ['offenburg', 'jähriger', 'somalier', 'verprügelt', 'jährigen', 'senior'],
#  ['tritt',
#   'solange',
#   'auf',
#   'den',
#   'kopf',
#   'des',
#   'am',
#   'boden',
#   'liegenden',
#   'seniors',
#   'ein',
#   'bis',
#   'dieser',
#   'bewusstlos',
#   'ist',
#   'und',
#   'mit',
#   'schweren',
#   'kopfverletzungen',
#   'in',
#   'die',
#   'klinik',
#   'kommt'],
#  ['bürgermeister-wahlen',
#   'in',
#   'italien',
#   'deutsche',
#   'medien',
#   'verschweigen',
#   'dass',
#   'massenhaft',
#   'sozialistische',
#   'hochburgen',
#   'an',
#   'salvini',
#   "'s",
#   'lega',
#   'fallen'],
#  ['grüne', 'spielen', 'dort', 'übrigens', 'keine', 'rolle'],
#  ['_junge_mdl',
#   'und',
#   'wahrscheinlich',
#   'können',
#   'sie',
#   'diese',
#   'behauptung',
#   'mit',
#   'fakten',
#   'unterlegen'],
#  ['ein',
#   'kleinkind',
#   'über',
#   'die',
#   'balkonbrüstung',
#   'halten',
#   'und',
#   'damit',
#   'drohen',
#   'es',
#   'in',
#   'die',
#   'tiefe',
#   'fallen',
#   'zu',
#   'lassen',
#   'bleibt',
#   'straflos',
#   'wenn',
#   'man',
#   'dessen',
#   'vater',
#   'und',
#   "'flüchtling",
#   'ist',
#   'der',
#   'gerade',
#   'von',
#   'der',
#   'polizei',
#   'nach',
#   'albanien',
#   'abgeschoben',
#   'werden',
#   'soll'],
#  ['_angebrannt',
#   'in',
#   'diesem',
#   'land',
#   'ist',
#   'jeder',
#   'rechts™/rechtsextrem™',
#   'der',
#   'nicht',
#   'innerhalb',
#   'der',
#   'von',
#   'linkslinken',
#   'amp',
#   'grünen',
#   'definierten',
#   'markierung',
#   '🎯',
#   'steht'],
#  ['protestierende',
#   'bürger',
#   'amp',
#   'eltern',
#   'einer',
#   "'schützt",
#   'unsere',
#   "kinder'-demo",
#   'dessau',
#   '=rechtsextrem™'],
#  ['so', 'soll', 'legitimer', 'protest', 'diskreditiert', 'werden'],
#  ['_angebrannt',
#   'der',
#   'spontanen',
#   'demo',
#   'in',
#   'dessau',
#   'rosslau',
#   'lag',
#   'ein',
#   'schwerer',
#   'sexueller',
#   'missbrauch',
#   'an',
#   'einem',
#   'jährigen'],
#  ['mädchen',
#   'durch',
#   'j.',
#   'asylbewerber',
#   'aus',
#   'niger',
#   'zugrunde',
#   'der',
#   'inzwischen',
#   'verhaftet',
#   'werden',
#   'konnte'],
#  ['dramatisierung', 'unerwünscht', 'faktenfinder', 'refugeeswelcome'],
#  ['„',
#   'ohne',
#   'ausreichend',
#   'personal',
#   'den',
#   'richtigen',
#   'einsatzmitteln',
#   'und',
#   'vor',
#   'allem',
#   'dem',
#   'politischen',
#   'willen',
#   'gepaart',
#   'mit',
#   'dem',
#   'nötigen',
#   'rückhalt',
#   'und',
#   'vertrauen',
#   'in',
#   'die',
#   'wird',
#   'dort',
#   'nie',
#   'ruhe',
#   'einkehren.',
#   '“',
#   'bn',
#   '_nachtfloh'],
#  ['die',
#   'deutsch',
#   'iranische',
#   'freundschaft',
#   'in',
#   'herzlichkeit',
#   'verbunden'],
#  ['ich',
#   'möchte',
#   'hier',
#   'offiziell',
#   'betonen',
#   'daß',
#   'herr',
#   'steinmeier',
#   'nicht',
#   'mein',
#   'präsident',
#   'und',
#   'sicherlich',
#   'auch',
#   'nicht',
#   'mein',
#   'außenminister',
#   'ist'],
#  ['bundesregierung', 'steinmeier', 'israel', 'antisemitismus'],
#  ['wenn',
#   'die',
#   'das',
#   'nächste',
#   'mal',
#   'nach',
#   'görlitz',
#   'kommen',
#   'können',
#   'sie',
#   'die',
#   'patenschaft',
#   'für',
#   'einige',
#   'hundert',
#   'schutzsuchende',
#   'übernehmen',
#   'und',
#   'um',
#   'sich',
#   'besser',
#   'zu',
#   'kümmern',
#   'sie',
#   'gleich',
#   'mitnehmen'],
#  ['offener',
#   'brief',
#   'vor',
#   'obm-wahl',
#   'hollywood-stars',
#   'bitten',
#   'görlitzer',
#   'wählt',
#   'weise'],
#  ['_hake_nach',
#   'ich',
#   'rufe',
#   'dazu',
#   'auf',
#   'von',
#   'nun',
#   'an',
#   'die',
#   'filme',
#   'bücher',
#   'mit',
#   'amp',
#   'von',
#   '👇',
#   'zu',
#   'boykottieren'],
#  ['_bruhl',
#   'burghardt',
#   'klaußner',
#   'bernhard',
#   'schlink',
#   'gleiches',
#   'gilt',
#   'auch',
#   'für',
#   'veranstaltungen',
#   'amp',
#   'merchandising',
#   'jeglicher',
#   'art',
#   '..',
#   '_bruhl',
#   'bin',
#   'von',
#   'ganzem',
#   'herzen',
#   '💙dabei'],
#  ['afd',
#   'afdwählen',
#   'deutschland',
#   'hat',
#   'nur',
#   'mit',
#   'der',
#   'afd',
#   'eine',
#   'chance',
#   'auf',
#   'zukunft'],
#  ['sonst',
#   'werden',
#   'wir',
#   'alle',
#   'ps',
#   'und',
#   'lesen',
#   'und',
#   'kaufen',
#   'sollte',
#   'tabu',
#   'sein'],
#  ['gehört',
#   'außerdem',
#   'zu',
#   'spd',
#   '..',
#   '_bruhl',
#   'an',
#   'die',
#   'hollywood-phantasten',
#   'wir',
#   'wählen',
#   'afd',
#   'weil',
#   'wir',
#   'unsere',
#   'freiheit',
#   'erhalten',
#   'wollen',
#   'bedroht',
#   'von',
#   'einer',
#   'von',
#   'altparteien',
#   'geförderten',
#   'ideologie',
#   'mit',
#   'endziel',
#   'weltherrschaft',
#   'weltweit',
#   'für',
#   'hunderttausende',
#   'tote/verletzte',
#   'verantwortlich',
#   'auch',
#   'in',
#   'deutschland'],
#  ['wer', 'hat', 'dem', 'kriminellen', 'grapscher', 'das', 'geschrieben'],
#  ['so',
#   'viel',
#   'iq',
#   'hat',
#   'der',
#   'nicht',
#   'dass',
#   'der',
#   'auch',
#   'nur',
#   'einen',
#   'satz',
#   'fehlerfrei',
#   'schreiben',
#   'kann',
#   '..',
#   '●',
#   'massive',
#   'eingriffe',
#   'in',
#   'die',
#   'freiheitsrechte',
#   '●',
#   'schwächung',
#   'der',
#   'wirtschaftlichen',
#   'mitte',
#   '●',
#   'massive',
#   'steuermehrbelastung',
#   'der',
#   'bürger',
#   '●',
#   'sozialistische',
#   'tendenzen',
#   'rg',
#   'vier',
#   'gründe',
#   'die',
#   'gruenen',
#   'nicht',
#   'mehr',
#   'zu',
#   'wählen',
#   'und',
#   'nun'],
#  ['🤔', 'kanzlerkandidatin'],
#  [',der',
#   'reporterseinen',
#   'presseausweis',
#   'zückte',
#   'u',
#   'sich',
#   'mit',
#   'einem',
#   'abstand',
#   'von',
#   'lt',
#   'cm',
#   'vor',
#   'dem',
#   'gesicht',
#   'eines',
#   'beamten',
#   'aufbaute'],
#  ['er',
#   'meinte',
#   'nach',
#   'polizeiangaben',
#   'dass',
#   'man',
#   'ihm',
#   'gar',
#   'nichts',
#   'könne',
#   'da',
#   'er',
#   'journalist',
#   'sei'],
#  [',polizei',
#   'kein',
#   'benehmen',
#   'trotz',
#   'hohem',
#   'bildungsabschluss',
#   'zdf'],
#  ['früher', 'warst', 'du', 'jahre', 'eingesperrt'],
#  ['oder',
#   'du',
#   'hast',
#   'dein',
#   'eigenes',
#   'leben',
#   'riskiert',
#   'für',
#   'die',
#   'idee',
#   'freiheit',
#   'und',
#   'demokratie'],
#  ['heute',
#   'reicht',
#   'schulschwänzen',
#   'gegen',
#   'den',
#   'klimawandel',
#   'für',
#   'den',
#   'friedensnobelpreis'],
#  ['den', 'preis', 'kann', 'man', 'schon', 'vergessen'],
#  ['merkel',
#   'hinterlässt',
#   'verbrannte',
#   'erde',
#   'für',
#   'die',
#   'cdu',
#   'aber',
#   'sogar',
#   'auch',
#   'außenpolitisch'],
#  ['dass',
#   'ihr',
#   'der',
#   'amerikanische',
#   'präsident',
#   'nicht',
#   'einmal',
#   'mehr',
#   'die',
#   'hand',
#   'gibt',
#   'zeigt',
#   'den',
#   'schweren',
#   'flurschaden',
#   'an',
#   'dem',
#   'sie',
#   'nicht',
#   'unschuldig',
#   'ist',
#   '..',
#   '😂👍da',
#   'fragt',
#   'man',
#   'sich',
#   'was',
#   'feiern',
#   'die',
#   'denn',
#   'da'],
#  ['sich',
#   'selbst',
#   'da',
#   'sie',
#   'auf',
#   'den',
#   'grünen',
#   'ideologen',
#   'zug',
#   'aufgesprungen',
#   'sind'],
#  ['wenn',
#   'sie',
#   'sich',
#   'über',
#   'zu',
#   'hohe',
#   'steuern',
#   'ärgern',
#   'vielleicht',
#   'sind',
#   'es',
#   'gerade',
#   'ihre',
#   'euros',
#   'die',
#   'als',
#   'entwicklungshilfe',
#   'nach',
#   'china',
#   'fließen'],
#  ['dort',
#   'ist',
#   'das',
#   'geld',
#   'ja',
#   'auch',
#   'besser',
#   'angelegt',
#   'als',
#   'im',
#   'deutschem',
#   'bildungssystem'],
#  ['in',
#   'der',
#   'regionalbahn',
#   'badenbaden',
#   'nach',
#   'rastatt',
#   'erklärt',
#   'ein',
#   'migrant',
#   'einer',
#   'seniorin',
#   'wie',
#   'integration',
#   'in',
#   'deutschland',
#   'funktioniert',
#   "'deutschland",
#   'ist',
#   'nicht',
#   'mehr',
#   'ihr',
#   'land',
#   'vergessen',
#   'sie',
#   'das',
#   'nicht'],
#  ['die',
#   'bergung',
#   'der',
#   'leiche',
#   'im',
#   'ankerzentrum',
#   'regensburg',
#   'war',
#   'zunächst',
#   'nicht',
#   'möglich',
#   'da',
#   'die',
#   'polizei',
#   'stunden',
#   'von',
#   'bewohnern',
#   'angegriffen',
#   'wurde'],
#  ['anzeigen', 'oder', 'festnahmen', 'gab', 'es', 'übrigens', 'nicht'],
#  ['mehr', 'als'],
#  ['euro',
#   'im',
#   'monat',
#   'abgeordnetendiäten',
#   'steigen',
#   'auf',
#   'rekordhoch',
#   '‼️'],
#  ['in',
#   'gotha',
#   'gab',
#   'es',
#   'nahe',
#   'einem',
#   'einkaufszentrum',
#   'eine',
#   'schießerei'],
#  ['ein',
#   'polizeibeamter',
#   'wurde',
#   'verletzt',
#   'ein',
#   'verdächtiger',
#   'festgenommen'],
#  ['zu', 'den', 'hintergründen', 'schweigt', 'die', 'polizei'],
#  ['berlin', 'palästinenser', 'attackieren', 'in', 'neukölln', 'am', 'sog'],
#  ['“',
#   'palästinenser-tag',
#   '”',
#   'den',
#   'israelischen',
#   'musiker',
#   'daniel',
#   'gurfinkel',
#   'massiv',
#   'und',
#   'beschimpfen',
#   'ihn',
#   'judenfeindlich',
#   'video',
#   'des',
#   'vorfalls',
#   'zeigt',
#   'wie',
#   'er',
#   'eingekreist',
#   'und',
#   'geschlagen',
#   'wird',
#   'antisemitismus'],
#  ['regensburg',
#   'syrer',
#   'schlägt',
#   'bei',
#   'einer',
#   'geburtstagsfeier',
#   'in',
#   'einer',
#   'sportgaststätte',
#   'einer',
#   '-jährigen',
#   'ins',
#   'gesicht',
#   'und',
#   'zückt',
#   'ein',
#   'einhand-messer',
#   'als',
#   'gäste',
#   'dazwischengehen',
#   'eskaliert',
#   'die',
#   'situation',
#   'es',
#   'kommt',
#   'zur',
#   'massenschlägerei',
#   'mit',
#   'mehreren',
#   'verletzten'],
#  ['regensburg',
#   'während',
#   'einer',
#   'geburtstagsfeier',
#   'in',
#   'einer',
#   'sportgaststätte',
#   'schlägt',
#   'ein',
#   'jähriger',
#   'syrischer',
#   'flüchtling',
#   'einer',
#   'jährigen',
#   'ins',
#   'gesicht',
#   'und',
#   'zieht',
#   'ein',
#   'einhandmesser'],
#  ['einschreitende',
#   'gäste',
#   'finden',
#   'sich',
#   'in',
#   'einer',
#   'massenschlägerei',
#   'wieder'],
#  ['das',
#   'befürchtet',
#   'dass',
#   'mitglieder',
#   'der',
#   'tschetschenischen',
#   'mafia',
#   'wachschutzaufträge',
#   'für',
#   'dienstgebäude',
#   'der',
#   'polizei',
#   'darunter',
#   'sek',
#   'und',
#   'mek',
#   'erhalten',
#   'haben',
#   'und',
#   'sensible',
#   'informationen',
#   'erhalten',
#   'haben'],
#  ['die', 'innere', 'sicherheit', 'in', 'deutschland', 'ist', 'kaputt'],
#  ['lehrerin',
#   'aus',
#   'sachsen',
#   'berichtet',
#   'dass',
#   'es',
#   'im',
#   'lehrerzimmer',
#   "'seit",
#   'etwa',
#   'jahren',
#   'keine',
#   'politischen',
#   'diskussionen',
#   'mehr',
#   'gibt',
#   'keiner',
#   'traut',
#   'sich',
#   'seinem',
#   'herzen',
#   'diesbezüglich',
#   'luft',
#   'zu',
#   'machen',
#   'ich',
#   'empfinde',
#   'die',
#   'situation',
#   'heute',
#   'noch',
#   'bedrückender',
#   'als',
#   'vor'],
#  ['alfred', 'nobel', 'würde', 'sich', 'im', 'grab', 'rumdrehen'],
#  ['ein',
#   'obama',
#   'führte',
#   'die',
#   'meisten',
#   'kriege',
#   'im',
#   'amt',
#   'eines',
#   'us-präsident',
#   'wurde',
#   'der',
#   'friedensnobelpreis',
#   'verliehen'],
#  ['nun',
#   'ein',
#   'psychisch',
#   'krankes',
#   'kind',
#   'steht',
#   'nun',
#   'ganz',
#   'weit',
#   'oben',
#   'auf',
#   'der',
#   'liste',
#   'für',
#   'die',
#   'verleihung',
#   'des',
#   "'friedensnobelpreis"],
#  ['sind', 'die', 'krank'],
#  ['während',
#   'in',
#   'berlin',
#   'fleissig',
#   'häuser',
#   'für',
#   'flüchtlinge',
#   'gebaut',
#   'und',
#   'das',
#   'taschengeld',
#   'auf',
#   'erhöht',
#   'wird',
#   'rechnet',
#   'das',
#   'sozialamt',
#   'einem',
#   'bedürftigen',
#   'deutschen',
#   'die',
#   'lebensmittelspenden',
#   'der',
#   'tafel',
#   'als',
#   'einnahme',
#   'im',
#   'jahr',
#   'an'],
#  ['pforzheim',
#   'arabischsprachiger',
#   'mann',
#   'zerrt',
#   'eine',
#   'frau',
#   'aus',
#   'dem',
#   'bus',
#   'die',
#   'sich',
#   'über',
#   'seinen',
#   'lärm',
#   'beschwerte',
#   'spuckt',
#   'ihr',
#   'ins',
#   'gesicht',
#   'ohrfeigt',
#   'sie',
#   'und',
#   'tritt',
#   'die',
#   '-jährige',
#   'derart',
#   'in',
#   'den',
#   'bauch',
#   'dass',
#   'sie',
#   'verletzt',
#   'zu',
#   'boden',
#   'geht'],
#  ['koeln',
#   'weil',
#   'die',
#   'irakerin',
#   'zozan',
#   'sich',
#   'scheiden',
#   'lies',
#   'und',
#   'ein',
#   'eigenständiges',
#   'europäisches',
#   'leben',
#   'ohne',
#   'zwang',
#   'führen',
#   'wollte',
#   'wurde',
#   'sie',
#   'von',
#   'ex-ehemann',
#   'dilgasch',
#   'mit',
#   'kopfschüssen',
#   'hingerichtet'],
#  ['das', 'gehört', 'nunmal', 'jetzt', 'zu', 'deutschland'],
#  ['diese',
#   'videos',
#   'werden',
#   'dann',
#   'nach',
#   'hause',
#   'geschickt',
#   'wo',
#   'man',
#   'sich',
#   'köstlich',
#   'über',
#   'unseren',
#   'staat',
#   'amüsiert'],
#  ['zu', 'recht'],
#  ['münchen',
#   'bankräuber',
#   'droht',
#   'mit',
#   'bombe',
#   'fotofahndung',
#   'nach',
#   'einem',
#   'arabisch',
#   'wirkendem',
#   'täter',
#   'der',
#   'mit',
#   'hilfe',
#   'eines',
#   'beschriebenen',
#   'zettels',
#   'wortlos',
#   'geld',
#   'fordert',
#   'mit',
#   'einer',
#   'bombe',
#   'droht',
#   'und',
#   'mit'],
#  ['die', 'flucht', 'ergreift'],
#  ['straftaten',
#   'in',
#   'jahren',
#   'clans',
#   'ins',
#   'nrw',
#   'der',
#   'taten',
#   'von',
#   'familien',
#   'verübt',
#   'clanverdächtige',
#   'tötungsdelikte',
#   'innenminister',
#   'sollte',
#   'zugeben',
#   'dass',
#   'migration',
#   'und',
#   'sicherheit',
#   'in',
#   'nrw',
#   'ausser',
#   'kontrolle',
#   'geraten',
#   'sind'],
#  ['kriminelle', 'clans', 'immerhin', 'das', 'thema', 'wird', 'angesprochen'],
#  ['dass',
#   'es',
#   'aber',
#   'überhaupt',
#   'soweit',
#   'kommen',
#   'konnte',
#   'ist',
#   'eine',
#   'bankrotterklärung',
#   'des',
#   'rechtsstaates'],
#  ['diese', 'clans', 'gibt', 'es', 'schon', 'lange'],
#  ['dass', 'es', 'fast', 'immer', 'migranten', 'sind', 'ist', 'auch', 'klar'],
#  ['in', 'hamm', 'wird', 'dieses', 'herzchen', 'gesucht'],
#  ['er',
#   'stieß',
#   'einen',
#   'jahrigen',
#   'sehbehinderten',
#   'mann',
#   'aus',
#   'dem',
#   'aufzug',
#   'als',
#   'dieser',
#   'den',
#   'aufzug',
#   'betreten',
#   'wollte'],
#  ['der', 'senior', 'verletzte', 'sich', 'beim', 'sturz', 'erheblich'],
#  ['seehofer', 'sprach', 'von', '„', 'herrschaft', 'des', 'unrechts', '“'],
#  ['jetzt',
#   'sagt',
#   'er',
#   'über',
#   'merkel',
#   '„',
#   'wir',
#   'sollten',
#   'in',
#   'der',
#   'union',
#   'stolz',
#   'sein',
#   'dass',
#   'so',
#   'eine',
#   'herausragende',
#   'persönlichkeit',
#   'aus',
#   'unseren',
#   'reihen',
#   'kommt.',
#   '“',
#   'der',
#   'zieht',
#   'eine',
#   'schleimspur',
#   'von',
#   'münchen',
#   'bis',
#   'berlin'],
#  ['schleimhofer', 'afd'],
#  ['hannover',
#   'prozess',
#   'um',
#   'die',
#   'versuchte',
#   'vergewaltigung',
#   'einer',
#   'bachelor',
#   'kandidatin',
#   "'baby",
#   'baby',
#   'i',
#   'need',
#   'to',
#   'fuck',
#   'sagte',
#   'der',
#   'flüchtling',
#   'aus',
#   'guinea',
#   'während',
#   'er',
#   'sein',
#   'opfer',
#   'würgte'],
#  ['bei',
#   'der',
#   'festnahme',
#   'verletzte',
#   'er',
#   'polizisten',
#   'und',
#   'beleidigte',
#   'sie',
#   'als',
#   'rassisten'],
#  ['clans',
#   'mit',
#   'drei-',
#   'und',
#   'vierstelligen',
#   'mitgliederzahlen',
#   'straftaten',
#   'in',
#   'drei',
#   'jahren',
#   'tatverdächtige',
#   'aus',
#   'dem',
#   'milieu',
#   'der',
#   'arabisch-/türkischstämmigen',
#   'grossfamilien',
#   'und',
#   'das',
#   'ist',
#   'nicht',
#   'deutschland',
#   'das',
#   'ist',
#   'nur',
#   'nrw'],
#  ['via', 'von', '_hermann'],
#  ['fastenbrechen',
#   'in',
#   'triberg',
#   'bürgermeister',
#   'amp',
#   'pfarrer',
#   'sind',
#   'auch',
#   'dabei',
#   'die',
#   'bürgermeister-sekretärin',
#   'aber',
#   'sitzt',
#   'bei',
#   'den',
#   'frauen',
#   'denn',
#   'es',
#   'herrscht',
#   "'strikte",
#   'trennung',
#   'der',
#   'geschlechter',
#   'ausschließlich',
#   'männer',
#   'waren',
#   'beim',
#   'fastenbrechen',
#   'frauen',
#   'sind',
#   'in',
#   'separaten',
#   'räumen'],
#  ['_zmd',
#   'über',
#   'morde',
#   'u.gewaltaten',
#   'von',
#   'deutschen',
#   'oder',
#   'christen',
#   'wird',
#   'nicht',
#   'so',
#   'ein',
#   'spektakel',
#   'gemacht'],
#  ['wer',
#   'sollte',
#   'denn',
#   'in',
#   'die',
#   'moschee',
#   'reinkommen',
#   'auch',
#   'ein',
#   'witz.kein',
#   'fremder',
#   'darf',
#   'hinein.kommt',
#   'mal',
#   'wieder',
#   'auf',
#   'den',
#   'boden',
#   'bücher',
#   'sind',
#   'zu',
#   'ersetzen',
#   'diese',
#   'propaganda',
#   'überall',
#   'finde',
#   'ich',
#   'abscheulich'],
#  ['das',
#   'schöne',
#   'am',
#   'klimawandel',
#   'damit',
#   'lässt',
#   'sich',
#   'von',
#   'der',
#   'massiven',
#   'steuererhöhung',
#   'über',
#   'die',
#   'einschränkung',
#   'der',
#   'reisefreiheit',
#   'bis',
#   'zur',
#   'beschneidung',
#   'von',
#   'meinungs-',
#   'und',
#   'pressefreiheit',
#   'jede',
#   'maßnahme',
#   'rechtfertigen',
#   'die',
#   'linken',
#   'psychpathen',
#   'nur',
#   'einfallen',
#   'kann'],
#  ['deshalb',
#   'fahren',
#   'die',
#   'so',
#   'darauf',
#   'ab',
#   '..',
#   'uni-senat',
#   'hagelvoll'],
#  ['jetzt',
#   'kommt',
#   'der',
#   'gender-zwang',
#   'an',
#   'der',
#   'ernst-moritz-arndt-universität',
#   'zu',
#   'greifswald'],
#  ['aus',
#   'orten',
#   'der',
#   'freiheit',
#   'und',
#   'der',
#   'offenen',
#   'debatten',
#   'sind',
#   'vielerorts',
#   'mittlerweile',
#   'götzentempel',
#   'der',
#   'politischen',
#   'korrektheit',
#   'geworden'],
#  ['handwerk', 'legen'],
#  ['ich',
#   'nenne',
#   'jeden',
#   'einen',
#   'barbaren',
#   'der',
#   'aus',
#   'religiösem',
#   'fanatismus',
#   'musikinstrumente',
#   'zerstört'],
#  ['wobei', 'barbar', 'noch', 'sehr', 'milde', 'ist'],
#  ['vor', 'allem', 'die', 'vollidioten', 'die', 'orgeln', 'zerstören'],
#  ['und', 'überhaupt', 'kirchenzerstörer'],
#  ['wann',
#   'verklagt',
#   'man',
#   'solche',
#   'sitzungsleiterinnen',
#   'nicht',
#   'vor',
#   'den',
#   'verfassungsgericht'],
#  ['die', 'missbrauchen', 'ihr', 'amt', 'aufs', 'schändlichste'],
#  ['ur-großvater', 'im', 'krieg', 'gedient'],
#  ['großvater', 'im', 'krieg', 'gedient'],
#  ['vater', 'und', 'schwiegervater', 'im', 'krieg', 'gedient'],
#  ['teilweise', 'viele', 'jahre', 'in', 'gefangenschaft'],
#  ['für', 'was'],
#  ['dafür🤔❓❗️', '\u2066\u2069', '\u2066\u2069', 'unserlandunserekultur'],
#  ['_kultur',
#   'ich',
#   'hab',
#   'zwar',
#   'nie',
#   'tkkg',
#   'gehört',
#   'aber',
#   'jetzt',
#   'dreht',
#   'die',
#   'welt',
#   'endgültig',
#   'durch'],
#  ['erst',
#   'war',
#   'pippi',
#   'langstrumpf',
#   'ein',
#   'problem',
#   'jetzt',
#   'tkkg',
#   'was',
#   'kommt',
#   'als',
#   'nächstes'],
#  ['gebrüder', 'löwenherz'],
#  ['unendliche', 'geschichte'],
#  ['michel', 'aus', 'lönneberga'],
#  ['hänsel', 'und', 'gretel'],
#  ['oder', 'asterix', 'und', 'obelix'],
#  ['es', 'reicht'],
#  ['_kultur', 'welch', 'schwachsinn', 'nicht', 'zu', 'fassen'],
#  ['tkkg', 'war', 'nie', "'problematisch"],
#  ['wer',
#   'das',
#   'behauptet',
#   'ist',
#   'in',
#   'dieser',
#   'zeit',
#   'nicht',
#   'aufgewachsen',
#   'oder',
#   'paranoid'],
#  ['ich', 'distanziere', 'mich', 'nicht', 'davon'],
#  ['ich', 'wähle', 'afd', 'zu', 'der', 'auch', 'hier', 'eine', 'egtl'],
#  ['unmögliche', 'verbindung', 'hergestellt', 'wird'],
#  ['lächerlich',
#   '..',
#   '➡️super',
#   'gut',
#   'gemacht❗️auf',
#   'jeden',
#   'fall',
#   '„',
#   'retweeten',
#   '“',
#   '❗️'],
#  ['man', 'kann', 'wirklich', 'nur', 'verzweifeln'],
#  ['warum', 'haben', 'die', 'politiker', 'das', 'zugelassen'],
#  ['warum', 'haben', 'wir', 'das', 'zugelassen'],
#  ['fck', 'islam'],
#  ['ich', 'will', 'diesen', 'rotz', 'aus', 'meinem', 'land', 'haben'],
#  ['zurück', 'in', 'das', 'mittelalter', 'mit', 'euch', '..'],
#  ['interessanter', 'artikel', 'aus'],
#  ["'unsere",
#   'klimaschutz-',
#   'und',
#   'energiepolitik',
#   'wird',
#   'zur',
#   'hauptgefahr',
#   'für',
#   'die',
#   'biologische',
#   'vielfalt'],
#  ['heute',
#   'jahre',
#   'später',
#   'halten',
#   'wir',
#   'am',
#   'ausbau',
#   'fest',
#   'und',
#   'verschließen',
#   'weiterhin',
#   'die',
#   'augen',
#   'vor',
#   'den',
#   'auswirkungen',
#   'afd',
#   'wählen'],
#  ['_aktiv',
#   'ich',
#   'staune',
#   'immer',
#   'darüber',
#   'dass',
#   'die',
#   'grünen',
#   'keinen',
#   'zusammenhang',
#   'zwischen',
#   'bevölkerungsexplosion',
#   'und',
#   'klimazerstörung',
#   'sehen'],
#  ['allein',
#   'die',
#   'millionen',
#   'migraten',
#   'die',
#   'wohnung',
#   'auto',
#   'und',
#   'arbeit',
#   'brauchen',
#   'werden',
#   'wieder',
#   'ein',
#   'gewaltiges',
#   'stück',
#   'grüngürtel',
#   'in',
#   'deutschland',
#   'zerstören',
#   '..'],
#  ['schweres',
#   'unwetter',
#   'am',
#   'frühen',
#   'abend',
#   'in',
#   'münchen',
#   'und',
#   'umland'],
#  ['viele', 'sachschäden', 'durch', 'hagel'],
#  ['menschen', 'leicht', 'verletzt'],
#  ['kommt',
#   'gut',
#   'nach',
#   'hause',
#   'falls',
#   'ihr',
#   'noch',
#   'unterwegs',
#   'seid'],
#  ['😂😂😂😂😂', 'herrlich'],
#  ['👍🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣ich', 'kann', 'nicht', 'mehr'],
#  ['es',
#   'wurde',
#   'nicht',
#   'verschärft',
#   'sondern',
#   'immer',
#   'ernster',
#   'genauer',
#   'und',
#   'buchstäblicher',
#   'genommen'],
#  ["'mein",
#   'kampf',
#   'auf',
#   'den',
#   'index',
#   'gesetzt',
#   'zu',
#   'haben',
#   'aber',
#   'den',
#   'koran',
#   'nicht',
#   'ist',
#   'die',
#   'größte',
#   'zivilisatorische',
#   'fehlleistung',
#   'der',
#   'bundesrepublik',
#   'deutschland'],
#  ['hauptsache',
#   '_gruenen',
#   'haben',
#   'mal',
#   'wieder',
#   'hyperventiliert',
#   'und',
#   'verbote',
#   'gefordert'],
#  ['sie', 'können', 'wieder', 'runterkommen', 'frau'],
#  ["'nach",
#   'recherchen',
#   'werden',
#   'rund',
#   'der',
#   'retouren',
#   'bei',
#   'amazon',
#   'in',
#   'irgendeiner',
#   'form',
#   'wieder',
#   'in',
#   'den',
#   'warenkreislauf',
#   'zurückgeführt'],
#  ['_gruenen',
#   'die',
#   'meisten',
#   'grünen',
#   'wären',
#   'zu',
#   'dumm',
#   'eine',
#   'würstchenbude',
#   'erfolgreich',
#   'zu',
#   'betreiben'],
#  ['aber',
#   'sie',
#   'wissen',
#   'natürlich',
#   'genau',
#   'was',
#   'konzerne',
#   'zu',
#   'tun',
#   'haben'],
#  ['der',
#   'standort',
#   'deutschland',
#   'wird',
#   'scheibchenweise',
#   'ruiniert',
#   '..',
#   '_gruenen',
#   'alles',
#   'ablenkung',
#   'von',
#   'der',
#   'flüchtlingskrise',
#   'und',
#   'der',
#   'masseneinwanderung',
#   '..',
#   'von',
#   'was',
#   'träumt',
#   'die',
#   'nachts'],
#  ['ist',
#   'ihr',
#   'nicht',
#   'bewußt',
#   'das',
#   'amazon',
#   'ein',
#   'gigant',
#   'ist',
#   'und',
#   'sie',
#   'nur',
#   'eine',
#   'kleine',
#   'dumme',
#   'grüne'],
#  ['größenwahn', 'ist', 'ihr', 'metier'],
#  ['katrin',
#   'göring-eckardt',
#   'mit',
#   'drei-punkte-plan',
#   'grüne',
#   'wollen',
#   'amazon',
#   'waren-vernichtung',
#   'verbieten',
#   'via'],
#  ['welche',
#   'botschaft',
#   'sendet',
#   'herr',
#   'maas',
#   'eigentlich',
#   'an',
#   'das',
#   'deutsche',
#   'christlich',
#   'geprägte',
#   'volk',
#   'wenn',
#   'seine',
#   'aussagen',
#   'zu',
#   'religiösen',
#   'festen',
#   'der',
#   'muslime',
#   'deutlich',
#   'anders',
#   'wirken',
#   'als',
#   'sein',
#   '„',
#   'froheweinachten',
#   'und',
#   'danke',
#   'für',
#   'die',
#   'zusammenarbeit',
#   '“',
#   'im',
#   'dezember',
#   'zu',
#   'ostern',
#   'nichts'],
#  ['religion',
#   'des',
#   'friedens',
#   'beliebter',
#   'syrischer',
#   'imam',
#   'ruft',
#   'in',
#   'basel',
#   'zum',
#   'krieg',
#   'gegen',
#   'ungläubige',
#   'auf'],
#  ['irrer',
#   'angriff',
#   'auf',
#   'die',
#   'meinungsfreiheit',
#   'aus',
#   'werte-deutschland',
#   'merkel-nachfolgerin',
#   'kramp-karrenbauer',
#   'fordert',
#   'klarnamenpflicht',
#   'weil',
#   'sie',
#   'wissen',
#   'möchte',
#   "'was",
#   'ihr',
#   'so',
#   'denkt'],
#  ['köstlich', 'die', 'zehn', 'gebote', 'der', 'ökoreligion'],
#  ['😂',
#   'alle',
#   'gebote',
#   'kann',
#   'man',
#   'hier',
#   'lernen',
#   'und',
#   'einstudieren',
#   'greta',
#   'fff',
#   'via/',
#   '_com'],
#  ['so',
#   'eine',
#   "'mutige",
#   'berichterstattung',
#   'pfingsten',
#   'drogentrip',
#   'würde',
#   'ich',
#   'mir',
#   'mal',
#   'wünschen',
#   'wenn',
#   'sich',
#   'weltweit',
#   'millionen',
#   'bärtige',
#   'mit',
#   'dem',
#   'gesicht',
#   'zu',
#   'boden',
#   'richtung',
#   'mekka',
#   'werfen'],
#  ['na', 'wie', 'wär', "'s"],
#  ['unfassbares',
#   'hass-verbrechen',
#   'in',
#   'chemnitz',
#   'am',
#   'tag',
#   'des',
#   'islamischen',
#   'zuckerfest',
#   'wollen',
#   'rechtsextreme™',
#   'ein',
#   'ferkel',
#   'grillen'],
#  ['sex-attacke',
#   'im',
#   'wohnheim',
#   'für',
#   'minderjährige',
#   'flüchtlinge',
#   'in',
#   'straubing',
#   '-jähriger',
#   'afrikaner',
#   'bespringt',
#   'betreuerin'],
#  ['man',
#   'muss',
#   'sich',
#   'einfach',
#   'mal',
#   'vergegenwärtigen',
#   'um',
#   'was',
#   'für',
#   'spinner',
#   'es',
#   'sich',
#   'bei',
#   'den',
#   'gehirngewaschenen',
#   'bei',
#   'fridaysforfuture',
#   'handelt',
#   'wer',
#   'oder',
#   'was',
#   'bringt',
#   'solche',
#   'hohlbirnen',
#   'hervor'],
#  ['😂', 'ganze', 'doku', 'fff'],
#  ['ich',
#   'bin',
#   'meinen',
#   'eltern',
#   'lehrern',
#   'und',
#   '-an',
#   'der',
#   'uni-',
#   'professoren',
#   'unendlich',
#   'dankbar',
#   'dass',
#   'sie',
#   'mich',
#   'zu',
#   'kritischem',
#   'denken',
#   'angeleitet',
#   'haben',
#   'um',
#   'bei',
#   'solchen',
#   'tendenzen',
#   "'hellwach",
#   'zu',
#   'sein'],
#  ['obwohl',
#   'der',
#   'streng',
#   'gläubige',
#   'herr',
#   'im',
#   'gefährder-system',
#   'der',
#   'polizei',
#   'in',
#   'der',
#   'höchsten',
#   'risikoklasse',
#   'geführt',
#   'ist',
#   'hortet',
#   'er',
#   'munter',
#   'waffen',
#   'mit',
#   'munition',
#   'und',
#   'schalldämpfer'],
#  ['naja', 'dient', 'wohl', 'der', 'religionsausübung'],
#  ['migranten', 'treten', 'jungen', 'österreicher', 'zusammen'],
#  ['das',
#   'ghetto-viertel',
#   'in',
#   'dem',
#   'das',
#   'passiert',
#   'ist',
#   'übrigens',
#   'ein',
#   'rot-grünes',
#   "'vorzeigeprojekt",
#   'für',
#   'modernes',
#   'nachhaltiges',
#   'und',
#   'zukünftiges',
#   'wohnen'],
#  ['aspern', 'seestadt'],
#  ['_junge_mdl',
#   'da',
#   'sich',
#   'hier',
#   'ja',
#   'immer',
#   'so',
#   'viele',
#   'gute',
#   'tummeln',
#   'hab',
#   'ne',
#   'frage',
#   'ist',
#   'das',
#   'hier',
#   'auch',
#   'ein',
#   'rassist'],
#  ['max', 'otte', 'singt', 'beim', 'hambacher', 'fest'],
#  ['die',
#   'demonstration',
#   'der',
#   'patrioten',
#   'verlief',
#   'ohne',
#   'zwischenfälle'],
#  ['so',
#   'wird',
#   'in',
#   'dunkeldeutschland',
#   'gehandelt',
#   'zahlreiche',
#   'dessau-roßlauer',
#   'hatten',
#   'am',
#   'sonntag',
#   'über',
#   'facebook',
#   'einen',
#   'eilig',
#   'veröffentlichten',
#   'fahndungsaufruf',
#   'geteilt',
#   'und',
#   'verbreitet',
#   'und',
#   'auch',
#   'selbst',
#   'nach',
#   'dem',
#   'tatverdächtigen',
#   'gesucht',
#   'und',
#   'den',
#   'nigerer',
#   'gestellt'],
#  ['ein', 'hoch', 'auf', 'die', 'bürger', 'von', 'roßlau', '♥️'],
#  ['ich',
#   'bin',
#   'selbst',
#   'aus',
#   'dem',
#   'westen',
#   'aber',
#   'davon',
#   'können',
#   'sich',
#   'die',
#   'gehirngewaschenen',
#   'weichbirnen',
#   'mal',
#   'eine',
#   'scheibe',
#   'abschneiden',
#   '..',
#   'die',
#   'fakten',
#   'zum',
#   'gästehaus',
#   'der',
#   'bundesregierung',
#   'schloss',
#   'meseberg',
#   'in',
#   'tagen',
#   'nur',
#   'an',
#   'tagen',
#   'genutzt',
#   'in',
#   'tagen',
#   'unterhaltskosten',
#   'von',
#   'millionen',
#   'in',
#   'tagen',
#   'objektschutzkosten',
#   'millionen',
#   'kosten',
#   'in',
#   'jahren',
#   'etwa',
#   'millionen',
#   'euro'],
#  ['als',
#   'fälscher',
#   'gilt',
#   'ein',
#   '-jähriger',
#   'iraker',
#   'aus',
#   'ludwigsburg',
#   'der',
#   'ebenfalls',
#   'in',
#   'dem',
#   'ford',
#   'mondeo',
#   'saß',
#   'gesteuert',
#   'von',
#   'einem',
#   '-jährigen',
#   'iraker',
#   'aus',
#   'hamm/westfalen'],
#  ['das',
#   'trio',
#   'wurde',
#   'angezeigt',
#   'und',
#   'auf',
#   'freien',
#   'fuß',
#   'gesetzt'],
#  ['einer', 'macht', 'die', 'theorie', 'für', 'alle'],
#  ['nun',
#   'werden',
#   'zweifel',
#   'geäußert',
#   'ob',
#   'die',
#   'nach',
#   'außen',
#   'semi-anarchische',
#   'bewegung',
#   'fridaysforfuture',
#   'nicht',
#   'doch',
#   'gesteuert',
#   'ist'],
#  ['nigerianer', 'vergewaltigt', '-jähriges', 'mädchen', 'in', 'roßlau'],
#  ['geschockte', 'bürger', 'werden', 'als', 'nazis', 'diffamiert'],
#  ['die',
#   'strafanzeige',
#   'der',
#   'kölner',
#   'polizei',
#   'zu',
#   'einem',
#   'nächtlichen',
#   'einsatz',
#   'in',
#   'widdersdorf',
#   'umfasst',
#   'inzwischen',
#   'einige',
#   'seiten.nachbarn',
#   'hatten',
#   'sich',
#   'wegen',
#   'ruhestörung',
#   'beschwert.die',
#   'polizei',
#   'rückte',
#   'schließlich',
#   'mit',
#   'beamten',
#   'an',
#   'und',
#   'legte',
#   'einen',
#   'zdf-reporter',
#   'in',
#   'handschellen'],
#  ['teilen',
#   'teilen',
#   'teilen',
#   'bundesweit',
#   'starten',
#   'migranten',
#   'juden',
#   'und',
#   'homosexuelle',
#   'einen',
#   'gegenprotest'],
#  ['zuvor',
#   'hatte',
#   "'hollywood",
#   'dazu',
#   'aufgerufen',
#   'den',
#   'afd🇩🇪❤',
#   'ob-kandidaten',
#   'für',
#   'görlitz',
#   'nicht',
#   'zu',
#   'wählen'],
#  ['sebastian', 'wippel🇩🇪', 'görlitzistschlaugörlitzwähltblau', '🇩🇪'],
#  ["'doppel-vergewaltigung",
#   'in',
#   'düsseldorf',
#   '-jährige',
#   'wird',
#   'im',
#   'hofgarten',
#   'von',
#   'zwei',
#   'nordafrikanern',
#   'vergewaltigt'],
#  ['deutschland',
#   'vor',
#   'der',
#   'eu-wahl',
#   'häufen',
#   'sich',
#   'die',
#   'übergriffe',
#   'gegen',
#   'die',
#   'afd'],
#  ['linksextremisten',
#   'beschmieren',
#   'das',
#   'haus',
#   'eines',
#   'afd-politikers',
#   'in',
#   'stade'],
#  ['mitschuld',
#   'an',
#   'dieser',
#   'pogromstimmung',
#   'tragen',
#   'auch',
#   'die',
#   'altparteien',
#   'msm',
#   'und',
#   'ör'],
#  ['man', 'fühlt', 'sich', 'in', 'unseligste', 'zeiten', 'zurückversetzt'],
#  ['im',
#   'französischen',
#   'trélazé',
#   'bei',
#   'angers',
#   'terrorisieren',
#   'frustrierte',
#   'afrikanische',
#   'und',
#   'arabischen',
#   'migranten-gangs',
#   'ihre',
#   'mitbürger'],
#  ['😨', 'europawahl', 'macron'],
#  ['sexualität', 'ist', 'ein', 'knast'],
#  ['was', 'für', 'einen', 'blödsinn', 'diese', 'gender-gaga', 'ablassen'],
#  ['und', 'dafür', 'gibt', 'es', 'mittlerweile', 'ca'],
#  ['professuren', 'in', 'deutschland'],
#  ['wir',
#   'fahren',
#   'die',
#   'wissenschaftsnation',
#   'sowas',
#   'von',
#   'vor',
#   'die',
#   'wand'],
#  ['da',
#   'haben',
#   'die',
#   'linken',
#   'und',
#   'gutmenschen',
#   'die',
#   'sprichwörtlich',
#   'nächste',
#   "'sau",
#   'die',
#   'sie',
#   'durchs',
#   'dorf',
#   'treiben',
#   'können',
#   'weil',
#   'toto',
#   'von',
#   'totoundharry',
#   'seine',
#   'freie',
#   'meinung',
#   'äußerte',
#   'die',
#   'den',
#   'linken',
#   'mal',
#   'wieder',
#   'nicht',
#   'passt',
#   'wird',
#   'er',
#   'an',
#   'den',
#   'pranger',
#   'gestellt'],
#  ['beim',
#   'bei',
#   'frontal',
#   'mogelte',
#   'sich',
#   'kopftuch',
#   'journalistin',
#   'nemi',
#   'el-hassan',
#   'wieder',
#   'rekordverdächtg',
#   'oft',
#   'in',
#   'den',
#   'eigenen',
#   'zdf',
#   'beitrag',
#   'dessen',
#   'autorin',
#   'sie',
#   'lediglich',
#   'ist'],
#  ['woran', 'kann', 'das', 'nur', 'liegen'],
#  ['sie', 'erreichen', 'das', 'zdf', 'in', 'mainz', 'übrigens', 'unter', 'tel'],
#  ['kriminelle',
#   'clans',
#   'haben',
#   'ihre',
#   'netzwerke',
#   'mittlerweile',
#   'über',
#   'ganz',
#   'nrw',
#   'gezogen',
#   "'in",
#   'jedem',
#   'zuständigkeitsbereich',
#   'der',
#   'polizeibehörden',
#   'leben',
#   'demnach',
#   'mitglieder',
#   'von',
#   'kriminellen',
#   'clans'],
#  ['alleine',
#   'die',
#   'mitglieder',
#   'eines',
#   'clans',
#   'wohnen',
#   'in',
#   'der',
#   'bezirke',
#   'clan'],
#  ['warum',
#   'der',
#   'eugh',
#   'die',
#   'abschiebung',
#   'schwerkrimineller',
#   'flüchtlinge',
#   'und',
#   'kindervergewaltiger',
#   'verbietet'],
#  ['so', 'viel', 'zum', 'thema', 'sicherheit'],
#  ['vetternwirtschaft', 'spd-parteibuch', 'wichtiger', 'als', 'eignung'],
#  ['giffey',
#   'lässt',
#   'leitungsposten',
#   'in',
#   'der',
#   'antidiskriminierungsstelle',
#   'ein',
#   'jahr',
#   'unbesetzt',
#   'weil',
#   'spd-parteigenossin',
#   'abgelehnt',
#   'wurde'],
#  ['schweiz', "'über", 'asylsuchende', 'müssten', 'nach', 'eritrea', 'zurück'],
#  ['sie',
#   'tauchen',
#   'aber',
#   'meist',
#   'in',
#   'nachbarstaaten',
#   'wie',
#   'deutschland',
#   'unter',
#   'ausreisepflichtige',
#   'erhalten',
#   'in',
#   'der',
#   'schweiz',
#   'nur',
#   'nothilfe',
#   'd.',
#   'h.',
#   'keine',
#   'sozialhilfe',
#   'mehr',
#   'franken',
#   'tag',
#   'und',
#   'eine',
#   'unterkunft'],
#  ['bautzen',
#   'und',
#   'die',
#   'riesenaufregung',
#   'ums',
#   'das',
#   'nazi-kennzeichen',
#   "'bz",
#   'hh'],
#  ['alle',
#   'befürchtungen',
#   'haben',
#   'sich',
#   'bestätigt',
#   'der',
#   'kz-besitzer',
#   'ist',
#   'ein',
#   'typischer',
#   'ostdeutscher',
#   'rechtsradikaler',
#   'abdullatif',
#   'hamami',
#   'er',
#   'kam',
#   'als',
#   'flüchtling',
#   'nach',
#   'deutschland'],
#  ['bonn',
#   '“',
#   'hilfe',
#   'papa',
#   '“',
#   'später',
#   'folgten',
#   'mehrere',
#   'weinende',
#   'emojis',
#   '”',
#   'nach',
#   'd',
#   'gekommene',
#   'afghane',
#   'arian',
#   'g.',
#   'setzt',
#   'eine',
#   '-jährige',
#   'die',
#   'er',
#   'am',
#   'busbahnhof',
#   'kennengelernt',
#   'hat',
#   'unter',
#   'drogen',
#   'und',
#   'vergewaltigt',
#   'mehrmals',
#   'sie',
#   'mit',
#   'einem',
#   'cousin',
#   'zusammen',
#   '¼',
#   'jahre',
#   'haft'],
#  ["'hundert",
#   'moscheen',
#   'will',
#   'die',
#   'ahmadiyya',
#   'muslim',
#   'jamaat',
#   'in',
#   'deutschland',
#   'bauen'],
#  ['das',
#   'verkündete',
#   'moscheen',
#   'projekt',
#   'ist',
#   'etwa',
#   'zur',
#   'hälfte',
#   'umgesetzt',
#   'nun',
#   'wurde',
#   'der',
#   'bauantrag',
#   'für',
#   'eine',
#   'moschee',
#   'in',
#   'leipzig',
#   'eingereicht'],
#  ['ich',
#   'lande',
#   'vor',
#   'gericht',
#   'wenn',
#   'ich',
#   'einen',
#   'falschen',
#   'tweet',
#   'schreibe',
#   'und',
#   'drogendealer',
# ...
#   'gegner',
#   'hintergehen',
#   'ihre',
#   'privatsphäre',
#   'verletzen',
#   'u',
#   'sogar',
#   'kriminelles',
#   'unrecht',
#   'begehen',
#   'schaden',
#   'wir',
#   'letzten',
#   'endes',
#   'unserer',
#   'politischen',
#   'kultur',
#   'u',
#   'damit',
#   'uns',
#   'allen',
#   'kein',
#   'ruhmesblatt',
#   '\u2066\u2069',
#   '\u2066\u2069',
#   'strachevideo',
#   'ibizagate'],
#  ['wenn', 'sich', 'medien', 'und', 'politik', 'ein', 'zimmer', 'nehmen'],
#  ['wir', 'lehnen', 'jede', 'form', 'der', 'gleichstellungspolitik', 'ab'],
#  ['weder', 'quoten', 'noch', 'zielvereinbarungen', 'fdp'],
#  ['gehören', 'in', 'ein', 'freies', 'deutschland'],
#  ['frauen',
#   'haben',
#   'alle',
#   'rechte',
#   'und',
#   'chancen',
#   'aus',
#   'eigener',
#   'kraft',
#   'ganz',
#   'ohne',
#   'paternalistische',
#   'emanzipationspolitik'],
#  ['bild', 'afd-grundsatzprogramm'],
#  ['als',
#   'jemand',
#   'der',
#   'unter',
#   'klarnamen',
#   'schreibt',
#   'an',
#   'alle',
#   'die',
#   'keine',
#   'publizisten',
#   'sind',
#   'und',
#   'deshalb',
#   'aus',
#   'sorge',
#   'um',
#   'ihre',
#   'existenz',
#   'anonym',
#   'twittern',
#   'müssen',
#   'ich',
#   'verstehe',
#   'sie',
#   'sehr',
#   'gut'],
#  ['daimler-chef', "'flüchtlinge", 'könnten', 'wirtschaftswunder', 'bringen'],
#  ['„',
#   'genau',
#   'solche',
#   'menschen',
#   'suchen',
#   'wir',
#   'bei',
#   'mercedes',
#   'und',
#   'überall',
#   'in',
#   'unserem',
#   'land.',
#   '“',
#   'daimler-chef',
#   "'massiver",
#   'stellenabbau'],
#  ['mittelfristig', 'könnten'],
#  ['stellen', 'wegfallen'],
#  ['feminist',
#   'inn',
#   'en',
#   'meinen',
#   'gleichstellung',
#   'wenn',
#   'sie',
#   '-berechtigung',
#   'sagen',
#   'also',
#   'ergebnisgleichheit',
#   'ganz',
#   'unabhängig',
#   'von',
#   'leistung'],
#  ['und',
#   'dann',
#   'entsteht',
#   'ein',
#   'widerspruch',
#   'zum',
#   'oben',
#   'zitierten',
#   'paragraphen',
#   'das',
#   'war',
#   'der',
#   'punkt',
#   '..',
#   'die',
#   'ganzen',
#   'niveaulosen',
#   'beleidigungen',
#   'ggü'],
#  ['der', 'afd', 'geben', 'gauland', 'letztlich', 'recht'],
#  ['wer',
#   'wissen',
#   'will',
#   'wer',
#   'die',
#   'antidemokraten',
#   'wirklich',
#   'sind',
#   'sollte',
#   'sich',
#   'fragen',
#   'wer',
#   'einer',
#   'ernsthaften',
#   'diskussion',
#   'über',
#   'sachthemen',
#   'ausweicht',
#   'und',
#   'sein',
#   'weltbild',
#   'nur',
#   'durch',
#   'ausgrenzung',
#   'schützen',
#   'kann'],
#  ['podiumsdiskussion',
#   'uni-schloss-münster',
#   'antifa',
#   'wdr',
#   'moderiert',
#   'zutaten',
#   'die',
#   'es',
#   'einem',
#   'afd-kandidaten',
#   'nicht',
#   'leicht',
#   'machen'],
#  ['ständiges', 'unterbrechen', 'gebrülle', 'zynisches', 'geklatsche'],
#  ['trotzdem',
#   'ist',
#   'es',
#   'mir',
#   'gelungen',
#   'unsere',
#   'positionen',
#   'zu',
#   'artikulieren'],
#  ['ein',
#   'ganz',
#   'herzliches',
#   'willkommen',
#   'und',
#   'all',
#   'unsere',
#   'freunde',
#   'von',
#   'der',
#   'fpö'],
#  ['ich',
#   'freue',
#   'mich',
#   'riesig',
#   'auf',
#   'die',
#   'künftige',
#   'zusammenarbeit',
#   'nun',
#   'auch',
#   'endlich',
#   'in',
#   'gemeinsamer',
#   'fraktion'],
#  ['👍🏻', 'eapn', 'afd'],
#  ['bei',
#   'der',
#   'nicht-wahl',
#   'von',
#   'harderkühnel',
#   'heißt',
#   'der',
#   'größte',
#   'verlierer',
#   'demokratie'],
#  ['es', 'gibt', 'kein', 'recht', 'auf', 'wahl'],
#  ['aber',
#   'es',
#   'gibt',
#   'eine',
#   'pflicht',
#   'die',
#   'nicht-wahl',
#   'zu',
#   'begründen'],
#  ['und', 'es', 'gibt', 'keine', 'gründe'],
#  ['man',
#   'kann',
#   'zur',
#   'afd',
#   'stehen',
#   'wie',
#   'man',
#   'will',
#   'aber',
#   'warum',
#   'darf',
#   'frau',
#   'harderkühnel',
#   'nicht',
#   'zur',
#   'bundestagsvizepräsidentin',
#   'gewählt',
#   'werden',
#   'aber',
#   'claudia',
#   'roth'],
#  ['roth',
#   'vertritt',
#   'als',
#   'vize',
#   'den',
#   'bundestag',
#   'aber',
#   'läuft',
#   'auf',
#   'demos',
#   'mit',
#   'bei',
#   'denen',
#   "'deutschland",
#   'verrecke',
#   'skandiert',
#   'wird'],
#  ['wir', 'brauchen', 'einen', 'schwarzen', 'papst'],
#  ['+++schlag',
#   'ins',
#   'gesicht',
#   'der',
#   'demokratie',
#   '+++',
#   'der',
#   'wähler',
#   'wird',
#   'sehr',
#   'genau',
#   'beobachten',
#   'wie',
#   'hier',
#   'mit',
#   'uns',
#   'umgegangen',
#   'wird'],
#  ['das',
#   'verhalten',
#   'der',
#   'anderen',
#   'parteien',
#   'ist',
#   'ganz',
#   'klar',
#   'undemokratisch'],
#  ['wir', 'sind', 'die', 'größte', 'oppositionspartei', 'im', 'bundestag'],
#  ['harderkühnel', 'bundestagsvizepraesidentin', 'afd'],
#  ['„',
#   'mit',
#   'rechten',
#   'reden',
#   '“',
#   'will',
#   'nicht',
#   'mit',
#   '„',
#   'rechten',
#   '“',
#   'reden',
#   'via'],
#  ['die', 'ddr', 'hätte', 'es', 'nicht', 'besser', 'hingekriegt'],
#  ['frankfurt', 'jahn'],
#  ['maaßen',
#   'ist',
#   'eine',
#   'großartige',
#   'persönlichkeit',
#   'der',
#   'deutschland',
#   'zu',
#   'dank',
#   'verpflichtet',
#   'ist'],
#  ['er',
#   'hat',
#   'sich',
#   'um',
#   'die',
#   'sicherheit',
#   'unseres',
#   'landes',
#   'verdient',
#   'macht'],
#  ['jetzt', 'widerspricht', 'er', 'merkels', 'regierungspropaganda'],
#  ['ehre', 'wem', 'ehre', 'gebührt'],
#  ['❝machen',
#   'sie',
#   'sich',
#   'mal',
#   'ehrlich',
#   'warum',
#   'kommt',
#   'das',
#   'genau',
#   'eine',
#   'woche',
#   'vor',
#   'der',
#   'europawahl',
#   '❞',
#   'afd-spitzenkandidat',
#   '_meuthen',
#   'stellt',
#   'bei',
#   'annewill',
#   '-autor',
#   'die',
#   'entscheidende',
#   'frage'],
#  ['strache',
#   'ep',
#   'meuthen',
#   'euwahl',
#   'ibizagate',
#   'oesterreich',
#   'neuwahlen'],
#  ['auch',
#   'auf',
#   'eu-länder',
#   'die',
#   'dem',
#   'migrationspakt',
#   'ausdrücklich',
#   'nicht',
#   'zugestimmt',
#   'haben',
#   'soll',
#   'der',
#   'pakt',
#   'nach',
#   'dem',
#   'willen',
#   'der',
#   'eu-kommission',
#   'nun',
#   'anwendung',
#   'finden'],
#  ['österreich', 'hat', 'dagegen', 'bereits', 'protestiert'],
#  ['ein', 'kommentar', 'von', 'matthias', 'moosdorf'],
#  ['unsere',
#   'regierung',
#   'hat',
#   'uns',
#   'beleogen',
#   'der',
#   'globale',
#   'migrationspakt',
#   'wird',
#   'verbindlich'],
#  ['wie', 'in', 'der', 'ddr', 'oder', 'schon', 'schlimmer'],
#  ['gewerkschaft',
#   'schmeißt',
#   'mitglied',
#   'raus',
#   'welches',
#   'in',
#   'die',
#   'afd',
#   'eintrat.😡',
#   'die',
#   'aufgabe',
#   'der',
#   'gewerkschaften',
#   'ist',
#   'die',
#   'interessenvertretung',
#   'der',
#   'angestellten',
#   'und',
#   'nicht',
#   'die',
#   'gesinnungskontrolle'],
#  ['zeit', 'für', 'vernunft', 'zeit', 'für', 'die', 'afd❣️'],
#  ['sie',
#   'haben',
#   'vergessen',
#   'kuba',
#   'pol',
#   'pot',
#   'china',
#   'ddr',
#   'und',
#   'die',
#   'tatsache',
#   'dass',
#   'die',
#   'nsdap',
#   'ursprünglich',
#   'eine',
#   'antibürgerliche',
#   'antikapitalistische',
#   'bewegung',
#   'die',
#   'industrie',
#   'und',
#   'banken',
#   'enteignen',
#   'wollte',
#   'röhm—flügel',
#   'wie',
#   'man',
#   'bei',
#   'götz',
#   'aly',
#   'gut',
#   'nachlesen',
#   'kann'],
#  ['afdwirkt',
#   'prof.',
#   'opaschowski',
#   'deutschlands',
#   'bekanntester',
#   'zukunftsforscher',
#   'übernimmt',
#   'die',
#   'kritik',
#   'der',
#   'afd',
#   'an',
#   'den',
#   'altparteien',
#   'die',
#   'weiterhin',
#   'ungeregelten',
#   'einwanderung',
#   'zulassen'],
#  ['man', 'soll', 'nicht', 'aufrechnen'],
#  ['bemerkenswert',
#   'ist',
#   'allerdings',
#   'die',
#   'ungleichgewichtigkeit',
#   'der',
#   'berichterstattung'],
#  ['bitte',
#   'unterstützen',
#   'sie',
#   'die',
#   'petition',
#   '»',
#   'keine',
#   'öffentliche',
#   'finanzierung',
#   'der',
#   'amadeu',
#   'antonio',
#   'stiftung',
#   '«'],
#  ['die',
#   'österreichische',
#   'regierung',
#   'wird',
#   'von',
#   'deutschland',
#   'aus',
#   'abgesetzt',
#   '–',
#   'woran',
#   'erinnert',
#   'das'],
#  ['hier', 'ein', 'lagebericht', 'aus', 'diavata', 'bei', 'thessaloniki'],
#  ['googeln',
#   'sie',
#   'mal',
#   'zdf',
#   'oder',
#   'ard',
#   'und',
#   'diavata',
#   'oder',
#   'thessaloniki'],
#  ['mit',
#   'etwas',
#   'glück',
#   'finden',
#   'sie',
#   'eine',
#   'dürftige',
#   'meldung',
#   'vom'],
#  ['ard', 'zdf', '🙈🙉🙊'],
#  ['mindestens', 'millionen', 'mal'],
#  ['bis',
#   'auch',
#   'der',
#   'letzte',
#   'nachtwächter',
#   'versteht',
#   'was',
#   'hier',
#   'abgeht'],
#  ['wochenrückblick',
#   'ein',
#   'sozialismus',
#   'mit',
#   'dem',
#   'antlitz',
#   'von',
#   'robert',
#   'habeck',
#   'via'],
#  ['ein',
#   'mitglied',
#   'der',
#   'partei',
#   'wird',
#   'gerade',
#   'prominent',
#   'auf',
#   'twitter',
#   'weil',
#   'es',
#   'einen',
#   'brandanschlag',
#   'auf',
#   'autos',
#   'von',
#   'afd-mitglieder',
#   'gut',
#   'findet'],
#  ['die',
#   'partei',
#   'wollte',
#   'ich',
#   'wählen',
#   'aber',
#   'mit',
#   'brandstiftung',
#   'will',
#   'ich',
#   'nix',
#   'zu',
#   'tun',
#   'haben'],
#  ['wie', 'krank', 'seid', 'ihr'],
#  ['ich',
#   'werde',
#   'sowas',
#   'nicht',
#   'wählen',
#   '..',
#   'es',
#   'gibt',
#   'kein',
#   'zwischenleben'],
#  ['ein', 'mensch', 'lebt', 'oder', 'er', 'ist', 'tot'],
#  ['entweder',
#   'man',
#   'ist',
#   'für',
#   'das',
#   'lebensrecht',
#   'von',
#   'ungeborenen',
#   'oder',
#   'für',
#   'ihren',
#   'tod'],
#  ['also',
#   'ist',
#   "'pro",
#   'life',
#   'vs.',
#   "'pro",
#   'death',
#   'entwaffnend',
#   'wahr'],
#  ['dieser',
#   'servicetweet',
#   'für',
#   'framing-expertin',
#   '_wehling',
#   'ist',
#   'völlig',
#   'gez-gebührenfrei'],
#  ['in',
#   'griechenland',
#   'bildet',
#   'sich',
#   'migrantenkarawane',
#   'unter',
#   "'allahu",
#   "akbar'-",
#   'und',
#   "'deutschland'-rufen",
#   'fliegen',
#   'steine',
#   'auf',
#   'polizisten',
#   'werden',
#   'frauen',
#   'in',
#   'die',
#   'erste',
#   'reihe',
#   'gestellt',
#   'kinder',
#   'als',
#   'rammböcke',
#   'benutzt',
#   'um',
#   'polizeiketten',
#   'zu',
#   'sprengen'],
#  ['daher', 'meine', 'frage', 'an', 'merkel'],
#  ['würde', 'mich', 'da', 'mal', 'nicht', 'so', 'früh', 'freuen'],
#  ['hofer', 'bpw'],
#  ['man', 'ist', 'leicht', 'drin'],
#  ['wer',
#   'raus',
#   'will',
#   'dem',
#   'wird',
#   'mit',
#   'untergangsszenarien',
#   'gedroht'],
#  ['die', 'führung', 'beansprucht', 'unfehlbarkeit', 'für', 'sich'],
#  ['eu', 'oder', 'sekte'],
#  ['zwei',
#   'monate',
#   'vor',
#   'landtagswahl',
#   'afd',
#   'in',
#   'mecklenburg-vorpommern',
#   'bei',
#   'prozent',
#   'spd',
#   'schmiert',
#   'ab'],
#  ['sind',
#   'sie',
#   'der',
#   'meinung',
#   'dass',
#   'die',
#   'familienpolitik',
#   'der',
#   'regierung',
#   'mangelhaft',
#   'ist'],
#  ['➡', '️die', 'antwort', 'heißt', 'afd'],
#  ['unser', 'justizminister', 'ist', 'einfach', 'nur', 'noch', 'peinlich'],
#  ['ersetze',
#   'özil',
#   'dürch',
#   'müller',
#   'und',
#   'kein',
#   'hahn',
#   'würde',
#   'danach',
#   'krähen'],
#  ['täglich',
#   'brände',
#   'in',
#   'berlin',
#   'was',
#   'macht',
#   'die',
#   'vereinte',
#   'altparteienkoalition'],
#  ['einen', 'anti-afd-konsens', 'unterschrieben'],
#  ['nur', 'die', 'lüge', 'braucht', 'die', 'stütze', 'der', 'staatsgewalt'],
#  ['die', 'wahrheit', 'steht', 'von', 'alleine', 'aufrecht'],
#  ['t.', 'jefferson'],
#  ['davon', 'will', 'nichts', 'wissen'],
#  ['erschreckendes', 'ausmaß', 'der', 'gewalt', 'gegen', 'die', 'afd'],
#  ['ersetze', "'rechte", 'durch', "'linke", 'und', 'dann', 'passt', 'das'],
#  ['wer',
#   'nicht',
#   'im',
#   'rot-grün-gutmenschlichen',
#   'mainstream',
#   'mitschwimmt',
#   'ist',
#   'rechts'],
#  ['hat', 'aber', 'nix', 'mit', 'nix', 'zu', 'tun', 'nicht', 'wahr'],
#  ['hendricks',
#   'spd',
#   'stellt',
#   'die',
#   'aktuelle',
#   'parteilinie',
#   'der',
#   'spd',
#   'vor',
#   'bevormundung',
#   'planwirtschaft',
#   'ideologiegläubigkeit'],
#  ['im',
#   'zeugenstand',
#   'hannelore',
#   'kraft',
#   'kann',
#   'schweigen',
#   'nach',
#   'köln',
#   'kaum',
#   'erklären',
#   'via'],
#  ['bundespräsidentenwahl',
#   'osze',
#   'schickt',
#   'wahlbeobachter',
#   'nach',
#   'österreich'],
#  ['einen',
#   'weiteren',
#   'beweis',
#   'dass',
#   'sämtliche',
#   'altparteien',
#   'einen',
#   'block',
#   'bilden',
#   'braucht',
#   'es',
#   'nicht'],
#  ['wählt', 'vielfalt', 'wählt', 'afd'],
#  ['jeder',
#   'jeden',
#   'tag',
#   'mal',
#   'dieses',
#   'pic',
#   'geteilt',
#   'und',
#   'wir',
#   'sind',
#   'diese',
#   'verräter',
#   'bis',
#   'weihnachten',
#   'los',
#   'afd',
#   'pegida',
#   'ltwmv',
#   'agh'],
#  ['der',
#   'deutsche',
#   'rechtsstaat',
#   'kann',
#   'so',
#   'knallhart',
#   'und',
#   'grausam',
#   'penibel',
#   'sein',
#   'wenn',
#   'es',
#   'um',
#   'falschparker',
#   'steuererklärungen',
#   'oder',
#   'gez-gebühren',
#   'geht',
#   '..',
#   'hey',
#   'follower',
#   'ab',
#   'sofort',
#   'twittere',
#   'ich',
#   'unter',
#   'dem',
#   'account',
#   'würde',
#   'mich',
#   'freuen',
#   'euch',
#   'dort',
#   'begrüßen',
#   'zu',
#   'dürfen'],
#  ['wie',
#   'wäre',
#   'es',
#   'denn',
#   'mal',
#   'wenn',
#   'sie',
#   'sich',
#   'um',
#   'die',
#   'echten',
#   'probleme',
#   'kümmern',
#   'würden'],
#  ['wie', 'vielter', 'tag', 'in', 'folge'],
#  ['über',
#   'der',
#   'kinder',
#   'lt',
#   'jahren',
#   'in',
#   'deutschland',
#   'haben',
#   'einen',
#   'migrationshintergrund',
#   'unglaublich'],
#  ['was', 'ist', 'wichtiger'],
#  ['das', 'kindeswohl', 'oder', 'die', 'religion'],
#  ['liegt',
#   'vielleicht',
#   'daran',
#   'dass',
#   'sie',
#   'nicht',
#   'qualifiziert',
#   'sind'],
#  ['polizei-großeinsatz',
#   'zwei',
#   'tote',
#   'bei',
#   'schüssen',
#   'in',
#   'marburger',
#   'arztpraxis',
#   'n'],
#  ['rumgejammere',
#   'dass',
#   'alte',
#   'den',
#   'jungen',
#   'mit',
#   'brexit',
#   'zukunft',
#   'verbauen',
#   'liegt',
#   'daneben.den',
#   'jungen',
#   'war',
#   'eu',
#   'so',
#   'egal',
#   'dass',
#   'nicht',
#   'gewählt',
#   'haben‼️'],
#  ['hass',
#   'kann',
#   'man',
#   'nur',
#   'bei',
#   'menschen',
#   'erzeugen',
#   'die',
#   'hassen',
#   'wenn',
#   'jemand',
#   'anderer',
#   'meinung',
#   'ist',
#   'als',
#   'sie',
#   'selbst'],
#  ['sehr', 'arm'],
#  ['die',
#   'spd-schlußfolgerung',
#   'aus',
#   'dem',
#   'brexit',
#   'staatsbürgerschaft',
#   'verschleudern',
#   'um',
#   'sich',
#   'ein',
#   'neues',
#   'willigeres',
#   'volk',
#   'suchen'],
#  ['simone',
#   'peter',
#   'grün',
#   'löscht',
#   'einen',
#   'von',
#   'mir',
#   'kritisierten',
#   'tweet',
#   'und',
#   'blockt',
#   'meinen',
#   'account',
#   'keine',
#   'argumente',
#   'afd'],
#  ['aber',
#   'wenn',
#   'ich',
#   'zu',
#   'viel',
#   'grünzeug',
#   'esse',
#   'produziere',
#   'ich',
#   'auch',
#   'zu',
#   'viel',
#   'co'],
#  ['istanbul-drahtzieher',
#   'in',
#   'russland',
#   'als',
#   'terrorist',
#   'angeklagt',
#   'in',
#   'europa',
#   'asyl',
#   'erhalten',
#   'via',
#   '_sputnik'],
#  ['heute', 'ist', 'der', '.juli'],
#  ['abgeordnete',
#   'erhalten',
#   'automatisch',
#   'und',
#   'ohne',
#   'debatten',
#   'mehr',
#   'geld'],
#  ['gauck', 'unterschrieb', 'das', 'gesetz'],
#  ['würde',
#   'das',
#   'die',
#   'afd',
#   'machen',
#   'wäre',
#   'die',
#   "'kacke",
#   'am',
#   'dampfen'],
#  ['bevor',
#   'sich',
#   'staatliche',
#   'institutionen',
#   'an',
#   'einer',
#   'kampagne',
#   'gegen',
#   'hassrede',
#   'beteiligen',
#   'muss',
#   'hassrede',
#   'zunächst',
#   'einmal',
#   'klar',
#   'definiert',
#   'werden',
#   '..',
#   'mecklenburg-vorpommern',
#   'afd',
#   'bei',
#   'prozent',
#   'spd',
#   'vor',
#   'machtverlust',
#   'via',
#   '👍👍👍❤️❤️❤️',
#   'afd',
#   '❤️❤️❤️',
#   '👍👍👍'],
#  ['na',
#   'dann',
#   'wollen',
#   'wir',
#   'mal',
#   'hoffen',
#   'dass',
#   'hofer',
#   'das',
#   'rennen',
#   'macht'],
#  ['spd', 'räumt', 'im', 'silvester-u-ausschuss', 'fehler', 'ein', 'koelnhbf'],
#  ['die', 'werden', 'nicht', 'lang', 'sondern', 'hassverzerrt', 'sein'],
#  ['die',
#   'bundespräsidenten-stichwahl',
#   'wird',
#   'in',
#   'ganz',
#   'österreich',
#   'zu',
#   'gänze',
#   'wiederholt'],
#  ['fpö', 'bekommt', 'recht'],
#  ['tagesschau',
#   'auf',
#   'der',
#   'barrikade',
#   'ard',
#   'ruft',
#   'die',
#   'briten',
#   'zur',
#   'neuwahl',
#   'auf'],
#  ['heben', 'höchstrichter', 'die', 'hofburg-wahl', 'auf'],
#  ['urteil', 'bereits', 'heute', 'mittag', 'und', 'auf', 'krone.at'],
#  ['sachsen',
#   'macht',
#   'ernst',
#   'im',
#   'ersten',
#   'halbjahr',
#   'wurden',
#   'bereits',
#   'mehr',
#   'menschen',
#   'abgeschoben',
#   'als',
#   'im',
#   'gesamten',
#   'jahr'],
#  ['maghreb-staaten',
#   'grüne',
#   'wollen',
#   'kompromiss',
#   'bei',
#   'sicheren',
#   'herkunftsstaaten'],
#  ['berlin|er',
#   'schulen',
#   'senat',
#   'will',
#   'nur',
#   'milliarden',
#   'euro',
#   'in',
#   'sanierung',
#   'stecken'],
#  ['hinterhalt', 'amp', 'steinwürfe', 'auf', 'kollegen'],
#  ['dpolg',
#   'pfalzgraf',
#   "'wir",
#   'brauchen',
#   'persönliche',
#   'schutzausstattung',
#   'für',
#   'jeden',
#   'polizisten'],
#  ['nach',
#   'übergriffen',
#   'gegen',
#   'frauen',
#   'polizei',
#   'erhöht',
#   'präsenz',
#   'beim',
#   'darmstädter',
#   'heinerfest',
#   'multikulti',
#   'lässt',
#   'grüßen'],
#  ['städtebund',
#   'will',
#   'flüchtlinge',
#   'als',
#   'polizisten',
#   'union',
#   'warnt',
#   'vor',
#   "'experimenten",
#   'sicherheit',
#   'facepalm'],
#  ['auf',
#   'gar',
#   'keinen',
#   'fall',
#   'will',
#   'ich',
#   'diskutieren',
#   'ich',
#   'frag',
#   'nur'],
#  ['ist', 'z.b'],
#  ['das', 'hier', 'hass', 'oder', 'eine', 'meinung'],
#  ['und', 'die', 'türkei', 'soll', 'in', 'die', 'eu', 'aufgenommen', 'werden'],
#  ...]

# %%
hatespeech5=""

with open("hatespeech/germeval2018.training.txt") as f:
    content = f.readlines()
    for row in content:
        if "OFFENSE" in row:
            x = row
            x = re.sub(r"http\S+|\.\.+|\S+\/\/+|www\S+|\d+|OFFENSE|OTHER|ABUSE|INSULT|PROFANITY|@[_A-Za-z0-9]+","", x)
            x+="."
            x = x.lower()
            x = remove_emoji(x)
            hatespeech5 += " " + x

# %%
hatespeech5 = clean(hatespeech5)

# %%
hatespeech5
# Out:
# [['kein', 'verläßlicher', 'verhandlungspartner'],
#  ['nachkarteln',
#   'nach',
#   'den',
#   'sondierzngsgesprächen',
#   'schickt',
#   'diese',
#   'stümper',
#   'spd',
#   'in',
#   'die',
#   'versenkung'],
#  ['bis',
#   'habe',
#   'ich',
#   'noch',
#   'gar',
#   'nicht',
#   'gelebt',
#   'und',
#   'es',
#   'geht',
#   'mir',
#   'am',
#   'arsch',
#   'vorbei',
#   'was',
#   'in',
#   'dieser',
#   'zeit',
#   'geschehen',
#   'ist'],
#  ['ich',
#   'lebe',
#   'im',
#   'heute',
#   'und',
#   'jetzt',
#   'und',
#   'nicht',
#   'in',
#   'der',
#   'vergangenheit'],
#  ['euere', 'afd', 'hetze', 'wirkt'],
#  ['da', 'könnt', 'ihr', 'stolz', 'sein', 'bei', 'ard-fernsehen'],
#  ['deutsche',
#   'medien',
#   'halbwahrheiten',
#   'und',
#   'einseitige',
#   'betrachtung',
#   'wie',
#   'bei',
#   'allen',
#   'vom',
#   'staat',
#   'finanzierten',
#   'billigen',
#   'propagandainstitutionen'],
#  ['oman', 'ralledich', 'mag', 'ja', 'immer', 'noch', 'keiner'],
#  ['du', 'willst', 'das', 'die', 'hetze', 'gegen', 'dich', 'aufhört'],
#  ['|lbr|',
#   'geh',
#   'in',
#   'rente',
#   'und',
#   'verzichte',
#   'auf',
#   'die',
#   '/deiner',
#   'pension'],
#  ['für',
#   'mich',
#   'ist',
#   'der',
#   'morgige',
#   'tag',
#   'ein',
#   'tag',
#   'der',
#   'größten',
#   'deutschen',
#   'schweinerei',
#   'seit',
#   'eine',
#   'riesen',
#   'mogelpackung',
#   'bekloppter',
#   'politiker'],
#  ['ich',
#   'kenne',
#   'noch',
#   'einige',
#   'namen',
#   'unter',
#   'den',
#   'spdler',
#   'die',
#   'ebenfalls',
#   'zu',
#   'grabe',
#   'getragen',
#   'müssten-sollten-werden'],
#  ['ach',
#   'gott',
#   'mehr',
#   'nicht',
#   'was',
#   'gedenkt',
#   'man',
#   'dagegen',
#   'zutun',
#   'nach',
#   'dem',
#   'gg',
#   'dürfen',
#   'nur',
#   'deutsche',
#   'staatsbürger',
#   'protestieren',
#   '.was',
#   'hier',
#   'geschehen',
#   'ist',
#   'ist',
#   'ein',
#   'aufstand',
#   'von',
#   'radikalen',
#   'moslems',
#   'da',
#   'sage',
#   'ich',
#   'nur',
#   'einsammeln',
#   'und',
#   'heimschicken'],
#  ['hubertuswas', 'hab', 'ich', 'mit', 'adolf', 'zu', 'tun'],
#  ['|lbr|',
#   'und',
#   'ich',
#   'erstarre',
#   'bei',
#   'beim',
#   'wort',
#   'nazi',
#   'auch',
#   'nicht',
#   'in',
#   'schuldgefühlen',
#   'wie',
#   'der',
#   'rest',
#   'nur',
#   'weil',
#   'ichliebe'],
#  ['wir',
#   'haben',
#   'keine',
#   'meinungsfreiheit',
#   'von',
#   'wem',
#   'soll',
#   'die',
#   'auch',
#   'kommen',
#   'wenn',
#   'man',
#   'eine',
#   'in',
#   'der',
#   'ddr',
#   'ausgebildete',
#   'bundeskanzlerin',
#   'hat',
#   '.mielke',
#   'hätte',
#   'sich',
#   'totgelacht.ich',
#   'glaube',
#   'am',
#   'grab',
#   'hört',
#   'man',
#   'in'],
#  ['infotweet',
#   'antifaschisten',
#   'sind',
#   'alle',
#   'vernachlässigte',
#   'scheidungskinder'],
#  ['und', 'die', 'linken', 'anarchisten', 'üben', 'in', 'hamburg'],
#  ['das',
#   'ist',
#   'einfach',
#   'soaber',
#   'noch',
#   'lange',
#   'kein',
#   'grund',
#   'deutschland',
#   'mit',
#   'fremden',
#   'männern',
#   'zu',
#   'fluten'],
#  ['juden',
#   'und',
#   'christen',
#   'werden',
#   'als',
#   'schweine',
#   'und',
#   'affen',
#   'bezeichnet',
#   'aber',
#   'das',
#   'steht',
#   'ja',
#   'nur',
#   'im',
#   'koran'],
#  ['die', 'suren', 'erspare', 'ich', 'mir', 'jetzt'],
#  ['kann', 'man', 'diesen', 'ganzen', 'scheiß', 'noch', 'glauben'],
#  ['bla', 'bla', 'bla'],
#  ['lügenpresse', 'verkauft', 'uns', 'mal', 'wider', 'für', 'dumm'],
#  ['alles', 'gespieltes', 'theater'],
#  ['das', 'kann', 'doch', 'nur', 'ein', 'fake', 'sein'],
#  ['die', 'sind', 'sowenig', 'deutsch', 'wie', 'erdogan'],
#  ['nu', 'gehts', 'wirklich', 'los'],
#  ['auch', 'im', 'tv', 'der', 'msm', 'nur', 'noch', 'nichtdeutsche'],
#  ['illner',
#   'das',
#   'söder',
#   'nun',
#   'auf',
#   'afd',
#   'programm',
#   'macht',
#   'und',
#   'die',
#   'wahrheit',
#   'ausspricht',
#   'welche',
#   'nur',
#   'bei',
#   'der',
#   'afd',
#   'rassistisch',
#   'und',
#   'polemisch',
#   'bei',
#   'söder',
#   'aber',
#   'bürgernahe',
#   'erkenntnis',
#   'ist',
#   'scheint',
#   'prozent',
#   'überhaupt',
#   'nicht',
#   'zu',
#   'stören'],
#  ['|lbr|', 'jaso', 'sind', 'sie.die', 'heuchler', 'und', 'doppelmoraler'],
#  ['sind',
#   'selbst',
#   'schuld',
#   'die',
#   'dummen',
#   'girlies',
#   'die',
#   'unbedingt',
#   'modell',
#   'werden',
#   'wollen'],
#  ['spätestens',
#   'seit',
#   'blümchen',
#   'wissen',
#   'wir',
#   'welche',
#   'waschlappen',
#   'in',
#   'der',
#   'regierung',
#   'sitzen'],
#  ['ja',
#   'das',
#   'ist',
#   'was',
#   'kinder',
#   'so',
#   'aufem',
#   'kindergartenspielplatz',
#   'so',
#   'anstellen',
#   'und',
#   'daraus',
#   'ist',
#   'der',
#   'glaube',
#   'der',
#   'moslems',
#   'endstanden'],
#  ['merkel',
#   'die',
#   'bürger',
#   'haben',
#   'keine',
#   'lust',
#   'auf',
#   'zuständigkeitsdebatten'],
#  ['eben',
#   'ein',
#   'verlogenes',
#   'miststück',
#   'mit',
#   'ausreichender',
#   'denunziantenerfahrung'],
#  ['abschieben', 'es', 'sind', 'doch', 'nur', 'moslems'],
#  ['mccain',
#   'erwies',
#   'sich',
#   'bisher',
#   'generell',
#   'als',
#   'mit',
#   'haut',
#   'überzogener',
#   'verlogener',
#   'politischer',
#   'dreckshaufen'],
#  ['was', 'heißt', 'hier', 'flüchtlingseinrichtungen'],
#  ['die',
#   'meisten',
#   'der',
#   'jungen',
#   '|lbr|',
#   'männer',
#   'sind',
#   'keine',
#   'flüchtlinge'],
#  ['sie', 'sind', 'rücksichtslose', 'invasoren'],
#  ['von',
#   'mir',
#   'aus',
#   'gibt',
#   'es',
#   'dieses',
#   'intersexuell',
#   'aber',
#   'die',
#   'eigentlichen',
#   'geschlechter',
#   'sind',
#   'männlein',
#   'und',
#   'weiblein'],
#  ['merkel',
#   'ich',
#   'sehe',
#   'nicht',
#   'was',
#   'wir',
#   'anders',
#   'machen',
#   'sollten',
#   'gt',
#   'wie',
#   'hohl',
#   'muss',
#   'man',
#   'eigentlich',
#   'sein',
#   'um',
#   'nichts',
#   'zu',
#   'begreifen',
#   'frau',
#   'murksel'],
#  ['dann',
#   'solltet',
#   'ihr',
#   'grünes',
#   'pack',
#   'eure',
#   'bodygards',
#   'verdoppeln'],
#  ['araber', 'haben', 'schon', 'ekelhafte', 'fressen'],
#  ['den',
#   'kleber',
#   'sollten',
#   'sie',
#   'nicht',
#   'anzeigen',
#   'sondern',
#   'zensiert'],
#  ['liebe',
#   'den',
#   'niedergang',
#   'der',
#   'ösi-grünen',
#   'und',
#   'diesen',
#   'herrn',
#   'pilz',
#   'will',
#   'ich',
#   'von',
#   'erklärt',
#   'bekommen'],
#  ['geht', 'da', 'was', 'heute'],
#  ['islamisierung',
#   'zusammenstöße',
#   'zw',
#   'gläubigen',
#   'richtig',
#   'islamisten',
#   'amp',
#   'sicherheitskräften',
#   'tagesschau',
#   'sendet',
#   'bereits',
#   'im',
#   'scharia-modus'],
#  ['der',
#   'einzige',
#   'der',
#   'sich',
#   'noch',
#   'darüber',
#   'freut',
#   'dass',
#   'merkel',
#   'auf',
#   'ihrem',
#   'stuhl',
#   'klebt',
#   '|lbr|',
#   'ist',
#   'der',
#   'beginnende',
#   '|lbr|',
#   'dekubitus'],
#  ['die', 'türken', 'fordern', 'gerechtigkeit'],
#  ['anstatt',
#   'dort',
#   'wo',
#   'sie',
#   'die',
#   '|lbr|',
#   'ungerechtigkeit',
#   'gewählt',
#   'haben',
#   'fordern',
#   'sie',
#   'das',
#   'in',
#   'österreich'],
#  ['haut', 'ab'],
#  ['kann',
#   'ja',
#   'mit',
#   'kahane',
#   'de',
#   'maizire',
#   'wagenknecht',
#   'trittin',
#   'und',
#   'eckhard',
#   'maas'],
#  ['eine', 'neue', 'sed', 'partei', 'gründen'],
#  ['hauptsache', 'imerika', 'ist', 'weg'],
#  ['dieser',
#   'typ',
#   'erinnert',
#   'mich',
#   'in',
#   'agitation',
#   'und',
#   'erscheinung',
#   'an',
#   'subjekte',
#   'der',
#   'ns',
#   'zeit',
#   'er',
#   'wird',
#   'zusammen',
#   'mit',
#   'der',
#   'raute',
#   'unser',
#   'grab',
#   'schaufeln',
#   'deutschland',
#   'und',
#   'die',
#   'deutschen',
#   'werden',
#   'zugunsten',
#   'eines',
#   'totalitären',
#   'eu',
#   'systems',
#   'vollständig',
#   'vernichtet',
#   'werden'],
#  ['streit',
#   'um',
#   'flüchtlings-obergrenze',
#   'so',
#   'könnten',
#   'cdu',
#   'und',
#   'csu',
#   'ihr',
#   'gesicht',
#   'wahren',
#   'wenn',
#   'eine',
#   'hässliche',
#   'fratze',
#   'gemeint',
#   'ist',
#   'geht',
#   's'],
#  ['von',
#   'parteien',
#   'hat',
#   'das',
#   'deutsche',
#   'volk',
#   'die',
#   'schnauze',
#   'voll',
#   'schon',
#   'gar',
#   'von',
#   'linken'],
#  ['|lbr|',
#   'wenn',
#   'wir',
#   'heute',
#   'den',
#   'begriff',
#   '„',
#   'kriminelle',
#   'vereinigung',
#   '„',
#   'hören',
#   'denken',
#   'die',
#   'meisten',
#   'an',
#   'den',
#   'sogenannten',
#   'bundestag/bundesregierung'],
#  ['spd',
#   'ist',
#   'der',
#   'größte',
#   'dreck',
#   'gewordenstegner',
#   'und',
#   'schulz',
#   'so',
#   'ziemlich',
#   'das',
#   'lächerliste',
#   'was',
#   'es',
#   'zu',
#   'bieten',
#   'hat'],
#  ['türken',
#   'die',
#   'sich',
#   'die',
#   'österreichische',
#   'staatsbürgerschaft',
#   'erschlichen',
#   'haben',
#   '|lbr|',
#   'müssen',
#   'aufgedeckt',
#   'und',
#   'verurteil',
#   'werden'],
#  ['unsere',
#   'jetzige',
#   'regierung',
#   'ist',
#   'verbrecherisch',
#   'hochkriminell',
#   'antideutsch',
#   'korrupt',
#   'und',
#   'geldgierig'],
#  ['was', 'soll', 'man', 'mit', 'so', 'einen', 'scheiß'],
#  ['dortmund', 'haut', 'wieder', 'auf', 'die', 'kacke'],
#  ['die',
#   'wollen',
#   'die',
#   'ganzen',
#   'braunhäutigen',
#   'verjagen',
#   'mit',
#   'dem',
#   'slogan',
#   'bunt',
#   'statt',
#   'braun'],
#  ['ich',
#   'schäme',
#   'mich',
#   'in',
#   'solchem',
#   'verbrecherstaat',
#   'mit',
#   'deutschfeindlichen',
#   'ganoven-richtern',
#   'und',
#   'korrupten',
#   'politikern',
#   'zu',
#   'leben'],
#  ['ist',
#   'doch',
#   'wahr',
#   'denn',
#   'dieses',
#   'dicke',
#   'etwas',
#   'bekommt',
#   'kaum',
#   'zwei',
#   'zusammenhängenden',
#   'sätze',
#   'heraus',
#   'und',
#   'von',
#   'sinnvoll',
#   'rede',
#   'ich',
#   'garnicht',
#   'erst'],
#  ['|lbr|',
#   'die',
#   'staatsanwaltschaft/richter',
#   'führen',
#   'nur',
#   'anordnungen',
#   'von',
#   'oben',
#   'aus'],
#  ['|lbr|', 'die', 'politiker', 'aus', 'dem', 'bmi', 'sinds'],
#  ['die',
#   'eu',
#   'dient',
#   'zur',
#   'aushebelung',
#   'der',
#   'selbstbestimmung',
#   'der',
#   'europ'],
#  ['völker',
#   '|lbr|',
#   'die',
#   'migranten',
#   'sollen',
#   'eine',
#   'wählermehrheit',
#   'für',
#   'die',
#   'eu',
#   'wahl',
#   'schaffen',
#   '|lbr|',
#   'dann',
#   'wird',
#   'alles',
#   'als',
#   'freier',
#   'wille',
#   'der',
#   'nationalstaaten',
#   'dargestellt'],
#  ['|lbr|', 'ziel', 'zentralregierung', 'in', 'brüssel'],
#  ['juhu',
#   'der',
#   'bayer',
#   'ohne',
#   'eier',
#   'will',
#   'wieder',
#   'einmal',
#   'alles',
#   'nach',
#   'der',
#   'wahl',
#   'richten',
#   'ich',
#   'pinkel',
#   'mir',
#   'vor',
#   'lachen',
#   'gleich',
#   'ein'],
#  ['dass',
#   'wir',
#   'diese',
#   'ganzen',
#   'is-kämpfer',
#   'haben',
#   'ist',
#   'ausschließlich',
#   'die',
#   '|lbr|',
#   'schuld',
#   'der',
#   'amerikaner'],
#  ['scheinheiliges', 'volk'],
#  ['migrantenanteil',
#   'in',
#   'großstädten',
#   '|lbr|',
#   'münchen',
#   '|lbr|',
#   'frankfurt',
#   '|lbr|',
#   'stuttgart',
#   '|lbr|',
#   'nürnberg',
#   '|lbr|',
#   'köln',
#   '|lbr|',
#   'hamburg',
#   '|lbr|',
#   'berlin',
#   '|lbr|',
#   'der',
#   'westen',
#   'so',
#   'gut',
#   'wie',
#   'verloren',
#   'wenn',
#   'sich',
#   'nix',
#   'ändert'],
#  ['in',
#   'diesem',
#   'kiez',
#   'sollten',
#   'besser',
#   'wahre',
#   'deutsche',
#   'leben',
#   'als',
#   'dieses',
#   'pack',
#   'von',
#   'linken',
#   'anarchisten'],
#  ['die',
#   'frauen',
#   'die',
#   'nach',
#   'geschäftsschluss',
#   'mit',
#   'öffentlichen',
#   'verkehrsmitteln',
#   'nach',
#   'hause',
#   'fahren',
#   'müssen',
#   'tun',
#   'mir',
#   'leid.und',
#   'wenn',
#   'man',
#   'dann',
#   'durch',
#   'käfertal',
#   'und',
#   'viernheim',
#   'nach',
#   'weinheim',
#   'fahren',
#   'muss',
#   'hat',
#   'man',
#   'das',
#   'gefühl',
#   'die',
#   'rnv',
#   'fährt',
#   'durch',
#   'den',
#   'kongo'],
#  ['jerusalem',
#   'war',
#   'schon',
#   'immer',
#   'die',
#   'hauptstadt',
#   'von',
#   'israel',
#   'genauso',
#   'wie',
#   'die',
#   'palästinenser',
#   'schon',
#   'immer',
#   'terroristen',
#   'waren'],
#  ['was', 'hast', 'du', 'gegen', 'asiaten', 'du', 'halbnigger'],
#  ['martin',
#   'schulz',
#   'ist',
#   'x',
#   'sitzen',
#   'geblieben',
#   'und',
#   'hat',
#   'keinen',
#   'schulabschluss'],
#  ['|lbr|',
#   'wie',
#   'kann',
#   'denn',
#   'so',
#   'ein',
#   'nulltipper',
#   'als',
#   'kanzlerkandidat',
#   'aufgestellt',
#   'werden'],
#  ['das',
#   'ist',
#   'die',
#   'stadt',
#   'mit',
#   'der',
#   'armlänge',
#   '|lbr|',
#   'wenn',
#   'ein',
#   'volk',
#   'seine',
#   'frauen',
#   'und',
#   'seine',
#   'kinder',
#   'nicht',
#   'beschütztwelchen',
#   'wert',
#   'hat',
#   'es',
#   'dann',
#   'noch'],
#  ['|lbr|',
#   'yücel',
#   'hatte',
#   'rechtdie',
#   'deutschen',
#   'taugen',
#   'nicht',
#   'viel'],
#  ['da', 'fehlen', 'dir', 'noch'],
#  ['und',
#   'die',
#   'müssen',
#   'nicht',
#   'im',
#   'kreis',
#   'wretweeten',
#   'sondern',
#   'hinausziehen',
#   'zu',
#   'den',
#   'barbaren',
#   'und',
#   'ihnen',
#   'das',
#   'evangelium',
#   'predigen'],
#  ['also',
#   'z.b',
#   'zu',
#   'den',
#   'mullahs',
#   'die',
#   'gerade',
#   'eine',
#   'frau',
#   'steinigen',
#   'weil',
#   'ihr',
#   'kopftuch',
#   'verrutscht',
#   'ist'],
#  ['wie', 'gesagt'],
#  ['dumme',
#   'kinder',
#   'von',
#   'alt',
#   'er',
#   'die',
#   'man',
#   'besser',
#   'abgetrieben',
#   'oder',
#   'besser',
#   'ins',
#   'klo',
#   'gewichst',
#   'hätte'],
#  ['und', 'ich', 'bin', 'kein', 'afd', 'wähler'],
#  ['wir',
#   'brauchen',
#   'dringend',
#   'einen',
#   'reset',
#   'der',
#   'msm',
#   'und',
#   'des',
#   'grundschulsystems',
#   'ohne',
#   'diese',
#   'verfluchten',
#   'handsockenpuppen',
#   'schwingenden',
#   'ökoantifafeministinnen'],
#  ['hoher',
#   'anspruch',
#   'im',
#   'namen',
#   'und',
#   'wurde',
#   'für',
#   'zu',
#   'leicht',
#   'befunden'],
#  ['du',
#   'für',
#   'sie',
#   'reicht',
#   'einfach',
#   'der',
#   'respekt',
#   'nicht',
#   'kennst',
#   'auch',
#   'den',
#   'unterschied',
#   'zwischen',
#   'einem',
#   'lieferwagen',
#   'und',
#   'einem',
#   'muslimischen',
#   'terroristen',
#   'nicht'],
#  ['das',
#   'böse',
#   'und',
#   'schlimme',
#   'daran',
#   'ist',
#   'das',
#   'du',
#   'das',
#   'garnicht',
#   'willst'],
#  ['was', 'ist', 'den', 'das', 'fette', 'etwas', 'da'],
#  ['was',
#   'kurz',
#   'zu',
#   'gast',
#   'bei',
#   'der',
#   'küchenschabe',
#   'hoffe',
#   'er',
#   'hat',
#   'den',
#   'kammerjäger',
#   'dabei'],
#  ['deutschlands',
#   'zukunft',
#   'wird',
#   'am',
#   'hindukusch',
#   'entschieden',
#   'spd',
#   'zitat',
#   '|lbr|',
#   'das',
#   'stimmt'],
#  ['wir', 'haben', 'dort', 'verloren'],
#  ['jetzt',
#   'fluten',
#   'die',
#   'afganen',
#   'nach',
#   'deutschland',
#   'und',
#   'zerstören',
#   'es',
#   'von',
#   'innen'],
#  ['kümmert', 'die', 'einen', 'feuchten', 'd'],
#  ['vehement', 'kotzt', 'sich', 'd.', 'cdu', 'üb'],
#  ['nazis',
#   'in',
#   'd.',
#   'afd',
#   'aus',
#   'hatte',
#   'aber',
#   'nach',
#   'nazitäter',
#   'in',
#   'd.',
#   'regierung',
#   'u',
#   'behinderte',
#   'd.',
#   'aufarbeitung',
#   'd.'],
#  ['sich',
#   'damit',
#   'auch',
#   'noch',
#   'brüsten',
#   'ist',
#   'schöndämlich',
#   '|lbr|',
#   'wenn',
#   'man',
#   'tief',
#   'genug',
#   'gräbt',
#   'findet',
#   'man',
#   'tatsächlich',
#   'immer',
#   'noch',
#   'eine',
#   'dümmere',
#   'deutscheobwohl',
#   'bei',
#   'katja',
#   'an',
#   'der',
#   'oberfläche',
#   'kratzen',
#   'schon',
#   'ausreicht'],
#  ['merkel',
#   'reiht',
#   'sich',
#   'nahtlos',
#   'in',
#   'die',
#   'kette',
#   'deutscher',
#   'diktatoren',
#   'ein',
#   'die',
#   'allesamt',
#   'ihre',
#   'biographien',
#   'schönen',
#   'ließen'],
#  ['schaut',
#   'euch',
#   'einfach',
#   'die',
#   'dummen',
#   'köpfe',
#   'andas',
#   'gehört',
#   'eindeutig',
#   'entsorgt'],
#  ['schon',
#   'ein',
#   'wahnsinnobwohl',
#   'nichtmal',
#   'der',
#   'bevölkerung',
#   'sie',
#   'gewählt',
#   'hat',
#   'darf',
#   'sie',
#   'trotzdem',
#   'weiter',
#   'regieren'],
#  ['|lbr|', 'ist', 'zum', 'kotzen'],
#  ['träume',
#   'und',
#   'wünscheleider',
#   '|lbr|',
#   'jamaika-scheisse',
#   'wird',
#   'durchgesetztdafür',
#   'sorgen',
#   'schon',
#   'die',
#   'lauch-scheisser',
#   '|lbr|',
#   'die',
#   'bleiben',
#   'klebend',
#   'sitzendder',
#   'troll',
#   'joschka',
#   'hat',
#   '’',
#   's',
#   'ihnen',
#   'vorgemacht',
#   'die',
#   'warze',
#   'roth',
#   'hat',
#   '’',
#   's',
#   'perfektioniert'],
#  ['die',
#   'gesamte',
#   'deutschfeindliche',
#   'asyl-politik',
#   'der',
#   'altparteien',
#   'provoziert',
#   'einen',
#   'bürgerkrieg'],
#  ['die', 'grünen', 'werden', 'als', 'erste', 'vernichtet', 'werden'],
#  ['die', 'julia', 'hat', 'ja', 'auch', 'kalte', 'lötstellen', 'im', 'kopf'],
#  ['bestimmt', 'ein', 'kind', 'der', 'er'],
#  ['sorry', 'aber', 'die', 'hätte', 'man', 'besser', 'ins', 'klo', 'gewichst'],
#  ['da', 'wären', 'die', 'heute', 'noch', 'auf', 'reißen'],
#  ['warum',
#   'veröffentlicht',
#   'ihr',
#   'keine',
#   'bilder',
#   'von',
#   'linken',
#   'anarchisten',
#   'die',
#   'gibt',
#   'es',
#   'zuhauf',
#   'aber',
#   'ihr',
#   'seit',
#   'nur',
#   'ein',
#   'unterstützer',
#   'dieser',
#   'horden'],
#  ['mobbing',
#   'an',
#   'schulen',
#   'setzt',
#   'sich',
#   'jetzt',
#   'in',
#   'der',
#   'politik',
#   'fort',
#   '|lbr|',
#   'altparteien',
#   'sprechen',
#   'alle',
#   'nicht',
#   'mit',
#   'der',
#   'afd',
#   'sondern',
#   'nur',
#   'abfällig',
#   'nazi',
#   'über',
#   'sie'],
#  ['da',
#   'die',
#   'kirche',
#   'jeher',
#   'den',
#   'herrschenden',
#   'in',
#   'den',
#   'arsch',
#   'gekrochen',
#   'ist',
#   'inkl'],
#  ['hitler', 'wundert', 'es', 'mich', 'nicht'],
#  ['dümmer', 'geht', 'immer', 'paßt', 'stalinisten', 'besser'],
#  ['geh',
#   'besser',
#   'grammatikfehler',
#   'jagen',
#   'ist',
#   'ein',
#   'rein',
#   'rotgrünes',
#   'ding',
#   'bevor',
#   'argumente',
#   'am',
#   'geist',
#   'kratzen'],
#  ['verlogene',
#   'doppelmoralistenheuchler',
#   '|lbr|',
#   'der',
#   'arme',
#   'hund',
#   '|lbr|',
#   'hetze'],
#  ['tja',
#   'ich',
#   'denke',
#   'eu',
#   'wird',
#   'an',
#   'bürgerkriegen',
#   'zugrunde',
#   'gehen',
#   'ist',
#   'ja',
#   'genau',
#   'das',
#   'was',
#   'die',
#   'eliten',
#   'planen',
#   'und',
#   'der',
#   'gierige',
#   'linke',
#   'scheiß',
#   'machts',
#   'möglich'],
#  ['so',
#   'sieht',
#   'meinungsfreiheit',
#   'in',
#   'deutschland',
#   'aus',
#   'dank',
#   'dieser',
#   'volksverräterin',
#   'merkel'],
#  ['|lbr|', 'herzlichen', 'willkommen', 'in', 'der', 'ddr'],
#  ['es', 'wird', 'zeit'],
#  ['es',
#   'gibt',
#   'schon',
#   'reichlich',
#   'dumme',
#   'in',
#   'den',
#   'eigenen',
#   'reihendiesmal',
#   'ist',
#   'es',
#   'halt',
#   'ein',
#   'arbeitsloser',
#   'journalist'],
#  ['seit',
#   'jahren',
#   'werd',
#   'n',
#   'wir',
#   'von',
#   'dieser',
#   'regierung',
#   'belogen',
#   'und',
#   'jetzt',
#   'sollen',
#   'wir',
#   'glauben',
#   'das',
#   'es',
#   'nur',
#   'ein',
#   'fake',
#   'ist'],
#  ['ich', 'glaube', 'das', 'es', 'echt', 'ist'],
#  ['wenn',
#   'trump',
#   'der',
#   'neue',
#   'hitler',
#   'ist',
#   '|lbr|',
#   'was',
#   'ist',
#   'dann',
#   'clinton'],
#  ['|lbr|', 'clinton', '|lbr|', 'der', 'antichrist'],
#  ['irgend',
#   'ein',
#   'idiot',
#   'hat',
#   'sich',
#   'über',
#   'die',
#   '„',
#   'feuerzangenbowle',
#   '„',
#   'aufgeregt',
#   'weil',
#   'dieser',
#   'film',
#   'während',
#   'der',
#   'nazizeit',
#   'gedreht',
#   'wurde.was'],
#  ['ist',
#   'mit',
#   'den',
#   'bestsellers',
#   'wie',
#   '„',
#   'emil',
#   'und',
#   'die',
#   'detektive',
#   '„',
#   'pünktchen',
#   'und',
#   'anton',
#   '„',
#   'oder',
#   '„',
#   'das',
#   'fliegende',
#   'klassenzimmer',
#   '„',
#   'von',
#   'erich',
#   'kästner'],
#  ['weg', 'weg', 'weg', 'mit', 'links'],
#  ['kein', 'klagerecht', 'für', 'migranten'],
#  ['keine', 'unterstützung', 'mit', 'schwesigraubgeld', 'für', 'linksautonome'],
#  ['prob', 'gelöst'],
#  ['weil', 'diese', 'antifantenbrut', 'nicht', 'ihre', 'gesichter', 'zeigt'],
#  ['solche',
#   'linksversifften',
#   'menschen',
#   'gehören',
#   'nicht',
#   'auf',
#   'die',
#   'straße',
#   'sondern',
#   'zensiert'],
#  ['warum',
#   'hat',
#   'wohl',
#   'der',
#   'terrorfürst',
#   'yassir',
#   'arafat',
#   'das',
#   'wort',
#   '»',
#   'palästinenser',
#   '«',
#   'für',
#   'die',
#   'araber',
#   'in',
#   'der',
#   'levante',
#   'benutzt'],
#  ['dieses',
#   'volk',
#   'gab',
#   'es',
#   'vorher',
#   'nicht',
#   'aber',
#   'man',
#   'bediente',
#   'sich',
#   'aus',
#   'dem',
#   'antisemitismus',
#   'der',
#   'römer',
#   'die',
#   'uns',
#   'juden',
#   'demütigten',
#   'amp',
#   'eretz',
#   'israel',
#   'in',
#   'palästina',
#   '«',
#   'unbenannten'],
#  ['die', 'für', 'die', 'linken', 'sind', 'weggeworfene', 'stimmen'],
#  ['ohne', 'sie', 'wäre', '|lbr|', 'eine', 'cdu/fdp-regierung', 'möglich'],
#  ['weg', 'mit', 'den', 'linken', 'sie', 'taugen', 'nichts'],
#  ['wir',
#   'sollten',
#   'den',
#   'deutschen',
#   'kinder',
#   'und',
#   'frauen',
#   'gedenken',
#   'die',
#   'durch',
#   'den',
#   'islam',
#   'ermordet',
#   'wurden'],
#  ['ich',
#   'will',
#   'nicht',
#   'das',
#   'es',
#   'kriminellen',
#   'flüchtlingen',
#   'deserteuren',
#   'und',
#   'feiglingen',
#   'hier',
#   'besser',
#   'gehterst',
#   'recht',
#   'nicht',
#   'dem',
#   'afrika-pack',
#   '|lbr|',
#   'und',
#   'weder',
#   'bin',
#   'ich',
#   'rassist',
#   'noch',
#   'ein',
#   'nazi',
#   'noch',
#   'xenophob'],
#  ['schade',
#   'das',
#   'die',
#   'kotzgrüne',
#   'brühe',
#   'nicht',
#   'im',
#   'erdreich',
#   'versickert',
#   '|lbr|',
#   'und',
#   'die',
#   'ausreisewilligen',
#   'werden',
#   'gegen',
#   'ihren',
#   'willen',
#   'festgehalten'],
#  ['politiker',
#   'holen',
#   'terroristen',
#   'ins',
#   'land',
#   'und',
#   'lassen',
#   'die',
#   'opfer',
#   'hilflos',
#   'zurück'],
#  ['wer',
#   'so',
#   'aussieht',
#   'der',
#   'träumt',
#   'davon',
#   'die',
#   'sollte',
#   'mal',
#   'sich',
#   'mal',
#   'auf',
#   'ihren',
#   'geisteszustand',
#   'untersuchen',
#   'lassen'],
#  ['hihihi',
#   'ich',
#   'finde',
#   'merkel',
#   'bastelte',
#   'sich',
#   'aus',
#   'der',
#   'cdu/csu',
#   'eine',
#   'neue',
#   'blockflöten-cdu',
#   'der',
#   'ddr',
#   'voller',
#   'ja-sager',
#   'und',
#   'klatscher',
#   'eben',
#   'ohne',
#   'hirn'],
#  ['bis',
#   'auf',
#   'den',
#   'holocaust',
#   'und',
#   'den',
#   'krieg',
#   'wahr',
#   'er',
#   'eigentlich',
#   'ein',
#   'solider',
#   'kanzler'],
#  ['merkel', 'vasallen', 'sind', 'bei', 'twitter', 'unerwünscht'],
#  ['flüchtlingsboote',
#   'in',
#   'küstennähe',
#   'torpedieren',
#   'dann',
#   'lernen',
#   'die',
#   'sozialschmarotzer',
#   'schwimmen',
#   '.leider',
#   'sind',
#   'unsere',
#   'u',
#   '-boote',
#   'alle',
#   'nicht',
#   'einsatzfähig'],
#  ['facebook',
#   'ist',
#   'nur',
#   'für',
#   'posten',
#   'von',
#   'urlaubsbilder',
#   'geeignetund',
#   'den',
#   'migranten-dreck',
#   'will',
#   'man',
#   'uns',
#   'mit',
#   'aller',
#   'gewalt',
#   'schönredenzum',
#   'kotzen'],
#  ['wurdest',
#   'du',
#   'luder',
#   'du',
#   'nicht',
#   'mit',
#   'rede.-und',
#   'schreibverbot',
#   'belegt'],
#  ['|lbr|',
#   'berlin',
#   'berlinmigranten',
#   'überallim',
#   'rathaus',
#   'und',
#   'auf',
#   'straßenne',
#   'richtige',
#   'kanackenstadt',
#   'gewordenoder',
#   'heißt',
#   'es',
#   'kanackenstaat'],
#  ['wenn',
#   'ich',
#   'nachdenke',
#   'ist',
#   'es',
#   'schon',
#   'erniedrigend',
#   'im',
#   'lobbyisten.babel',
#   'deutschland',
#   'unter',
#   'führung',
#   'der',
#   'finger',
#   'kauenden',
#   'marionette',
#   'leben',
#   'zu',
#   'müssen'],
#  ['g',
#   'ist',
#   'geplante',
#   'verarschung',
#   'von',
#   'merkel',
#   '|lbr|',
#   'die',
#   'gewaltexzesse',
#   'sichern',
#   'ihren',
#   'nächsten',
#   'wahlsieg',
#   '|lbr|',
#   'außer',
#   'spesen',
#   'nix',
#   'gewesen'],
#  ['dummheit',
#   'ist',
#   'in',
#   'deutschland',
#   'seit',
#   'stasi-merkel',
#   'weit',
#   'verbreitet'],
#  ['übrigens',
#   'das',
#   'war',
#   'sie',
#   'bei',
#   'adolf',
#   'ebenso',
#   'und',
#   'wir',
#   'wissen',
#   'alle',
#   'wohin',
#   'das',
#   'führte'],
#  ['wie',
#   'verkommen',
#   'müssen',
#   'erst',
#   'die',
#   'sein',
#   'die',
#   'dieses',
#   'gesicht',
#   'gewählt',
#   'haben'],
#  ['wie', 'blöd', 'sind', 'deutsche', 'politiker', 'eigentlich'],
#  ['die', 'meisten', 'deutschen', 'misstrauen', 'merkel'],
#  ['|lbr|',
#   'warum',
#   'schreibt',
#   'dieses',
#   'vasallenpack',
#   'der',
#   'deutschen',
#   'lügenpresse',
#   'nicht',
#   'mal',
#   'darüber'],
#  ['moin', 'piepser', 'hänge', 'hier', 'immer', 'noch', 'fest'],
#  ['cm',
#   'schnee',
#   'bringen',
#   'd.',
#   'kommunalpolitik',
#   'durcheinander',
#   'was',
#   'wollen',
#   'die',
#   'affen',
#   'dem',
#   'is',
#   'entgegen',
#   'setzen'],
#  ['stasi',
#   'im',
#   'erika',
#   'alias',
#   'merkel',
#   'bezahlt',
#   'das',
#   'ganze',
#   'noch'],
#  ['und', 'maas', 'der', 'neue', 'heinrich'],
#  ['h', 'regelt', 'das', 'ganze'],
#  ['wer', 'jetzt', 'denkt', 'das', 'hatten', 'wir', 'schon', 'ist', 'nazi'],
#  ['das',
#   'sind',
#   'doch',
#   'alles',
#   'masturbierende',
#   'pickelplatagen',
#   'keine',
#   'ahnung',
#   'von',
#   'etwasdeswegen',
#   'werden',
#   'sie',
#   'bestimmt',
#   'berufspolitiker'],
#  ['na',
#   'klar',
#   'kriegt',
#   'der',
#   'lob',
#   'von',
#   'allen',
#   'seitenist',
#   'ja',
#   'ein',
#   'merkel-blindenhund'],
#  ['|lbr|',
#   'wollt',
#   'ihr',
#   'tatsächliche',
#   'opfer',
#   'sehen',
#   'dann',
#   'geht',
#   'auf',
#   'friedhöfe',
#   'oder',
#   'sprecht',
#   'mit',
#   'den',
#   'angehörigen'],
#  ['jeder',
#   'kann',
#   'die',
#   'von',
#   'kalergi',
#   'in',
#   'den',
#   'ern',
#   'verfassten',
#   'pamphlete',
#   'die',
#   'die',
#   'ideologie',
#   'der',
#   'heutigen',
#   'eu',
#   'vorweg',
#   'nahmen',
#   'recherchieren',
#   'es',
#   'ist',
#   'eine',
#   'zionistische',
#   'rassistische',
#   'ideologie',
#   'die',
#   'auf',
#   'vermischung',
#   'der',
#   'weisen',
#   'europäer',
#   'abzielt',
#   'geführt',
#   'von',
#   'einer',
#   'art',
#   'herrenrasse'],
#  ['heiko',
#   'maas',
#   'hat',
#   'das',
#   'buch',
#   'genau',
#   'wie',
#   'seine',
#   'aktuellen',
#   'tweets',
#   'nicht',
#   'einmal',
#   'selbst',
#   'verfasst'],
#  ['der',
#   'schriftsteller',
#   'michael',
#   'ebmeyer',
#   'stand',
#   'ihm',
#   'mit',
#   'seinem',
#   'schmalzigen',
#   'stil',
#   'zur',
#   'seite'],
#  ['bundeskanzler',
#   'kurz',
#   'wird',
#   'sicherlich',
#   'nicht',
#   'noch',
#   'einmal',
#   'bei',
#   'maischberger',
#   'sitzen'],
#  ['bei',
#   'einer',
#   'frau',
#   'ohne',
#   'anstand',
#   'keinerlei',
#   'erziehung',
#   'und',
#   'achtung',
#   'vor',
#   'andersdenkende'],
#  ['eine',
#   'heuchelnde',
#   'anhängerin',
#   'der',
#   'diktatur',
#   'das',
#   'ist',
#   'frau',
#   'maischberger'],
#  ['|lbr|', 'maischberger'],
#  ['so',
#   'sind',
#   'sie',
#   'haltunwissend',
#   'und',
#   'unbelehrbarje',
#   'weniger',
#   'ahnung',
#   'desto',
#   'lauter',
#   'ihr',
#   'geschrei'],
#  ['schulz', 'ist', 'als', 'kanzler', 'undenkbar'],
#  ['zweimal', 'sitzengeblieben', 'und', 'ohne', 'schulabschluss'],
#  ['eine',
#   '|lbr|',
#   'schande',
#   'für',
#   'die',
#   'spd',
#   'und',
#   'ein',
#   'armutszeichen'],
#  ['für', 'd.'],
#  ['spd',
#   'ist',
#   'für',
#   'de',
#   'nicht',
#   'wählbar',
#   'dieses',
#   'üble',
#   'pack',
#   'fordert',
#   'd',
#   'familiennachzug',
#   'für',
#   'alle',
#   'muslimische',
#   'invasoren',
#   'forderung',
#   'von',
#   'malu',
#   'dreyer',
#   'schulz',
#   '|lbr|',
#   'afd'],
#  ['phantomschmerz',
#   'fehlende',
#   'eier',
#   'und',
#   'machtgeilheit',
#   'zwangen',
#   'heute',
#   'erneut',
#   'den',
#   'bayern-horsti',
#   'ohne',
#   'vaseline',
#   'in',
#   'den',
#   'ar',
#   'der',
#   'kanzlerette'],
#  ['sie',
#   'sind',
#   'ein',
#   'steuerbetrüger',
#   'und',
#   'haben',
#   'die',
#   'einzige',
#   'demokratische',
#   'partei',
#   'deutschlands',
#   'afd',
#   'nicht',
#   'zu',
#   'beleidigen'],
#  ['bald', 'sind', 'sie', 'verschwunden'],
#  ['so',
#   'schaun',
#   'sieger',
#   'aus',
#   'lalalalla',
#   'so',
#   'schaun',
#   'sieger',
#   'aus',
#   'lalalallaalla',
#   '|lbr|',
#   'mein',
#   'traum',
#   'geht',
#   'in',
#   'erfüllungkotzgrüne',
#   'brühe',
#   'versickert',
#   'endlich',
#   'im',
#   'erdreich'],
#  ['die',
#   'linke',
#   'arroganz',
#   'wird',
#   'schon',
#   'noch',
#   'ihre',
#   'ohrfeigen',
#   'bekommen',
#   'wenn',
#   'so',
#   'tapfere',
#   'blödies',
#   'wie',
#   'm.albrecht',
#   'länger',
#   'am',
#   'watschenbaum',
#   'rütteln'],
#  ['hatte',
#   'schon',
#   'angst',
#   'das',
#   'ich',
#   'ab',
#   'jetzt',
#   'nur',
#   'noch',
#   'an',
#   'den',
#   'baum',
#   'oder',
#   'in',
#   'die',
#   'hecke',
#   'pissen',
#   'darf'],
#  ['vasallen', 'merkels', 'melden', 'sich', 'zu', 'wort'],
#  ['ich',
#   'wundere',
#   'mich',
#   'immer',
#   'wieder',
#   'wieviele',
#   'dumme',
#   'menschen',
#   'es',
#   'in',
#   'deutschland',
#   'gibt'],
#  ['jahre', 'gehirnwäsche', 'hat', 'ihre', 'spuren', 'hinterlassen'],
#  ['irgendwie',
#   'verständlich',
#   'daß',
#   'berlusconi',
#   'diesen',
#   'schulz',
#   'mit',
#   'einem',
#   'kz-aufseher',
#   'verglich'],
#  ['und',
#   'zu',
#   'dir',
#   'h',
#   'maas',
#   'am',
#   'frühen',
#   'morgen',
#   'tust',
#   'du',
#   'nicht',
#   'so',
#   'wie',
#   'das',
#   'volk',
#   'es',
#   'will',
#   'so',
#   'lecke',
#   'es',
#   'am',
#   'arsche'],
#  ['f.n.g.v.b', 'lauf', 'forrest'],
#  ['setz',
#   'dir',
#   'mal',
#   'keinen',
#   'falschen',
#   'lorbeerkranz',
#   'auf',
#   'die',
#   'schmierige',
#   'frisur',
#   'mohammed'],
#  ['das',
#   'tut',
#   'die',
#   'deutsche',
#   'gesellschaft',
#   'bestehend',
#   'aus',
#   'gutmenschen',
#   'duckmäusern',
#   'und',
#   'hatern',
#   'schon',
#   'ganz',
#   'von',
#   'selbst',
#   'orientierungslose',
#   'jugendliche',
#   'in',
#   'die',
#   'hände',
#   'von',
#   'moslems',
#   'treiben'],
#  ['nix', 'sezession', 'der', 'ruhrpott', 'ist', 'mir', 'woll'],
#  ['und',
#   'wer',
#   'dat',
#   'nich',
#   'will',
#   'dem',
#   'komm',
#   'ich',
#   'dabei',
#   'bei',
#   'mir',
#   'weht',
#   'die',
#   'deutsche',
#   'fahne',
#   'nicht',
#   'wie',
#   'merkel',
#   'die',
#   'unsere',
#   'fahne',
#   'in',
#   'den',
#   'dreck',
#   'schmeißt',
#   'und',
#   'draufspuckt'],
#  ['das',
#   'video',
#   'kennt',
#   'jeder',
#   'das',
#   'ist',
#   'ihre',
#   'einstellung',
#   'zu',
#   'unserem',
#   'land'],
#  ['ihr',
#   'diskutiert',
#   'allen',
#   'ernstes',
#   'über',
#   'eine',
#   'völlig',
#   'schwachsinnige',
#   'noch',
#   'dazu',
#   'ausgezeichnete',
#   'rede',
#   'einer',
#   'vielleicht',
#   'schon',
#   'nicht',
#   'mehr',
#   'im',
#   'land',
#   'befindlichen',
#   'psychopathin',
#   'habt',
#   'ihr',
#   'nichts',
#   'besseres',
#   'zu',
#   'tun',
#   '⁉'],
#  ['seit',
#   'wenigen',
#   'stunden',
#   'zurück',
#   'in',
#   'deutschland',
#   'was',
#   'für',
#   'eine',
#   'lächerliche',
#   'manipulierte',
#   'und',
#   'verlogene',
#   'parteienlandschaft',
#   'um',
#   'murksels',
#   'thron'],
#  ['es', 'gibt', 'genug', 'fakten'],
#  ['stehen',
#   'mittlerweile',
#   'sogar',
#   'in',
#   'der',
#   'bild',
#   '|lbr|',
#   'ich',
#   'will',
#   'gewiss',
#   'keinen',
#   'krieg'],
#  ['ich',
#   'will',
#   'nur',
#   'dass',
#   'frauen',
#   'und',
#   'kinder',
#   'sowie',
#   'eine',
#   'heile',
#   'familie',
#   'dem',
#   'volk',
#   'wichtiger',
#   'werden',
#   'als',
#   'staatlich',
#   'geförderter',
#   'asylbetrug'],
#  ['na',
#   'der',
#   'typ',
#   'ist',
#   'wohl',
#   'die',
#   'personifizierte',
#   'linksgrünversyphte',
#   'abartigkeit'],
#  ['das',
#   'auch',
#   'noch',
#   'mit',
#   'aufruf',
#   'zur',
#   'gewalt',
#   'die',
#   'den',
#   'deutschen',
#   'durch',
#   'messerschwingenden',
#   'libanesen-und',
#   'türkenabschaum',
#   'angetan',
#   'werden',
#   'soll',
#   'weil',
#   'es',
#   'ja',
#   'so',
#   'innovative',
#   'unmenschen',
#   'sind'],
#  ['wie', 'kommt', 'son', 'typ', 'an', 'solchen', 'posten'],
#  ['mit',
#   'verlaub',
#   'würde',
#   'dummheit',
#   'quietschen',
#   'müssten',
#   'sie',
#   'den',
#   'ganzen',
#   'tag',
#   'mit',
#   'einer',
#   'öl',
#   'kanne',
#   'herum',
#   'laufen'],
#  ['da',
#   'der',
#   'türkei',
#   'in',
#   'asien',
#   'liegt',
#   'ist',
#   'das',
#   'reines',
#   'wunsch',
#   'denken'],
#  ['die', 'nato', 'und', 'eu', 'braucht', 'die', 'türkei', 'nicht'],
#  ['heinrichkrug',
#   'lass',
#   'dich',
#   'von',
#   'diesen',
#   'merkel',
#   'vasall',
#   'nicht',
#   'ärgern'],
#  ['einfach', 'diese', 'vasallen', 'ignorieren'],
#  ['und',
#   'diese',
#   'ukrainischen',
#   'nazis',
#   'werden',
#   'heute',
#   'vom',
#   'westen',
#   'unterstützt',
#   'poroschenko',
#   'ist',
#   'ein',
#   'hinterfotziger',
#   'hund',
#   'er',
#   'lügt',
#   'und',
#   'betrügt'],
#  ['das',
#   'sind',
#   'alles',
#   'nur',
#   'schlepper-unterstützer',
#   'und',
#   'sollten',
#   'bestraft',
#   'werden'],
#  ['diese',
#   'nichtsnützigen',
#   'analphabeten',
#   'will',
#   'syrien',
#   'nicht',
#   'zurückdie',
#   'sind',
#   'froh',
#   'das',
#   'deutschland',
#   'sie',
#   'nicht',
#   'mehr',
#   'hergibt'],
#  ['der',
#   'de',
#   'rot',
#   'grün',
#   'versiffte',
#   'journalismus',
#   'hetzt',
#   'gegen',
#   'all',
#   'die',
#   'präsidenten',
#   'anderer',
#   'länder',
#   'siehe',
#   'kurz',
#   'orban',
#   'trump',
#   'die',
#   'ihr',
#   'volk',
#   'vorziehen',
#   '|lbr|',
#   'afd'],
#  ['verdammt', 'nochmal', 'ihr', 'afrikaner'],
#  ['fangt',
#   'endlich',
#   'an',
#   'eure',
#   'probleme',
#   '|lbr|',
#   'selbst',
#   'zu',
#   'lösen'],
#  ['nur', 'die', 'besser', 'gestellten', 'können', 'abhauen'],
#  ['es',
#   'ist',
#   'widerlich',
#   'sich',
#   'diesen',
#   'machtpoker',
#   'um',
#   'merkel',
#   'mit',
#   'ansehen',
#   'zu',
#   'müssen',
#   'zuzusehen',
#   'welche',
#   'schwachmaten',
#   'ausschließlich',
#   'um',
#   'macht',
#   'streiten'],
#  ['gute',
#   'nacht',
#   'ihr',
#   'lieben',
#   'da',
#   'draußen',
#   'und',
#   'träumt',
#   'schön',
#   'von',
#   'murksel',
#   'und',
#   'ihrem',
#   'kurzschwanzdackel',
#   'luschet'],
#  ['was',
#   'soll',
#   'man',
#   'schon',
#   'von',
#   'so',
#   'einer',
#   'lügenbande',
#   'erwarten'],
#  ['alles', 'politische', 'schwachköpfe'],
#  ['es',
#   'gibt',
#   'nur',
#   'ein',
#   'maas',
#   'das',
#   'ist',
#   'ein',
#   'mittelmaß',
#   'und',
#   'heißt',
#   'auch',
#   'so'],
#  ['wen', 'interessiert', 'schon', 'was', 'der', 'kleine', 'wicht', 'ruft'],
#  ['jerusalem', 'ist', 'die', 'hauptstadt', 'israels'],
#  ['so',
#   'werden',
#   'wir',
#   'von',
#   'den',
#   'moslems',
#   'unterwandert',
#   'und',
#   'die',
#   'meisten',
#   'kriegen',
#   'nichts',
#   'mit'],
#  ['wir',
#   'sind',
#   'ein',
#   'christliches',
#   'abendland',
#   'und',
#   'haben',
#   'die',
#   'moslems',
#   'schon',
#   'vor',
#   'wien',
#   'zurückgeschickt.es',
#   'wird',
#   'zeit',
#   'denen',
#   'die',
#   'grenzen',
#   'aufzuzeigen'],
#  ['illegale',
#   'invasoren',
#   'abfangen',
#   'und',
#   'dorthin',
#   'zurückjagen',
#   '|lbr|',
#   'wo',
#   'sie',
#   'herkommen'],
#  ['das', 'erspart', 'teure', 'abschiebungen'],
#  ['weiter', 'so'],
#  ['moin',
#   'hat',
#   'schon',
#   'einer',
#   'gemerkt',
#   'das',
#   'die',
#   'ganzen',
#   'syrer',
#   'wieder',
#   'gehen',
#   'können'],
#  ['auch',
#   'die',
#   'hyperpigmentierten',
#   'schwarzafrikanischen',
#   'syrer',
#   'können',
#   'auch',
#   'wieder',
#   'nach',
#   'hause'],
#  ['da',
#   'die',
#   'politik',
#   'das',
#   'nicht',
#   'propagiert',
#   'kann',
#   'man',
#   'wohl',
#   'von',
#   'gewollten',
#   'austausch',
#   'reden'],
#  ['der', 'abschaum', 'der', 'menschheit', 'bekommt', 'deutsche', 'pässe'],
#  ['diese',
#   'schuldigen',
#   'behörden',
#   'würden',
#   'in',
#   'einem',
#   'rechtsstaat',
#   'verklagt'],
#  ['|lbr|',
#   'tiraden',
#   'gibt',
#   'es',
#   'nur',
#   'von',
#   'deutschland',
#   'eu',
#   'gegen',
#   'trump',
#   'und',
#   'nicht',
#   'umgekehrt',
#   '|lbr|',
#   'manipulationspresse'],
#  ['auf', 'das', 'der', 'furor', 'teutonicus', 'erwacht', 'zurhöllemitmerkel'],
#  ['hat',
#   'man',
#   'das',
#   'mit',
#   'den',
#   'juden',
#   'gemacht',
#   'dass',
#   'zeigt',
#   'das',
#   'die',
#   'deutschen',
#   'aus',
#   'der',
#   'geschichte',
#   'nichts',
#   'gelernt',
#   'haben'],
#  ['wann', 'öffnet', 'dachau', 'wieder'],
#  ['schumacher',
#   'brandt',
#   'schmidt',
#   'wehner',
#   'leber',
#   'u',
#   'ehmke',
#   'wären',
#   'in',
#   'der',
#   'heutigen',
#   'spd',
#   'nazis',
#   'u',
#   'der',
#   'shariah',
#   'schulz',
#   'würde',
#   'sie',
#   'aus',
#   'der',
#   'spd',
#   'rausschmeißen'],
#  ['ehrliche',
#   'antwort',
#   'wir',
#   'haben',
#   'schwachmaten',
#   'und',
#   'dumpfbacken',
#   'als',
#   'politiker'],
#  ['nur', 'die', 'dumm-deutschen', 'wollen', 'es', 'nicht', 'begreifen'],
#  ['|lbr|',
#   'dumbest',
#   'woman',
#   'on',
#   'earth',
#   'angela',
#   'merkel',
#   'says',
#   'islam',
#   'is',
#   '‘',
#   'not',
#   'the',
#   'source',
#   'of',
#   'terrorism',
#   '’'],
#  ['es',
#   'gäbe',
#   'eine',
#   'lösungwir',
#   'sollten',
#   'als',
#   'verstärkung',
#   'die',
#   'maghreb-polizei',
#   'holen',
#   '|lbr|',
#   'nichts',
#   'fürchten',
#   'die',
#   'kleinen',
#   'schmarotzer',
#   'mehr'],
#  ['mit',
#   'dem',
#   'geld',
#   'für',
#   'die',
#   'goldjungenfamilien',
#   'hätte',
#   'man',
#   'jedem',
#   'deutschen',
#   'rentner/in',
#   'ein',
#   'menschenwürdiges',
#   'dasein',
#   'sichern',
#   'können.zur',
#   'hölle',
#   'mit',
#   'merkel'],
#  ['eins',
#   'hat',
#   'sultan',
#   'erdogan',
#   'schnell',
#   'erkannt',
#   'der',
#   'weg',
#   'zum',
#   'islamischen',
#   'großreich',
#   'is',
#   'wurde',
#   'ihm',
#   'vom',
#   'gefühlsdusel-westen',
#   'gut',
#   'geebnet',
#   'u.',
#   'bezahlt'],
#  ['und', 'das', 'von', 'einem', 'ungewaschenen'],
#  ['au', 'backe', 'lord', 'helmchen'],
#  ['sie',
#   'sind',
#   'leider',
#   'ohne',
#   'bildung',
#   'und',
#   'ohne',
#   'orthographische',
#   '|lbr|',
#   'grundkenntnisse',
#   'berechtigt',
#   'ihren',
#   'politischen',
#   'müll',
#   'hinauszuonanieren'],
#  ['gabriel',
#   'hat',
#   'sich',
#   'gemeldet',
#   'weil',
#   'er',
#   'auch',
#   'mal',
#   'was',
#   'sagen',
#   'wollte'],
#  ['diese',
#   'witzfigur',
#   'nimmt',
#   'doch',
#   'keiner',
#   'erst',
#   'weltweit',
#   'nicht'],
#  ['das', 'ist', 'ein', 'spinner', 'der', 'türken', 'hasst'],
#  ['defende', 'europe'],
#  ['ja', 'da', 'stimme', 'ich', 'zu'],
#  ['wir', 'brauchen', 'keine', '|lbr|', 'nazis'],
#  ['wir',
#   'brauchen',
#   'politiker',
#   'mit',
#   'hirn',
#   'und',
#   'nicht',
#   'mit',
#   'magenverkleinerung'],
#  ['nennen',
#   'wir',
#   'sie',
#   'beim',
#   'namendeserteure',
#   'fahnenflüchtige',
#   '|lbr|',
#   'die',
#   'werden',
#   'in',
#   'jedem',
#   'krieg',
#   'verfolgt',
#   'geächtet',
#   'und',
#   'hingerichtet',
#   'nur',
#   'dielieben',
#   'sie'],
#  ['die', 'hätte', 'man', 'früher', 'als', 'hexe', 'verbrannt'],
#  ['hitler', 'ist', 'zurück', 'und', 'heißt', 'jetzt', 'merkel'],
#  ['sind', 'die', 'türken', 'eigentlich', 'alle', 'so', 'aggressiv'],
#  ['die',
#   'zeit',
#   'ist',
#   'überreif',
#   'für',
#   'dass',
#   'große',
#   'ausmisten',
#   'in',
#   'politik',
#   'justiz',
#   'u',
#   'medien',
#   'dieses',
#   'ganze',
#   'rot',
#   'grün',
#   'versiffte',
#   'parteibuch',
#   'pack',
#   'zum',
#   'teufel',
#   'jagen'],
#  ['man',
#   'beobachte',
#   'usa',
#   'links',
#   'und',
#   'grün',
#   'stehen',
#   'wie',
#   'überall',
#   'für',
#   'intoleranz',
#   'gewalt',
#   'terror',
#   'bei',
#   'gegendemos',
#   'das',
#   'war',
#   'schon',
#   'immer',
#   'so'],
#  ['stimmt',
#   'und',
#   'merkel',
#   'als',
#   'reinfall',
#   'für',
#   'das',
#   'deutsche',
#   'volk',
#   'und',
#   'europa'],
#  ['|lbr|', 'diese', 'heuchlerin', 'sollte', 'lieber', 'ganz', 'still', 'sein'],
#  ['heute', 'wird', '“', 'unwort', 'des', 'jahres', '”', 'bekanntgegeben'],
#  ['wie',
#   'wärs',
#   'mit',
#   '„',
#   'fresse',
#   '“',
#   '„',
#   'kacke',
#   '“',
#   'oder',
#   '„',
#   'bätschi',
#   '”'],
#  ['bosbach',
#   'hätte',
#   'die',
#   'ditfurth',
#   'mit',
#   'ohrfeigen',
#   'und',
#   'tritten',
#   'aus',
#   'dem',
#   'studio',
#   'davonjagen',
#   '|lbr|',
#   'und',
#   'ihr',
#   'den',
#   'fächer',
#   'ins',
#   'maul',
#   'stopfen',
#   'sollen'],
#  ['ja', 'so', 'wäre', 'das'],
#  ['europäer',
#   'begreifen',
#   'langsam',
#   'dass',
#   'sie',
#   'durch',
#   'eu',
#   'allen',
#   'voran',
#   'merkel',
#   'juncker',
#   'nur',
#   'belogen',
#   'und',
#   'betrogen',
#   'und',
#   'ausgenommen',
#   'werden'],
#  ['|lbr|', 'katalonien'],
#  ['niemand', 'mag', 'dichaber', 'du', 'erfüllst', 'einen', 'riesen', 'zweck'],
#  ['ein',
#   'afrikaner',
#   'der',
#   'in',
#   'china',
#   'lebt',
#   'oder',
#   'geboren',
#   'ist',
#   'ist',
#   'dann',
#   'was'],
#  ['das', 'ist', 'lachhaft'],
#  ['es', 'gibt', 'nur', 'eine', 'nationale', 'identität'],
#  ['sie', 'hängt', 'von', 'der', 'abstammung', 'ab'],
#  ['eine',
#   'ratte',
#   'die',
#   'im',
#   'pferdestall',
#   'geboren',
#   'wird',
#   'ist',
#   'auch',
#   'niemals',
#   'ein',
#   'pferd'],
#  ['darüber', 'sollte', 'wohl', 'einigkeit', 'bestehen'],
#  ['sigmar', 'dumpfbacke', 'gabriel', 'gefällt', 'mir', 'richtig', 'gut'],
#  ['die',
#   'türken',
#   'machen',
#   'ihre',
#   'politik',
#   'in',
#   'der',
#   'mitte',
#   'deutschlands',
#   'meine',
#   'güte',
#   'was',
#   'hat',
#   'die',
#   'merkel-klicke',
#   'nur',
#   'für',
#   'einen',
#   'iq'],
#  ['was', 'für', 'eine', 'missratenes', 'blechgesicht'],
#  ['habt',
#   'ihr',
#   'schon',
#   'in',
#   'erwägung',
#   'gezogen',
#   'das',
#   'die',
#   'wahlen',
#   'nur',
#   'reine',
#   'verarsche',
#   'sind',
#   'seit',
#   'sind',
#   'immer',
#   'die',
#   'gleichen',
#   'volksverräter',
#   'dran',
#   'wie',
#   'blöd',
#   'kann',
#   'man',
#   'sein',
#   'und',
#   'das',
#   'nicht',
#   'irgendwann',
#   'zu',
#   'durchschauen',
#   '‼'],
#  ['wenn',
#   'tauber',
#   'lebensmüde',
#   'ist',
#   'sollte',
#   'er',
#   'bei',
#   'mir',
#   'klingeln'],
#  ['und', 'warum', 'redet', 'dieser', 'vasall', 'merkels', 'dann', 'noch'],
#  ['dortmund',
#   'leipzig',
#   '|lbr|',
#   'die',
#   'großmäuligen',
#   'dortmunder',
#   'werden',
#   'von',
#   'leipzig',
#   'hergespielt'],
#  ['der',
#   'untergang',
#   'der',
#   'nation',
#   'wurde',
#   'mit',
#   'der',
#   'grenz',
#   'öffnung',
#   'eingeleitet'],
#  ['der', 'regierenden', 'sind', 'ost', 'bzw', 'kommunisten'],
#  ['die',
#   'cdu',
#   'und',
#   'andere',
#   'parteien',
#   'sind',
#   'ein',
#   'verlogener',
#   'haufen',
#   'politiker',
#   'die',
#   'sich',
#   'die',
#   'taschen',
#   'auf',
#   'steuerzahlers',
#   'kosten',
#   'voll',
#   'machen'],
#  ['ich',
#   'empfinde',
#   'es',
#   'geradezu',
#   'als',
#   'beleidigend',
#   'wenn',
#   'son',
#   'ein',
#   'dreckiges',
#   'stück',
#   'sed-stasi-erbe',
#   'wie',
#   'a.ferkel',
#   'den',
#   'zusammenhalt',
#   'der',
#   'gesellschaft',
#   'predigt'],
#  ['merkel', 'muß', 'weg'],
#  ['neuwahlen',
#   'müßen',
#   'ran',
#   'und',
#   'so',
#   'eine',
#   'elendsfigur',
#   'wie',
#   'schulz',
#   'darf',
#   'hier',
#   'nichts',
#   'zu',
#   'bestellen',
#   'haben'],
#  ['unterkunft', 'normales', 'essen', 'und', 'trinken'],
#  ['sie', 'sind', 'keine', 'sozialtouristen', 'auf', 'unsere', 'kosten'],
#  ['sippenhaftung',
#   'für',
#   'alle',
#   'ausländer',
#   'wer',
#   'länger',
#   'als',
#   'jahr',
#   'keine',
#   '|lbr|',
#   'arbeit',
#   'findet',
#   'muss',
#   'dorthin',
#   'zurück',
#   'wo',
#   'er',
#   'herkommt'],
#  ['ohne', 'jede', '|lbr|', 'ausnahme'],
#  ['wenn',
#   'ich',
#   'die',
#   'gesamten',
#   'deutschfeindlichen',
#   'labereien',
#   'von',
#   'oppermann',
#   'stegner',
#   'usw'],
#  ['hier', 'aufführen', 'würde', 'knallte', 'der', 'server', 'durch'],
#  ['ich',
#   'grüble',
#   'nun',
#   'schon',
#   'monate',
#   'bin',
#   'ich',
#   'ein',
#   'nazi',
#   'oder',
#   'leidet',
#   'angie',
#   'unter',
#   'einer',
#   'narzisstischen',
#   'persönlichkeitsstörung'],
#  ['wenn',
#   'die',
#   'grünen',
#   'stinktiere',
#   'in',
#   'deutschland',
#   'verschwinden',
#   'im',
#   'september',
#   'wird',
#   'deutschlands',
#   'luft',
#   'enorm',
#   'besser',
#   'werden'],
#  ['die',
#   'afd',
#   'will',
#   'einen',
#   'sitz',
#   'in',
#   'der',
#   'holocaust-mahnmal-stiftung'],
#  ['leider',
#   'hat',
#   'die',
#   'luegeafd',
#   'nach',
#   'ihren',
#   'einzug',
#   'in',
#   'den',
#   'bundestag',
#   'ein',
#   'anrecht',
#   'auf',
#   'vertretung',
#   'in',
#   'diversen',
#   'aufsichtsgremien',
#   'auch',
#   'für',
#   'die',
#   'stiftung',
#   '»',
#   'denkmal',
#   'für',
#   'die',
#   'ermordeten',
#   'juden',
#   'europas',
#   '«'],
#  ['antisemitismus', 'noafd', 'fckafd'],
#  ['finaler',
#   'schuss',
#   'wäre',
#   'besser',
#   'dann',
#   'würde',
#   'er',
#   'uns',
#   'kein',
#   'geld',
#   'mehr',
#   'kosten'],
#  ['bald',
#   'haben',
#   'wir',
#   'in',
#   'berlin',
#   'einen',
#   'imam',
#   'als',
#   'bürgermeister.rrg',
#   'haben',
#   'abgewirtschaftet',
#   '.am',
#   'besten',
#   'wäre',
#   'es',
#   'wenn',
#   'wir',
#   'eine',
#   'mauer',
#   'um',
#   'berlin',
#   'ziehen',
#   'um',
#   'das',
#   'pack',
#   'mitsamt',
#   'der',
#   'meck-pomm',
#   'schlampe',
#   'zu',
#   'isolieren',
#   'aber',
#   'bitte',
#   'keine',
#   'care-paketflieger',
#   'schicken'],
#  ['irgendwie',
#   'beruhigend',
#   'das',
#   'es',
#   'woanders',
#   'noch',
#   'schwachsinnigere',
#   'politik',
#   'gibt',
#   'als',
#   'bei',
#   'den',
#   'deutschen'],
#  ['die', 'brd', 'ist', 'eine', 'einzige', 'schande'],
#  ['ihr', 'würstel', 'glaubt', 'an', 'den', 'schaden', 'einer', 'erderwärmung'],
#  ['genau', '|lbr|', 'das', 'gegenteil', 'ist', 'der', 'fall'],
#  ['in',
#   'einer',
#   'nicht',
#   'politicalcorrectness-geistesgestörten',
#   'welt',
#   'würden',
#   'sie',
#   'dem',
#   'invasoren-',
#   'abschaum',
#   'die',
#   'scheiße',
#   'aus',
#   'dem',
#   'hirn',
#   'prügeln'],
#  ['einweisen',
#   'dafür',
#   'gibt',
#   '’',
#   's',
#   'die',
#   'geschlossenen',
#   '|lbr|',
#   'und',
#   'den',
#   'der',
#   'diese',
#   'alte',
#   'hübsch',
#   'findet',
#   'oder',
#   'gar',
#   'erotischebenfalls'],
#  ['|lbr|', 'im', 'land', 'ihresgleichen', 'bestimmt', 'der', 'renner'],
#  ['hilfe',
#   'treibt',
#   'wieder',
#   'ihr',
#   'unwesen',
#   '|lbr|',
#   'da',
#   'sind',
#   'schon',
#   'schmierfinke',
#   'am',
#   'werkeglaubt',
#   'tatsächlich',
#   'noch',
#   'jemand',
#   'diesen',
#   'unfug'],
#  ['n-tv',
#   'murksel',
#   'ein',
#   'profi',
#   'im',
#   'umgang',
#   'mit',
#   'schwierigen',
#   'partnern',
#   'ein',
#   'profi',
#   'wie',
#   'eine',
#   'mecklenburger',
#   'kuh',
#   'die',
#   'rückenschwimmen',
#   'lernt',
#   'meine',
#   'ich'],
#  ['es', 'ist', 'zum', 'kotzen', 'seit', 'tagen'],
#  ['nicht',
#   'täuschen',
#   'lassendas',
#   'sind',
#   'freiwillige',
#   'die',
#   'schnellstmöglich',
#   'dieses',
#   'affenland',
#   'verlassen',
#   'wollten'],
#  ['dem',
#   'kommentar',
#   'entnehme',
#   'ich',
#   'das',
#   'auch',
#   'ihre',
#   'schaukel',
#   'als',
#   'kind',
#   'zu',
#   'nahe',
#   'an',
#   'der',
#   'wand',
#   'gestanden',
#   'hat'],
#  ['wie',
#   'so',
#   'ein',
#   'wackeldackelda',
#   'hatte',
#   'der',
#   'westerwelle',
#   'von',
#   'hinten',
#   'mehr',
#   'esprit',
#   'als',
#   'der',
#   'da',
#   'von',
#   'vorne'],
#  ['bei',
#   'den',
#   'antifa',
#   'terroristen',
#   'fällt',
#   'mir',
#   'nur',
#   'eins',
#   'ein',
#   '„',
#   'der',
#   'dieb',
#   'rannte',
#   'aus',
#   'dem',
#   'kaufhaus',
#   'und',
#   'schrie',
#   'haltet',
#   'den',
#   'dieb',
#   '“'],
#  ['mal',
#   'schauen',
#   'wieviel',
#   'frauen',
#   'dieses',
#   'jahr',
#   'von',
#   'illegalen',
#   'einwanderern',
#   'vergewaltigt',
#   'oder',
#   'belästigt',
#   'werden'],
#  ['|lbr|',
#   'ich',
#   'hoffe',
#   'aufrichtig',
#   'sollte',
#   'es',
#   'dieses',
#   'jahr',
#   'silvester',
#   'wieder',
#   'eskalieren',
#   'dass',
#   'sich',
#   'die',
#   'europäer',
#   'endlich',
#   'erheben',
#   'und',
#   'es',
#   'zum',
#   'aufstand',
#   'kommt',
#   'der',
#   'in',
#   'die',
#   'geschichte',
#   'eingehen',
#   'wird'],
#  ['ditib', 'imame', 'stasi', 'der', 'türkei'],
#  ['|lbr|',
#   'neue',
#   'beweise',
#   'von',
#   'liegen',
#   'den',
#   'medien',
#   'und',
#   'der',
#   'politik',
#   'vor'],
#  ['|lbr|', 'was', 'passiert'],
#  ['|lbr|', 'sofort', 'raus', 'aus', 'd'],
#  ['im',
#   'grunde',
#   'hätte',
#   'dir',
#   'bosbach',
#   'eine',
#   'schallende',
#   'ohrfeige',
#   '|lbr|',
#   'geben',
#   'müssen',
#   'dass',
#   'dir',
#   'der',
#   'fächer',
#   'davongeflogen',
#   'wäre'],
#  ['warum',
#   'lese',
#   'ich',
#   'nix',
#   'über',
#   'abgaswerten',
#   'von',
#   'ausländischen',
#   'autos.werden',
#   'diese',
#   'daten',
#   'uns',
#   'unterschlagen',
#   'kann',
#   'mir',
#   'beim',
#   'besten',
#   'willen',
#   'nicht',
#   'vorstellen',
#   'dass',
#   'nur',
#   'bei',
#   'deutschen',
#   'automotoren',
#   'geschummelt',
#   'wurde'],
#  ['ein',
#   'weiterer',
#   'grund',
#   'den',
#   'ich',
#   'häufig',
#   'erlebe',
#   'ist',
#   'dass',
#   'es',
#   'zu',
#   'wenig',
#   'männer',
#   'richtige',
#   'männer',
#   'im',
#   'schuldienst',
#   'gibt'],
#  ['erfolgreicher',
#   'unterricht',
#   'ist',
#   'vor',
#   'allem',
#   'auch',
#   'identifikation'],
#  ['mädchen', 'lieben', 'mich', 'jungen', 'rebellieren'],
#  ['politiker',
#   'gleichbedeutend',
#   'mit',
#   'berufslügner',
#   'richten',
#   'gerade',
#   'irreparable',
#   'schäden',
#   'für',
#   'unser',
#   'land',
#   'europa',
#   'und',
#   'die',
#   'welt',
#   'an',
#   'und',
#   'mio',
#   'schauen',
#   'zu'],
#  ['die', 'lächerliste', 'person', 'seit', 'es', 'die', 'linken', 'gibt'],
#  ['mit',
#   'einem',
#   'maulkorb',
#   'für',
#   'katja',
#   'wäre',
#   'es',
#   'ruhiger',
#   'um',
#   'die',
#   'linken',
#   'und',
#   'zudem',
#   'wäre',
#   'sie',
#   'dann',
#   'attraktiver'],
#  ['wie',
#   'dämlich',
#   'müssen',
#   'erst',
#   'die',
#   'sesselfurzer',
#   'sein',
#   'wenn',
#   'sie',
#   'den',
#   'unterschied',
#   'von',
#   'und',
#   'jahren',
#   'nicht',
#   'erkennen'],
#  ['habt',
#   'ihr',
#   'immer',
#   'noch',
#   'nicht',
#   'verstanden',
#   'das',
#   'der',
#   'krieg',
#   'gegen',
#   'die',
#   'deutschen',
#   'schon',
#   'begonnen',
#   'hat',
#   'das',
#   'gehört',
#   'zum',
#   'plan',
#   'es',
#   'gibt',
#   'genügend',
#   'hinweise',
#   'das',
#   'diese',
#   'leute',
#   'absichtlich',
#   'bewaffnet',
#   'werden',
#   'um',
#   'solche',
#   'anschläge',
#   'auszuführen'],
#  ['die',
#   'afd',
#   'ihre',
#   'lupenreinen',
#   'faschistoiden',
#   'politiker',
#   'amp',
#   'die',
#   'zahlreichen',
#   'deutschen',
#   'sympathisanten',
#   'werden',
#   'in',
#   'deutschland',
#   'immer',
#   'lauter'],
#  ['ein',
#   'richter',
#   'aus',
#   'dresden',
#   'parteimitglied',
#   'beleidigte',
#   'den',
#   'sohn',
#   'von',
#   'boris',
#   'becker',
#   'als',
#   '»',
#   'halbneger',
#   '«',
#   'amp',
#   'es',
#   'gibt',
#   'sogar',
#   'dafür',
#   'befürworter'],
#  ['noafd', 'fckafd'],
#  ['die',
#   'allerwichtigste',
#   'frage',
#   'ist',
#   'doch',
#   'wie',
#   'entsorge',
#   'ich',
#   'die',
#   'grünen'],
#  ['einfach', 'nicht', 'wählen'],
#  ['die', 'chancen', 'stehen', 'gut'],
#  ['hetze',
#   'der',
#   'öffentlich-',
#   'rechtlichen',
#   'gegen',
#   'trump',
#   'zum',
#   'kotzen',
#   'diese',
#   'verlogenen',
#   'vasallen',
#   'merkels'],
#  ['die',
#   'gesamten',
#   'nullen',
#   'der',
#   'altparteien',
#   'sind',
#   'nur',
#   'noch',
#   'ein',
#   'merkel-wahlzirkus'],
#  ['|lbr|', 'nur', 'posten', 'zählen'],
#  ['deutschlands', 'bürger', 'interessieren', 'denen', 'einen', 'scheiß'],
#  ['eine',
#   'partei',
#   'ohne',
#   'rückgrat',
#   'die',
#   'auf',
#   'das',
#   'votum',
#   'der',
#   'wählerschaft',
#   'schei',
#   't',
#   'und',
#   'sich',
#   'gerade',
#   'selbst',
#   'zerlegt'],
#  ['der', 'wähler', 'vergisst', 'nicht'],
#  ['da', 'sieht', 'man', 'dass', 'schulz', 'x', 'sitzen', 'geblieben', 'ist'],
#  ['er',
#   'irrt',
#   'wenn',
#   'er',
#   'glaubt',
#   '|lbr|',
#   'dass',
#   'die',
#   'flüchtlinge',
#   'nach',
#   'osteuropa',
#   'gehen'],
#  ['sie', 'wollen', '-deutsch'],
#  ['die', 'neue', 'pampers', 'werbung'],
#  ['|lbr|',
#   'nur',
#   'kinder',
#   'von',
#   'invasoren',
#   'die',
#   'man',
#   'uns',
#   'dort',
#   'zeigt'],
#  ['|lbr|', 'ich', 'würde', 'keine', 'pampers', 'kaufen'],
#  ['|lbr|', 'deutsche', 'sollten', 'nur', 'deutsche', 'produkte', 'kaufen'],
#  ['|lbr|', 'und', 'deutsche', 'werbung'],
#  ['pünktlich',
#   'zum',
#   'wahlkampfauftakt',
#   'ermittelt',
#   'der',
#   'brüsseler',
#   'sumpf',
#   'gg'],
#  ['schulz',
#   'brücke',
#   'bauen',
#   'tsd',
#   'kühe',
#   'rüber',
#   'und',
#   'zuscheißen',
#   'dieses',
#   'nest'],
#  ['younower',
#   'zu',
#   'werden',
#   'ist',
#   'der',
#   'finale',
#   'schritt',
# ...
#   'des',
#   'gesunden',
#   'menschenverstands'],
#  ['die',
#   'schulden',
#   'der',
#   'griechen',
#   'soll',
#   'der',
#   'deutsche',
#   'steuerzahler',
#   'übernehmen',
#   '|lbr|',
#   'denkt',
#   'martin',
#   'schulz'],
#  ['jagt', 'ihn', 'davon', 'den', 'schulischen', 'versager'],
#  ['solange',
#   'solch',
#   'polit-pfeifen',
#   'wie',
#   'murksel',
#   'u.',
#   'ihre',
#   'muschpoke',
#   'bestimmen',
#   'was',
#   'rechts',
#   'ist',
#   'läuft',
#   'mir',
#   'das',
#   'am',
#   'ars',
#   'vorbei',
#   'dieses',
#   'verlogene',
#   'pack'],
#  ['nur',
#   'die',
#   'grünen',
#   'reden',
#   'über',
#   'klimakatastrophe',
#   '|lbr|',
#   'wieso',
#   'ist',
#   'diese',
#   'kotzgrüne',
#   'brühe',
#   'nicht',
#   'versickert'],
#  ['|lbr|', 'ihr', 'dummen', 'was', 'habt', 'ihr', 'nur', 'getan'],
#  ['an',
#   'merkel',
#   'gauck',
#   'flintenuschi',
#   'amp',
#   'co',
#   'wer',
#   'krieg',
#   'predigt',
#   'ist',
#   'des',
#   'teufels',
#   'feldprediger',
#   'altes',
#   'deutsches',
#   'sprichwort'],
#  ['es',
#   'ist',
#   'eindeutig',
#   'und',
#   'unmissverständlichunsere',
#   'humanitäre',
#   'haltung',
#   'ist',
#   'falsch',
#   'naiv',
#   'und',
#   'dumm',
#   'vollkommen',
#   'im',
#   'arsch'],
#  ['drachenlord',
#   'wird',
#   'immer',
#   'fetter',
#   'bald',
#   'kann',
#   'man',
#   'die',
#   'sau',
#   'schlachten',
#   'und',
#   'damit',
#   'eine',
#   'ganze',
#   'familie',
#   'eine',
#   'woche',
#   'ernähren'],
#  ['vorauseilender',
#   'gehorsam',
#   'der',
#   'eigentlich',
#   'nichts',
#   'anderes',
#   'ist',
#   'als',
#   'angst',
#   'welche',
#   'aus',
#   'dem',
#   'wissen',
#   'resultiert',
#   'es',
#   'mit',
#   'einem',
#   'unberechenbaren',
#   'bösewicht',
#   'zu',
#   'tun',
#   'zu',
#   'haben'],
#  ['konfrontation',
#   'und',
#   'klare',
#   'kante',
#   'wie',
#   'die',
#   'ösis',
#   'kriegen',
#   'die',
#   'deutschen',
#   'nicht',
#   'mehr',
#   'hin',
#   'kastriertes',
#   'dummvolk'],
#  ['die',
#   'einzigsten',
#   'fähigen',
#   'verbündeten',
#   'deutschlands',
#   'wahren',
#   'finnland',
#   'und',
#   'japan'],
#  ['ach',
#   'ja',
#   'es',
#   'gibt',
#   'schwachköpfe',
#   'wie',
#   'den',
#   'hier',
#   'die',
#   'listen',
#   'unter',
#   'nazifreunde',
#   'weil',
#   'sie',
#   'zu',
#   'beurteilungen',
#   'zu',
#   'dämlich',
#   'sind'],
#  ['für', 'den', 'zensierten', 'scheiss', 'auch', 'noch', 'mehr', 'bezahlen'],
#  ['so',
#   'eine',
#   'unverschämtheit.freie',
#   'senderwahl',
#   'ich',
#   'bezahl',
#   'nur',
#   'die',
#   'sender',
#   'die',
#   'ich',
#   'sehen',
#   'will'],
#  ['hört',
#   'das',
#   'denn',
#   'nie',
#   'auf',
#   'werden',
#   'wir',
#   'dieses',
#   'bis',
#   'zum',
#   'bitteren',
#   'ende',
#   'ertragen',
#   'müssen'],
#  ['|lbr|',
#   'wieso',
#   'schicken',
#   'wir',
#   'diese',
#   'elendige',
#   'subjekte',
#   'nicht',
#   'zu',
#   'ihren',
#   'familien',
#   'zurückwieso',
#   'nicht'],
#  ['|lbr|', 'familienrückführung', 'statt', 'familiennachzug'],
#  ['der',
#   'ober-schul-versager',
#   'schulz',
#   'forder',
#   'einen',
#   'unsinn',
#   'an',
#   'den',
#   'sich',
#   'die',
#   '|lbr|',
#   'ost-staaten',
#   'und',
#   'schon',
#   'gar',
#   'nicht',
#   'die',
#   'invasoren',
#   'halten',
#   'werden'],
#  ['von',
#   'linken',
#   'unterwanderte',
#   'richter',
#   'haben',
#   'einen',
#   'terroristen',
#   'freigesprochen',
#   'wir',
#   'leben',
#   'in',
#   'einer',
#   'bananenrepublik'],
#  ['der',
#   'neue',
#   'präsident',
#   'der',
#   'vereinigten',
#   'staaten',
#   'heißt',
#   'jetzt',
#   'donald',
#   'trump'],
#  ['auch',
#   'wenn',
#   'es',
#   'merkel',
#   'und',
#   'ihren',
#   'vasallen',
#   'nicht',
#   'passt'],
#  ['weidel', 'klasse'],
#  ['hat',
#   'den',
#   'politundjournalienabschaum',
#   'zu',
#   'recht',
#   'abgehakt',
#   'und',
#   'verlassen',
#   'zdf',
#   'lügensender'],
#  ['jetzt', 'wohl', 'bewiesen'],
#  ['sehe',
#   'mir',
#   'den',
#   'film',
#   'an',
#   'da',
#   'ich',
#   'ein',
#   'dickes',
#   'fell',
#   'habe'],
#  ['aber', 'eines', 'ist', 'fakt'],
#  ['wäre',
#   'der',
#   'deutsche',
#   'islamisten',
#   'mein',
#   'kind',
#   'würde',
#   'ich',
#   'ihn',
#   'eigenhändig',
#   'erschlagen'],
#  ['würde',
#   'lachen',
#   'wenn',
#   'er',
#   'wirklich',
#   'mal',
#   'vom',
#   'stock',
#   'ins',
#   'erdgeschoss',
#   'mit',
#   'seinem',
#   'fettarsch',
#   'durchbricht'],
#  ['dann',
#   'würde',
#   'ich',
#   'mich',
#   'doch',
#   'glatt',
#   'auf',
#   'denunziantenniveau',
#   'begebensorry',
#   'das',
#   'kann',
#   'ich',
#   'nicht'],
#  ['zumal',
#   'ich',
#   'fing',
#   'schon',
#   'vor',
#   'monaten',
#   'an',
#   'alles',
#   'linksversifftgute',
#   'wegzublocken',
#   'weil',
#   'ich',
#   'meine',
#   'nerven',
#   'noch',
#   'was',
#   'behalten',
#   'möchte'],
#  ['pure',
#   'verzweiflung',
#   'das',
#   'würde',
#   'sich',
#   'nicht',
#   'einmal',
#   'ein',
#   'nafri',
#   'antun',
#   'nehmen',
#   'eher',
#   'zur',
#   'not',
#   'ne',
#   'ziege'],
#  ['da',
#   'diese',
#   'meldung',
#   'von',
#   'den',
#   'vasallen',
#   'merkels',
#   'kommt',
#   'würde',
#   'ich',
#   'sagen',
#   'das',
#   'diese',
#   'meldung',
#   'der',
#   'tagesschau',
#   'gelogen',
#   'ist'],
#  ['lügenpresse', 'und', 'lügen', 'medien'],
#  ['heute', 'abend', 'bei', 'maischberger'],
#  ['anschlag', 'auf', 'bürgermeister'],
#  ['wie', 'verblödet', 'ist', 'dieses', 'land'],
#  ['anschlag', 'welcher', 'anschlag'],
#  ['ein',
#   'kleiner',
#   'kratzer',
#   'am',
#   'hals',
#   'und',
#   'deutschland',
#   'steht',
#   'kopf'],
#  ['vergewaltigung',
#   'raub',
#   'totschlag',
#   'durch',
#   'asylanten',
#   'kaum',
#   'einer',
#   'spricht',
#   'drüber'],
#  ['die', 'polizei', 'muss', 'mit', 'gummigeschossen', 'bewaffnet', 'werden'],
#  ['auf', 'die', '|lbr|', 'verhüllten', 'birnen', 'halten'],
#  ['dann', 'hauen', 'die', 'chaoten', 'ab'],
#  ['hoffentlich', 'finden', 'sie', 'alle', 'schweine'],
#  ['gut',
#   'so',
#   'nicht',
#   'nachlassen',
#   'wir',
#   'posten',
#   'alles',
#   'was',
#   'wir',
#   'gegen',
#   'merkel',
#   'finden',
#   'bin',
#   'zum',
#   'september'],
#  ['|lbr|', 'ziel', 'muss', 'sein', 'merkel', 'ist', 'weg'],
#  ['über',
#   'diese',
#   'missstände',
#   'bereits',
#   'zig',
#   'x',
#   'berichtetniemanden',
#   'interessiert',
#   'esdie',
#   'wollen',
#   'und',
#   'lieben',
#   'ihre',
#   'asylanten',
#   'samt',
#   'verbrechern'],
#  ['die',
#   'türken',
#   'dringen',
#   'hier',
#   'ein',
#   'und',
#   'wollen',
#   'uns',
#   'ihre',
#   'art',
#   'zu',
#   'leben',
#   'aufzwingen'],
#  ['und',
#   '|lbr|',
#   'beschimpfen',
#   'unsere',
#   'entscheidungsunfähigen',
#   'weicheier',
#   'als',
#   'nazis'],
#  ['die',
#   'werden',
#   'doch',
#   'wieder',
#   'von',
#   'der',
#   'anarchistenfreunliche',
#   'justiz',
#   'freigelassen'],
#  ['die', 'zeit', 'des', 'kuschelns', 'ist', 'vorbei'],
#  ['wir',
#   'haben',
#   'den',
#   'moslems',
#   'und',
#   'islamisten',
#   'offiziell',
#   'den',
#   'krieg',
#   'erklärt'],
#  ['ein', 'neuer', 'kreuzung'],
#  ['sie', 'wollten', 'es', 'nicht', 'anders'],
#  ['jahre',
#   'haben',
#   'wir',
#   'dem',
#   'islam',
#   'zeit',
#   'gegeben',
#   'um',
#   'sich',
#   'zu',
#   'ändern'],
#  ['die',
#   'große',
#   'mehrheit',
#   'der',
#   'de',
#   'möchte',
#   'keine',
#   'kinder',
#   'mit',
#   'kopftuch',
#   'in',
#   'd',
#   'schule',
#   'sehen',
#   'kreuze',
#   'mussten',
#   'weg',
#   'dafür',
#   'sitzen',
#   'kopftuch',
#   'mädchen',
#   'in',
#   'den',
#   'klassen'],
#  ['beifall',
#   'ihr',
#   'niederländer',
#   'schon',
#   'im',
#   '.jahrhundert',
#   'haben',
#   'die',
#   'österreicher',
#   '|lbr|',
#   'die',
#   'türkischen',
#   'invasoren',
#   'davongejagt'],
#  ['weiter', 'so'],
#  ['vielleicht',
#   'sollte',
#   'man',
#   'den',
#   'idioten',
#   'mal',
#   'zeigen',
#   'wo',
#   'der',
#   'frosch',
#   'die',
#   'locken',
#   'hat'],
#  ['amerika', 'bringt', 'innenpolitisch', 'nichts', 'auf', 'die', 'reihe'],
#  ['|lbr|',
#   'alle',
#   'präsidenten',
#   'mußten',
#   'sich',
#   'mit',
#   'kriegen',
#   'und',
#   'morden',
#   'im',
#   'ausland',
#   'profilieren'],
#  ['die',
#   'grünen',
#   'sollten',
#   'auch',
#   'ein',
#   'kopftuch',
#   'tragen',
#   'damit',
#   'man',
#   'ihre',
#   'dummen',
#   'fressen',
#   'nicht',
#   'sehen',
#   'muss'],
#  ['irgendwann',
#   'sind',
#   'die',
#   'kleinen',
#   'scheisser',
#   'auch',
#   'immun',
#   'gegen',
#   'reizgasgegen',
#   'das',
#   'deutsche',
#   'strafrecht',
#   'sind',
#   'sie',
#   'es',
#   'bereits'],
#  ['nee',
#   'man',
#   'nennt',
#   'es',
#   'verstand',
#   'und',
#   'erzieherische',
#   'maßnahne',
#   'in',
#   'die',
#   'richtige',
#   'richtung'],
#  ['aber',
#   'so',
#   'etwas',
#   'verstehen',
#   'linke',
#   'kommies',
#   'und',
#   'merkels',
#   'nicht'],
#  ['wohl', 'zu', 'viel', 'weihwasser', 'gesoffen'],
#  ['von', 'wegen', 'glühender', 'sozialdemokrat'],
#  ['x', 'sitzen', 'geblieben', '|lbr|', 'und', 'ohne', 'schulabschluss'],
#  ['und', 'gigantischer', 'raffzahn'],
#  ['pfui', 'schulz'],
#  ['familienrückführung',
#   'statt',
#   'familiennachzugdas',
#   'wäre',
#   'das',
#   'einzig',
#   'logische',
#   'vernünftige',
#   'und',
#   'anständige'],
#  ['|lbr|', 'alles', 'andere', 'ist', 'menschendiebstahl'],
#  ['der',
#   'tod',
#   'von',
#   'maria',
#   'aus',
#   'freiburg-vom',
#   'flüchtling',
#   'husseink',
#   'brutalst',
#   'ermordert-wurde',
#   'auch',
#   'erst',
#   'durch',
#   'öffentlichen',
#   'druck',
#   'publik',
#   'gemacht'],
#  ['|lbr|',
#   'euer',
#   'problem',
#   'über',
#   'refcrime',
#   'wird',
#   'immer',
#   'noch',
#   'staatsgetreu',
#   'geschwiegen-bei',
#   'deutschen',
#   'tätern',
#   'undifferenziert',
#   'in',
#   'endlosschleife',
#   'berichtet'],
#  ['ihr',
#   'seit',
#   'elende',
#   'schmierfinkeihr',
#   'gehört',
#   'mit',
#   'eurer',
#   'gefakter',
#   'berichterstattung',
#   'tatsächlich',
#   'auf',
#   'den',
#   'müll'],
#  ['jetzt', 'hört', 'auf', 'mit', 'euren', 'sanktionen'],
#  ['sie',
#   'bringen',
#   'nichts',
#   'und',
#   '|lbr|',
#   'schädigen',
#   'ja',
#   '-schädigen-',
#   'die',
#   'eigene',
#   'wirtschaft',
#   'ihr',
#   'nulltipper'],
#  ['gerettete', 'flüchtlinge'],
#  ['nein',
#   'vor',
#   'der',
#   'lybischen',
#   'küste',
#   'abgeholte',
#   '|lbr|',
#   'invasoren',
#   'fluten',
#   'die',
#   'italienischen',
#   'häfen'],
#  ['schluss', 'damit'],
#  ['mein', 'gott'],
#  ['was',
#   'hat',
#   'die',
#   'sed-trulla',
#   'mit',
#   'hilfe',
#   'von',
#   'linken',
#   'u-booten',
#   'aus',
#   'deutschland',
#   'gemacht'],
#  ['das', 'das', 'das', 'durfte'],
#  ['wenn',
#   'europa',
#   'den',
#   'zuzug',
#   'von',
#   'muslimen',
#   'nicht',
#   'stoppt',
#   'ist',
#   'es',
#   'für',
#   'immer',
#   'unwiderruflich',
#   'verloren',
#   '|lbr|',
#   'april'],
#  ['bei',
#   'manchen',
#   'menschen',
#   'scheint',
#   'die',
#   'gehirnwäsche',
#   'durch',
#   'politik',
#   'und',
#   'medien',
#   'hervorragend',
#   'geklappt',
#   'zu',
#   'haben'],
#  ['übrigens',
#   'ich',
#   'holte',
#   'mir',
#   'dieses',
#   'almosen',
#   'nicht',
#   'ab',
#   'ließ',
#   'mir',
#   'meine',
#   'würde',
#   'durch',
#   'birne',
#   'und',
#   'schäußle',
#   'nicht',
#   'nehmen'],
#  ['machtgerangel',
#   'in',
#   'deutschland',
#   'zum',
#   'kotz',
#   'nur',
#   'nicht',
#   'auf',
#   'den',
#   'gedanken',
#   'kommen',
#   'für',
#   'das',
#   'dem',
#   'deutschen',
#   'volke',
#   'zu',
#   'wirken',
#   'willkommen',
#   'im',
#   'schland'],
#  ['trump', 'sprich', 'tramp'],
#  ['wenn',
#   'die',
#   'laien-ministerin',
#   'über',
#   'trump',
#   'labert',
#   '|lbr|',
#   'bleibt',
#   'mir',
#   'nur',
#   'lass',
#   'den',
#   'trampel',
#   'quaken'],
#  ['zu', 'mehr', 'taugt', 'sie', 'nicht'],
#  ['die',
#   'grünen',
#   'idioten',
#   'sind',
#   'untragbar',
#   'für',
#   'unser',
#   'ganzes',
#   'land'],
#  ['und',
#   'schwule',
#   'die',
#   'sich',
#   'selbst',
#   'als',
#   'schwuchtel',
#   'titulieren',
#   'sind',
#   'sowieso',
#   'idioten'],
#  ['uuuuuunnnnd',
#   'da',
#   'isser',
#   'wieder',
#   'der',
#   'hyperintelligente',
#   'differenzierer'],
#  ['war', 'es', 'nicht'],
#  ['es', 'war', 'kein', 'deutscher'],
#  ['es', 'war', 'ein', 'negroider'],
#  ['die',
#   'arme',
#   'frau',
#   'ist',
#   'diesen',
#   'tätlichkeiten',
#   'dank',
#   'solcher',
#   'leute',
#   'wie',
#   'dir',
#   'zum',
#   'opfer',
#   'gefallen'],
#  ['und', 'ja', 'es', 'macht', 'einen', 'unterschied'],
#  ['schlimmer',
#   'sind',
#   'die',
#   'is',
#   'kämpfer',
#   'die',
#   'unkontrolliert',
#   'ins',
#   'land',
#   'kommen'],
#  ['brüder', 'wie', 'heute', 'gezeigt', 'in', 'der', 'ard'],
#  ['nicht', 'nur', 'bio', 'muslems', 'haben', 'da', 'gekämpft'],
#  ['auch', 'deutscher', 'menschen', 'müll'],
#  ['anders', 'kann', 'man', 'solche', 'menschen', 'nicht', 'bezeichnen'],
#  ['ich',
#   'will',
#   'dieses',
#   'arschloch',
#   'nicht',
#   'auf',
#   'freiem',
#   'fuß',
#   'wissenegal',
#   'in',
#   'welchem',
#   'land'],
#  ['ralle',
#   'du',
#   'alter',
#   'mülleimer',
#   'lebst',
#   'ja',
#   'immer',
#   'nochdachte',
#   'das',
#   'zeitliche',
#   'hat',
#   'dich',
#   'gesegnet',
#   '|lbr|',
#   'bist',
#   'halt',
#   'eine',
#   'zähe',
#   'unkrautwurzel'],
#  ['öffentlich-rechtlichen',
#   'nazi',
#   'medien',
#   'und',
#   'merkel',
#   'vasallen',
#   'setzten',
#   'ihre',
#   'hetzkampagne',
#   'gegen',
#   'den',
#   'präsidenten',
#   'der',
#   'vereinigten',
#   'staaten',
#   'fort'],
#  ['meiner',
#   'meinung',
#   'nach',
#   'ist',
#   'frau',
#   'merkel',
#   'eine',
#   'volksverräterin'],
#  ['raub',
#   'mord',
#   'vergewaltigung',
#   'muss',
#   'gesühnt',
#   'werdenegal',
#   'in',
#   'welchem',
#   'landabschiebung',
#   'erst',
#   'nachdem',
#   'diese',
#   'schweine',
#   'ihre',
#   'strafe',
#   'absitzen'],
#  ['eutschfeindliche',
#   'richter',
#   'sind',
#   'von',
#   'merkel',
#   'eingestellt',
#   'und',
#   'stehen',
#   'unter',
#   'ihrem',
#   'befehl'],
#  ['immer',
#   'hasskick',
#   'wenn',
#   'ich',
#   'merkel',
#   'und',
#   'claudia',
#   'roth',
#   'seh'],
#  ['ich', 'nenne', 'solche', 'kaliber', 'bessermenschen'],
#  ['die',
#   'bezeichnen',
#   'dich',
#   'als',
#   'mörder',
#   'wenn',
#   'du',
#   'eine',
#   'fruchtfliege',
#   'killst',
#   'haben',
#   'aber',
#   'selbst',
#   'x-fach',
#   'abgetrieben'],
#  ['|lbr|', 'doppelmoral', '|lbr|', 'narzissmus'],
#  ['aus', 'dem', 'seelenleben', 'von', '-delegierten'],
#  ['a',
#   'wir',
#   'haben',
#   'die',
#   'wahl',
#   'zwischen',
#   'sch',
#   'und',
#   'großer',
#   'sch',
#   'b',
#   'noch',
#   'schlimmer'],
#  ['vielleicht',
#   'sollte',
#   'mal',
#   'jemand',
#   'der',
#   'deutschland',
#   'hassenden',
#   'partei',
#   'b',
#   'die',
#   'grünen',
#   'erklären',
#   'was',
#   'subsidaerer',
#   'schutz',
#   'bedeutet'],
#  ['ich',
#   'führe',
#   'doch',
#   'keine',
#   'menschen',
#   'zusammen',
#   'die',
#   'dieses',
#   'land',
#   'absehbar',
#   'wieder',
#   'verlassen',
#   'müssen'],
#  ['wer', 'soll', 'diesen', 'irrsinn', 'den', 'bezahlen'],
#  ['die', 'grünen', 'etwa'],
#  ['freundchen',
#   'studiere',
#   'die',
#   'weltgeschichte',
#   'mal',
#   'etwas',
#   'genauer'],
#  ['in',
#   'jenen',
#   'ländern',
#   'in',
#   'denen',
#   'vollverschleierung',
#   'nur',
#   'für',
#   'frauen',
#   'pflicht',
#   'ist',
#   'gab'],
#  ['es', 'einst', 'kultur', 'und', 'vielfalt'],
#  ['der', 'islamisierung'],
#  ['|lbr|',
#   'bevor',
#   'du',
#   'jetzt',
#   'meckerst',
#   'geh',
#   'bitte',
#   'frauen',
#   'im',
#   'iran',
#   'vor',
#   'steinigung',
#   'retten'],
#  ['die', 'strotzt', 'vor', 'blödheit'],
#  ['teilt', 'sich', 'mit', 'fatima', 'roth', 'einen', 'er-iq'],
#  ['an',
#   'alle',
#   'nehmt',
#   'mich',
#   'bitte',
#   'aus',
#   'dem',
#   'verschissenen',
#   'thread',
#   'mit',
#   'ao',
#   'raus',
#   'ich',
#   'ertrage',
#   'deren',
#   'geistige',
#   'insolvenz',
#   'nicht'],
#  ['und',
#   'der',
#   'flüchtlingsnachwuchs',
#   'wird',
#   'sich',
#   'in',
#   'die',
#   'immer',
#   'radikaler',
#   'werdenden',
#   'parallelgesellschaften',
#   'integrieren'],
#  ['wohin', 'sonst'],
#  ['wir',
#   'werden',
#   'uns',
#   'in',
#   'dieser',
#   'sache',
#   'wenn',
#   'es',
#   'sein',
#   'muss',
#   'auch',
#   'gegen',
#   'die',
#   'kirche',
#   'stellen',
#   'sollte',
#   'sie',
#   'auf',
#   'den',
#   'gedanken',
#   'kommen',
#   'dies',
#   'zu',
#   'unterstützen'],
#  ['das',
#   'schwert',
#   'des',
#   'mönch',
#   'ritters',
#   'ist',
#   'noch',
#   'immer',
#   'scharf'],
#  ['das', 'sollte', 'selbst', 'die', 'kirche', 'wissen'],
#  ['fdpbisher',
#   'immer',
#   'unbedeutend',
#   'wirklichen',
#   'schaden',
#   'konnten',
#   'sie',
#   'nie',
#   'anrichtenbis',
#   'jetzt'],
#  ['|lbr|',
#   'lindner',
#   '.noch',
#   'eine',
#   'größere',
#   'pfeife',
#   'als',
#   'westerwelle'],
#  ['man',
#   'darf',
#   'nicht',
#   'vergessen',
#   'dass',
#   'die',
#   'öffentlich-rechtlichen',
#   'vasallen',
#   'von',
#   'merkel',
#   'sind',
#   'und',
#   'das',
#   'berichten',
#   'was',
#   'merkel',
#   'vorgibt'],
#  ['die',
#   'wievielte',
#   'generation',
#   'türken',
#   'scheint',
#   'hier',
#   'auf',
#   'der',
#   'straße',
#   'zu',
#   'sein',
#   'ca.die',
#   'te',
#   'das',
#   'wespen',
#   'nest'],
#  ['gottseidank',
#   'lachen',
#   'viele',
#   'deutsche',
#   'schon',
#   'lange',
#   'über',
#   'merkels',
#   'hohe',
#   'kriminelle',
#   'energie'],
#  ['verhindern', 'sie', 'es', 'in', 'fr'],
#  ['was',
#   'zum',
#   'dönerwetter',
#   'hat',
#   'denn',
#   'der',
#   'seehofer',
#   'an',
#   'der',
#   'oberlippe'],
#  ['hat', 'er', 'dreckigen', 'schmuddelsex', 'mit', 'c.roth', 'gehabt'],
#  ['oder', 'tritt', 'das', 'böse', 'zu', 'tage'],
#  ...]

# %%
hatespeech6=""

with open("hatespeech/germeval2018.test.txt") as f:
    content = f.readlines()
    for row in content:
        if "OFFENSE" in row:
            x = row
            x = re.sub(r"http\S+|\.\.+|\S+\/\/+|www\S+|\d+|OFFENSE|OTHER|ABUSE|INSULT|PROFANITY|@[_A-Za-z0-9]+|\|lbr\|","", x)
            x+="."
            x = x.lower()
            x = remove_emoji(x)
            hatespeech6 += " " + x

# %%
hatespeech6 = clean(hatespeech6 )

# %%
hatespeech6
# Out:
# [['asylantenflut', 'bringt', 'eben', 'nur', 'negatives', 'für', 'deutschland'],
#  ['drum', 'asylanenstop', 'und', 'rückführung', 'der', 'mehrzahl'],
#  ['frauen',
#   'zu',
#   'einem',
#   'ja',
#   'zu',
#   'überreden',
#   'ist',
#   'nicht',
#   'selten',
#   'erfolgreich'],
#  ['viele',
#   'frauen',
#   'wollen',
#   'nicht',
#   'als',
#   'zu',
#   'leicht',
#   'zu',
#   'haben',
#   'angesehen',
#   'werden'],
#  ['oder', 'mögen', 'das', 'spiel'],
#  ['oder', 'wollen', 'testen', 'ob', 'er', 'wirklich', 'interessiert', 'ist'],
#  ['ich', 'weiß', 'halt', 'wie', 'man', 'frauen', 'zum', 'miauen', 'bringt'],
#  ['liebe', 'freunde', 'gauck', 'das', 'symbol', 'des', 'sklaventums'],
#  ['wen',
#   'interessiert',
#   'denn',
#   'die',
#   'meinung',
#   'des',
#   'außenminister',
#   'der',
#   'in',
#   'meinen',
#   'augen',
#   'strunzdumm',
#   'ist',
#   'spd'],
#  ['|lbr|',
#   'laßt',
#   'doch',
#   'endlich',
#   'mal',
#   'das',
#   'wort',
#   'nazi',
#   'nationalsozialist',
#   'als',
#   'schimpfwort',
#   'aus',
#   'dem',
#   'spiel.verdammt',
#   'noch',
#   'mal'],
#  ['besser',
#   'einen',
#   'schwarz',
#   'arbeiten',
#   'zu',
#   'lassen',
#   'als',
#   'pädophile',
#   'bastarde',
#   'in',
#   'der',
#   'partei',
#   'zu',
#   'dulden',
#   'wie',
#   'es',
#   'in',
#   'der',
#   'groko',
#   'schon',
#   'mal',
#   'vorkommt'],
#  ['von', 'mir', 'aus', 'könnt', 'ihr', 'jämmerlich', 'verrecken'],
#  ['zum', 'mond'],
#  ['da',
#   'sind',
#   'doch',
#   'auf',
#   'der',
#   'kehrseite',
#   'schon',
#   'die',
#   'reichsdeutschen',
#   'mit',
#   'ihren',
#   'flugscheiben',
#   '-ufos'],
#  ['an', 'der', 'universität', 'von', 'queeristan'],
#  ['ich', 'scheisse', 'auf', 'die', 'spd'],
#  ['|lbr|', 'scheinheilgste', 'partei', 'deutschlands'],
#  ['die',
#   'größte',
#   'bedrohung',
#   'des',
#   'friedens',
#   'geht',
#   'von',
#   'usa',
#   'und',
#   'ihren',
#   'herren',
#   'in',
#   'israel',
#   'aus'],
#  ['|lbr|', 'nur', 'viel', 'wind', 'um', 'nichts'],
#  ['asylwahnsinn', 'geht', 'weiter'],
#  ['der',
#   'dummschwätzer',
#   'herr',
#   'dobrindt',
#   'gehört',
#   'nicht',
#   'in',
#   'die',
#   'bundesregierung',
#   'sondern',
#   'ins',
#   'irrenhaus',
#   'cdu',
#   'csu'],
#  ['das', 'kommt', 'davon', 'wenn', 'die', 'gesellschaft', 'verweiblicht'],
#  ['kaffeeklatsch', 'wird', 'politik'],
#  ['fußball',
#   'werde',
#   'ich',
#   'mit',
#   'sicherheit',
#   'nicht',
#   'auf',
#   'dem',
#   'asozialen',
#   'hartz',
#   'iv',
#   'sender',
#   'rtl',
#   'schauen'],
#  ['klar', 'ungleiche', 'rechte', 'sind', 'für', 'dich', 'gerecht'],
#  ['du', 'wirst', 'nicht', 'sympathischer'],
#  ['aber', 'das', 'erwarte', 'ich', 'von', 'einer', 'muslima', 'auch', 'nicht'],
#  ['logik',
#   '|lbr|',
#   'es',
#   'gibt',
#   'dreiundzwölfzig',
#   'geschlechter',
#   'und',
#   'der',
#   'islam',
#   'ist',
#   'ne',
#   'ethnie'],
#  ['|lbr|', 'drum', 'eben'],
#  ['nazi', 'na', 'und'],
#  ['wäre', 'angemessene', 'reaktion'],
#  ['ich', 'hatte', 'nie', 'was', 'gegen', 'das', 'ns-regime'],
#  ['aber', 'gegen', 'die', 'siegermächte'],
#  ['weil',
#   'barbarische',
#   'märchen',
#   'an',
#   'schulen',
#   'nur',
#   'im',
#   'literatur-unterricht',
#   'was',
#   'zu',
#   'suchen',
#   'haben'],
#  ['mutti',
#   'merkel',
#   'hat',
#   'röttgen',
#   'nunmehr',
#   'erlaubt',
#   'wieder',
#   'zu',
#   'sprechen',
#   'cdu'],
#  ['ist', 'ja', 'auch', 'verständlich'],
#  ['was',
#   'soll',
#   'man',
#   'mit',
#   'nem',
#   'mitarbeiter',
#   'der',
#   'demnächst',
#   'wegen',
#   'babypause',
#   'ausfällt'],
#  ['ich',
#   'weiß',
#   'ja',
#   'nicht',
#   'ob',
#   'deine',
#   'schwester',
#   'eine',
#   'minderjährige',
#   'töchter',
#   'hat',
#   'auf',
#   'die',
#   'du',
#   'scharf',
#   'bist'],
#  ['ein',
#   'tolles',
#   'produkt',
#   'in',
#   'alter',
#   'sed',
#   'tradition',
#   'merkel',
#   'und',
#   'ihre',
#   'satrapen',
#   'haben',
#   'diesen',
#   'propagandafilm',
#   'abgenickt'],
#  ['da',
#   'erkennt',
#   'man',
#   'mit',
#   'was',
#   'für',
#   'jämmerlichen',
#   'deppen',
#   'die',
#   'abgefuckte',
#   'spd',
#   'aus',
#   'machtgeilheit',
#   'jahre',
#   'das',
#   'volk',
#   'verraten',
#   'und',
#   'verkauft',
#   'hat'],
#  ['hoffentlich',
#   'kann',
#   'der',
#   'pfaffe',
#   'noch',
#   'lange',
#   'weiter',
#   'pilgern'],
#  ['ich',
#   'persönlich',
#   'scheisse',
#   'auf',
#   'die',
#   'grüne',
#   'kinderfickerpartei'],
#  ['ich',
#   'würde',
#   'sagen',
#   'sie',
#   'hat',
#   'psychische',
#   'probleme',
#   'und',
#   'benötigt',
#   'professionelle',
#   'hilfe'],
#  ['und', 'deine', 'sind', 'extrem', 'doof'],
#  ['frau',
#   'böttinger',
#   'meine',
#   'meinung',
#   'dazu',
#   'ist',
#   'sie',
#   'sollten',
#   'uns',
#   'mit',
#   'ihrem',
#   'pferdegebiss',
#   'nicht',
#   'weiter',
#   'belästigen',
#   'wdr'],
#  ['wie', 'blöd', 'können', 'die', 'niedersachsen', 'doch', 'sein'],
#  ['tauber',
#   'ich',
#   'würde',
#   'sagen',
#   'die',
#   'tatsächlichen',
#   'arschlöcher',
#   'sitzen',
#   'in',
#   'der',
#   'regierung',
#   '|lbr|',
#   'so',
#   'ist',
#   'es'],
#  ['wo',
#   'bleibt',
#   'der',
#   'private',
#   'wachdienst',
#   'der',
#   'die',
#   'in',
#   'den',
#   'arsch',
#   'tritt'],
#  ['friedman', 'raus', 'ab', 'ins', 'gelobte', 'land'],
#  ['|lbr|', 'christen', 'sind', 'tierfreundlich'],
#  ['asiaten', 'nicht'],
#  ['außer', 'buddisten'],
#  ['das',
#   'hätte',
#   'ich',
#   'der',
#   'fdp',
#   'nicht',
#   'zugetraut',
#   'alle',
#   'achtung'],
#  ['nur', 'die', 'grünen', 'kriechen', 'allen', 'in', 'den', 'arsch'],
#  ['jetzt',
#   'wieder',
#   'linksgrüne-propaganda',
#   'von',
#   'linksfaschisten',
#   'böhmermann',
#   'laferlichterluther'],
#  ['terror', 'wird', 'durch', 'gegenterror', 'beantwortet', 'werden'],
#  ['ach', 'das', 'ist', 'doch', 'ein', 'sturm', 'im', 'wasserglas'],
#  ['spahn', 'ist', 'nun', 'mal', 'ne', 'rechte', 'tucke'],
#  ['gut',
#   'sofort',
#   'alles',
#   'geld',
#   'stoppen',
#   'beziehungen',
#   'abbrechen',
#   'und',
#   'alle',
#   'griechen',
#   'aus',
#   'deutschland',
#   'raus',
#   'keinerlei',
#   'renten-und',
#   'sozialleistungen'],
#  ['anders', 'gesagt', 'ihr', 'seid', 'rassisten'],
#  ['so', 'siehst', 'aus'],
#  ['kuscheljutiz', 'für', 'asylantenpack'],
#  ['jeder',
#   'der',
#   'mit',
#   'gabriel',
#   'und',
#   'steinmeier',
#   'paktiert',
#   'hat',
#   'bei',
#   'mir',
#   'verschissen'],
#  ['spd', 'schmarotzer', 'pädophile', 'und', 'denunzianten'],
#  ['geht', "'s", 'noch'],
#  ['ihr', 'habt', 'doch', 'einen', 'an', 'der', 'waffel'],
#  ['du', 'wirst', 'heute', 'schon', 'ausgelacht'],
#  ['die',
#   'eliten',
#   'wollen',
#   'deutschland',
#   'ausrotten',
#   'kapieren',
#   'zu',
#   'wenig'],
#  ['|lbr|', 'genau', 'traurige', 'wahrheit'],
#  ['ausrottung', 'ohne', 'kaum', 'widerstand'],
#  ['herr', 'friedman', 'und', 'konsorten'],
#  ['es',
#   'wird',
#   'der',
#   'tag',
#   'der',
#   'rache',
#   'der',
#   'freien',
#   'völker',
#   'kommen'],
#  ['der', 'abschaum', 'regiert', 'die', 'ostküste', 'jubelt'],
#  ['wo',
#   'ist',
#   'dann',
#   'dein',
#   'problem',
#   'damit',
#   'wenn',
#   'jemand',
#   'den',
#   'islam',
#   'ablehnt'],
#  ['die',
#   'zersetzung',
#   'die',
#   'vernichtung',
#   'der',
#   'kultur',
#   'der',
#   'abschaum',
#   'hat',
#   'immer',
#   'nur',
#   'einen',
#   'ursprung'],
#  ['kinder',
#   'schänden',
#   'und',
#   'das',
#   'volk',
#   'verraten',
#   'das',
#   'ist',
#   'die',
#   'ideologie',
#   'der',
#   'sozis',
#   'und',
#   'ihrer',
#   'grünen',
#   'helfer'],
#  ['und',
#   'was',
#   'bekommt',
#   'ein',
#   'asylant',
#   'der',
#   'deutsche',
#   'umzubringen',
#   'versucht'],
#  ['ja', 'furchtbar'],
#  ['das',
#   'nächste',
#   'mal',
#   'sollte',
#   'man',
#   'sie',
#   'alt',
#   'und',
#   'hässlich',
#   'nennen'],
#  ['mannheim', 'multikulti', 'versiffte', 'stadt'],
#  ['klein', 'istambul', 'und', 'rumänen/', 'bulgaren'],
#  ['weltoffenheit', 'ist', 'im', 'auswärtigen', 'amt', 'ein', 'fremdwort'],
#  ['deutsche',
#   'botschaft',
#   'in',
#   'manila',
#   'strotzt',
#   'vor',
#   'menschenverachtung'],
#  ['ich', 'kann', 'mit', 'schlampen', 'umgehen'],
#  ['die', 'froschfresser', 'haben', 'nichts', 'gelernt'],
#  ['ihr', 'untergang', 'ist', 'selbstverschuldet'],
#  ['mich',
#   'interessiert',
#   "'s",
#   'weil',
#   'ich',
#   'es',
#   'gut',
#   'finde',
#   'dass',
#   'es',
#   'inmitten',
#   'islamischen',
#   'barbarei',
#   'wenigstens',
#   'eine',
#   'demokratie',
#   'gibt',
#   'in',
#   'der',
#   'ich',
#   'schwänze',
#   'lutschen',
#   'kann',
#   'ohne',
#   'ins',
#   'gefängnis',
#   'zu',
#   'kommen'],
#  ['ich', 'spritz', 'gleich', 'ab', 'so', 'geil', 'machst', 'du', 'mich'],
#  ['diese',
#   'scheiß',
#   'islamisten',
#   'gejaule',
#   'will',
#   'doch',
#   'kein',
#   'mensch',
#   'hören',
#   'wdr'],
#  ['ekelhaft',
#   'claudia',
#   'roth',
#   'wieder',
#   'im',
#   'fernsehen',
#   'sehen',
#   'zu',
#   'müssen',
#   'bundestag'],
#  ['wenn',
#   'du',
#   'arsch',
#   'geficktes',
#   'elitäre',
#   'schwein',
#   'den',
#   'mut',
#   'und',
#   'eier',
#   'hättest',
#   'dann',
#   'sag',
#   'wirklich',
#   'wie',
#   'du',
#   'heisst'],
#  ['oh', 'entschuldigung'],
#  ['|lbr|', 'so', 'ein', 'schwein', 'sitzt', 'noch', 'da', 'oben'],
#  ['pfui', 'teufel'],
#  ['ich',
#   'wähle',
#   'afd',
#   'weil',
#   'die',
#   'mich',
#   'noch',
#   'nicht',
#   'beschissen',
#   'haben'],
#  ['die',
#   'anderen',
#   'parteien',
#   'hingegen',
#   'schon',
#   'insbesondere',
#   'das',
#   'pack',
#   'aus',
#   'der',
#   'groko'],
#  ['ein',
#   'wirklicher',
#   'eklat',
#   'ist',
#   'dass',
#   'sich',
#   'das',
#   'ach',
#   'so',
#   'soziale',
#   'pack',
#   'der',
#   'spd',
#   'im',
#   'auswärtigen',
#   'amt',
#   'menschenverachtend',
#   'verhält',
#   'und',
#   'willkürlich',
#   'handelt'],
#  ['ist', 'eine', 'körperverletzung'],
#  ['sorry', 'diese', 'frau', 'ist', 'einfach', 'dumm'],
#  ['in',
#   'meinen',
#   'augen',
#   'ist',
#   'andrea',
#   'nahles',
#   'strunzdumm',
#   'und',
#   'hat',
#   'einen',
#   'riesen',
#   'nagel',
#   'in',
#   'der',
#   'kappe',
#   'nur',
#   'sie',
#   'merkt',
#   'es',
#   'nicht',
#   'spd'],
#  ['die',
#   'okkupanten',
#   'wollen',
#   'den',
#   'deutschen',
#   'und',
#   'damit',
#   'den',
#   'europäischen',
#   'geist',
#   'vernichten'],
#  ['ich',
#   'finde',
#   'claudia',
#   'roth',
#   'auch',
#   'ekelhaft',
#   'und',
#   'ich',
#   'gehe',
#   'noch',
#   'viel',
#   'weiter'],
#  ['man', 'sollte', 'sie', 'rückstandslos', 'entsorgen'],
#  ['natürlich', 'nur', 'für', 'bolschewisten', 'und', 'schwule'],
#  ['auch',
#   'heute',
#   'darf',
#   'schwerverbrecher',
#   'uli',
#   'hoeneß',
#   'im',
#   'spiel',
#   'gegen',
#   'fc',
#   'bayern',
#   'natürlich',
#   'nicht',
#   'fehlen',
#   'ard'],
#  ['warum',
#   'lädt',
#   'man',
#   'eine',
#   'derart',
#   'strunzdumme',
#   'frau',
#   'demirkan',
#   'bei',
#   'maischberger',
#   'ein',
#   'ard'],
#  ['wegen',
#   'wem',
#   'genau',
#   'müssen',
#   'jüdische',
#   'schulen',
#   'mit',
#   'soldaten',
#   'beschützt',
#   'werden',
#   'normal',
#   'polizei',
#   'reicht',
#   'nicht',
#   'mehr'],
#  ['das',
#   'privileg',
#   'der',
#   'frauen',
#   'zeigt',
#   'sich',
#   'bereits',
#   'an',
#   'ihrer',
#   'kleidung'],
#  ['während',
#   'männlichen',
#   'kleidung',
#   'auf',
#   'effizienz',
#   'und',
#   'bestmögliche',
#   'ausnutzung',
#   'der',
#   'arbeitskraft',
#   'ausgelegt',
#   'wird',
#   'leisten',
#   'sich',
#   'frauen',
#   'extravagante',
#   'maskeraden'],
#  ['|lbr|',
#   'ich',
#   'suche',
#   'dazu',
#   'noch',
#   'mal',
#   'das',
#   'zitat',
#   'von',
#   'vilar',
#   'raus'],
#  ['die', 'größten', 'volksverräter', 'sind', 'sozialdemokraten'],
#  ['erst',
#   'twittert',
#   'bettina',
#   'kudla',
#   'ihre',
#   'kritik',
#   'an',
#   'der',
#   'asylpolitik',
#   'merkels',
#   'mit',
#   'd',
#   'ns-begriff',
#   '„',
#   'umvolkung',
#   '“',
#   'jetzt',
#   'fordert',
#   'h.',
#   'winkler',
#   'kolationen',
#   'mit',
#   'afd'],
#  ['geschundenen', 'von', 'jahre', 'ddr', 'und', 'jahren', 'bundesrepublik'],
#  ['wo', 'ist', 'kubicki', 'heute'],
#  ['hat',
#   'ihn',
#   'berlin',
#   'schon',
#   'zum',
#   'trinker',
#   'und',
#   'zum',
#   'hurenbock',
#   'gemacht'],
#  ['diese',
#   'asiatische',
#   'horde',
#   'und',
#   'ihre',
#   'ostküsstenhelfer',
#   'muss',
#   'endlich',
#   'in',
#   'die',
#   'schranken',
#   'gewiesen',
#   'werden'],
#  ['ja',
#   'das',
#   'ist',
#   'das',
#   's.rechtschreibkorrekturverfälschungsmistprogramm'],
#  ['wäre', 'hitler', 'an', 'der', 'macht', 'wäre', 'gauck', 'ss', 'offizier'],
#  ['die', 'grössten', 'verbrecher', 'am', 'volk', 'spd'],
#  ['|lbr|', 'der', 'dummbatz', 'hat', 'doch', 'den', 'arsch', 'offen'],
#  ['ich',
#   'würde',
#   'die',
#   'asylanten',
#   'in',
#   'den',
#   'arsch',
#   'treten',
#   'wenn',
#   'die',
#   'meine',
#   'tür',
#   'betreten'],
#  ['mrtrump',
#   'sie',
#   'waren',
#   'mir',
#   'mal',
#   'sympathisch',
#   'mit',
#   'ihrer',
#   'aussage',
#   'das',
#   'sie',
#   'die',
#   'merkel',
#   'loben',
#   'da',
#   'haben',
#   'sie',
#   'jetzt',
#   'bei',
#   'mir',
#   'verschissen'],
#  ['facebook',
#   'ist',
#   'verkommen',
#   'zu',
#   'einem',
#   'medium',
#   'dass',
#   'nur',
#   'noch',
#   'die',
#   'darmbewohner',
#   'der',
#   'abgefuckten',
#   'altparteien',
#   'und',
#   'die',
#   'sogenannte',
#   'religion',
#   'der',
#   'steinzeitzombies',
#   'vertritt'],
#  ['ich',
#   'bemerke',
#   'in',
#   'unseren',
#   'medien',
#   'eine',
#   'strategie',
#   'die',
#   'fdp',
#   'gleich',
#   'der',
#   'afd',
#   'zum',
#   'abschuss',
#   'freizugeben'],
#  ['frauen',
#   'werden',
#   'für',
#   'gleiche',
#   'arbeit',
#   'nicht',
#   'niedriger',
#   'bezahlt'],
#  ['|lbr|', 'wie', 'bereits', 'erwähnt', 'leisten', 'sie', 'weniger', 'arbeit'],
#  ['liebe',
#   'freunde',
#   'viel',
#   'zu',
#   'lange',
#   'geschwiegen',
#   'was',
#   'hat',
#   'diese',
#   'person',
#   'verbrochen'],
#  ['die', 'rumänischen', 'banden', 'besetzen', 'unser', 'land'],
#  ['solidarität', 'mit', 'ďen', 'palästinensern'],
#  ['tŕotzt', 'dem', 'terror', 'zions'],
#  ['als', 'deutscher', 'staatsbürger', 'zählt', 'deine', 'meinung', 'nicht'],
#  ['söder', 'sollte', 'verteidigungsminister', 'werden'],
#  ['entsorgt', 'von', 'der', 'leyen'],
#  ['glaubte',
#   'du',
#   'echt',
#   'eine',
#   'frau',
#   'mit',
#   'befriedigendem',
#   'sexleben',
#   'rennt',
#   'durch',
#   'die',
#   'welt',
#   'und',
#   'sieht',
#   'überall',
#   'böse',
#   'männer',
#   'und',
#   'sexuelle',
#   'gewalt'],
#  ['die',
#   'rhetorik',
#   'der',
#   'afd',
#   'redner',
#   'erinnert',
#   'mich',
#   'an',
#   'die',
#   'propaganda',
#   'der',
#   'nazis',
#   'zwischen'],
#  ['chemtrail', 'özdemir', 'übt', 'schon', 'mal', 'böse', 'kucken', 'lanz'],
#  ['hi', 'erkundige', 'dich', 'mal', 'über', 'den', 'hooton', 'plan'],
#  ['dann', 'wirst', 'du', 'verstehen', 'was', 'hier', 'gerade', 'passiert'],
#  ['solange',
#   'es',
#   'frauen',
#   'gibt',
#   'die',
#   'bereit',
#   'sind',
#   'sich',
#   'hochzuschlafen',
#   'solange',
#   'wird',
#   'es',
#   'auch',
#   'männer',
#   'geben',
#   'die',
#   'das',
#   'für',
#   'sich',
#   'ausnutzen'],
#  ['wer', 'steckt', 'dahinter'],
#  ['merkel',
#   'und',
#   'ihr',
#   'aussatz',
#   'mit',
#   'friedmann',
#   'an',
#   'der',
#   'spitze'],
#  ['na', 'ja', 'du', 'als', 'moslem', 'musst', 'juden', 'ja', 'hassen'],
#  ['steht', 'ja', 'in', 'deinem', 'heiligen', 'buch', 'drin'],
#  ['spd', 'schmarotzer', 'pädophile', 'und', 'dummköpfe'],
#  ['transgender', 'ist', 'sie'],
#  ['dieses', 'miststück'],
#  ['|lbr|',
#   'klar',
#   'für',
#   'doch.alles',
#   'kostenlos',
#   'für',
#   'ausländerpfui',
#   'teufel'],
#  ['wo', 'sind', 'wir', 'bloß', 'hingekommen', 'in', 'd'],
#  ['wie',
#   'kann',
#   'man',
#   'nur',
#   'derart',
#   'strunzdumme',
#   'moderatoren',
#   'wie',
#   'bei',
#   'taff',
#   'auf',
#   'prosieben',
#   'beschäftigen'],
#  ['wie',
#   'kann',
#   'eine',
#   'universität',
#   'ihre',
#   'reputation',
#   'auf',
#   'einen',
#   'schlag',
#   'um',
#   'prozent',
#   'steigern'],
#  ['|lbr|', 'simpel', 'den', 'gender-studies-lehrstuhl', 'auflösen'],
#  ['dürfen', 'jungen', 'auch', 'werden', 'was', 'sie', 'wollen'],
#  ['ichbinantifa',
#   'weil',
#   'ich',
#   'gerne',
#   'gewalt',
#   'gegen',
#   'andersdenkende',
#   'ausübe',
#   'und',
#   'mir',
#   'dabei',
#   'nicht',
#   'wie',
#   'ein',
#   'faschist',
#   'vorkommen',
#   'will'],
#  ['frau',
#   'neumann',
#   'im',
#   'fußball',
#   'und',
#   'ich',
#   'schalte',
#   'sofort',
#   'ab',
#   'auf',
#   'wiedersehen',
#   'zdf'],
#  ['kölnertreff',
#   'ekelhafte',
#   'sendung',
#   'moderatorin',
#   'mit',
#   'pferdegebiss',
#   'und',
#   'schwuchtel',
#   'aus',
#   'österreich',
#   'wdr'],
#  ['ich',
#   'halte',
#   'niemand',
#   'für',
#   'normal',
#   'der',
#   'einer',
#   'religion',
#   'angehört'],
#  ['aber', 'das', 'ist', 'eine', 'andere', 'geschichte'],
#  ['der', 'steinmaier', 'redet', 'nur', 'scheisse'],
#  ['gerade', 'auf', 'ntv'],
#  ['was',
#   'mich',
#   'an',
#   'linken',
#   'am',
#   'meisten',
#   'nervt',
#   'ist',
#   'deren',
#   'moralisierende',
#   'dämlichkeit'],
#  ['|lbr|',
#   'wissen',
#   'tun',
#   'sie',
#   'nicht',
#   'viel',
#   'aber',
#   'die',
#   'moral',
#   'haben',
#   'sie',
#   'gepachtet'],
#  ['wie',
#   'schleimig',
#   'und',
#   'rückgratlos',
#   'ist',
#   'werden',
#   'wir',
#   'in',
#   'den',
#   'nächsten',
#   'tagen',
#   'sehen'],
#  ['nie', 'wieder', 'spd'],
#  ['maas-dein', 'bolschewismus', 'ist', 'am', 'ende'],
#  ['überhaupt',
#   'keine',
#   'afrikaner',
#   'nach',
#   'd.',
#   'wie',
#   'vor',
#   'wo',
#   'die',
#   'd',
#   'noch',
#   'd',
#   'war'],
#  ['ach',
#   'du',
#   'scheisse',
#   'wer',
#   'mit',
#   'nahles',
#   'in',
#   'die',
#   'zukunft',
#   'geht',
#   'kann',
#   'auch',
#   'gleich',
#   'den',
#   'stegner',
#   'dazu',
#   'packen'],
#  ['du', 'küsst', 'bestimmt', 'auch', 'jeden'],
#  ['egal', 'ob', 'er', 'sich', 'die', 'zähne', 'putzt', 'oder', 'nicht'],
#  ['da',
#   'zeigt',
#   'sich',
#   'leider',
#   'mal',
#   'wieder',
#   'dass',
#   'uns',
#   'der',
#   'fall',
#   'der',
#   'mauer',
#   'nicht',
#   'nur',
#   'viel',
#   'gutes',
#   'gebracht',
#   'hat',
#   'sonder',
#   'eben',
#   'auch'],
#  ['die',
#   'braucht',
#   'ihren',
#   'hass',
#   'auf',
#   'deutschland',
#   '-sonst',
#   'ist',
#   'die',
#   'weg'],
#  ['weibliche',
#   'sexualität',
#   'wird',
#   'unmittelbar',
#   'getriggert',
#   'durch',
#   'dominanz',
#   'und',
#   'stärke',
#   'des',
#   'mannes'],
#  ['vermischte', 'und', 'vermanschte', 'ziel', 'der', 'd', 'vernichter'],
#  ['du', 'bist', 'jung', 'und', 'schön'],
#  ['hallo',
#   'frau',
#   'merkel',
#   'wie',
#   'lebt',
#   'es',
#   'sich',
#   'eigentlich',
#   'mit',
#   'so',
#   'einer',
#   'großen',
#   'schuld',
#   'und',
#   'all',
#   'dem',
#   'blut',
#   'an',
#   'den',
#   'händen'],
#  ['|lbr|', 'das', 'blut', 'klebt'],
#  ['ja', 'mir', 'geht', 'es', 'zu', 'gut'],
#  ['und',
#   'ich',
#   'möchte',
#   'nicht',
#   'dass',
#   'sich',
#   'das',
#   'durch',
#   'die',
#   'einwanderung',
#   'islamischer',
#   'praktiken',
#   'und',
#   'lehren',
#   'ändert'],
#  ['was', 'für', 'politiker'],
#  ['ich',
#   'sehe',
#   'immer',
#   'nur',
#   'hinterfotzige',
#   'heuchler',
#   'und',
#   'schmarotzer'],
#  ['es', 'gibt', 'kein', 'palästina'],
#  ['claudia', 'roth', 'ist', 'eine', 'schande', 'für', 'deutschland'],
#  ['was', 'für', 'bullshit'],
#  ['wenn',
#   'er',
#   'mit',
#   'wissen',
#   'und',
#   'unterstützung',
#   'von',
#   'merkel',
#   'gehandelt',
#   'hat',
#   'dann',
#   'ist',
#   'das',
#   'ein',
#   'skandal',
#   'der',
#   'gesamten',
#   'bundesregierung'],
#  ['zion', 'wird', 'sein', 'nürnberg', 'jetzt', 'erleben'],
#  ['der',
#   'ströbele',
#   'ist',
#   'eben',
#   'immer',
#   'noch',
#   'ein',
#   'terroristen',
#   'schützer'],
#  ['wie',
#   'überall',
#   'sind',
#   'frauen',
#   'zu',
#   'bequem',
#   'oder',
#   'zu',
#   'untalentiert'],
#  ['was',
#   'fährt',
#   'jetzt',
#   'wieder',
#   'an',
#   'die',
#   'wand',
#   'nachdem',
#   'er',
#   'schon',
#   'den',
#   'nürburgring',
#   'versenkt',
#   'hat'],
#  ['in',
#   'meinen',
#   'augen',
#   'ist',
#   'kurt',
#   'beck',
#   'eine',
#   'absolute',
#   'nullnummer',
#   'und',
#   'vollniete',
#   'spd'],
#  ['|lbr|', 'raus', 'raus', 'raus', 'mit', 'dem', 'ganzen', 'niggergesindel'],
#  ['freie',
#   'völker',
#   'der',
#   'welt',
#   'steht',
#   'endlich',
#   'auf',
#   'werdet',
#   'wach'],
#  ['usa-', 'die', 'größte', 'völkermordzentrale'],
#  ['kunst', 'muss', 'provozieren', '|lbr|', 'äh', 'nein'],
#  ['aber',
#   'wenn',
#   'man',
#   'kein',
#   'talent',
#   'hat',
#   'dann',
#   'bleibt',
#   'einem',
#   'nur',
#   'die',
#   'provokation'],
#  ['das',
#   'ist',
#   'man',
#   'ja',
#   'schon',
#   'ein',
#   'ganz',
#   'schlimmer',
#   'nazi',
#   'wenn',
#   'man',
#   'jemand',
#   'jagen',
#   'oder',
#   'entsorgen',
#   'will'],
#  ['aber', 'die', 'linksgedrehten', 'dürfen', 'hinrichten'],
#  ['und',
#   'in',
#   'hessen',
#   'die',
#   'verräter',
#   'der',
#   'spd',
#   'die',
#   'kommunisten',
#   'der',
#   'grünen',
#   'und',
#   'die',
#   'linke',
#   'führen',
#   'gespräche',
#   '.aha'],
#  ['das',
#   'von',
#   'der',
#   'spd',
#   'verseuchte',
#   'und',
#   'geleitete',
#   'auswärtige',
#   'amt',
#   'und',
#   'seine',
#   'deutsche',
#   'botschaft',
#   'in',
#   'manila',
#   'strotzt',
#   'vor',
#   'menschenverachtung'],
#  ['der', 'is', 'sind', 'muslime'],
#  ['angeführt', 'von', 'einem', 'korangelehrten'],
#  ['nichts',
#   'was',
#   'der',
#   'is',
#   'tut',
#   'ist',
#   'gegen',
#   'koran',
#   'oder',
#   'hadithe'],
#  ['in',
#   'ihrem',
#   'heimatland',
#   'scheißen',
#   'sich',
#   'die',
#   'flüchtlinge',
#   'in',
#   'die',
#   'hose',
#   'und',
#   'hier',
#   'in',
#   'deutschland',
#   'lassen',
#   'sie',
#   'die',
#   'sau',
#   'raus',
#   'wdr'],
#  ['zur', 'hölle', 'mit', 'den', 'koreanern'],
#  ['pofalla', 'und', 'ole', 'von', 'beust', 'seid', 'ihr', 'beide', 'schwul'],
#  ['oder', 'hat', 'die', 'der', 'name', 'geil', 'gemacht'],
#  ['po', 'falla', 'lanz', 'illner'],
#  ['berlin',
#   'ist',
#   'wie',
#   'eine',
#   'gealterte',
#   'hure',
#   'aus',
#   'deren',
#   'schoß',
#   'der',
#   'äther',
#   'der',
#   'fäulnis',
#   'wabert'],
#  ['unwort',
#   'des',
#   'jahrhunderts',
#   'stammwähler',
#   '|lbr|',
#   'jeder',
#   'der',
#   'seine',
#   'stimme',
#   'einer',
#   'partei',
#   'gibt',
#   'weil',
#   'er',
#   'es',
#   'schon',
#   'immer',
#   'so',
#   'tat',
#   'ist',
#   'ein',
#   'riesenarschloch'],
#  ['maas', 'führt', 'vielleicht', 'die', 'ketzerei', 'auch', 'wieder', 'ein'],
#  ['träum', 'weiter', 'cinderella'],
#  ['wohl', 'eher', 'die', 'hetzkammer', 'der', 'abgefuckten', 'altparteien'],
#  ['da',
#   'werden',
#   'einige',
#   'bastarde',
#   'mit',
#   'ganz',
#   'schön',
#   'dreck',
#   'am',
#   'stecken',
#   'dabei',
#   'sein'],
#  ['merkel',
#   'wie',
#   'ihr',
#   'vater',
#   'bolchewisten',
#   'und',
#   'landesverräter',
#   'in',
#   'einer',
#   'person'],
#  ['wenn',
#   'wir',
#   'glück',
#   'haben',
#   'wird',
#   'china',
#   'die',
#   'welt',
#   'beherrschen'],
#  ['wenn', 'wir', 'pech', 'haben', 'der', 'islam'],
#  ['ein', 'typischer', 'sozi'],
#  ['immer', 'volksverräter'],
#  ['bei',
#   'euch',
#   'werden',
#   'die',
#   'wenigen',
#   'klugen',
#   'ja',
#   'von',
#   'dir',
#   'und',
#   'krawall-käthe',
#   'nieder',
#   'gemobbt'],
#  ['und', 'eine', 'horde', 'von', 'devoten', 'lemmingen', 'folgt', 'ihr'],
#  ['die',
#   'sklaven',
#   'der',
#   'merkel',
#   'und',
#   'der',
#   'alten',
#   'sed',
#   'müssen',
#   'endlich',
#   'lernen',
#   'zu',
#   'gehorchen'],
#  ['muss', 'cool', 'sein'],
#  ['so', 'ne', 'stadt', 'ganz', 'ohne', 'kopftücher'],
#  ['würde',
#   'mich',
#   'ja',
#   'nicht',
#   'wundern',
#   'wenn',
#   'diese',
#   'deppen',
#   'staatsgelder',
#   'kassieren',
#   'würden'],
#  ['die',
#   'fette',
#   'claudia',
#   'kleinert',
#   'aus',
#   'der',
#   'sieht',
#   'heute',
#   'auch',
#   'wieder',
#   'aus',
#   'wie',
#   'eine',
#   'presswurst',
#   'wdr'],
#  ['wer',
#   'zum',
#   'ziegenficker',
#   'in',
#   'die',
#   'türkei',
#   'fährt',
#   'ist',
#   'selber',
#   'schuld',
#   'wenn',
#   'er',
#   'dort',
#   'in',
#   'den',
#   'knast',
#   'geht'],
#  ['merkel',
#   'und',
#   'konsorten',
#   'haben',
#   'durch',
#   'die',
#   'sed',
#   'gut',
#   'gelernt'],
#  ['der', 'abschaum', 'ist', 'und', 'bleibt', 'oben'],
#  ['|lbr|', 'die', 'haben', 'noch', 'einen', 'arsch', 'in', 'der', 'hose'],
#  ['weltanschauliche', 'neutralität'],
#  ['dieses', 'floskel', 'ist', 'so', 'absurd', 'gelogen'],
#  ['|lbr|',
#   'der',
#   'deutsche',
#   'staat',
#   'ist',
#   'alles',
#   'aber',
#   'nicht',
#   'weltanschaulich',
#   'neutral'],
#  ['kämpft', 'gegen', 'die', 'zersètzer', 'wie', 'edathy', 'und', 'friedrich'],
#  ['steht', 'auf', 'uñd', 'erfìndét', 'unsere', 'idee', 'ganz', 'neu'],
#  ['stattdessen',
#   'sollte',
#   'man',
#   'das',
#   'gesamte',
#   'führungspack',
#   'der',
#   'spd',
#   'wegsperren'],
#  ['spd', 'schmarotzer', 'pädophile', 'und', 'drnunzianten'],
#  ['claudia',
#   'roth',
#   'ist',
#   'eine',
#   'schande',
#   'für',
#   'das',
#   'parlament',
#   'und',
#   'sie',
#   'als',
#   'bundestagsvize',
#   'ist',
#   'eine',
#   'schande',
#   'für',
#   'unser',
#   'land'],
#  ['das',
#   'auswärtige',
#   'amt',
#   'scheisst',
#   'auf',
#   'die',
#   'menschenwürde',
#   'und',
#   'auf',
#   'art'],
#  ['übrigens', 'geführt', 'von', 'der', 'spd'],
#  ['dieses',
#   'bild',
#   'hat',
#   'mich',
#   'der',
#   'derzeitige',
#   'feminismus',
#   'gelehrt'],
#  ['da',
#   'sieht',
#   'man',
#   'frauen',
#   'nur',
#   'am',
#   'jammern',
#   'u',
#   'rumheulen',
#   'über',
#   'das',
#   'böse',
#   'weiße',
#   'patriarchat'],
#  ['was',
#   'ist',
#   'dieser',
#   'tarek',
#   'leitner',
#   'nur',
#   'für',
#   'ein',
#   'fehlgeleiteter',
#   'hurensohn'],
#  ['orf', 'konfrontationen'],
#  ['stimmt', 'ja', 'auch'],
#  ['meistens', 'leisten', 'frauen', 'aber', 'einfach', 'weniger'],
#  ['wann',
#   'merkt',
#   'die',
#   'spd',
#   'dass',
#   'nur',
#   'ein',
#   'alkoholisierter',
#   'klotz',
#   'am',
#   'bein',
#   'ist'],
#  ['schämt', 'euch', 'ihr', 'dummen', 'säue'],
#  ['in', 'der', 'brdgmbh', 'mit', 'zweierlei', 'maß'],
#  ['schon', 'klar'],
#  ['ein', 'weiteres', 'kapitel', 'linker', 'opferkultur'],
#  ['ich', 'scheisse', 'auf', 'die', 'spd'],
#  ['gibt',
#   'es',
#   'einen',
#   'scheinheiligeren',
#   'haufen',
#   'als',
#   'das',
#   'spd',
#   'verseuchte',
#   'auswärtige',
#   'amt'],
#  ['hab', "'s", 'bereits', 'kommentiert'],
#  ['der', 'typ', 'ist', 'ein', 'clown'],
#  ['|lbr|', 'autonome', 'dürfen', 'alles'],
#  ['wären', 'das', 'rechte-', 'gt', 'höchtstrafen'],
#  ['ich',
#   'verstehe',
#   'immer',
#   'weniger',
#   'warum',
#   'die',
#   'polen',
#   'tschechen',
#   'und',
#   'ungarn',
#   'unsere',
#   'vorbildliche',
#   'migrationspolitik',
#   'nicht',
#   'mitmachen',
#   'wollen'],
#  ['|lbr|',
#   'ist',
#   'es',
#   'denen',
#   'nicht',
#   'langweilig',
#   'mit',
#   'weihnachtsmärkten',
#   'so',
#   'ganz',
#   'ohne',
#   'barrieren',
#   'polizisten',
#   'und',
#   'nagelbomben'],
#  ['ach', 'ja', 'stimmt', 'eure', 'bekloppte', 'religion'],
#  ['|lbr|', 'ausl'],
#  ['täter',
#   'werden',
#   'wie',
#   'üblich',
#   'mit',
#   'bewährung',
#   'freigelassen',
#   'statt',
#   'wie',
#   'früher',
#   'ins',
#   'arbeitslager',
#   'bis',
#   'zum',
#   'umfallen'],
#  ['es',
#   'wird',
#   'zeit',
#   'das',
#   'mann',
#   'entsorgt',
#   'am',
#   'besten',
#   'rückstandlos'],
#  ['die', 'juden', 'habens', 'mit', 'dem', 'schuldkult', 'geschafft'],
#  ['nazi=', 'gleich', 'sehen', 'gehirngewaschene', 'deutsche', 'gt', 'rot'],
#  ['|lbr|',
#   'die',
#   'linken',
#   'stinken',
#   'zum',
#   'himmel',
#   'gegen',
#   'patrioten',
#   'und',
#   'rechte',
#   'schlecht',
#   'hin'],
#  ['ach',
#   'ja',
#   'gibt',
#   'es',
#   'noch',
#   'ein',
#   'kz',
#   'was',
#   'der',
#   'pfaffe',
#   'gauck',
#   'noch',
#   'nicht',
#   'besucht',
#   'hat'],
#  ['ist',
#   'es',
#   'noch',
#   'ein',
#   'verfassungsgericht',
#   'oder',
#   'ist',
#   'es',
#   'schon',
#   'ein',
#   'verarschungsgericht'],
#  ['soll', 'er', 'doch', 'dort', 'verrotten'],
#  ['der',
#   'langweilige',
#   'dieter',
#   'nuhr',
#   'macht',
#   'sich',
#   'über',
#   'soziale',
#   'randgruppen',
#   'lustig',
#   'pfui'],
#  ['|lbr|',
#   'arme',
#   'deutsche',
#   'bürger',
#   'wehrt',
#   'euch',
#   'geht',
#   'auf',
#   'die',
#   'straße'],
#  ['naira',
#   'ich',
#   'habe',
#   'in',
#   'hamburg',
#   'ein',
#   'baby',
#   'im',
#   'krabbelalter',
#   'in',
#   'der',
#   'krippe',
#   'gesehen',
#   'mit',
#   'kopftuch',
#   'und',
#   'stecknadeln',
#   'am',
#   'kopf'],
#  ['|lbr|', 'wie', 'krank', 'ist', 'sowas', 'eigentlich'],
#  ['solange',
#   'die',
#   'sich',
#   'selber',
#   'die',
#   'köpfe',
#   'einschlagen',
#   'und',
#   'deutsche',
#   'in',
#   'ruhe',
#   'lassen'],
#  ['schwesig', 'und', 'stegner-', 'die', 'neue', 'ss'],
#  ['warum',
#   'muss',
#   'ich',
#   'mir',
#   'in',
#   'der',
#   'einen',
#   'deutschen',
#   'jammerlappen',
#   'anhören',
#   'wdr'],
#  ['was', 'für', 'ein', 'jämmerlicher', 'spinner'],
#  ['nazis',
#   'hatten',
#   'wir',
#   'vor',
#   'der',
#   'letzen',
#   'wahl',
#   'wesentlich',
#   'mehr',
#   'als',
#   'nun'],
#  ['allerdings',
#   'wundert',
#   'mich',
#   'nichts',
#   'mehr',
#   'wenn',
#   'ich',
#   'an',
#   'das',
#   'rassistische',
#   'gesindel',
#   'in',
#   'den',
#   'deutschen',
#   'botschaften',
#   'und',
#   'konsulaten',
#   'denke'],
#  ['pfaffen',
#   'und',
#   'die',
#   'us-ostküste.gleicher',
#   'glaube',
#   'gleiche',
#   'ideologie'],
#  ['nein', 'heißt', 'nicht', 'immer', 'nein'],
#  ['gerade', 'bei', 'frauen'],
#  ['wozu',
#   'brauchen',
#   'wir',
#   'überhaupt',
#   'noch',
#   'teure',
#   'politiker',
#   'wenn',
#   'die',
#   'politik',
#   'austauschbar',
#   'ist',
#   'und',
#   'uns',
#   'insgesamt',
#   'allen',
#   'doch',
#   'nur',
#   'bescheißen'],
#  ['wie',
#   'strunzdumm',
#   'ist',
#   'denn',
#   'die',
#   'türkische',
#   'rechtsanwältin',
#   'in',
#   'der',
#   'sie',
#   'sollte',
#   'besser',
#   'machen',
#   'was',
#   'sie',
#   'kann',
#   'ziegen',
#   'hüten',
#   'wdr'],
#  ['in',
#   'deutschland',
#   'ist',
#   'es',
#   'toll',
#   'deutsche',
#   'rentner',
#   'wühlen',
#   'in',
#   'mülltonnen',
#   'ausländer',
#   'gehen',
#   'gemütlich',
#   'einkaufen'],
#  ['aber', 'prozent', 'der', 'opfer', 'sind', 'frauen'],
#  ['das',
#   'ist',
#   'das',
#   'bessere',
#   'geschlecht',
#   'mit',
#   'den',
#   'möpsen',
#   'und',
#   'den',
#   'vaginas'],
#  ['|lbr|', 'frauen'],
#  ['ist',
#   'jetzt',
#   'auch',
#   'eingeschwungen',
#   'auf',
#   'den',
#   'anti-afd-kurs',
#   'der',
#   'kartellparteien'],
#  ['bei',
#   'so',
#   'vielen',
#   'verschwulten',
#   'entscheidungen',
#   'fragt',
#   'man',
#   'sich',
#   'doch',
#   'wer',
#   'hat',
#   'den',
#   'verfassungsrichtern',
#   'ins',
#   'hinr',
#   'geschissen'],
#  ['man',
#   'muss',
#   'den',
#   'volksverrätern',
#   'der',
#   'sozis',
#   'entschlossen',
#   'entgegentreten'],
#  ['|lbr|',
#   'hoffentlich',
#   'sind',
#   'die',
#   'nationalisten',
#   'dann',
#   'die',
#   'sieger',
#   'nicht',
#   'die',
#   'asylantenbeschützer',
#   'und',
#   'asyalantenabschaum'],
#  ['vielleicht', 'hatte', 'er', 'seine', 'tage'],
#  ['und', 'scheißt', 'auf', 'die', 'verdammten', 'asyl', 'schmarotzer'],
#  ['dies',
#   'afd',
#   'ist',
#   'allerdings',
#   'schwächer',
#   'also',
#   'die',
#   'politische',
#   'linke'],
#  ['und', 'die', 'linke', 'ist', 'ein', 'freund', 'des', 'islam'],
#  ['|lbr|', 'was', 'letzteren', 'so', 'bedrohlich', 'macht'],
#  ['mal',
#   'ehrlich',
#   'wer',
#   'denkt',
#   'bei',
#   'pforzheim',
#   'nicht',
#   'an',
#   'furzheim'],
#  ['liebe',
#   'freunde',
#   'denkt',
#   'einfach.der',
#   'debile',
#   'klitschko',
#   'gefeiert',
#   'der',
#   'brd',
#   'medien.also',
#   'ein',
#   'primitiver',
#   'sklave',
#   'der',
#   'us',
#   'ostküste'],
#  ['das', 'würde', 'den', 'zustand', 'von', 'claudia', 'roth', 'erklären'],
#  ['zur', 'hölle', 'mit', 'den', 'koreanischen', 'tierquälern'],
#  ['leider', 'wahr'],
#  ['zu',
#   'sehr',
#   'mit',
#   'nazikeule',
#   'verunglimpft',
#   'sodaß',
#   'sie',
#   'kaum',
#   'bürger',
#   'hier',
#   'wählen'],
#  ['afd', 'kann', 'nur', 'die', 'systemlinge', 'stürzen'],
#  ['ausgerechnet',
#   'die',
#   'scheinheiligen',
#   'heuchler',
#   'aus',
#   'der',
#   'abgefuckten',
#   'spd',
#   'reissen',
#   'das',
#   'maul',
#   'auf'],
#  ['spd', 'schmarotzer', 'pädophile', 'und', 'denunzianten'],
#  ['alles', 'zum', 'schutz', 'von', 'ausländern', 'hierzulande'],
#  ['nichts', 'wenns', 'um', 'eigene', 'volk', 'heimat', 'tradition', 'geht'],
#  ['ständig',
#   'gegen',
#   'deutsche',
#   'hetzen',
#   'und',
#   'über',
#   'unsere',
#   'kultur',
#   'spotten',
#   'aber',
#   'nicht',
#   'die',
#   'eier',
#   'haben',
#   'zu',
#   'einer',
#   'mohammed-karikatur',
#   'laferlichterluther'],
#  ['im',
#   'koran',
#   'steht',
#   'zwar',
#   'dass',
#   'moslems',
#   'ungläubige',
#   'töten',
#   'sollen',
#   'aber',
#   'das',
#   'hat',
#   'nichts',
#   'damit',
#   'zu',
#   'tun',
#   'wenn',
#   'moslems',
#   'ungläubige',
#   'töten'],
#  ['erster',
#   'fc',
#   'bayern',
#   'münchen',
#   'zeichnet',
#   'sich',
#   'aus',
#   'durch',
#   'scheintote',
#   'als',
#   'trainer',
#   'und',
#   'schwerverbrecher',
#   'im',
#   'management'],
#  ['ich',
#   'weiß',
#   'worum',
#   'es',
#   'geht',
#   'um',
#   'frauen',
#   'und',
#   'ihre',
#   'emotionalen',
#   'befindlichkeiten'],
#  ['wie', 'immer'],
#  ['was',
#   'hätte',
#   'a.',
#   'h.',
#   'mit',
#   'solche',
#   'skupellosen',
#   'tätern',
#   'gemacht'],
#  ['sicher', 'das', 'richtige'],
#  ['redet', 'da', 'etwa', 'ein', 'spd', 'politiker', 'von', 'rechtsstaat'],
#  ['|lbr|',
#   'dessen',
#   'parteifreund',
#   'steinmeier',
#   'hätte',
#   'als',
#   'minister',
#   'kleine',
#   'kinder',
#   'im',
#   'dreck',
#   'verrecken',
#   'lassen'],
#  ['ist', 'halt', 'feminismus', 'im', 'fortgeschrittenen', 'stadium'],
#  ['was', 'erwartet', 'du', 'da'],
#  ['üblicherweise', 'werden', 'ehen', 'von', 'frauen', 'gewollt'],
#  ['es',
#   'entspricht',
#   'ihrem',
#   'bedürfnis',
#   'nach',
#   'romantik',
#   'und',
#   'versorgung'],
#  ['und',
#   'warum',
#   'sollte',
#   'man',
#   'sich',
#   'mit',
#   'angehörigen',
#   'anderer',
#   'religionen',
#   'solidarisieren',
#   'wenn',
#   'man',
#   'diese',
#   'religion',
#   'bekloppt',
#   'findet'],
#  ['logisch',
#   'wenn',
#   'sie',
#   'die',
#   'zersetzung',
#   'vorangetrieben',
#   'haben',
#   'und',
#   'das',
#   'volk',
#   'genug',
#   'betrogen',
#   'haben',
#   'gehen',
#   'sie',
#   'ins',
#   'gelobte',
#   'land'],
#  ['|lbr|', 'gar', 'nicht', 'gewußt'],
#  ['überall', 'judenspuren'],
#  ['|lbr|',
#   'von',
#   'nun',
#   'an',
#   'nur',
#   'noch',
#   'ein',
#   'gesundes',
#   'gutes',
#   'neues',
#   'jahr'],
#  ['als', 'fdj', 'funktionärin', 'weiss', 'sie', 'doch', 'wie', 'das', 'geht'],
#  ['die', 'umfrage', 'ist', 'von', 'forsa'],
#  ['also', 'im', 'wesentlichen', 'wertlos'],
#  ['lieber',
#   'von',
#   'einem',
#   'scheinheiligen',
#   'heuchler',
#   'als',
#   'nazi',
#   'oder',
#   'pack',
#   'tituliert',
#   'werden',
#   'als',
#   'diese',
#   'schmarotzer',
#   'der',
#   'abgefuckten',
#   'spd',
#   'zu',
#   'wählen'],
#  ['|lbr|', 'raus', 'mit', 'den', 'ganzen', 'asylbetrügern'],
#  ['nur', 'wer', 'kann', 'will', 'das', 'wirklich', 'durchsetzen'],
#  ['freiheit',
#   'und',
#   'vielfalt',
#   'sind',
#   'immer',
#   'dann',
#   'gewährleistet',
#   'wenn',
#   'alle',
#   'frau_innen',
#   'kopftuch',
#   'tragen',
#   'und',
#   'jeder',
#   'dieselbe',
#   'linke',
#   'meinung',
#   'hat'],
#  ['ich', 'wäre', 'sehr', 'erstaunt', 'wenn', 'er', 'hirn', 'hätte'],
#  ['man',
#   'sollte',
#   'grundsätzlich',
#   'nur',
#   'schweinefleisch',
#   'an',
#   'das',
#   'migrantenpack',
#   'ausgeben'],
#  ['sollten',
#   'diese',
#   'das',
#   'zurückweisen',
#   'könnten',
#   'sie',
#   'ja',
#   'in',
#   'den',
#   'zahlreichen',
#   'kanalisationen',
#   'ratten',
#   'fangen',
#   'und',
#   'verzehren'],
#  ['merkel',
#   'und',
#   'ihre',
#   'devoten',
#   'schleimer',
#   'und',
#   'kriecher',
#   'haben',
#   'es',
#   'geschafft',
#   'ein',
#   'sklavenstaat'],
#  ['die', 'islamisierung', 'läuft', 'hier', 'in', 'deutschland'],
#  ['ich',
#   'arbeite',
#   'in',
#   'einem',
#   'beruf',
#   'wo',
#   'ich',
#   'tatsächlich',
#   'arbeiten',
#   'muss',
#   'und',
#   'nicht',
#   'das',
#   'steuergeld',
#   'anderer',
#   'leute',
#   'verschwende'],
#  ['merkel', 'und', 'gauck', 'ein', 'ideales', 'paar'],
#  ['sklaven', 'der', 'ostküste'],
#  ['was', 'bist', 'du', 'denn', 'für', 'ne', 'göre'],
#  ['ich', 'gedenke', 'der', 'opfer', 'der', 'sogenannten', "'flüchtlinge'"],
#  ['lindner',
#   'steckt',
#   'heute',
#   'abend',
#   'schon',
#   'seinen',
#   'kopf',
#   'in',
#   'den',
#   'arsch',
#   'von',
#   'merkel',
#   'widerlich',
#   'fdp'],
#  ['näch',
#   'meiner',
#   'erfahrung',
#   'tritt',
#   'die',
#   'abgefuckte',
#   'spd',
#   'die',
#   'menschenwürde',
#   'mit',
#   'füßen',
#   'siehe',
#   'das',
#   'abartige',
#   'auswärtigen',
#   'amt',
#   'und',
#   'seine',
#   'schergen'],
#  ['|lbr|', 'genau'],
#  ['viel',
#   'mehr',
#   'meinungsdiktatur',
#   'und',
#   'selbstherrlichkeit',
#   'der',
#   'regierung',
#   'gegen',
#   'das',
#   'volk'],
#  ['und',
#   'das',
#   'sagt',
#   'alles',
#   'über',
#   'dich',
#   'aus',
#   'was',
#   'es',
#   'wert',
#   'ist',
#   'zu',
#   'wissen'],
#  ['reicht', 'merkel', 'nicht'],
#  ['oder', 'ist', 'die', 'auch', 'ein', 'mann'],
#  ['wen',
#   'interessiert',
#   'dieser',
#   'dumme',
#   'türke',
#   'gibt',
#   'es',
#   'nichts',
#   'wichtigeres',
#   'aus',
#   'nrw',
#   'zu',
#   'berichten',
#   'wdr'],
#  ['dieses',
#   'gesamte',
#   'gesockse',
#   'mit',
#   'ihrem',
#   'clan',
#   'muss',
#   'innerhalb',
#   'eines',
#   'tages',
#   'raus',
#   'aus',
#   'deutschland'],
#  ['von',
#   'mir',
#   'aus',
#   'kann',
#   'der',
#   'im',
#   'türkischen',
#   'knast',
#   'verrecken'],
#  ['solange',
#   'es',
#   'deutsche',
#   'botschaften',
#   'wie',
#   'die',
#   'in',
#   'manila',
#   'gibt',
#   'gibt',
#   'es',
#   'auch',
#   'menschenverachtung'],
#  ['ich',
#   'persönlich',
#   'finde',
#   'jerusalem',
#   'ja',
#   'doof',
#   'der',
#   'mief',
#   'der',
#   'religionen',
#   'raubt',
#   'der',
#   'stadt',
#   'die',
#   'attraktivität'],
#  ['|lbr|',
#   'aber',
#   'selbstverständlich',
#   'ist',
#   'es',
#   'die',
#   'hauptstadt',
#   'israels'],
#  ['|lbr|', 'und', 'palästina', 'interessiert', 'keinen'],
#  ['stimmt',
#   'selbst',
#   'spd-kinderexperte',
#   'edathy',
#   'hat',
#   'sich',
#   'nur',
#   'für',
#   'die',
#   'jungs',
#   'interessiert'],
#  ['ich',
#   'hoffe',
#   'das',
#   'die',
#   'rache',
#   'so',
#   'brutal',
#   'sein',
#   'wird',
#   'das',
#   'europa',
#   'endlich',
#   'keine',
#   'rücksicht',
#   'mehr',
#   'nimmt'],
#  ['frau',
#   'merkel',
#   'hat',
#   'ein',
#   'krebsgeschwür',
#   'nach',
#   'deutschland',
#   'gebracht',
#   'es',
#   'wird',
#   'sich',
#   'schlimmer',
#   'ausbreiten',
#   'als',
#   'die',
#   'pest.wir',
#   'sind',
#   'den',
#   'untergang',
#   'geweiht'],
#  ['ich', 'scheisse', 'auf', 'die', 'groko'],
#  ['ich',
#   'fürchte',
#   'in',
#   'berlin',
#   'wird',
#   'es',
#   'bald',
#   'einen',
#   'platz',
#   'zum',
#   'gedenken',
#   'an',
#   'die',
#   'opfer',
#   'des',
#   'sexismus',
#   'geben'],
#  ['|lbr|', 'und', 'er', 'wird', 'sawsan-chebli-platz', 'heißen'],
#  ['und',
#   'anstelle',
#   'sofort',
#   'abzureisen',
#   'jammert',
#   'dieser',
#   'armselige',
#   'gauck',
#   'auch',
#   'noch',
#   'mit',
#   'den',
#   'griechen'],
#  ['straeter', 'ist', 'einfach', 'nur', 'noch', 'strunz', 'langweilig'],
#  ['verdammt', 'die', 'olle', 'merkel', 'tritt', 'wieder', 'an'],
#  ['|lbr|', 'wie', 'sagte', 'axel', 'stoll', 'zum', 'fs', 'elekrojude'],
#  ['lindner',
#   'ist',
#   'für',
#   'mich',
#   'einer',
#   'der',
#   'größten',
#   'lügner',
#   'und',
#   'heuchler',
#   'der',
#   'fdp'],
#  ['aber',
#   'zeit',
#   'sich',
#   'darin',
#   'nicht',
#   'die',
#   'naturgemäße',
#   'dummheit',
#   'der',
#   'grünen'],
#  ['eine',
#   'quote',
#   'ist',
#   'diskriminierung',
#   'auf',
#   'grund',
#   'des',
#   'geschlechts'],
#  ['nichts', 'weiter'],
#  ['|lbr|',
#   'deutsche',
#   'können',
#   'ja',
#   'verrecken',
#   'aber',
#   'wehe',
#   'einem',
#   'asylanten',
#   'wird',
#   "'s",
#   'geld',
#   'gestrichen'],
#  ['welche',
#   'frau',
#   'will',
#   'sich',
#   'eigentlich',
#   'die',
#   'blöße',
#   'geben',
#   'so',
#   'unattraktiv',
#   'zu',
#   'wirken',
#   'dass',
#   'sie',
#   'noch',
#   'niemals',
#   'sexuell',
#   'belästigt',
#   'wurde'],
#  ['|lbr|', 'metoo'],
#  ['ein',
#   'system',
#   'der',
#   'zersetzung',
#   'ein',
#   'system',
#   'der',
#   'lemminge',
#   'der',
#   'usa',
#   'ein',
#   'system',
#   'von',
#   'sklaven'],
#  ['gottes',
#   'strafe',
#   'für',
#   'die',
#   'schwulenlobby',
#   'folgt',
#   'hoffentlich',
#   'bald'],
#  ['|lbr|', 'nazi'],
#  ['na', 'und'],
#  ['kann',
#   'man',
#   'stolz',
#   'drauf',
#   'sein',
#   'auf',
#   'unsrer',
#   'eltern',
#   'und',
#   'großeltern'],
#  ['alles',
#   'fürs',
#   'eigene',
#   'volk',
#   'hieß',
#   'es',
#   'damals',
#   'noch',
#   '.sozial'],
#  ['kann', 'bleiben', 'wo', 'sie', 'ist', 'dumme', 'nuss'],
#  ['lieber',
#   'höre',
#   'ich',
#   'mir',
#   'die',
#   'sogenannten',
#   'braunen',
#   'an',
#   'als',
#   'das',
#   'scheinheilige',
#   'gefasel',
#   'der',
#   'dreckslinken',
#   'faschistenschweine'],
#  ['wenn',
#   'du',
#   'aber',
#   'schminke',
#   'und',
#   'high',
#   'heels',
#   'trägst',
#   'dann',
#   'setzt',
#   'du',
#   'sexuelle',
#   'signale'],
#  ['dessen', 'solltest', 'du', 'dir', 'bewusst', 'sein'],
#  ['aber',
#   'bitte',
#   'jetzt',
#   'nicht',
#   'auch',
#   'noch',
#   'ne',
#   'opfernummer',
#   'von',
#   'männlicher',
#   'seite'],
#  ['auch',
#   'heute',
#   'wieder',
#   'nur',
#   'drittklassige',
#   'laiendarsteller',
#   'in',
#   'einem',
#   'extrem',
#   'beschissenen',
#   'tatort',
#   'ard'],
#  ['sei',
#   'mal',
#   'ehrlich',
#   'wie',
#   'sollen',
#   'man',
#   'frauen',
#   'noch',
#   'ernst',
#   'nehmen'],
#  ['ich',
#   'will',
#   'die',
#   'mauer',
#   'zurück',
#   'und',
#   'dann',
#   'die',
#   'schmarotzenden',
#   'ossis',
#   'und',
#   'die',
#   'flüchtlinge',
#   'rausschmeissen'],
#  ['nur',
#   'mag',
#   'ich',
#   'dieses',
#   'gerede',
#   'nicht',
#   'wo',
#   'ein',
#   'linkgrüner-journalistenblock',
#   'seine',
#   'prognose',
#   'mit',
#   'wunschdenken',
#   'verwechselt'],
#  ['es',
#   'ist',
#   'mir',
#   'scheißegal',
#   'wenn',
#   'sich',
#   'die',
#   'türken',
#   'untereinander',
#   'den',
#   'schädel',
#   'einschlagen',
#   'damit',
#   'habe',
#   'ich',
#   'kein',
#   'problem',
#   'zdf'],
#  ['dank',
#   'der',
#   'gender',
#   'studies',
#   'bekommen',
#   'unqualifizierte',
#   'frauen',
#   'eine',
#   'berufliche',
#   'perspektive',
#   'auf',
#   'kosten',
#   'der',
#   'steuerzahler'],
#  ['|lbr|', 'genderstudies'],
#  ['da',
#   'sollten',
#   'auch',
#   'asylanten',
#   'eingesetzt',
#   'werden',
#   'die',
#   'für',
#   'nichts',
#   'abkassieren',
#   'und',
#   'sich',
#   'den',
#   'tag',
#   'über',
#   'langweilen'],
#  ['du', 'bist', 'einfach', 'nur', 'noch', 'lächerlich'],
#  ['die',
#   'anzahl',
#   'der',
#   'dreckigen',
#   'bastarde',
#   'in',
#   'diese',
#   'politverblödungsshows',
#   'wäre',
#   'bei',
#   'wenn',
#   'nicht',
#   'hin',
#   'und',
#   'wieder',
#   'jemand',
#   'von',
#   'der',
#   'afd',
#   'dazu',
#   'käme'],
#  ['wir',
#   'brauchen',
#   'das',
#   'scheiß',
#   'europa',
#   'nicht',
#   'ich',
#   'bin',
#   'deutscher',
#   'und',
#   'kein',
#   'europäer',
#   'btw'],
#  ['männersteuer', 'oder', 'so'],
#  ['kommt', 'noch'],
#  ['die',
#   'umverteilung',
#   'hin',
#   'zu',
#   'frauen',
#   'ist',
#   'ja',
#   'bereits',
#   'jetzt',
#   'massiv'],
#  ['schlimm', 'genug'],
#  ['religiöses', 'recht', 'raus', 'aus', 'deutschland'],
#  ['wer', 'scharia', 'will', 'soll', 'nach', 'saudi-arabien', 'auswandern'],
#  ['na', 'ja'],
#  ['hochschlafen', 'können', 'wir', 'männer', 'uns', 'zumindest', 'nicht'],
#  ['oder', 'pass', 'wegwerfen', 'und', 'asylantrag', 'stellen'],
#  ['laßt', 'doch', 'endlich', 'mal', 'den', 'schuldkult', 'beenden'],
#  ['zeit', 'ist'],
#  ['es',
#   'wird',
#   'zeit',
#   'dass',
#   'das',
#   'linksgrüne',
#   'meinungskartell',
#   'bei',
#   'ard/zdf',
#   'zerlegt',
#   'wird'],
#  ['|lbr|', 'man', 'kann', 'nur', 'noch', 'kotzen'],
#  ['ein',
#   'schmieriger',
#   'sozi',
#   'ein',
#   'faschist',
#   'der',
#   'extremen',
#   'linken',
#   'ein',
#   'antideutsches',
#   'subjekt'],
#  ['du',
#   'verehrst',
#   'einen',
#   'pädophilen',
#   'kriegstreiber',
#   'der',
#   'angewiesen',
#   'hat',
#   'die',
#   'ganze',
#   'welt',
#   'zum',
#   'islam',
#   'zu',
#   'bekehren'],
#  ['auch', 'mittels', 'gewalt'],
#  ['und', 'immer', 'daran', 'denken', 'wer', 'grün', 'wählt', 'wählt', 'islam'],
#  ['natürlich', 'die', 'ostküstenhure', 'droht'],
#  ['ich', 'scheisse', 'auf', 'die', 'abgefuckte', 'spd'],
#  ['schmarotzer', 'pädophile', 'und', 'denunzianten'],
#  ['genau', 'volksfeinde', 'sind', 'die', 'komministen', 'zecken', 'antifa'],
#  ['nrw', 'minister', 'jäger'],
#  ['die', 'grosse', 'pfeife', 'spricht'],
#  ['ausländer', 'raus', 'ist', 'eine', 'reine', 'meinungsäußerung'],
#  ['der',
#   'strunzdumme',
#   'verstappen',
#   'und',
#   'sollte',
#   'lieber',
#   'seifenkisten',
#   'mit',
#   'wohnwagen',
#   'fahren',
#   'mehr',
#   'kann',
#   'er',
#   'ohnehin',
#   'nicht',
#   'fsky'],
#  ['ich', 'schon'],
#  ['ich',
#   'teile',
#   'mit',
#   'ihnen',
#   'die',
#   'ablehnung',
#   'der',
#   'derzeitigen',
#   'flüchtlingspolitik',
#   'und',
#   'des',
#   'islam'],
#  ['von',
#   'deinen',
#   'islamisten',
#   '|lbr|',
#   'dschiadisten',
#   'freunden',
#   'und',
#   'jagt',
#   'dich',
#   'olle',
#   'nackert',
#   'über',
#   'die',
#   "wies'n"],
#  ['was', 'für', 'ein', 'dummer', 'tweet'],
#  ['|lbr|',
#   'von',
#   'diesen',
#   'typen',
#   'kritisiert',
#   'werden',
#   'ist',
#   'eine',
#   'ehre'],
#  ['|lbr|', 'die', 'rotfaschisten', 'zittern'],
#  ['ich', 'glaube', 'claudiaroth', 'kann', 'einfach', 'nur', 'peinlich'],
#  ['bundestag', 'bundestagsvizepraesident'],
#  ['lange', 'rede', 'kurzer', 'sinn'],
#  ['|lbr|', 'auf', 'den', 'punkt', 'gebracht', 'quatschkopp⁉'],
#  ['zum', 'kotzen.alles', 'duckmäuser', 'und', 'volksverräter'],
#  ['aber',
#   'richtig',
#   'und',
#   'abschiebungen',
#   'aller',
#   'verdächtiger',
#   'asylanten',
#   'samt',
#   'asylschmarotzer'],
#  ['die', 'wollen', 'von', 'nix', 'ablenken'],
#  ['die', 'sind', 'naturgemäß', 'so', 'dumm'],
#  ['das', 'individuum', 'hätte', 'sich', 'vorher', 'umbringen', 'sollen'],
#  ['besser', 'noch', 'man', 'kastriert', 'solche', 'schweine'],
#  ['die',
#   'meisten',
#   'muslimas',
#   'im',
#   'westen',
#   'tragen',
#   'das',
#   'kopftuch',
#   'freiwillig',
#   'und',
#   'selbstbewusst'],
#  ['|lbr|', 'und', 'genau', 'das', 'ist', 'die', 'tragödie'],
#  ['usa',
#   'wo',
#   'demokraten',
#   'für',
#   'establishment',
#   'korruption',
#   'und',
#   "'weiter",
#   'so',
#   'stehen',
#   'siegen',
#   'die',
#   'trumps'],
#  ['mit', 'bernie', 'wärs', 'anders', 'gelaufen'],
#  ['spd', 'aufgepasst'],
#  ['die',
#   'art',
#   'islam',
#   'die',
#   'frauen',
#   'für',
#   'männliche',
#   'verfügungsmasse',
#   'hält'],
#  ['abgefuckte', 'hühnerscheisse'],
#  ['aber',
#   'klar',
#   'dass',
#   'jemand',
#   'aus',
#   'der',
#   'scheinheiligsten',
#   'partei',
#   'deutschlands',
#   'so',
#   'denkt'],
#  ['spd', 'schmarotzer', 'pädophile', 'und', 'denunzianten'],
#  ['|lbr|', 'wer', 'hat', 'uns', 'verraten'],
#  ['bei', 'einer', 'direktwahl', 'hätte', 'claudi', 'roth', 'nichtmal'],
#  ['keiner', 'will', 'sie', 'haben'],
#  ['lanz', 'maischberger'],
#  ['na', 'ja'],
#  ['blödsinn', 'sind', 'grid-girls', 'schon'],
#  ['|lbr|', 'so', 'ist', 'es'],
#  ['schwule', 'dürfen', 'ja', 'immer', 'bleiben'],
#  ['pfui', 'teufel'],
#  ['sie', 'ist', 'eine', 'rassistin'],
#  ['und', 'sexistin'],
#  ['rechtskonservativ',
#   'wäre',
#   'mir',
#   'lieber',
#   '.liberal',
#   'führt',
#   'zur',
#   'dekadenz'],
#  ['das',
#   'problem',
#   'ist',
#   'dass',
#   'es',
#   'ja',
#   'nicht',
#   'bei',
#   'feministen',
#   'bleibt'],
#  ['das',
#   'ist',
#   'jetzt',
#   'für',
#   'alle',
#   'nicht-moslems',
#   'ne',
#   'no',
#   'go',
#   'area'],
#  ['nein', 'dafür', 'ist', 'sie', 'zu', 'degeneriert'],
#  ['die',
#   'alte',
#   'ist',
#   'doch',
#   'auch',
#   'drogen',
#   'total',
#   'schlechte',
#   'haut',
#   'und',
#   'ständig',
#   'das',
#   'nervöse',
#   'blinzeln',
#   'maischberger'],
#  ['das',
#   'würde',
#   'bedeuten',
#   'dass',
#   'er',
#   'seine',
#   'eigene',
#   'mohammedanische',
#   'sozialisierung',
#   'worunter',
#   'etwa',
#   'auch',
#   'die',
#   'frauenverachtung',
#   'fällt',
#   'aufgeben',
#   'müsste'],
#  ['schlimm',
#   'das',
#   'einer',
#   'wie',
#   'volker',
#   'beck',
#   'noch',
#   'in',
#   'talkshows',
#   'eingeladen',
#   'wird'],
#  ['|lbr|', 'die', 'hat', 'doch', 'den', 'arsch', 'offen'],
#  ['diese',
#   'sieht',
#   'immer',
#   'mehr',
#   'aus',
#   'wie',
#   'andrea',
#   'nahles',
#   'in',
#   'den',
#   'klamotten',
#   'einer',
#   'übergewichtigen',
#   'nutte'],
#  ['von',
#   'der',
#   'abgefuckten',
#   'spd',
#   'fallen',
#   'mir',
#   'auf',
#   'anhieb',
#   'mindestens',
#   'bastarde',
#   'ein',
#   'die',
#   'ich',
#   'nahe',
#   'an',
#   'göbbels',
#   'oder',
#   'himmler',
#   'sehe'],
#  ['ich',
#   'weiß',
#   'ich',
#   'habe',
#   'das',
#   'schon',
#   'mal',
#   'geschrieben',
#   'aber',
#   '|lbr|',
#   'ich',
#   'hasse',
#   'die',
#   'grünen'],
#  ['mit', 'tiefster', 'inbrunst'],
#  ['dieser', 'holtmann', 'scheint', 'ein', 'grüner-bastard', 'zu', 'sein'],
#  ['was',
#   'lustig',
#   'ist',
#   'da',
#   'sie',
#   'ja',
#   'damit',
#   'implizit',
#   'die',
#   'these',
#   'der',
#   'genderisten',
#   'bestätigen',
#   'würden',
#   'das',
#   'geschlecht',
#   'konstruiert',
#   'ist'],
#  ['schon',
#   'der',
#   'vater',
#   'der',
#   'als',
#   'protestantischer',
#   'pfaffe',
#   'freiwillig',
#   'in',
#   'die',
#   'ddr',
#   'ging',
#   'um',
#   'den',
#   'bolschewismus',
#   'zu',
#   'huldigen.die',
#   'tochter',
#   'ist',
#   'um',
#   'nichts',
#   'besser'],
#  ['außerdem', 'sind', 'sie', 'politisch', 'dumm'],
#  ['das', 'ganze', 'postengeschacher', 'ist', 'schmarotzertum'],
#  ['das', 'ganze', 'pack', 'gehört', 'weg', 'gejagt'],
#  ['tagdermenschenrechte',
#   '|lbr|',
#   'täglich',
#   'werden',
#   'menschen',
#   'die',
#   'nicht',
#   'deutsch',
#   'genug',
#   'aussehen',
#   'sowie',
#   'deren',
#   'unterkünfte',
#   'angegriffen'],
#  ['|lbr|',
#   'alltag',
#   'in',
#   'deutschland',
#   'heute.mann',
#   'schmeißt',
#   'alle',
#   'ausländer',
#   'raus'],
#  ['deutschland', 'den', 'deutschen'],
#  ['es',
#   'fehlt',
#   'frauen',
#   'im',
#   'vgl',
#   'zu',
#   'männern',
#   'im',
#   'schnitt',
#   'an',
#   'ehrgeiz',
#   'kreativität',
#   'und',
#   'arbeitseifer'],
#  ['da',
#   'ist',
#   'sie',
#   'ja',
#   'wieder',
#   'die',
#   'moderatorin',
#   'der',
#   'mit',
#   'der',
#   'alten',
#   'schwarzen',
#   'schmodder',
#   'hose',
#   'und',
#   'den',
#   'fettigen',
#   'haaren',
#   'wdr'],
#  ['fy',
#   'kriechen',
#   'tun',
#   'nur',
#   'die',
#   'schäbigen',
#   'bastarde',
#   'aus',
#   'der',
#   'abgefuckten',
#   'spd',
#   'und',
#   'zwar',
#   'ganz',
#   'tief',
#   'in',
#   'den',
#   'arsch',
#   'von',
#   'im',
#   'erika'],
#  ['zu', 'sperrig'],
#  ['ich', 'würde', 'pussikratie', 'vorschlagen'],
#  ['na',
#   'du',
#   'alte',
#   'l.',
#   'feierst',
#   'von',
#   'unseren',
#   'steuergeldern',
#   'auf',
#   'der',
#   "wies'n"],
#  ['|lbr|',
#   'hoffentlich',
#   'reisst',
#   'dir',
#   'einer',
#   'dein',
#   'dirnd',
#   'l',
#   'runter'],
#  ['genau',
#   'so',
#   'wenig',
#   'wie',
#   'mit',
#   'moslems',
#   'oder',
#   'asiaten',
#   'die',
#   'tierquäler'],
#  ['grüne',
#   'und',
#   'fdp',
#   'kriechen',
#   'merkel',
#   'doch',
#   'jetzt',
#   'schon',
#   'in',
#   'den',
#   'arsch',
#   'damit',
#   'sie',
#   'nur',
#   'schnell',
#   'an',
#   'die',
#   'macht',
#   'kommen',
#   'cdu'],
#  ['ist',
#   'es',
#   'eigentlich',
#   'zufall',
#   'dass',
#   'die',
#   'infantilisierung',
#   'der',
#   'gesellschaft',
#   'mit',
#   'dem',
#   'anteil',
#   'von',
#   'frauen',
#   'in',
#   'politik',
#   'und',
#   'medien',
#   'steigt'],
#  ['flaggen', 'verbrennen', 'und', 'gegen', 'israel', 'sein'],
#  ['ist', 'es', 'das', 'wofür', 'deutschland', 'multikulturalismus', 'braucht'],
# ...
#   'ob',
#   'tier',
#   'oder',
#   'mensch.die',
#   'schäden',
#   'sieht',
#   'man',
#   'in',
#   'der',
#   'natur'],
#  ['ein',
#   'tatort',
#   'mit',
#   'der',
#   'presswurst',
#   'saalfeld',
#   'geht',
#   'gar',
#   'nicht',
#   'ard'],
#  ['ich',
#   'akzeptiere',
#   'den',
#   'fakt',
#   'dass',
#   'gender',
#   'studies',
#   'eine',
#   'ausgeburt',
#   'des',
#   'feminismus',
#   'sind',
#   'ideologischer',
#   'mumpitz',
#   'ohne',
#   'falsifizierbarkeit',
#   'mit',
#   'dem',
#   'anspruch',
#   'die',
#   'gesellschaft',
#   'nicht',
#   'zu',
#   'erforschen',
#   'sondern',
#   'zu',
#   'ändern'],
#  ['meckern',
#   'über',
#   'die',
#   'touristen',
#   'auf',
#   'bali',
#   'dabei',
#   'ist',
#   'die',
#   'sendung',
#   'taff',
#   'einer',
#   'der',
#   'größten',
#   'schmeißfliegen',
#   'pro'],
#  ['wie',
#   'zu',
#   'erwarten',
#   'gewesen',
#   'war',
#   'denkt',
#   'die',
#   'fette',
#   'yvonne',
#   'willicks',
#   'wieder',
#   'nur',
#   'ans',
#   'fressen',
#   'wdr'],
#  ['viele',
#   'schwule',
#   'finden',
#   'grüne',
#   'und',
#   'islam',
#   'toll',
#   'und',
#   'genießen',
#   'die',
#   'anwesenheit',
#   'von',
#   'frauen',
#   'zum',
#   'tratschen'],
#  ['|lbr|', 'frag', 'mich', 'mal'],
#  ['dort',
#   'kann',
#   'er',
#   'wieder',
#   'heucheln',
#   'und',
#   'sich',
#   'kostenlos',
#   'vollfressen'],
#  ['wie',
#   'haben',
#   'sie',
#   'es',
#   'denn',
#   'dann',
#   'in',
#   'die',
#   'politik',
#   'geschafft'],
#  ['trotz',
#   'all',
#   'der',
#   'benachteiligung',
#   'die',
#   'es',
#   'anderen',
#   'frauen',
#   'unmöglich',
#   'macht',
#   'politiker',
#   'zu',
#   'werden'],
#  ['es',
#   'ist',
#   'einfach',
#   'unerträglich',
#   'diesen',
#   'syrischen',
#   'jammerlappen',
#   'bei',
#   'maischberger',
#   'sehen',
#   'zu',
#   'müssen',
#   'ard'],
#  ['also',
#   'sie',
#   'sollten',
#   'sich',
#   'wirklich',
#   'mal',
#   'einer',
#   'psychologischen',
#   'untersuchung',
#   'unterziehen'],
#  ['und', 'die', 'künast', 'auch'],
#  ['die',
#   'ganze',
#   'grüne',
#   'bagage',
#   'würde',
#   'hyperventilieren',
#   'wenn',
#   'auch',
#   'nur',
#   'ein',
#   'afdler',
#   'ne',
#   'israelfahne',
#   'verbrennen',
#   'würde'],
#  ['und',
#   'claudia',
#   'roth',
#   'wäre',
#   'in',
#   'der',
#   'nervenklinik',
#   'vor',
#   'lauter',
#   'betroffenheit'],
#  ['|lbr|',
#   'der',
#   'krieg',
#   'in',
#   'den',
#   'städten',
#   'endet',
#   'blutig',
#   'und',
#   'tödlich'],
#  ['wollt', 'ihr', 'das'],
#  ['nein', 'dannschmeißt', 'sämtliches', 'asylantenpack', 'raus'],
#  ['liebe',
#   'freunde',
#   'seht',
#   'euch',
#   'das',
#   'staatsfernsehen',
#   'zdf',
#   'über',
#   'flüchtlinge',
#   'an'],
#  ['kein',
#   'wunder',
#   'dass',
#   'der',
#   'verkehr',
#   'in',
#   'leipzig',
#   'läuft',
#   'wir',
#   'haben',
#   'ja',
#   'auch',
#   'genug',
#   'geld',
#   'in',
#   'den',
#   'scheiß',
#   'osten',
#   'gepumpt'],
#  ['für', 'solche', 'typen', 'wäre', 'kastration', 'das', 'beste'],
#  ['lieber',
#   'hundert',
#   'stimmen',
#   'für',
#   'die',
#   'afd',
#   'als',
#   'eine',
#   'stimme',
#   'für',
#   'die',
#   'spd',
#   'die',
#   'scheinheilgste',
#   'partei',
#   'deutschlands'],
#  ['|lbr|', 'a.', 'h.', 'war', 'als', 'diktator', 'aber', 'fürs', 'volk'],
#  ['na',
#   'weil',
#   'die',
#   'sendung',
#   'scheisse',
#   'ist',
#   'und',
#   'schulz',
#   'und',
#   'böhmermann',
#   'zwei',
#   'vollpfosten',
#   'sind'],
#  ['liebe',
#   'freunde',
#   'grad',
#   'hessenschau',
#   'gesehen.eine',
#   'propagandaschau',
#   'der',
#   'sozis'],
#  ['hat',
#   'uns',
#   'alles',
#   'im',
#   'erika',
#   'mitsamt',
#   'der',
#   'abgefuckten',
#   'groko',
#   'eingebrockt'],
#  ['ich', 'wäre', 'für'],
#  ['euro',
#   'für',
#   'jeden',
#   'zigeuner',
#   'als',
#   'begrüssungsgeld.endlich',
#   'kommen',
#   'sie.herzlich',
#   'willkommen'],
#  ['|lbr|', 'danke', 'dieser', 'regierung'],
#  ['der',
#   'größte',
#   'verbrecherapparat',
#   'ist',
#   'die',
#   'sozialdemokratie',
#   'und',
#   'ihr',
#   'grüner',
#   'steigbügelhalter'],
#  ['tja', 'nur', 'ne', 'vagina', 'zu', 'haben', 'reicht', 'halt', 'nicht'],
#  ['ich',
#   'würde',
#   'herrn',
#   'voigts',
#   'nun',
#   'nicht',
#   'als',
#   'journalisten',
#   'bezeichnen'],
#  ['nein',
#   'gender-studies',
#   'studies',
#   'beschäftigen',
#   'sich',
#   'mit',
#   'feminismus'],
#  ['es', 'ist', 'die', 'rassenlehre', 'unserer', 'zeit'],
#  ['|lbr|', 'die', 'linke', 'gehört', 'verboten', 'nicht', 'die', 'npd'],
#  ['herr',
#   'strunz',
#   'ist',
#   'in',
#   'meinen',
#   'augen',
#   'nur',
#   'strunzdumm',
#   'maischberger'],
#  ['ja',
#   'und',
#   'wenn',
#   'ich',
#   'es',
#   'so',
#   'empfinde',
#   'dann',
#   'bin',
#   'ich',
#   'ein',
#   'meerschweinchen'],
#  ['europäische',
#   'straßen',
#   'sehen',
#   'aus',
#   'wie',
#   'im',
#   'nahen',
#   'osten',
#   'voller',
#   'verrückter',
#   'mossis',
#   'die',
#   'juden',
#   'den',
#   'tod',
#   'wünschen',
#   'aber',
#   'keine',
#   'sorge',
#   '|lbr|',
#   'das',
#   'ist',
#   'vielfalt',
#   'das',
#   'ist',
#   'bunt',
#   'und',
#   'eine',
#   'islamisierung',
#   'findet',
#   'nicht',
#   'statt'],
#  ['ich',
#   'finde',
#   'die',
#   'freiheit',
#   'seine',
#   'kinder',
#   'zu',
#   'verstümmeln',
#   'ist',
#   'weniger',
#   'wert',
#   'als',
#   'die',
#   'freiheit',
#   'einvernehmlich',
#   'sex',
#   'haben',
#   'zu',
#   'dürfen'],
#  ['so',
#   'wie',
#   'jedem',
#   'klar',
#   'war',
#   'dass',
#   'unkontrollierte',
#   'einwanderung',
#   'aus',
#   'islamischen',
#   'regionen',
#   'ein',
#   'sicherheitsrisiko',
#   'per',
#   'se',
#   'darstellt'],
#  ['ich',
#   'habe',
#   'kein',
#   'verständnis',
#   'für',
#   'jesidische',
#   'jüdische',
#   'und',
#   'christliche',
#   'vertreter',
#   'die',
#   'mitansehen',
#   'wie',
#   'angehörige',
#   'ihrer',
#   'glaubensgemeinschaft',
#   'von',
#   'radikalen',
#   'muslimen',
#   'gewalt',
#   'erleben',
#   'aber',
#   'öffentlich',
#   'nicht',
#   'den',
#   'mut',
#   'haben',
#   'diesen',
#   'islamischen',
#   'extremismus',
#   'zu',
#   'benennen',
#   'ihr',
#   'seid',
#   'feiglinge'],
#  ['ach', 'du', 'scheisse'],
#  ['niemals', 'die', 'kinderfickerpartei'],
#  ['frau',
#   'nahles',
#   'von',
#   'der',
#   'spd',
#   'sollte',
#   'lieber',
#   'wieder',
#   'kinderlieder',
#   'singen',
#   'denn',
#   'das',
#   'ist',
#   'das',
#   'einzigste',
#   'was',
#   'sie',
#   'kann',
#   'spd'],
#  ['vielleicht',
#   'sollten',
#   'wir',
#   'doch',
#   'wieder',
#   'die',
#   'wehrpflicht',
#   'einführen'],
#  ['für', 'männer', 'und', 'frauen'],
#  ['würde',
#   'unserer',
#   'jungen',
#   'generation',
#   'aus',
#   'schneeflöckchen',
#   'und',
#   'weicheiern',
#   'gut',
#   'tun'],
#  ['roth',
#   'haye',
#   'friedman',
#   'die',
#   'geballte',
#   'ladung',
#   'der',
#   'zersetzung'],
#  ['ein',
#   'parteivorsitzender',
#   'der',
#   'im',
#   'suff',
#   'nicht',
#   'mehr',
#   'weiß',
#   'was',
#   'er',
#   'tut'],
#  ['|lbr|', 'danke'],
#  ['mit',
#   'wird',
#   'jamaika',
#   'nicht',
#   'besser',
#   'als',
#   'die',
#   'groko',
#   'sonder',
#   'schlechter'],
#  ['|lbr|',
#   'hoffentlich',
#   'werden',
#   'es',
#   'nicht',
#   'noch',
#   'mehr',
#   'asylanten'],
#  ['stoppt', 'die', 'asylantenflucht', 'kann', 'es', 'nur', 'heißen'],
#  ['die',
#   'bolschewistenhure',
#   'wird',
#   'endlich',
#   'da',
#   'enden',
#   'wo',
#   'viele',
#   'geendet',
#   'haben'],
#  ['|lbr|',
#   'pfui',
#   'teufel',
#   'sollen',
#   'die',
#   'wilderer',
#   'zur',
#   'hölle',
#   'fahren'],
#  ['ich',
#   'erwarte',
#   'von',
#   'einer',
#   'nominell',
#   'konservativen',
#   'partei',
#   'wie',
#   'der',
#   'cdu/csu',
#   'dass',
#   'sie',
#   'der',
#   'todfeind',
#   'der',
#   'grünen',
#   'ist'],
#  ['nicht', 'ihr', 'verbündeter'],
#  ['die', 'sklaven', 'freuen', 'sich.der', 'abschaum', 'regiert'],
#  ['|lbr|',
#   'es',
#   'kann',
#   'ganz',
#   'schnell',
#   'passieren',
#   'das',
#   'der',
#   'wind',
#   'sich',
#   'dreht'],
#  ['das',
#   'spd',
#   'verseuchte',
#   'auswärtige',
#   'amt',
#   'behandelt',
#   'filipinos',
#   'wir',
#   'menschen'],
#  ['|lbr|', 'spd', 'rassismus', 'pur'],
#  ['eine',
#   'bodenlose',
#   'frechheit',
#   'noch',
#   'geld',
#   'bei',
#   'ditib',
#   'reinzustecken',
#   'ich',
#   'würde',
#   'die',
#   'moslems',
#   'rausschmeißen',
#   'und',
#   'zwar',
#   'schnell'],
#  ['deutschland', 'braucht', 'dieses', 'subjekt', 'der', 'zersetzung', 'nicht'],
#  ['jeder',
#   'der',
#   'den',
#   'altparteien',
#   'seine',
#   'stimme',
#   'gibt',
#   'handelt',
#   'etwa',
#   'so',
#   'als',
#   'würde',
#   'er',
#   'gutes',
#   'essen',
#   'in',
#   'den',
#   'müll',
#   'werfen',
#   'während',
#   'kleine',
#   'kinder',
#   'verhungern'],
#  ['auch', 'da', 'werden', 'viele', 'schwanger', 'um', 'sich', 'zu', 'drücken'],
#  ['hochgeschlafen', 'hat', 'sie', 'sich', 'sicher', 'nicht'],
#  ['ich',
#   'finde',
#   'es',
#   'eine',
#   'schande',
#   'verbrecher',
#   'uli',
#   'hoeneß',
#   'bei',
#   'einem',
#   'bayern',
#   'spiel',
#   'sehen',
#   'zu',
#   'müssen'],
#  ['in', 'wien'],
#  ['und', 'wer', 'ist', 'besitzer'],
#  ['ein', 'jude'],
#  ['der',
#   'typisch',
#   'dumme',
#   'deutsche',
#   'stammwähler',
#   'der',
#   'den',
#   'islamistischen',
#   'dreckshaufen',
#   'schon',
#   'fast',
#   'anbetet',
#   'sieht',
#   'sich',
#   'jetzt',
#   'mit',
#   'dem',
#   'judenkomplex',
#   'konfrontiert'],
#  ['aber',
#   'es',
#   'waren',
#   'die',
#   'vom',
#   'dummdeutschen',
#   'gewählten',
#   'schmarotzer',
#   'die',
#   'den',
#   'islamdreck',
#   'hier',
#   'gezüchtet',
#   'haben'],
#  ['sie',
#   'nennen',
#   'sich',
#   'aber',
#   'dennoch',
#   'muslime',
#   'und',
#   'geben',
#   'damit',
#   'zu',
#   'verstehen',
#   'dass',
#   'sie',
#   'sich',
#   'diesem',
#   'unsinn',
#   'zugehörig',
#   'fühlen'],
#  ['der',
#   'tag',
#   'der',
#   'rache',
#   'muss',
#   'unbarmherzig',
#   'und',
#   'gnadenlos',
#   'sein'],
#  ['|lbr|',
#   'aber',
#   'bis',
#   'dahin',
#   'machen',
#   'wir',
#   'sie',
#   'nur',
#   'lächerlich'],
#  ['liegt',
#   'daran',
#   'dass',
#   'es',
#   'frau',
#   'nichts',
#   'kostet',
#   'irgendwas',
#   'zu',
#   'behaupten'],
#  ['jede',
#   'partei',
#   'die',
#   'mit',
#   'der',
#   'abgefuckten',
#   'scheinheiligsten',
#   'partei',
#   'deutschlands',
#   'zusammenarbeitet',
#   'tut',
#   'dies',
#   'maximal',
#   'aus',
#   'machtgeilheit'],
#  ['|lbr|',
#   'entweder',
#   'sind',
#   'die',
#   'in',
#   'eurer',
#   'löschzentren',
#   'völlig',
#   'unqualifiziert',
#   'oder',
#   'sind',
#   'selbst',
#   'antisemiten'],
#  ['anders', 'ist', 'das', 'nicht', 'erklärbar'],
#  ['sagt',
#   'euch',
#   'jeden',
#   'tag',
#   'neu',
#   '|lbr|',
#   'es',
#   'kommt',
#   'der',
#   'tag',
#   'der',
#   'rache'],
#  ['|lbr|', 'und', 'der', 'wird', 'unbarmherzig', 'sein'],
#  ['dies', 'ist', 'ein', 'besetztes', 'land'],
#  ['und', 'merkel', 'und', 'ihre', 'knechte', 'kriechen', 'vor', 'obama'],
#  ['hier',
#   'sieht',
#   'man',
#   'wunderbar',
#   'was',
#   'man',
#   'als',
#   'funktionärin',
#   'für',
#   'propaganda',
#   'in',
#   'der',
#   'sed',
#   'gelernt',
#   'hat'],
#  ['diese', 'hat', 'nur', 'brei', 'im', 'kopf', 'illner'],
#  ['pfui',
#   'teufel',
#   '.die',
#   'weiber',
#   'sollte',
#   'man',
#   'nach',
#   'afrika',
#   'mit',
#   'samt',
#   'negern',
#   'abschieben'],
#  ['ungarn', 'zeigt', 'wies', 'geht'],
#  ['und', 'dämon-merkel'],
#  ['du',
#   'bringst',
#   'deinem',
#   'sohn',
#   'bei',
#   'dass',
#   'eine',
#   'frau',
#   'ohne',
#   'kopftuch',
#   'nichts',
#   'weiter',
#   'ist',
#   'als',
#   'eine',
#   'schlampe'],
#  ['|lbr|',
#   'genauso',
#   'wie',
#   'du',
#   'dich',
#   'abwertend',
#   'über',
#   'bikinis',
#   'und',
#   'freizügigkeit',
#   'äußerst'],
#  ['da', 'kann', 'ja', 'nur', 'feministischer', 'porno', 'bei', 'rauskommen'],
#  ['also',
#   'viel',
#   'gerede',
#   'über',
#   'gefühle',
#   'eine',
#   'debatte',
#   'darüber',
#   'wer',
#   'welches',
#   'geschlecht',
#   'und',
#   'ob',
#   'penetration',
#   'vergewaltigung',
#   'ist'],
#  ['cdu-generalsekretär',
#   'beschimpft',
#   'einen',
#   'facebook-pöbler',
#   'als',
#   'arschloch',
#   'finden',
#   'sie',
#   'das',
#   'in',
#   'ordnung'],
#  ['|lbr|', 'tauber-du', 'arsch'],
#  ['ach', 'du', 'scheisse', 'bloß', 'nicht'],
#  ['so',
#   'einfach',
#   'geht',
#   'das',
#   'für',
#   'eine',
#   'geknechtete',
#   'nation',
#   'und',
#   'die',
#   'sklaven',
#   'feiern',
#   'obama'],
#  ['|lbr|', 'wo', 'sind', 'die', 'wahren', 'männer'],
#  ['aller', 'verschwult', 'oder', 'was'],
#  ['oh', 'mann', 'hätte', 'bei', 'a.h.', 'nie', 'gegeben'],
#  ['was', 'ist', 'nur', 'aus', 'dem', 'verfassungsgericht', 'geworden'],
#  ['diese', 'voskhule', 'administration', 'tut', 'dem', 'land', 'nicht', 'gut'],
#  ['linksrotgrün', 'verschwult'],
#  ['wer', 'gerechte', 'löhne', 'fordert', 'ist', 'ein', 'narr'],
#  ['heimat',
#   'ist',
#   'da',
#   'wo',
#   'keine',
#   'moslems',
#   'sind',
#   'aktuellestunde',
#   'wdr'],
#  ['so',
#   'etwas',
#   'kommt',
#   'davon',
#   'wenn',
#   'man',
#   'einen',
#   'ahnungslosen',
#   'alkoholiker',
#   'zum',
#   'parteivorsitzenden',
#   'macht',
#   'spd'],
#  ['|lbr|', 'sehr', 'richtig', 'schluß', 'mit', 'der', 'nazikeule'],
#  ['|lbr|', 'verfluchten', 'jäger'],
#  ['abschaffung', 'der', 'jagt'],
#  ['ihr', 'seid', 'scheisse'],
#  ['der',
#   'islam',
#   'gehört',
#   'nicht',
#   'zu',
#   'deutschland',
#   'und',
#   'du',
#   'gehörst',
#   'nicht',
#   'in',
#   'die',
#   'regierung'],
#  ['also', 'mal', 'ehrlich', 'unter', 'uns'],
#  ['wer',
#   'wählt',
#   'grün',
#   'künast',
#   'roth',
#   'tritin',
#   'und',
#   'die',
#   'ganzen',
#   'phädophilen'],
#  ['wenn',
#   'du',
#   'dich',
#   'sexy',
#   'anziehst',
#   'musst',
#   'du',
#   'dich',
#   'allerdings',
#   'nicht',
#   'wundern',
#   'wenn',
#   'du',
#   'auch',
#   'sexuell',
#   'behandelt',
#   'wirst'],
#  ['na',
#   'wenn',
#   'das',
#   'aus',
#   'einem',
#   'spd',
#   'maul',
#   'kommt',
#   'dann',
#   'besser',
#   'hetze',
#   'und',
#   'angeblicher',
#   'rassismus',
#   'als',
#   'die',
#   'scheinheilige',
#   'heuchelei',
#   'des',
#   'spd',
#   'verseuchten',
#   'auswärtigen',
#   'amtes'],
#  ['spd', 'schmarotzer', 'pädophile', 'und', 'denunzianten'],
#  ['und', 'genau', 'das', 'trifft', 'z.', 'z.', 'voll', 'zu'],
#  ['je',
#   'länger',
#   'ich',
#   'mich',
#   'mit',
#   'feministen',
#   'beschäftige',
#   'umso',
#   'mehr',
#   'bin',
#   'ich',
#   'der',
#   'überzeugung',
#   'dass',
#   'die',
#   'alte',
#   'diagnose',
#   'dass',
#   'denen',
#   'einfach',
#   'nur',
#   'ein',
#   'guter',
#   'fick',
#   'fehlt',
#   'korrekt',
#   'ist'],
#  ['zdf-kika',
#   'präsentiert',
#   '„',
#   'leben',
#   'wie',
#   'zu',
#   'zeiten',
#   'des',
#   'propheten',
#   'teil',
#   '-jähriger',
#   'syrer',
#   'stellt',
#   'seine',
#   'siebenjährige',
#   'ehefrau',
#   'vor.',
#   '“',
#   'die',
#   'grün-muslimische',
#   'pädophilie-achse',
#   'lebt'],
#  ['laßt', 'doch', 'endlic', 'mal', 'a.', 'h.u'],
#  ['das', 'ns-regime', 'in', 'ruhe'],
#  ['spd',
#   'partei',
#   'ohne',
#   'rückgrat',
#   'einfach',
#   'nur',
#   'zum',
#   'kotzen',
#   'inklusive'],
#  ['welcher', 'zaussel', 'bewacht', 'denn', 'da', 'die', 'urne'],
#  ['bestimmt', 'einer', 'von', 'bundestag'],
#  ['natürlich', 'darfst', 'du', 'das'],
#  ['du', 'sendest', 'dennoch', 'sexuelle', 'signale', 'aus'],
#  ['in', 'deinem', 'alter', 'nicht', 'mehr', 'so', 'viele', 'aber', 'dennoch'],
#  ['jammergestallt',
#   'petra',
#   'roth.das',
#   'die',
#   'es',
#   'überhaupt',
#   'noch',
#   'wagt',
#   'sich',
#   'darzustellen'],
#  ['was',
#   'ihr',
#   'sexuelle',
#   'belästigung',
#   'nennt',
#   'ist',
#   'für',
#   'mich',
#   'eine',
#   'gepflegte',
#   'unterhaltung',
#   'in',
#   'einer',
#   'homo-kneipe'],
#  ['|lbr|', 'metoo'],
#  ['asylantenstopp',
#   'sofort',
#   'für',
#   'die',
#   'sozialschmarotzer',
#   'und',
#   'rückführung',
#   'für',
#   'welche',
#   'noch',
#   'hier',
#   'sind'],
#  ['ösi',
#   'können',
#   'das',
#   'miststück',
#   'gerne',
#   'behalten',
#   'und',
#   'direkt',
#   'abschieben'],
#  ['bild',
#   'ist',
#   'eh',
#   'scheisse',
#   'und',
#   'hat',
#   'mit',
#   'der',
#   'cia',
#   'zu',
#   'tun'],
#  ['das',
#   'geseiere',
#   'dieses',
#   'pfaffen',
#   'gauck',
#   'widert',
#   'jeden',
#   'aufrechten',
#   'nur',
#   'an',
#   'warum',
#   'beantragt',
#   'dieses',
#   'objekt',
#   'der',
#   'zersetzung',
#   'nicht',
#   'asyl',
#   'im',
#   'gelobten',
#   'land'],
#  ['alles', 'nur', 'wegen', 'der', 'asylschmarotzer'],
#  ['grün', 'ist', 'abfall', 'und', 'abfall', 'muss', 'auf', 'den', 'kompost'],
#  ['lasst', 'uns', 'für', 'die', 'freiheit', 'kämpfen'],
#  ['gegen', 'die', 'ostküste', 'und', 'ihre', 'vasallen'],
#  ['die', 'größte', 'schande', 'sind', 'die', 'cdu-verbrecher'],
#  ['man', 'muss', 'diesen', 'aussatz', 'täglich', 'anprangern'],
#  ['vor', 'was', 'habt', 'ihr', 'angst', 'liebe', 'bürger'],
#  ['steht', 'endlich', 'auf', 'und', 'kämpft', 'gegen', 'das', 'regime'],
#  ['die',
#   'widerliche',
#   'eunuchenstimme',
#   'von',
#   'ist',
#   'einfach',
#   'nur',
#   'ekelhaft',
#   'rtl',
#   'formel',
#   'da',
#   'schalte',
#   'ich',
#   'lieber',
#   'auf',
#   'orf'],
#  ['die',
#   'amis',
#   'haben',
#   'keinen',
#   'charakter',
#   'keinen',
#   'freien',
#   'geist',
#   'keine',
#   'kultur'],
#  ['|lbr|',
#   'also',
#   'wird',
#   'deutschland',
#   'und',
#   'europa',
#   'am',
#   'ende',
#   'siegen'],
#  ['ja', 'ich', 'habe', 'ein', 'problem', 'mit', 'dem', 'islam'],
#  ['was', 'dagegen'],
#  ['|lbr|', 'so', 'ist', 'es'],
#  ['möge', 'der', 'zahnarzt', 'zur', 'hölle', 'fahren'],
#  ...]

# %%
hatespeech_corpora= hatespeech + hatespeech2+ hatespeech3 + hatespeech4 + hatespeech5 + hatespeech6

# %%
len(hatespeech_corpora)
# Out:
# 22282

# %%
def create_ngrams(corpora):
    ngram_dict = {}
    stopwords = nltk.corpus.stopwords.words("german")
    stopwords +=["findbecci","--","..", "§", '”','|lbr|', '’', "rebecca", "freeflorian", "florian" , "„"]
    
    for i in range(2):
        ngram_dict[f"{i+2}-grams"] =[]
  
        store = []
        for sents in corpora:
            ngram_dict[f"{i+2}-grams"] += [ gram for gram in list(nltk.ngrams(sents,i+2)) if (len(set(stopwords).intersection(set(gram)))== 0) and (len(gram[0])>1) and (len(gram[1])>1)]
    
    return ngram_dict

# %%
ngram_dict = create_ngrams(hatespeech_corpora)

# %%
len(ngram_dict[f"{2}-grams"])
# Out:
# 60397

# %%
res = nltk.FreqDist(ngram_dict["2-grams"])

# %%
res.most_common(1000)
# Out:
# [(('frau', 'merkel'), 90),
#  (('immer', 'mehr'), 67),
#  (('schon', 'lange'), 53),
#  (('seit', 'jahren'), 50),
#  (('schon', 'mal'), 49),
#  (('le', 'pen'), 48),
#  (('deutsche', 'volk'), 36),
#  (('angela', 'merkel'), 33),
#  (('schon', 'immer'), 32),
#  (('schon', 'seit'), 32),
#  (('bla', 'bla'), 32),
#  (('ach', 'ja'), 27),
#  (('ja', 'schon'), 24),
#  (('armes', 'deutschland'), 23),
#  (('eigene', 'volk'), 22),
#  (('eigenen', 'land'), 22),
#  (('geht', "'s"), 22),
#  (('claudia', 'roth'), 21),
#  (('endlich', 'mal'), 21),
#  (('na', 'ja'), 21),
#  (('ganz', 'einfach'), 21),
#  (('afd', 'wählen'), 20),
#  (('ja', 'immer'), 20),
#  (('erst', 'mal'), 20),
#  (('ja', 'wohl'), 19),
#  (('schon', 'längst'), 18),
#  (('frau', 'petry'), 18),
#  (('schmarotzer', 'pädophile'), 18),
#  (('sigmar', 'gabriel'), 17),
#  (('milliarden', 'euro'), 17),
#  (('sei', 'dank'), 17),
#  (('berliner', 'polizei'), 17),
#  (('grenzen', 'dicht'), 16),
#  (('saudi', 'arabien'), 16),
#  (('vielen', 'dank'), 16),
#  (('deutschen', 'volk'), 16),
#  (('gibt', "'s"), 16),
#  (('partei', 'deutschlands'), 16),
#  (('ha', 'ha'), 15),
#  (('viele', 'menschen'), 14),
#  (('islam', 'gehört'), 14),
#  (('mal', 'sehen'), 14),
#  (('spd', 'schmarotzer'), 14),
#  (('erst', 'recht'), 13),
#  (('alice', 'schwarzer'), 13),
#  (('mal', 'jemand'), 13),
#  (('junge', 'männer'), 13),
#  (('na', 'klar'), 13),
#  (('bescheid', 'sagen'), 13),
#  (('mehr', 'geld'), 12),
#  (('cdu', 'spd'), 12),
#  (('marine', 'le'), 12),
#  (('mal', 'mehr'), 12),
#  (('geht', 'gar'), 12),
#  (('wohl', 'eher'), 12),
#  (('gott', 'sei'), 12),
#  (('frau', 'le'), 12),
#  (('herr', 'sigmar'), 12),
#  (('gabriel', 'bitte'), 12),
#  (('twitter', 'teilen'), 12),
#  (('sundance', 'justnobody'), 12),
#  (('nix', 'mehr'), 11),
#  (('heiko', 'maas'), 11),
#  (('pfui', 'teufel'), 11),
#  (('nahen', 'osten'), 11),
#  (('hartz', 'iv'), 11),
#  (('ganz', 'europa'), 11),
#  (('ganz', 'schnell'), 11),
#  (('mal', 'ehrlich'), 11),
#  (('neue', 'seite'), 11),
#  (('hut', 'ab'), 11),
#  (('mal', 'ne'), 11),
#  (('seit', 'gestern'), 11),
#  (('liebe', 'freunde'), 11),
#  (('beim', 'herumsurfen'), 11),
#  (('herumsurfen', 'gesehen'), 11),
#  (('merkel', 'macht'), 10),
#  (('eigene', 'bevölkerung'), 10),
#  (('ganz', 'deutschland'), 10),
#  (('deutschen', 'volkes'), 10),
#  (('ganz', 'klar'), 10),
#  (('deutschen', 'bürger'), 10),
#  (('danke', 'frau'), 10),
#  (('einfach', 'mal'), 10),
#  (('deutsche', 'politiker'), 10),
#  (('teufel', 'jagen'), 10),
#  (('gute', 'nacht'), 10),
#  (('donald', 'trump'), 10),
#  (('sucht', 'endlich'), 10),
#  (('scheinheilgste', 'partei'), 10),
#  (('fettigen', 'haaren'), 10),
#  (('spd', 'cdu'), 9),
#  (('horst', 'seehofer'), 9),
#  (('oh', 'mann'), 9),
#  (('letzten', 'jahren'), 9),
#  (('jahre', 'alt'), 9),
#  (('wer', 'bezahlt'), 9),
#  (('sofort', 'raus'), 9),
#  (('straße', 'gehen'), 9),
#  (('schon', 'fast'), 9),
#  (('mehr', 'lange'), 9),
#  (('immer', 'weniger'), 9),
#  (('ganz', 'schön'), 9),
#  (('deutsche', 'bürger'), 9),
#  (('sexuelle', 'belästigung'), 9),
#  (('ja', 'mal'), 9),
#  (('nächstes', 'jahr'), 9),
#  (('etablierten', 'parteien'), 9),
#  (('schon', 'gar'), 9),
#  (('bürgerkriegsflüchtlingen', 'helfen'), 9),
#  (('vorsätzliche', 'beihilfe'), 9),
#  (('nötigern', 'erpressern'), 9),
#  (('erpressern', 'gewalttätern'), 9),
#  (('selbe', 'gilt'), 9),
#  (('völker', 'regiert'), 9),
#  (('martin', 'schulz'), 9),
#  (('notre', 'dame'), 9),
#  (('o.', 'wilke'), 9),
#  (('schwager', 'schwagerwars'), 9),
#  (('_geld', '_ein'), 9),
#  (('erfolg', 'löschung'), 9),
#  (('millionen', 'menschen'), 8),
#  (('sexuelle', 'übergriffe'), 8),
#  (('jahre', 'lang'), 8),
#  (('deutschen', 'steuerzahler'), 8),
#  (('erst', 'gar'), 8),
#  (('kriminelle', 'ausländer'), 8),
#  (('verstand', 'verloren'), 8),
#  (('pegida', 'aufdiestraße'), 8),
#  (('ja', 'ja'), 8),
#  (('wacht', 'endlich'), 8),
#  (('mal', 'ganz'), 8),
#  (('freien', 'fuß'), 8),
#  (('punkt', 'gebracht'), 8),
#  (('arsch', 'vorbei'), 8),
#  (('land', 'kommen'), 8),
#  (('richtig', 'gemacht'), 8),
#  (('selber', 'schuld'), 8),
#  (('eh', 'schon'), 8),
#  (('eigenen', 'volk'), 8),
#  (('schon', 'länger'), 8),
#  (('danke', 'merkel'), 8),
#  (('unserer', 'regierung'), 8),
#  (('mehr', 'menschen'), 8),
#  (('bundesrepublik', 'deutschland'), 8),
#  (('jungen', 'männer'), 8),
#  (('guten', 'morgen'), 8),
#  (('a.', 'merkel'), 8),
#  (('ab', 'sofort'), 8),
#  (('stärkste', 'kraft'), 8),
#  (('rot', 'grün'), 8),
#  (('besten', 'blockieren'), 8),
#  (('merkel', 'vasallen'), 8),
#  (('vasallen', 'merkels'), 8),
#  (('volker', 'beck'), 8),
#  (('haaren', 'wdr'), 8),
#  (('refugees', 'refugeesnotwelcome'), 7),
#  (('deutsche', 'frauen'), 7),
#  (('pro', 'jahr'), 7),
#  (('seit', 'monaten'), 7),
#  (('her', 'kommen'), 7),
#  (('kurzer', 'zeit'), 7),
#  (('millionen', 'euro'), 7),
#  (('aufdiestraße', 'montagistpegidatag'), 7),
#  (('eigenen', 'bürger'), 7),
#  (('müssen', 'erst'), 7),
#  (('is', 'ja'), 7),
#  (('mal', 'schauen'), 7),
#  (('ja', 'genau'), 7),
#  (('lässt', 'grüßen'), 7),
#  (('seit', 'wochen'), 7),
#  (('schnauze', 'voll'), 7),
#  (('eigene', 'meinung'), 7),
#  (('land', 'gelassen'), 7),
#  (('letzter', 'zeit'), 7),
#  (('ganz', 'ehrlich'), 7),
#  (('jähriges', 'mädchen'), 7),
#  (('geht', 'ja'), 7),
#  (('deutschland', 'gibt'), 7),
#  (('dumme', 'deutsche'), 7),
#  (('ganze', 'zeit'), 7),
#  (('ganze', 'welt'), 7),
#  (('wär', "'s"), 7),
#  (('land', 'zurück'), 7),
#  (('beide', 'völker'), 7),
#  (('wurde', 'heute'), 7),
#  (('andrea', 'nahles'), 7),
#  (('ep', 'europawahl'), 7),
#  (('ursula', 'haverbeck'), 7),
#  (('walter', 'lübcke'), 7),
#  (('sitzen', 'geblieben'), 7),
#  (('papa', 'wilberg'), 7),
#  (('schwagerwars', 'gebtdenschwagerfrei'), 7),
#  (('twittersupport', 'melden'), 7),
#  (('löschung', 'od'), 7),
#  (('hungerstreik', 'rapefugees'), 6),
#  (('islamisierung', 'deutschlands'), 6),
#  (('millionen', 'asylanten'), 6),
#  (('afd', 'wähler'), 6),
#  (('krimigranten', 'rapefugees'), 6),
#  (('gern', 'mal'), 6),
#  (('wer', 'glaubt'), 6),
#  (('merkel', 'cdu'), 6),
#  (('heute', 'schon'), 6),
#  (('cdu', 'csu'), 6),
#  (('ne', 'menge'), 6),
#  (('sexuell', 'belästigt'), 6),
#  (('recht', 'geben'), 6),
#  (('kommen', 'immer'), 6),
#  (('politische', 'gegner'), 6),
#  (('letzte', 'woche'), 6),
#  (('seit', 'jahrzehnten'), 6),
#  (('frau', 'schwarzer'), 6),
#  (('viktor', 'orban'), 6),
#  (('multi', 'kulti'), 6),
#  (('gefallen', 'lassen'), 6),
#  (('gut', 'gemacht'), 6),
#  (('fresse', 'halten'), 6),
#  (('ja', 'fast'), 6),
#  (('land', 'geholt'), 6),
#  (('mann', 'wurde'), 6),
#  (('nie', 'mehr'), 6),
#  (('viele', 'deutsche'), 6),
#  (('ne', 'frage'), 6),
#  (('mal', 'bitte'), 6),
#  (('herr', 'maas'), 6),
#  (('mehr', 'geben'), 6),
#  (('deutschland', 'schon'), 6),
#  (('ach', 'ne'), 6),
#  (('je', 'mehr'), 6),
#  (('macht', 'endlich'), 6),
#  (('nächsten', 'jahre'), 6),
#  (('geld', 'mehr'), 6),
#  (('schon', 'klar'), 6),
#  (('wäre', 'ja'), 6),
#  (('immer', 'schlimmer'), 6),
#  (('heute', 'morgen'), 6),
#  (('gute', 'besserung'), 6),
#  (('schlimm', 'genug'), 6),
#  (('kopf', 'schütteln'), 6),
#  (('mal', 'schön'), 6),
#  (('freie', 'meinungsäußerung'), 6),
#  (('ja', 'klar'), 6),
#  (('gibt', 'ja'), 6),
#  (('herr', 'baumgartner'), 6),
#  (('mal', 'besser'), 6),
#  (("'s", 'ja'), 6),
#  (('strasse', 'gehen'), 6),
#  (('gute', 'idee'), 6),
#  (('warum', 'hört'), 6),
#  (('zwei', 'jahre'), 6),
#  (('genug', 'geld'), 6),
#  (('wer', 'hätte'), 6),
#  (('merkel', 'muß'), 6),
#  (('richtig', 'gut'), 6),
#  (('wohl', 'kaum'), 6),
#  (('bundes', 'regierung'), 6),
#  (('deutschland', 'sagen'), 6),
#  (('hoch', 'kriminellen'), 6),
#  (('kriminellen', 'brandstiftern'), 6),
#  (('parteien', 'michboche'), 6),
#  (('sowas', 'unterstützen'), 6),
#  (('verdammt', 'nochmal'), 6),
#  (('ab', 'morgen'), 6),
#  (('nacht', 'deutschland'), 6),
#  (('video', 'wurde'), 6),
#  (('paar', 'jahren'), 6),
#  (('herr', 'orban'), 6),
#  (('for', 'future'), 6),
#  (('europawahl', 'ep'), 6),
#  (('stasifrau', 'kahane'), 6),
#  (('kahane', 'funktioniert'), 6),
#  (('read', 'more'), 6),
#  (('wikimedia', 'cc'), 6),
#  (('cc', 'by-sa'), 6),
#  (('endlich', 'sucht'), 6),
#  (('betroffen', 'futschi'), 6),
#  (('europawahl', 'euelections'), 6),
#  (('jaxxon', 'sundance'), 6),
#  (('merkels', 'vasallen'), 6),
#  (('auswärtige', 'amt'), 6),
#  (('abgefuckten', 'spd'), 6),
#  (('gender', 'studies'), 6),
#  (('yvonne', 'willicks'), 6),
#  (('ganz', 'genau'), 5),
#  (('afd', 'deutschland'), 5),
#  (('nächsten', 'jahren'), 5),
#  (('deutsche', 'wirtschaft'), 5),
#  (('ernst', 'nehmen'), 5),
#  (('nein', 'danke'), 5),
#  (('grenzen', 'sichern'), 5),
#  (('nächste', 'mal'), 5),
#  (('na', 'super'), 5),
#  (('grüne', 'linke'), 5),
#  (('mutti', 'merkel'), 5),
#  (('wer', 'schützt'), 5),
#  (('eigenen', 'landsleute'), 5),
#  (('geschichte', 'eingehen'), 5),
#  (('sexuell', 'missbraucht'), 5),
#  (('simone', 'peter'), 5),
#  (('warum', 'darf'), 5),
#  (('sofort', 'abgeschoben'), 5),
#  (('mund', 'verbieten'), 5),
#  (('frauke', 'petry'), 5),
#  (('politisch', 'korrekt'), 5),
#  (('ganz', 'fest'), 5),
#  (('frau', 'dr.'), 5),
#  (('problem', 'gelöst'), 5),
#  (('mal', 'selber'), 5),
#  (('verrecken', 'lassen'), 5),
#  (('herzlich', 'willkommen'), 5),
#  (('gerade', 'mal'), 5),
#  (('ausländer', 'raus'), 5),
#  (('beim', 'namen'), 5),
#  (('wahrheit', 'sagt'), 5),
#  (('hand', 'nehmen'), 5),
#  (('wäre', 'besser'), 5),
#  (('sagen', 'darf'), 5),
#  (('gar', 'nix'), 5),
#  (('schaut', 'mal'), 5),
#  (('ganz', 'sicher'), 5),
#  (('warum', 'kommt'), 5),
#  (('mal', 'richtig'), 5),
#  (('land', 'verlassen'), 5),
#  (('erste', 'mal'), 5),
#  (('deutsche', 'geschichte'), 5),
#  (('zeug', 'hält'), 5),
#  (('mal', 'gespannt'), 5),
#  (('gespannt', 'wann'), 5),
#  (('medien', 'schweigen'), 5),
#  (('wäre', 'schon'), 5),
#  (('viele', 'jahre'), 5),
#  (('schon', 'vorher'), 5),
#  (('höchste', 'zeit'), 5),
#  (('müssen', 'ja'), 5),
#  (('ernst', 'gemeint'), 5),
#  (('fuß', 'gesetzt'), 5),
#  (('spd', 'grüne'), 5),
#  (('ja', 'gar'), 5),
#  (('lügen', 'lügen'), 5),
#  (('hip-hop', 'song'), 5),
#  (('freie', 'meinung'), 5),
#  (('ne', 'neue'), 5),
#  (('offenen', 'augen'), 5),
#  (('mehr', 'leute'), 5),
#  (('dümmer', 'geht'), 5),
#  (('erster', 'linie'), 5),
#  (('oh', 'nein'), 5),
#  (('sollten', 'mal'), 5),
#  (('unserer', 'politiker'), 5),
#  (('stimmt', 'ja'), 5),
#  (('ne', 'gute'), 5),
#  (('zahlen', 'müssen'), 5),
#  (('deutsch', 'lernen'), 5),
#  (('ja', 'wirklich'), 5),
#  (('ard', 'zdf'), 5),
#  (('mehr', 'normal'), 5),
#  (('unserer', 'kultur'), 5),
#  (('schon', 'beim'), 5),
#  (('ach', 'nee'), 5),
#  (('taschen', 'voll'), 5),
#  (('letzten', 'jahre'), 5),
#  (('klasse', 'rede'), 5),
#  (('vereinigten', 'staaten'), 5),
#  (('albert', 'schweitzer'), 5),
#  (('ganze', 'stadt'), 5),
#  (('jungen', 'menschen'), 5),
#  (('festung', 'europa'), 5),
#  (('deutschland', 'braucht'), 5),
#  (('nächste', 'woche'), 5),
#  (('bitte', 'mal'), 5),
#  (('großen', 'teil'), 5),
#  (('ganzes', 'land'), 5),
#  (('wahre', 'gesicht'), 5),
#  (('völlig', 'egal'), 5),
#  (('wer', 'heute'), 5),
#  (('mal', 'darüber'), 5),
#  (('allahu', 'akbar'), 5),
#  (('bürger', 'wehren'), 5),
#  (('europäische', 'union'), 5),
#  (('la', 'la'), 5),
#  (('junge', 'frau'), 5),
#  (('oesterreich', 'neuwahlen'), 5),
#  (('stärkste', 'partei'), 5),
#  (('fake', 'news'), 5),
#  (('sarah', 'connor'), 5),
#  (('cdu', 'afd'), 5),
#  (('sylvia', 'stolz'), 5),
#  (('hc', 'strache'), 5),
#  (('liebe', 'bessermenschen'), 5),
#  (('afd', 'sachsen'), 5),
#  (('frau', 'steinbach'), 5),
#  (('frau', 'nahles'), 5),
#  (('oh', 'je'), 5),
#  (('auswärtigen', 'amtes'), 5),
#  (('ekelwilfred', 'wiltewka'), 5),
#  (('_k', '_de'), 5),
#  (('döner', 'mehr'), 5),
#  (('merkel', 'vasall'), 5),
#  (('grün', 'versiffte'), 5),
#  (('abgefuckte', 'spd'), 5),
#  (('deutsche', 'botschaft'), 5),
#  (('islamisierung', 'europas'), 4),
#  (('gute', 'nachricht'), 4),
#  (('darf', 'bleiben'), 4),
#  (('sz', 'faz'), 4),
#  (('europa', 'deutschland'), 4),
#  (('mal', 'gesagt'), 4),
#  (('flüchtlinge', 'mehr'), 4),
#  (('make', 'rape'), 4),
#  (('rape', 'legal'), 4),
#  (('warum', 'sollten'), 4),
#  (('deutsche', 'medien'), 4),
#  (('medien', 'berichten'), 4),
#  (('geld', 'bekommen'), 4),
#  (('mehr', 'flüchtlinge'), 4),
#  (('zukunft', 'europas'), 4),
#  (('grenzen', 'schließen'), 4),
#  (('staat', 'bezahlt'), 4),
#  (('müssen', 'zurück'), 4),
#  (('wohl', 'schon'), 4),
#  (('wählt', 'afd'), 4),
#  (('klare', 'aussage'), 4),
#  (('nächsten', 'wahlen'), 4),
#  (('is', 'schon'), 4),
#  (('brutal', 'vergewaltigt'), 4),
#  (('armlänge', 'abstand'), 4),
#  (('paar', 'wochen'), 4),
#  (('prof.', 'schachtschneider'), 4),
#  (('deutsches', 'recht'), 4),
#  (('deutsche', 'steuerzahler'), 4),
#  (('genannten', 'vollzugsbeamten'), 4),
#  (('grenzdienst', 'schußwaffen'), 4),
#  (('personen', 'gebrauchen'), 4),
#  (('wiederholten', 'weisung'), 4),
#  (('etwa', 'mitgeführten'), 4),
#  (('mitgeführten', 'beförderungsmittel'), 4),
#  (('entziehen', 'versuchen'), 4),
#  (('mündliche', 'weisung'), 4),
#  (('warnschuß', 'ersetzt'), 4),
#  (('grenzdienst', 'gilt'), 4),
#  (('absatz', 'bezeichneten'), 4),
#  (('bezeichneten', 'personen'), 4),
#  (('grenzdienst', 'übertragen'), 4),
#  (('letzten', 'tagen'), 4),
#  (('geltendes', 'recht'), 4),
#  (('mundtot', 'gemacht'), 4),
#  (('jahre', 'altes'), 4),
#  (('mehrfach', 'geld'), 4),
#  (('drecks', 'pack'), 4),
#  (('garnicht', 'erst'), 4),
#  (('schon', 'recht'), 4),
#  (('ja', 'nix'), 4),
#  (('ecke', 'gestellt'), 4),
#  (('paar', 'tagen'), 4),
#  (('kriminelle', 'asylbewerber'), 4),
#  (('gehört', 'sofort'), 4),
#  (('herrn', 'jesus'), 4),
#  (('jesus', 'christus'), 4),
#  (('schuld', 'daran'), 4),
#  (('immer', 'schön'), 4),
#  (('dafür', 'verantwortlich'), 4),
#  (('jahren', 'mal'), 4),
#  (('wann', 'kommt'), 4),
#  (('wer', 'denkt'), 4),
#  (('frei', 'erfunden'), 4),
#  (('fragt', 'mal'), 4),
#  (('raus', 'raus'), 4),
#  (('kleine', 'kinder'), 4),
#  (('merkel', 'geht'), 4),
#  (('neues', 'deutschland'), 4),
#  (('schwer', 'verletzt'), 4),
#  (('dumm', 'verkauft'), 4),
#  (('krieg', 'erklärt'), 4),
#  (('einfach', 'ignorieren'), 4),
#  (('denen', 'sowas'), 4),
#  (('jahre', 'zurück'), 4),
#  (('schon', 'jahre'), 4),
#  (('guten', 'alten'), 4),
#  (('damals', 'schon'), 4),
#  (('volk', 'steht'), 4),
#  (('vielleicht', 'sollten'), 4),
#  (('jan', 'böhmermann'), 4),
#  (('aufs', 'maul'), 4),
#  (('geschichte', 'wiederholt'), 4),
#  (('große', 'gefahr'), 4),
#  (('ganzen', 'welt'), 4),
#  (('realität', 'verloren'), 4),
#  (('kim', 'jong'), 4),
#  (('mehr', 'tragbar'), 4),
#  (('liebe', 'leute'), 4),
#  (('flüchtlinge', 'bekommen'), 4),
#  (('gehen', 'dürfen'), 4),
#  (('ganzen', 'tag'), 4),
#  (('wurde', 'schon'), 4),
#  (('radio', 'gehört'), 4),
#  (('gestern', 'abend'), 4),
#  (('leute', 'geht'), 4),
#  (('meinung', 'sagen'), 4),
#  (('mehr', 'sehen'), 4),
#  (('mehr', 'deutsche'), 4),
#  (('wort', 'mehr'), 4),
#  (('heiße', 'luft'), 4),
#  (('ja', 'schließlich'), 4),
#  (('gibt', 'genug'), 4),
#  (('leider', 'gibt'), 4),
#  (('dumme', 'menschen'), 4),
#  (('teilen', 'teilen'), 4),
#  (('polizei', 'lässt'), 4),
#  (('kinder', 'sollen'), 4),
#  (('niemand', 'mehr'), 4),
#  (('geld', 'verdienen'), 4),
#  (('macht', 'ne'), 4),
#  (('wisst', 'schon'), 4),
#  (('lieber', 'mal'), 4),
#  (('passt', 'ja'), 4),
#  (('stolz', 'darauf'), 4),
#  (('deutschland', 'schafft'), 4),
#  (('ddr', 'zeiten'), 4),
#  (('deutschland', 'geht'), 4),
#  (('seit', 'tagen'), 4),
#  (('unterkriegen', 'lassen'), 4),
#  (('viele', 'leute'), 4),
#  (('wen', 'wundert'), 4),
#  (('wandern', 'fälle'), 4),
#  (('angst', 'macht'), 4),
#  (('jahre', 'alten'), 4),
#  (('glauben', 'ab'), 4),
#  (('wäre', 'schön'), 4),
#  (('fast', 'schon'), 4),
#  (('gute', 'arbeit'), 4),
#  (('deutsche', 'rentner'), 4),
#  (('dummes', 'deutschland'), 4),
#  (('danke', 'herr'), 4),
#  (('absolut', 'recht'), 4),
#  (('europäischen', 'länder'), 4),
#  (('tolle', 'frau'), 4),
#  (('sieht', "'s"), 4),
#  (('gute', 'frau'), 4),
#  (('leider', 'schon'), 4),
#  (('bach', 'runter'), 4),
#  (('genau', 'deswegen'), 4),
#  (('regierung', 'mal'), 4),
#  (('illegale', 'einwanderer'), 4),
#  (('deutschland', 'kommen'), 4),
#  (('deutschen', 'volke'), 4),
#  (('islamischen', 'staates'), 4),
#  (('darauf', 'warten'), 4),
#  (('immer', 'stärker'), 4),
#  (('dummen', 'deutschen'), 4),
#  (('straße', 'leben'), 4),
#  (('paar', 'jahre'), 4),
#  (('mehr', 'hören'), 4),
#  (('millionen', 'flüchtlingen'), 4),
#  (('vollkommen', 'recht'), 4),
#  (('genug', 'platz'), 4),
#  (('sollen', 'flüchtlinge'), 4),
#  (('sowas', 'gibt'), 4),
#  (('denen', 'einfach'), 4),
#  (('schon', 'traurig'), 4),
#  (('immer', 'besser'), 4),
#  (('besser', 'wäre'), 4),
#  (('na', 'endlich'), 4),
#  (('herr', 'bosbach'), 4),
#  (('jetzige', 'regierung'), 4),
#  (('steckt', 'dahinter'), 4),
#  (('mehr', 'gibt'), 4),
#  (('wahre', 'worte'), 4),
#  (('sagt', 'mal'), 4),
#  (('merkel', 'co.'), 4),
#  (('denen', 'geht'), 4),
#  (('dran', 'denken'), 4),
#  (('deutsche', 'kinder'), 4),
#  (('menschen', 'aufnehmen'), 4),
#  (('mittlerweile', 'schon'), 4),
#  (('nie', 'gedacht'), 4),
#  (('gelobte', 'land'), 4),
#  (('kopftuch', 'tragen'), 4),
#  (('wer', 'wählt'), 4),
#  (('vernichtung', 'deutschlands'), 4),
#  (('kaum', 'jemand'), 4),
#  (('ja', 'ne'), 4),
#  (('video', 'anzusehen'), 4),
#  (('heute', 'aufgenommen'), 4),
#  (('land', 'bitten'), 4),
#  (('bitten', 'endlich'), 4),
#  (('endlich', 'aufzustehen'), 4),
#  (('aktuelle', 'politik'), 4),
#  (('politik', 'anzugehen'), 4),
#  (('demos', 'schreibt'), 4),
#  (('kommunalpolitiker', 'werdet'), 4),
#  (('werdet', 'einfach'), 4),
#  (('einfach', 'aktiv'), 4),
#  (('traurig', 'wäre'), 4),
#  (('junge', 'kräftige'), 4),
#  (('kräftige', 'männer'), 4),
#  (('wahrheit', 'gesagt'), 4),
#  (('ganz', 'normal'), 4),
#  (('zeit', 'mehr'), 4),
#  (('ab', 'heute'), 4),
#  (('interessanter', 'artikel'), 4),
#  (('bravo', 'tschechien'), 4),
#  (('darüber', 'nachgedacht'), 4),
#  (('fragen', 'warum'), 4),
#  (('öffentlichen', 'raum'), 4),
#  (('erst', 'seit'), 4),
#  (('wolfgang', 'schäuble'), 4),
#  (("'allahu", 'akbar'), 4),
#  (('juni', 'uhr'), 4),
#  (('jahre', 'haft'), 4),
#  (('polizei', 'amp'), 4),
#  (('via', '_news'), 4),
#  (('fc', 'bayern'), 4),
#  (('friday', 'for'), 4),
#  (('vergangenen', 'jahr'), 4),
#  (('afd', '➡️'), 4),
#  (('afd-spitzenkandidat', '_meuthen'), 4),
#  (('strache', 'ep'), 4),
#  (('europawahl', 'meuthen'), 4),
#  (('meuthen', 'euwahl'), 4),
#  (('ibizagate', 'oesterreich'), 4),
#  (('robert', 'habeck'), 4),
#  (('weilesreicht', 'dankespd'), 4),
#  (('mdl', 'köbberling'), 4),
#  (('politische', 'islam'), 4),
#  (('heutigen', 'tage'), 4),
#  (('afd', 'stärkste'), 4),
#  (('deutschland', '🇩🇪'), 4),
#  (('daniel', 'cohn-bendit'), 4),
#  (('jahre', 'alte'), 4),
#  (('ernst', 'cran'), 4),
#  (('deutsches', 'mädchen'), 4),
#  (('illegal', 'eingereiste'), 4),
#  (('matteo', 'salvini'), 4),
#  (('hallo', 'frau'), 4),
#  (('erika', 'steinbach'), 4),
#  (('freiem', 'fuß'), 4),
#  (('horst', 'mahler'), 4),
#  (('afrikanische', 'herrenrasse…'), 4),
#  (('sozial', 'gleichgestellte'), 4),
#  (('gleichgestellte', 'akzeptieren'), 4),
#  (('tages', 'folge'), 4),
#  (('heute', 'abend'), 4),
#  (('medien', 'presse'), 4),
#  (('alias', 'ekelwilfred'), 4),
#  (('richtigen', 'orten'), 4),
#  (('rebeccas', 'verschwinden'), 4),
#  (('euelections', 'ep'), 4),
#  (('twitter-support', 'melden'), 4),
#  (('hetzlichendank', 'abklatschen'), 4),
#  (('linken', 'anarchisten'), 4),
#  (('rassistische', 'ideologie'), 4),
#  (('vasall', 'merkels'), 4),
#  (('wand', 'gestanden'), 4),
#  (('gehirn', 'prothesen'), 4),
#  (('dummes', 'gelaber'), 4),
#  (('auswärtigen', 'amt'), 4),
#  (('abgefuckten', 'altparteien'), 4),
#  (('spd', 'politiker'), 4),
#  (('dreck', 'verrecken'), 4),
#  (('axel', 'stoll'), 4),
#  (('abgefuckte', 'hühnerscheisse'), 4),
#  (('servicezeit', 'wdr'), 4),
#  (('schmoddrigen', 'schwarzen'), 4),
#  (('alten', 'schmoddrigen'), 4),
#  (('lieber', 'hundert'), 4),
#  (('hundert', 'stimmen'), 4),
#  (('religiöse', 'fanatikerin'), 4),
#  (('millionen', 'flüchtlinge'), 3),
#  (('refugeesnotwelcome', 'refugeesgohome'), 3),
#  (('idee', 'gekommen'), 3),
#  (('deutschland', 'mal'), 3),
#  (('afd', 'gibt'), 3),
#  (('lieber', 'horst'), 3),
#  (('neuen', 'asylanten'), 3),
#  (('asylanten', 'flüchtlinge'), 3),
#  (('na', 'toll'), 3),
#  (('spd', 'afd'), 3),
#  (('land', 'lassen'), 3),
#  (('flüchtlinge', 'asylanten'), 3),
#  (('neue', 'asylanten'), 3),
#  (('millionen', 'muslime'), 3),
#  (('all', 'incl'), 3),
#  (('faz', 'zeit'), 3),
#  (('zeit', 'nzz'), 3),
#  (('arme', 'deutsche'), 3),
#  (('wirschaffendas', 'merkel'), 3),
#  (('dank', 'merkel'), 3),
#  (('mehr', 'asylanten'), 3),
#  (('kriminelle', 'asylanten'), 3),
#  (('warum', 'sehen'), 3),
#  (('sichere', 'drittstaaten'), 3),
#  (('wer', 'zahlt'), 3),
#  (('asylanten', 'bekommen'), 3),
#  (('asylanten', 'sollen'), 3),
#  (('macht', 'merkel'), 3),
#  (('deutschen', 'schon'), 3),
#  (('fünf', 'männer'), 3),
#  (('pegida', 'afd'), 3),
#  (('afd', 'cdu'), 3),
#  (('deutschland', 'zerstört'), 3),
#  (('ärzte', 'ingenieure'), 3),
#  (('islamisierung', 'findet'), 3),
#  (('deutsche', 'soldaten'), 3),
#  (('christlichen', 'land'), 3),
#  (('schon', 'mehr'), 3),
#  (('woher', 'kommen'), 3),
#  (('frauen', 'kinder'), 3),
#  (('deutschland', 'afd'), 3),
#  (('vielleicht', 'wäre'), 3),
#  (('alte', 'schachtel'), 3),
#  (('alen', 'r.'), 3),
#  (('deutsche', 'polizei'), 3),
#  (('zwei', 'tage'), 3),
#  (('zehn', 'jahren'), 3),
#  (('liebe', 'menschen'), 3),
#  (('refugees', 'welcome'), 3),
#  (('wesentlich', 'mehr'), 3),
#  (('klingt', 'komisch'), 3),
#  (('wand', 'fahren'), 3),
#  (('immer', 'schon'), 3),
#  (('kommen', 'konnte'), 3),
#  (('denkt', 'daran'), 3),
#  (('eil', 'meldung'), 3),
#  (('anetta', 'kahane'), 3),
#  (('antonio', 'stiftung'), 3),
#  (('ersten', 'mal'), 3),
#  (('rechtliche', 'schritte'), 3),
#  (('kulturelle', 'bereicherung'), 3),
#  (('professor', 'schachtschneider'), 3),
#  (('warum', 'warum'), 3),
#  (('jahre', 'hinweg'), 3),
#  (('altes', 'mädchen'), 3),
#  (('taten', 'folgen'), 3),
#  (('europäischen', 'parlament'), 3),
#  (('mal', 'daran'), 3),
#  (('daran', 'gedacht'), 3),
#  (('nahost', 'abholen'), 3),
#  (('abholen', 'lassen'), 3),
#  (('na', 'sowas'), 3),
#  (('alleinstehende', 'männer'), 3),
#  (('unserer', 'gesellschaft'), 3),
#  (('politische', 'partei'), 3),
#  (('unmöglich', 'macht'), 3),
#  (('präsident', 'zeman'), 3),
#  (('orbán', 'viktor'), 3),
#  (('sehen', 'wer'), 3),
#  (('wand', 'stellen'), 3),
#  (('ganzen', 'scheiß'), 3),
#  (('hoffentlich', 'bald'), 3),
#  (('sofort', 'ausweisen'), 3),
#  (('lassen', 'anstatt'), 3),
#  (('dumm', 'gelaufen'), 3),
#  (('bescheuerten', 'gutmenschen'), 3),
#  (('wahren', 'grund'), 3),
#  (('zurück', 'schicken'), 3),
#  (('fatima', 'roth'), 3),
#  (('macht', 'mal'), 3),
#  (('ganze', 'familie'), 3),
#  (('pack', 'gehört'), 3),
#  (('sollten', 'lieber'), 3),
#  (('ja', 'egal'), 3),
#  (('bestes', 'beispiel'), 3),
#  (('schon', 'garnicht'), 3),
#  (('reicht', 'langsam'), 3),
#  (('soviel', 'geld'), 3),
#  (('hallo', 'freunde'), 3),
#  (('darüber', 'nachdenken'), 3),
#  (('egal', 'woher'), 3),
#  (('affen', 'seit'), 3),
#  (('seit', 'untergebildet'), 3),
#  (('beim', 'schlagen'), 3),
#  (('neuen', 'facharbeiter'), 3),
#  (('hört', 'endlich'), 3),
#  (('wurde', 'bereits'), 3),
#  (('daumen', 'hoch'), 3),
#  (('deutschen', 'patrioten'), 3),
#  (('polizei', 'darf'), 3),
#  (('euro', 'strafe'), 3),
#  (('unserer', 'geschichte'), 3),
#  (('knast', 'stecken'), 3),
#  (('schon', 'lese'), 3),
#  (('judas', '//'), 3),
#  (('lieben', 'erinnert'), 3),
#  (('zuvor', 'gesagt'), 3),
#  (('letzten', 'zeit'), 3),
#  (('zeit', 'spötter'), 3),
#  (('eigenen', 'gottlosen'), 3),
#  (('gottlosen', 'begierden'), 3),
#  (('begierden', 'leben'), 3),
#  (('spaltungen', 'hervorrufen'), 3),
#  (('hervorrufen', 'niedrig'), 3),
#  (('niedrig', 'gesinnte'), 3),
#  (('heute', 'show'), 3),
#  (('rechte', 'ecke'), 3),
#  (('wurde', 'ja'), 3),
#  (('herr', 'putin'), 3),
#  (('hoffentlich', 'findet'), 3),
#  (('sieht', 'ja'), 3),
#  (('deutsche', 'regierung'), 3),
#  (('köpfe', 'einschlagen'), 3),
#  (('geschrieben', 'wurde'), 3),
#  (('schreiben', 'darf'), 3),
#  (('medien', 'verschweigen'), 3),
#  (('nie', 'passiert'), 3),
#  (('deutsch', 'sprechen'), 3),
#  (('volk', 'gegenüber'), 3),
#  (('dachte', 'immer'), 3),
#  (('denke', 'mal'), 3),
#  (('mehr', 'einreisen'), 3),
#  (('oft', 'genug'), 3),
#  (('beim', 'thema'), 3),
#  (('krieg', 'zurück'), 3),
#  (('zurück', 'lassen'), 3),
#  (('wissen', 'ja'), 3),
#  (('zurück', 'geschickt'), 3),
#  (('eigenen', 'leute'), 3),
#  (('wirklich', 'angst'), 3),
#  (('hakim', "'s"), 3),
#  (('gab', "'s"), 3),
#  (('mal', 'interessieren'), 3),
#  (('ja', 'damals'), 3),
#  (('schöne', 'heile'), 3),
#  (('heile', 'welt'), 3),
#  (('wurde', 'immer'), 3),
#  (('gute', 'alte'), 3),
#  (('ans', 'licht'), 3),
#  (('iv', 'empfänger'), 3),
#  (('wäre', 'wäre'), 3),
#  (('beispiel', 'dafür'), 3),
#  (('alten', 'deutschen'), 3),
#  (('mehr', 'wählbar'), 3),
#  (('mehr', 'zahlen'), 3),
#  (('alten', 'menschen'), 3),
#  (('nächsten', 'wahl'), 3),
#  (('land', 'gekämpft'), 3),
#  (('namens', 'merkel'), 3),
#  (('wählen', 'gehen'), 3),
#  (('till', 'schweiger'), 3),
#  (('nazis', 'usw'), 3),
#  (('nächsten', 'tag'), 3),
#  (('weiß', 'gar'), 3),
#  (('ganz', 'große'), 3),
#  (('schon', 'ganz'), 3),
#  (('viele', 'viele'), 3),
#  (('jong', 'merkel'), 3),
#  (('gerade', 'passiert'), 3),
#  (('rechenschaft', 'gezogen'), 3),
#  (('gibt', 'immer'), 3),
#  (('beim', 'zahnarzt'), 3),
#  (('neue', 'zähne'), 3),
#  (('leben', 'lang'), 3),
#  (('deutschen', 'jugendlichen'), 3),
#  (('frau', 'm.'), 3),
#  (('mal', 'drüber'), 3),
#  (('beim', 'arzt'), 3),
#  (('wahres', 'dran'), 3),
#  (('deutsche', 'michel'), 3),
#  (('dringend', 'nötig'), 3),
#  (('schon', 'bald'), 3),
#  (('wäre', 'mal'), 3),
#  (('bürgerwehren', 'bilden'), 3),
#  (('muslimischen', 'ländern'), 3),
#  (('deutschem', 'boden'), 3),
#  (('ruhe', 'lassen'), 3),
#  (('einfach', 'unfassbar'), 3),
#  (('kam', 'heute'), 3),
#  (('eigenes', 'volk'), 3),
#  (('wirklich', 'passiert'), 3),
#  (('wer', 'sowas'), 3),
#  (('sowas', 'macht'), 3),
#  (('mehr', 'verarschen'), 3),
#  (('merkel', 'endlich'), 3),
#  (('typisch', 'deutsche'), 3),
#  (('her', 'gekommen'), 3),
#  (('tatsächlich', 'jemand'), 3),
#  (('jahre', 'dauern'), 3),
#  (('abgelehnt', 'wurde'), 3),
#  (('nix', 'passiert'), 3),
#  (('teppich', 'gekehrt'), 3),
#  (('eh', 'nix'), 3),
#  (('bekommt', 'angst'), 3),
#  (('mehr', 'los'), 3),
#  (('gutes', 'beispiel'), 3),
#  (('grüne', 'fdp'), 3),
#  (('wahlen', 'kommen'), 3),
#  (('beim', 'scheißen'), 3),
#  (('gibt', 'wohl'), 3),
#  (('mehr', 'drauf'), 3),
#  (('einfach', 'unglaublich'), 3),
#  (('per', 'post'), 3),
#  (('thema', 'meinungsfreiheit'), 3),
#  (('nie', 'richtig'), 3),
#  (('ja', 'gerne'), 3),
#  (('mehr', 'weit'), 3),
#  (('ans', 'tageslicht'), 3),
#  (('her', 'kommt'), 3),
#  (('soviel', 'essen'), 3),
#  (('sozialen', 'netzwerken'), 3),
#  (('laufen', 'lassen'), 3),
#  (('sagen', 'müssen'), 3),
#  (('wirklich', 'mal'), 3),
#  (('zunge', 'zergehen'), 3),
#  (('zergehen', 'lassen'), 3),
#  (('neuen', 'freunde'), 3),
#  (('demokratie', 'gibt'), 3),
#  (('richtig', 'los'), 3),
#  (('thilo', 'sarrazin'), 3),
#  (('ja', 'sicher'), 3),
#  (('finanzielle', 'unterstützung'), 3),
#  (('dafür', 'gibt'), 3),
#  (('grenzen', 'schützen'), 3),
#  (('mal', 'sowas'), 3),
#  (('heute', 'ganz'), 3),
#  (('ja', 'erstmal'), 3),
#  (('nazi', 'beschimpft'), 3),
#  (('männer', 'geben'), 3),
#  (('freies', 'deutschland'), 3),
#  (('welt', 'gesetzt'), 3),
#  (('armen', 'traumatisierten'), 3),
#  (('bitte', 'lesen'), 3),
#  (('deutschen', 'medien'), 3),
#  (('iss', 'ja'), 3),
#  (('wort', 'lügenpresse'), 3),
#  (('schwanz', 'ab'), 3),
#  (('natürlich', 'immer'), 3),
#  (('ganz', 'ganz'), 3),
#  (('wort', 'melden'), 3),
#  (('wort', 'deutsch'), 3),
#  (('deutschen', 'pass'), 3),
#  (('bezahlt', 'bekommen'), 3),
#  (('leider', 'wahr'), 3),
#  (('mehr', 'hinzuzufügen'), 3),
#  (('frei', 'rum'), 3),
#  (('felix', 'baumgartner'), 3),
#  (('mal', 'klartext'), 3),
#  (('gerne', 'mal'), 3),
#  (('wann', 'endlich'), 3),
#  (('gutes', 'gelingen'), 3),
#  (('grenzen', 'geschlossen'), 3),
#  (('warum', 'tragen'), 3),
#  (('unmittelbaren', 'zwang'), 3),
#  (('ausübung', 'öffentlicher'), 3),
#  (('öffentlicher', 'gewalt'), 3),
#  (('bundes', 'uzwg'), 3),
#  (('seid', 'ja'), 3),
#  (('vollkommen', 'richtig'), 3),
#  (('wozu', 'brauchen'), 3),
#  (('flüchtlinge', 'schießen'), 3),
#  (('wehrlose', 'menschen'), 3),
#  (('schaden', 'angerichtet'), 3),
#  (('frau', 'maischberger'), 3),
#  (('unserer', 'kanzlerin'), 3),
#  (('frauen', 'vergewaltigen'), 3),
#  (('ganz', 'abgesehen'), 3),
#  (('grund', 'warum'), 3),
#  (('oh', 'wunder'), 3),
#  (('bestimmt', 'schon'), 3),
#  (('deutschland', 'kaputt'), 3),
#  (('mehr', 'kommt'), 3),
#  (('geld', 'wäre'), 3),
#  (('geld', 'fuer'), 3),
#  (('eigenen', 'kinder'), 3),
#  (('land', 'aufgebaut'), 3),
#  (('fette', 'gabriel'), 3),
#  (('mehr', 'raus'), 3),
#  (('alte', 'menschen'), 3),
#  (('heimatland', 'zurück'), 3),
#  (('tag', 'kommen'), 3),
#  (('recht', 'darauf'), 3),
#  (('flaschen', 'sammeln'), 3),
#  (('steuern', 'zahlt'), 3),
#  (('herzlichen', 'glückwunsch'), 3),
#  (('siehe', 'unten'), 3),
#  (('pro', 'monat'), 3),
#  (('steuern', 'zahlen'), 3),
#  (('müssen', 'endlich'), 3),
#  (('davon', 'mal'), 3),
#  (('denen', 'mal'), 3),
#  (('sowas', 'schon'), 3),
#  (('wer', 'gerne'), 3),
#  (('geht', 'los'), 3),
#  (('deutscher', 'staatsbürger'), 3),
#  (('jahren', 'schon'), 3),
#  (('menschen', 'gehören'), 3),
#  (('vorher', 'schon'), 3),
#  (('voller', 'härte'), 3),
#  (('klar', 'denken'), 3),
#  (('oh', 'oh'), 3),
#  (('geht', 'eh'), 3),
#  (('geld', 'verdient'), 3),
#  (('pleite', 'gehen'), 3),
#  (('pro', 'kopf'), 3),
#  (('mehr', 'ganz'), 3),
#  (('rein', 'theoretisch'), 3),
#  (('daran', 'schuld'), 3),
#  (('tolle', 'rede'), 3),
#  (('bravo', 'marine'), 3),
#  (('wegen', 'volksverhetzung'), 3),
#  (('madame', 'le'), 3)]

# %%
def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
save_obj(ngram_dict, "ngrams_hatespeech_without_stopwords")

# %%
def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
load_obj("ngrams_hatespeech_without_stopwords")
# Out:
# {'2-grams': [('schwimmbad', 'gehen'),
#   ('menschenrechte', 'pressefreiheit'),
#   ('pressefreiheit', 'islamisierung'),
#   ('islamisierung', 'wieso'),
#   ('wieso', 'bekommen'),
#   ('bekommen', 'rapefugees'),
#   ('rapefugees', 'mehr'),
#   ('hartz', 'enpfänger'),
#   ('verfluchten', 'rapefugees'),
#   ('krieg', 'erklären'),
#   ('ruhrpott', 'unterwegs'),
#   ('überall', 'schwangere'),
#   ('schwangere', 'muslimische'),
#   ('muslimische', 'frauen'),
#   ('kindern', 'islamisierung'),
#   ('islamisierung', 'asylanteninvasion'),
#   ('gewaltausbrüchen', 'kommt'),
#   ('verantwortlichen', 'hierfür'),
#   ('hierfür', 'sitzen'),
#   ('regierung', 'merkel'),
#   ('millionen', 'menschen'),
#   ('menschen', 'leben'),
#   ('millionen', 'flüchtlinge'),
#   ('flüchtlinge', 'bereiten'),
#   ('rassisten', 'sprechen'),
#   ('flüchtlinge', 'verpassen'),
#   ('refugees', 'refugeesnotwelcome'),
#   ('refugeesnotwelcome', 'refugeesgohome'),
#   ('refugeesgohome', 'abmerkeln'),
#   ('kölner', 'polizei'),
#   ('gestiegene', 'anzeigen'),
#   ('grund', 'frauen'),
#   ('frauen', 'seien'),
#   ('seien', 'anzeigefreudiger'),
#   ('rapefugees', 'offenes'),
#   ('offenes', 'freies'),
#   ('freies', 'wlan'),
#   ('sophienhof', 'kiel'),
#   ('gestern', 'nachmittag'),
#   ('unterdenlinden', 'petry'),
#   ('petry', 'fordert'),
#   ('fordert', 'bessere'),
#   ('bessere', 'regelung'),
#   ('regelung', 'gesetze'),
#   ('richtig', 'warum'),
#   ('hungerstreik', 'rapefugees'),
#   ('rapefugees', 'blutrache'),
#   ('blutrache', 'zwangsbekehrung'),
#   ('zwangsbekehrung', 'scharia'),
#   ('scharia', 'kinderbräute'),
#   ('kinderbräute', 'vielehe'),
#   ('vielehe', 'genitalverstümmelung'),
#   ('worin', 'liegt'),
#   ('deutsche', 'biertrinker'),
#   ('glyphosat', 'dezimieren'),
#   ('claudia', 'roth'),
#   ('roth', 'wer'),
#   ('wer', 'sex-attacken'),
#   ('asylanten', 'anprangert'),
#   ('geistiger', 'bruder'),
#   ('fuck', 'you'),
#   ('you', 'from'),
#   ('from', 'switzerland'),
#   ('asylanten', 'grüne'),
#   ('februar', 'kamen'),
#   ('neusten', 'angaben'),
#   ('ard', 'tagesschau'),
#   ('tagesschau', 'trotz'),
#   ('trotz', 'grenzkontrollen'),
#   ('balkanroute', 'asylanten'),
#   ('verbrechen', 'begangen'),
#   ('menschenwürde.hungerstreik', 'rapefugees'),
#   ('rapefugees', 'merkel'),
#   ('schlampe', 'eigentlich'),
#   ('idee', 'gekommen'),
#   ('merkelmussweg', 'refugeesnotwelcome'),
#   ('farce', 'angesichts'),
#   ('merkeldiktatur', 'vorangetriebenen'),
#   ('vorangetriebenen', 'islamisierung'),
#   ('islamisierung', 'europas'),
#   ('gratis', 'häuser'),
#   ('häuser', 'wohnungen'),
#   ('wohnungen', 'handys'),
#   ('handys', 'u.'),
#   ('u.', 'öffitickets'),
#   ('öffitickets', 'mindestsicherung'),
#   ('mindestsicherung', 'straffreiheit'),
#   ('straffreiheit', 'vorreihung'),
#   ('ambulanzen', 'schlaraffenland'),
#   ('zib', 'asylanten'),
#   ('asylanten', 'beateuhse'),
#   ('beateuhse', 'konzern'),
#   ('konzern', 'vermarktet'),
#   ('vermarktet', 'scharia'),
#   ('scharia', 'konforme'),
#   ('konforme', 'sexprodukte'),
#   ('sexprodukte', 'bitte'),
#   ('bitte', 'boykottiert'),
#   ('laut', 'orban'),
#   ('merkel', 'europa'),
#   ('asylanten', 'fluten'),
#   ('fluten', 'zusätzlich'),
#   ('sowieso', 'kommen'),
#   ('ende', 'gelände'),
#   ('griechenland', 'riesige'),
#   ('riesige', 'asylanten-kontingente'),
#   ('asylanten-kontingente', 'abnehmen'),
#   ('wetten', 'annewill'),
#   ('ernst-grube-halle', 'endlich'),
#   ('endlich', 'geräumt'),
#   ('geräumt', 'leipzig'),
#   ('leipzig', 'npd'),
#   ('npd', 'jn'),
#   ('jn', 'legida'),
#   ('legida', 'refugeesnotwelcome'),
#   ('refugeesnotwelcome', 'illner'),
#   ('erst', 'hieß'),
#   ('top', 'arbeitskräfte'),
#   ('wichsenden', 'vergewaltigenden'),
#   ('vergewaltigenden', 'betrügenden'),
#   ('betrügenden', 'asylanten'),
#   ('volk', 'kümmern'),
#   ('annewill', 'refugees'),
#   ('refugees', 'refugeesnotwelcome'),
#   ('refugeesnotwelcome', 'slovenien'),
#   ('slovenien', 'macht'),
#   ('grenze', 'dicht'),
#   ('gute', 'nachricht'),
#   ('merkelmussweg', 'abmerkeln'),
#   ('abmerkeln', 'refugeesnotwelcome'),
#   ('refugeesnotwelcome', 'luxushotels'),
#   ('asylanten', 'unterkünfte'),
#   ('unterkünfte', 'umfunktioniert'),
#   ('umfunktioniert', 'deutsche'),
#   ('deutsche', 'müssen'),
#   ('primitiven', 'heruntergekommenen'),
#   ('heruntergekommenen', 'slums'),
#   ('slums', 'leben.annewill'),
#   ('leben.annewill', 'ard'),
#   ('ard', 'niemand'),
#   ('asylwahn', 'rapefugees'),
#   ('rapefugees', 'volksentscheid'),
#   ('asylrecht', 'grenzen'),
#   ('grenzen', 'dicht'),
#   ('dicht', 'merkel'),
#   ('ausnahmen', 'beim'),
#   ('beim', 'mindestlohn'),
#   ('scharia', 'vereinbar'),
#   ('moslems', 'betroffen'),
#   ('spd', 'cdu'),
#   ('cdu', 'deutschland'),
#   ('deutschland', 'pöbelnde'),
#   ('pöbelnde', 'asylanten'),
#   ('asylanten', 'zeigen'),
#   ('zeigen', 'kopf-ab-gesten'),
#   ('ermittlungen', 'gg'),
#   ('un', 'flüchtlingshilfe'),
#   ('flüchtlingshilfe', 'asylanten'),
#   ('überfremdung', 'deutschlands'),
#   ('politiker', 'wisst'),
#   ('ganz', 'genau'),
#   ('reicht', 'stopp'),
#   ('klare', 'schlechterstellunf'),
#   ('deutschland', 'mal'),
#   ('eigentlich', 'treffen'),
#   ('rapefugees', 'politiker'),
#   ('politiker', 'ossis'),
#   ('ossis', 'journalisten'),
#   ('d-radio', 'millionen'),
#   ('millionen', 'menschen'),
#   ('menschen', 'fluechtlinge'),
#   ('fluechtlinge', 'migranten'),
#   ('migranten', 'asylanten'),
#   ('tuerkei', 'verhandlungen'),
#   ('erde', 'geld'),
#   ('kranker', 'mensch'),
#   ('mensch', 'genießt'),
#   ('goethe', 'deutschland'),
#   ('deutschland', 'hartziv'),
#   ('hartziv', 'merkel'),
#   ('merkel', 'fluechtlinge'),
#   ('fluechtlinge', 'asylanten'),
#   ('jahr', 'mussten'),
#   ('mussten', 'eltern'),
#   ('schwimmbad', 'gingen'),
#   ('schon', 'schwimmen'),
#   ('rapefugees', 'hartaberfair'),
#   ('eu', 'länder'),
#   ('bürger', 'wichtiger'),
#   ('moralisch', 'ethisch'),
#   ('finanziell', 'verständlich'),
#   ('verständlich', 'besorgtegutmenschen'),
#   ('besorgtegutmenschen', 'regen'),
#   ('asylanten', 'getötet'),
#   ('lageso-toter', 'moabithilft'),
#   ('moabithilft', 'ente'),
#   ('ente', 'handgranate'),
#   ('handgranate', 'warfen'),
#   ('warfen', 'migranten'),
#   ('swr', 'radio'),
#   ('radio', 'momentan'),
#   ('werbung', 'pro'),
#   ('pro', 'asylanten'),
#   ('asylanten', 'gemacht'),
#   ('weihnachtssongs', 'fastnachts-seeligkeit'),
#   ('fastnachts-seeligkeit', 'idee'),
#   ('idee', 'hartzer'),
#   ('hartzer', 'vs'),
#   ('vs', 'asylanten'),
#   ('wer', 'schneller'),
#   ('schneller', 'nen'),
#   ('nen', 'arbeits/ausbildungsplatz'),
#   ('arbeits/ausbildungsplatz', 'findet'),
#   ('deutsch', 'lernt/kann'),
#   ('lernt/kann', 'darf'),
#   ('darf', 'bleiben'),
#   ('bürgerkriegsartigen', 'zuständen'),
#   ('lasche', 'konservative'),
#   ('irre', 'sozialistische'),
#   ('sozialistische', 'regierung'),
#   ('regierung', 'fluten'),
#   ('asylanten', 'utter'),
#   ('utter', 'zbale'),
#   ('this', 'hashtag'),
#   ('hashtag', 'rapefugees'),
#   ('rapefugees', 'gestern'),
#   ('gestern', 'kamen'),
#   ('heute', 'nacht'),
#   ('nacht', 'wurde'),
#   ('wurde', 'versucht'),
#   ('versucht', 'einzubrechen'),
#   ('jahre', 'emanzipation'),
#   ('emanzipation', 'zugunsten'),
#   ('zugunsten', 'islamistischer'),
#   ('islamistischer', 'vergewaltiger'),
#   ('tonne', 'treten'),
#   ('rapefugees', 'afd'),
#   ('afd', 'deutschland'),
#   ('deutschland', 'übt'),
#   ('übt', 'karneval'),
#   ('eh', 'bald'),
#   ('moslems', 'feiern'),
#   ('deutsche', 'frauen'),
#   ('angst', 'zuhause'),
#   ('mond', 'gerade'),
#   ('schon', 'längst'),
#   ('ard', 'asylanten'),
#   ('asylanten', 'fahren'),
#   ('taxi', 'herum'),
#   ('merkel', 'macht'),
#   ('einf', 'verschiedene'),
#   ('verschiedene', 'menschen'),
#   ('menschen', 'bzw'),
#   ('bzw', 'völker/kulturen'),
#   ('völker/kulturen', 'zusammenleg'),
#   ('zusammenleg', 'sagen'),
#   ('seit', 'ma'),
#   ('ma', 'glückl'),
#   ('glückl', 'miteinander+versteht'),
#   ('idomeni', 'asylanten'),
#   ('asylanten', 'fluechtlinge'),
#   ('fluechtlinge', 'schöne'),
#   ('schöne', 'vorstellung'),
#   ('blanke', 'gewalt'),
#   ('merkel', 'drückt'),
#   ('drückt', 'daheim'),
#   ('daheim', 'krokodilstränen'),
#   ('afd', 'gibt'),
#   ('schulsprache', 'islamisierung'),
#   ('islamisierung', 'deutschlands'),
#   ('vollem', 'gange'),
#   ('gange', 'stelle'),
#   ('deutschland', 'einmarschieren'),
#   ('scharia', 'krieg'),
#   ('syrien', 'wer'),
#   ('werner', 'faymann'),
#   ('paradebeispiel', 'dafür'),
#   ('kontingent', 'refugeesnotwelcome'),
#   ('refugeesnotwelcome', 'traurig'),
#   ('traurig', 'lieber'),
#   ('lieber', 'horst'),
#   ('horst', 'seehofer'),
#   ('bayerische', 'staat'),
#   ('staat', 'braucht'),
#   ('islamisierung', 'bayerns'),
#   ('riegel', 'vorschiebt'),
#   ('sz', 'faz'),
#   ('nix', 'mehr'),
#   ('gut', 'außer'),
#   ('außer', 'denen'),
#   ('geklauten', 'handys.maischberger'),
#   ('syrischen', 'pässen'),
#   ('dorthin', 'ausgeflogen'),
#   ('cdu', 'schaffen'),
#   ('weitere', 'millionen'),
#   ('millionen', 'asylanten'),
#   ('dumme', 'bevölkerung'),
#   ('maischberger', 'fratscher'),
#   ('fratscher', 'geld'),
#   ('investition.bis', 'dahin'),
#   ('dahin', 'weiterhin'),
#   ('weiterhin', 'rapefugees'),
#   ('rapefugees', 'islamisierung'),
#   ('is', 'terroristen'),
#   ('abmerkeln', 'egal'),
#   ('annewill', 'einprozent'),
#   ('einprozent', 'grenzendicht'),
#   ('grenzendicht', 'refugees'),
#   ('refugees', 'refugeesnotwelcome'),
#   ('refugeesnotwelcome', 'deutschland'),
#   ('asylanten', 'blockieren'),
#   ('quartalsweise', 'milliarden'),
#   ('milliarden', 'schnorrt'),
#   ('reker', 'beugt'),
#   ('scharia', 'schafft'),
#   ('frauen', 'sicherheitszonen'),
#   ('sicherheitszonen', '=fluchtpunkte'),
#   ('=fluchtpunkte', 'flüchtlinge'),
#   ('flüchtlinge', 'köln'),
#   ('köln', 'massenvergewaltigungen'),
#   ('massenvergewaltigungen', 'maischberger'),
#   ('maischberger', 'liefers'),
#   ('achten', 'frauen'),
#   ('paradies', 'hier.lasche'),
#   ('hier.lasche', 'strafen'),
#   ('vergewaltigungen', 'perlen'),
#   ('redaktionskonferenz', 'heute'),
#   ('heute', 'idee'),
#   ('dresden', 'islamisierung'),
#   ('muslime', 'nopegida'),
#   ('nopegida', 'nolegida'),
#   ('pegida', 'stehen'),
#   ('stehen', 'schulter'),
#   ('zähnen', 'bewaffnet'),
#   ('rapefugees', 'schauhin'),
#   ('schauhin', 'merkel'),
#   ('merkel', 'rechnet'),
#   ('mio', 'neuen'),
#   ('neuen', 'asylanten'),
#   ('vergleich', 'schätzung'),
#   ('dank', 'cdu'),
#   ('schwarzen', 'burkas'),
#   ('rapefugees', 'schade'),
#   ('frei', '-nicht'),
#   ('-nicht', 'mehr'),
#   ('europa', 'deutschland'),
#   ('deutschland', 'sophienhof'),
#   ('sophienhof', 'koelnbhf'),
#   ('koelnbhf', 'merkelmussweg'),
#   ('merkelmussweg', 'islamisierung'),
#   ('islamisierung', 'flüchtlingskrise'),
#   ('flüchtlingskrise', 'wer'),
#   ('deutsche', 'arbeitslose'),
#   ('selben', 'finanz'),
#   ('mittel', 'fordert'),
#   ('asylanten', 'zukommen'),
#   ('gutmenschen', 'vegetarier'),
#   ('vegetarier', 'veganer'),
#   ('tierschützer', 'eigentlich'),
#   ('halal', '-schlachtung'),
#   ('asylanten', 'flüchtlinge'),
#   ('rapefugees', 'nutzt'),
#   ('nutzt', 'kritisiert'),
#   ('inthebox', 'patridiot'),
#   ('na', 'toll'),
#   ('afd', 'wähler'),
#   ('wähler', 'sollen'),
#   ('mehr', 'grund'),
#   ('rapefugees', 'maischberger'),
#   ('maischberger', 'laschet'),
#   ('laschet', 'pegida'),
#   ('pegida', 'gibts'),
#   ('westen', 'nicht.leute'),
#   ('nicht.leute', 'trauen'),
#   ('mitzulaufen', 'wegen'),
#   ('wegen', 'ächtung'),
#   ('umso', 'realer'),
#   ('realer', 'dor'),
#   ('dor', 'beateuhse'),
#   ('beateuhse', 'fördert'),
#   ('fördert', 'scharia'),
#   ('internet-sexshop', 'el'),
#   ('el', 'asira'),
#   ('niederlanden', 'danke'),
#   ('danke', 'clausnitz'),
#   ('seid', 'helden'),
#   ('sos', 'rapefugees'),
#   ('rapefugees', 'koelnhbf'),
#   ('koelnhbf', 'cologne'),
#   ('cologne', 'islamisierung'),
#   ('westdeutschland', 'danke'),
#   ('hartaberfair', 'gesagt'),
#   ('gesagt', 'brechen'),
#   ('ausbildung', 'ab.afd'),
#   ('ab.afd', 'asylanten'),
#   ('asylanten', 'betteln'),
#   ('asylbewerber', 'fluechtlinge'),
#   ('fluechtlinge', 'asylum'),
#   ('weils', 'mal'),
#   ('mal', 'gesagt'),
#   ('gesagt', 'wurde'),
#   ('falsch', 'ab'),
#   ('flüchtlinge', 'mehr'),
#   ('refugeesnotwelcome', 'flüchtlingen'),
#   ('sofort', 'gratis'),
#   ('gratis', 'villen'),
#   ('villen', 'autos'),
#   ('autos', 'auszuhändigen'),
#   ('hungerstreik', 'rapefugees'),
#   ('rapefugees', 'könnten'),
#   ('kriminelle', 'loswerden'),
#   ('beherrschbare', 'zahlen'),
#   ('zahlen', 'runtergehen'),
#   ('asylanten', 'wohl'),
#   ('wohl', 'mitbekommen'),
#   ('linke', 'gutmenschen'),
#   ('gutmenschen', 'antifa'),
#   ('deutsche', 'nation'),
#   ('nation', 'zerstören'),
#   ('deutsche', 'europäische'),
#   ('europäische', 'geschichte'),
#   ('geschichte', 'tradition'),
#   ('tradition', 'bräuche'),
#   ('bräuche', 'sprache'),
#   ('sprache', 'leben'),
#   ('leben', 'lehren'),
#   ('hartaberfair', 'oecd'),
#   ('oecd', 'schätzt'),
#   ('schätzt', 'wachstum'),
#   ('nächsten', 'jahren'),
#   ('asylanten', 'außer'),
#   ('spd', 'afd'),
#   ('spd', 'afd'),
#   ('afd', 'bereicherung'),
#   ('bereicherung', 'flüchtlinge'),
#   ('flüchtlinge', 'spd'),
#   ('spd', 'islamisierung'),
#   ('deutschlandradio', 'kultur'),
#   ('kultur', 'erfahren'),
#   ('islam', 'gg'),
#   ('frauenfreundlichere', 'relion'),
#   ('islamisierung', 'pegida'),
#   ('pegida', 'ca'),
#   ('syrer', 'fliehen'),
#   ('warum', 'kämpft'),
#   ('refugeesnotwelcome', 'fluechtlinge'),
#   ('ard', '+ein'),
#   ('+ein', 'zdfspezial'),
#   ('thema', 'handgranate'),
#   ('maas', 'kretschmann'),
#   ('kretschmann', 'asylanten'),
#   ('asylanten', 'integrierte'),
#   ('abgeschoben', 'illegale'),
#   ('illegale', 'täter'),
#   ('täter', 'dürfen'),
#   ('dürfen', 'bleiben'),
#   ('wieso', 'läuft'),
#   ('refugeescrisis', 'islam'),
#   ('islam', 'rapefugees'),
#   ('rapefugees', 'liebe'),
#   ('liebe', 'gutmenschen'),
#   ('einzelfall', 'asylanten'),
#   ('immer', 'mehr.kiel'),
#   ('mehr.kiel', 'sophienhof'),
#   ('armen', 'asylanten.afd'),
#   ('asylanten.afd', 'frankreich'),
#   ('frankreich', 'sagt'),
#   ('asylanten', 'aufnehmenund'),
#   ('seit', 'jahresbeginn'),
#   ('jahresbeginn', 'schon'),
#   ('merkel', 'verpiss'),
#   ('warum', 'spendet'),
#   ('spendet', 'hoaxmap'),
#   ('asylanten', 'passiert'),
#   ('schlimmste', 'krise'),
#   ('scheiße', 'findet'),
#   ('findet', 'warum'),
#   ('warum', 'wollt'),
#   ('möglichst', 'vielen'),
#   ('vielen', 'asylanten'),
#   ('asylanten', 'zumuten'),
#   ('totalitären', 'ideologie'),
#   ('gesellschaft', 'anzuheizen'),
#   ('anzuheizen', 'taqqiya'),
#   ('taqqiya', 'abmerkeln'),
#   ('abmerkeln', 'deutschland'),
#   ('zwangsmigration', 'aufzwingen.das'),
#   ('aufzwingen.das', 'geht'),
#   ('afd', 'hartaberfair'),
#   ('blog', 'glaube'),
#   ('get', 'rid'),
#   ('rid', 'of'),
#   ('of', 'islam'),
#   ('islam', 'muslims'),
#   ('muslims', 'rapefugees'),
#   ('rapefugees', 'deutschland'),
#   ('staatlichkeit', 'aufgegeben'),
#   ('fugen', 'gehoben'),
#   ('irrsinn', 'islamisierung'),
#   ('islamisierung', 'cdu'),
#   ('cdu', 'hartaberfair'),
#   ('hartaberfair', 'ifo-chef'),
#   ('ifo-chef', 'sinn'),
#   ('sinn', 'warnt'),
#   ('flüchtling', 'kostet'),
#   ('kostet', 'deutschland'),
#   ('asylanten', 'warum'),
#   ('warum', 'wurde'),
#   ('polizei', 'aufgelöst'),
#   ('flüchtlinge', 'flüchtlingskrise'),
#   ('flüchtlingskrise', 'asylanten'),
#   ('asylanten', 'ungarn'),
#   ('volksabstimmung', 'durchführen'),
#   ('refugeesnotwelcome', 'seit'),
#   ('seit', 'beginn'),
#   ('asylflut', 'sprunghafter'),
#   ('sprunghafter', 'anstieg'),
#   ('grenzendicht', 'rapefugees'),
#   ('rapefugees', 'nrw'),
#   ('nrw', 'duisburg-marxloh'),
#   ('anfangder', 'rest'),
#   ('arbeit', 'abmerkeln'),
#   ('abmerkeln', 'islamisierung'),
#   ('islamisierung', 'migranten'),
#   ('clausnitz', 'anzeigen'),
#   ('anzeigen', 'wg'),
#   ('körperlicher', 'angriffe+diebstahl'),
#   ('angriffe+diebstahl', 'eingegangen'),
#   ('kölnhbf', 'polizei'),
#   ('polizei', 'rapefugees'),
#   ('rapefugees', 'handgranate'),
#   ('handgranate', 'asyl'),
#   ('asyl', 'merkel'),
#   ('merkel', 'kiel'),
#   ('kiel', 'wer'),
#   ('blockparteien', 'wählt'),
#   ('wählt', 'macht'),
#   ('kommenden', 'verbrechen'),
#   ('abmerkeln', 'rapefugees'),
#   ('rapefugees', 'afd'),
#   ('afd', 'wählen'),
#   ('deutsche', 'frauen'),
#   ('rapefugees', 'opfern'),
#   ('wasistlinks', 'illner'),
#   ('deutsche', 'wirtschaft'),
#   ('asylanten', 'überschlagen'),
#   ('neuen', 'asylanten'),
#   ('asylanten', 'kampf'),
#   ('asylmafia', 'merkel'),
#   ('gericht', 'stellen'),
#   ('stellen', 'cdu'),
#   ('cdu', 'abwählen'),
#   ('abwählen', 'überall'),
#   ('zuhause', 'aufgenommen'),
#   ('aufgenommen', 'habenkann'),
#   ('ernst', 'nehmen'),
#   ('mio', 'arbeitslose'),
#   ('arbeitslose', 'muslimische'),
#   ('muslimische', 'asylanten'),
#   ('deutsche', 'mehrheit'),
#   ('land', 'lassen'),
#   ('nazis', 'beschimpfen'),
#   ('beschimpfen', 'cdu'),
#   ('islamisierung', 'schon'),
#   ('heutige', 'tagesscheisse'),
#   ('tagesscheisse', 'heist'),
#   ('heist', 'hoaxmap'),
#   ('tätsächlichen', 'vergewaltigungen'),
#   ('wirklich', 'unbequem'),
#   ('islam', 'scharia'),
#   ('scharia', 'salafismus'),
#   ('salafismus', 'multikulti'),
#   ('notwehr', 'afd'),
#   ('afd', 'wählen'),
#   ('kaputt', 'abmaasen'),
#   ('abmaasen', 'regsprecher'),
#   ('regsprecher', 'krimigranten'),
#   ('krimigranten', 'rapefugees'),
#   ('gesagt', 'hätte'),
#   ('hätte', 'domian´'),
#   ('abgefeiert', 'gez'),
#   ('gez', 'wdr'),
#   ('wdr', 'live'),
#   ('live', 'koelnhbf'),
#   ('koelnhbf', 'rapefugees'),
#   ('rapefugees', 'bezeichnend'),
#   ('bezeichnend', 'musl.verbände'),
#   ('musl.verbände', 'schließen'),
#   ('weltoffenheit', 'an.hinterher'),
#   ('hilft', 'islamisierung'),
#   ('islamisierung', 'abmerkeln'),
#   ('abmerkeln', 'gerüchten'),
#   ('gerüchten', 'zufolge'),
#   ('zufolge', 'finden'),
#   ('mittelmeer', 'inzwischen'),
#   ('inzwischen', 'mehr'),
#   ('mehr', 'pässe'),
#   ('flüchtlinge', 'asylanten'),
#   ('asylanten', 'merkel'),
#   ('gern', 'mal'),
#   ('täglichen', 'inländerfeindlichkeit'),
#   ('inländerfeindlichkeit', 'sehen'),
#   ('refugeesnotwelcome', 'brdregime'),
#   ('brdregime', 'volksverräter'),
#   ('volksverräter', 'unrecht'),
#   ('allermeisten', 'immer'),
#   ('eigenen', 'menschenrechte'),
#   ('menschenrechte', 'scharia-basiert'),
#   ('neue', 'asylanten'),
#   ('asylanten', 'kamen'),
#   ('bamf', 'geht'),
#   ('fürs', 'gesamte'),
#   ('gesamte', 'jahr'),
#   ('mal', 'rechnen'),
#   ('kandidaten', 'eigentlich'),
#   ('glaubwürdiger', 'und/oder'),
#   ('und/oder', 'seriöser'),
#   ('tausende', 'neue'),
#   ('neue', 'muslime'),
#   ('muslime', 'millionen'),
#   ('millionen', 'muslime'),
#   ('muslime', 'brauchen'),
#   ('brauchen', 'gebetsräume'),
#   ('gebetsräume', 'bald'),
#   ('tausende', 'moscheen'),
#   ('moscheen', 'gebaut'),
#   ('hinlänglich', 'berichtet'),
#   ('abartig', 'verhalten'),
#   ('davon', 'muß'),
#   ('muß', 'flüchtlinge'),
#   ('flüchtlinge', 'zwangsweise'),
#   ('privathaushalten', 'einzuquartieren'),
#   ('merkel', 'rapefugees'),
#   ('rapefugees', 'vorhersagetweet'),
#   ('vorhersagetweet', 'heimleiter'),
#   ('asylanten', 'heim'),
#   ('clausnitz', 'entlassen'),
#   ('afd', 'mitgliedsoviel'),
#   ('demokratie', 'diskriminierung'),
#   ('höchster', 'stelle'),
#   ('weiteren', 'langzeitarbeitslosen'),
#   ('vergewaltigenden', 'asylanten'),
#   ('asylanten', 'asylanten'),
#   ('asylanten', 'kommen'),
#   ('erbärmlichsten', 'zuständen'),
#   ('taschengeld', 'all'),
#   ('all', 'incl'),
#   ('incl', 'merkel'),
#   ('merkel', 'denkt'),
#   ('schwulenhilfe', 'berlin'),
#   ('berlin', 'richtet'),
#   ('schwule', 'asylanten'),
#   ('asylanten', 'schwulen-unterkünfte'),
#   ('schw.puff', 'könnten'),
#   ('könnten', 'asylanten'),
#   ('recht', 'ominös'),
#   ('wüsste', 'gerne'),
#   ('lokführer', 'hassan'),
#   ('hassan', 'ali'),
#   ('mohammed', 'hießen'),
#   ('hießen', 'fluechtlingskrise'),
#   ('fluechtlingskrise', 'islamisierung'),
#   ('islamisierung', 'dürfen'),
#   ('stuttgart', 'flüchtlinge'),
#   ('rapefugees', 'immer'),
#   ('vfbbvb', 'frau'),
#   ('türkischen', 'wurzeln'),
#   ('wurzeln', 'erzählt'),
#   ('direkt', 'neben'),
#   ('tochter', 'asylanten-heim'),
#   ('asylanten-heim', 'aufmacht'),
#   ('fiese', 'rassistin'),
#   ('rassistin', 'flüchtlinsheime'),
#   ('tag', 'gratis'),
#   ('gratis', 'rinderfilet'),
#   ('rinderfilet', 'serviert'),
#   ('menschenwürde.hungerstreik', 'rapefugees'),
#   ('vorhin', 'jemand'),
#   ('jemand', 'erzählt'),
#   ('handgranate', 'evtl'),
#   ('asylanten', 'selber'),
#   ('selber', 'kam'),
#   ('nie', 'islamisch'),
#   ('islamisierung', 'europas'),
#   ('wirklich', 'läuft'),
#   ('mal', 'samstag'),
#   ('samstag', 'früh'),
#   ('arbeit', 'fahren'),
#   ('fahren', 'asylanten'),
#   ('asylanten', 'domian'),
#   ('domian', 'merkel'),
#   ('.e', 'asylanten'),
#   ('spanien', 'abschieben'),
#   ('überall', 'gespart'),
#   ('arbeitslos', 'sind.das'),
#   ('solidarität', 'heuchlerin'),
#   ('rotherham', 'möglich'),
#   ('islamisierung', 'bereits'),
#   ('bereits', 'stattgefunden'),
#   ('griechenland', 'grenze'),
#   ('grenze', 'mazedonien'),
#   ('radikalen', 'migranten'),
#   ('migranten', 'klar'),
#   ('flüchtlinge', 'mehr'),
#   ('mehr', 'krimigranten'),
#   ('krimigranten', 'rapefugees'),
#   ('rapefugees', 'deutschebank'),
#   ('deutschebank', 'sagt'),
#   ('sagt', 'asylanten'),
#   ('asylanten', 'helfen'),
#   ('wirtschaft.die', 'kompetenz'),
#   ('geschäftszahlen', 'ablesen'),
#   ('warum', 'lädt'),
#   ('normalen', 'bürger'),
#   ('thema', 'asylanten'),
#   ('asylanten', 'geht'),
#   ('cdu', 'regiert'),
#   ('land+bund', 'hartaberfair'),
#   ('hartaberfair', 'schwahn'),
#   ('schwahn', '.das'),
#   ('.das', 'problem'),
#   ('fehlende', 'geld'),
#   ('liebe', 'gemeinden'),
#   ('legen', 'asylanten'),
#   ('asylanten', 'obergrenzen'),
#   ('obergrenzen', 'fest'),
#   ('sz', 'faz'),
#   ('faz', 'zeit'),
#   ('zeit', 'nzz'),
#   ('nzz', 'worauf'),
#   ('worauf', 'warten'),
#   ('warten', 'flüchtlinge'),
#   ('asylanten', 'eigendlich'),
#   ('griechenland', 'europa'),
#   ('benzinabgabe', 'eingeführt'),
#   ('deutsche', 'zahlen'),
#   ('zahlen', 'rekordsteuern'),
#   ('langsames', 'internet'),
#   ('hungerstreik', 'rapefugees'),
#   ('rapefugees', 'gutmenschen'),
#   ('islam', 'unterstützen'),
#   ('bald', 'immer'),
#   ('immer', 'aggressiver'),
#   ('orf', 'zib'),
#   ('zib', 'vergewaltigung'),
#   ('kind', 'hallenbad'),
#   ('hallenbad', 'wien'),
#   ('informationen', 'wg'),
#   ('wg', 'opferschutz'),
#   ('wer', 'glaubt'),
#   ('griechische', 'rentner'),
#   ('griechische', 'marine'),
#   ('türkei', 'bringen'),
#   ('nichte', 'wurde'),
#   ('wurde', 'eltern'),
#   ('gesagt', 'mädchen'),
#   ('mädchen', 'sollen'),
#   ('unterricht', 'kommen'),
#   ('islamisierung', 'merkel'),
#   ('hergeholten', 'kulturbereicherer'),
#   ('kulturbereicherer', 'cdu'),
#   ('cdu', 'wählen'),
#   ('eigene', 'scharia-partei'),
#   ('scharia-partei', 'gründen'),
#   ('abmerkeln', 'amnestyinternational'),
#   ('amnestyinternational', 'heult'),
#   ('schwimmbäder', 'scheissen'),
#   ('hungerstreik', 'rapefugees'),
#   ('freilichtmuseum', 'hessenpark'),
#   ('asylanten', 'nein'),
#   ('nein', 'danke'),
#   ('danke', 'armlaenge'),
#   ('make', 'rape'),
#   ('rape', 'legal'),
#   ('landtagswahlen', 'afd'),
#   ('-stellig', 'abschließen'),
#   ('kaiserin-wählt', 'afd'),
#   ('notwehr', 'nichtwähler'),
#   ('nichtwähler', 'nichtwählen'),
#   ('nichtwählen', 'krimigranten'),
#   ('krimigranten', 'rapefugees'),
#   ('rapefugees', 'karneval'),
#   ('frauen', 'fühlen'),
#   ('weiberfastnacht', 'rapefugees'),
#   ('rapefugees', 'cameron'),
#   ('cameron', 'bringt'),
#   ('außer', 'asylanten'),
#   ('asylanten', 'chaos'),
#   ('chaos', 'regierung'),
#   ('regierung', 'spd'),
#   ('spd', 'fordert'),
#   ('arme', 'deutsche'),
#   ('sexuelle', 'übergriffe'),
#   ('asylanten', 'attakieren'),
#   ('schwimmbad', 'jugendliche'),
#   ('jugendliche', 'mädchen'),
#   ('bekommen', 'daraufhin'),
#   ('daraufhin', 'hausverbot'),
#   ('steuererhöhungen', 'wegen'),
#   ('fachkräfte', 'kommen'),
#   ('kommen', 'erst'),
#   ('wirschaffendas', 'merkel'),
#   ('merkel', 'integration'),
#   ('integration', 'rapefugees'),
#   ('rapefugees', 'spd'),
#   ('spd', 'cdu'),
#   ('cdu', 'religion'),
#   ('islamisierung', 'katholischemissionare'),
#   ('katholischemissionare', 'gnargh'),
#   ('gnargh', 'gegner'),
#   ('nazis', 'gleichzusetzen'),
#   ('einfach', 'falsch'),
#   ('ns-regime', 'clausnitz'),
#   ('clausnitz', 'bautzen'),
#   ('bautzen', 'deutschland'),
#   ('deutschland', 'räumung'),
#   ('refugeesnotwelcome', 'leyen'),
#   ('leyen', 'erklärt'),
#   ('erklärt', 'deutschland'),
#   ('fluechtlinge', 'asylanten'),
#   ('soldaten', 'ausbilden'),
#   ('sichern', 'nichtwähler'),
#   ('macht', 'briefwahl'),
#   ('schnell', 'krimigranten'),
#   ('krimigranten', 'rapefugees'),
#   ('rapefugees', 'stegner'),
#   ('stegner', 'augstein'),
#   ('augstein', 'simonepeter'),
#   ('simonepeter', 'gabriel'),
#   ('gabriel', 'roth'),
#   ('roth', 'künast'),
#   ('rechte', 'ausfressen'),
#   ('afd', 'schuldsind'),
#   ('schuldsind', 'groko'),
#   ('asylanten', 'verantwortlich'),
#   ('dank', 'merkel'),
#   ('merkel', 'mehr'),
#   ('mehr', 'asylanten'),
#   ('asylanten', 'mehr'),
#   ('mehr', 'türken'),
#   ('türken', 'mehr'),
#   ('mehr', 'ausgaben'),
#   ('ausgaben', 'türkei'),
#   ('türkei', 'kommt'),
#   ('cdu', 'abwahl'),
#   ('wurde', 'eigentlich'),
#   ('syrischen', 'ärzten'),
#   ('ja', 'wohl'),
#   ('wohl', 'wahrlich'),
#   ('deutsche', 'wurde'),
#   ('wurde', 'jahre'),
#   ('jahre', 'lang'),
#   ('volk', 'afd'),
#   ('afd', 'merkelmussweg'),
#   ('merkelmussweg', 'pseudo'),
#   ('pseudo', 'sturmwarnung'),
#   ('schutz', 'deutscher'),
#   ('deutscher', 'frauen'),
#   ('düsseldorf', 'karneval'),
#   ('karneval', 'morgenmagazin'),
#   ('morgenmagazin', 'läßt'),
#   ('läßt', 'asylanten'),
#   ('berlinale', 'israelfeindlichen'),
#   ('israelfeindlichen', 'film'),
#   ('film', 'anschauen'),
#   ('davon', 'lernt'),
#   ('lernt', 'schreiben'),
#   ('kitaplatz', 'gilt'),
#   ('flüchtlingskinder', 'fluechtlingskrise'),
#   ('fluechtlingskrise', 'asylanten'),
#   ('asylanten', 'fluechtlinge'),
#   ('fluechtlinge', 'hayali'),
#   ('spanien', 'abschieben'),
#   ('riesige', 'verschuldung'),
#   ('tipp', 'grenzen'),
#   ('grenzen', 'sichern'),
#   ('warum', 'spenden'),
#   ('spenden', 'grüne'),
#   ('grüne', 'cdu'),
#   ('menschen', 'leichter'),
#   ('leichter', 'ausgeben'),
#   ('ausgeben', 'läßt'),
#   ('huldigt', 'invasoren'),
#   ('christen', 'erbarmungslos'),
#   ('erbarmungslos', 'ermorden'),
#   ('rapefugees', 'christen'),
#   ('christen', 'kirche'),
#   ('kirche', 'fpoe'),
#   ('abmerkeln', 'abschieben'),
#   ('abschieben', 'grenzkontrollen'),
#   ('grenzkontrollen', 'islamisierung'),
#   ('islamisierung', 'stoppen'),
#   ('ziehe', 'revolution'),
#   ('zumindest', 'nehmen'),
#   ('marcel', 'proust'),
#   ('proust', 'wehrdich'),
#   ('wehrdich', 'ia'),
#   ('ia', 'stehauf'),
#   ('stehauf', 'srfarena'),
#   ('srfarena', 'svp'),
#   ('svp', 'logik'),
#   ('logik', 'minarette'),
#   ('gefährlich', 'waffen'),
#   ('scharia-staat', 'saudi-arabien'),
#   ('saudi-arabien', 'unbedenklich'),
#   ('regierung', 'schützt'),
#   ('angeblichen', 'sturm'),
#   ('sturm', 'beim'),
#   ('beim', 'rosenmontagszug'),
#   ('gang-rape', 'rapefugees'),
#   ('rapefugees', 'abmerkeln'),
#   ('abmerkeln', 'fluechtlingskrise'),
#   ('bald', 'nachlassen'),
#   ('hohen', 'anforderungen'),
#   ('anforderungen', 'kennen'),
#   ('warum', 'sollten'),
#   ('sollten', 'weibliche'),
#   ('weibliche', 'eindringlinge'),
#   ('eindringlinge', 'eigentlich'),
#   ('rapefugees', 'verhaftungen'),
#   ('armseligen', 'behörde'),
#   ('polizei', 'köln'),
#   ('köln', 'rapefugees'),
#   ('deutschland', 'strömen'),
#   ('weitere', 'etappe'),
#   ('islamisierung', 'erfolgt'),
#   ('erfolgt', 'islamistheproblem'),
#   ('islamistheproblem', 'afd'),
#   ('afd', 'herrlich'),
#   ('herrlich', 'deutsche'),
#   ('deutsche', 'medien'),
#   ('medien', 'berichten'),
#   ('hamburger', 'karnevalumzug'),
#   ('karnevalumzug', 'wurde'),
#   ('wegem', 'sturm'),
#   ('sturm', 'abgesagt'),
#   ('rapefugees', 'straftaten'),
#   ('deutsche', 'nazi'),
#   ('nazi', 'pack'),
#   ('irgendwann', 'entscheiden'),
#   ('mal', 'ernsthaften'),
#   ('ernsthaften', 'widerstand'),
#   ('widerstand', 'leisten.wirschaffendas'),
#   ('leisten.wirschaffendas', 'rapefugees'),
#   ('tag', 'stehen'),
#   ('stehen', 'algerier'),
#   ('algerier', 'marokkaner'),
#   ('afghanen', 'asylanten'),
#   ('asylanten', 'sterntv'),
#   ('sterntv', 'zeigt'),
#   ('asylanten', 'lehnen'),
#   ('lehnen', 'arbeit'),
#   ('arbeit', 'ab'),
#   ('netto', 'verdienen'),
#   ('stimmt', 'führen'),
#   ('gäbe', 'bald'),
#   ('wiederholungstäter', 'mehr'),
#   ('srfarena', 'dsi'),
#   ('dsi', 'handab'),
#   ('rotkäppchenkomplex', 'fütter'),
#   ('fütter', 'lieber'),
#   ('wolf', 'kriminelle'),
#   ('kriminelle', 'asylanten'),
#   ('eigene', 'volk'),
#   ('volk', 'merkel'),
#   ('merkel', 'cdu'),
#   ('cdu', 'friedlicher'),
#   ('friedlicher', 'karneval'),
#   ('zib', 'wolf'),
#   ('wolf', 'heute'),
#   ('einzige', 'zeile'),
#   ('asylanten', 'schweinefleisch'),
#   ('wer', 'saufen'),
#   ('kinder', 'vergewaltigen'),
#   ('vergewaltigen', 'braucht'),
#   ('extra', 'wurst'),
#   ('wurst', 'fuck'),
#   ('fuck', 'refugges'),
#   ('refugges', 'asylpaket'),
#   ('asylpaket', 'endlich'),
#   ('endlich', 'beschlossene'),
#   ('beschlossene', 'sache'),
#   ('asylflut', 'eingedämmt'),
#   ('flüchtlinge', 'flüchtlingspolitik'),
#   ('flüchtlingspolitik', 'asylanten'),
#   ('asylanten', 'islamisierung'),
#   ('unübersehbar', 'stattfindende'),
#   ('stattfindende', 'islamisierung'),
#   ('islamisierung', 'deutschlands'),
#   ('deutschland', 'katastrophal'),
#   ('katastrophal', 'schlecht'),
#   ('schlecht', 'asylchaos'),
#   ('asylchaos', 'abmerkeln'),
#   ('abmerkeln', 'annewill'),
#   ('annewill', 'islamisierung'),
#   ('gerade', 'unterwerfung'),
#   ('unterwerfung', 'gelesen'),
#   ('asylant', 'verkleidet'),
#   ('fasnacht', 'frauen'),
#   ('frauen', 'begrabschen'),
#   ...],
#  '3-grams': [('menschenrechte', 'pressefreiheit', 'islamisierung'),
#   ('pressefreiheit', 'islamisierung', 'wieso'),
#   ('islamisierung', 'wieso', 'bekommen'),
#   ('wieso', 'bekommen', 'rapefugees'),
#   ('bekommen', 'rapefugees', 'mehr'),
#   ('überall', 'schwangere', 'muslimische'),
#   ('schwangere', 'muslimische', 'frauen'),
#   ('kindern', 'islamisierung', 'asylanteninvasion'),
#   ('verantwortlichen', 'hierfür', 'sitzen'),
#   ('millionen', 'menschen', 'leben'),
#   ('millionen', 'flüchtlinge', 'bereiten'),
#   ('refugees', 'refugeesnotwelcome', 'refugeesgohome'),
#   ('refugeesnotwelcome', 'refugeesgohome', 'abmerkeln'),
#   ('grund', 'frauen', 'seien'),
#   ('frauen', 'seien', 'anzeigefreudiger'),
#   ('rapefugees', 'offenes', 'freies'),
#   ('offenes', 'freies', 'wlan'),
#   ('unterdenlinden', 'petry', 'fordert'),
#   ('petry', 'fordert', 'bessere'),
#   ('fordert', 'bessere', 'regelung'),
#   ('bessere', 'regelung', 'gesetze'),
#   ('hungerstreik', 'rapefugees', 'blutrache'),
#   ('rapefugees', 'blutrache', 'zwangsbekehrung'),
#   ('blutrache', 'zwangsbekehrung', 'scharia'),
#   ('zwangsbekehrung', 'scharia', 'kinderbräute'),
#   ('scharia', 'kinderbräute', 'vielehe'),
#   ('kinderbräute', 'vielehe', 'genitalverstümmelung'),
#   ('claudia', 'roth', 'wer'),
#   ('roth', 'wer', 'sex-attacken'),
#   ('geistiger', 'bruder', '“'),
#   ('fuck', 'you', 'from'),
#   ('you', 'from', 'switzerland'),
#   ('ard', 'tagesschau', 'trotz'),
#   ('tagesschau', 'trotz', 'grenzkontrollen'),
#   ('menschenwürde.hungerstreik', 'rapefugees', 'merkel'),
#   ('merkeldiktatur', 'vorangetriebenen', 'islamisierung'),
#   ('vorangetriebenen', 'islamisierung', 'europas'),
#   ('gratis', 'häuser', 'wohnungen'),
#   ('häuser', 'wohnungen', 'handys'),
#   ('wohnungen', 'handys', 'u.'),
#   ('handys', 'u.', 'öffitickets'),
#   ('u.', 'öffitickets', 'mindestsicherung'),
#   ('öffitickets', 'mindestsicherung', 'straffreiheit'),
#   ('mindestsicherung', 'straffreiheit', 'vorreihung'),
#   ('ambulanzen', 'schlaraffenland', 'ö'),
#   ('zib', 'asylanten', 'beateuhse'),
#   ('asylanten', 'beateuhse', 'konzern'),
#   ('beateuhse', 'konzern', 'vermarktet'),
#   ('konzern', 'vermarktet', 'scharia'),
#   ('vermarktet', 'scharia', 'konforme'),
#   ('scharia', 'konforme', 'sexprodukte'),
#   ('konforme', 'sexprodukte', 'bitte'),
#   ('sexprodukte', 'bitte', 'boykottiert'),
#   ('asylanten', 'fluten', 'zusätzlich'),
#   ('ende', 'gelände', 'd'),
#   ('griechenland', 'riesige', 'asylanten-kontingente'),
#   ('riesige', 'asylanten-kontingente', 'abnehmen'),
#   ('ernst-grube-halle', 'endlich', 'geräumt'),
#   ('endlich', 'geräumt', 'leipzig'),
#   ('geräumt', 'leipzig', 'npd'),
#   ('leipzig', 'npd', 'jn'),
#   ('npd', 'jn', 'legida'),
#   ('jn', 'legida', 'refugeesnotwelcome'),
#   ('legida', 'refugeesnotwelcome', 'illner'),
#   ('wichsenden', 'vergewaltigenden', 'betrügenden'),
#   ('vergewaltigenden', 'betrügenden', 'asylanten'),
#   ('annewill', 'refugees', 'refugeesnotwelcome'),
#   ('refugees', 'refugeesnotwelcome', 'slovenien'),
#   ('refugeesnotwelcome', 'slovenien', 'macht'),
#   ('merkelmussweg', 'abmerkeln', 'refugeesnotwelcome'),
#   ('abmerkeln', 'refugeesnotwelcome', 'luxushotels'),
#   ('asylanten', 'unterkünfte', 'umfunktioniert'),
#   ('unterkünfte', 'umfunktioniert', 'deutsche'),
#   ('umfunktioniert', 'deutsche', 'müssen'),
#   ('primitiven', 'heruntergekommenen', 'slums'),
#   ('heruntergekommenen', 'slums', 'leben.annewill'),
#   ('slums', 'leben.annewill', 'ard'),
#   ('leben.annewill', 'ard', 'niemand'),
#   ('asylwahn', 'rapefugees', 'volksentscheid'),
#   ('asylrecht', 'grenzen', 'dicht'),
#   ('grenzen', 'dicht', 'merkel'),
#   ('ausnahmen', 'beim', 'mindestlohn'),
#   ('spd', 'cdu', 'deutschland'),
#   ('cdu', 'deutschland', 'pöbelnde'),
#   ('deutschland', 'pöbelnde', 'asylanten'),
#   ('pöbelnde', 'asylanten', 'zeigen'),
#   ('asylanten', 'zeigen', 'kopf-ab-gesten'),
#   ('un', 'flüchtlingshilfe', 'asylanten'),
#   ('rapefugees', 'politiker', 'ossis'),
#   ('politiker', 'ossis', 'journalisten'),
#   ('d-radio', 'millionen', 'menschen'),
#   ('millionen', 'menschen', 'fluechtlinge'),
#   ('menschen', 'fluechtlinge', 'migranten'),
#   ('fluechtlinge', 'migranten', 'asylanten'),
#   ('kranker', 'mensch', 'genießt'),
#   ('goethe', 'deutschland', 'hartziv'),
#   ('deutschland', 'hartziv', 'merkel'),
#   ('hartziv', 'merkel', 'fluechtlinge'),
#   ('merkel', 'fluechtlinge', 'asylanten'),
#   ('jahr', 'mussten', 'eltern'),
#   ('finanziell', 'verständlich', 'besorgtegutmenschen'),
#   ('verständlich', 'besorgtegutmenschen', 'regen'),
#   ('lageso-toter', 'moabithilft', 'ente'),
#   ('moabithilft', 'ente', 'handgranate'),
#   ('ente', 'handgranate', 'warfen'),
#   ('handgranate', 'warfen', 'migranten'),
#   ('swr', 'radio', 'momentan'),
#   ('werbung', 'pro', 'asylanten'),
#   ('pro', 'asylanten', 'gemacht'),
#   ('weihnachtssongs', 'fastnachts-seeligkeit', 'idee'),
#   ('fastnachts-seeligkeit', 'idee', 'hartzer'),
#   ('idee', 'hartzer', 'vs'),
#   ('hartzer', 'vs', 'asylanten'),
#   ('wer', 'schneller', 'nen'),
#   ('schneller', 'nen', 'arbeits/ausbildungsplatz'),
#   ('nen', 'arbeits/ausbildungsplatz', 'findet'),
#   ('deutsch', 'lernt/kann', 'darf'),
#   ('lernt/kann', 'darf', 'bleiben'),
#   ('irre', 'sozialistische', 'regierung'),
#   ('sozialistische', 'regierung', 'fluten'),
#   ('asylanten', 'utter', 'zbale'),
#   ('this', 'hashtag', 'rapefugees'),
#   ('hashtag', 'rapefugees', 'gestern'),
#   ('rapefugees', 'gestern', 'kamen'),
#   ('heute', 'nacht', 'wurde'),
#   ('nacht', 'wurde', 'versucht'),
#   ('wurde', 'versucht', 'einzubrechen'),
#   ('jahre', 'emanzipation', 'zugunsten'),
#   ('emanzipation', 'zugunsten', 'islamistischer'),
#   ('zugunsten', 'islamistischer', 'vergewaltiger'),
#   ('rapefugees', 'afd', 'deutschland'),
#   ('afd', 'deutschland', 'übt'),
#   ('deutschland', 'übt', 'karneval'),
#   ('ard', 'asylanten', 'fahren'),
#   ('einf', 'verschiedene', 'menschen'),
#   ('verschiedene', 'menschen', 'bzw'),
#   ('menschen', 'bzw', 'völker/kulturen'),
#   ('bzw', 'völker/kulturen', 'zusammenleg'),
#   ('völker/kulturen', 'zusammenleg', 'sagen'),
#   ('seit', 'ma', 'glückl'),
#   ('ma', 'glückl', 'miteinander+versteht'),
#   ('idomeni', 'asylanten', 'fluechtlinge'),
#   ('asylanten', 'fluechtlinge', 'schöne'),
#   ('fluechtlinge', 'schöne', 'vorstellung'),
#   ('merkel', 'drückt', 'daheim'),
#   ('drückt', 'daheim', 'krokodilstränen'),
#   ('schulsprache', 'islamisierung', 'deutschlands'),
#   ('vollem', 'gange', 'stelle'),
#   ('kontingent', 'refugeesnotwelcome', 'traurig'),
#   ('refugeesnotwelcome', 'traurig', 'lieber'),
#   ('traurig', 'lieber', 'horst'),
#   ('lieber', 'horst', 'seehofer'),
#   ('bayerische', 'staat', 'braucht'),
#   ('gut', 'außer', 'denen'),
#   ('weitere', 'millionen', 'asylanten'),
#   ('maischberger', 'fratscher', 'geld'),
#   ('investition.bis', 'dahin', 'weiterhin'),
#   ('dahin', 'weiterhin', 'rapefugees'),
#   ('weiterhin', 'rapefugees', 'islamisierung'),
#   ('annewill', 'einprozent', 'grenzendicht'),
#   ('einprozent', 'grenzendicht', 'refugees'),
#   ('grenzendicht', 'refugees', 'refugeesnotwelcome'),
#   ('refugees', 'refugeesnotwelcome', 'deutschland'),
#   ('quartalsweise', 'milliarden', 'schnorrt'),
#   ('frauen', 'sicherheitszonen', '=fluchtpunkte'),
#   ('sicherheitszonen', '=fluchtpunkte', 'flüchtlinge'),
#   ('=fluchtpunkte', 'flüchtlinge', 'köln'),
#   ('flüchtlinge', 'köln', 'massenvergewaltigungen'),
#   ('köln', 'massenvergewaltigungen', 'maischberger'),
#   ('massenvergewaltigungen', 'maischberger', 'liefers'),
#   ('paradies', 'hier.lasche', 'strafen'),
#   ('redaktionskonferenz', 'heute', 'idee'),
#   ('muslime', 'nopegida', 'nolegida'),
#   ('pegida', 'stehen', 'schulter'),
#   ('rapefugees', 'schauhin', 'merkel'),
#   ('schauhin', 'merkel', 'rechnet'),
#   ('mio', 'neuen', 'asylanten'),
#   ('frei', '-nicht', 'mehr'),
#   ('europa', 'deutschland', 'sophienhof'),
#   ('deutschland', 'sophienhof', 'koelnbhf'),
#   ('sophienhof', 'koelnbhf', 'merkelmussweg'),
#   ('koelnbhf', 'merkelmussweg', 'islamisierung'),
#   ('merkelmussweg', 'islamisierung', 'flüchtlingskrise'),
#   ('islamisierung', 'flüchtlingskrise', 'wer'),
#   ('gutmenschen', 'vegetarier', 'veganer'),
#   ('rapefugees', 'nutzt', 'kritisiert'),
#   ('afd', 'wähler', 'sollen'),
#   ('rapefugees', 'maischberger', 'laschet'),
#   ('maischberger', 'laschet', 'pegida'),
#   ('laschet', 'pegida', 'gibts'),
#   ('westen', 'nicht.leute', 'trauen'),
#   ('mitzulaufen', 'wegen', 'ächtung'),
#   ('umso', 'realer', 'dor'),
#   ('realer', 'dor', 'beateuhse'),
#   ('dor', 'beateuhse', 'fördert'),
#   ('beateuhse', 'fördert', 'scharia'),
#   ('internet-sexshop', 'el', 'asira'),
#   ('niederlanden', 'danke', 'clausnitz'),
#   ('sos', 'rapefugees', 'koelnhbf'),
#   ('rapefugees', 'koelnhbf', 'cologne'),
#   ('koelnhbf', 'cologne', 'islamisierung'),
#   ('hartaberfair', 'gesagt', 'brechen'),
#   ('ausbildung', 'ab.afd', 'asylanten'),
#   ('ab.afd', 'asylanten', 'betteln'),
#   ('asylbewerber', 'fluechtlinge', 'asylum'),
#   ('weils', 'mal', 'gesagt'),
#   ('mal', 'gesagt', 'wurde'),
#   ('sofort', 'gratis', 'villen'),
#   ('gratis', 'villen', 'autos'),
#   ('villen', 'autos', 'auszuhändigen'),
#   ('hungerstreik', 'rapefugees', 'könnten'),
#   ('beherrschbare', 'zahlen', 'runtergehen'),
#   ('asylanten', 'wohl', 'mitbekommen'),
#   ('linke', 'gutmenschen', 'antifa'),
#   ('deutsche', 'nation', 'zerstören'),
#   ('deutsche', 'europäische', 'geschichte'),
#   ('europäische', 'geschichte', 'tradition'),
#   ('geschichte', 'tradition', 'bräuche'),
#   ('tradition', 'bräuche', 'sprache'),
#   ('bräuche', 'sprache', 'leben'),
#   ('sprache', 'leben', 'lehren'),
#   ('hartaberfair', 'oecd', 'schätzt'),
#   ('oecd', 'schätzt', 'wachstum'),
#   ('spd', 'afd', 'bereicherung'),
#   ('afd', 'bereicherung', 'flüchtlinge'),
#   ('bereicherung', 'flüchtlinge', 'spd'),
#   ('flüchtlinge', 'spd', 'islamisierung'),
#   ('deutschlandradio', 'kultur', 'erfahren'),
#   ('islamisierung', 'pegida', 'ca'),
#   ('ard', '+ein', 'zdfspezial'),
#   ('maas', 'kretschmann', 'asylanten'),
#   ('kretschmann', 'asylanten', 'integrierte'),
#   ('abgeschoben', 'illegale', 'täter'),
#   ('illegale', 'täter', 'dürfen'),
#   ('täter', 'dürfen', 'bleiben'),
#   ('refugeescrisis', 'islam', 'rapefugees'),
#   ('islam', 'rapefugees', 'liebe'),
#   ('rapefugees', 'liebe', 'gutmenschen'),
#   ('immer', 'mehr.kiel', 'sophienhof'),
#   ('armen', 'asylanten.afd', 'frankreich'),
#   ('asylanten.afd', 'frankreich', 'sagt'),
#   ('seit', 'jahresbeginn', 'schon'),
#   ('jahresbeginn', 'schon', 't'),
#   ('warum', 'spendet', 'hoaxmap'),
#   ('scheiße', 'findet', 'warum'),
#   ('findet', 'warum', 'wollt'),
#   ('möglichst', 'vielen', 'asylanten'),
#   ('vielen', 'asylanten', 'zumuten'),
#   ('gesellschaft', 'anzuheizen', 'taqqiya'),
#   ('anzuheizen', 'taqqiya', 'abmerkeln'),
#   ('taqqiya', 'abmerkeln', 'deutschland'),
#   ('zwangsmigration', 'aufzwingen.das', 'geht'),
#   ('get', 'rid', 'of'),
#   ('rid', 'of', 'islam'),
#   ('of', 'islam', 'muslims'),
#   ('islam', 'muslims', 'rapefugees'),
#   ('muslims', 'rapefugees', 'deutschland'),
#   ('irrsinn', 'islamisierung', 'cdu'),
#   ('islamisierung', 'cdu', 'hartaberfair'),
#   ('cdu', 'hartaberfair', 'ifo-chef'),
#   ('hartaberfair', 'ifo-chef', 'sinn'),
#   ('ifo-chef', 'sinn', 'warnt'),
#   ('flüchtling', 'kostet', 'deutschland'),
#   ('asylanten', 'warum', 'wurde'),
#   ('flüchtlinge', 'flüchtlingskrise', 'asylanten'),
#   ('flüchtlingskrise', 'asylanten', 'ungarn'),
#   ('refugeesnotwelcome', 'seit', 'beginn'),
#   ('asylflut', 'sprunghafter', 'anstieg'),
#   ('grenzendicht', 'rapefugees', 'nrw'),
#   ('rapefugees', 'nrw', 'duisburg-marxloh'),
#   ('arbeit', 'abmerkeln', 'islamisierung'),
#   ('abmerkeln', 'islamisierung', 'migranten'),
#   ('clausnitz', 'anzeigen', 'wg'),
#   ('körperlicher', 'angriffe+diebstahl', 'eingegangen'),
#   ('kölnhbf', 'polizei', 'rapefugees'),
#   ('polizei', 'rapefugees', 'handgranate'),
#   ('rapefugees', 'handgranate', 'asyl'),
#   ('handgranate', 'asyl', 'merkel'),
#   ('asyl', 'merkel', 'kiel'),
#   ('merkel', 'kiel', 'wer'),
#   ('blockparteien', 'wählt', 'macht'),
#   ('abmerkeln', 'rapefugees', 'afd'),
#   ('rapefugees', 'afd', 'wählen'),
#   ('neuen', 'asylanten', 'kampf'),
#   ('gericht', 'stellen', 'cdu'),
#   ('stellen', 'cdu', 'abwählen'),
#   ('cdu', 'abwählen', 'überall'),
#   ('zuhause', 'aufgenommen', 'habenkann'),
#   ('mio', 'arbeitslose', 'muslimische'),
#   ('arbeitslose', 'muslimische', 'asylanten'),
#   ('nazis', 'beschimpfen', 'cdu'),
#   ('heutige', 'tagesscheisse', 'heist'),
#   ('tagesscheisse', 'heist', 'hoaxmap'),
#   ('islam', 'scharia', 'salafismus'),
#   ('scharia', 'salafismus', 'multikulti'),
#   ('notwehr', 'afd', 'wählen'),
#   ('kaputt', 'abmaasen', 'regsprecher'),
#   ('abmaasen', 'regsprecher', 'krimigranten'),
#   ('regsprecher', 'krimigranten', 'rapefugees'),
#   ('gesagt', 'hätte', 'domian´'),
#   ('abgefeiert', 'gez', 'wdr'),
#   ('gez', 'wdr', 'live'),
#   ('wdr', 'live', 'koelnhbf'),
#   ('live', 'koelnhbf', 'rapefugees'),
#   ('koelnhbf', 'rapefugees', 'bezeichnend'),
#   ('rapefugees', 'bezeichnend', 'musl.verbände'),
#   ('bezeichnend', 'musl.verbände', 'schließen'),
#   ('hilft', 'islamisierung', 'abmerkeln'),
#   ('islamisierung', 'abmerkeln', 'gerüchten'),
#   ('abmerkeln', 'gerüchten', 'zufolge'),
#   ('gerüchten', 'zufolge', 'finden'),
#   ('mittelmeer', 'inzwischen', 'mehr'),
#   ('inzwischen', 'mehr', 'pässe'),
#   ('flüchtlinge', 'asylanten', 'merkel'),
#   ('täglichen', 'inländerfeindlichkeit', 'sehen'),
#   ('refugeesnotwelcome', 'brdregime', 'volksverräter'),
#   ('brdregime', 'volksverräter', 'unrecht'),
#   ('eigenen', 'menschenrechte', 'scharia-basiert'),
#   ('neue', 'asylanten', 'kamen'),
#   ('fürs', 'gesamte', 'jahr'),
#   ('glaubwürdiger', 'und/oder', 'seriöser'),
#   ('tausende', 'neue', 'muslime'),
#   ('neue', 'muslime', 'millionen'),
#   ('muslime', 'millionen', 'muslime'),
#   ('millionen', 'muslime', 'brauchen'),
#   ('muslime', 'brauchen', 'gebetsräume'),
#   ('brauchen', 'gebetsräume', 'bald'),
#   ('tausende', 'moscheen', 'gebaut'),
#   ('davon', 'muß', 'flüchtlinge'),
#   ('muß', 'flüchtlinge', 'zwangsweise'),
#   ('merkel', 'rapefugees', 'vorhersagetweet'),
#   ('rapefugees', 'vorhersagetweet', 'heimleiter'),
#   ('vergewaltigenden', 'asylanten', 'asylanten'),
#   ('asylanten', 'asylanten', 'kommen'),
#   ('taschengeld', 'all', 'incl'),
#   ('all', 'incl', 'merkel'),
#   ('incl', 'merkel', 'denkt'),
#   ('schwulenhilfe', 'berlin', 'richtet'),
#   ('schwule', 'asylanten', 'schwulen-unterkünfte'),
#   ('schw.puff', 'könnten', 'asylanten'),
#   ('lokführer', 'hassan', 'ali'),
#   ('mohammed', 'hießen', 'fluechtlingskrise'),
#   ('hießen', 'fluechtlingskrise', 'islamisierung'),
#   ('fluechtlingskrise', 'islamisierung', 'dürfen'),
#   ('vfbbvb', 'frau', 'm'),
#   ('türkischen', 'wurzeln', 'erzählt'),
#   ('tochter', 'asylanten-heim', 'aufmacht'),
#   ('fiese', 'rassistin', 'flüchtlinsheime'),
#   ('tag', 'gratis', 'rinderfilet'),
#   ('gratis', 'rinderfilet', 'serviert'),
#   ('vorhin', 'jemand', 'erzählt'),
#   ('asylanten', 'selber', 'kam'),
#   ('mal', 'samstag', 'früh'),
#   ('arbeit', 'fahren', 'asylanten'),
#   ('fahren', 'asylanten', 'domian'),
#   ('asylanten', 'domian', 'merkel'),
#   ('islamisierung', 'bereits', 'stattgefunden'),
#   ('griechenland', 'grenze', 'mazedonien'),
#   ('radikalen', 'migranten', 'klar'),
#   ('flüchtlinge', 'mehr', 'krimigranten'),
#   ('mehr', 'krimigranten', 'rapefugees'),
#   ('krimigranten', 'rapefugees', 'deutschebank'),
#   ('rapefugees', 'deutschebank', 'sagt'),
#   ('deutschebank', 'sagt', 'asylanten'),
#   ('sagt', 'asylanten', 'helfen'),
#   ('thema', 'asylanten', 'geht'),
#   ('land+bund', 'hartaberfair', 'schwahn'),
#   ('hartaberfair', 'schwahn', '.das'),
#   ('schwahn', '.das', 'problem'),
#   ('legen', 'asylanten', 'obergrenzen'),
#   ('asylanten', 'obergrenzen', 'fest'),
#   ('sz', 'faz', 'zeit'),
#   ('faz', 'zeit', 'nzz'),
#   ('zeit', 'nzz', 'worauf'),
#   ('nzz', 'worauf', 'warten'),
#   ('worauf', 'warten', 'flüchtlinge'),
#   ('deutsche', 'zahlen', 'rekordsteuern'),
#   ('hungerstreik', 'rapefugees', 'gutmenschen'),
#   ('bald', 'immer', 'aggressiver'),
#   ('orf', 'zib', 'vergewaltigung'),
#   ('kind', 'hallenbad', 'wien'),
#   ('informationen', 'wg', 'opferschutz'),
#   ('nichte', 'wurde', 'eltern'),
#   ('gesagt', 'mädchen', 'sollen'),
#   ('hergeholten', 'kulturbereicherer', 'cdu'),
#   ('kulturbereicherer', 'cdu', 'wählen'),
#   ('eigene', 'scharia-partei', 'gründen'),
#   ('abmerkeln', 'amnestyinternational', 'heult'),
#   ('amnestyinternational', 'heult', 'h'),
#   ('asylanten', 'nein', 'danke'),
#   ('nein', 'danke', 'armlaenge'),
#   ('make', 'rape', 'legal'),
#   ('notwehr', 'nichtwähler', 'nichtwählen'),
#   ('nichtwähler', 'nichtwählen', 'krimigranten'),
#   ('nichtwählen', 'krimigranten', 'rapefugees'),
#   ('krimigranten', 'rapefugees', 'karneval'),
#   ('weiberfastnacht', 'rapefugees', 'cameron'),
#   ('rapefugees', 'cameron', 'bringt'),
#   ('außer', 'asylanten', 'chaos'),
#   ('asylanten', 'chaos', 'regierung'),
#   ('chaos', 'regierung', 'spd'),
#   ('regierung', 'spd', 'fordert'),
#   ('schwimmbad', 'jugendliche', 'mädchen'),
#   ('bekommen', 'daraufhin', 'hausverbot'),
#   ('fachkräfte', 'kommen', 'erst'),
#   ('wirschaffendas', 'merkel', 'integration'),
#   ('merkel', 'integration', 'rapefugees'),
#   ('integration', 'rapefugees', 'spd'),
#   ('rapefugees', 'spd', 'cdu'),
#   ('spd', 'cdu', 'religion'),
#   ('islamisierung', 'katholischemissionare', 'gnargh'),
#   ('katholischemissionare', 'gnargh', 'gegner'),
#   ('ns-regime', 'clausnitz', 'bautzen'),
#   ('clausnitz', 'bautzen', 'deutschland'),
#   ('bautzen', 'deutschland', 'räumung'),
#   ('refugeesnotwelcome', 'leyen', 'erklärt'),
#   ('leyen', 'erklärt', 'deutschland'),
#   ('schnell', 'krimigranten', 'rapefugees'),
#   ('krimigranten', 'rapefugees', 'stegner'),
#   ('rapefugees', 'stegner', 'augstein'),
#   ('stegner', 'augstein', 'simonepeter'),
#   ('augstein', 'simonepeter', 'gabriel'),
#   ('simonepeter', 'gabriel', 'roth'),
#   ('gabriel', 'roth', 'künast'),
#   ('afd', 'schuldsind', 'groko'),
#   ('schuldsind', 'groko', 'u'),
#   ('dank', 'merkel', 'mehr'),
#   ('merkel', 'mehr', 'asylanten'),
#   ('mehr', 'asylanten', 'mehr'),
#   ('asylanten', 'mehr', 'türken'),
#   ('mehr', 'türken', 'mehr'),
#   ('türken', 'mehr', 'ausgaben'),
#   ('mehr', 'ausgaben', 'türkei'),
#   ('ausgaben', 'türkei', 'kommt'),
#   ('ja', 'wohl', 'wahrlich'),
#   ('deutsche', 'wurde', 'jahre'),
#   ('wurde', 'jahre', 'lang'),
#   ('volk', 'afd', 'merkelmussweg'),
#   ('afd', 'merkelmussweg', 'pseudo'),
#   ('merkelmussweg', 'pseudo', 'sturmwarnung'),
#   ('schutz', 'deutscher', 'frauen'),
#   ('düsseldorf', 'karneval', 'morgenmagazin'),
#   ('karneval', 'morgenmagazin', 'läßt'),
#   ('morgenmagazin', 'läßt', 'asylanten'),
#   ('berlinale', 'israelfeindlichen', 'film'),
#   ('israelfeindlichen', 'film', 'anschauen'),
#   ('davon', 'lernt', 'schreiben'),
#   ('flüchtlingskinder', 'fluechtlingskrise', 'asylanten'),
#   ('fluechtlingskrise', 'asylanten', 'fluechtlinge'),
#   ('asylanten', 'fluechtlinge', 'hayali'),
#   ('tipp', 'grenzen', 'sichern'),
#   ('warum', 'spenden', 'grüne'),
#   ('spenden', 'grüne', 'cdu'),
#   ('menschen', 'leichter', 'ausgeben'),
#   ('leichter', 'ausgeben', 'läßt'),
#   ('christen', 'erbarmungslos', 'ermorden'),
#   ('rapefugees', 'christen', 'kirche'),
#   ('christen', 'kirche', 'fpoe'),
#   ('abmerkeln', 'abschieben', 'grenzkontrollen'),
#   ('abschieben', 'grenzkontrollen', 'islamisierung'),
#   ('grenzkontrollen', 'islamisierung', 'stoppen'),
#   ('marcel', 'proust', 'wehrdich'),
#   ('proust', 'wehrdich', 'ia'),
#   ('wehrdich', 'ia', 'stehauf'),
#   ('ia', 'stehauf', 'srfarena'),
#   ('stehauf', 'srfarena', 'svp'),
#   ('srfarena', 'svp', 'logik'),
#   ('svp', 'logik', 'minarette'),
#   ('scharia-staat', 'saudi-arabien', 'unbedenklich'),
#   ('angeblichen', 'sturm', 'beim'),
#   ('sturm', 'beim', 'rosenmontagszug'),
#   ('gang-rape', 'rapefugees', 'abmerkeln'),
#   ('rapefugees', 'abmerkeln', 'fluechtlingskrise'),
#   ('hohen', 'anforderungen', 'kennen'),
#   ('warum', 'sollten', 'weibliche'),
#   ('sollten', 'weibliche', 'eindringlinge'),
#   ('weibliche', 'eindringlinge', 'eigentlich'),
#   ('polizei', 'köln', 'rapefugees'),
# ...
#   ('cdu/spd-nahen', 'wirtschaftsinstitute', 'seriösen'),
#   ('wirtschaftsinstitute', 'seriösen', 'prognosen'),
#   ('pro', 'jahr', 'kosten'),
#   ('bürgerliche', 'mitte', 'schon'),
#   ('mitte', 'schon', 'lange'),
#   ('schon', 'lange', 'verlassen'),
#   ('islamisierung', 'umerziehung', 'migrantenstadel'),
#   ('umerziehung', 'migrantenstadel', 'merkelmussweg'),
#   ('laufende', 'islamisierung', 'deutschlands'),
#   ('europas', 'macht', 'deutlich'),
#   ('durchfüttern', 'zelte', 'bekleidung'),
#   ('deutschland', 'hassen', 'immer'),
#   ('hassen', 'immer', 'mehr'),
#   ('immer', 'mehr', 'flüchtlinge'),
#   ('mehr', 'flüchtlinge', 'dorthin'),
#   ('flüchtlinge', 'dorthin', 'holen'),
#   ('asylanten', 'eu', 'sichere'),
#   ('eu', 'sichere', 'drittstaaten'),
#   ('lieber', 'horst', 'seehofer'),
#   ('horst', 'seehofer', 'gibt'),
#   ('tierasyl', 'aufgehoben', 'wären'),
#   ('sz', 'faz', 'zeit'),
#   ('faz', 'zeit', 'nzz'),
#   ('zeit', 'nzz', 'worauf'),
#   ('nzz', 'worauf', 'warten'),
#   ('stop', 'refugges', 'merkel'),
#   ('co', 'erwarten', 'flüchtlinge'),
#   ('islamisierung', 'nein', 'besser'),
#   ('rapefugees', 'wasserspritzpistole', 'gefüllt'),
#   ('schweineblut', '^^', 'extraunterkünfte'),
#   ('schützen.wärs', 'net', 'besser'),
#   ('flieger', 'nachhause', 'asylanten'),
#   ('nachhause', 'asylanten', 'eu'),
#   ('asylanten', 'eu', 'gipfel'),
#   ('islamisierung', 'siehe', 'schweden'),
#   ('siehe', 'schweden', 'dt'),
#   ('flüchtlinge', 'illegale', 'überfremdung'),
#   ('illegale', 'überfremdung', 'islamisierung'),
#   ('überfremdung', 'islamisierung', 'antigermanismus'),
#   ('islamisierung', 'antigermanismus', 'widerstand'),
#   ('antigermanismus', 'widerstand', 'abmerkeln'),
#   ('widerstand', 'abmerkeln', 'remigration'),
#   ('land', 'lassen', 'terrorrazzien'),
#   ('islamisierung', 'lieber', 'horst'),
#   ('lieber', 'horst', 'seehofer'),
#   ('sz', 'faz', 'zeit'),
#   ('faz', 'zeit', 'nzz'),
#   ('asylanten', 'ewige', 'langzeitarbeitslose'),
#   ('zukunft', 'europas', 'entscheiden'),
#   ('infiltration', 'massiver', 'migrations'),
#   ('massiver', 'migrations', 'jihad'),
#   ('latent', 'linke', 'konditionierung'),
#   ('sorge', 'wegen', 'islamisierung'),
#   ('wegen', 'islamisierung', 'silvesternacht'),
#   ('bereits', 'vorbestraften', 'asylanten'),
#   ('nächste', 'mal', 'vertecke'),
#   ('dumme', 'nazi', 'sau'),
#   ('nazi', 'sau', 'tortalerkrieg'),
#   ('sau', 'tortalerkrieg', 'nordafrikanische'),
#   ('tortalerkrieg', 'nordafrikanische', 'single'),
#   ('nordafrikanische', 'single', 'männer'),
#   ('single', 'männer', 'not'),
#   ('männer', 'not', 'welcome'),
#   ('not', 'welcome', 'rapefugees'),
#   ('deutsche', 'frauen', 'stellen'),
#   ('wasistrechts', 'wer', 'zahlt'),
#   ('kompletten', 'unterhalt', 'beim'),
#   ('unterhalt', 'beim', 'studium'),
#   ('ard', 'läuft', 'schon'),
#   ('mehr', 'polizei', 'weniger'),
#   ('polizei', 'weniger', 'feiernde'),
#   ('abmerkeln', 'rapefugees', 'merkelmussweg'),
#   ('rapefugees', 'merkelmussweg', 'refugees'),
#   ('merkelmussweg', 'refugees', 'nohate'),
#   ('regierung', 'alimentiert', 'menschen'),
#   ('welt', 'fördert', 'islamisierung'),
#   ('fördert', 'islamisierung', 'unsrer'),
#   ('islamisierung', 'unsrer', 'heimatmit'),
#   ('unsrer', 'heimatmit', 'unsren'),
#   ('heimatmit', 'unsren', 'steuern'),
#   ('afd', 'make', 'rape'),
#   ('make', 'rape', 'legal'),
#   ('rape', 'legal', 'findet'),
#   ('legal', 'findet', 'merkel'),
#   ('abmerkeln', 'merkelmussweg', 'merkeldiktatur'),
#   ('merkelmussweg', 'merkeldiktatur', 'hausverbot'),
#   ('gibt', 'orban', 'merkel'),
#   ('orban', 'merkel', 'cdu'),
#   ('merkel', 'cdu', 'rapefugees'),
#   ('cdu', 'rapefugees', 'cdu'),
#   ('rapefugees', 'cdu', 'integration'),
#   ('cdu', 'integration', 'findet'),
#   ('koelnhbf', 'fluechtlinge', 'rapefugees'),
#   ('neue', 'begriff', 'asylsuchende'),
#   ('mehr', 'mitleid', 'hervorrufen'),
#   ('asylanten', 'asylbewerber', 'migranten'),
#   ('mehr', 'asylanten', 'zäune'),
#   ('nigeria', 'indien', 'thailand'),
#   ('indien', 'thailand', 'israel'),
#   ('thailand', 'israel', 'frankr'),
#   ('israel', 'frankr', 'belgien'),
#   ('frankr', 'belgien', 'ukzu'),
#   ('belgien', 'ukzu', 'stoppen'),
#   ('ukzu', 'stoppen', 'frankreich'),
#   ('stoppen', 'frankreich', 'macht'),
#   ('frankreich', 'macht', 'ja'),
#   ('macht', 'ja', 'schon'),
#   ('ja', 'schon', 'grenzkontrollen'),
#   ('grenzenzu', 'festungeuropa', 'refugees'),
#   ('festungeuropa', 'refugees', 'refugeesnotwelcome'),
#   ('falsche', 'fünfziger', 'gabriel'),
#   ('merkel', 'asylanten', 'maybritillner'),
#   ('siggi', 'erst', 'recht'),
#   ('erst', 'recht', 'durchregieren'),
#   ('groko', 'tagesschau', 'nennt'),
#   ('tagesschau', 'nennt', 'levante-dschihadisten'),
#   ('syrien', 'kämpfen', 'einigermaßen'),
#   ('kämpfen', 'einigermaßen', 'gemäßigte'),
#   ('einigermaßen', 'gemäßigte', 'rebellen'),
#   ('gemäßigte', 'rebellen', 'illner'),
#   ('rebellen', 'illner', 'cdu'),
#   ('illner', 'cdu', 'lebt'),
#   ('falschen', 'land', 'scheint'),
#   ('asylanten', 'gibts', 'dicke'),
#   ('diebstahl', 'scharia', 'erschießen'),
#   ('illegalem', 'grenzübertritt', 'afd'),
#   ('islamicstate', 'islamisierung', 'fluechtlingskrise'),
#   ('islamisierung', 'fluechtlingskrise', 'zdfzoom'),
#   ('fluechtlingskrise', 'zdfzoom', 'flüchtlinge'),
#   ('zdfzoom', 'flüchtlinge', 'asylanten'),
#   ('frau', 'knobel-ulrich', 'u'),
#   ('rapefugees', 'abmerkeln', 'unterhaltsam'),
#   ('asylanten-heim', 'entsteht', 'rettet'),
#   ('multikuliti', 'wahn', 'rapefugees'),
#   ('wahn', 'rapefugees', 'rapefugees'),
#   ('hartzundherzlich', 'syrische', 'asylanten'),
#   ('klopapier', 'gelegentlich', 'fehlt'),
#   ('kinderbraut', 'frauenunterdrückung', 'intoleranz'),
#   ('frauenunterdrückung', 'intoleranz', 'scharia'),
#   ('intoleranz', 'scharia', 'sonderrecht'),
#   ('radikale', 'kriminelle', 'islamisten'),
#   ('kriminelle', 'islamisten', 'installieren'),
#   ('-diebstahl', 'hand', 'ab'),
#   ('refugeeswelcome', 'refugeesnotwelcome', 'nopegida'),
#   ('refugeesnotwelcome', 'nopegida', 'isis'),
#   ('nopegida', 'isis', 'unterstützer'),
#   ('isis', 'unterstützer', 'scharia'),
#   ('unterstützer', 'scharia', 'befürworter'),
#   ('scharia', 'befürworter', 'islam'),
#   ('befürworter', 'islam', 'gehört'),
#   ('de', 'sympathisanten', 'gg'),
#   ('sympathisanten', 'gg', 'bruch'),
#   ('gg', 'bruch', 'gutheißer'),
#   ('bruch', 'gutheißer', 'asylindustrie'),
#   ('gutheißer', 'asylindustrie', 'profitierer'),
#   ('asylindustrie', 'profitierer', 'asylanten'),
#   ('profitierer', 'asylanten', 'sollen'),
#   ('asylanten', 'sollen', 'arbeiten'),
#   ('sollen', 'arbeiten', 'können.die'),
#   ('arbeiten', 'können.die', 'wirtschaft'),
#   ('können.die', 'wirtschaft', 'gibt'),
#   ('wirtschaft', 'gibt', 'knowhow'),
#   ('übrigen', 'müsste', 'klar'),
#   ('rapefugees', 'aka', 'is'),
#   ('aka', 'is', 'monkeys'),
#   ('macht', 'merkel', 'cdu'),
#   ('hessen', 'politische', 'fluechtlinge'),
#   ('politische', 'fluechtlinge', 'hartaberfair'),
#   ('fluechtlinge', 'hartaberfair', 'warum'),
#   ('asylanten', 'müssen', 'zurück'),
#   ('schüler', 'sollen', 'refugees'),
#   ('sollen', 'refugees', 'betten'),
#   ('refugeesnotwelcome', 'gutmenschgohome', 'alleinherrscher'),
#   ('gutmenschgohome', 'alleinherrscher', 'putin'),
#   ('sanktionen', 'belegt-diktator', 'erdogan'),
#   ('klasse', 'merkel', 'asylanten'),
#   ('merkel', 'asylanten', 'flüchtlinge'),
#   ('perverse', 'kleine', 'kinderficker'),
#   ('gewalttätige', 'asylanten', 'refugees'),
#   ('asylanten', 'refugees', 'cdu'),
#   ('refugees', 'cdu', 'kapiert'),
#   ('europa', 'ausser', 'cdu'),
#   ('blanke', 'politische', 'schwachsinn'),
#   ('politische', 'schwachsinn', 'sturmwarnung'),
#   ('schwachsinn', 'sturmwarnung', 'rosenmontag'),
#   ('sturmwarnung', 'rosenmontag', 'rapefugees'),
#   ('rosenmontag', 'rapefugees', 'kriminalität'),
#   ('rapefugees', 'kriminalität', 'afd'),
#   ('kriminalität', 'afd', 'kapitulation'),
#   ('vollen', 'gange', 'cdu'),
#   ('gange', 'cdu', 'schweden'),
#   ('cdu', 'schweden', 'findet'),
#   ('schweden', 'findet', 'missbrauch'),
#   ('findet', 'missbrauch', 'v.kindern'),
#   ('missbrauch', 'v.kindern', 'ok'),
#   ('v.kindern', 'ok', 'kinderehen'),
#   ('ok', 'kinderehen', 'asylanten'),
#   ('tolerant', 'assange', 'mensch'),
#   ('assange', 'mensch', 'gabriel'),
#   ('domian', 'sollen', 'dt'),
#   ('rapefugees', 'is', 'danken'),
#   ('is', 'danken', 'glawischnig'),
#   ('danken', 'glawischnig', 'weltfrauentag'),
#   ('burka', 'scharia', 'islam'),
#   ('scharia', 'islam', 'isis'),
#   ('islam', 'isis', 'diegrünen'),
#   ('isis', 'diegrünen', 'menschenrechte'),
#   ('diegrünen', 'menschenrechte', 'frauenrechte'),
#   ('menschenrechte', 'frauenrechte', 'vdb'),
#   ('frauenrechte', 'vdb', 'make'),
#   ('vdb', 'make', 'rape'),
#   ('make', 'rape', 'legal'),
#   ('wohl', 'schon', 'athmosphärisch'),
#   ('schon', 'athmosphärisch', 'vorbereiten'),
#   ('rapefugees.in', 'gesamter', 'eu'),
#   ('gesamter', 'eu', 'tgl'),
#   ('klöckner', 'wählen', 'heißt'),
#   ('wählen', 'heißt', 'mio'),
#   ('heißt', 'mio', 'neue'),
#   ('mio', 'neue', 'asylanten'),
#   ('neue', 'asylanten', 'türkei'),
#   ('asylanten', 'türkei', 'mitglied'),
#   ('euro', 'neue', 'steuern'),
#   ('neue', 'steuern', 'zensur'),
#   ('steuern', 'zensur', 'sharia.ich'),
#   ('afd', 'wählen', 'cdu'),
#   ('deutschen', 'schon', 'aufgegeben'),
#   ('asylanten', 'möglichst', 'schnell'),
#   ('kriminelle', 'islamistische', 'migranten'),
#   ('gewünschten', 'scharia', 'bestrafen'),
#   ('scharia', 'bestrafen', '-wäre'),
#   ('bestrafen', '-wäre', 'schnell'),
#   ('-wäre', 'schnell', 'ruhe'),
#   ('verwandten', 'fahren.ich', 'fordere'),
#   ('abend=', 'eu', 'gipfel'),
#   ('eu', 'gipfel', 'hast'),
#   ('heute', 'schon', 'gnachtmahlt'),
#   ('schon', 'gnachtmahlt', 'angela'),
#   ('europa', 'flüchtlinge', 'fleuchtlingskrise'),
#   ('flüchtlinge', 'fleuchtlingskrise', 'asylanten'),
#   ('fleuchtlingskrise', 'asylanten', 'geplatzte'),
#   ('asylanten', 'geplatzte', 'träume'),
#   ('asylanten', 'fünf', 'männer'),
#   ('irgendwie', 'übel', 'muß'),
#   ('übel', 'muß', 'leider'),
#   ('muß', 'leider', 'abschalten'),
#   ('lanz', 'merkel', 'scharia'),
#   ('merkel', 'scharia', 'kölnhbf'),
#   ('scharia', 'kölnhbf', 'wieso'),
#   ('kölnhbf', 'wieso', 'nehmen'),
#   ('bundesasylzentrum', 'wallis', 'wähler'),
#   ('wehren-', 'wählt', 'afd'),
#   ('ausnotwehr', 'rapefugees', 'madmerkel'),
#   ('rapefugees', 'madmerkel', 'annewill'),
#   ('madmerkel', 'annewill', 'lanz'),
#   ('annewill', 'lanz', 'hoaxmap'),
#   ('manchmal', 'niemand', 'allianz'),
#   ('abschaffung', 'deutschland', 's'),
#   ('grüne', 'linke', 'spd'),
#   ('linke', 'spd', 'cdu'),
#   ('beachtlich', 'wieviel', 'gutmenschen'),
#   ('hosen', 'gestrichen', 'vollgeschissen'),
#   ('afd', 'eu', 'stellt'),
#   ('eu', 'stellt', 'mio'),
#   ('refugeesnotwelcome', 'fluechtlinge', 'pegida'),
#   ('fluechtlinge', 'pegida', 'afd'),
#   ('pegida', 'afd', 'cdu'),
#   ('afd', 'cdu', 'merkelmussweg'),
#   ('cdu', 'merkelmussweg', 'refugeeswelcome'),
#   ('merkelmussweg', 'refugeeswelcome', 'brüllern'),
#   ('flüchtlinge', 'wohl', 'egal'),
#   ('afd', 'islamisierung', 'übrigens'),
#   ('zeit', 'flüchtlinge', 'nein'),
#   ('merkel', 'vertrauensfrage', 'kiel'),
#   ('einkaufszentrum', 'lieber', 'spd'),
#   ('lieber', 'spd', 'wähler'),
#   ('sonstiger', 'traumtänzer', 'rapefugees'),
#   ('traumtänzer', 'rapefugees', 'ja'),
#   ('amerika', 'australien', 'ostasien'),
#   ('ns-regime', 'abmerkeln', 'islamisierung'),
#   ('trümmerfrau', 'asylanten', 'bürgerwehr'),
#   ('asylanten', 'bürgerwehr', 'heute-journal'),
#   ('bürgerwehr', 'heute-journal', 'un'),
#   ('heute-journal', 'un', 'ehrt'),
#   ('un', 'ehrt', 'merkel'),
#   ('beitrag', 'später', 'suche'),
#   ('bekommen', 'asylanten', 'aufgedrückt'),
#   ('bekommen', 'ttip', 'vorgesetzt'),
#   ('ttip', 'vorgesetzt', 'müssen'),
#   ('vorgesetzt', 'müssen', 'übelste'),
#   ('müssen', 'übelste', 'moderne'),
#   ('übelste', 'moderne', 'propaganda'),
#   ('refugeesnotwelcome', 'schleichende', 'islamisierung'),
#   ('frauen', 'ungläubige', 'verbannen'),
#   ('ungläubige', 'verbannen', 'schweinefleischpflicht'),
#   ('verbannen', 'schweinefleischpflicht', 'sinnvoll'),
#   ('schweinefleischpflicht', 'sinnvoll', 'hört'),
#   ('mehr', 'sexuelle', 'übergriffe'),
#   ('rapefugees', 'refugeesnotwelcome', 'grenzendicht'),
#   ('refugeesnotwelcome', 'grenzendicht', 'abmerkeln'),
#   ('grenzendicht', 'abmerkeln', 'frau'),
#   ('abmerkeln', 'frau', 'merkelmussweg'),
#   ('frau', 'merkelmussweg', 'deutschland'),
#   ('eu', 'immer', 'mehr'),
#   ('immer', 'mehr', 'isoliert'),
#   ('mehr', 'isoliert', 'dank'),
#   ('nächste', 'gipfel', 'erfolglos'),
#   ('gipfel', 'erfolglos', 'österreich'),
#   ('erfolglos', 'österreich', 'macht'),
#   ('flüchtlingsobergrenze', 'refugees', 'refugeesnotwelcome'),
#   ('refugees', 'refugeesnotwelcome', 'refugeesgohome'),
#   ('refugeesnotwelcome', 'refugeesgohome', 'merkelmussweg'),
#   ('refugeesgohome', 'merkelmussweg', 'cdu'),
#   ('merkelmussweg', 'cdu', 'bahnstrecke'),
#   ('cdu', 'bahnstrecke', 's'),
#   ('erding-', 'münchen', 'wurde'),
#   ('münchen', 'wurde', 'vorhin'),
#   ('wurde', 'vorhin', 'gesperrt'),
#   ('de', 'läuft', 'definitiv'),
#   ('illner', 'edathy', 'islamisierung'),
#   ('edathy', 'islamisierung', 'antisemitismus'),
#   ('gesamten', 'arabischen', 'raum'),
#   ('arabischen', 'raum', 'verbreitet'),
#   ('raum', 'verbreitet', 'praktisch'),
#   ('verbreitet', 'praktisch', 'salonfähig.warum'),
#   ('islamisierung', 'asyl', 'etwa'),
#   ('asyl', 'etwa', 'prozent'),
#   ('christen', 'verschiedener', 'konfessionen'),
#   ('islamisierung', 'regierung', 'merkel'),
#   ('regierung', 'merkel', 'betreibt'),
#   ('verlogene', 'migrationspolitik', 'vs'),
#   ('migrationspolitik', 'vs', 'eigene'),
#   ('vs', 'eigene', 'bevölkerung'),
#   ('jakarta', 'islam', 'islam'),
#   ('islam', 'islam', 'islam'),
#   ('islamisierung', 'mrd', 'zahlen'),
#   ('arschloch', 'ochsner', 'redet'),
#   ('fluchtlinge', 'asylanten', 'gibt'),
#   ('fachkräfte', 'ärzte', 'ingenieure'),
#   ('brauchen', 'dringend', 'wahlbeobachter'),
#   ('ltwrlp', 'ltwrp', 'ltwbw'),
#   ('ltwrp', 'ltwbw', 'merkel'),
#   ('ltwbw', 'merkel', 'afd'),
#   ('merkel', 'afd', 'cdu'),
#   ('afd', 'cdu', 'csu'),
#   ('cdu', 'csu', 'spd'),
#   ('csu', 'spd', 'malu'),
#   ('spd', 'malu', 'laschet'),
#   ('malu', 'laschet', 'rapefugees'),
#   ('laschet', 'rapefugees', 'krimigranten'),
#   ('rapefugees', 'krimigranten', 'ja'),
#   ('schutz', 'suchende', 'flüchtlinge'),
#   ('radikale', 'islamisten-krimigranten-rapefugees', 'entpuppen'),
#   ('islamisten-krimigranten-rapefugees', 'entpuppen', '-in'),
#   ('entpuppen', '-in', 'gefangenenlager'),
#   ('-in', 'gefangenenlager', 'stecken'),
#   ('m²', 'großes', 'mausoleum'),
#   ('tillich', 'gabriel', 'hetzt'),
#   ('islamisierung', 'opfern', 'sollen'),
#   ('schweinefleisch', 'puh', 'bloss'),
#   ('puh', 'bloss', 'glück'),
#   ('bloss', 'glück', 'gehabt'),
#   ('mal', 'gut', 'gegangen'),
#   ('clausnitz', 'sachsen', 'flüchtlingskrise'),
#   ('sachsen', 'flüchtlingskrise', 'asylanten'),
#   ('flüchtlingskrise', 'asylanten', 'muttikulti'),
#   ('mutti', 'merkel', 'verschuldete'),
#   ('merkel', 'verschuldete', 'eskalation'),
#   ('refugeesnotwelcome', 'boykottiert', 'bild'),
#   ('frei', 'rumlaufende', 'rapefugees'),
#   ('unwesen', 'treiben.abmerkeln', 'täglich'),
#   ('treiben.abmerkeln', 'täglich', 'gibt'),
#   ('schande', 'fuck', 'you'),
#   ('fuck', 'you', 'refugges'),
#   ('you', 'refugges', 'mindestlohn'),
#   ('wegen', 'asylanten', 'teilweise'),
#   ('asylanten', 'teilweise', 'ausgesetzt'),
#   ('opferschutz', 'frauen', 'u'),
#   ('christen', 'bekommen', 'extraunterkünfte'),
#   ('schützen.u', 'wer', 'schützt'),
#   ('sterben', 'sehen', 'möchte'),
#   ('asylanten', 'afd', 'noafd'),
#   ('afd', 'noafd', 'nonazis'),
#   ('noafd', 'nonazis', 'sachsenanhalt'),
#   ('nonazis', 'sachsenanhalt', 'menschistmensch'),
#   ('mazedonien', 'versuchen', 'tausende'),
#   ('versuchen', 'tausende', 'asylanten'),
#   ('deutschland', 'durchzubrechen', 'fast'),
#   ('beschütze', 'deutsche', 'frauen'),
#   ('deutsche', 'frauen', 'teilzeit'),
#   ('hungerstreik', 'rapefugees', 'fr'),
#   ('invasoren', 'lagers', 'calais'),
#   ('lagers', 'calais', 'geräumt'),
#   ('calais', 'geräumt', 'gr'),
#   ('invasorenlager', 'idomeni', 'räumen'),
#   ('asylanten', 'verteilen', 'könnten'),
#   ('lanz', 'sicher', 'mutig'),
#   ('opfersindopfer', 'statt', 'hoax'),
#   ('bestätigten', 'sexuellen', 'übergriffen'),
#   ('rapefugees.das', 'wäre', 'wirkliche'),
#   ('wäre', 'wirkliche', 'transparenz'),
#   ('tun', 'kriminalität', 'v.'),
#   ('kriminalität', 'v.', 'asylanten'),
#   ('/g', 'meth', 'durchzudrehen'),
#   ...]}
