# %%
import nltk
import string
import pickle
import numpy as np

# %%
import zipfile
content = {}
with zipfile.ZipFile("keyword.zip") as zfile:
    for f in zfile.namelist():
        if f != "keyword/":
            content[f] = zfile.read(f).decode("utf8")
content.keys()
# Out:
# dict_keys(['keyword/automobil_50k.txt', 'keyword/news_text100k.txt', 'keyword/sport_50k.txt', 'keyword/wirtschaft_50k.txt'])

# %%
def clean(text):
    tokenized_sents=[]
    text = text.lower()
    text = nltk.sent_tokenize(text)
    for sent in text:
        sent = nltk.word_tokenize(sent)
        sent = [x for x in sent if x not in string.punctuation]
        sent = [x for x in sent if x not in ["``", "''", "€", "$"]]
        sent = [x for x in sent if x.isalpha()]
        if len(sent) > 1:
            tokenized_sents.append(sent)
        
    
    return tokenized_sents

# %%
for key in content:
    content[key] = clean(content[key])

# %%
def create_trigrams(dic_corpora):
    ngram_dict = {}
    stopwords = nltk.corpus.stopwords.words("german")
    stopwords+=["findbecci","--","..", "§", '”', "rebecca", "freeflorian", "\|lbr\|", "|lbr|"]
   
    for index, key in enumerate(dic_corpora):
        print(key)
        ngram_dict[key] =[]
  
        for sents in dic_corpora[key]:

            ngram_dict[key] += [gram for gram in list(nltk.ngrams(sents,3)) if len(set(stopwords).intersection(set(gram)))== 0 and (len(gram[0])>1) and (len(gram[1])>1)]
    
    return ngram_dict

# %%
trigrams = create_trigrams(content)
# Out:
# keyword/automobil_50k.txt
# keyword/news_text100k.txt
# keyword/sport_50k.txt
# keyword/wirtschaft_50k.txt

# %%
def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
hatespeech = load_obj("ngrams_hatespeech_without_stopwords")

# %%
trigrams["keywords/hatespeech"] = hatespeech["3-grams"]

# %%
trigrams["keywords/hatespeech"][:100]
# Out:
# [('menschenrechte', 'pressefreiheit', 'islamisierung'),
#  ('pressefreiheit', 'islamisierung', 'wieso'),
#  ('islamisierung', 'wieso', 'bekommen'),
#  ('wieso', 'bekommen', 'rapefugees'),
#  ('bekommen', 'rapefugees', 'mehr'),
#  ('überall', 'schwangere', 'muslimische'),
#  ('schwangere', 'muslimische', 'frauen'),
#  ('kindern', 'islamisierung', 'asylanteninvasion'),
#  ('verantwortlichen', 'hierfür', 'sitzen'),
#  ('millionen', 'menschen', 'leben'),
#  ('millionen', 'flüchtlinge', 'bereiten'),
#  ('refugees', 'refugeesnotwelcome', 'refugeesgohome'),
#  ('refugeesnotwelcome', 'refugeesgohome', 'abmerkeln'),
#  ('grund', 'frauen', 'seien'),
#  ('frauen', 'seien', 'anzeigefreudiger'),
#  ('rapefugees', 'offenes', 'freies'),
#  ('offenes', 'freies', 'wlan'),
#  ('unterdenlinden', 'petry', 'fordert'),
#  ('petry', 'fordert', 'bessere'),
#  ('fordert', 'bessere', 'regelung'),
#  ('bessere', 'regelung', 'gesetze'),
#  ('hungerstreik', 'rapefugees', 'blutrache'),
#  ('rapefugees', 'blutrache', 'zwangsbekehrung'),
#  ('blutrache', 'zwangsbekehrung', 'scharia'),
#  ('zwangsbekehrung', 'scharia', 'kinderbräute'),
#  ('scharia', 'kinderbräute', 'vielehe'),
#  ('kinderbräute', 'vielehe', 'genitalverstümmelung'),
#  ('claudia', 'roth', 'wer'),
#  ('roth', 'wer', 'sex-attacken'),
#  ('geistiger', 'bruder', '“'),
#  ('fuck', 'you', 'from'),
#  ('you', 'from', 'switzerland'),
#  ('ard', 'tagesschau', 'trotz'),
#  ('tagesschau', 'trotz', 'grenzkontrollen'),
#  ('menschenwürde.hungerstreik', 'rapefugees', 'merkel'),
#  ('merkeldiktatur', 'vorangetriebenen', 'islamisierung'),
#  ('vorangetriebenen', 'islamisierung', 'europas'),
#  ('gratis', 'häuser', 'wohnungen'),
#  ('häuser', 'wohnungen', 'handys'),
#  ('wohnungen', 'handys', 'u.'),
#  ('handys', 'u.', 'öffitickets'),
#  ('u.', 'öffitickets', 'mindestsicherung'),
#  ('öffitickets', 'mindestsicherung', 'straffreiheit'),
#  ('mindestsicherung', 'straffreiheit', 'vorreihung'),
#  ('ambulanzen', 'schlaraffenland', 'ö'),
#  ('zib', 'asylanten', 'beateuhse'),
#  ('asylanten', 'beateuhse', 'konzern'),
#  ('beateuhse', 'konzern', 'vermarktet'),
#  ('konzern', 'vermarktet', 'scharia'),
#  ('vermarktet', 'scharia', 'konforme'),
#  ('scharia', 'konforme', 'sexprodukte'),
#  ('konforme', 'sexprodukte', 'bitte'),
#  ('sexprodukte', 'bitte', 'boykottiert'),
#  ('asylanten', 'fluten', 'zusätzlich'),
#  ('ende', 'gelände', 'd'),
#  ('griechenland', 'riesige', 'asylanten-kontingente'),
#  ('riesige', 'asylanten-kontingente', 'abnehmen'),
#  ('ernst-grube-halle', 'endlich', 'geräumt'),
#  ('endlich', 'geräumt', 'leipzig'),
#  ('geräumt', 'leipzig', 'npd'),
#  ('leipzig', 'npd', 'jn'),
#  ('npd', 'jn', 'legida'),
#  ('jn', 'legida', 'refugeesnotwelcome'),
#  ('legida', 'refugeesnotwelcome', 'illner'),
#  ('wichsenden', 'vergewaltigenden', 'betrügenden'),
#  ('vergewaltigenden', 'betrügenden', 'asylanten'),
#  ('annewill', 'refugees', 'refugeesnotwelcome'),
#  ('refugees', 'refugeesnotwelcome', 'slovenien'),
#  ('refugeesnotwelcome', 'slovenien', 'macht'),
#  ('merkelmussweg', 'abmerkeln', 'refugeesnotwelcome'),
#  ('abmerkeln', 'refugeesnotwelcome', 'luxushotels'),
#  ('asylanten', 'unterkünfte', 'umfunktioniert'),
#  ('unterkünfte', 'umfunktioniert', 'deutsche'),
#  ('umfunktioniert', 'deutsche', 'müssen'),
#  ('primitiven', 'heruntergekommenen', 'slums'),
#  ('heruntergekommenen', 'slums', 'leben.annewill'),
#  ('slums', 'leben.annewill', 'ard'),
#  ('leben.annewill', 'ard', 'niemand'),
#  ('asylwahn', 'rapefugees', 'volksentscheid'),
#  ('asylrecht', 'grenzen', 'dicht'),
#  ('grenzen', 'dicht', 'merkel'),
#  ('ausnahmen', 'beim', 'mindestlohn'),
#  ('spd', 'cdu', 'deutschland'),
#  ('cdu', 'deutschland', 'pöbelnde'),
#  ('deutschland', 'pöbelnde', 'asylanten'),
#  ('pöbelnde', 'asylanten', 'zeigen'),
#  ('asylanten', 'zeigen', 'kopf-ab-gesten'),
#  ('un', 'flüchtlingshilfe', 'asylanten'),
#  ('rapefugees', 'politiker', 'ossis'),
#  ('politiker', 'ossis', 'journalisten'),
#  ('d-radio', 'millionen', 'menschen'),
#  ('millionen', 'menschen', 'fluechtlinge'),
#  ('menschen', 'fluechtlinge', 'migranten'),
#  ('fluechtlinge', 'migranten', 'asylanten'),
#  ('kranker', 'mensch', 'genießt'),
#  ('goethe', 'deutschland', 'hartziv'),
#  ('deutschland', 'hartziv', 'merkel'),
#  ('hartziv', 'merkel', 'fluechtlinge'),
#  ('merkel', 'fluechtlinge', 'asylanten'),
#  ('jahr', 'mussten', 'eltern')]

# %%
def transform_ngrams(dic):
    trigrams={}
    for keys in dic:
        tuples = []
        for doc in dic[keys]:
            tuples.append("_".join(doc))
        trigrams[keys] = tuples
    return trigrams

# %%
trigram = transform_ngrams(trigrams)

# %%
trigram
# Out:
# {'keyword/automobil_50k.txt': ['ford_ordentlich_einheizen',
#   'monatlichen_kosten_dämpfend',
#   'paar_kleinigkeiten_vergessen',
#   'umgelegten_sitzlehnen_bilden',
#   'sitzlehnen_bilden_leider',
#   'komplett_ebenen_ladeboden',
#   'statt_schriller_farben',
#   'schriller_farben_verrückter',
#   'farben_verrückter_formen',
#   'paar_frischer_funktionen',
#   'frischer_funktionen_gibt',
#   'früher_kaum_vorstellbar',
#   'bundeskanzlerin_angela_merkel',
#   'angela_merkel_cdu',
#   'fc_bayern_spielt',
#   'fc_aberdeen_remis',
#   'aston_martin_zeigt',
#   'concept_car_heißt',
#   'ähnelt_darüber_hinaus',
#   'euro_aufpreis_gibt',
#   'maximal_nm_entwickelt',
#   'fünf_meter_lange',
#   'tonnen_schwere_limousine',
#   'coupé_kostet_franken',
#   'farbige_applikationen_zeichnen',
#   'streife_ließ_kräftig',
#   'ließ_kräftig_dampf',
#   'kräftig_dampf_ab',
#   'messe_auto_china',
#   'befragt_wurden_männer',
#   'frauen_ab_jahren',
#   'alten_kombi_liegt',
#   'deutschen_autokäufer_vorerst',
#   'fürs_fahrvergnügen_gibts',
#   'millimeter_geringerer_bodenfreiheit',
#   'geringerer_bodenfreiheit_sowie',
#   'elektronische_differentialsperre_xds',
#   'dürfte_daimler_interessieren',
#   'bisschen_neid_unterdrücken',
#   'schier_unglaublicher_beinfreiheit',
#   'unglaublicher_beinfreiheit_sprechen',
#   'tourenzähler_stehen_beeindruckende',
#   'stehen_beeindruckende_nm',
#   'wiener_rathaus_steuern',
#   'september_bringt_alfa',
#   'neues_heißes_einstiegsmodell',
#   'anton_hunger_anmerkte',
#   'politur_versprechen_brillianz',
#   'sechs_produkte_getestet',
#   'immer_schräger_werdende',
#   'schräger_werdende_frontscheiben',
#   'werdende_frontscheiben_kritisierten',
#   'fotostrecke_bilder_rebmann',
#   'bilder_rebmann_je',
#   'rebmann_je_seltener',
#   'regierungssprecher_ulrich_wilhelm',
#   'vorher_genau_prüfen',
#   'mustang_gt_anbieten',
#   'immerhin_schon_lange',
#   'schon_lange_wartezeiten',
#   'beiden_tarifen_verlangte',
#   'dollar_teuren_einsteiger',
#   'eingesetzten_rohstoffe_wenigstens',
#   'rohstoffe_wenigstens_angemessen',
#   'wenigstens_angemessen_genutzt',
#   'neue_steuer_könne',
#   'steuer_könne_theoretisch',
#   'könne_theoretisch_schon',
#   'kraft_treten_heißt',
#   'versicherungen_müssen_ab',
#   'januar_deutlich_mehr',
#   'deutlich_mehr_berappen',
#   'erstmals_richtig_kalt',
#   'kleinen_dreizylinder_sagt',
#   'dreizylinder_sagt_lutz',
#   'auto_bullig_elegant',
#   'lange_fuhr_bmw',
#   'fiat_immer_mehr',
#   'immer_mehr_autos',
#   'klappen_sieben_personen',
#   'kompaktvan_transportieren_beinfreiheit',
#   'berliner_kino_cinemaxx',
#   'kino_cinemaxx_lenkte',
#   'cinemaxx_lenkte_downey',
#   'euro_aufpreis_kostet',
#   'paar_jahren_mal',
#   'hinten_montiert_sagt',
#   'montiert_sagt_maximilian',
#   'sagt_maximilian_maurer',
#   'brigitte_zypries_mal',
#   'zypries_mal_kräftig',
#   'hype_minister_lahmt',
#   'zuletzt_prozent_mehr',
#   'ford_raptor_svt',
#   'schwimmweste_beim_bergsteigen',
#   'laut_werksangaben_verbraucht',
#   'durchschnitt_liter_diesel',
#   'pariser_vorort_velizy',
#   'vorort_velizy_zeigen',
#   'circa_drei_jahren',
#   'neue_strahlt_preußische',
#   'strahlt_preußische_nüchternheit',
#   'statt_bayerischem_barock',
#   'gefahrene_tiptronic_s',
#   'version_stolze_euro',
#   'massenmarke_mehr_bieten',
#   'jahreszeit_vier_personen',
#   'damals_flotten_sekunden',
#   'indes_wurde_bekannt',
#   'toyota_offenbar_bereits',
#   'offenbar_bereits_seit',
#   'sportlichen_viertürers_geht',
#   'rapide_cls_sportback',
#   'cls_sportback_gt',
#   'gerade_fünf_prozent',
#   'fünf_prozent_davon',
#   'deutschen_umwelthilfe_duh',
#   'ulrich_bez_erstmals',
#   'projekt_cygnet_berichtete',
#   'cygnet_berichtete_dachte',
#   'dank_geänderter_vorderachsgeometrie',
#   'auto_dagegen_schwerer',
#   'dagegen_schwerer_geworden',
#   'getan_schliesslich_kommen',
#   'schliesslich_kommen_heute',
#   'kommen_heute_suv',
#   'drei_siechen_riesen',
#   'siechen_riesen_ford',
#   'riesen_ford_general',
#   'ford_general_motors',
#   'letzten_großen_branchentreff',
#   'genfer_salon_märchenhaft',
#   'salon_märchenhaft_sparsame',
#   'märchenhaft_sparsame_autos',
#   'liter_je_kilometer',
#   'handys_verwendung_finden',
#   'statt_glamouröser_sowie',
#   'dingen_benzinfressender_sportwagen',
#   'erheblichen_finanziellen_schwierigkeiten',
#   'besonders_wertvolle_fahrzeuge',
#   'concours_eingeladen_rennmotorräder',
#   'programm_komplett_gemeinsam',
#   'neuen_mini_e',
#   'new_york_erfahrungswerte',
#   'späteres_elektrogroßserienauto_sammeln',
#   'große_glasdach_verhelfen',
#   'platz_gibts_rundum',
#   'gibts_rundum_üppig',
#   'spanngurten_befestigte_weihnachtsbaum',
#   'befestigte_weihnachtsbaum_hielt',
#   'weihnachtsbaum_hielt_dagegen',
#   'dollar_müsse_niedrigere',
#   'müsse_niedrigere_kraftstoffpreise',
#   'richtigen_knopf_fürs',
#   'knopf_fürs_öffnen',
#   'exemplaren_verkaufte_alhambra',
#   'verkaufte_alhambra_gewachsen',
#   'kleine_format_schnell',
#   'format_schnell_vergessen',
#   'schnell_vergessen_dürften',
#   'kilometer_pro_stunde',
#   'limousine_erweitert_mercedes',
#   'deutschen_markt_hergestellt',
#   'duisburg_oberhausen_bottrop',
#   'oberhausen_bottrop_gelsenkirchen',
#   'bottrop_gelsenkirchen_herne',
#   'gelsenkirchen_herne_bochum',
#   'gemeinsame_erklärung_unterzeichnet',
#   'welt_rund_einheiten',
#   'wenig_reifendruck_erhöht',
#   'ganzen_jahr_genutzt',
#   'grenze_verstärkt_kontrolliert',
#   'quadratmeter_großes_glasdach',
#   'großes_glasdach_sorgt',
#   'zahlung_gegebenen_gebrauchtwagen',
#   'gegebenen_gebrauchtwagen_zurücknehmen',
#   'verachteten_wahlvolk_finanziert',
#   'komfortabel_ausgestattet_dienen',
#   'magnesium_fast_ausschließlich',
#   'fast_ausschließlich_per',
#   'ausschließlich_per_druckguss',
#   'per_druckguss_produziert',
#   'kolben_flüssiges_leichtmetall',
#   'gemeinsam_erreichen_beide',
#   'erreichen_beide_motoren',
#   'hochrotem_kopf_erzählt',
#   'kopf_erzählt_linn',
#   'quietschendes_keuchen_gehört',
#   'inhalt_volle_unterstützung',
#   'style_bietet_laut',
#   'bietet_laut_mercedes',
#   'erste_große_limousine',
#   'neu_entwickelte_multiantriebsplattform',
#   'rückleuchten_sowie_neue',
#   'sowie_neue_farben',
#   'neue_farben_stoffe',
#   'herstellers_erfüllen_ab',
#   'erfüllen_ab_wären',
#   'zeiten_wurde_mitte',
#   'wurde_mitte_gebaut',
#   'alte_erfolgsrezept_anknüpfen',
#   'besondere_flexibilität_verspricht',
#   'drei_segmente_sogar',
#   'segmente_sogar_prozent',
#   'audi_tt_rs',
#   'hamburg_ron_gettelfinger',
#   'uaw_bezeichnete_mccain',
#   'peugeot_rcz_geerbt',
#   'kühlen_luftstrom_genießen',
#   'luftstrom_genießen_mittlerweile',
#   'erkenntnis_ans_tageslicht',
#   'besondere_behandlung_benötigt',
#   'knapp_meter_hoch',
#   'meter_hoch_aufragenden',
#   'mercedes_intern_w',
#   'energie_laut_bahnsprecher',
#   'laut_bahnsprecher_gunnar',
#   'bahnsprecher_gunnar_meyer',
#   'etwa_zehn_prozent',
#   'vier_zentimeter_radstand',
#   'zentimeter_radstand_kommen',
#   'mondeo_sicherer_fühlen',
#   'früher_verspricht_ford',
#   'geringen_luftwiderstands_cw',
#   'bleifreiem_benzin_führte',
#   'zwei_jahren_gebaute',
#   'jahren_gebaute_audi',
#   'grösseren_bmw_dürfte',
#   'europäischen_automobilindustrie_steuert',
#   'satte_euro_aufpreis',
#   'dreißiger_jahren_prägte',
#   'jahren_prägte_henri',
#   'prägte_henri_thomas',
#   'deren_auffälligstes_merkmal',
#   'schildförmigen_kühlergrill_platzierten',
#   'kühlergrill_platzierten_scheinwerfer',
#   'ehemals_kleine_sportwagenspezialist',
#   'zunehmender_laufleistung_steige',
#   'reguläre_porsche_cayenne',
#   'porsche_cayenne_bekommt',
#   'palais_het_loo',
#   'genannten_rückdrall_verhindert',
#   'möglichst_niedrige_verbrauchszahlen',
#   'niedrige_verbrauchszahlen_zielen',
#   'verbrauchszahlen_zielen_scheinen',
#   'beim_beschleunigen_bemerkbar',
#   'neue_mini_macht',
#   'aufsteiger_juventus_turin',
#   'juventus_turin_siegte',
#   'turin_siegte_dank',
#   'inzwischen_alessandro_del',
#   'alessandro_del_piero',
#   'atalanta_renault_nämlich',
#   'renault_nämlich_runde',
#   'ps_starken_sportmodell',
#   'starken_sportmodell_ab',
#   'hügeliger_herbstlandschaft_präsentiert',
#   'dank_neu_gestaltetem',
#   'neu_gestaltetem_stoßfänger',
#   'gestaltetem_stoßfänger_überarbeiteten',
#   'stoßfänger_überarbeiteten_scheinwerfern',
#   'größeren_kühleröffnungen_dynamisch',
#   'immer_mehr_fahrzeughersteller',
#   'bedeutendsten_europäischen_umrüster',
#   'roten_rakete_entlang',
#   'bedenken_macht_google',
#   'macht_google_seit',
#   'google_seit_mai',
#   'seit_mai_gesichter',
#   'ergebnis_ps_nm',
#   'suzuki_unterschiedliche_schwerpunkte',
#   'unterschiedliche_schwerpunkte_setzen',
#   'mehr_millionen_exemplaren',
#   'dadurch_versprechen_beide',
#   'versprechen_beide_hersteller',
#   'äußerst_spontanes_ansprechverhalten',
#   'groß_gewachsene_passagiere',
#   'gewachsene_passagiere_ausreichend',
#   'passagiere_ausreichend_platz',
#   'verbraucht_liter_diesel',
#   'schafft_stundenkilometer_spitze',
#   'audi_bastelt_fleißig',
#   'weitläufig_abgesperrten_milliardärsenklave',
#   'schon_dafür_zahlt',
#   'knapp_zehn_dollar',
#   'zehn_dollar_maut',
#   'jahre_alfa_romeo',
#   'alfa_romeo_standen',
#   'überall_wurde_geschrieben',
#   'ab_donnerstagmittag_erwartet',
#   'adac_dichten_verkehr',
#   'biogas_getankt_fährt',
#   'nürnberg_sitzen_kinder',
#   'schutzgitter_immer_geschlossen',
#   'minister_tiefensee_vorangetriebene',
#   'tiefensee_vorangetriebene_ökologische',
#   'vorangetriebene_ökologische_reinwaschung',
#   'ökologische_reinwaschung_schwerer',
#   'reinwaschung_schwerer_geländewagen',
#   'schwerer_geländewagen_erfüllt',
#   'hamburg_renault_läutet',
#   'jahr_lang_gar',
#   'offenes_auto_mehr',
#   'politiker_fürchterliche_angst',
#   'fürchterliche_angst_vorm',
#   'angst_vorm_volk',
#   'franken_aufpreis_optional',
#   'aufpreis_optional_erhältlichen',
#   'optional_erhältlichen_parksensoren',
#   'trotzdem_genießt_bmw',
#   'sachen_doppeltem_turbolader',
#   'doppeltem_turbolader_gesteuerten',
#   'turbolader_gesteuerten_nebenaggregaten',
#   'gesteuerten_nebenaggregaten_rückgewinnung',
#   'millionen_testkilometer_wurden',
#   'testkilometer_wurden_absolviert',
#   'wurden_absolviert_drei',
#   'absolviert_drei_mal',
#   'beim_vorgänger_sagt',
#   'vorgänger_sagt_entwicklungsvorstand',
#   'sagt_entwicklungsvorstand_thomas',
#   'entwicklungsvorstand_thomas_weber',
#   'immer_mehr_hersteller',
#   'mehr_hersteller_brachen',
#   'kunden_mindestens_jahre',
#   'mindestens_jahre_alt',
#   'schon_seit_zwei',
#   'seit_zwei_jahren',
#   'golf_gti_kilometer',
#   'damals_wurden_fahrzeuge',
#   'wurden_fahrzeuge_ausgeliefert',
#   'großen_zeitlichen_abstand',
#   'italienischen_kultwägelchen_abzugrenzen',
#   'dänemark_plus_prozent',
#   'plus_prozent_finnland',
#   'prozent_finnland_plus',
#   'finnland_plus_prozent',
#   'plus_prozent_schweden',
#   'prozent_schweden_plus',
#   'schweden_plus_sechs',
#   'plus_sechs_prozent',
#   'schweiz_plus_vier',
#   'plus_vier_prozent',
#   'neuwagen_glänzende_geschäfte',
#   'testfahrt_geht_holen',
#   'geht_holen_mütter',
#   'haus_schuljungs_stehen',
#   'hausfrauen_schütteln_verständnislos',
#   'passat_blue_motion',
#   'sündhaft_teuren_einzelstücken',
#   'teuren_einzelstücken_darf',
#   'ersten_öffentlichen_ausfahrt',
#   'euro_mehr_pro',
#   'mehr_pro_jahr',
#   'pro_jahr_fällig',
#   'kostet_euro_mehr',
#   'euro_mehr_steuern',
#   'mehr_steuern_pro',
#   'steuern_pro_jahr',
#   'autos_bleiben_dafür',
#   'bleiben_dafür_immer',
#   'dafür_immer_öfter',
#   'seit_jahrzehnten_sinkt',
#   'museum_mobile_gleich',
#   'mobile_gleich_neben',
#   'wm_dagegen_ruhmlos',
#   'hersteller_wählte_bewusst',
#   'wählte_bewusst_china',
#   'strategisch_wichtig_eingestuft',
#   'steilheck_sieht_gar',
#   'ab_sofort_bestellt',
#   'subaru_legacy_diesel',
#   'oben_angesprochenen_defizite',
#   'meter_lange_venga',
#   'lange_venga_wurde',
#   'venga_wurde_komplett',
#   'denkt_dabei_allerdings',
#   'dabei_allerdings_kaum',
#   'karren_sitzen_bleiben',
#   'prozent_rechnen_fühle',
#   'galerie_vw_touran',
#   'vw_touran_fit',
#   'neu_gestaltete_heckpartie',
#   'fast_kerzengerade_fensterlinie',
#   'kerzengerade_fensterlinie_macht',
#   'freiheit_verbürgt_vereine',
#   'spurassistent_beispielsweise_passt',
#   'technisch_gesehen_stammt',
#   'modellen_opel_insignia',
#   'üppiger_beladung_klar',
#   'gerade_vorgestellten_konzeptautos',
#   'letzten_halter_bezieht',
#   'adac_sieht_wegen',
#   'letzter_zeit_kräftig',
#   'zeit_kräftig_gefallenen',
#   'kräftig_gefallenen_ölpreises',
#   'gefallenen_ölpreises_weiteren',
#   'ölpreises_weiteren_spielraum',
#   'peking_berichtet_tom',
#   'berichtet_tom_grünweg',
#   'tom_grünweg_fotostrecke',
#   'grünweg_fotostrecke_bilder',
#   'fotostrecke_bilder_krise',
#   'arabischen_halbinsel_läuft',
#   'nordamerika_sollen_fast',
#   'sollen_fast_millionen',
#   'general_motors_gebaute',
#   'motors_gebaute_fahrzeuge',
#   'gebaute_fahrzeuge_überprüft',
#   'kriminalstatistik_geben_sagte',
#   'überführung_trat_kurz',
#   'knapp_stundenkilometer_bretterte',
#   'stundenkilometer_bretterte_big',
#   'bretterte_big_daddy',
#   'big_daddy_don',
#   'daddy_don_garlits',
#   'sinnvoller_wäre_reiner',
#   'optimalen_drehzahlbereich_läuft',
#   'drehzahlbereich_läuft_aufgeladen',
#   'einfach_maserati_streckte',
#   'dutzende_sexy_kandidatinnen',
#   'sexy_kandidatinnen_werben',
#   'neuen_rekordstände_sei',
#   'massiv_subventionierten_firmenwagen',
#   'ab_heute_wohl',
#   'meisten_besucher_drängeln',
#   'ab_januar_erwartet',
#   'januar_erwartet_sehen',
#   'kleine_stückzahlen_erreichen',
#   'stückzahlen_erreichen_sagt',
#   'dafür_mehr_lob',
#   'mehr_lob_einheimsten',
#   'zwei_jahre_ausgetragenen',
#   'jahre_ausgetragenen_wettbewerbs',
#   'beim_projekt_gravity',
#   'teil_dritter_tag',
#   'dritter_tag_esp',
#   'norwegen_eingetroffen_tief',
#   'eingetroffen_tief_verschneit',
#   'letzten_kilometer_rollten',
#   'geschlossene_schneedecke_teilweise',
#   'schneedecke_teilweise_recht',
#   'teilweise_recht_saftig',
#   'recht_saftig_bergauf',
#   'banknote_fand_durfte',
#   'behalten_prüfung_bestanden',
#   'mehr_ausreichend_sicherheit',
#   'ausreichend_sicherheit_gegeben',
#   'sicherheit_gegeben_warnt',
#   'gegeben_warnt_rainer',
#   'warnt_rainer_hillgärtner',
#   'weiteren_kriterien_erreichte',
#   'prozent_kindersicherheit_prozent',
#   'kindersicherheit_prozent_fußgängerschutz',
#   'euro_gelegen_diesel',
#   'gelegen_diesel_meist',
#   'großen_kommen_extras',
#   'weit_entfernt_schienen',
#   'art_vollkommenheit_vermitteln',
#   'vollkommenheit_vermitteln_ähnlich',
#   'wohl_geformte_anatomie',
#   'geformte_anatomie_steht',
#   'bevorstehende_anspielend_verfügt',
#   'gut_euro_zusätzlich',
#   'immer_mehr_menschen',
#   'mehr_menschen_fahren',
#   'konzern_panasonic_peve',
#   'beim_autolackhersteller_basf',
#   'autolackhersteller_basf_coatings',
#   'kojo_thompson_road',
#   'sportlicher_beschleunigung_zeigen',
#   'allrad_deutlich_souveräner',
#   'deutlich_souveräner_voran',
#   'serienmäßig_verbauten_fußmatten',
#   'verbauten_fußmatten_aufgelegt',
#   'knapp_zehn_sekunden',
#   'einzelnen_schalter_optimiert',
#   'artikel_wer_normalerweise',
#   'wer_normalerweise_brücken',
#   'überflüssig_langsam_klein',
#   'jahre_ähnlich_geblieben',
#   'gemütliche_breite_sitzbank',
#   'audis_bang_olufssen',
#   'heute_morgen_kurz',
#   'grande_atlantico_angelegt',
#   'seat_ibiza_tdi',
#   'ibiza_tdi_cr',
#   'tdi_cr_ecomotive',
#   'legendären_yellow_cabs',
#   'formel_schumacher_erster',
#   'kommende_saison_ambitioniert',
#   'wenigen_nationen_deren',
#   'nationen_deren_aggressivität',
#   'deren_aggressivität_sogar',
#   'gefährliches_verhalten_mündet',
#   'verhalten_mündet_prozent',
#   'mündet_prozent_geben',
#   'riskanten_fahrmanövern_reagiert',
#   'kleine_schwäche_ohnehin',
#   'schwäche_ohnehin_egal',
#   'kilometer_pro_stunde',
#   'verbrauch_gibt_bmw',
#   'gramm_pro_kilometer',
#   'größten_autobauer_europa',
#   'autobauer_europa_mut',
#   'happy_end_gibt',
#   'lediglich_verkauften_modellen',
#   'verkauften_modellen_gerechnet',
#   'ausfuhrkontrolle_bafa_steht',
#   'frühjahr_weitgehend_unbekannt',
#   'zehn_grad_minus',
#   'auto_sieht_schon',
#   'umliegenden_villen_klirren',
#   'villen_klirren_lassen',
#   'usa_bittet_praktisch',
#   'gründer_opfer_machiavellistischer',
#   'opfer_machiavellistischer_machenschaften',
#   'gefeierte_vw_passat',
#   'vw_passat_blue',
#   'passat_blue_motion',
#   'halben_liter_weniger',
#   'plötzlich_finden_viele',
#   'finden_viele_besitzer',
#   'viele_besitzer_irgendetwas',
#   'besitzer_irgendetwas_komisch',
#   'pflichtangebot_bezieht_beläuft',
#   'rund_milliarden_schwedische',
#   'milliarden_schwedische_kronen',
#   'schwedische_kronen_rund',
#   'kronen_rund_milliarden',
#   'rund_milliarden_euro',
#   'zurückgelegten_kilometer_drei',
#   'kilometer_drei_cent',
#   'drei_cent_zahlen',
#   'autobranche_weit_verbreitet',
#   'dabei_verspricht_natürlich',
#   'maximal_newtonmetern_schiebt',
#   'sinnfrei_herumpiepst_entscheidet',
#   'herumpiepst_entscheidet_nathan',
#   'weibliches_wesen_handeln',
#   'äußeres_ungleich_schöner',
#   'neuen_golf_variant',
#   'konkurrenten_anschaut_meint',
#   'anschaut_meint_längst',
#   'nachtleben_steht_achtet',
#   'verschiedene_kunststoffe_verhindern',
#   'ab_euro_erhältlich',
#   'wärme_verloren_geht',
#   'bemüht_soviel_bremsenergie',
#   'leichte_wolke_süßen',
#   'wolke_süßen_dufts',
#   'deutschen_bild_gibt',
#   'sprecher_citroëns_bedeckt',
#   'tdi_ps_fronttriebler',
#   'quadratmeter_großes_solardach',
#   'sonnigen_tag_hinweg',
#   'tag_hinweg_ungefähr',
#   'gut_gewählt_vielleicht',
#   'versteckten_prototypen_wurden',
#   'prototypen_wurden_erst',
#   'resch_hält_dagegen',
#   'nötigen_bauteilen_erklärte',
#   'freitag_firmensprecherin_natalya',
#   'firmensprecherin_natalya_sidoruk',
#   'zwei_millionen_anträgen',
#   'fünf_milliarden_euro',
#   'milliarden_euro_eigentlich',
#   'euro_eigentlich_ausgeschöpft',
#   'eigentlich_ausgeschöpft_interessenten',
#   'ausgeschöpft_interessenten_konnten',
#   'felix_rehwald_dpa',
#   'herstellern_üblichen_technik',
#   'lederbezüge_gekühlte_luft',
#   'gekühlte_luft_fächelt',
#   'luft_fächelt_bedient',
#   'konkurrent_mercedes_macht',
#   'verlangt_opel_einfach',
#   'noblen_fast_drei',
#   'fast_drei_meter',
#   'drei_meter_radstand',
#   'meter_radstand_lassen',
#   'sieben_sitzen_reichlich',
#   'sitzen_reichlich_freiraum',
#   'schade_anna_dafür',
#   'verbrauch_schaut_schaut',
#   'zweifarbig_außerdem_gibt',
#   'zehn_wählbaren_außenfarben',
#   'wählbaren_außenfarben_zwei',
#   'außenfarben_zwei_neue',
#   'mazdas_marketingabteilung_clear',
#   'marketingabteilung_clear_water',
#   'clear_water_blue',
#   'water_blue_metallic',
#   'midnight_bronce_mica',
#   'bronce_mica_getauft',
#   'ausgeprägten_anfahrlethargie_verblüffend',
#   'anfahrlethargie_verblüffend_flott',
#   'genf_gezeigte_suzuki',
#   'gezeigte_suzuki_beispielsweise',
#   'gramm_je_kilometer',
#   'basf_ausgerufenen_farbverlockung',
#   'ausgerufenen_farbverlockung_taten',
#   'farbverlockung_taten_folgen',
#   'taten_folgen_ließen',
#   'tachonadel_konnte_stundenlang',
#   'zehn_jahre_später',
#   'jahre_später_eigentlich',
#   'ab_heute_april',
#   'fehlverhalten_umso_größer',
#   'heiss_blick_versteigert',
#   'blick_versteigert_zusammen',
#   'getunten_suzuki_swift',
#   'kilometer_baustelle_zügeln',
#   'las_vegas_gibt',
#   'beim_ersten_harten',
#   'ersten_harten_rallyetest',
#   'komplett_neuen_autos',
#   'gravierender_konstruktionsfehler_zeigt',
#   'liter_pro_gefahrene',
#   'pro_gefahrene_kilometer',
#   'ermitteln_sollten_autofahrer',
#   'mehrere_tankzyklen_notieren',
#   'einzige_richtige_lesestück',
#   'vergangenen_jahrhunderts_begann',
#   'verbesserten_aerodynamik_erreicht',
#   'verbrauch_gibt_brabus',
#   'bestellt_teile_ja',
#   'beim_konzern_direkt',
#   'neue_markentypische_design',
#   'kostenloses_fahrzeug_statt',
#   'fahrzeug_statt_kostenloses',
#   'statt_kostenloses_handy',
#   'kostenloses_handy_sagt',
#   'handy_sagt_stefan',
#   'sagt_stefan_lippert',
#   'zweite_treibende_kraft',
#   'italienischen_autos_bisher',
#   'autos_bisher_ja',
#   'bisher_ja_meistens',
#   'geringen_punkten_smart',
#   'alten_mercedes_beim',
#   'mercedes_beim_schrotthändler',
#   'verwertungsnachweis_ausstellen_lassen',
#   'wagens_beträgt_drei',
#   'beträgt_drei_tonnen',
#   'cockpit_bietet_platz',
#   'portemonnaie_wirklich_wehtut',
#   'verhalten_ändern_sagte',
#   'ändern_sagte_tiefensee',
#   'kombi_jegliche_zurückhaltung',
#   'jegliche_zurückhaltung_ab',
#   'hochplateau_deutlich_ruhiger',
#   'lange_vorführen_lassen',
#   'thema_spritsparen_galt',
#   'sportwagen_vorstellt_bissig',
#   'luxus_nirgends_mehr',
#   'nirgends_mehr_tradition',
#   'titaniumdie_ausstattungsvarianten_ambiente',
#   'ausstattungsvarianten_ambiente_basis',
#   'ambiente_basis_trend',
#   'basis_trend_euro',
#   'trend_euro_aufpreis',
#   'titanium_euro_aufpreis',
#   'beide_längen_angeboten',
#   'wartungsarmen_riemen_aufs',
#   'riemen_aufs_hinterrad',
#   'aufs_hinterrad_übertragen',
#   'einstiegsversion_tendance_hdi',
#   'tendance_hdi_fap',
#   'ps_starkem_kostet',
#   'starkem_kostet_ab',
#   'kostet_ab_euro',
#   'laut_peugeot_deutschland',
#   'peugeot_deutschland_euro',
#   'deutschland_euro_weniger',
#   'günstige_alternative_lorbeeren',
#   'alternative_lorbeeren_einheimsen',
#   'überarbeiteten_antara_findet',
#   'verschlüsselte_automotive_wlan',
#   'zentralen_verkehrsrechner_verbunden',
#   'auto_kontakt_aufnehmen',
#   'immer_liebe_wolkenschlösschenbauer',
#   'tibet_durchs_himalaja',
#   'mehr_schalter_trägt',
#   'dezember_wurde_zudem',
#   'russischen_petersburg_eröffnet',
#   'zugleich_nahmen_laut',
#   'nahmen_laut_statistischem',
#   'laut_statistischem_bundesamt',
#   'wurden_rund_verkehrstote',
#   'rund_verkehrstote_gezählt',
#   'viele_menschen_mögen',
#   'sache_kaum_besser',
#   'entsprechenden_bumms_sorgt',
#   'mittel_reichten_somit',
#   'stetig_zunehmende_größe',
#   'zwei_milliarden_autos',
#   'kalifornische_mobilitätsexperte_dan',
#   'mobilitätsexperte_dan_sperling',
#   'buch_two_billion',
#   'two_billion_cars',
#   'leider_bietet_volvo',
#   'bietet_volvo_dafür',
#   'französischer_raser_bekommt',
#   'deutsche_verkehrssünder_deshalb',
#   'fotostrecke_bilder_wohnmobil',
#   'bilder_wohnmobil_extrem',
#   'augenblicke_lieben_danny',
#   'lieben_danny_brink',
#   'linke_spur_wechseln',
#   'benzinverbrauch_künftig_besser',
#   'künftig_besser_erkennen',
#   'fritz_fend_immer',
#   'fend_immer_schlechter',
#   'wahnsinnigen_transportprojekts_wagen',
#   'niemals_halt_macht',
#   'komfortseite_ergänzen_elektrisch',
#   'beheizbare_außenspiegel_höhenverstellbare',
#   'außenspiegel_höhenverstellbare_beifahrersitze',
#   'punkten_erhielten_früher',
#   'erhielten_früher_vier',
#   'früher_vier_sterne',
#   'general_motors_powertrain',
#   'motors_powertrain_europe',
#   'startklar_meter_lang',
#   'vergangenen_monaten_hundert',
#   'elektroantrieb_umgerüstete_smarts',
#   'dicht_gedrängten_feld',
#   'autonation_nummer_eins',
#   'nummer_eins_eingeholt',
#   'mitte_kräftig_auffahren',
#   'diesel_klare_vorteile',
#   'klare_vorteile_beim',
#   'vorteile_beim_verbrauch',
#   'ungefähr_schließlich_wurden',
#   'schottischem_einschlag_gedreht',
#   'hohen_geschwindigkeiten_macht',
#   'autofan_per_google',
#   'per_google_jagd',
#   'stärkste_ottomotor_steht',
#   'nochmals_geringere_nachfrage',
#   'geringere_nachfrage_sorgen',
#   'sachen_innovationsführerschaft_längst',
#   'heiße_tränen_vergießen',
#   'tränen_vergießen_sobald',
#   'hof_rollen_sah',
#   'benchmarkende_kleine_blechspielzeuge',
#   'prozent_mehr_drehmoment',
#   'dennoch_weniger_verbrauchen',
#   'rang_zwei_lag',
#   'preis_ab_franken',
#   'denen_moss_fast',
#   'teure_überproduktion_verfehltes',
#   'überproduktion_verfehltes_wirtschaften',
#   'april_enthüllte_dieter',
#   'enthüllte_dieter_zetsche',
#   'neuen_mercedes_glk',
#   'frisch_renovierten_touran',
#   'weniger_nutzwert_gern',
#   'nutzwert_gern_mehr',
#   'gern_mehr_ausgeben',
#   'interesse_daran_neue',
#   'daran_neue_gaskunden',
#   'firma_rinspeed_sorgt',
#   'rinspeed_sorgt_traditionell',
#   'ebenfalls_neuen_sechsgangautomatik',
#   'neuen_sechsgangautomatik_kombiniert',
#   'zumindest_hierzulande_kaum',
#   'hierzulande_kaum_jemand',
#   'dacia_sandero_bietet',
#   'sandero_bietet_ähnliche',
#   'bietet_ähnliche_qualität',
#   'auto_dagegen_hilft',
#   'dagegen_hilft_unten',
#   'neuen_flügeltürers_sls',
#   'neuen_turboladers_geschärfter',
#   'turboladers_geschärfter_chips',
#   'maschine_rund_ps',
#   'sekunde_genannte_rekordzug',
#   'genannte_rekordzug_wurde',
#   'zusammen_etwa_millionen',
#   'etwa_millionen_euro',
#   'innenraum_überrascht_mazda',
#   'überrascht_mazda_neben',
#   'mazda_neben_diversen',
#   'straßenbild_bestens_bekannt',
#   'ford_focus_citroën',
#   'focus_citroën_subaru',
#   'citroën_subaru_impreza',
#   'grauen_stoffsitzen_direkt',
#   'mittelpunkt_jedenfalls_stehen',
#   'dürren_mitteilung_sagte',
#   'zuvor_großangekündigte_autoversteigerung',
#   'großangekündigte_autoversteigerung_ab',
#   'volvo_amazon_her',
#   'weitere_vier_prozent',
#   'vier_prozent_verfolgen',
#   'kaum_hörbare_lassen',
#   'umgerechnet_meilen_mille',
#   'meilen_mille_miglia',
#   'viele_kommentatoren_kommen',
#   'kommentatoren_kommen_offensichtlich',
#   'unrechtsbewusstsein_offensichtlich_resistent',
#   'altea_freetrack_startklar',
#   'großen_erwartungen_gestartete',
#   'erwartungen_gestartete_auto',
#   'gestartete_auto_kam',
#   'auto_kam_zunächst',
#   'kam_zunächst_gar',
#   'besser_kleine_brötchen',
#   'entwickelten_märkten_gebe',
#   'günstige_autos_sagte',
#   'tata_motors_ratan',
#   'motors_ratan_tata',
#   'geschlossenes_golf_cabrio',
#   'teuerste_nummernschild_großbritanniens',
#   'auto_china_weitere',
#   'china_weitere_mehr',
#   'minder_deutsche_fahrzeuge',
#   'deutsche_fahrzeuge_premiere',
#   'wall_street_journal',
#   'street_journal_teilweise',
#   'krediten_chinesischer_staatsbanken',
#   'chinesischer_staatsbanken_finanzieren',
#   'milliarden_yuan_milliarden',
#   'yuan_milliarden_euro',
#   'bank_of_china',
#   'peugeot_sagt_professor',
#   'sagt_professor_loubet',
#   'citroën_gehören_sechs',
#   'gehören_sechs_airbags',
#   'sechs_airbags_esp',
#   'airbags_esp_tempomat',
#   'esp_tempomat_klimaanlage',
#   'tempomat_klimaanlage_zentralverriegelung',
#   'klimaanlage_zentralverriegelung_elektrische',
#   'zentralverriegelung_elektrische_fensterheber',
#   'elektrische_fensterheber_vorn',
#   'fensterheber_vorn_sowie',
#   'vorn_sowie_elektrisch',
#   'sowie_elektrisch_verstellbare',
#   'elektrisch_verstellbare_außenspiegel',
#   'arm_aufs_türblech',
#   'aufs_türblech_legen',
#   'fahrzeuge_müssten_oft',
#   'betongerahmten_doppelspuren_dahin',
#   'doppelspuren_dahin_schleichen',
#   'nennenswerte_bautätigkeiten_auszumachen',
#   'bautätigkeiten_auszumachen_seien',
#   'nutzer_geprägte_petitesse',
#   'geprägte_petitesse_trennen',
#   'petitesse_trennen_nämlich',
#   'emirat_dubai_möchte',
#   'dubai_möchte_derartige',
#   'möchte_derartige_situationen',
#   'derartige_situationen_entschärfen',
#   'gab_deshalb_gleich',
#   'deshalb_gleich_drei',
#   'gleich_drei_großraumrettungswagen',
#   'daneben_stehenden_technisch',
#   'stehenden_technisch_identischen',
#   'technisch_identischen_golf',
#   'identischen_golf_umso',
#   'golf_umso_mehr',
#   'deutsche_volk_schon',
#   'volk_schon_lange',
#   'fiat_wog_kilo',
#   'problem_bislang_lassen',
#   'teurer_handarbeit_herstellen',
#   'sogenannten_autoklaven_immensen',
#   'autoklaven_immensen_heizöfen',
#   'immensen_heizöfen_gebacken',
#   'medien_genannt_sei',
#   'etwa_einheiten_pro',
#   'einheiten_pro_jahr',
#   'pro_jahr_angestrebt',
#   'jahr_angestrebt_sagte',
#   'angestrebt_sagte_stadler',
#   'automobile_oberhaus_blies',
#   'neuen_golf_r',
#   'wuchtet_dagegen_newtonmeter',
#   'kurbelwelle_ebenfalls_ab',
#   'damals_beteiligten_städten',
#   'zukunftstechnologie_treu_geblieben',
#   'treu_geblieben_sagt',
#   'überholstreifen_liegen_derzeit',
#   'sechs_zentimeter_breiter',
#   'gestreckten_radstands_schlanker',
#   'metern_nahezu_unverändert',
#   'nahezu_unverändert_blieb',
#   'projekt_jahrelang_blockiert',
#   'mehr_geländewagen_verkauft',
#   'gesamten_bundesrepublik_rückt',
#   'bundesrepublik_rückt_dudenhöffer',
#   'computergestützten_systeme_gibt',
#   'bereits_bisher_allerdings',
#   'motorräder_müssen_seit',
#   'müssen_seit_immer',
#   'seit_immer_beleuchtet',
#   'wiederum_ganz_schön',
#   'ganz_schön_heftig',
#   'schön_heftig_ausfallen',
#   'altbekannte_liter_große',
#   'liter_große_erhält',
#   'teuerste_bmw_bislang',
#   'bezeichnung_concept_series',
#   'concept_series_activehybrid',
#   'series_activehybrid_kombiniert',
#   'activehybrid_kombiniert_bmw',
#   'kw_starken_elektromotor',
#   'beetle_unterschiedliche_motoren',
#   'viertürer_gran_coupé',
#   'gran_coupé_geben',
#   'concept_car_gezeigt',
#   'zweite_seat_heisst',
#   'seat_heisst_ibiza',
#   'motto_tote_plaudern',
#   'schließens_angeht_befindet',
#   'weltweit_erfolgreichsten_kleinwagen',
#   'einfach_frech_kopiert',
#   'drei_jahren_nachziehen',
#   'fashion_week_berlin',
#   'ersten_mal_stattfindet',
#   'schon_seit_arbeiten',
#   'vielen_verschiedenen_optionen',
#   'verschiedenen_optionen_spielen',
#   'fahrzeug_ganz_deutlich',
#   'sagt_jens_müller',
#   'halbfertiger_bambusrahmen_handgemacht',
#   'berlin_bamboo_bikes',
#   'laut_ace_sollen',
#   'wenigen_ausnahmen_durchgehend',
#   'durchgebrannte_zylinderkopfdichtungen_wurden',
#   'seite_palmen_strand',
#   'regelfall_gelangen_prozent',
#   'deren_verbrennung_entstehen',
#   'statt_nackter_flächen',
#   'leicht_gepolstertes_armaturenbrett',
#   'frontklappe_verschwinden_geben',
#   'aktuelle_elektrische_reichweite',
#   'elektrische_reichweite_darstellt',
#   'liter_je_kilometer',
#   'je_kilometer_gesenkt',
#   'leicht_verwässerte_nachschärfen',
#   'dieselfahrzeugen_liegen_aufgrund',
#   'dynamischen_karosserie_verbirgt',
#   'komplett_neues_fahrwerk',
#   'kleinstwagen_mobilisierte_jahre',
#   'mobilisierte_jahre_lang',
#   'öffentlichen_personennahverkehr_öpnv',
#   'raffinerien_verdienten_dagegen',
#   'verdienten_dagegen_kaum',
#   'dagegen_kaum_geld',
#   'hoher_geschwindigkeit_extrem',
#   'geschwindigkeit_extrem_laut',
#   'eigene_modellreihe_seit',
#   'eigenständige_modellreihe_angeboten',
#   'weitere_neuerung_drückte',
#   'euro_deutlich_billiger',
#   'gerade_vorgestellte_gts',
#   'fahre_seit_knapp',
#   'seit_knapp_monaten',
#   'deutschen_zunächst_bmw',
#   'zunächst_bmw_isetta',
#   'neue_star_eigentlich',
#   'ausgezeichnete_straßenlage_dank',
#   'deutschland_mehr_autos',
#   'mehr_autos_verkauft',
#   'zusammen_sagt_zetsche',
#   'sagt_zetsche_stolz',
#   'letztgenannte_frage_wurde',
#   'kundschaft_ziemlich_eindeutig',
#   'ziemlich_eindeutig_beantwortet',
#   'dafür_steckt_tim',
#   'steckt_tim_wright',
#   'mazda_cosmo_owners',
#   'cosmo_owners_club',
#   'ausgesprochen_japanische_angelegenheit',
#   'bar_gespeichert_flüssiggas',
#   'gespeichert_flüssiggas_rund',
#   'flüssiggas_rund_zehn',
#   'rund_zehn_bar',
#   'kleiner_pfeil_hervor',
#   'cockpits_erhielten_jeweils',
#   'erhielten_jeweils_eigene',
#   'jeweils_eigene_einfassungen',
#   'firmen_audi_bmw',
#   'audi_bmw_citroën',
#   'bmw_citroën_daihatsu',
#   'citroën_daihatsu_honda',
#   'daihatsu_honda_kia',
#   'honda_kia_lexus',
#   'spiegel_online_herr',
#   'online_herr_barth',
#   'deutlich_zugenommen_bestätigt',
#   'zugenommen_bestätigt_pietro',
#   'bestätigt_pietro_zollino',
#   'pietro_zollino_statt',
#   'zollino_statt_autos',
#   'markteinführung_euro_kosten',
#   ...],
#  'keyword/news_text100k.txt': ['jahre_arbeiterkammer_bedeuten',
#   'arbeiterkammer_bedeuten_jahre',
#   'bedeuten_jahre_einsatz',
#   'big_aggregierte_spitzenmietpreiswachstum',
#   'geringer_abschwächung_anhalten',
#   'davis_geht_angesichts',
#   'herrschenden_kapitalistischen_produktionsweise',
#   'kapitalistischen_produktionsweise_zudem',
#   'produktionsweise_zudem_davon',
#   'sämtliche_formen_unproduktiver',
#   'formen_unproduktiver_arbeit',
#   'herrschenden_klasse_entlohnt',
#   'zwei_spuren_pro',
#   'spuren_pro_fahrtrichtung',
#   'fünf_verletzten_darunter',
#   'autobahnkreuz_nürnberg_gekommen',
#   'aachener_gastronomen_verlieren',
#   'aaron_lahl_verdeutlicht',
#   'beitrag_analyzing_queer',
#   'antke_engel_inwiefern',
#   'klassischen_psychoanalyse_komplett',
#   'psychoanalyse_komplett_entkernt',
#   'aaron_purschwitz_m',
#   'trotz_platz_zwei',
#   'ab_mai_dürfen',
#   'mai_dürfen_cafés',
#   'kundschaft_ausserhalb_bedienen',
#   'ab_dezember_sollen',
#   'ausgangsbeschränkungen_fallen_kinos',
#   'fallen_kinos_theater',
#   'berittene_männer_drei',
#   'männer_drei_wachen',
#   'doktor_befinden_mussten',
#   'ab_uhr_stehen',
#   'fk_shakhtar_donetsk',
#   'shakhtar_donetsk_gegenüber',
#   'ab_mai_dürfen',
#   'ab_wurden_etliche',
#   'drei_stöckige_hochhäuser',
#   'ab_dezember_tritt',
#   'ab_uhr_liest',
#   'freitag_februar_johannes',
#   'februar_johannes_twaroch',
#   'ab_juni_gilt',
#   'ab_mai_sollen',
#   'einkaufszentren_öffnen_ebenfalls',
#   'ab_märz_senken',
#   'märz_senken_viele',
#   'senken_viele_versicherungen',
#   'berechnung_herangezogen_weiß',
#   'herangezogen_weiß_nikola',
#   'weiß_nikola_junick',
#   'ab_september_ziehen',
#   'ab_uhr_live',
#   'rund_neun_millionen',
#   'neun_millionen_autofahrer',
#   'millionen_autofahrer_neue',
#   'autofahrer_neue_regionalklassen',
#   'neuer_dienst_eingeführt',
#   'markt_langsam_erholen',
#   'inländischer_produktion_umgestellt',
#   'ab_uhr_erreichte',
#   'ersten_millionen_prozent',
#   'freundschaft_millionen_prozent',
#   'millionen_prozent_sehen',
#   'ab_uhr_sahen',
#   'uhr_sahen_millionen',
#   'sahen_millionen_zuschauer',
#   'ab_februar_geht',
#   'alias_meyer_offerman',
#   'ab_märz_läuft',
#   'märz_läuft_immer',
#   'läuft_immer_montags',
#   'ab_uhr_dürften',
#   'uhr_dürften_restaurants',
#   'ab_mai_empfängt',
#   'vorstandsmitglied_renko_dirksen',
#   'vorstands_koordinieren_teilte',
#   'ab_september_reist',
#   'september_reist_oscarpreisträgerin',
#   'reist_oscarpreisträgerin_hilary',
#   'oscarpreisträgerin_hilary_swank',
#   'hilary_swank_million',
#   'swank_million_dollar',
#   'million_dollar_baby',
#   'ab_uhr_schunkelten',
#   'bahnhof_köln_evakuiert',
#   'köln_evakuiert_ab',
#   'ab_anfang_übernimmt',
#   'anfang_übernimmt_bremen',
#   'ab_april_gilt',
#   'paar_weitere_quartierstrassen',
#   'ab_april_plant',
#   'april_plant_signa',
#   'abarhoun_bestritt_trotz',
#   'traf_dabei_zweimal',
#   'ab_august_fährt',
#   'twin_city_liner',
#   'partie_offen_gestalten',
#   'referee_daniel_siebert',
#   'falschwerweise_strafstoß_entschied',
#   'möglichkeit_vereinseigene_sporthallen',
#   'vereinseigene_sporthallen_bzw',
#   'ehc_red_bull',
#   'red_bull_münchen',
#   'genauso_erfolgreich_weitergehen',
#   'durchgeführten_tests_stark',
#   'schnitt_menschen_getestet',
#   'juli_dürfen_kunden',
#   'dürfen_kunden_geschäfte',
#   'mai_kommen_je',
#   'bahnhof_gösing_führt',
#   'heutigen_mittwoch_dezember',
#   'mittwoch_dezember_gilt',
#   'neuen_ölheizkessel_mehr',
#   'ölheizkessel_mehr_aufgestellt',
#   'spanier_carlos_sainz',
#   'carlos_sainz_anstelle',
#   'kommenden_januar_gibt',
#   'pro_krankheitsfall_drei',
#   'krankheitsfall_drei_tage',
#   'drei_tage_bezahlten',
#   'tage_bezahlten_urlaub',
#   'kommenden_wochenende_fahren',
#   'wochenende_fahren_nachts',
#   'bergland_einzelne_schauer',
#   'einzelne_schauer_möglich',
#   'differenzierte_beurteilung_je',
#   'ab_dezember_gibt',
#   'homepage_kurze_videos',
#   'ab_dienstag_beginnt',
#   'öffentliche_leben_drastisch',
#   'leben_drastisch_heruntergefahren',
#   'deutlich_mehr_zuschauer',
#   'etwa_kilometer_transportleitung',
#   'ab_donnerstag_september',
#   'donnerstag_september_bricht',
#   'ab_donnerstag_steigen',
#   'insgesamt_zehn_weiteren',
#   'zehn_weiteren_staaten',
#   'weiteren_staaten_untersagt',
#   'abdul_azim_akanga',
#   'azim_akanga_fügte',
#   'dennis_gilke_rückte',
#   'beanstandete_rund_stimmen',
#   'zurzeit_köln_solingen',
#   'bestimmten_länge_könnten',
#   'neuinfektionen_pro_einwohner',
#   'pro_einwohner_innerhalb',
#   'sogenannten_zusätzliche_einschränkungen',
#   'zusätzliche_einschränkungen_geben',
#   'einzelfall_entschieden_klassen',
#   'trennen_vorher_ab',
#   'draußen_maximal_personen',
#   'maximal_personen_zulässig',
#   'zuständige_behörde_lässt',
#   'behörde_lässt_ausnahmen',
#   'ab_einmündung_untere',
#   'einmündung_untere_wiesenstraße',
#   'untere_wiesenstraße_entlang',
#   'ab_ende_august',
#   'ende_august_ging',
#   'kurs_kontinuierlich_abwärts',
#   'tiefsten_stand_seit',
#   'stand_seit_anfang',
#   'seit_anfang_august',
#   'ab_ende_august',
#   'ende_august_sollen',
#   'völlig_neue_thinkpad',
#   'neue_thinkpad_p',
#   'zeller_gemeinderat_ausschließlich',
#   'abends_feiern_eva',
#   'feiern_eva_klingler',
#   'rotlichtkönigin_margarete_reinhardt',
#   'abendstimmung_ende_september',
#   'uhr_beim_kraftwerk',
#   'beim_kraftwerk_birsfelden',
#   'lokal_praktisch_leer',
#   'mark_twains_tom',
#   'twains_tom_sawyer',
#   'huckleberry_finn_verwandelt',
#   'abenteuer_pur_erlebten',
#   'projekt_eh_eingestellt',
#   'klar_davon_distanzieren',
#   'kopfhaut_meist_mehr',
#   'meist_mehr_zeit',
#   'mehr_zeit_brauchen',
#   'videokonferenzen_remote_desktop',
#   'aktivistin_johanna_fuoß',
#   'tierschutzorganisation_peta_kritisiert',
#   'entrichteten_beiträge_rückwirkend',
#   'beiträge_rückwirkend_erstattet',
#   'späteren_einschränkungen_akut',
#   'einschränkungen_akut_betroffener',
#   'akut_betroffener_bürger',
#   'natürlich_gedanken_gemacht',
#   'situation_reagiert_hätte',
#   'rund_drei_wochen',
#   'marc_lüthi_meldete',
#   'jobangebot_komplett_unerwartet',
#   'komplett_unerwartet_kam',
#   'kaum_zwei_wochen',
#   'gesunkenen_zinsen_entstünden',
#   'gesamte_laufzeit_nominale',
#   'laufzeit_nominale_mehrkosten',
#   'vier_milliarden_euro',
#   'erneuten_aufstieg_dennoch',
#   'gesund_fürs_geschäft',
#   'rapper_relativ_klassische',
#   'relativ_klassische_werdegang',
#   'gar_untypischen_künstler',
#   'untypischen_künstler_hervorgebracht',
#   'anke_rothenpieler_weiß',
#   'rothenpieler_weiß_allein',
#   'digitalen_wegen_möchte',
#   'genussvollem_essen_näherbringen',
#   'reparatur_kaputter_gegenstände',
#   'betriebe_profitieren_sollten',
#   'profitieren_sollten_gingen',
#   'größeren_ansturm_sei',
#   'bildung_wurde_vermittelt',
#   'mensch_mehr_hätte',
#   'ministerpräsident_armin_laschet',
#   'sprecher_laut_nachrichtenportal',
#   'laut_nachrichtenportal_alef',
#   'sieben_punkten_aussichtsreich',
#   'punktlose_schlusslicht_island',
#   'interessante_mörderjägerinnen_hervorbringen',
#   'plüderhausen_wiewohl_sauber',
#   'verlassen_sollten_möglichst',
#   'sollten_möglichst_erfolgen',
#   'möglichst_erfolgen_sowie',
#   'gute_alte_panzerkette',
#   'alte_panzerkette_erlebt',
#   'verspielten_anhängern_wobei',
#   'anhängern_wobei_immer',
#   'wobei_immer_gleich',
#   'immer_gleich_mehrere',
#   'gleich_mehrere_getragen',
#   'wunderschön_schwärmt_sonja',
#   'schwärmt_sonja_huber',
#   'datenschutzeinstellungen_wurden_erheblich',
#   'wurden_erheblich_verbessert',
#   'donauwörther_seien_vermehrt',
#   'heimat_unterwegs_berichtet',
#   'unterwegs_berichtet_steger',
#   'gesellige_seite_kommt',
#   'richterlich_angeordneten_nachzählungen',
#   'angeordneten_nachzählungen_ergaben',
#   'wochen_wusste_niemand',
#   'wusste_niemand_wer',
#   'nase_wirklich_vorne',
#   'hand_mann_beschwert',
#   'frage_bislang_unbeantwortet',
#   'buch_übers_gehört',
#   'oft_schon_genannt',
#   'schon_genannt_wurde',
#   'deutsches_forschungsinstitut_findet',
#   'vermindertes_hörvermögen_besonders',
#   'tiefen_frequenzen_sowie',
#   'frequenzen_sowie_beeinträchtigungen',
#   'kurzzeitgedächtnisses_müssen_letztlich',
#   'müssen_letztlich_beim',
#   'letztlich_beim_design',
#   'ganz_schön_sinnlos',
#   'schön_sinnlos_denke',
#   'zweier_konzentrieren_anstatt',
#   'durchschnittlich_gut_besetzten',
#   'gut_besetzten_vierer',
#   'besser_später_begonnen',
#   'später_begonnen_hätte',
#   'inzwischen_deutliche_spuren',
#   'deutliche_spuren_hinterlassen',
#   'veranstaltungen_beschäftigen_viele',
#   'beschäftigen_viele_menschen',
#   'neue_fahrplan_gilt',
#   'bremer_vahr_verloren',
#   'vorarlberg_wurden_unregelmäßigkeiten',
#   'wurden_unregelmäßigkeiten_aufgedeckt',
#   'immer_mehr_veranstalter',
#   'halten_sagt_peintinger',
#   'ministerpräsident_kretschmer_setzen',
#   'zwang_freilich_explizit',
#   'freilich_explizit_auszuschließen',
#   'apotheken_kommen_infrage',
#   'saftigen_strukturierteren_pinela',
#   'weiterführenden_literatur_gibt',
#   'bayerischen_landkreis_tirschenreuth',
#   'kanzler_lieber_wäre',
#   'lieber_wäre_scholz',
#   'skigebiet_deer_valley',
#   'mörderische_frage_wer',
#   'aktuelle_personal_gibt',
#   'schon_fertiggestellte_projekte',
#   'fertiggestellte_projekte_könnten',
#   'projekte_könnten_weitere',
#   'könnten_weitere_unterstützung',
#   'weitere_unterstützung_gebrauchen',
#   'sollen_langsam_merken',
#   'wirksame_militanz_gerettet',
#   'bewegung_tun_gut',
#   'unterschiedliche_meinungen_gebe',
#   'nächste_mehrjährige_finanzrahmen',
#   'verknüpfte_next_generation',
#   'next_generation_eu',
#   'generation_eu_sowie',
#   'wahl_absolut_sicher',
#   'stehplätzen_könnten_je',
#   'mehr_abwechslung_gesorgt',
#   'beide_maßnahmen_bedeuten',
#   'maßnahmen_bedeuten_natürlich',
#   'zwei_prozent_völlig',
#   'prozent_völlig_ausreichend',
#   'draußen_aufzuhalten_teilte',
#   'aufzuhalten_teilte_peter',
#   'teilte_peter_hinze',
#   'peter_hinze_bürgermeister',
#   'sogar_wahlen_angepasst',
#   'ordentliche_rechtsprechung_erwarten',
#   'paar_jahre_dauern',
#   'coronavirus_getestet_worden',
#   'bislang_denkt_niemand',
#   'denkt_niemand_darüber',
#   'wirklich_selbstfahrenden_auto',
#   'fahrers_sicher_fährt',
#   'boom_schnell_vorbei',
#   'leben_ständig_worte',
#   'nachbarskinder_besser_kennen',
#   'besser_kennen_gelernt',
#   'weitere_kopie_erwartet',
#   'kopie_erwartet_spricht',
#   'fortsetzung_übertragen_wurde',
#   'zeugen_stattfinden_siehe',
#   'stattfinden_siehe_artikel',
#   'siehe_artikel_rechts',
#   'hohe_medizinische_verantwortung',
#   'einst_vier_hinüberretten',
#   'absolute_chaos_ausbricht',
#   'zukünftigen_überfüllungen_vorzubeugen',
#   'führung_verliert_müsste',
#   'linde_überraschend_gut',
#   'dritte_quartal_gekommen',
#   'lage_innerhalb_kürzester',
#   'innerhalb_kürzester_zeit',
#   'zwei_identischen_tore',
#   'identischen_tore_beide',
#   'tore_beide_vorgelegt',
#   'dinge_transportieren_müsse',
#   'siegfrieds_kühns_schwarzweiß',
#   'wurde_corona_immer',
#   'corona_immer_intensiver',
#   'text_ständig_umgeschrieben',
#   'bewusstsein_dafür_wachse',
#   'kleiner_erster_schritt',
#   'kalkulierbar_darauf_hoffen',
#   'neuen_wetterbedingungen_gewöhnt',
#   'ganze_bild_interessanterweise',
#   'bild_interessanterweise_gab',
#   'namen_wechselseitiger_unterricht',
#   'eigentlich_ganz_typisch',
#   'hauptmann_bratges_größte',
#   'bratges_größte_sorge',
#   'leicht_abschalten_besinnen',
#   'sport_sowieso_immer',
#   'sowieso_immer_weiß',
#   'immer_weiß_schild',
#   'gewissen_freilauf_gewährt',
#   'grosseltern_schützt_halte',
#   'art_abrechnung_macht',
#   'abrechnung_macht_wusste',
#   'jahre_alte_schulden',
#   'alte_schulden_interessieren',
#   'parlament_weitgehend_ausgeschaltet',
#   'offenen_seiten_gehabt',
#   'aerosole_frei_fliegen',
#   'frei_fliegen_konnten',
#   'fliegen_konnten_genauso',
#   'minister_heinz_faßmann',
#   'verzehrkarte_rettet_gerade',
#   'rettet_gerade_vereine',
#   'gute_schippe_weniger',
#   'schippe_weniger_pathos',
#   'liedchen_ganz_gut',
#   'ganz_gut_getan',
#   'wurde_beim_zwanzigjahrjubiläum',
#   'jahr_schon_ausführlich',
#   'schon_ausführlich_gemacht',
#   'heinz_niggs_grossem',
#   'niggs_grossem_interviewprojekt',
#   'david_bowie_sagte',
#   'bowie_sagte_schon',
#   'knallharte_nüchterne_frau',
#   'zwei_siege_kommen',
#   'misogynen_rassisten_anzusehen',
#   'neue_grippeform_auftreten',
#   'dennoch_sollen_angehörige',
#   'umständen_geschuldet_leider',
#   'geschuldet_leider_allein',
#   'deren_zahl_sei',
#   'zahl_sei_rückläufig',
#   'sei_rückläufig_erklärt',
#   'rückläufig_erklärt_meyer',
#   'gemeinde_steuerfuss_prozent',
#   'partei_wäre_schon',
#   'wäre_schon_geholfen',
#   'frau_anfang_spaziert',
#   'kurzer_hose_bekleidet',
#   'jahresfrist_kündigte_sony',
#   'namen_reality_audio',
#   'reality_audio_hört',
#   'ja_wirklich_brutal',
#   'schilling_muß_ja',
#   'muß_ja_rollen',
#   'tabellenführer_msv_duisburg',
#   'msv_duisburg_erreichten',
#   'spruch_entwickelt_komplizierte',
#   'entwickelt_komplizierte_nebenwirkungen',
#   'debatte_darüber_wer',
#   'darüber_wer_charlie',
#   'woche_lang_spürbar',
#   'hübsche_geschichte_parat',
#   'vorstandsvorsitzende_konnte_zufrieden',
#   'konnte_zufrieden_melden',
#   'absolute_sicherheit_gibt',
#   'aktion_könne_helfen',
#   'neue_reiseabenteuer_nutzen',
#   'zentren_sei_mittlerweile',
#   'nehmen_seien_wichtig',
#   'immerhin_planbaren_jahrhundertsituation',
#   'planbaren_jahrhundertsituation_stehen',
#   'jahrhundertsituation_stehen_gelassen',
#   'bezirke_schaffen_kaum',
#   'schaffen_kaum_neue',
#   'kaum_neue_radweginfrastruktur',
#   'bisherige_höhe_reicht',
#   'formel_unterstreicht_källenius',
#   'unterstreicht_källenius_bleibt',
#   'gebiet_mogiljow_genug',
#   'energiewende_versorgungssicher_gewährleistet',
#   'moralischen_furor_beängstigend',
#   'schon_letztes_jahr',
#   'heimische_kulturszene_braucht',
#   'informationen_fließen_spärlich',
#   'erfolg_verdient_gehabt',
#   'business_as_usual',
#   'kunden_kommen_trotzdem',
#   'mahnungen_führen_jahrein',
#   'führen_jahrein_jahraus',
#   'ausschließen_schildert_lutterjohann',
#   'operation_birgt_nebenwirkungen',
#   'montag_endlich_umgesetzt',
#   'rahmenbedingungen_müssen_stimmen',
#   'sozialen_netzwerken_zeigen',
#   'netzwerken_zeigen_vielen',
#   'zeigen_vielen_geht',
#   'weimarer_republik_lange',
#   'republik_lange_getan',
#   'versammlungsbehörden_müssen_eingehalten',
#   'monogame_beziehungen_erachten',
#   'weniger_wert_erachtet',
#   'tief_greifende_kulturelle',
#   'greifende_kulturelle_bildungspolitische',
#   'wohnungspolitische_ungleichheiten_aufrecht',
#   'paar_besondere_tücken',
#   'besondere_tücken_bereit',
#   'unterschiede_tatsächlich_überwunden',
#   'besondere_belastungen_ertragen',
#   'belastungen_ertragen_müssen',
#   'geschriebene_oft_schon',
#   'oft_schon_wenige',
#   'schon_wenige_stunden',
#   'wenige_stunden_später',
#   'stunden_später_makulatur',
#   'weiteren_entfremdung_innerhalb',
#   'sei_eben_wetterabhängig',
#   'stadt_arbeitet_derzeit',
#   'arbeitet_derzeit_daran',
#   'grundstück_zugreifen_bestätigt',
#   'zugreifen_bestätigt_michael',
#   'bestätigt_michael_guntersdorf',
#   'städtischen_bühnen_leitet',
#   'straße_gehen_sagte',
#   'studie_zeigt_laut',
#   'zeigt_laut_meinel',
#   'geplanten_zubau_habens',
#   'zubau_habens_stillschweigend',
#   'habens_stillschweigend_genommen',
#   'adäquate_physische_distanz',
#   'tanz_einzuhalten_gab',
#   'einzuhalten_gab_letztlich',
#   'januar_seit_monaten',
#   'egoistisch_machende_angst',
#   'menschen_daran_hindert',
#   'wenigsten_leute_fühlen',
#   'wurden_ja_geschlossen',
#   'zahl_ankommender_migranten',
#   'kaum_vier_jahre',
#   'vier_jahre_später',
#   'jahre_später_kommt',
#   'newtonmeter_maximalem_drehmoment',
#   'maximalem_drehmoment_daher',
#   'rückholung_deutscher_reisender',
#   'deutscher_reisender_drängt',
#   'unfähiger_politiker_schnallt',
#   'politischen_gegner_weidlich',
#   'gegner_weidlich_ausnutzen',
#   'bereits_gefassten_beschlüsse',
#   'verordnungen_umgesetzt_wurden',
#   'umgesetzt_wurden_weiterzuverfolgen',
#   'ehrlich_gesagt_läuft',
#   'erste_pokalschießen_geplant',
#   'einfache_lösung_gibt',
#   'sah_trainer_jesse',
#   'trainer_jesse_marsch',
#   'freund_roop_sei',
#   'roop_sei_dank',
#   'wunderbare_kleine_discokugel',
#   'schneiderin_webt_ja',
#   'anschliessend_verarbeitet_erklärt',
#   'verarbeitet_erklärt_ksenia',
#   'erklärt_ksenia_shiryaeva',
#   'bundesregierung_gerade_versprochen',
#   'verfassung_ganz_toll',
#   'zwei_wichtigsten_paragraphen',
#   'bayerischen_gezielt_weggelassen',
#   'gezielt_weggelassen_wurden',
#   'río_de_la',
#   'de_la_plata',
#   'lediglich_millionen_menschen',
#   'gutes_beispiel_abgibt',
#   'ok_gewohnt_gefühlsbetont',
#   'ganze_natürlich_schon',
#   'natürlich_schon_immer',
#   'einfach_wachsen_lassen',
#   'käfergeschädigtem_holz_schnell',
#   'holz_schnell_ausgebreitet',
#   'schnell_ausgebreitet_hätte',
#   'umsichtig_reagiert_hätte',
#   'eins_steht_fest',
#   'sektorspezifische_maßnahmen_stünden',
#   'hohen_regulativen_spannungsverhältnis',
#   'konto_lande_seien',
#   'lande_seien_oft',
#   'seien_oft_viele',
#   'oft_viele_rentner',
#   'auswahl_sagt_schmitt',
#   'dürfte_gute_chancen',
#   'eindringlich_davon_abgeraten',
#   'take_that_allerhand',
#   'übermäßige_freiheit_betonte',
#   'ließ_thiem_zurück',
#   'menschen_christliche_spiritualität',
#   'christliche_spiritualität_erleben',
#   'lukas_cranach_illustrierten',
#   'cranach_illustrierten_druckwerk',
#   'illustrierten_druckwerk_passional',
#   'druckwerk_passional_christi',
#   'ganz_sicher_überstehen',
#   'schwäche_sei_sagte',
#   'politik_seit_mindestens',
#   'nüchterne_sachliche_betrachtung',
#   'sachliche_betrachtung_nachdem',
#   'motto_wer_angst',
#   'gebe_allerlei_private',
#   'allerlei_private_initiativen',
#   'ultrabook_lincplus_p',
#   'gibt_digitale_lösungen',
#   'gibt_dutzende_berichte',
#   'dutzende_berichte_wonach',
#   'geschäfte_informieren_lässt',
#   'gibt_einzelne_gruppen',
#   'gibt_grüne_bonuspunkte',
#   'kommissionspräsidentin_durchaus_ernst',
#   'durchaus_ernst_meint',
#   'tun_außer_leider',
#   'geld_dafür_bezahlen',
#   'insgesamt_weniger_leute',
#   'weniger_leute_fernsehen',
#   'offizieller_seite_umgesetzt',
#   'spielern_gegenüber_verantwortlich',
#   'einzig_richtige_entscheidung',
#   'schon_egal_schönen',
#   'egal_schönen_abend',
#   'vollen_olympiastadion_stattfinden',
#   'afd_insgesamt_beobachtet',
#   'ermutigend_teilte_sozialministerin',
#   'teilte_sozialministerin_petra',
#   'sozialministerin_petra_spd',
#   'menschen_mehr_geld',
#   'mehr_geld_hätten',
#   'region_hinterlasse_lücken',
#   'china_stünden_schon',
#   'stünden_schon_parat',
#   'schon_parat_hallo',
#   'parat_hallo_europa',
#   'besonders_hohe_gebäude',
#   'tönt_wahnsinnig_fortschrittlich',
#   'verändert_statik_logik',
#   'stagnierenden_verkauf_ankurbeln',
#   'mega_witzig_freut',
# ...
#   'asylanten_lehnen_arbeit',
#   'lehnen_arbeit_ab',
#   'srfarena_dsi_handab',
#   'rotkäppchenkomplex_fütter_lieber',
#   'wolf_kriminelle_asylanten',
#   'eigene_volk_merkel',
#   'volk_merkel_cdu',
#   'merkel_cdu_friedlicher',
#   'cdu_friedlicher_karneval',
#   'zib_wolf_heute',
#   'kinder_vergewaltigen_braucht',
#   'extra_wurst_fuck',
#   'wurst_fuck_refugges',
#   'fuck_refugges_asylpaket',
#   'refugges_asylpaket_endlich',
#   'asylpaket_endlich_beschlossene',
#   'endlich_beschlossene_sache',
#   'flüchtlinge_flüchtlingspolitik_asylanten',
#   'flüchtlingspolitik_asylanten_islamisierung',
#   'unübersehbar_stattfindende_islamisierung',
#   'stattfindende_islamisierung_deutschlands',
#   'deutschland_katastrophal_schlecht',
#   'katastrophal_schlecht_asylchaos',
#   'schlecht_asylchaos_abmerkeln',
#   'asylchaos_abmerkeln_annewill',
#   'abmerkeln_annewill_islamisierung',
#   'gerade_unterwerfung_gelesen',
#   'fasnacht_frauen_begrabschen',
#   'frauen_begrabschen_gehen',
#   'fasnacht_satire_asylanten',
#   'pestcholera_kinderfickende_schächtende',
#   'kinderfickende_schächtende_rapefugees',
#   'wer_kinder-_frauen-',
#   'tierrechte_verteidigt_darf',
#   'ne_extra_asylanten',
#   'extra_asylanten_-polizei',
#   'asylantenheime_anzünden=verbrecherisch_-aber',
#   'anzünden=verbrecherisch_-aber_einziges',
#   '-aber_einziges_augenmerk',
#   'deutsche_straftäter_+nicht',
#   'krimigranten_rapefugees_=nogo',
#   'rapefugees_=nogo_merkel',
#   '=nogo_merkel_läßt',
#   'merkel_läßt_deutschen',
#   'läßt_deutschen_steuerzahler',
#   'deutschen_steuerzahler_bluten',
#   'syrien_algerien_marokko',
#   'algerien_marokko_tunesien',
#   'marokko_tunesien_etc',
#   'bietet_mio_asylanten',
#   'mio_asylanten_all',
#   'asylanten_all_incl',
#   'grandios_dumm_wann',
#   'dumm_wann_stoppen',
#   'wann_stoppen_faymann',
#   'stoppen_faymann_spö',
#   'mikl-leitner_övp_endlich',
#   'kölner_kulturtänzer_demnächst',
#   'kulturtänzer_demnächst_handlos',
#   'morgen_abläuft.im_asylanten-heim',
#   'abläuft.im_asylanten-heim_gäbe',
#   'schwimmbad_edathy_gefällt',
#   'zukommt_rapefugees_rapefugees',
#   'kommen_koelnhbf_nolegida',
#   'koelnhbf_nolegida_flüchten',
#   'merkel_europäische_lösung',
#   'europäische_lösung_asylanten',
#   'lösung_asylanten_asyl',
#   'asylanten_asyl_schade',
#   'refugeesnotwelcome_widerstand_rapefugees',
#   'widerstand_rapefugees_laufen',
#   'obergrenze_armlänge_alaaf',
#   'armlänge_alaaf_karneval',
#   'alaaf_karneval_annewill',
#   'karneval_annewill_warum',
#   'annewill_warum_gibt',
#   'asylanten_überall_selbe',
#   'überall_selbe_leistung',
#   'selbe_leistung_bekommen',
#   'stellt_lügenpresse_eigentl',
#   'lügenpresse_eigentl_schon',
#   'eigentl_schon_überlegungen',
#   'hahahaha_rapefugees_frauen',
#   'flüchtlingen_ficken_lassen',
#   'welt_mehr_geld',
#   'mehr_geld_bekommen',
#   'weniger_nazis_beurteilen',
#   'nazis_beurteilen_sagte',
#   'beurteilen_sagte_niemand',
#   'appeseament_islamisierung_taqqiya',
#   'islamisierung_taqqiya_viele',
#   'taqqiya_viele_menschen',
#   'islamisierung_berichtet_hartaberfair',
#   'schaffen_msc_fluechtlinge',
#   'msc_fluechtlinge_beim',
#   'fluechtlinge_beim_lasttweet',
#   'beim_lasttweet_aufgefallen',
#   'arabisch_dominierte_viertel',
#   'aufschrei_ausgruenden_belästigung',
#   'gemeindebund_erwartet_mio',
#   'erwartet_mio_asylanten',
#   'millionen_muslimischen_migranten',
#   'cdu/spd-nahen_wirtschaftsinstitute_seriösen',
#   'wirtschaftsinstitute_seriösen_prognosen',
#   'pro_jahr_kosten',
#   'bürgerliche_mitte_schon',
#   'mitte_schon_lange',
#   'schon_lange_verlassen',
#   'islamisierung_umerziehung_migrantenstadel',
#   'umerziehung_migrantenstadel_merkelmussweg',
#   'laufende_islamisierung_deutschlands',
#   'europas_macht_deutlich',
#   'durchfüttern_zelte_bekleidung',
#   'deutschland_hassen_immer',
#   'hassen_immer_mehr',
#   'immer_mehr_flüchtlinge',
#   'mehr_flüchtlinge_dorthin',
#   'flüchtlinge_dorthin_holen',
#   'asylanten_eu_sichere',
#   'eu_sichere_drittstaaten',
#   'lieber_horst_seehofer',
#   'horst_seehofer_gibt',
#   'tierasyl_aufgehoben_wären',
#   'sz_faz_zeit',
#   'faz_zeit_nzz',
#   'zeit_nzz_worauf',
#   'nzz_worauf_warten',
#   'stop_refugges_merkel',
#   'co_erwarten_flüchtlinge',
#   'islamisierung_nein_besser',
#   'rapefugees_wasserspritzpistole_gefüllt',
#   'schweineblut_^^_extraunterkünfte',
#   'schützen.wärs_net_besser',
#   'flieger_nachhause_asylanten',
#   'nachhause_asylanten_eu',
#   'asylanten_eu_gipfel',
#   'islamisierung_siehe_schweden',
#   'siehe_schweden_dt',
#   'flüchtlinge_illegale_überfremdung',
#   'illegale_überfremdung_islamisierung',
#   'überfremdung_islamisierung_antigermanismus',
#   'islamisierung_antigermanismus_widerstand',
#   'antigermanismus_widerstand_abmerkeln',
#   'widerstand_abmerkeln_remigration',
#   'land_lassen_terrorrazzien',
#   'islamisierung_lieber_horst',
#   'lieber_horst_seehofer',
#   'sz_faz_zeit',
#   'faz_zeit_nzz',
#   'asylanten_ewige_langzeitarbeitslose',
#   'zukunft_europas_entscheiden',
#   'infiltration_massiver_migrations',
#   'massiver_migrations_jihad',
#   'latent_linke_konditionierung',
#   'sorge_wegen_islamisierung',
#   'wegen_islamisierung_silvesternacht',
#   'bereits_vorbestraften_asylanten',
#   'nächste_mal_vertecke',
#   'dumme_nazi_sau',
#   'nazi_sau_tortalerkrieg',
#   'sau_tortalerkrieg_nordafrikanische',
#   'tortalerkrieg_nordafrikanische_single',
#   'nordafrikanische_single_männer',
#   'single_männer_not',
#   'männer_not_welcome',
#   'not_welcome_rapefugees',
#   'deutsche_frauen_stellen',
#   'wasistrechts_wer_zahlt',
#   'kompletten_unterhalt_beim',
#   'unterhalt_beim_studium',
#   'ard_läuft_schon',
#   'mehr_polizei_weniger',
#   'polizei_weniger_feiernde',
#   'abmerkeln_rapefugees_merkelmussweg',
#   'rapefugees_merkelmussweg_refugees',
#   'merkelmussweg_refugees_nohate',
#   'regierung_alimentiert_menschen',
#   'welt_fördert_islamisierung',
#   'fördert_islamisierung_unsrer',
#   'islamisierung_unsrer_heimatmit',
#   'unsrer_heimatmit_unsren',
#   'heimatmit_unsren_steuern',
#   'afd_make_rape',
#   'make_rape_legal',
#   'rape_legal_findet',
#   'legal_findet_merkel',
#   'abmerkeln_merkelmussweg_merkeldiktatur',
#   'merkelmussweg_merkeldiktatur_hausverbot',
#   'gibt_orban_merkel',
#   'orban_merkel_cdu',
#   'merkel_cdu_rapefugees',
#   'cdu_rapefugees_cdu',
#   'rapefugees_cdu_integration',
#   'cdu_integration_findet',
#   'koelnhbf_fluechtlinge_rapefugees',
#   'neue_begriff_asylsuchende',
#   'mehr_mitleid_hervorrufen',
#   'asylanten_asylbewerber_migranten',
#   'mehr_asylanten_zäune',
#   'nigeria_indien_thailand',
#   'indien_thailand_israel',
#   'thailand_israel_frankr',
#   'israel_frankr_belgien',
#   'frankr_belgien_ukzu',
#   'belgien_ukzu_stoppen',
#   'ukzu_stoppen_frankreich',
#   'stoppen_frankreich_macht',
#   'frankreich_macht_ja',
#   'macht_ja_schon',
#   'ja_schon_grenzkontrollen',
#   'grenzenzu_festungeuropa_refugees',
#   'festungeuropa_refugees_refugeesnotwelcome',
#   'falsche_fünfziger_gabriel',
#   'merkel_asylanten_maybritillner',
#   'siggi_erst_recht',
#   'erst_recht_durchregieren',
#   'groko_tagesschau_nennt',
#   'tagesschau_nennt_levante-dschihadisten',
#   'syrien_kämpfen_einigermaßen',
#   'kämpfen_einigermaßen_gemäßigte',
#   'einigermaßen_gemäßigte_rebellen',
#   'gemäßigte_rebellen_illner',
#   'rebellen_illner_cdu',
#   'illner_cdu_lebt',
#   'falschen_land_scheint',
#   'asylanten_gibts_dicke',
#   'diebstahl_scharia_erschießen',
#   'illegalem_grenzübertritt_afd',
#   'islamicstate_islamisierung_fluechtlingskrise',
#   'islamisierung_fluechtlingskrise_zdfzoom',
#   'fluechtlingskrise_zdfzoom_flüchtlinge',
#   'zdfzoom_flüchtlinge_asylanten',
#   'frau_knobel-ulrich_u',
#   'rapefugees_abmerkeln_unterhaltsam',
#   'asylanten-heim_entsteht_rettet',
#   'multikuliti_wahn_rapefugees',
#   'wahn_rapefugees_rapefugees',
#   'hartzundherzlich_syrische_asylanten',
#   'klopapier_gelegentlich_fehlt',
#   'kinderbraut_frauenunterdrückung_intoleranz',
#   'frauenunterdrückung_intoleranz_scharia',
#   'intoleranz_scharia_sonderrecht',
#   'radikale_kriminelle_islamisten',
#   'kriminelle_islamisten_installieren',
#   '-diebstahl_hand_ab',
#   'refugeeswelcome_refugeesnotwelcome_nopegida',
#   'refugeesnotwelcome_nopegida_isis',
#   'nopegida_isis_unterstützer',
#   'isis_unterstützer_scharia',
#   'unterstützer_scharia_befürworter',
#   'scharia_befürworter_islam',
#   'befürworter_islam_gehört',
#   'de_sympathisanten_gg',
#   'sympathisanten_gg_bruch',
#   'gg_bruch_gutheißer',
#   'bruch_gutheißer_asylindustrie',
#   'gutheißer_asylindustrie_profitierer',
#   'asylindustrie_profitierer_asylanten',
#   'profitierer_asylanten_sollen',
#   'asylanten_sollen_arbeiten',
#   'sollen_arbeiten_können.die',
#   'arbeiten_können.die_wirtschaft',
#   'können.die_wirtschaft_gibt',
#   'wirtschaft_gibt_knowhow',
#   'übrigen_müsste_klar',
#   'rapefugees_aka_is',
#   'aka_is_monkeys',
#   'macht_merkel_cdu',
#   'hessen_politische_fluechtlinge',
#   'politische_fluechtlinge_hartaberfair',
#   'fluechtlinge_hartaberfair_warum',
#   'asylanten_müssen_zurück',
#   'schüler_sollen_refugees',
#   'sollen_refugees_betten',
#   'refugeesnotwelcome_gutmenschgohome_alleinherrscher',
#   'gutmenschgohome_alleinherrscher_putin',
#   'sanktionen_belegt-diktator_erdogan',
#   'klasse_merkel_asylanten',
#   'merkel_asylanten_flüchtlinge',
#   'perverse_kleine_kinderficker',
#   'gewalttätige_asylanten_refugees',
#   'asylanten_refugees_cdu',
#   'refugees_cdu_kapiert',
#   'europa_ausser_cdu',
#   'blanke_politische_schwachsinn',
#   'politische_schwachsinn_sturmwarnung',
#   'schwachsinn_sturmwarnung_rosenmontag',
#   'sturmwarnung_rosenmontag_rapefugees',
#   'rosenmontag_rapefugees_kriminalität',
#   'rapefugees_kriminalität_afd',
#   'kriminalität_afd_kapitulation',
#   'vollen_gange_cdu',
#   'gange_cdu_schweden',
#   'cdu_schweden_findet',
#   'schweden_findet_missbrauch',
#   'findet_missbrauch_v.kindern',
#   'missbrauch_v.kindern_ok',
#   'v.kindern_ok_kinderehen',
#   'ok_kinderehen_asylanten',
#   'tolerant_assange_mensch',
#   'assange_mensch_gabriel',
#   'domian_sollen_dt',
#   'rapefugees_is_danken',
#   'is_danken_glawischnig',
#   'danken_glawischnig_weltfrauentag',
#   'burka_scharia_islam',
#   'scharia_islam_isis',
#   'islam_isis_diegrünen',
#   'isis_diegrünen_menschenrechte',
#   'diegrünen_menschenrechte_frauenrechte',
#   'menschenrechte_frauenrechte_vdb',
#   'frauenrechte_vdb_make',
#   'vdb_make_rape',
#   'make_rape_legal',
#   'wohl_schon_athmosphärisch',
#   'schon_athmosphärisch_vorbereiten',
#   'rapefugees.in_gesamter_eu',
#   'gesamter_eu_tgl',
#   'klöckner_wählen_heißt',
#   'wählen_heißt_mio',
#   'heißt_mio_neue',
#   'mio_neue_asylanten',
#   'neue_asylanten_türkei',
#   'asylanten_türkei_mitglied',
#   'euro_neue_steuern',
#   'neue_steuern_zensur',
#   'steuern_zensur_sharia.ich',
#   'afd_wählen_cdu',
#   'deutschen_schon_aufgegeben',
#   'asylanten_möglichst_schnell',
#   'kriminelle_islamistische_migranten',
#   'gewünschten_scharia_bestrafen',
#   'scharia_bestrafen_-wäre',
#   'bestrafen_-wäre_schnell',
#   '-wäre_schnell_ruhe',
#   'verwandten_fahren.ich_fordere',
#   'abend=_eu_gipfel',
#   'eu_gipfel_hast',
#   'heute_schon_gnachtmahlt',
#   'schon_gnachtmahlt_angela',
#   'europa_flüchtlinge_fleuchtlingskrise',
#   'flüchtlinge_fleuchtlingskrise_asylanten',
#   'fleuchtlingskrise_asylanten_geplatzte',
#   'asylanten_geplatzte_träume',
#   'asylanten_fünf_männer',
#   'irgendwie_übel_muß',
#   'übel_muß_leider',
#   'muß_leider_abschalten',
#   'lanz_merkel_scharia',
#   'merkel_scharia_kölnhbf',
#   'scharia_kölnhbf_wieso',
#   'kölnhbf_wieso_nehmen',
#   'bundesasylzentrum_wallis_wähler',
#   'wehren-_wählt_afd',
#   'ausnotwehr_rapefugees_madmerkel',
#   'rapefugees_madmerkel_annewill',
#   'madmerkel_annewill_lanz',
#   'annewill_lanz_hoaxmap',
#   'manchmal_niemand_allianz',
#   'abschaffung_deutschland_s',
#   'grüne_linke_spd',
#   'linke_spd_cdu',
#   'beachtlich_wieviel_gutmenschen',
#   'hosen_gestrichen_vollgeschissen',
#   'afd_eu_stellt',
#   'eu_stellt_mio',
#   'refugeesnotwelcome_fluechtlinge_pegida',
#   'fluechtlinge_pegida_afd',
#   'pegida_afd_cdu',
#   'afd_cdu_merkelmussweg',
#   'cdu_merkelmussweg_refugeeswelcome',
#   'merkelmussweg_refugeeswelcome_brüllern',
#   'flüchtlinge_wohl_egal',
#   'afd_islamisierung_übrigens',
#   'zeit_flüchtlinge_nein',
#   'merkel_vertrauensfrage_kiel',
#   'einkaufszentrum_lieber_spd',
#   'lieber_spd_wähler',
#   'sonstiger_traumtänzer_rapefugees',
#   'traumtänzer_rapefugees_ja',
#   'amerika_australien_ostasien',
#   'ns-regime_abmerkeln_islamisierung',
#   'trümmerfrau_asylanten_bürgerwehr',
#   'asylanten_bürgerwehr_heute-journal',
#   'bürgerwehr_heute-journal_un',
#   'heute-journal_un_ehrt',
#   'un_ehrt_merkel',
#   'beitrag_später_suche',
#   'bekommen_asylanten_aufgedrückt',
#   'bekommen_ttip_vorgesetzt',
#   'ttip_vorgesetzt_müssen',
#   'vorgesetzt_müssen_übelste',
#   'müssen_übelste_moderne',
#   'übelste_moderne_propaganda',
#   'refugeesnotwelcome_schleichende_islamisierung',
#   'frauen_ungläubige_verbannen',
#   'ungläubige_verbannen_schweinefleischpflicht',
#   'verbannen_schweinefleischpflicht_sinnvoll',
#   'schweinefleischpflicht_sinnvoll_hört',
#   'mehr_sexuelle_übergriffe',
#   'rapefugees_refugeesnotwelcome_grenzendicht',
#   'refugeesnotwelcome_grenzendicht_abmerkeln',
#   'grenzendicht_abmerkeln_frau',
#   'abmerkeln_frau_merkelmussweg',
#   'frau_merkelmussweg_deutschland',
#   'eu_immer_mehr',
#   'immer_mehr_isoliert',
#   'mehr_isoliert_dank',
#   'nächste_gipfel_erfolglos',
#   'gipfel_erfolglos_österreich',
#   'erfolglos_österreich_macht',
#   'flüchtlingsobergrenze_refugees_refugeesnotwelcome',
#   'refugees_refugeesnotwelcome_refugeesgohome',
#   'refugeesnotwelcome_refugeesgohome_merkelmussweg',
#   'refugeesgohome_merkelmussweg_cdu',
#   'merkelmussweg_cdu_bahnstrecke',
#   'cdu_bahnstrecke_s',
#   'erding-_münchen_wurde',
#   'münchen_wurde_vorhin',
#   'wurde_vorhin_gesperrt',
#   'de_läuft_definitiv',
#   'illner_edathy_islamisierung',
#   'edathy_islamisierung_antisemitismus',
#   'gesamten_arabischen_raum',
#   'arabischen_raum_verbreitet',
#   'raum_verbreitet_praktisch',
#   'verbreitet_praktisch_salonfähig.warum',
#   'islamisierung_asyl_etwa',
#   'asyl_etwa_prozent',
#   'christen_verschiedener_konfessionen',
#   'islamisierung_regierung_merkel',
#   'regierung_merkel_betreibt',
#   'verlogene_migrationspolitik_vs',
#   'migrationspolitik_vs_eigene',
#   'vs_eigene_bevölkerung',
#   'jakarta_islam_islam',
#   'islam_islam_islam',
#   'islamisierung_mrd_zahlen',
#   'arschloch_ochsner_redet',
#   'fluchtlinge_asylanten_gibt',
#   'fachkräfte_ärzte_ingenieure',
#   'brauchen_dringend_wahlbeobachter',
#   'ltwrlp_ltwrp_ltwbw',
#   'ltwrp_ltwbw_merkel',
#   'ltwbw_merkel_afd',
#   'merkel_afd_cdu',
#   'afd_cdu_csu',
#   'cdu_csu_spd',
#   'csu_spd_malu',
#   'spd_malu_laschet',
#   'malu_laschet_rapefugees',
#   'laschet_rapefugees_krimigranten',
#   'rapefugees_krimigranten_ja',
#   'schutz_suchende_flüchtlinge',
#   'radikale_islamisten-krimigranten-rapefugees_entpuppen',
#   'islamisten-krimigranten-rapefugees_entpuppen_-in',
#   'entpuppen_-in_gefangenenlager',
#   '-in_gefangenenlager_stecken',
#   'm²_großes_mausoleum',
#   'tillich_gabriel_hetzt',
#   'islamisierung_opfern_sollen',
#   'schweinefleisch_puh_bloss',
#   'puh_bloss_glück',
#   'bloss_glück_gehabt',
#   'mal_gut_gegangen',
#   'clausnitz_sachsen_flüchtlingskrise',
#   'sachsen_flüchtlingskrise_asylanten',
#   'flüchtlingskrise_asylanten_muttikulti',
#   'mutti_merkel_verschuldete',
#   'merkel_verschuldete_eskalation',
#   'refugeesnotwelcome_boykottiert_bild',
#   'frei_rumlaufende_rapefugees',
#   'unwesen_treiben.abmerkeln_täglich',
#   'treiben.abmerkeln_täglich_gibt',
#   'schande_fuck_you',
#   'fuck_you_refugges',
#   'you_refugges_mindestlohn',
#   'wegen_asylanten_teilweise',
#   'asylanten_teilweise_ausgesetzt',
#   'opferschutz_frauen_u',
#   'christen_bekommen_extraunterkünfte',
#   'schützen.u_wer_schützt',
#   'sterben_sehen_möchte',
#   'asylanten_afd_noafd',
#   'afd_noafd_nonazis',
#   'noafd_nonazis_sachsenanhalt',
#   'nonazis_sachsenanhalt_menschistmensch',
#   'mazedonien_versuchen_tausende',
#   'versuchen_tausende_asylanten',
#   'deutschland_durchzubrechen_fast',
#   'beschütze_deutsche_frauen',
#   'deutsche_frauen_teilzeit',
#   'hungerstreik_rapefugees_fr',
#   'invasoren_lagers_calais',
#   'lagers_calais_geräumt',
#   'calais_geräumt_gr',
#   'invasorenlager_idomeni_räumen',
#   'asylanten_verteilen_könnten',
#   'lanz_sicher_mutig',
#   'opfersindopfer_statt_hoax',
#   'bestätigten_sexuellen_übergriffen',
#   'rapefugees.das_wäre_wirkliche',
#   'wäre_wirkliche_transparenz',
#   'tun_kriminalität_v.',
#   'kriminalität_v._asylanten',
#   '/g_meth_durchzudrehen',
#   ...]}

# %%
vocab = nltk.FreqDist(sum(trigram.values(),[]))

# %%
vocab = sorted(list(vocab.items()),key= lambda x: x[1], reverse=True)

# %%
vocab = [x[0] for x in vocab]

# %%
vocab[:100]
# Out:
# ['unten_stehenden_link',
#  'stehenden_link_verwenden',
#  'fc_bayern_münchen',
#  'bundeskanzlerin_angela_merkel',
#  'rund_millionen_euro',
#  'rund_milliarden_euro',
#  'tour_de_france',
#  'gramm_pro_kilometer',
#  'bundestrainer_joachim_löw',
#  'hypo_real_estate',
#  'angela_merkel_cdu',
#  'general_motors_gm',
#  'beim_fc_bayern',
#  'louis_van_gaal',
#  'wall_street_journal',
#  'schon_seit_jahren',
#  'financial_times_deutschland',
#  'new_york_times',
#  'preisen_ab_euro',
#  'euro_pro_jahr',
#  'zwei_milliarden_euro',
#  'hertha_bsc_berlin',
#  'beim_großen_preis',
#  'fünf_milliarden_euro',
#  'europäische_zentralbank_ezb',
#  'bank_of_america',
#  'auto_club_europa',
#  'seit_vielen_jahren',
#  'carl_zeiss_jena',
#  'ums_leben_gekommen',
#  'kanzlerin_angela_merkel',
#  'höchsten_stand_seit',
#  'new_york_dpa',
#  'bundesfinanzminister_peer_steinbrück',
#  'peer_steinbrück_spd',
#  'zehn_millionen_euro',
#  'ersten_neun_monaten',
#  'sv_wehen_wiesbaden',
#  'internationalen_automobilausstellung_iaa',
#  'ersten_mal_seit',
#  'trainer_louis_van',
#  'club_europa_ace',
#  'drei_milliarden_euro',
#  'vier_milliarden_euro',
#  'knapp_millionen_euro',
#  'spvgg_greuther_fürth',
#  'mark_van_bommel',
#  'etwa_millionen_euro',
#  'cent_pro_liter',
#  'rund_milliarden_dollar',
#  'beim_hamburger_sv',
#  'zwei_minuten_später',
#  'liveticker_spiegel_online',
#  'royal_bank_of',
#  'real_estate_hre',
#  'immer_mehr_menschen',
#  'wolfgang_tiefensee_spd',
#  'horst_seehofer_csu',
#  'bank_of_scotland',
#  'gramm_je_kilometer',
#  'bundesverkehrsminister_wolfgang_tiefensee',
#  'kilometern_pro_stunde',
#  'ersten_drei_monaten',
#  'finanzminister_peer_steinbrück',
#  'rund_zehn_prozent',
#  'seit_geraumer_zeit',
#  'zehn_milliarden_euro',
#  'seit_zehn_jahren',
#  'seit_fünf_jahren',
#  'gott_sei_dank',
#  'internationalen_währungsfonds_iwf',
#  'prozent_mehr_geld',
#  'uhr_liveticker_spiegel',
#  'kilometer_pro_stunde',
#  'tom_grünweg_fotostrecke',
#  'grünweg_fotostrecke_bilder',
#  'seit_drei_jahren',
#  'zwei_jahre_später',
#  'zwei_millionen_euro',
#  'los_angeles_lakers',
#  'liter_je_kilometer',
#  'seit_zwei_jahren',
#  'mindestens_euro_kosten',
#  'passauer_neuen_presse',
#  'tiefsten_stand_seit',
#  'gazzetta_dello_sport',
#  'drei_millionen_euro',
#  'euro_je_aktie',
#  'bahnchef_hartmut_mehdorn',
#  'bla_bla_bla',
#  'bildinfo_ausblenden_bild',
#  'verkehrsclub_deutschland_vcd',
#  'fünf_millionen_euro',
#  'seit_vier_jahren',
#  'wolfgang_schäuble_cdu',
#  'ersten_sechs_monaten',
#  'frankfurter_allgemeinen_zeitung',
#  'dow_jones_industrial',
#  'salt_lake_city',
#  'rekordmeister_bayern_münchen']

# %%
term_freq = {genre: nltk.FreqDist(text) for genre, text in trigram.items()}

# %%
term_freq
# Out:
# {'keyword/automobil_50k.txt': FreqDist({'gramm_pro_kilometer': 76, 'preisen_ab_euro': 47, 'auto_club_europa': 33, 'internationalen_automobilausstellung_iaa': 26, 'club_europa_ace': 24, 'gramm_je_kilometer': 21, 'tom_grünweg_fotostrecke': 19, 'grünweg_fotostrecke_bilder': 19, 'liter_je_kilometer': 17, 'mindestens_euro_kosten': 17, ...}),
#  'keyword/news_text100k.txt': FreqDist({'bundeskanzlerin_angela_merkel': 32, 'rund_millionen_euro': 23, 'ums_leben_gekommen': 22, 'fc_bayern_münchen': 20, 'new_york_times': 19, 'bundesgesundheitsminister_jens_spahn': 14, 'ministerpräsident_markus_söder': 14, 'angela_merkel_cdu': 13, 'bundeskanzler_sebastian_kurz': 12, 'seit_vielen_jahren': 12, ...}),
#  'keyword/sport_50k.txt': FreqDist({'unten_stehenden_link': 340, 'stehenden_link_verwenden': 340, 'fc_bayern_münchen': 107, 'tour_de_france': 75, 'bundestrainer_joachim_löw': 71, 'louis_van_gaal': 60, 'beim_fc_bayern': 52, 'hertha_bsc_berlin': 42, 'beim_großen_preis': 36, 'trainer_louis_van': 26, ...}),
#  'keyword/wirtschaft_50k.txt': FreqDist({'unten_stehenden_link': 270, 'stehenden_link_verwenden': 270, 'rund_milliarden_euro': 70, 'hypo_real_estate': 70, 'bundeskanzlerin_angela_merkel': 64, 'rund_millionen_euro': 55, 'general_motors_gm': 50, 'financial_times_deutschland': 48, 'wall_street_journal': 48, 'angela_merkel_cdu': 40, ...}),
#  'keywords/hatespeech': FreqDist({'schon_seit_jahren': 17, 'bla_bla_bla': 17, 'spd_schmarotzer_pädophile': 14, 'marine_le_pen': 12, 'frau_le_pen': 12, 'herr_sigmar_gabriel': 12, 'sigmar_gabriel_bitte': 12, 'gott_sei_dank': 11, 'beim_herumsurfen_gesehen': 11, 'scheinheilgste_partei_deutschlands': 10, ...})}

# %%
def create_dtm(dictionary,vocab):
    matrix=[]

    for value in dictionary.values():
        array=[]
        for word in vocab: 
            array.append(value.get(word, 0))
        matrix.append(array)    
    return np.array(matrix)

# %%
def tfidf(matrix, terms, voc,n):
    
    
    y=matrix.sum(axis=1)
    
    
    y=y[:,np.newaxis]
    tm= (np.divide(matrix,y)) * np.log(matrix.shape[0]/((matrix>0).sum(0)))
   
    idf_list=[]
   
    for i in range(tm.shape[0]):
        
        idf_list.append(tm[i].argsort()[::-1])
        
    docs={}
    doc_list=[]
    
 
    for index, key in enumerate(terms.keys()):
        for i in range(n):
            doc_list.append(voc[idf_list[index][i]])
        
        docs[key]= doc_list
        doc_list=[]
    return docs

# %%
dtm=create_dtm(term_freq,vocab)

# %%
results = tfidf(dtm, term_freq, vocab,1000)

# %%
result_list= results["keywords/hatespeech"]

# %%
for index, value in enumerate(result_list):
    result_list[index]= " ".join(value.split("_"))

# %%
result_list
# Out:
# ['bla bla bla',
#  'spd schmarotzer pädophile',
#  'marine le pen',
#  'frau le pen',
#  'herr sigmar gabriel',
#  'sigmar gabriel bitte',
#  'beim herumsurfen gesehen',
#  'scheinheilgste partei deutschlands',
#  'danke frau merkel',
#  'nötigern erpressern gewalttätern',
#  'fettigen haaren wdr',
#  'beide völker regiert',
#  'schwager schwagerwars gebtdenschwagerfrei',
#  'erfolg löschung od',
#  'hoch kriminellen brandstiftern',
#  'stasifrau kahane funktioniert',
#  'wikimedia cc by-sa',
#  'jaxxon sundance justnobody',
#  'ne neue seite',
#  'rot grün versiffte',
#  'ursula haverbeck –',
#  'werdet einfach aktiv',
#  'la la la',
#  'ep europawahl meuthen',
#  'ibizagate oesterreich neuwahlen',
#  'etwa mitgeführten beförderungsmittel',
#  'sozial gleichgestellte akzeptieren',
#  'dreck verrecken lassen',
#  'lieber hundert stimmen',
#  'aktuelle politik anzugehen',
#  'kommunalpolitiker werdet einfach',
#  'junge kräftige männer',
#  'bitten endlich aufzustehen',
#  'wurde heute aufgenommen',
#  'video wurde heute',
#  "gibt 's ja",
#  'millionen menschen aufnehmen',
#  'herrn jesus christus',
#  'absatz bezeichneten personen',
#  'make rape legal',
#  'land bitten endlich',
#  'hürde islamisten herde',
#  'euwahl ibizagate oesterreich',
#  'meuthen euwahl ibizagate',
#  'europawahl meuthen euwahl',
#  'strache ep europawahl',
#  'islamistischen extremismus arabischen',
#  'mal darüber nachgedacht',
#  'arabischen antisemitismus nationale',
#  'extremismus arabischen antisemitismus',
#  'europa afd deutschland',
#  'a. merkel co.',
#  'wahrheitsunterdrückern a. merkel',
#  'marktwirtschaft statt sozialismus',
#  'cdu spd fdp',
#  'afd stärkste kraft',
#  'tim k. –',
#  'horst mahler –',
#  'us-präsident donald trump',
#  'instagram snapchat drogenszene',
#  'snapchat drogenszene hennigsdorf/oranienburg',
#  'anmelden telefonanbieter dürfen',
#  'telefonanbieter dürfen überhaupt',
#  'daten mehr speichern',
#  'bescheid sagen beim',
#  'nowehrmuc jaxxon sundance',
#  'erfolg löschung/sperrung klatschen',
#  'wohlstandskokon zurückzieht handelt',
#  'verlogenen wahrheitsunterdrückern a.',
#  'letzten zeit spötter',
#  'vorhandenen wohlstandskokon zurückzieht',
#  'integrationssoftware neu programmieren',
#  'refugees refugeesnotwelcome refugeesgohome',
#  'lieber horst seehofer',
#  'sz faz zeit',
#  'faz zeit nzz',
#  'jahre altes mädchen',
#  'pegida aufdiestraße montagistpegidatag',
#  'affen seit untergebildet',
#  'schmoddrigen schwarzen hose',
#  'eigenen gottlosen begierden',
#  'gottlosen begierden leben',
#  'spaltungen hervorrufen niedrig',
#  'hervorrufen niedrig gesinnte',
#  'schöne heile welt',
#  'hartz iv empfänger',
#  'mal gespannt wann',
#  'kim jong merkel',
#  'wäre schon lange',
#  'macht ne neue',
#  'ausübung öffentlicher gewalt',
#  'madame le pen',
#  'jahres inklusive fast',
#  'inklusive fast millionen',
#  'nächsten jahre beibehalten',
#  'heutigen verhältnisse bestritten',
#  'wasserkopf- arbeits -plätzen',
#  'scheinheilgsten partei deutschlands',
#  'europawahl euelections ep',
#  'gute nacht deutschland',
#  'friday for future',
#  'bus voller krebs-patienten',
#  'demonstranten fordern ausrufung',
#  'alexander gauland vorsitzender',
#  'lange gewänder trägt',
#  'schon mal darüber',
#  'grün wählt wählt',
#  'wer grün wählt',
#  'mdl köbberling spd',
#  'guten morgen 🇩🇪',
#  'weilesreicht dankespd afd',
#  'deutschland lebende migranten',
#  'zeit nzz worauf',
#  'nzz worauf warten',
#  'mio neue asylanten',
#  'mehr sexuelle übergriffe',
#  'greifen bus voller',
#  'ard amp zdf',
#  'cdu csu spd',
#  'afd deutschland asyl',
#  'netz protonmail führt',
#  'protonmail führt echtzeit-überwachungen',
#  "zufälle gibt 's",
#  'hallo hallo. «',
#  'beim eurovision song',
#  'gt verbot problem',
#  'mascha wartet schon',
#  'schönes wochenende 😀😀👍👍👍',
#  'huch kim jong',
#  'ach ja fast',
#  'hallo frau merkel',
#  'russlanddeutschen konservativen –',
#  'linke gefahr –',
#  'refugeesnotwelcome refugeesgohome merkelmussweg',
#  'amadeu antonio stiftung',
#  'tja liebe bessermenschen',
#  'saarländische ministerpräsidentin annegret',
#  'rechtsextremismus unmöglich macht',
#  'polizei brisante straftaten',
#  'armen hilfsbedürftigen menschen',
#  'ankömmlinge seien männer',
#  'bint abī bakr',
#  'mehrfach geld beziehen',
#  'ministerpräsidentin annegret kramp-karrenbauer',
#  'dank willkürlicher facebook-zensur',
#  'gehört sofort abgeschoben',
#  'mohammed neues gebracht',
#  'raus raus raus',
#  'nationalen gebot sei',
#  'rechte ecke gestellt',
#  'krieg zurück lassen',
#  'jeweils ganz fest',
#  'pegida-vereine jeweils ganz',
#  'offiziellen pegida-vereine jeweils',
#  'deutschen ernsthaft annimmt',
#  'gebaute alleinstehende männer',
#  'kräftig gebaute alleinstehende',
#  'junge kräftig gebaute',
#  'flüchtlinge junge kräftig',
#  'nahost abholen lassen',
#  'ausländischen zeitungen erklären',
#  'mal daran gedacht',
#  'schon mal daran',
#  'kranken mehr geld',
#  'schwer sexuell missbraucht',
#  'guten textbeitrag verbreiten',
#  'facebook-zensur weder bilder',
#  'willkürlicher facebook-zensur weder',
#  'zweieinhalb jahre haft',
#  'deutsches maedchen freiheit',
#  'west europäischer frau',
#  'besten blockieren 😉',
#  'dafür zahlen müssen',
#  'art amp weise',
#  'gesamte berliner muschpoke',
#  'schon immer terroristen',
#  'palästinenser schon immer',
#  'hetzlichen dank abklatschen',
#  'twittersupport melden anschließend',
#  'ursula haverbeck europawahl',
#  'sagen beim herumsurfen',
#  'mitarbeiter betroffen futschi',
#  'davon betroffen futschi',
#  'grüne linke afd',
#  'täter wäre wäre',
#  'berliner polizei amp',
#  'gehirn prothesen träger',
#  'merkel vasallen hetzen',
#  'schon mal geschrieben',
#  'gt zerstört europa',
#  'gutes neues jahr',
#  'spd verseuchte auswärtige',
#  'verseuchte auswärtige amt',
#  'moslems ungläubige töten',
#  'scheinheiligsten partei deutschlands',
#  'alten schmoddrigen hose',
#  'fette yvonne willicks',
#  'spd verseuchten auswärtigen',
#  'mal a. h.u',
#  'alten schmoddrigen schwarzen',
#  'abartigen auswärtigen amtes',
#  'immer dran denken',
#  'spd schandmäuler pädophile',
#  'fresse rein “',
#  'terrororganisation hisbollah ab',
#  'bundestag lehnt verbot',
#  'minimalistisch seltsam nordisch',
#  'henryk m. broder',
#  'anlaufen italienischer gewässer',
#  'nachrichten folge grillfest',
#  'brandenburg afd stärkste',
#  'demographischer schock laut',
#  'zeit online “',
#  'daniel cohn-bendit fordert',
#  'globalen einnahmequellen steuer-erotik',
#  'exporte seltener erden',
#  'seltener erden deutlich',
#  'erden deutlich zurück',
#  'tages folge editorial',
#  'kay nielsen minimalistisch',
#  'nielsen minimalistisch seltsam',
#  'menschen teil vier',
#  'deutschland bundestag lehnt',
#  'spd fdp grüne',
#  'a…loch wiltewka alias',
#  'ekelwilfred papa wilberg',
#  'endlich sucht endlich',
#  'wilberg o. wilke',
#  'capitol alias ekelwilfred',
#  'rückt immer mehr',
#  'herzchen amp berliner',
#  'amp berliner –',
#  'ekelwilfred alias wiltewka',
#  'alias wiltewka wilberg',
#  'endlich amp holt',
#  'rebeccas verschwinden ausgemacht.😢',
#  ' junge mdl herr junge',
#  'frau angela merkel',
#  'alias ekelwilfred wiltewka',
#  'europäischer frau genauso',
#  'deutschland moscheen heute',
#  'arbeitslosigeit kriminalität geringe',
#  'kriminalität geringe bildung',
#  'geringe bildung etc',
#  'neunziger jahre einwanderungsfreundlichste',
#  'jahre einwanderungsfreundlichste land',
#  'einwanderungsfreundlichste land europas',
#  'muslimischen ländern offen',
#  'identisch hohe arbeitslosigeit',
#  'ländern offen steht',
#  'multi kulti funktioniert',
#  'erkennen verträumte multi',
#  'verträumte multi kulti',
#  'multi kulti augen',
#  'zurückzieht handelt verantwortlos',
#  'hohe arbeitslosigeit kriminalität',
#  'europaweit identisch hohe',
#  'chaos streit krieg',
#  'abendblatt berichtet dürfen',
#  'wissen willst wer',
#  'kritisieren darfst voltaire',
#  'lügenpresse erste sparmaßnahmen',
#  'erste sparmaßnahmen ha',
#  'sparmaßnahmen ha ha',
#  'arbeit frei gestellt',
#  'chefredaktion genehmigten ausnahmefällen',
#  'offenen augen sehen',
#  'berliner tageszeitung schreiben',
#  'alfons frese vorsitzender',
#  'tagesspiegel -betriebsrats hält',
#  'video min völkerwanderung',
#  'überfremdung spürbar wahrnehmen',
#  'politiker europäischer länder',
#  'handelt verantwortlos gegenüber',
#  'bringen gute nacht',
#  'schafft diktatorin a.',
#  'bundesweit starten migranten',
#  'minderjähriger mädchen fördert',
#  'monatelangen schlaf erwacht',
#  'frau dr. merkel',
#  'fürs eigene volk',
#  'per flugzeug regierung',
#  'afd-fraktion ltmv mv',
#  'starten migranten juden',
#  'diktatorin a. merkel',
#  "salvini 's lega",
#  'zwei nordafrikanern vergewaltigt',
#  'notre dame brennt',
#  'großer zahl auftreten',
#  'viele verführen. “',
#  'guten alten zeit',
#  'vergewaltigung minderjähriger mädchen',
#  'europa guanyin einwanderung',
#  'schon lange bekannt',
#  'ja schon lange',
#  'party richtig los',
#  'importieren islamistischen extremismus',
#  'ne gute nachricht',
#  'mal ne gute',
#  'christlich geprägtes land',
#  'vielleicht einfach mal',
#  'beiden völker regiert',
#  'sozialbürgermeisterin kristin kaufmann',
#  'dresdens sozialbürgermeisterin kristin',
#  'vier millionen asylanten',
#  'genug eigene probleme',
#  'ganze land besteht',
#  'todestrafe fur babies',
#  'ja immer schlimmer',
#  'a. merkel zerstört',
#  'waffengewalt legitim wäre',
#  'frau bekommt angst',
#  'ständig anzeigen erstatten',
#  'gestiegen abends liest',
#  'frau folgende schlagzeile',
#  'bewiesenen pädophilen vergangenheit',
#  'pädophilen vergangenheit suchen',
#  'made my day',
#  'staatlich geförderte bespassung',
#  'hut ab herr',
#  'hut ab genau',
#  'wünsche gutes gelingen',
#  'afd geht gar',
#  'politisch vollends verirrt',
#  'grünen-chefin simone peter',
#  'schaum vorm mund',
#  "geht 's ja",
#  'nix kommt dabei',
#  'kommt dabei raus',
#  'ja ständig anzeigen',
#  'gestalten lüstern angeschaut',
#  'müssen flaschen sammeln',
#  'aussehende gestalten lüstern',
#  "geht 's nimmer",
#  'millionen hartz iv',
#  'eh schon lange',
#  'viele viele jahre',
#  'deutsche michel zahlt',
#  'gewährt.- wohl kaum',
#  "wer 's glaubt",
#  'cdu spd grüne',
#  'müssen erst mal',
#  'nächste wahl kommt',
#  'teilen teilen teilen',
#  'garnicht soviel essen',
#  'wann wandern fälle',
#  'kleines beispiel gefällig',
#  'mob mehrere dubios',
#  'mehrere dubios aussehende',
#  'dubios aussehende gestalten',
#  'ans eigene volk',
#  "geht 's los",
#  'rechtsradikal ausgerichtet wären-und',
#  'wer steckt dahinter',
#  'le pen macht',
#  'wer min zeit',
#  'nazis usw prüft',
#  'no go area',
#  'the walking dead',
#  'ab nächste woche',
#  'europa bringen lassen',
#  'pegida legida anhängern',
#  'kommentare profiele usw',
#  'seit jahren fordern',
#  'bach runter geht',
#  'bravo marine le',
#  'mal sehen wer',
#  'dadurch wähler verschaffen',
#  'wahlrecht gewährt.- wohl',
#  'möglich wahlrecht gewährt.-',
#  'asyl gewährt -und',
#  'spd cdu fdp',
#  'goldene nase verdienen',
#  'regierung dadurch wähler',
#  'rechte regierung dadurch',
#  'teil rechtsradikal ausgerichtet',
#  'großen teil rechtsradikal',
#  'ja schon seit',
#  'schon mal jemand',
#  'fast millionen menschen',
#  'zunge zergehen lassen',
#  'freien fuß gesetzt',
#  'wohl kaum jemand',
#  'vergangenen jahr milliarden',
#  'mal ganz abgesehen',
#  'eurovision song contest',
#  'vollendete tatsachen gestellt',
#  'endlich mal jemand',
#  'hamburger abendblatt berichtet',
#  'gürtel enger schnallen',
#  'russlands präsident wladimir',
#  'einreise per flugzeug',
#  'eigenen beinen stehen',
#  'immer mehr bürger',
#  'schon letzte woche',
#  'ha ha ha',
#  'land schon fast',
#  'guten geistern verlassen',
#  'zukunft unserer kinder',
#  'ganz schnell passieren',
#  'sozusagen zwei fliegen',
#  'amerikanischen geheimbund skull',
#  'na vielleicht sollen',
#  'vielleicht sollen ja',
#  'skull glauben schenken',
#  'einsicht ganz selten',
#  'land wert zumindest',
#  'geheimbund skull glauben',
#  'roten idioten u',
#  'haufen bomben sparen',
#  'sicht volle fahrt',
#  'volle fahrt voraus',
#  'fahrt voraus deutschland',
#  'ard- deutschlandtrend zustimmung',
#  'sgb rund mrd',
#  'hörigen schweden tun',
#  'duerfte leider schon',
#  "warum geht 's",
#  'nicht.also weiterhin ab',
#  'kräftigen anstieg rechnen',
#  'österreichs grenzen stehen',
#  'laschet stellvertretender bundesvorsitzender',
#  'armin laschet stellvertretender',
#  'bessere model stehen',
#  'eigentlich ganz einfach',
#  'einzig wahre lehre',
#  'grenzen mal sehen',
#  'gegnern unserer leitkultur',
#  'unserer leitkultur keinerlei',
#  'leitkultur keinerlei gnade',
#  'seit jahren rechtsextremismus',
#  'jahren rechtsextremismus geschaffen',
#  'lebensunterhalt sichern wirklich',
#  'sichern wirklich gut',
#  'wirklich gut gemacht',
#  'internet schlägt zurück',
#  'jedermann/-frau sofort eingestellt',
#  'grenzen stehen tausende',
#  'danke pegida danke',
#  'pegida danke afd',
#  'schweden schließt samstag',
#  'alice schwarzer gehört',
#  'vergessen schweden bekommt',
#  'öffentlich darauf hingewiesen',
#  'haidar ahmed paradoxen',
#  'bild feministin islamischer',
#  'feministin islamischer kreuzzug',
#  'islamischer kreuzzug faschismus',
#  'schon seit khomeinis',
#  'seit khomeinis zeiten',
#  'khomeinis zeiten ende',
#  'sofort genau erkannt',
#  'viele emmaausgaben komplett',
#  'dafür flüchtlinge aufzunehmen',
#  'mal selber kopftuch',
#  'selber kopftuch tragen',
#  'schon ne weile',
#  'weiblichen jubelndeutschen sammeln',
#  'fünften mal aufs',
#  'leisten steuerhinterziehung koks',
#  'mal aufs maul',
#  'hierarchisch strukturierten kultur',
#  'beispiel rainer brüderle',
#  'könig richard löwenherz',
#  'englische könig richard',
#  'deutschen volk schon',
#  'ja soooo leid',
#  'fällt denen ja',
#  'denen ja früh',
#  'jahren bürgerkriegsähnliche zustande',
#  'bürgerkriegsähnliche zustande geben',
#  'danke berlin danke',
#  'berlin danke frau',
#  'frau merkel danke',
#  'merkel danke herr',
#  'danke herr gabriel',
#  'land bringen dadurch',
#  'grenzen offen halten',
#  'arbeit geht steuern',
#  'geht steuern zahlt',
#  'nahen osten verkauft',
#  'osten verkauft müssten',
#  'kapazitätsgrenze schon hinaus',
#  'globalen massstäben missachtet',
#  'sollen etwa abgelehnte',
#  'schon längst hätten',
#  'endlich schweden aufgewacht',
#  'richtig falsch laufen',
#  'denen asyl gewährt',
#  'bewaffneter widerstand legitim',
#  'neuer tiefpunkt zdf-lanz',
#  'tiefpunkt zdf-lanz vs.csu-ramsauer',
#  'schlagzeile merkel setzt',
#  'paar millionen bereicherer',
#  'millionen bereicherer vertragen',
#  'balkan bricht immer',
#  'öffentliche dienst alarm',
#  'bricht immer neue',
#  'immer neue rekorde',
#  'beteiligten seien sofort',
#  'beschleunigten asylverfahrens vorgeführt',
#  'asylverfahrens vorgeführt worden',
#  'deutschen polizeigewerkschaft alarm',
#  'polizeigewerkschaft alarm geschlagen',
#  'rainer wendt warnt',
#  'industrielle weltmacht entwickelte',
#  'vielen kleinen stadtstaaten',
#  'stolze kleine land',
#  'eigenem haus einladen',
#  'koks nutten usw',
#  'parlament zudem mehrere',
#  'sagte ministerpräsident stefan',
#  'zudem mehrere gesetzesverschärfungen',
#  'etwa abgelehnte asylbewerber',
#  'abgelehnte asylbewerber schneller',
#  'asylbewerber schneller abgeschoben',
#  'schwedennicht besonders erfreulich',
#  'doppelte staatsbürgerschaft vergeben',
#  'night mher normal',
#  'wille angela merkel',
#  'angela merkel viele',
#  'merkel viele dank',
#  'unserer lande kaput',
#  'lande kaput gemacht',
#  'kaput gemacht habben',
#  'fremde wilde personen',
#  'schulen kindertagesstätten ausländer-',
#  'normalmaß hinaus belastet',
#  'russland weder europa',
#  'gehen hängt wohl',
#  'mittlerweile offenbar unschwer',
#  'offenbar unschwer erkennen',
#  'naziprotest bezeichneten ereignissen',
#  'bezeichnung problem umändern',
#  'rechten zwangsläufig mord',
#  'soldat mehr wirklich',
#  'mehr wirklich ernsthaft',
#  'wirklich ernsthaft motivierbar',
#  'heute verwendeten waffensystemen',
#  'knapp menschen wohnen',
#  'thermalsichtgeräte autonome computergesteuerte',
#  'autonome computergesteuerte geschütze',
#  'computergesteuerte geschütze hochsensible',
#  'geschütze hochsensible antipersonenminen',
#  'meter tötungsradius clusterbomben',
#  'tötungsradius clusterbomben atomwaffen',
#  'clusterbomben atomwaffen usw.',
#  'verschissenen dreck wert',
#  'mehr politiker wach',
#  'immer mehr politiker',
#  'sei teilweise völlig',
#  'verkehrsüberwachung sei teilweise',
#  'völlig ungesichert schimpfte',
#  'schweden großzügig flüchtlinge',
#  'großzügig flüchtlinge aufgenommen',
#  'stimmung kippt –',
#  'zeit darauf aufmerksam',
#  'nachbarländern bewundert kaum',
#  'bewundert kaum jemand',
#  'meisten abgelehnten asylbewerber',
#  'abgelehnten asylbewerber freiwillig',
#  'bekommen dafür geld',
#  'wochen gewitzelt wurde',
#  'gewitzelt wurde scheint',
#  'wurde scheint realität',
#  'laut polizeigewerkschaft dpolg',
#  'polizeigewerkschaft dpolg steigt',
#  'dpolg-bundesvorsitzende rainer wendt',
#  'rainer wendt sagte',
#  'steuerhinterziehung koks nutten',
#  'afd wähler besser',
#  'medien frau schwarzer',
#  'brodelnden giftmgemisch entwickeln',
#  'erzogen worden nie',
#  'deren politischer szene',
#  'politischer szene verknüpt',
#  'manuela schweswig anhören',
#  'beweihräuchert staatlich verordnete',
#  'staatlich verordnete frauenquoten',
#  'verordnete frauenquoten lgbt-propaganda',
#  'kulturfremde masseneinwanderung gleichermaßen',
#  'millionen ungeborene kinder',
#  'wurde wohl heimlich',
#  'mutterleib ermordet wurden',
#  'europäische werte petition',
#  'interview schon lange',
#  'interviewer herr köppel',
#  'herr köppel bemerkte',
#  'scheidung deklassiert wurden',
#  'richter finden ließe',
#  'konnte darüber herzlich',
#  'ganz schnell schluss',
#  'kompanie walküren gegenübersteht',
#  'wer legt wert',
#  'alte steuerhinterzieherinaber recht',
#  'mittel alter fachisten',
#  'untergang unserer hart',
#  'unserer hart erkämpften',
#  'hart erkämpften rechte',
#  'geht gar nicht.würden',
#  'bestimmtes leben bedeutet',
#  'alice schwarzer dürfte',
#  'mal angezogen putzen',
#  'damals schon gewußt',
#  'voll richtig erkannt',
#  'staatsschutz wegen volksverhetzung',
#  'ausrichtung durchweg konsequent',
#  'eigentlich normal wäre',
#  'heutigen zeiten großes',
#  'zeiten großes lob',
#  'damals schon recht',
#  'alice schwarzer gefällt',
#  'kopftuch oh nein',
#  'wohl heimlich angesteckt',
#  'duisburg marxloh gelaufen',
#  'erst mal abwarten',
#  'unberechenbare irre person',
#  'merkel weiß wohl',
#  'warten mal abjeden',
#  'mal abjeden tag',
#  'abjeden tag gibt',
#  "tag gibt 's",
#  "'s ja neue",
#  'ja neue unglaublichkeiten',
#  'zig fach gepostetbeweismaterial',
#  'heimlich angesteckt u',
#  'fach gepostetbeweismaterial liegt',
#  'gerfolgen-desto mehr wahlvolk',
#  'mehr wahlvolk geht',
#  'afd legt woche',
#  'legt woche fuer',
#  'woche fuer woche',
#  'grenze unserer kapazität',
#  'momentanen tendenzenund je',
#  'wundert nix mehr',
#  'zumich wundert nix',
#  'weiteres zumich wundert',
#  'm.ohne weiteres zumich',
#  'is kämpferin schlock',
#  'kämpferin schlock lass',
#  'deutschland massive probleme',
#  'herr maas behaupten',
#  'maas behaupten wer',
#  'reicht zuviel gesindel',
#  'zuviel gesindel treibt',
#  'alice zahl ehrlich',
#  'alte schabrake namens',
#  'schabrake namens merkel',
#  'namens merkel muß',
#  'deutsche muß her',
#  'hirnlosen gebrabbel kommt',
#  'schaff schon garnicht',
#  'schon garnicht mehr',
#  'garnicht mehr soviel',
#  'frau m.ohne weiteres',
#  'kopftuch trägt wegen',
#  'tragen koptücher gestern',
#  'ober lehrer herr',
#  'is mr dog',
#  'wollten immer europa',
#  'balkan krieg verursacht',
#  'dog untill is',
#  'untill is facing',
#  'is facing you',
#  'facing you then',
#  'you then is',
#  'then is mr',
#  "auf'n schlips getreten",
#  'vergessen braun is',
#  'schlips getreten fühlt',
#  'getreten fühlt herrlich',
#  'humanistischen islam ganz',
#  'islam ganz schnell',
#  'mater neben pater',
#  'alice schwarzer trifft',
#  'bisschen unglücklich allerdings',
#  'rot pur-rot schwarz',
#  'ganz europa grauset´s',
#  'putin herr putin',
#  'herr putin herr',
#  'genau fachkräfte kommet',
#  'lehrer herr friedmann',
#  'herr friedmann usw',
#  'völlig schleierhaft warum',
#  'steinzeit unterdrückungs krawalle',
#  'unterdrückungs krawalle agressions',
#  'krawalle agressions wiederlicher',
#  'agressions wiederlicher scheissglaube',
#  'erlkönigin wer reitet',
#  'liebes pack kommt',
#  'pack kommt her',
#  'schreckliche spiele spiel',
#  'seit ruhig bleibt',
#  'ruhig bleibt ruhig',
#  'willst feines europa',
#  'frau merkel frau',
#  'merkel frau merkel',
#  'frau merkel siehst',
#  'grün vergessen braun',
#  'braun is ja',
#  'nonnen tragen koptücher',
#  'horror pur erleben',
#  'merkels ehepartner herr',
#  'ehepartner herr merkel',
#  'nie wirklich symp',
#  'ganz wenigen echten',
#  'wenigen echten weiblichen',
#  'echten weiblichen akkteure',
#  'sogenannten emanzen sorry',
#  'emanzen sorry halten',
#  'pur erleben interessiert',
#  'erst drauf kommen',
#  'erleben interessiert ansch',
#  'erfahrungsgemäß absolut integrationsresistent',
#  'augen ungläubige agressiv',
#  'ungläubige agressiv bekämpfen',
#  'multi/kulti großstatdt schwager',
#  'großstatdt schwager ex-moslem',
#  'gerne zitierten argument',
#  'zitierten argument kommen',
#  'frau merkels ehepartner',
#  'schon beim pranger',
#  'schwarzer schon beim',
#  'alice schwarzer schon',
#  'reichstag-brands gespannt heil',
#  'gespannt heil merkel',
#  'alice schwarzer recht',
#  'her justizminister kummern',
#  'mündige bürger umerzogen',
#  'fdj hemd getragen',
#  'uniform fdj gekämpft',
#  'super gedicht fadd',
#  'gedicht fadd gefällt',
#  'frau schwarzer anregen',
#  'frau schwarzer mal',
#  'duchgeknallten meinungsmacher reiten',
#  'klugen gedanken fähig',
#  'mal recht gebeten',
#  'ganz offen gelogen',
#  'islamistische kreuzzügler aua',
#  'gut alice schwarzer',
#  'unserer kapazität “',
#  'frau merkelmein gott',
#  'bisherigen großzügigen aufnahme',
#  'menschen strömen richtung',
#  'seit selber schuld',
#  'selber schuld warum',
#  'schuld warum lasst',
#  'politiker habt versagt',
#  'strasse gehen passiert',
#  'kommt endlich raus',
#  'video gepostetvon heute',
#  'gepostetvon heute morgen',
#  'strömen richtung deutschland',
#  'rot braun weiß',
#  'schützen .oder lieg',
#  'schwanzlose jünger sehen',
#  'immer kommt rein',
#  'gurgel gehendie welcome',
#  'gehendie welcome fraktion',
#  'walking dead staffel',
#  'invasion biblischen ausmaßes',
#  'biblischen ausmaßes schluß',
#  'länder seit selber',
#  'deutschland unterwegs eben',
#  'österreich deutschland unterwegs',
#  'richtung österreich deutschland',
#  'ehrenamtlich natürlich schaffen.ironie',
#  'natürlich schaffen.ironie off',
#  'nieder verbrennen zelte',
#  'verbrennen zelte hinterlassen',
#  'zelte hinterlassen dreck',
#  'richtig gute grenzbefestigung',
#  'merkel denen versprochen',
#  'mal ne ladung',
#  'land einzunehmen.man hätte',
#  'hohen christlichen feiertagen',
#  'zuhause.die polizei läuft',
#  'ja schon belegt',
#  'waffenkammer öffnen na',
#  'öffnen na ja',
#  'ort sein.dies spielt',
#  'sein.dies spielt natürlich',
#  'schreibe.also nix ernstes',
#  'vielen vielen menschen',
#  'braun weiß kariert',
#  'laufen laufen immer',
#  'flüchten ja klar',
#  'eu krenzen dicht',
#  'neues buch schreiben',
#  'buch schreiben europas',
#  'schreiben europas bürger',
#  'europas bürger schafft',
#  'gut nacht deutschland',
#  'einfach grenzen platz',
#  'angeblich flüchten ja',
#  'stein erst gar',
#  'weiß kariert usw',
#  'schuld garantiert schon',
#  'garantiert schon bewußt',
#  'nacht deutschland schweden',
#  'deutschland schweden östereich',
#  'restlichen eu- länder',
#  'aktuellen krise seit',
#  'krise seit monaten',
#  'fremden unterwegs kostenlos',
#  'raubenden meute überlassen',
#  'hetzenden raubenden meute',
#  'frauen echte frauen',
#  'ja frauen echte',
#  'immer versprochen hast',
#  'stich gelassen wurden',
#  'is gut hätten',
#  'gut hätten paroli',
#  'hätten paroli halten',
#  'paroli halten könnenaber',
#  'halten könnenaber nein',
#  'überbezahlten polit idioten',
#  'polit idioten gehören',
#  'sagen volker vielhuber',
#  'echt schlecht wirklich',
#  'dank frau merkelmein',
#  'spekulationen ueber steuererhoehung/fluechtlingssoli',
#  'vielen dank frau',
#  'dank frau merkel',
#  'na na na',
#  'laufen schon wetten',
#  'arbeitsplätze ehrenamtlich natürlich',
#  'hartz euro billiglohn',
#  'weder hartz euro',
#  'deutschland ca theater-',
#  'bitte züchtig kleiden',
#  'züchtig kleiden sollen',
#  'wohl zusammen rücken',
#  'zusammen rücken müssen',
#  'keinster weise mehr',
#  'kinder geregelter ablauf',
#  'sogenannten renommierten parteien',
#  'renommierten parteien zeigen',
#  'ca theater- opern-',
#  'aufgehalten weder hartz',
#  'wären ca plätze',
#  'funktionierende demokratie benötigt',
#  'demokratie benötigt vernünftig',
#  'benötigt vernünftig denkende',
#  'vernünftig denkende rechte',
#  'denkende rechte liberale',
#  'ja neue töne',
#  'neue töne frau',
#  'weiblichen berufsschüler gab',
#  'des… kla.tv|von klagemauer.tv',
#  'taktik des… kla.tv|von',
#  'moderne kriegstreiber beherrschen',
#  'schiff manner sollen',
#  'manner sollen frauenkleidung',
#  'kopftuch tragen mussen',
#  'wiedergutmachung fur frauen',
#  'fur frauen unterdruckung',
#  'halbe nahe osten',
#  'ansturm halten frau',
#  'halten frau merkel',
#  'gucke schon mal',
#  'bittere ende kommt',
#  'ja immer schlimmerschrecklich',
#  'massen müssen verdammt',
#  'müssen verdammt nochmal',
#  'verdammt nochmal gestoppt',
#  'anschauen instrumentalisierende kriegsführung',
#  'instrumentalisierende kriegsführung flüchtlinge',
#  'terror medien-klagemauer.tv »',
#  'töne frau innenministerin',
#  'politiker herrn orban',
#  'festung europa schnell',
#  'inklusive schießscharten scharfschützen',
#  'scharfschützen heißes öl',
#  'ganze landstriche leer',
#  'vielen jungen männer',
#  'jungen männer sollten',
#  'heimat verteidigen anstatt',
#  'elend zurückzulassen.aber ab',
#  'zurückzulassen.aber ab morgen',
#  'de misere gesagt.wers',
#  'misere gesagt.wers glaubt',
#  'kommen sagte frau',
#  'frau merkel vorgestern',
#  'höre mal selber',
#  'mal selber ab',
#  'selber ab minute',
#  'jahrelang cdu spd',
#  'spd grüne wählen',
#  'volkes aufgehalten weder',
#  'schießscharten scharfschützen heißes',
#  'mauer inklusive schießscharten',
#  'europa schnell fertiggestellt',
#  'chinesische mauer inklusive',
#  'sagt mal leute',
#  'viele flucht impulse',
#  'stehen leoparden eigentlich',
#  'zitat grünen-chefin simone',
#  'simone peter rief',
#  'sollen vorher österreich',
#  'vorher österreich richtig',
#  'österreich richtig zuscheissen',
#  'land niemanden mehr',
#  'wanderheuschrecken zurück zwingen',
#  'slovenia kaine stop',
#  'foto oben paßt',
#  'deutschen grenzen recht',
#  'flüchtlingskrise immer frage',
#  'immer frage wer',
#  'frage wer steckt',
#  'unnormal mal ehrlich',
#  'essen kleidung usw',
#  'vermeintliches schlaraffenland angekommen',
#  'schwedische regierung rückt',
#  'deutschland frau merkel',
#  'völlig bekloppten überfahren',
#  'kind auffangen bevor',
#  'abartigen schwarzen träumen',
#  'nation klar definiert',
#  'viele staatsangehörige vertreten',
#  'oben offenen zuwanderungszahl',
#  'offenen zuwanderungszahl verteidigen',
#  'anrüchig scheint festgelegt',
#  'wohnhaus errichten lassen',
#  'allerdümmsten lämmer wählen',
#  'gesagt werte frau',
#  'werte frau merkel',
#  'österreichs festung europa',
#  'demo laut äussern',
#  'unaufgeräumte zimmer aufzuregen',
#  'ne eigene meinung',
#  'bedeutet pure demokratie',
#  'weder spd cdu',
#  'einfach völlig bekloppten',
#  'ami- hörigen politikern',
#  'paar ami- hörigen',
#  'kämmerchen dinge aushecken',
#  'möglichst objektive meinung',
#  'mehr rationalistät statt',
#  'rationalistät statt emotionen',
#  'richtige stelle setzen',
#  'wohl fürs volk',
#  'fürs volk aufmerksam',
#  'volksentscheide erlaubt washington',
#  'seit wievielen jahren',
#  'wievielen jahren sitzt',
#  'einziger echter vertreter',
#  'zuviel mitspracherecht bekommen',
#  'mitspracherecht bekommen könnten',
#  'extrem wichtiger schritt',
#  'einströmenden steigt immer',
#  'frau merkel mutti',
#  'merkel mutti genannt',
#  'geheimen kämmerchen dinge',
#  'cdu fdp grüne',
#  'wer seit jahrzehnten',
#  'übernimmt allgemeine gerüchte',
#  'schafft frau merkel',
#  'seit jahren riesenprobleme',
#  'extrem integrationswilligen zuwanderern',
#  'sagen alter schwede',
#  'beschlossen wurden reichen',
#  'ganze zeit recht',
#  'frau merkel durchlesen',
#  'deutschen volk zumuten',
#  'komplett links gewählt',
#  'problem herr premier',
#  'seit jahrzehnten treu-doof',
#  'herr premier schickt',
#  'stoff teddy land',
#  'grenzenlosen möglichkeitendie deutsche',
#  'möglichkeitendie deutsche elite',
#  'deutsche elite wartet',
#  'ungeduldgrüne spd cdu',
#  'empfangs-komitee steht schon',
#  'germanischen ländern passiert',
#  'inzwischen sicher komplett',
#  'heute berichte darüber',
#  'ungültig erklärt wurden',
#  'erst mal sollten',
#  'herrschenden allparteienkoalition macht',
#  'sorgloses wahlverhalten verdient',
#  'politischen idioten abgebe',
#  'wer fragt eigentlich',
#  'euist reune luege',
#  'afrika laufen ubd',
#  'laufen ubd zahlen',
#  'endlich aufund stoppt',
#  'faymann merkl koalition',
#  'verhindern .keinen grenzzaunganz',
#  'sterne hotels deren',
#  'hotels deren personal',
#  'deren personal entlassen',
#  'personal entlassen wirdauch',
#  'oesterreich bereitsder fallstoppt',
#  'wahsinndieser moslem n',
#  'privatbesitz unserer kultur',
#  'volksentscheide schon seit',
#  'politischen entscheidungen eingebunden']

# %%
np.savetxt("triigram_keywords_tf_idf_with_news_without_stopwords.csv", result_list, delimiter =",",fmt ='% s')
