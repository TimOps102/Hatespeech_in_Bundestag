# %%
import nltk
import string
import pickle
import numpy as np
from collections import Counter

# %%
import zipfile
content = {}
with zipfile.ZipFile("keyword.zip") as zfile:
    for f in zfile.namelist():
        if f != "keyword/":
            content[f] = zfile.read(f).decode("utf8")
content.keys()
# Out:
# dict_keys(['keyword/automobil_50k.txt', 'keyword/news_text100k.txt', 'keyword/sport_50k.txt', 'keyword/wirtschaft_50k.txt'])

# %%
def clean(text):
    tokenized_sents=[]
    text = text.lower()
    text = nltk.sent_tokenize(text)
    for sent in text:
        sent = nltk.word_tokenize(sent)
        sent = [x for x in sent if x not in string.punctuation]
        sent = [x for x in sent if x not in ["``", "''", "€", "$"]]
        sent = [x for x in sent if x.isalpha()]
        if len(sent) > 1:
            tokenized_sents.append(sent)
        
    
    return tokenized_sents

# %%
for key in content:
    content[key] = clean(content[key])

# %%
def create_bigrams(dic_corpora):
    ngram_dict = {}
   
    stopwords = nltk.corpus.stopwords.words("german")
    stopwords +=["findbecci","--","..", "§", '”', "rebecca", "freeflorian", "\|lbr\|", "|lbr|"]
   
    for index, key in enumerate(dic_corpora):
        print(key)
        ngram_dict[key] =[]
  
        for sents in dic_corpora[key]:

            ngram_dict[key] += [gram for gram in list(nltk.ngrams(sents,2)) if len(set(stopwords).intersection(set(gram)))== 0]
    
    return ngram_dict

# %%
bigrams = create_bigrams(content)
# Out:
# keyword/automobil_50k.txt
# keyword/news_text100k.txt
# keyword/sport_50k.txt
# keyword/wirtschaft_50k.txt

# %%
def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
hatespeech = load_obj("ngrams_hatespeech_without_stopwords")

# %%
bigrams["keywords/hatespeech"] = hatespeech["2-grams"]

# %%
bigrams["keywords/hatespeech"][:100]
# Out:
# [('schwimmbad', 'gehen'),
#  ('menschenrechte', 'pressefreiheit'),
#  ('pressefreiheit', 'islamisierung'),
#  ('islamisierung', 'wieso'),
#  ('wieso', 'bekommen'),
#  ('bekommen', 'rapefugees'),
#  ('rapefugees', 'mehr'),
#  ('hartz', 'enpfänger'),
#  ('verfluchten', 'rapefugees'),
#  ('krieg', 'erklären'),
#  ('ruhrpott', 'unterwegs'),
#  ('überall', 'schwangere'),
#  ('schwangere', 'muslimische'),
#  ('muslimische', 'frauen'),
#  ('kindern', 'islamisierung'),
#  ('islamisierung', 'asylanteninvasion'),
#  ('gewaltausbrüchen', 'kommt'),
#  ('verantwortlichen', 'hierfür'),
#  ('hierfür', 'sitzen'),
#  ('regierung', 'merkel'),
#  ('millionen', 'menschen'),
#  ('menschen', 'leben'),
#  ('millionen', 'flüchtlinge'),
#  ('flüchtlinge', 'bereiten'),
#  ('rassisten', 'sprechen'),
#  ('flüchtlinge', 'verpassen'),
#  ('refugees', 'refugeesnotwelcome'),
#  ('refugeesnotwelcome', 'refugeesgohome'),
#  ('refugeesgohome', 'abmerkeln'),
#  ('kölner', 'polizei'),
#  ('gestiegene', 'anzeigen'),
#  ('grund', 'frauen'),
#  ('frauen', 'seien'),
#  ('seien', 'anzeigefreudiger'),
#  ('rapefugees', 'offenes'),
#  ('offenes', 'freies'),
#  ('freies', 'wlan'),
#  ('sophienhof', 'kiel'),
#  ('gestern', 'nachmittag'),
#  ('unterdenlinden', 'petry'),
#  ('petry', 'fordert'),
#  ('fordert', 'bessere'),
#  ('bessere', 'regelung'),
#  ('regelung', 'gesetze'),
#  ('richtig', 'warum'),
#  ('hungerstreik', 'rapefugees'),
#  ('rapefugees', 'blutrache'),
#  ('blutrache', 'zwangsbekehrung'),
#  ('zwangsbekehrung', 'scharia'),
#  ('scharia', 'kinderbräute'),
#  ('kinderbräute', 'vielehe'),
#  ('vielehe', 'genitalverstümmelung'),
#  ('worin', 'liegt'),
#  ('deutsche', 'biertrinker'),
#  ('glyphosat', 'dezimieren'),
#  ('claudia', 'roth'),
#  ('roth', 'wer'),
#  ('wer', 'sex-attacken'),
#  ('asylanten', 'anprangert'),
#  ('geistiger', 'bruder'),
#  ('fuck', 'you'),
#  ('you', 'from'),
#  ('from', 'switzerland'),
#  ('asylanten', 'grüne'),
#  ('februar', 'kamen'),
#  ('neusten', 'angaben'),
#  ('ard', 'tagesschau'),
#  ('tagesschau', 'trotz'),
#  ('trotz', 'grenzkontrollen'),
#  ('balkanroute', 'asylanten'),
#  ('verbrechen', 'begangen'),
#  ('menschenwürde.hungerstreik', 'rapefugees'),
#  ('rapefugees', 'merkel'),
#  ('schlampe', 'eigentlich'),
#  ('idee', 'gekommen'),
#  ('merkelmussweg', 'refugeesnotwelcome'),
#  ('farce', 'angesichts'),
#  ('merkeldiktatur', 'vorangetriebenen'),
#  ('vorangetriebenen', 'islamisierung'),
#  ('islamisierung', 'europas'),
#  ('gratis', 'häuser'),
#  ('häuser', 'wohnungen'),
#  ('wohnungen', 'handys'),
#  ('handys', 'u.'),
#  ('u.', 'öffitickets'),
#  ('öffitickets', 'mindestsicherung'),
#  ('mindestsicherung', 'straffreiheit'),
#  ('straffreiheit', 'vorreihung'),
#  ('ambulanzen', 'schlaraffenland'),
#  ('zib', 'asylanten'),
#  ('asylanten', 'beateuhse'),
#  ('beateuhse', 'konzern'),
#  ('konzern', 'vermarktet'),
#  ('vermarktet', 'scharia'),
#  ('scharia', 'konforme'),
#  ('konforme', 'sexprodukte'),
#  ('sexprodukte', 'bitte'),
#  ('bitte', 'boykottiert'),
#  ('laut', 'orban'),
#  ('merkel', 'europa')]

# %%
def transform_ngrams(dic):
    bigrams={}
    for keys in dic:
        tuples = []
        for doc in dic[keys]:
            tuples.append("_".join(doc))
        bigrams[keys] = tuples
    return bigrams

# %%
bigram = transform_ngrams(bigrams)

# %%
bigram
# Out:
# {'keyword/automobil_50k.txt': ['ford_ordentlich',
#   'ordentlich_einheizen',
#   'bidirektionalen_schlüssel',
#   'monatlich_günstiger',
#   'niedrigeren_anschaffungspreise',
#   'kastenwagen_wirken',
#   'monatlichen_kosten',
#   'kosten_dämpfend',
#   'entwickler_dennoch',
#   'paar_kleinigkeiten',
#   'kleinigkeiten_vergessen',
#   'umgelegten_sitzlehnen',
#   'sitzlehnen_bilden',
#   'bilden_leider',
#   'komplett_ebenen',
#   'ebenen_ladeboden',
#   'statt_schriller',
#   'schriller_farben',
#   'farben_verrückter',
#   'verrückter_formen',
#   'paar_frischer',
#   'frischer_funktionen',
#   'funktionen_gibt',
#   'billiges_plastik',
#   'früher_kaum',
#   'kaum_vorstellbar',
#   'unterstützung_bekommen',
#   'bundeskanzlerin_angela',
#   'angela_merkel',
#   'merkel_cdu',
#   'fc_bayern',
#   'bayern_spielt',
#   'fc_aberdeen',
#   'aberdeen_remis',
#   'hsv_gewinnt',
#   'aston_martin',
#   'martin_zeigt',
#   'leider_fahren',
#   'eigentlich_läge',
#   'beruf_macht',
#   'dadurch_verringern',
#   'spontaner_reagieren',
#   'concept_car',
#   'car_heißt',
#   'ähnelt_darüber',
#   'darüber_hinaus',
#   'euro_aufpreis',
#   'aufpreis_gibt',
#   'maximal_nm',
#   'nm_entwickelt',
#   'dennoch_brauchts',
#   'fünf_meter',
#   'meter_lange',
#   'tonnen_schwere',
#   'schwere_limousine',
#   'schwung_kommt',
#   'coupé_kostet',
#   'kostet_franken',
#   'cabrio_franken',
#   'farbige_applikationen',
#   'applikationen_zeichnen',
#   'dienstgradhöchste_offizier',
#   'streife_ließ',
#   'ließ_kräftig',
#   'kräftig_dampf',
#   'dampf_ab',
#   'gesehen_hätte',
#   'zwei_probleme',
#   'lang_sodass',
#   'fußmatte_verhaken',
#   'autos_eingedroschen',
#   'messe_auto',
#   'auto_china',
#   'peking_dauert',
#   'wertstabilste_marke',
#   'deutschen_automarkt',
#   'bald_ausgedient',
#   'befragt_wurden',
#   'wurden_männer',
#   'frauen_ab',
#   'ab_jahren',
#   'danach_folgt',
#   'alten_kombi',
#   'kombi_liegt',
#   'kleingedruckten_gibt',
#   'opel_reichlich',
#   'meckern_gibts',
#   'beim_crash',
#   'ungeborene_ausüben',
#   'deutschen_autokäufer',
#   'autokäufer_vorerst',
#   'transparenten_verbrauchskennzeichnung',
#   'pkw_rechnen',
#   'computer_übernimmt',
#   'fürs_fahrvergnügen',
#   'fahrvergnügen_gibts',
#   'millimeter_geringerer',
#   'geringerer_bodenfreiheit',
#   'bodenfreiheit_sowie',
#   'elektronische_differentialsperre',
#   'differentialsperre_xds',
#   'kurvengeschwindigkeiten_steigen',
#   'dürfte_daimler',
#   'daimler_interessieren',
#   'europa_goldelt',
#   'ungerne_fliegt',
#   'bisschen_neid',
#   'neid_unterdrücken',
#   'zentimetern_körpergröße',
#   'schier_unglaublicher',
#   'unglaublicher_beinfreiheit',
#   'beinfreiheit_sprechen',
#   'tourenzähler_stehen',
#   'stehen_beeindruckende',
#   'beeindruckende_nm',
#   'darauf_ausruhen',
#   'vergleichsweise_glimpflich',
#   'steuern_scheint',
#   'allerdings_brachte',
#   'größte_spritverbraucher',
#   'lenkrad_sitzt',
#   'drei_personen',
#   'tempomat_gekoppelt',
#   'joseph_corré',
#   'life_ball',
#   'roten_teppich',
#   'wiener_rathaus',
#   'rathaus_steuern',
#   'september_bringt',
#   'bringt_alfa',
#   'neues_heißes',
#   'heißes_einstiegsmodell',
#   'schlechte_entwicklung',
#   'anton_hunger',
#   'hunger_anmerkte',
#   'politur_versprechen',
#   'versprechen_brillianz',
#   'dauerversuch_wurden',
#   'sechs_produkte',
#   'produkte_getestet',
#   'ford_hinkt',
#   'vorjahresabsatz_hinterher',
#   'millionen_autos',
#   'hochgezogene_heckpartien',
#   'immer_schräger',
#   'schräger_werdende',
#   'werdende_frontscheiben',
#   'frontscheiben_kritisierten',
#   'künast_empfiehlt',
#   'besonderes_bremssystem',
#   'fotostrecke_bilder',
#   'bilder_rebmann',
#   'rebmann_je',
#   'je_seltener',
#   'desto_wertvoller',
#   'regierungssprecher_ulrich',
#   'ulrich_wilhelm',
#   'montag_klargestellt',
#   'vorher_genau',
#   'genau_prüfen',
#   'gilt_natürlich',
#   'knight_rider',
#   'david_hasselhoff',
#   'koblenz_dpa',
#   'abschüssiger_straße',
#   'weiher_rollt',
#   'vollkaskoversicherung_zahlen',
#   'mustang_gt',
#   'gt_anbieten',
#   'tata_nano',
#   'immerhin_schon',
#   'schon_lange',
#   'lange_wartezeiten',
#   'beiden_tarifen',
#   'tarifen_verlangte',
#   'unternehmen_daraufhin',
#   'unfallgeschädigten_heißt',
#   'sechs_kreisverkehre',
#   'geschmeidig_halten',
#   'bleibt_abzuwarten',
#   'schlechtes_paket',
#   'dollar_teuren',
#   'teuren_einsteiger',
#   'eingesetzten_rohstoffe',
#   'rohstoffe_wenigstens',
#   'wenigstens_angemessen',
#   'angemessen_genutzt',
#   'neue_steuer',
#   'steuer_könne',
#   'könne_theoretisch',
#   'theoretisch_schon',
#   'kraft_treten',
#   'treten_heißt',
#   'sprit_steuern',
#   'versicherungen_müssen',
#   'müssen_ab',
#   'januar_deutlich',
#   'deutlich_mehr',
#   'mehr_berappen',
#   'frankfurter_elternhaus',
#   'erstmals_richtig',
#   'richtig_kalt',
#   'beamte_versucht',
#   'neige_gibt',
#   'kleinen_dreizylinder',
#   'dreizylinder_sagt',
#   'sagt_lutz',
#   'länger_gemacht',
#   'auto_bullig',
#   'bullig_elegant',
#   'lange_fuhr',
#   'fuhr_bmw',
#   'hauptkonkurrenten_audi',
#   'kleinwagensegment_davon',
#   'italiener_präsentieren',
#   'schmucken_italia',
#   'zunächst_kümmerte',
#   'blinden_scheinwerfer',
#   'desaströse_elektrik',
#   'sonders_verrottet',
#   'natürlich_sprüht',
#   'koreanischer_kleinwagen',
#   'fiat_immer',
#   'immer_mehr',
#   'mehr_autos',
#   'klappen_sieben',
#   'sieben_personen',
#   'kompaktvan_transportieren',
#   'transportieren_beinfreiheit',
#   'einigermaßen_raum',
#   'berliner_kino',
#   'kino_cinemaxx',
#   'cinemaxx_lenkte',
#   'lenkte_downey',
#   'ingolstadt_selber',
#   'roten_teppich',
#   'euro_aufpreis',
#   'aufpreis_kostet',
#   'dsg_bietet',
#   'flottere_beschleunigungswerte',
#   'weniger_verbrauch',
#   'deutlich_besser',
#   'nächsten_frühjahr',
#   'paar_jahren',
#   'jahren_mal',
#   'autos_eigentlich',
#   'sichersten_seien',
#   'immer_einsamer',
#   'je_nördlicher',
#   'weitere_motorisierungen',
#   'benziner_tfsi',
#   'ps_sowie',
#   'hohen_temperaturen',
#   'brennraums_verkraften',
#   'tüv_nord',
#   'besseren_reifen',
#   'lenkkräfte_vorne',
#   'sollten_raten',
#   'besseren_reifen',
#   'hinten_montiert',
#   'montiert_sagt',
#   'sagt_maximilian',
#   'maximilian_maurer',
#   'vorort_qurum',
#   'dreck_befreien',
#   'brigitte_zypries',
#   'zypries_mal',
#   'mal_kräftig',
#   'schienbein_getreten',
#   'hype_minister',
#   'minister_lahmt',
#   'italien_schaffte',
#   'internationalen_durchbruch',
#   'zuletzt_prozent',
#   'prozent_mehr',
#   'ford_raptor',
#   'raptor_svt',
#   'schwimmweste_beim',
#   'beim_bergsteigen',
#   'laut_werksangaben',
#   'werksangaben_verbraucht',
#   'durchschnitt_liter',
#   'liter_diesel',
#   'dritte_junge',
#   'verkehrsunfall_starb',
#   'fahrrad_unterwegs',
#   'respekt_bleibt',
#   'straße_natürlich',
#   'pariser_vorort',
#   'vorort_velizy',
#   'velizy_zeigen',
#   'marke_aussehen',
#   'lenninger_sagt',
#   'circa_drei',
#   'drei_jahren',
#   'neue_strahlt',
#   'strahlt_preußische',
#   'preußische_nüchternheit',
#   'statt_bayerischem',
#   'bayerischem_barock',
#   'ans_aussteigen',
#   'denken_allenfalls',
#   'dusche_danach',
#   'boxster_s',
#   's_exakt',
#   'exakt_euro',
#   'gefahrene_tiptronic',
#   'tiptronic_s',
#   's_version',
#   'version_stolze',
#   'stolze_euro',
#   'gebürtige_saarländer',
#   'jahre_alt',
#   'massenmarke_mehr',
#   'mehr_bieten',
#   'optischen_durchschnitt',
#   'jahreszeit_vier',
#   'vier_personen',
#   'tempo_schafft',
#   'damals_flotten',
#   'flotten_sekunden',
#   'höchstgeschwindigkeit_liegt',
#   'indes_wurde',
#   'wurde_bekannt',
#   'toyota_offenbar',
#   'offenbar_bereits',
#   'bereits_seit',
#   'gaspedalen_weiß',
#   'sportlichen_viertürers',
#   'viertürers_geht',
#   'rapide_cls',
#   'cls_sportback',
#   'sportback_gt',
#   'italienisches_vorbild',
#   'völlige_enttäuschung',
#   'gerade_fünf',
#   'fünf_prozent',
#   'prozent_davon',
#   'neuen_erhebung',
#   'deutschen_umwelthilfe',
#   'umwelthilfe_duh',
#   'steuerbonus_erwartet',
#   'positive_auswirkungen',
#   'möglichen_wiederverkauf',
#   'geregelter_verkehr',
#   'ulrich_bez',
#   'bez_erstmals',
#   'projekt_cygnet',
#   'cygnet_berichtete',
#   'berichtete_dachte',
#   'verspäteten_aprilscherz',
#   'oft_günstiger',
#   'beim_sharan',
#   'konstanter_geschwindigkeit',
#   'automatisch_bergab',
#   'dank_geänderter',
#   'geänderter_vorderachsgeometrie',
#   'verstärkten_dreieckslenkern',
#   'baukasten_herausgeholt',
#   'massiv_leichter',
#   'auto_dagegen',
#   'dagegen_schwerer',
#   'schwerer_geworden',
#   'yokohama_ebenfalls',
#   'getan_schliesslich',
#   'schliesslich_kommen',
#   'kommen_heute',
#   'heute_suv',
#   'harten_alltagseinsatz',
#   'beachtliche_kilometerleistungen',
#   'drei_siechen',
#   'siechen_riesen',
#   'riesen_ford',
#   'ford_general',
#   'general_motors',
#   'chrysler_stehen',
#   'schmerzhaften_verlusten',
#   'demonstrieren_zumindest',
#   'letzten_großen',
#   'großen_branchentreff',
#   'mehrere_messen',
#   'straße_gelangen',
#   'adac_eigens',
#   'genfer_salon',
#   'salon_märchenhaft',
#   'märchenhaft_sparsame',
#   'sparsame_autos',
#   'einser_stand',
#   'liter_je',
#   'je_kilometer',
#   'handys_verwendung',
#   'verwendung_finden',
#   'statt_glamouröser',
#   'glamouröser_sowie',
#   'dingen_benzinfressender',
#   'benzinfressender_sportwagen',
#   'geeignete_bereifung',
#   'einzelfall_ab',
#   'ducatis_gt',
#   'kleine_fehler',
#   'gran_turismo',
#   'ideale_gefährt',
#   'ausgewachsenen_passagieren',
#   'dritten_sitzreihe',
#   'verletzungsrisiko_beträchtlich',
#   'erheblichen_finanziellen',
#   'finanziellen_schwierigkeiten',
#   'ende_zumindest',
#   'besonders_wertvolle',
#   'wertvolle_fahrzeuge',
#   'concours_eingeladen',
#   'eingeladen_rennmotorräder',
#   'programm_komplett',
#   'komplett_gemeinsam',
#   'alten_ju',
#   'jüchener_himmel',
#   'neuen_mini',
#   'mini_e',
#   'demnächst_einheiten',
#   'los_angeles',
#   'new_york',
#   'york_erfahrungswerte',
#   'späteres_elektrogroßserienauto',
#   'elektrogroßserienauto_sammeln',
#   'dreieck_aufgespreizte',
#   'große_glasdach',
#   'glasdach_verhelfen',
#   'größten_gesamtglasfläche',
#   'platz_gibts',
#   'gibts_rundum',
#   'rundum_üppig',
#   'spanngurten_befestigte',
#   'befestigte_weihnachtsbaum',
#   'weihnachtsbaum_hielt',
#   'hielt_dagegen',
#   'belastungen_stand',
#   'dollar_müsse',
#   'müsse_niedrigere',
#   'niedrigere_kraftstoffpreise',
#   'tiefgarage_lupe',
#   'taschenlampe_braucht',
#   'richtigen_knopf',
#   'knopf_fürs',
#   'fürs_öffnen',
#   'neun_zentimeter',
#   'breite_meter',
#   'exemplaren_verkaufte',
#   'verkaufte_alhambra',
#   'alhambra_gewachsen',
#   'innenraum_empfängt',
#   'kleine_format',
#   'format_schnell',
#   'schnell_vergessen',
#   'vergessen_dürften',
#   'fahrzeug_kommt',
#   'kilometer_pro',
#   'pro_stunde',
#   'halbes_jahr',
#   'limousine_erweitert',
#   'erweitert_mercedes',
#   'hauptferienzeit_neu',
#   'kleinen_bmws',
#   'deutschen_markt',
#   'markt_hergestellt',
#   'duisburg_oberhausen',
#   'oberhausen_bottrop',
#   'bottrop_gelsenkirchen',
#   'gelsenkirchen_herne',
#   'herne_bochum',
#   'gemeinsame_erklärung',
#   'erklärung_unterzeichnet',
#   'kleiner_hubraum',
#   'leistung_vw',
#   'flottenkönig_passat',
#   'ps_spendiert',
#   'nordamerika_dürften',
#   'welt_rund',
#   'rund_einheiten',
#   'wenig_reifendruck',
#   'reifendruck_erhöht',
#   'besondere_vorteil',
#   'ganzen_jahr',
#   'jahr_genutzt',
#   'bremse_startet',
#   'sekundenbruchteilen_erneut',
#   'stehende_kilometer',
#   'grenze_verstärkt',
#   'verstärkt_kontrolliert',
#   'quadratmeter_großes',
#   'großes_glasdach',
#   'glasdach_sorgt',
#   'neuwagens_storniert',
#   'zahlung_gegebenen',
#   'gegebenen_gebrauchtwagen',
#   'gebrauchtwagen_zurücknehmen',
#   'deutlich_teurer',
#   'carrera_gt',
#   'unternehmen_euro',
#   'rechnung_stellte',
#   'verachteten_wahlvolk',
#   'wahlvolk_finanziert',
#   'komfortabel_ausgestattet',
#   'ausgestattet_dienen',
#   'größere_bauteile',
#   'magnesium_fast',
#   'fast_ausschließlich',
#   'ausschließlich_per',
#   'per_druckguss',
#   'druckguss_produziert',
#   'kolben_flüssiges',
#   'flüssiges_leichtmetall',
#   'gussform_presst',
#   'spektrum_wohl',
#   'gemeinsam_erreichen',
#   'erreichen_beide',
#   'beide_motoren',
#   'hochrotem_kopf',
#   'kopf_erzählt',
#   'erzählt_linn',
#   'quietschendes_keuchen',
#   'keuchen_gehört',
#   'inhalt_volle',
#   'volle_unterstützung',
#   'harley_days',
#   'style_bietet',
#   'bietet_laut',
#   'laut_mercedes',
#   'erste_große',
#   'große_limousine',
#   'neu_entwickelte',
#   'entwickelte_multiantriebsplattform',
#   'neuen_designmerkmalen',
#   'astra_zählen',
#   'verbreiterte_chromspange',
#   'kühlergrill_retuschierte',
#   'rückleuchten_sowie',
#   'sowie_neue',
#   'neue_farben',
#   'farben_stoffe',
#   'ab_müssten',
#   'schnitt_prozent',
#   'herstellers_erfüllen',
#   'erfüllen_ab',
#   'ab_wären',
#   'ab_prozent',
#   'schönste_kapitän',
#   'zeiten_wurde',
#   'wurde_mitte',
#   'mitte_gebaut',
#   'jedoch_bringen',
#   'neuen_vorzeichen',
#   'alte_erfolgsrezept',
#   'erfolgsrezept_anknüpfen',
#   'elektronische_system',
#   'fahrzeugklassen_angeboten',
#   'besondere_flexibilität',
#   'flexibilität_verspricht',
#   'garmin_nüvi',
#   'tüv_süd',
#   'kleinstwagen_hinzu',
#   'wagen_zulegten',
#   'drei_segmente',
#   'segmente_sogar',
#   'sogar_prozent',
#   'dunkle_dachhimmel',
#   'pisser_gesagt',
#   'audi_angetrieben',
#   'aufgeladenen_triebwerk',
#   'audi_tt',
#   'tt_rs',
#   'hamburg_ron',
#   'ron_gettelfinger',
#   'mächtige_chef',
#   'uaw_bezeichnete',
#   'bezeichnete_mccain',
#   'peugeot_rcz',
#   'rcz_geerbt',
#   'kühlen_luftstrom',
#   'luftstrom_genießen',
#   'genießen_mittlerweile',
#   'meisten_halter',
#   'aufpreis_mitgeliefert',
#   'deutschland_brachte',
#   'erkenntnis_ans',
#   'ans_tageslicht',
#   'dabei_geht',
#   'frost_schnee',
#   'besondere_behandlung',
#   'behandlung_benötigt',
#   'bereits_hetzte',
#   'unbefestigten_karrenwege',
#   'knapp_meter',
#   'meter_hoch',
#   'hoch_aufragenden',
#   'hinterland_palermos',
#   'vergangenen_monaten',
#   'projekt_gestemmt',
#   'roadster_entwickelt',
#   'mercedes_intern',
#   'intern_w',
#   'w_genannt',
#   'genannt_debütierte',
#   'vier_jahren',
#   'neue_sportwagen',
#   'dresden_basiert',
#   'niedrigem_schwerpunkt',
#   'echte_sportskanone',
#   'energie_laut',
#   'laut_bahnsprecher',
#   'bahnsprecher_gunnar',
#   'gunnar_meyer',
#   'etwa_zehn',
#   'zehn_prozent',
#   'realität_wenig',
#   'entspricht_mehr',
#   'aktuellen_zeitgeist',
#   'mehr_platz',
#   'variabilität_gleichzeitig',
#   'innenraum_vergrößert',
#   'vier_zentimeter',
#   'zentimeter_radstand',
#   'radstand_kommen',
#   'kofferraum_schluckt',
#   'satte_liter',
#   'vorräder_wirkt',
#   'neues_niveau',
#   'mondeo_sicherer',
#   'sicherer_fühlen',
#   'früher_verspricht',
#   'verspricht_ford',
#   'feinen_fahrwerks',
#   'geringen_luftwiderstands',
#   'luftwiderstands_cw',
#   'bleifreiem_benzin',
#   'benzin_führte',
#   'untersuchung_zufolge',
#   'blech_legt',
#   'zwei_jahren',
#   'jahren_gebaute',
#   'gebaute_audi',
#   'grösseren_bmw',
#   'bmw_dürfte',
#   'franken_liegen',
#   'steigerung_gegenüber',
#   'fleming_forderte',
#   'europäische_industriepolitik',
#   'diskriminierungen_verhindert',
#   'europäischen_automobilindustrie',
#   'automobilindustrie_steuert',
#   'stärkste_hybrid',
#   'satte_euro',
#   'euro_aufpreis',
#   'elektrisch_vorankommen',
#   'unteren_preissegment',
#   'verkauf_angeboten',
#   'dreißiger_jahren',
#   'jahren_prägte',
#   'prägte_henri',
#   'henri_thomas',
#   'deren_auffälligstes',
#   'auffälligstes_merkmal',
#   'schildförmigen_kühlergrill',
#   'kühlergrill_platzierten',
#   'platzierten_scheinwerfer',
#   'verbotsplaketten_verteilt',
#   'sollen_blieb',
#   'dabei_dürfen',
#   'autobauer_versuchen',
#   'ehemals_kleine',
#   'kleine_sportwagenspezialist',
#   'bisher_vertikal',
#   'neuen_module',
#   'deutlich_mehr',
#   'hintere_schiebetür',
#   'mittelklasse_führt',
#   'prozent_restwert',
#   'weniger_überraschend',
#   'zunehmender_laufleistung',
#   'laufleistung_steige',
#   'mängel_stark',
#   'rund_euro',
#   'reguläre_porsche',
#   'porsche_cayenne',
#   'cayenne_bekommt',
#   'allradler_gts',
#   'palais_het',
#   'het_loo',
#   'heck_gibt',
#   'rückbank_versteckt',
#   'kleines_luftgitter',
#   'genannten_rückdrall',
#   'rückdrall_verhindert',
#   'möglichst_niedrige',
#   'niedrige_verbrauchszahlen',
#   'verbrauchszahlen_zielen',
#   'zielen_scheinen',
#   'spritfressenden_limousinen',
#   'aussterben_bedroht',
#   'beim_beschleunigen',
#   'beschleunigen_bemerkbar',
#   'preise_starten',
#   'überarbeitet_wurde',
#   'neue_mini',
#   'mini_macht',
#   'vorgängers_fortzusetzen',
#   'aufsteiger_juventus',
#   'juventus_turin',
#   'turin_siegte',
#   'siegte_dank',
#   'inzwischen_alessandro',
#   'alessandro_del',
#   'del_piero',
#   'atalanta_renault',
#   'renault_nämlich',
#   'nämlich_runde',
#   'ps_starken',
#   'starken_sportmodell',
#   'sportmodell_ab',
#   'geplante_verlängerung',
#   'hügeliger_herbstlandschaft',
#   'herbstlandschaft_präsentiert',
#   'wenig_beeindruckend',
#   'luftgefederte_drophead',
#   'frontpartie_gibt',
#   'dank_neu',
#   'neu_gestaltetem',
#   'gestaltetem_stoßfänger',
#   'stoßfänger_überarbeiteten',
#   'überarbeiteten_scheinwerfern',
#   'größeren_kühleröffnungen',
#   'kühleröffnungen_dynamisch',
#   'handwerkliche_qualität',
#   'immer_mehr',
#   'mehr_fahrzeughersteller',
#   'bedeutendsten_europäischen',
#   'europäischen_umrüster',
#   'behindertenfahrzeuge_führen',
#   'pfadfinder_pause',
#   'monitor_hindurchsehen',
#   'umsonst_jagt',
#   'eindrucksvollen_stunt',
#   'roten_rakete',
#   'rakete_entlang',
#   'weltpremiere_feiert',
#   'bedenken_macht',
#   'macht_google',
#   'google_seit',
#   'seit_mai',
#   'mai_gesichter',
#   'nummernschilder_unkenntlich',
#   'ergebnis_ps',
#   'ps_nm',
#   'spontanes_ansprechverhaltern',
#   'euro_liegen',
#   'ruth_bellotti',
#   'ganze_serie',
#   'tisch_stellen',
#   'suzuki_unterschiedliche',
#   'unterschiedliche_schwerpunkte',
#   'schwerpunkte_setzen',
#   'dabei_meint',
#   'wert_gelegt',
#   'mittelkonsole_elegant',
#   'rechts_ausschwingen',
#   'letzte_exemplar',
#   'band_lief',
#   'mehr_millionen',
#   'millionen_exemplaren',
#   'juni_mehr',
#   'millionen_ausgewertet',
#   'dadurch_versprechen',
#   'versprechen_beide',
#   'beide_hersteller',
#   'äußerst_spontanes',
#   'spontanes_ansprechverhalten',
#   'hoher_laufkultur',
#   'reihe_zwei',
#   'groß_gewachsene',
#   'gewachsene_passagiere',
#   'passagiere_ausreichend',
#   'ausreichend_platz',
#   'sechs_türen',
#   'verbraucht_liter',
#   'liter_diesel',
#   'schafft_stundenkilometer',
#   'stundenkilometer_spitze',
#   'audi_bastelt',
#   'bastelt_fleißig',
#   'sieben_gängen',
#   'vorteil_umweltfreunde',
#   'geld_verdient',
#   'kunden_gibt',
#   'vier_rädern',
#   'weitläufig_abgesperrten',
#   'abgesperrten_milliardärsenklave',
#   'riesigen_latifundien',
#   'sehen_bekommen',
#   'schon_dafür',
#   'dafür_zahlt',
#   'knapp_zehn',
#   'zehn_dollar',
#   'dollar_maut',
#   'jahre_alfa',
#   'alfa_romeo',
#   'romeo_standen',
#   'überall_wurde',
#   'wurde_geschrieben',
#   'geschichte_erneut',
#   'schubs_geben',
#   'ab_donnerstagmittag',
#   'donnerstagmittag_erwartet',
#   'adac_dichten',
#   'dichten_verkehr',
#   'darüber_hinaus',
#   'biogas_getankt',
#   'getankt_fährt',
#   'nürnberg_sitzen',
#   'sitzen_kinder',
#   'schutzgitter_immer',
#   'immer_geschlossen',
#   'minister_tiefensee',
#   'tiefensee_vorangetriebene',
#   'vorangetriebene_ökologische',
#   'ökologische_reinwaschung',
#   'reinwaschung_schwerer',
#   'schwerer_geländewagen',
#   'geländewagen_erfüllt',
#   'hamburg_renault',
#   'renault_läutet',
#   'franzosen_mehr',
#   'jahr_lang',
#   'lang_gar',
#   'offenes_auto',
#   'auto_mehr',
#   'neuen_mégane',
#   'außerdem_müssen',
#   'politiker_fürchterliche',
#   'fürchterliche_angst',
#   'angst_vorm',
#   'vorm_volk',
#   'gepanzerten_autos',
#   'straßen_getrauen',
#   'daher_empfehlen',
#   'franken_aufpreis',
#   'aufpreis_optional',
#   'optional_erhältlichen',
#   'erhältlichen_parksensoren',
#   'trotzdem_genießt',
#   'genießt_bmw',
#   'sachen_doppeltem',
#   'doppeltem_turbolader',
#   'turbolader_gesteuerten',
#   'gesteuerten_nebenaggregaten',
#   'nebenaggregaten_rückgewinnung',
#   'guten_ruf',
#   'millionen_testkilometer',
#   'testkilometer_wurden',
#   'wurden_absolviert',
#   'absolviert_drei',
#   'drei_mal',
#   'beim_vorgänger',
#   'vorgänger_sagt',
#   'sagt_entwicklungsvorstand',
#   'entwicklungsvorstand_thomas',
#   'thomas_weber',
#   'immer_mehr',
#   'mehr_hersteller',
#   'hersteller_brachen',
#   'einstigen_tabu',
#   'eigene_modellpalette',
#   'rs_wurde',
#   'iaa_präsentiert',
#   'recht_streng',
#   'sixt_müssen',
#   'kunden_mindestens',
#   'mindestens_jahre',
#   'jahre_alt',
#   'schon_seit',
#   'seit_zwei',
#   'zwei_jahren',
#   'führerschein_besitzen',
#   'datenblatt_weist',
#   'golf_gti',
#   'gti_kilometer',
#   'ende_april',
#   'spanischen_zwellinge',
#   'neuen_motoren',
#   'neuem_interieur',
#   'händlern_stehen',
#   'entsprechend_zahlreich',
#   'verschiedenste_systemausfälle',
#   'gepanzerte_limousine',
#   'zentrales_element',
#   'damals_wurden',
#   'wurden_fahrzeuge',
#   'fahrzeuge_ausgeliefert',
#   'großen_zeitlichen',
#   'zeitlichen_abstand',
#   'gleichen_werk',
#   'polnischen_tychy',
#   'band_läuft',
#   'kölner_genutzt',
#   'italienischen_kultwägelchen',
#   'kultwägelchen_abzugrenzen',
#   'lange_tradition',
#   'dänemark_plus',
#   'plus_prozent',
#   'prozent_finnland',
#   'finnland_plus',
#   'plus_prozent',
#   'prozent_schweden',
#   'schweden_plus',
#   'plus_sechs',
#   'sechs_prozent',
#   'schweiz_plus',
#   'plus_vier',
#   'vier_prozent',
#   'neuwagen_glänzende',
#   'glänzende_geschäfte',
#   'kourosh_mansory',
#   'testfahrt_geht',
#   'geht_holen',
#   'holen_mütter',
#   'haus_schuljungs',
#   'schuljungs_stehen',
#   'aufgerissenem_mund',
#   'hausfrauen_schütteln',
#   'schütteln_verständnislos',
#   'sperrigen_gegenständen',
#   'per_steuerknüppel',
#   'kleine_knauser',
#   'großen_bruder',
#   'passat_blue',
#   'blue_motion',
#   'sündhaft_teuren',
#   'teuren_einzelstücken',
#   'einzelstücken_darf',
#   'intensivster_erprobung',
#   'darf_gespannt',
#   'juke_reagieren',
#   'ersten_öffentlichen',
#   'öffentlichen_ausfahrt',
#   'durchschnittlichem_hubraum',
#   'euro_mehr',
#   'mehr_pro',
#   'pro_jahr',
#   'jahr_fällig',
#   'kostet_euro',
#   'euro_mehr',
#   'mehr_steuern',
#   'steuern_pro',
#   'pro_jahr',
#   'autos_bleiben',
#   'bleiben_dafür',
#   'dafür_immer',
#   'immer_öfter',
#   'seit_jahrzehnten',
#   'jahrzehnten_sinkt',
#   'verkehrstoten_stetig',
#   'museum_mobile',
#   'mobile_gleich',
#   'gleich_neben',
#   'heutigen_stammsitz',
#   'ausstellung_treffen',
#   'generationen_effizienz',
#   'usa_ging',
#   'wm_dagegen',
#   'dagegen_ruhmlos',
#   'hersteller_wählte',
#   'wählte_bewusst',
#   'bewusst_china',
#   'strategisch_wichtig',
#   'wichtig_eingestuft',
#   'arne_timm',
#   'gordian_gasch',
#   'steilheck_sieht',
#   'sieht_gar',
#   'bild_wirkt',
#   'fünftürer_stehen',
#   'gemeinsamen_basis',
#   'eigenen_angaben',
#   'bundestag_konzentrieren',
#   'sportlichste_variante',
#   'ab_sofort',
#   'sofort_bestellt',
#   'verbrauch_bzw',
#   'passat_übrigens',
#   'subaru_legacy',
#   'legacy_diesel',
#   'bmw_schaffen',
#   'könnten_wohl',
#   'oben_angesprochenen',
#   'angesprochenen_defizite',
#   'kind_tatsächlich',
#   'künstler_steckt',
#   'talente_vorhanden',
#   'chancen_gut',
#   'ziehen_lassen',
#   'beim_stopp',
#   'ampel_geht',
#   ...],
#  'keyword/news_text100k.txt': ['jahre_arbeiterkammer',
#   'arbeiterkammer_bedeuten',
#   'bedeuten_jahre',
#   'jahre_einsatz',
#   'soziale_gerechtigkeit',
#   'referendum_lagen',
#   'bayerischen_exporte',
#   'milliarden_euro',
#   'big_aggregierte',
#   'aggregierte_spitzenmietpreiswachstum',
#   'geringer_abschwächung',
#   'abschwächung_anhalten',
#   'wichtiger_schritt',
#   'davis_geht',
#   'geht_angesichts',
#   'herrschenden_kapitalistischen',
#   'kapitalistischen_produktionsweise',
#   'produktionsweise_zudem',
#   'zudem_davon',
#   'sämtliche_formen',
#   'formen_unproduktiver',
#   'unproduktiver_arbeit',
#   'herrschenden_klasse',
#   'klasse_entlohnt',
#   'aas_as',
#   'aktuellen_arbeiten',
#   'fleher_brücke',
#   'ende_abgeschlossen',
#   'zwei_spuren',
#   'spuren_pro',
#   'pro_fahrtrichtung',
#   'a_renzenhof',
#   'schweren_verkehrsunfall',
#   'fünf_verletzten',
#   'verletzten_darunter',
#   'gestrigen_sonntagabend',
#   'autobahnkreuz_nürnberg',
#   'nürnberg_gekommen',
#   'aachener_gastronomen',
#   'gastronomen_verlieren',
#   'aaron_lahl',
#   'lahl_verdeutlicht',
#   'beitrag_analyzing',
#   'analyzing_queer',
#   'antke_engel',
#   'engel_inwiefern',
#   'queere_psychoanalyse',
#   'klassischen_psychoanalyse',
#   'psychoanalyse_komplett',
#   'komplett_entkernt',
#   'emanzipatorisches_potential',
#   'gegenteil_verkehrt',
#   'aaron_purschwitz',
#   'purschwitz_m',
#   'm_sicherte',
#   'trotz_platz',
#   'platz_zwei',
#   'weitsprung_meter',
#   'ab_mai',
#   'mai_dürfen',
#   'dürfen_cafés',
#   'restaurants_öffnen',
#   'kundschaft_ausserhalb',
#   'ausserhalb_bedienen',
#   'ab_uhr',
#   'drei_minuten',
#   'leben_ruhen',
#   'menschen_gedacht',
#   'getötet_verletzt',
#   'traumatisiert_worden',
#   'ab_uhr',
#   'neuen_informieren',
#   'ab_dezember',
#   'dezember_sollen',
#   'ausgangsbeschränkungen_fallen',
#   'fallen_kinos',
#   'kinos_theater',
#   'ab_juni',
#   'komplett_offen',
#   'ab_uhr',
#   'mahntafeln_übergeben',
#   'ab_galt',
#   'festgelegt_wurde',
#   'berittene_männer',
#   'männer_drei',
#   'drei_wachen',
#   'doktor_befinden',
#   'befinden_mussten',
#   'ab_uhr',
#   'uhr_stehen',
#   'fk_shakhtar',
#   'shakhtar_donetsk',
#   'donetsk_gegenüber',
#   'ab_mai',
#   'mai_dürfen',
#   'innenbereich_sowie',
#   'schrittweise_öffnen',
#   'ab_wurden',
#   'wurden_etliche',
#   'konzentrationslager_verschleppt',
#   'drei_stöckige',
#   'stöckige_hochhäuser',
#   'ab_dezember',
#   'dezember_tritt',
#   'neue_verordnung',
#   'ab_uhr',
#   'uhr_liest',
#   'freitag_februar',
#   'februar_johannes',
#   'johannes_twaroch',
#   'ab_juli',
#   'touristen_öffnen',
#   'ab_juni',
#   'juni_gilt',
#   'fürs_parken',
#   'ab_mai',
#   'mai_sollen',
#   'geschäfte_friseure',
#   'einkaufszentren_öffnen',
#   'öffnen_ebenfalls',
#   'strengen_auflagen',
#   'ab_märz',
#   'märz_senken',
#   'senken_viele',
#   'viele_versicherungen',
#   'ab_oktober',
#   'berechnung_herangezogen',
#   'herangezogen_weiß',
#   'weiß_nikola',
#   'nikola_junick',
#   'ab_september',
#   'september_ziehen',
#   'ersten_bewohner',
#   'ab_uhr',
#   'uhr_live',
#   'ab_gibt',
#   'rund_neun',
#   'neun_millionen',
#   'millionen_autofahrer',
#   'autofahrer_neue',
#   'neue_regionalklassen',
#   'ab_solle',
#   'neuer_dienst',
#   'dienst_eingeführt',
#   'markt_langsam',
#   'langsam_erholen',
#   'inländischer_produktion',
#   'produktion_umgestellt',
#   'ab_uhr',
#   'uhr_erreichte',
#   'himmels_willen',
#   'ersten_millionen',
#   'millionen_prozent',
#   'krankenhausserie_wollten',
#   'freundschaft_millionen',
#   'millionen_prozent',
#   'prozent_sehen',
#   'ab_uhr',
#   'uhr_sahen',
#   'sahen_millionen',
#   'millionen_zuschauer',
#   'episode_leuchtfeuer',
#   'ab_dezember',
#   'zwei_teststraßen',
#   'etwa_soldatinnen',
#   'standort_linz',
#   'oberösterreich_betrieben',
#   'ab_februar',
#   'februar_geht',
#   'alias_meyer',
#   'meyer_offerman',
#   'ab_märz',
#   'märz_läuft',
#   'läuft_immer',
#   'immer_montags',
#   'neue_feuer',
#   'ab_uhr',
#   'uhr_dürften',
#   'dürften_restaurants',
#   'mehr_geöffnet',
#   'ab_mai',
#   'mai_empfängt',
#   'beliebte_urlaubsregion',
#   'ab_juli',
#   'vorstandsmitglied_renko',
#   'renko_dirksen',
#   'vorstands_koordinieren',
#   'koordinieren_teilte',
#   'ab_september',
#   'september_reist',
#   'reist_oscarpreisträgerin',
#   'oscarpreisträgerin_hilary',
#   'hilary_swank',
#   'swank_million',
#   'million_dollar',
#   'dollar_baby',
#   'ab_euro',
#   'ab_uhr',
#   'uhr_schunkelten',
#   'ab_uhr',
#   'bahnhof_köln',
#   'köln_evakuiert',
#   'evakuiert_ab',
#   'zugverkehr_unterbrochen',
#   'ab_anfang',
#   'anfang_übernimmt',
#   'übernimmt_bremen',
#   'ab_april',
#   'april_gilt',
#   'kreis_tempo',
#   'paar_weitere',
#   'weitere_quartierstrassen',
#   'tempo_drosselt',
#   'ab_april',
#   'april_plant',
#   'plant_signa',
#   'vorbereitenden_maßnahmen',
#   'ab_april',
#   'flugabwehrsysteme_einsatzbereit',
#   'abarhoun_bestritt',
#   'bestritt_trotz',
#   'erkrankung_partien',
#   'letzten_saison',
#   'traf_dabei',
#   'dabei_zweimal',
#   'ab_august',
#   'august_fährt',
#   'twin_city',
#   'city_liner',
#   'trotz_umsatzeinbussen',
#   'hoher_flughöhe',
#   'ab_ca',
#   'teilnehmer_spürbar',
#   'partie_offen',
#   'offen_gestalten',
#   'rafael_czichos',
#   'baumgartner_kam',
#   'österreicher_fiel',
#   'referee_daniel',
#   'daniel_siebert',
#   'falschwerweise_strafstoß',
#   'strafstoß_entschied',
#   'abdallah_macht',
#   'beruf_spaß',
#   'august_steht',
#   'sportvereine_zudem',
#   'möglichkeit_vereinseigene',
#   'vereinseigene_sporthallen',
#   'sporthallen_bzw',
#   'november_startet',
#   'clubs_darunter',
#   'ehc_red',
#   'red_bull',
#   'bull_münchen',
#   'dezember_lockert',
#   'kanton_wallis',
#   'genauso_erfolgreich',
#   'erfolgreich_weitergehen',
#   'märz_stieg',
#   'durchgeführten_tests',
#   'tests_stark',
#   'vier_tagen',
#   'märz_wurden',
#   'schnitt_menschen',
#   'menschen_getestet',
#   'juli_dürfen',
#   'dürfen_kunden',
#   'kunden_geschäfte',
#   'begleitung_besuchen',
#   'ride_angebot',
#   'stadt_kostenlos',
#   'oktober_fällt',
#   'september_tritt',
#   'mai_kommen',
#   'kommen_je',
#   'ersten_lockerungen',
#   'bahnhof_gösing',
#   'gösing_führt',
#   'kraftwerk_stierwaschboden',
#   'heutigen_mittwoch',
#   'mittwoch_dezember',
#   'dezember_gilt',
#   'elektronische_zeitschriften',
#   'ermäßigte_mehrwertsteuersatz',
#   'jahr_sollen',
#   'neuen_ölheizkessel',
#   'ölheizkessel_mehr',
#   'mehr_aufgestellt',
#   'kommenden_jahr',
#   'spanier_carlos',
#   'carlos_sainz',
#   'sainz_anstelle',
#   'kommenden_januar',
#   'januar_gibt',
#   'pro_krankheitsfall',
#   'krankheitsfall_drei',
#   'drei_tage',
#   'tage_bezahlten',
#   'bezahlten_urlaub',
#   'kommenden_montag',
#   'betrieb_aufnehmen',
#   'ab_pfingsten',
#   'bestimmten_auflagen',
#   'kommenden_wochenende',
#   'wochenende_fahren',
#   'fahren_nachts',
#   'busse_mehr',
#   'südwesthälfte_sowie',
#   'bergland_einzelne',
#   'einzelne_schauer',
#   'schauer_möglich',
#   'siebten_monat',
#   'beziehungsweise_prozent',
#   'lohns_geben',
#   'altersklasse_wurden',
#   'regionsmeisterschaften_ausgetragen',
#   'zweiten_klasse',
#   'differenzierte_beurteilung',
#   'beurteilung_je',
#   'standard_vorgesehen',
#   'kind_gerecht',
#   'ab_dezember',
#   'dezember_gibt',
#   'homepage_kurze',
#   'kurze_videos',
#   'fachschaften_vorstellen',
#   'ab_dienstag',
#   'dienstag_beginnt',
#   'union_berlin',
#   'ab_dienstag',
#   'schweizweit_restaurants',
#   'sportbetriebe_geschlossen',
#   'ab_dienstag',
#   'öffentliche_leben',
#   'leben_drastisch',
#   'drastisch_heruntergefahren',
#   'wochenende_dürfen',
#   'deutlich_mehr',
#   'mehr_zuschauer',
#   'geschäften_verboten',
#   'etwa_kilometer',
#   'kilometer_transportleitung',
#   'ortsteilen_anschließen',
#   'ab_donnerstag',
#   'donnerstag_september',
#   'september_bricht',
#   'gemeinsamen_exkursionen',
#   'ab_donnerstag',
#   'bilder_sehen',
#   'oktober_entstanden',
#   'ab_donnerstag',
#   'donnerstag_steigen',
#   'temperaturen_jedoch',
#   'ab_donnerstag',
#   'insgesamt_zehn',
#   'zehn_weiteren',
#   'weiteren_staaten',
#   'staaten_untersagt',
#   'abdul_azim',
#   'azim_akanga',
#   'akanga_fügte',
#   'jedoch_nahtlos',
#   'dennis_gilke',
#   'gilke_rückte',
#   'offensivmann_hegel',
#   'abdullah_spricht',
#   'beanstandete_rund',
#   'rund_stimmen',
#   'bestimmten_inzidenzwert',
#   'ausgangsbeschränkungen_erlassen',
#   'euro_entwickelte',
#   'deutschen_urlauberpaar',
#   'wahrer_fan',
#   'wolfgangsees_deklarierte',
#   'älteren_frau',
#   'zweiten_reihe',
#   'kreisfreie_stadt',
#   'zurzeit_köln',
#   'köln_solingen',
#   'seit_gestern',
#   'direkter_nachbarschaft',
#   'bestimmten_länge',
#   'länge_könnten',
#   'womöglich_vergiften',
#   'neuinfektionen_pro',
#   'pro_einwohner',
#   'einwohner_innerhalb',
#   'sieben_tagen',
#   'sogenannten_zusätzliche',
#   'zusätzliche_einschränkungen',
#   'einschränkungen_geben',
#   'einzelfall_entschieden',
#   'entschieden_klassen',
#   'trennen_vorher',
#   'vorher_ab',
#   'sowohl_drinnen',
#   'draußen_maximal',
#   'maximal_personen',
#   'personen_zulässig',
#   'zuständige_behörde',
#   'behörde_lässt',
#   'lässt_ausnahmen',
#   'ab_einmündung',
#   'einmündung_untere',
#   'untere_wiesenstraße',
#   'wiesenstraße_entlang',
#   'neue_decke',
#   'ab_ende',
#   'ende_august',
#   'august_ging',
#   'kurs_kontinuierlich',
#   'kontinuierlich_abwärts',
#   'freitag_erreichte',
#   'tiefsten_stand',
#   'stand_seit',
#   'seit_anfang',
#   'anfang_august',
#   'ab_ende',
#   'ende_august',
#   'august_sollen',
#   'thinkpad_p',
#   'thinkpad_p',
#   'thinkpad_pgenund',
#   'völlig_neue',
#   'neue_thinkpad',
#   'thinkpad_p',
#   'p_verfügbar',
#   'abendfüllendes_thema',
#   'nächsten_sitzung',
#   'kommenden_montag',
#   'zeller_gemeinderat',
#   'gemeinderat_ausschließlich',
#   'themenkomplex_innenstadtentwicklung',
#   'stadtmarketing_beschäftigen',
#   'abends_feiern',
#   'feiern_eva',
#   'eva_klingler',
#   'wolfgang_wegner',
#   'rotlichtkönigin_margarete',
#   'margarete_reinhardt',
#   'abends_rief',
#   'kinderärztin_sogar',
#   'abendstimmung_ende',
#   'ende_september',
#   'uhr_beim',
#   'beim_kraftwerk',
#   'kraftwerk_birsfelden',
#   'lokal_praktisch',
#   'praktisch_leer',
#   'nie_erlebt',
#   'ganz_regnen',
#   'mark_twains',
#   'twains_tom',
#   'tom_sawyer',
#   'huckleberry_finn',
#   'finn_verwandelt',
#   'abenteuer_pur',
#   'pur_erlebten',
#   'alpinen_skirennfahrer',
#   'projekt_eh',
#   'eh_eingestellt',
#   'abgesehen_davon',
#   'davon_wusste',
#   'schmiergelder_geflossen',
#   'klar_davon',
#   'davon_distanzieren',
#   'tönungen_beginnst',
#   'denen_nahe',
#   'kopfhaut_meist',
#   'meist_mehr',
#   'mehr_zeit',
#   'zeit_brauchen',
#   'komplett_aufgehellt',
#   'videokonferenzen_remote',
#   'remote_desktop',
#   'anschlusses_bedeutsam',
#   'regionen_seien',
#   'aktivistin_johanna',
#   'johanna_fuoß',
#   'tierschutzorganisation_peta',
#   'peta_kritisiert',
#   'lebendrupf_trotzdem',
#   'aktuell_weiß',
#   'betroffenen_bekommen',
#   'entrichteten_beiträge',
#   'beiträge_rückwirkend',
#   'rückwirkend_erstattet',
#   'vorhandenen_material',
#   'maximum_herausholen',
#   'späteren_einschränkungen',
#   'einschränkungen_akut',
#   'akut_betroffener',
#   'betroffener_bürger',
#   'natürlich_gedanken',
#   'gedanken_gemacht',
#   'situation_reagiert',
#   'reagiert_hätte',
#   'rund_drei',
#   'drei_wochen',
#   'telefon_klingelte',
#   'marc_lüthi',
#   'lüthi_meldete',
#   'jobangebot_komplett',
#   'komplett_unerwartet',
#   'unerwartet_kam',
#   'andererseits_fällt',
#   'kaum_zwei',
#   'zwei_wochen',
#   'strengen_kontaktbeschränkungen',
#   'sicher_genug',
#   'raum_spielen',
#   'gesunkenen_zinsen',
#   'zinsen_entstünden',
#   'gesamte_laufzeit',
#   'laufzeit_nominale',
#   'nominale_mehrkosten',
#   'vier_milliarden',
#   'milliarden_euro',
#   'geraden_sei',
#   'große_rückstand',
#   'vfb_stuttgart',
#   'erneuten_aufstieg',
#   'aufstieg_dennoch',
#   'bibel_steht',
#   'angst_sei',
#   'gesund_fürs',
#   'fürs_geschäft',
#   'schnell_ersichtlich',
#   'rapper_relativ',
#   'relativ_klassische',
#   'klassische_werdegang',
#   'gar_untypischen',
#   'untypischen_künstler',
#   'künstler_hervorgebracht',
#   'anke_rothenpieler',
#   'rothenpieler_weiß',
#   'weiß_allein',
#   'beruflichen_hintergrund',
#   'schöner_artikel',
#   'top_drei',
#   'deutschen_boomen',
#   'politiker_äußerten',
#   'bestürzt_darüber',
#   'reichstag_zugetragen',
#   'lärmbelastung_bedenken',
#   'unterhaltsame_kommentare',
#   'fall_sei',
#   'digitalen_wegen',
#   'wegen_möchte',
#   'menschen_erreichen',
#   'genussvollem_essen',
#   'essen_näherbringen',
#   'reparatur_kaputter',
#   'kaputter_gegenstände',
#   'sowohl_bewohner',
#   'betriebe_profitieren',
#   'profitieren_sollten',
#   'sollten_gingen',
#   'grünen_auseinander',
#   'polizei_wandert',
#   'ergebnislosen_suche',
#   'gut_papendelle',
#   'größeren_ansturm',
#   'ansturm_sei',
#   'gut_gerüstet',
#   'kunden_gibt',
#   'bildung_wurde',
#   'wurde_vermittelt',
#   'mensch_mehr',
#   'mehr_hätte',
#   'zusehends_teuer',
#   'dabei_wirkt',
#   'ministerpräsident_armin',
#   'armin_laschet',
#   'söder_betont',
#   'vorsichtigen_kurs',
#   'damals_wurden',
#   'verhandlungen_fortgesetzt',
#   'anschläge_aufgegeben',
#   'sprecher_laut',
#   'laut_nachrichtenportal',
#   'nachrichtenportal_alef',
#   'sieben_punkten',
#   'punkten_aussichtsreich',
#   'punktlose_schlusslicht',
#   'schlusslicht_island',
#   'erfolgsaussichten_gewonnen',
#   'mehr_auszuschließen',
#   'interessante_mörderjägerinnen',
#   'mörderjägerinnen_hervorbringen',
#   'neue_hallenbad',
#   'vordermann_hält',
#   'plüderhausen_wiewohl',
#   'wiewohl_sauber',
#   'tiefer_taugt',
#   'verlassen_sollten',
#   'sollten_möglichst',
#   'möglichst_erfolgen',
#   'erfolgen_sowie',
#   'abstandsregeln_eingehalten',
#   'gute_alte',
#   'alte_panzerkette',
#   'panzerkette_erlebt',
#   'neuen_höhenflug',
#   'zarten_kettchen',
#   'verspielten_anhängern',
#   'anhängern_wobei',
#   'wobei_immer',
#   'immer_gleich',
#   'gleich_mehrere',
#   'mehrere_getragen',
#   'soziale_aspekt',
#   'absoluten_höhepunkte',
#   'wunderschön_schwärmt',
#   'schwärmt_sonja',
#   'sonja_huber',
#   'datenschutzeinstellungen_wurden',
#   'wurden_erheblich',
#   'erheblich_verbessert',
#   'donauwörther_seien',
#   'seien_vermehrt',
#   'heimat_unterwegs',
#   'unterwegs_berichtet',
#   'berichtet_steger',
#   'überzeugt_davon',
#   'erwartungen_erfüllen',
#   'gesellige_seite',
#   'seite_kommt',
#   'richterlich_angeordneten',
#   'angeordneten_nachzählungen',
#   'nachzählungen_ergaben',
#   'klares_bild',
#   'wochen_wusste',
#   'wusste_niemand',
#   'niemand_wer',
#   'nase_wirklich',
#   'wirklich_vorne',
#   'date_ok',
#   'halt_mal',
#   'hand_mann',
#   'mann_beschwert',
#   'distanzierten_schwimmigranten',
#   'hätte_trump',
#   'heutigem_stand',
#   'frage_bislang',
#   'bislang_unbeantwortet',
#   'eigentumsdelikte_stehen',
#   'bayerischen_ermittler',
#   'buch_übers',
#   'übers_gehört',
#   'umfangreichen_werk',
#   'jährigen_japaners',
#   'oft_schon',
#   'schon_genannt',
#   'genannt_wurde',
#   'engen_favoritenkreis',
#   'deutsches_forschungsinstitut',
#   'forschungsinstitut_findet',
#   'top_fünf',
#   'menge_falsch',
#   'gewissen_fatalismus',
#   'vermindertes_hörvermögen',
#   'hörvermögen_besonders',
#   'tiefen_frequenzen',
#   'frequenzen_sowie',
#   'sowie_beeinträchtigungen',
#   'kurzzeitgedächtnisses_müssen',
#   'müssen_letztlich',
#   'letztlich_beim',
#   'beim_design',
#   'software_berücksichtigt',
#   'ständig_beisammen',
#   'dokumentationen_dürften',
#   'kosten_kommen',
#   'ganz_schön',
#   'schön_sinnlos',
#   'sinnlos_denke',
#   'champagnerglas_nippe',
#   'größere_könnten',
#   'zweier_konzentrieren',
#   'konzentrieren_anstatt',
#   'durchschnittlich_gut',
#   'gut_besetzten',
#   'besetzten_vierer',
#   'sogenannten_göttersee',
#   'besser_später',
#   'später_begonnen',
#   'begonnen_hätte',
#   'eis_gelegt',
#   'inzwischen_deutliche',
#   'deutliche_spuren',
#   'spuren_hinterlassen',
#   'höhenflug_insbesondere',
#   'veranstaltungen_beschäftigen',
#   'beschäftigen_viele',
#   'viele_menschen',
#   'aargau_gibt',
#   'gewichtige_änderungen',
#   'neue_fahrplan',
#   'fahrplan_gilt',
#   'hauptquest_findet',
#   'vier_wochen',
#   'immer_erreichbar',
#   'bremer_vahr',
#   'vahr_verloren',
#   'zahlen_künftig',
#   'vorarlberg_wurden',
#   'wurden_unregelmäßigkeiten',
#   'unregelmäßigkeiten_aufgedeckt',
#   'sports_entschließen',
#   'immer_mehr',
#   'mehr_veranstalter',
#   'halten_sagt',
#   'sagt_peintinger',
#   'kanzleramtsminister_braun',
#   'ministerpräsident_kretschmer',
#   'kretschmer_setzen',
#   'zwang_freilich',
#   'freilich_explizit',
#   'explizit_auszuschließen',
#   'kleinere_systeme',
#   'fass_greift',
#   'hirnschädigungen_hervorrufen',
#   'medizinische_praxen',
#   'apotheken_kommen',
#   'kommen_infrage',
#   'autochthonen_trauben',
#   'saftigen_strukturierteren',
#   'strukturierteren_pinela',
#   'weiterführenden_literatur',
#   'literatur_gibt',
#   'teil_probleme',
#   'nackte_zahlen',
#   'fakten_spiegeln',
#   'jahres_wider',
#   'internationale_veranstaltungen',
#   'überraschendes_kam',
#   'antworten_heraus',
#   'bundesweiten_spitzenreiter',
#   'bayerischen_landkreis',
#   'landkreis_tirschenreuth',
#   'frage_wer',
#   'kanzler_lieber',
#   'lieber_wäre',
#   'wäre_scholz',
#   'effekte_wäre',
#   'skigebiet_deer',
#   'deer_valley',
#   'rocky_mountains',
#   'wahrer_hingucker',
#   'geschichten_kommen',
#   'populäre_publikumsfilme',
#   'bewegte_mann',
#   'gesellschaftssatire_rossini',
#   'mörderische_frage',
#   'frage_wer',
#   'wem_schlief',
#   'zahlreiche_episoden',
#   'tatort_finden',
#   'positive_personen',
#   'zweistelliger_zahl',
#   'quarantäne_entlassen',
#   'bewegen_appellierte',
#   'aktuelle_personal',
#   'personal_gibt',
#   'schon_fertiggestellte',
#   'fertiggestellte_projekte',
#   'projekte_könnten',
#   'könnten_weitere',
#   'weitere_unterstützung',
#   'unterstützung_gebrauchen',
#   'ankunft_erstmal',
#   'sollen_langsam',
#   'langsam_merken',
#   'wirksame_militanz',
#   'militanz_gerettet',
#   'bewegung_tun',
#   'tun_gut',
#   'unterschiedliche_meinungen',
#   'meinungen_gebe',
#   'nächste_mehrjährige',
#   'mehrjährige_finanzrahmen',
#   'verknüpfte_next',
#   'next_generation',
#   'generation_eu',
#   'eu_sowie',
#   'rechtsstaatlichkeitsdebatte_seien',
#   'sprache_gekommen',
#   'pauli_möchte',
#   'parteigenossen_schwindet',
#   'wahl_absolut',
#   'absolut_sicher',
#   'volle_reisefreiheit',
#   'dortigen_vorschriften',
#   'beste_reiseschutz',
#   'ort_bleiben',
#   'natur_genießen',
#   'beiden_seiten',
#   'stehplätzen_könnten',
#   'könnten_je',
#   'sitze_montiert',
#   'längere_sicht',
#   'frischen_wind',
#   'mehr_abwechslung',
#   'abwechslung_gesorgt',
#   'beide_maßnahmen',
#   'maßnahmen_bedeuten',
#   'bedeuten_natürlich',
#   'wirkliche_dramatik',
#   'zwei_prozent',
#   'prozent_völlig',
#   'völlig_ausreichend',
#   'derartigen_windböen',
#   'draußen_aufzuhalten',
#   'aufzuhalten_teilte',
#   'teilte_peter',
#   'peter_hinze',
#   'hinze_bürgermeister',
#   'wahl_trat',
#   'sogar_wahlen',
#   'wahlen_angepasst',
#   'ordentliche_rechtsprechung',
#   'rechtsprechung_erwarten',
#   'steigenden_strompreisen',
#   'konto_einzahlt',
#   'erklärte_thimm',
#   'politischen_gespräche',
#   'weitere_planung',
#   'berlin_legt',
#   'kracher_drauf',
#   'gestiegene_nachfrage',
#   'heimischen_baumärkten',
#   'besser_spät',
#   'bestimmte_produkte',
#   'gerne_platziert',
#   'august_losgeht',
#   'ordentlich_werbung',
#   'großen_liebe',
#   'bild_rettete',
#   'paar_jahre',
#   'jahre_dauern',
#   'niemand_positiv',
#   'coronavirus_getestet',
#   'getestet_worden',
#   'bislang_denkt',
#   'denkt_niemand',
#   'niemand_darüber',
#   'bislang_scheint',
#   'wirklich_selbstfahrenden',
#   'selbstfahrenden_auto',
#   'fahrers_sicher',
#   'sicher_fährt',
#   'anderweitig_benötigt',
#   'immer_mal',
#   'überraschung_gut',
#   'recalls_führte',
#   'borer_weiss',
#   'boom_schnell',
#   'schnell_vorbei',
#   'leben_ständig',
#   'ständig_worte',
#   'gedanken_einflüstert',
#   'grundmauern_baut',
#   'poetischen_daseins',
#   'merkwürdigste_krankheit',
#   'nachbarskinder_besser',
#   'besser_kennen',
#   'kennen_gelernt',
#   'weitere_kopie',
#   'kopie_erwartet',
#   'erwartet_spricht',
#   'ungewöhnliche_wahl',
#   'fortsetzung_übertragen',
#   'übertragen_wurde',
#   'ja_wohl',
#   'pipeline_geben',
#   'beleidigung_strafbar',
#   'zeugen_stattfinden',
#   'stattfinden_siehe',
#   'siehe_artikel',
#   'artikel_rechts',
#   'hohe_medizinische',
#   'medizinische_verantwortung',
#   'richtige_risikoeinschätzung',
#   'einst_vier',
#   'vier_hinüberretten',
#   'absolute_chaos',
#   'chaos_ausbricht',
#   'nützlicher_hack',
#   'zukünftigen_überfüllungen',
#   'überfüllungen_vorzubeugen',
#   'führung_verliert',
#   'verliert_müsste',
#   'wahlen_schon',
#   'schlecht_abschneiden',
#   'danach_verlor',
#   'breiten_aufstellung',
#   'vorquartal_sowie',
#   'besseren_entwicklung',
#   'linde_überraschend',
#   'überraschend_gut',
#   'dritte_quartal',
#   'quartal_gekommen',
#   'geht_s',
#   's_richtig',
#   'lage_innerhalb',
#   'innerhalb_kürzester',
#   'kürzester_zeit',
#   'halt_einfach',
#   'gasse_hochfahren',
#   'cobblehopple_lebt',
#   'depressionen_zurück',
#   'kam_plötzlich',
#   'bühne_getanzt',
#   'zwei_identischen',
#   'identischen_tore',
#   'tore_beide',
#   'beide_vorgelegt',
#   'halles_vucur',
#   'dinge_transportieren',
#   'transportieren_müsse',
#   'siegfrieds_kühns',
#   'kühns_schwarzweiß',
#   'farbe_mitwirken',
#   'felgenraten_gespielt',
#   'felge_gehört',
#   'wurde_corona',
#   'corona_immer',
#   'immer_intensiver',
#   'text_ständig',
#   'ständig_umgeschrieben',
#   'erfolgreich_genug',
#   'passieren_dürfen',
#   'bewusstsein_dafür',
#   'dafür_wachse',
#   'jahreswechsel_gesehen',
#   'ersten_monaten',
#   'schief_gelaufen',
#   'kleiner_erster',
#   'erster_schritt',
#   'sport_einfach',
#   'kalkulierbar_darauf',
#   'darauf_hoffen',
#   'richtig_spaß',
#   'falsche_art',
#   'neuen_wetterbedingungen',
#   'wetterbedingungen_gewöhnt',
#   'ganze_bild',
#   'bild_interessanterweise',
#   'interessanterweise_gab',
#   'erfolgreiche_unterrichtsmethode',
#   'namen_wechselseitiger',
#   'wechselseitiger_unterricht',
#   'eigentlich_ganz',
#   'ganz_typisch',
#   'hauptmann_bratges',
#   'bratges_größte',
#   'größte_sorge',
#   'derzeit_meint',
#   'schon_okay',
#   'hochgebirge_innerhalb',
#   'leicht_abschalten',
#   'abschalten_besinnen',
#   'konzept_bewährt',
#   'immer_fiktiv',
#   'hemmungslos_albern',
#   'einzelne_hervorholen',
#   'sport_sowieso',
#   'sowieso_immer',
#   'immer_weiß',
#   'weiß_schild',
#   'zahlen_allein',
#   'welt_erklären',
#   'passt_ja',
#   'gewissen_freilauf',
#   'freilauf_gewährt',
#   'umfeld_dabei',
#   'grosseltern_schützt',
#   'schützt_halte',
#   'mannschaft_zulost',
#   'halle_dasteht',
#   'lustige_anekdote',
#   'schlimmstenfalls_besorgniserregend',
#   'rechter_trost',
#   'indischen_hauptstadt',
#   'art_abrechnung',
#   'abrechnung_macht',
#   'macht_wusste',
#   'jahre_alte',
#   'alte_schulden',
#   'schulden_interessieren',
#   'ausgeschlossen_gelten',
#   'tag_ändern',
#   'parlament_weitgehend',
#   'weitgehend_ausgeschaltet',
#   'unangenehme_folgen',
#   'tochter_getrennt',
#   'steht_meistens',
#   'offenen_seiten',
#   'seiten_gehabt',
#   ...],
#  'keyword/sport_50k.txt': ['freitag_ja',
#   'fantastische_atmosphäre',
#   'ganz_schnell',
#   'fehlern_lernen',
#   'beliebten_erythropoetin',
#   'erythropoetin_epo',
#   'epo_erhöht',
#   'blutdruck_sowie',
#   'roten_blutkörperchen',
#   'blutes_führt',
#   'kanada_bekommen',
#   'serie_b',
#   'saison_treu',
#   'treffern_maßgeblich',
#   'direkten_wiederaufstieg',
#   'wiederaufstieg_beteiligt',
#   'wesentlich_effektiver',
#   'gegenerischen_tor',
#   'fv_biberach',
#   'beide_ergebnisse',
#   'ergebnisse_flossen',
#   'karabatic_viele',
#   'viele_jahre',
#   'gelbhemden_spielen',
#   'sieger_hamilton',
#   'räikkönen_links',
#   'münchen_mehr',
#   'tun_bekomme',
#   'groß_erklärt',
#   'skg_walldorf',
#   'walldorf_behauptete',
#   'eintracht_rsselsheim',
#   'mannschaftsbesprechung_anberaumt',
#   'fc_chelsea',
#   'diverse_verletzte',
#   'verletzte_spieler',
#   'spieler_verzichten',
#   'verkürzte_salomon',
#   'salomon_kalou',
#   'kalou_zwischenzeitlich',
#   'anschließenden_pressekonferenz',
#   'großen_schweigen',
#   'jahren_wurde',
#   'traum_wahr',
#   'wahr_russland',
#   'russland_besiegte',
#   'einstigen_bundestrainer',
#   'bundestrainer_wirkte',
#   'dritten_platz',
#   'rallye_japan',
#   'japan_sicherte',
#   'jahre_alte',
#   'alte_franzose',
#   'sapporo_vorzeitig',
#   'trainer_ottmar',
#   'ottmar_hitzfeld',
#   'berlin_suspendiert',
#   'hinterher_sagen',
#   'sagen_okay',
#   'weiteren_punkt',
#   'champions_league',
#   'league_geholt',
#   'maria_riesch',
#   'ersten_podestplatz',
#   'podestplatz_eingefahren',
#   'wettkampf_erhhen',
#   'trainingstechnischer_sicht',
#   'sicht_sinnvoll',
#   'frau_meuli',
#   'meuli_mountainbikenatitrainerin',
#   'mountainbikenatitrainerin_obwohl',
#   'ja_snowboarderin',
#   'klubbesitzer_porcedda',
#   'alessandro_menarini',
#   'menarini_suchen',
#   'suchen_demnach',
#   'timo_gebhart',
#   'alexander_hleb',
#   'harmlosen_nie',
#   'nie_gefährdet',
#   'impfstoff_bekommen',
#   'spielern_sicher',
#   'sicher_anbieten',
#   'trikot_kaufen',
#   'kaufen_darum',
#   'vorschlag_gemacht',
#   'sven_butenschön',
#   'butenschön_angeschlagen',
#   'neuzugang_prestin',
#   'prestin_ryan',
#   'ryan_bereits',
#   'ersten_kommen',
#   'primera_division',
#   'führung_gegangen',
#   'bayer_leverkusen',
#   'pokalfinale_erreicht',
#   'plötzlich_hieß',
#   'internetanbieter_bruno',
#   'bruno_labbadia',
#   'kaiserslautern_wechseln',
#   'roggisch_dennoch',
#   'rund_seiten',
#   'uci_weitergeleitet',
#   'kevin_kuranyi',
#   'bislang_wurde',
#   'trio_bestehend',
#   'gareth_barry',
#   'barry_mio',
#   'mio_roque',
#   'roque_santa',
#   'santa_cruz',
#   'cruz_mio',
#   'carlos_tevez',
#   'tevez_mio',
#   'mio_verpflichtet',
#   'wichtiger_schritt',
#   'innen_fehlt',
#   'dichten_tennisatmosphäre',
#   'gäste_drängten',
#   'weite_strecken',
#   'ersten_satz',
#   'entscheidend_davon',
#   'singh_siegte',
#   'millionen_dotierten',
#   'dotierten_turnier',
#   'australier_adam',
#   'adam_scott',
#   'südafrikaner_trevor',
#   'trevor_immelmann',
#   'hugo_almeida',
#   'almeida_erzielte',
#   'entscheidende_tor',
#   'thomas_becker',
#   'zweitbester_bonner',
#   'bonner_korbjäger',
#   'bayern_braucht',
#   'zeit_werder',
#   'abfahrt_vermissen',
#   'vermissen_erzählt',
#   'erzählt_büchel',
#   'platini_kritisiert',
#   'ukraine_eigentlich',
#   'em_abgehakt',
#   'klappt_sagte',
#   'wieskötter_potsdam',
#   'siegtreffer_besorgte',
#   'besorgte_schließlich',
#   'schließlich_schmidt',
#   'fünf_metern',
#   'metern_einschoss',
#   'ehemaligen_mannschaftsärzte',
#   'mannschaftsärzte_lothar',
#   'lothar_heinrich',
#   'andreas_schmid',
#   'schmid_laufen',
#   'arjen_robben',
#   'robben_macht',
#   'lustig_liebt',
#   'familiäre_atmosphäre',
#   'bayern_schätzt',
#   'trainer_van',
#   'van_gaal',
#   'gaal_wirklich',
#   'wirklich_tickt',
#   'neue_vorsitzende',
#   'vorsitzende_gerhard',
#   'gerhard_keul',
#   'keul_steinau',
#   'herren_eröffne',
#   'eröffne_hiermit',
#   'neuen_kommentare',
#   'heute_aben',
#   'deutschen_lager',
#   'platz_zwei',
#   'zwei_dafür',
#   'dafür_empfehlen',
#   'empfehlen_müssen',
#   'bunjaku_rückt',
#   'rückt_voraussichtlich',
#   'voraussichtlich_mike',
#   'mike_frantz',
#   'entscheidende_schlag',
#   'turniersieg_sagte',
#   'sagte_slocum',
#   'times_online',
#   'englische_medien',
#   'medien_melden',
#   'michael_ballacks',
#   'ballacks_club',
#   'club_fc',
#   'fc_chelsea',
# ...
#   'quartalsweise_milliarden',
#   'milliarden_schnorrt',
#   'reker_beugt',
#   'scharia_schafft',
#   'frauen_sicherheitszonen',
#   'sicherheitszonen_=fluchtpunkte',
#   '=fluchtpunkte_flüchtlinge',
#   'flüchtlinge_köln',
#   'köln_massenvergewaltigungen',
#   'massenvergewaltigungen_maischberger',
#   'maischberger_liefers',
#   'achten_frauen',
#   'paradies_hier.lasche',
#   'hier.lasche_strafen',
#   'vergewaltigungen_perlen',
#   'redaktionskonferenz_heute',
#   'heute_idee',
#   'dresden_islamisierung',
#   'muslime_nopegida',
#   'nopegida_nolegida',
#   'pegida_stehen',
#   'stehen_schulter',
#   'zähnen_bewaffnet',
#   'rapefugees_schauhin',
#   'schauhin_merkel',
#   'merkel_rechnet',
#   'mio_neuen',
#   'neuen_asylanten',
#   'vergleich_schätzung',
#   'dank_cdu',
#   'schwarzen_burkas',
#   'rapefugees_schade',
#   'frei_-nicht',
#   '-nicht_mehr',
#   'europa_deutschland',
#   'deutschland_sophienhof',
#   'sophienhof_koelnbhf',
#   'koelnbhf_merkelmussweg',
#   'merkelmussweg_islamisierung',
#   'islamisierung_flüchtlingskrise',
#   'flüchtlingskrise_wer',
#   'deutsche_arbeitslose',
#   'selben_finanz',
#   'mittel_fordert',
#   'asylanten_zukommen',
#   'gutmenschen_vegetarier',
#   'vegetarier_veganer',
#   'tierschützer_eigentlich',
#   'halal_-schlachtung',
#   'asylanten_flüchtlinge',
#   'rapefugees_nutzt',
#   'nutzt_kritisiert',
#   'inthebox_patridiot',
#   'na_toll',
#   'afd_wähler',
#   'wähler_sollen',
#   'mehr_grund',
#   'rapefugees_maischberger',
#   'maischberger_laschet',
#   'laschet_pegida',
#   'pegida_gibts',
#   'westen_nicht.leute',
#   'nicht.leute_trauen',
#   'mitzulaufen_wegen',
#   'wegen_ächtung',
#   'umso_realer',
#   'realer_dor',
#   'dor_beateuhse',
#   'beateuhse_fördert',
#   'fördert_scharia',
#   'internet-sexshop_el',
#   'el_asira',
#   'niederlanden_danke',
#   'danke_clausnitz',
#   'seid_helden',
#   'sos_rapefugees',
#   'rapefugees_koelnhbf',
#   'koelnhbf_cologne',
#   'cologne_islamisierung',
#   'westdeutschland_danke',
#   'hartaberfair_gesagt',
#   'gesagt_brechen',
#   'ausbildung_ab.afd',
#   'ab.afd_asylanten',
#   'asylanten_betteln',
#   'asylbewerber_fluechtlinge',
#   'fluechtlinge_asylum',
#   'weils_mal',
#   'mal_gesagt',
#   'gesagt_wurde',
#   'falsch_ab',
#   'flüchtlinge_mehr',
#   'refugeesnotwelcome_flüchtlingen',
#   'sofort_gratis',
#   'gratis_villen',
#   'villen_autos',
#   'autos_auszuhändigen',
#   'hungerstreik_rapefugees',
#   'rapefugees_könnten',
#   'kriminelle_loswerden',
#   'beherrschbare_zahlen',
#   'zahlen_runtergehen',
#   'asylanten_wohl',
#   'wohl_mitbekommen',
#   'linke_gutmenschen',
#   'gutmenschen_antifa',
#   'deutsche_nation',
#   'nation_zerstören',
#   'deutsche_europäische',
#   'europäische_geschichte',
#   'geschichte_tradition',
#   'tradition_bräuche',
#   'bräuche_sprache',
#   'sprache_leben',
#   'leben_lehren',
#   'hartaberfair_oecd',
#   'oecd_schätzt',
#   'schätzt_wachstum',
#   'nächsten_jahren',
#   'asylanten_außer',
#   'spd_afd',
#   'spd_afd',
#   'afd_bereicherung',
#   'bereicherung_flüchtlinge',
#   'flüchtlinge_spd',
#   'spd_islamisierung',
#   'deutschlandradio_kultur',
#   'kultur_erfahren',
#   'islam_gg',
#   'frauenfreundlichere_relion',
#   'islamisierung_pegida',
#   'pegida_ca',
#   'syrer_fliehen',
#   'warum_kämpft',
#   'refugeesnotwelcome_fluechtlinge',
#   'ard_+ein',
#   '+ein_zdfspezial',
#   'thema_handgranate',
#   'maas_kretschmann',
#   'kretschmann_asylanten',
#   'asylanten_integrierte',
#   'abgeschoben_illegale',
#   'illegale_täter',
#   'täter_dürfen',
#   'dürfen_bleiben',
#   'wieso_läuft',
#   'refugeescrisis_islam',
#   'islam_rapefugees',
#   'rapefugees_liebe',
#   'liebe_gutmenschen',
#   'einzelfall_asylanten',
#   'immer_mehr.kiel',
#   'mehr.kiel_sophienhof',
#   'armen_asylanten.afd',
#   'asylanten.afd_frankreich',
#   'frankreich_sagt',
#   'asylanten_aufnehmenund',
#   'seit_jahresbeginn',
#   'jahresbeginn_schon',
#   'merkel_verpiss',
#   'warum_spendet',
#   'spendet_hoaxmap',
#   'asylanten_passiert',
#   'schlimmste_krise',
#   'scheiße_findet',
#   'findet_warum',
#   'warum_wollt',
#   'möglichst_vielen',
#   'vielen_asylanten',
#   'asylanten_zumuten',
#   'totalitären_ideologie',
#   'gesellschaft_anzuheizen',
#   'anzuheizen_taqqiya',
#   'taqqiya_abmerkeln',
#   'abmerkeln_deutschland',
#   'zwangsmigration_aufzwingen.das',
#   'aufzwingen.das_geht',
#   'afd_hartaberfair',
#   'blog_glaube',
#   'get_rid',
#   'rid_of',
#   'of_islam',
#   'islam_muslims',
#   'muslims_rapefugees',
#   'rapefugees_deutschland',
#   'staatlichkeit_aufgegeben',
#   'fugen_gehoben',
#   'irrsinn_islamisierung',
#   'islamisierung_cdu',
#   'cdu_hartaberfair',
#   'hartaberfair_ifo-chef',
#   'ifo-chef_sinn',
#   'sinn_warnt',
#   'flüchtling_kostet',
#   'kostet_deutschland',
#   'asylanten_warum',
#   'warum_wurde',
#   'polizei_aufgelöst',
#   'flüchtlinge_flüchtlingskrise',
#   'flüchtlingskrise_asylanten',
#   'asylanten_ungarn',
#   'volksabstimmung_durchführen',
#   'refugeesnotwelcome_seit',
#   'seit_beginn',
#   'asylflut_sprunghafter',
#   'sprunghafter_anstieg',
#   'grenzendicht_rapefugees',
#   'rapefugees_nrw',
#   'nrw_duisburg-marxloh',
#   'anfangder_rest',
#   'arbeit_abmerkeln',
#   'abmerkeln_islamisierung',
#   'islamisierung_migranten',
#   'clausnitz_anzeigen',
#   'anzeigen_wg',
#   'körperlicher_angriffe+diebstahl',
#   'angriffe+diebstahl_eingegangen',
#   'kölnhbf_polizei',
#   'polizei_rapefugees',
#   'rapefugees_handgranate',
#   'handgranate_asyl',
#   'asyl_merkel',
#   'merkel_kiel',
#   'kiel_wer',
#   'blockparteien_wählt',
#   'wählt_macht',
#   'kommenden_verbrechen',
#   'abmerkeln_rapefugees',
#   'rapefugees_afd',
#   'afd_wählen',
#   'deutsche_frauen',
#   'rapefugees_opfern',
#   'wasistlinks_illner',
#   'deutsche_wirtschaft',
#   'asylanten_überschlagen',
#   'neuen_asylanten',
#   'asylanten_kampf',
#   'asylmafia_merkel',
#   'gericht_stellen',
#   'stellen_cdu',
#   'cdu_abwählen',
#   'abwählen_überall',
#   'zuhause_aufgenommen',
#   'aufgenommen_habenkann',
#   'ernst_nehmen',
#   'mio_arbeitslose',
#   'arbeitslose_muslimische',
#   'muslimische_asylanten',
#   'deutsche_mehrheit',
#   'land_lassen',
#   'nazis_beschimpfen',
#   'beschimpfen_cdu',
#   'islamisierung_schon',
#   'heutige_tagesscheisse',
#   'tagesscheisse_heist',
#   'heist_hoaxmap',
#   'tätsächlichen_vergewaltigungen',
#   'wirklich_unbequem',
#   'islam_scharia',
#   'scharia_salafismus',
#   'salafismus_multikulti',
#   'notwehr_afd',
#   'afd_wählen',
#   'kaputt_abmaasen',
#   'abmaasen_regsprecher',
#   'regsprecher_krimigranten',
#   'krimigranten_rapefugees',
#   'gesagt_hätte',
#   'hätte_domian´',
#   'abgefeiert_gez',
#   'gez_wdr',
#   'wdr_live',
#   'live_koelnhbf',
#   'koelnhbf_rapefugees',
#   'rapefugees_bezeichnend',
#   'bezeichnend_musl.verbände',
#   'musl.verbände_schließen',
#   'weltoffenheit_an.hinterher',
#   'hilft_islamisierung',
#   'islamisierung_abmerkeln',
#   'abmerkeln_gerüchten',
#   'gerüchten_zufolge',
#   'zufolge_finden',
#   'mittelmeer_inzwischen',
#   'inzwischen_mehr',
#   'mehr_pässe',
#   'flüchtlinge_asylanten',
#   'asylanten_merkel',
#   'gern_mal',
#   'täglichen_inländerfeindlichkeit',
#   'inländerfeindlichkeit_sehen',
#   'refugeesnotwelcome_brdregime',
#   'brdregime_volksverräter',
#   'volksverräter_unrecht',
#   'allermeisten_immer',
#   'eigenen_menschenrechte',
#   'menschenrechte_scharia-basiert',
#   'neue_asylanten',
#   'asylanten_kamen',
#   'bamf_geht',
#   'fürs_gesamte',
#   'gesamte_jahr',
#   'mal_rechnen',
#   'kandidaten_eigentlich',
#   'glaubwürdiger_und/oder',
#   'und/oder_seriöser',
#   'tausende_neue',
#   'neue_muslime',
#   'muslime_millionen',
#   'millionen_muslime',
#   'muslime_brauchen',
#   'brauchen_gebetsräume',
#   'gebetsräume_bald',
#   'tausende_moscheen',
#   'moscheen_gebaut',
#   'hinlänglich_berichtet',
#   'abartig_verhalten',
#   'davon_muß',
#   'muß_flüchtlinge',
#   'flüchtlinge_zwangsweise',
#   'privathaushalten_einzuquartieren',
#   'merkel_rapefugees',
#   'rapefugees_vorhersagetweet',
#   'vorhersagetweet_heimleiter',
#   'asylanten_heim',
#   'clausnitz_entlassen',
#   'afd_mitgliedsoviel',
#   'demokratie_diskriminierung',
#   'höchster_stelle',
#   'weiteren_langzeitarbeitslosen',
#   'vergewaltigenden_asylanten',
#   'asylanten_asylanten',
#   'asylanten_kommen',
#   'erbärmlichsten_zuständen',
#   'taschengeld_all',
#   'all_incl',
#   'incl_merkel',
#   'merkel_denkt',
#   'schwulenhilfe_berlin',
#   'berlin_richtet',
#   'schwule_asylanten',
#   'asylanten_schwulen-unterkünfte',
#   'schw.puff_könnten',
#   'könnten_asylanten',
#   'recht_ominös',
#   'wüsste_gerne',
#   'lokführer_hassan',
#   'hassan_ali',
#   'mohammed_hießen',
#   'hießen_fluechtlingskrise',
#   'fluechtlingskrise_islamisierung',
#   'islamisierung_dürfen',
#   'stuttgart_flüchtlinge',
#   'rapefugees_immer',
#   'vfbbvb_frau',
#   'türkischen_wurzeln',
#   'wurzeln_erzählt',
#   'direkt_neben',
#   'tochter_asylanten-heim',
#   'asylanten-heim_aufmacht',
#   'fiese_rassistin',
#   'rassistin_flüchtlinsheime',
#   'tag_gratis',
#   'gratis_rinderfilet',
#   'rinderfilet_serviert',
#   'menschenwürde.hungerstreik_rapefugees',
#   'vorhin_jemand',
#   'jemand_erzählt',
#   'handgranate_evtl',
#   'asylanten_selber',
#   'selber_kam',
#   'nie_islamisch',
#   'islamisierung_europas',
#   'wirklich_läuft',
#   'mal_samstag',
#   'samstag_früh',
#   'arbeit_fahren',
#   'fahren_asylanten',
#   'asylanten_domian',
#   'domian_merkel',
#   '.e_asylanten',
#   'spanien_abschieben',
#   'überall_gespart',
#   'arbeitslos_sind.das',
#   'solidarität_heuchlerin',
#   'rotherham_möglich',
#   'islamisierung_bereits',
#   'bereits_stattgefunden',
#   'griechenland_grenze',
#   'grenze_mazedonien',
#   'radikalen_migranten',
#   'migranten_klar',
#   'flüchtlinge_mehr',
#   'mehr_krimigranten',
#   'krimigranten_rapefugees',
#   'rapefugees_deutschebank',
#   'deutschebank_sagt',
#   'sagt_asylanten',
#   'asylanten_helfen',
#   'wirtschaft.die_kompetenz',
#   'geschäftszahlen_ablesen',
#   'warum_lädt',
#   'normalen_bürger',
#   'thema_asylanten',
#   'asylanten_geht',
#   'cdu_regiert',
#   'land+bund_hartaberfair',
#   'hartaberfair_schwahn',
#   'schwahn_.das',
#   '.das_problem',
#   'fehlende_geld',
#   'liebe_gemeinden',
#   'legen_asylanten',
#   'asylanten_obergrenzen',
#   'obergrenzen_fest',
#   'sz_faz',
#   'faz_zeit',
#   'zeit_nzz',
#   'nzz_worauf',
#   'worauf_warten',
#   'warten_flüchtlinge',
#   'asylanten_eigendlich',
#   'griechenland_europa',
#   'benzinabgabe_eingeführt',
#   'deutsche_zahlen',
#   'zahlen_rekordsteuern',
#   'langsames_internet',
#   'hungerstreik_rapefugees',
#   'rapefugees_gutmenschen',
#   'islam_unterstützen',
#   'bald_immer',
#   'immer_aggressiver',
#   'orf_zib',
#   'zib_vergewaltigung',
#   'kind_hallenbad',
#   'hallenbad_wien',
#   'informationen_wg',
#   'wg_opferschutz',
#   'wer_glaubt',
#   'griechische_rentner',
#   'griechische_marine',
#   'türkei_bringen',
#   'nichte_wurde',
#   'wurde_eltern',
#   'gesagt_mädchen',
#   'mädchen_sollen',
#   'unterricht_kommen',
#   'islamisierung_merkel',
#   'hergeholten_kulturbereicherer',
#   'kulturbereicherer_cdu',
#   'cdu_wählen',
#   'eigene_scharia-partei',
#   'scharia-partei_gründen',
#   'abmerkeln_amnestyinternational',
#   'amnestyinternational_heult',
#   'schwimmbäder_scheissen',
#   'hungerstreik_rapefugees',
#   'freilichtmuseum_hessenpark',
#   'asylanten_nein',
#   'nein_danke',
#   'danke_armlaenge',
#   'make_rape',
#   'rape_legal',
#   'landtagswahlen_afd',
#   '-stellig_abschließen',
#   'kaiserin-wählt_afd',
#   'notwehr_nichtwähler',
#   'nichtwähler_nichtwählen',
#   'nichtwählen_krimigranten',
#   'krimigranten_rapefugees',
#   'rapefugees_karneval',
#   'frauen_fühlen',
#   'weiberfastnacht_rapefugees',
#   'rapefugees_cameron',
#   'cameron_bringt',
#   'außer_asylanten',
#   'asylanten_chaos',
#   'chaos_regierung',
#   'regierung_spd',
#   'spd_fordert',
#   'arme_deutsche',
#   'sexuelle_übergriffe',
#   'asylanten_attakieren',
#   'schwimmbad_jugendliche',
#   'jugendliche_mädchen',
#   'bekommen_daraufhin',
#   'daraufhin_hausverbot',
#   'steuererhöhungen_wegen',
#   'fachkräfte_kommen',
#   'kommen_erst',
#   'wirschaffendas_merkel',
#   'merkel_integration',
#   'integration_rapefugees',
#   'rapefugees_spd',
#   'spd_cdu',
#   'cdu_religion',
#   'islamisierung_katholischemissionare',
#   'katholischemissionare_gnargh',
#   'gnargh_gegner',
#   'nazis_gleichzusetzen',
#   'einfach_falsch',
#   'ns-regime_clausnitz',
#   'clausnitz_bautzen',
#   'bautzen_deutschland',
#   'deutschland_räumung',
#   'refugeesnotwelcome_leyen',
#   'leyen_erklärt',
#   'erklärt_deutschland',
#   'fluechtlinge_asylanten',
#   'soldaten_ausbilden',
#   'sichern_nichtwähler',
#   'macht_briefwahl',
#   'schnell_krimigranten',
#   'krimigranten_rapefugees',
#   'rapefugees_stegner',
#   'stegner_augstein',
#   'augstein_simonepeter',
#   'simonepeter_gabriel',
#   'gabriel_roth',
#   'roth_künast',
#   'rechte_ausfressen',
#   'afd_schuldsind',
#   'schuldsind_groko',
#   'asylanten_verantwortlich',
#   'dank_merkel',
#   'merkel_mehr',
#   'mehr_asylanten',
#   'asylanten_mehr',
#   'mehr_türken',
#   'türken_mehr',
#   'mehr_ausgaben',
#   'ausgaben_türkei',
#   'türkei_kommt',
#   'cdu_abwahl',
#   'wurde_eigentlich',
#   'syrischen_ärzten',
#   'ja_wohl',
#   'wohl_wahrlich',
#   'deutsche_wurde',
#   'wurde_jahre',
#   'jahre_lang',
#   'volk_afd',
#   'afd_merkelmussweg',
#   'merkelmussweg_pseudo',
#   'pseudo_sturmwarnung',
#   'schutz_deutscher',
#   'deutscher_frauen',
#   'düsseldorf_karneval',
#   'karneval_morgenmagazin',
#   'morgenmagazin_läßt',
#   'läßt_asylanten',
#   'berlinale_israelfeindlichen',
#   'israelfeindlichen_film',
#   'film_anschauen',
#   'davon_lernt',
#   'lernt_schreiben',
#   'kitaplatz_gilt',
#   'flüchtlingskinder_fluechtlingskrise',
#   'fluechtlingskrise_asylanten',
#   'asylanten_fluechtlinge',
#   'fluechtlinge_hayali',
#   'spanien_abschieben',
#   'riesige_verschuldung',
#   'tipp_grenzen',
#   'grenzen_sichern',
#   'warum_spenden',
#   'spenden_grüne',
#   'grüne_cdu',
#   'menschen_leichter',
#   'leichter_ausgeben',
#   'ausgeben_läßt',
#   'huldigt_invasoren',
#   'christen_erbarmungslos',
#   'erbarmungslos_ermorden',
#   'rapefugees_christen',
#   'christen_kirche',
#   'kirche_fpoe',
#   'abmerkeln_abschieben',
#   'abschieben_grenzkontrollen',
#   'grenzkontrollen_islamisierung',
#   'islamisierung_stoppen',
#   'ziehe_revolution',
#   'zumindest_nehmen',
#   'marcel_proust',
#   'proust_wehrdich',
#   'wehrdich_ia',
#   'ia_stehauf',
#   'stehauf_srfarena',
#   'srfarena_svp',
#   'svp_logik',
#   'logik_minarette',
#   'gefährlich_waffen',
#   'scharia-staat_saudi-arabien',
#   'saudi-arabien_unbedenklich',
#   'regierung_schützt',
#   'angeblichen_sturm',
#   'sturm_beim',
#   'beim_rosenmontagszug',
#   'gang-rape_rapefugees',
#   'rapefugees_abmerkeln',
#   'abmerkeln_fluechtlingskrise',
#   'bald_nachlassen',
#   'hohen_anforderungen',
#   'anforderungen_kennen',
#   'warum_sollten',
#   'sollten_weibliche',
#   'weibliche_eindringlinge',
#   'eindringlinge_eigentlich',
#   'rapefugees_verhaftungen',
#   'armseligen_behörde',
#   'polizei_köln',
#   'köln_rapefugees',
#   'deutschland_strömen',
#   'weitere_etappe',
#   'islamisierung_erfolgt',
#   'erfolgt_islamistheproblem',
#   'islamistheproblem_afd',
#   'afd_herrlich',
#   'herrlich_deutsche',
#   'deutsche_medien',
#   'medien_berichten',
#   'hamburger_karnevalumzug',
#   'karnevalumzug_wurde',
#   'wegem_sturm',
#   'sturm_abgesagt',
#   'rapefugees_straftaten',
#   'deutsche_nazi',
#   'nazi_pack',
#   'irgendwann_entscheiden',
#   'mal_ernsthaften',
#   'ernsthaften_widerstand',
#   'widerstand_leisten.wirschaffendas',
#   'leisten.wirschaffendas_rapefugees',
#   'tag_stehen',
#   'stehen_algerier',
#   'algerier_marokkaner',
#   'afghanen_asylanten',
#   'asylanten_sterntv',
#   'sterntv_zeigt',
#   'asylanten_lehnen',
#   'lehnen_arbeit',
#   'arbeit_ab',
#   'netto_verdienen',
#   'stimmt_führen',
#   'gäbe_bald',
#   'wiederholungstäter_mehr',
#   'srfarena_dsi',
#   'dsi_handab',
#   'rotkäppchenkomplex_fütter',
#   'fütter_lieber',
#   'wolf_kriminelle',
#   'kriminelle_asylanten',
#   'eigene_volk',
#   'volk_merkel',
#   'merkel_cdu',
#   'cdu_friedlicher',
#   'friedlicher_karneval',
#   'zib_wolf',
#   'wolf_heute',
#   'einzige_zeile',
#   'asylanten_schweinefleisch',
#   'wer_saufen',
#   'kinder_vergewaltigen',
#   'vergewaltigen_braucht',
#   'extra_wurst',
#   'wurst_fuck',
#   'fuck_refugges',
#   'refugges_asylpaket',
#   'asylpaket_endlich',
#   'endlich_beschlossene',
#   'beschlossene_sache',
#   'asylflut_eingedämmt',
#   'flüchtlinge_flüchtlingspolitik',
#   'flüchtlingspolitik_asylanten',
#   'asylanten_islamisierung',
#   'unübersehbar_stattfindende',
#   'stattfindende_islamisierung',
#   'islamisierung_deutschlands',
#   'deutschland_katastrophal',
#   'katastrophal_schlecht',
#   'schlecht_asylchaos',
#   'asylchaos_abmerkeln',
#   'abmerkeln_annewill',
#   'annewill_islamisierung',
#   'gerade_unterwerfung',
#   'unterwerfung_gelesen',
#   'asylant_verkleidet',
#   'fasnacht_frauen',
#   'frauen_begrabschen',
#   ...]}

# %%
vocab = nltk.FreqDist(sum(bigram.values(),[]))

# %%
vocab = sorted(list(vocab.items()),key= lambda x: x[1], reverse=True)

# %%
vocab = [x[0] for x in vocab]

# %%
vocab[:100]
# Out:
# ['millionen_euro',
#  'milliarden_euro',
#  'verlinken_möchten',
#  'unten_stehenden',
#  'stehenden_link',
#  'link_verwenden',
#  'vergangenen_jahr',
#  'seit_jahren',
#  'milliarden_dollar',
#  'spiegel_online',
#  'fc_bayern',
#  'immer_mehr',
#  'new_york',
#  'bayern_münchen',
#  'rund_euro',
#  'champions_league',
#  'general_motors',
#  'zwei_jahren',
#  'jahre_alte',
#  'darüber_hinaus',
#  'ab_euro',
#  'rund_prozent',
#  'rund_millionen',
#  'welt_online',
#  'millionen_dollar',
#  'zehn_prozent',
#  'schon_seit',
#  'angela_merkel',
#  'pro_jahr',
#  'drei_jahren',
#  'prozent_mehr',
#  'beim_fc',
#  'jahre_alt',
#  'ersten_mal',
#  'zwei_wochen',
#  'vergangenen_jahren',
#  'zwei_jahre',
#  'schon_mal',
#  'zehn_jahren',
#  'kommenden_jahr',
#  'werder_bremen',
#  'euro_pro',
#  'deutsche_bank',
#  'pro_kilometer',
#  'berlin_dpa',
#  'ab_uhr',
#  'vfb_stuttgart',
#  'eigenen_angaben',
#  'ersten_quartal',
#  'schon_lange',
#  'wall_street',
#  'vier_jahren',
#  'ab_sofort',
#  'los_angeles',
#  'hamburger_sv',
#  'rund_milliarden',
#  'hertha_bsc',
#  'fünf_prozent',
#  'fünf_jahren',
#  'joachim_löw',
#  'bereits_seit',
#  'angaben_zufolge',
#  'van_gaal',
#  'mehr_geld',
#  'etwa_euro',
#  'bundeskanzlerin_angela',
#  'ps_starken',
#  'nummer_eins',
#  'prozent_weniger',
#  'nächsten_jahr',
#  'erster_linie',
#  'ersten_halbjahr',
#  'erstmals_seit',
#  'vfl_wolfsburg',
#  'real_madrid',
#  'letzten_jahren',
#  'tour_de',
#  'jahre_alten',
#  'bayer_leverkusen',
#  'litern_hubraum',
#  'euro_kosten',
#  'deutlich_mehr',
#  'ersten_blick',
#  'frau_merkel',
#  'michael_ballack',
#  'borussia_dortmund',
#  'jahre_lang',
#  'vw_golf',
#  'schon_immer',
#  'fc_barcelona',
#  'zweiten_platz',
#  'zweiten_quartal',
#  'vergangenen_wochen',
#  'millionen_franken',
#  'fotostrecke_bilder',
#  'drei_jahre',
#  'vergangenen_woche',
#  'zehn_jahre',
#  'ig_metall',
#  'lange_zeit']

# %%
term_freq = {genre: nltk.FreqDist(text) for genre, text in bigram.items()}

# %%
term_freq
# Out:
# {'keyword/automobil_50k.txt': FreqDist({'spiegel_online': 224, 'ab_euro': 212, 'rund_euro': 183, 'pro_kilometer': 149, 'ps_starken': 115, 'general_motors': 113, 'litern_hubraum': 104, 'seit_jahren': 95, 'vw_golf': 92, 'millionen_euro': 92, ...}),
#  'keyword/news_text100k.txt': FreqDist({'millionen_euro': 185, 'milliarden_euro': 110, 'darüber_hinaus': 109, 'seit_jahren': 78, 'immer_mehr': 77, 'donald_trump': 76, 'jahre_alt': 67, 'new_york': 63, 'ab_uhr': 55, 'fc_bayern': 55, ...}),
#  'keyword/sport_50k.txt': FreqDist({'verlinken_möchten': 340, 'unten_stehenden': 340, 'stehenden_link': 340, 'link_verwenden': 340, 'fc_bayern': 312, 'bayern_münchen': 258, 'champions_league': 233, 'millionen_euro': 227, 'jahre_alte': 158, 'beim_fc': 157, ...}),
#  'keyword/wirtschaft_50k.txt': FreqDist({'milliarden_euro': 831, 'millionen_euro': 654, 'milliarden_dollar': 339, 'verlinken_möchten': 270, 'unten_stehenden': 270, 'stehenden_link': 270, 'link_verwenden': 270, 'vergangenen_jahr': 224, 'new_york': 155, 'millionen_dollar': 144, ...}),
#  'keywords/hatespeech': FreqDist({'frau_merkel': 90, 'immer_mehr': 67, 'schon_lange': 53, 'seit_jahren': 50, 'schon_mal': 49, 'le_pen': 48, 'deutsche_volk': 36, 'angela_merkel': 33, 'schon_immer': 32, 'schon_seit': 32, ...})}

# %%
def create_dtm(dictionary,vocab):
    matrix=[]

    for value in dictionary.values():
        array=[]
        for word in vocab: 
            array.append(value.get(word, 0))
        matrix.append(array)    
    return np.array(matrix)

# %%
def tfidf(matrix, terms, voc,n):
    
    
    y=matrix.sum(axis=1)
    
    
    y=y[:,np.newaxis]
    tm= (np.divide(matrix,y)) * np.log(matrix.shape[0]/((matrix>0).sum(0)))
   
    idf_list=[]
   
    for i in range(tm.shape[0]):
        
        idf_list.append(tm[i].argsort()[::-1])
        
    docs={}
    doc_list=[]
    
 
    for index, key in enumerate(terms.keys()):
        for i in range(n):
            doc_list.append(voc[idf_list[index][i]])
        
        docs[key]= doc_list
        doc_list=[]
    return docs

# %%
dtm=create_dtm(term_freq,vocab)

# %%
results = tfidf(dtm, term_freq, vocab,1000)

# %%
result_list= results["keywords/hatespeech"]

# %%
for index, value in enumerate(result_list):
    result_list[index]= " ".join(value.split("_"))

# %%
result_list
# Out:
# ['bla bla',
#  'le pen',
#  "geht 's",
#  'afd wählen',
#  'frau petry',
#  'schmarotzer pädophile',
#  "gibt 's",
#  'partei deutschlands',
#  'spd schmarotzer',
#  'islam gehört',
#  'armes deutschland',
#  'eigene volk',
#  'twitter teilen',
#  'gabriel bitte',
#  'sundance justnobody',
#  'marine le',
#  'frau le',
#  'herr sigmar',
#  'herumsurfen gesehen',
#  'beim herumsurfen',
#  'liebe freunde',
#  'pfui teufel',
#  'fettigen haaren',
#  'eigene bevölkerung',
#  'deutschen volkes',
#  'danke frau',
#  'teufel jagen',
#  'sucht endlich',
#  'scheinheilgste partei',
#  'saudi arabien',
#  'grenzen dicht',
#  'o. wilke',
#  'schwager schwagerwars',
#  'völker regiert',
#  'notre dame',
#  'erpressern gewalttätern',
#  ' geld  ein',
#  'erfolg löschung',
#  'selbe gilt',
#  'vorsätzliche beihilfe',
#  'nötigern erpressern',
#  'bürgerkriegsflüchtlingen helfen',
#  'deutsche bürger',
#  'sofort raus',
#  'eigenen volk',
#  'haaren wdr',
#  'volker beck',
#  'vasallen merkels',
#  'merkel vasallen',
#  'besten blockieren',
#  'rot grün',
#  'a. merkel',
#  'danke merkel',
#  'arsch vorbei',
#  'pegida aufdiestraße',
#  'verstand verloren',
#  'kriminelle ausländer',
#  'alice schwarzer',
#  'bescheid sagen',
#  'jähriges mädchen',
#  'schwagerwars gebtdenschwagerfrei',
#  'sitzen geblieben',
#  'ursula haverbeck',
#  'ep europawahl',
#  'beide völker',
#  "wär 's",
#  'dumme deutsche',
#  'land zurück',
#  'land gelassen',
#  'is ja',
#  'eigenen bürger',
#  'aufdiestraße montagistpegidatag',
#  'her kommen',
#  'deutsche frauen',
#  'refugees refugeesnotwelcome',
#  'löschung od',
#  'twittersupport melden',
#  'papa wilberg',
#  'claudia roth',
#  'neue seite',
#  'heiko maas',
#  'frau schwarzer',
#  'wikimedia cc',
#  'parteien michboche',
#  'sowas unterstützen',
#  'video wurde',
#  'herr orban',
#  'europawahl ep',
#  'stasifrau kahane',
#  'kahane funktioniert',
#  'read more',
#  'endlich sucht',
#  'cc by-sa',
#  'hoch kriminellen',
#  'europawahl euelections',
#  'jaxxon sundance',
#  'merkels vasallen',
#  'abgefuckten spd',
#  'gender studies',
#  'yvonne willicks',
#  'politische gegner',
#  'kriminellen brandstiftern',
#  'betroffen futschi',
#  'deutschland sagen',
#  'mal bitte',
#  'ne menge',
#  'bundes regierung',
#  'afd wähler',
#  'millionen asylanten',
#  'islamisierung deutschlands',
#  'hungerstreik rapefugees',
#  'multi kulti',
#  'fresse halten',
#  'land geholt',
#  'krimigranten rapefugees',
#  "'s ja",
#  'warum hört',
#  'herr maas',
#  'ach ne',
#  'macht endlich',
#  'herr baumgartner',
#  'merkel muß',
#  'strasse gehen',
#  'deutschen bürger',
#  'merkel macht',
#  'oh mann',
#  'martin schulz',
#  'wer bezahlt',
#  'sexuelle belästigung',
#  'spd cdu',
#  'etablierten parteien',
#  'deutschen volk',
#  'ne neue',
#  'ach nee',
#  'unserer kultur',
#  'ne gute',
#  'sylvia stolz',
#  'abgefuckte spd',
#  'liebe bessermenschen',
#  ' k  de',
#  'taschen voll',
#  'klasse rede',
#  'deutsche botschaft',
#  'afd sachsen',
#  'albert schweitzer',
#  'festung europa',
#  'frau steinbach',
#  'frau nahles',
#  'oh je',
#  'auswärtigen amtes',
#  'bitte mal',
#  'ganzes land',
#  'offenen augen',
#  'simone peter',
#  'freie meinung',
#  'merkel vasall',
#  'cdu afd',
#  'bürger wehren',
#  'afd deutschland',
#  'grenzen sichern',
#  'na super',
#  'mutti merkel',
#  'wer schützt',
#  'eigenen landsleute',
#  'sofort abgeschoben',
#  'frauke petry',
#  'grün versiffte',
#  'hip-hop song',
#  'politisch korrekt',
#  'frau dr.',
#  'mal selber',
#  'verrecken lassen',
#  'ausländer raus',
#  'wahrheit sagt',
#  'warum kommt',
#  'döner mehr',
#  'medien schweigen',
#  'lügen lügen',
#  'oesterreich neuwahlen',
#  'gespannt wann',
#  'ekelwilfred wiltewka',
#  'deutsche volk',
#  'ha ha',
#  'unserer regierung',
#  'sexuelle übergriffe',
#  'guten morgen',
#  'land kommen',
#  'selber schuld',
#  'wacht endlich',
#  'junge männer',
#  'afd ➡️',
#  'wahrheit gesagt',
#  'interessanter artikel',
#  'bravo tschechien',
#  "'allahu akbar",
#  'polizei amp',
#  'via  news',
#  'friday for',
#  'ibizagate oesterreich',
#  'afd-spitzenkandidat  meuthen',
#  'strache ep',
#  'europawahl meuthen',
#  'meuthen euwahl',
#  'junge kräftige',
#  'robert habeck',
#  'weilesreicht dankespd',
#  'kräftige männer',
#  'politik anzugehen',
#  'einfach aktiv',
#  'heute aufgenommen',
#  'deutsche kinder',
#  'menschen aufnehmen',
#  'wer wählt',
#  'vernichtung deutschlands',
#  'ja ne',
#  'video anzusehen',
#  'land bitten',
#  'werdet einfach',
#  'bitten endlich',
#  'endlich aufzustehen',
#  'aktuelle politik',
#  'afd stärkste',
#  'demos schreibt',
#  'kommunalpolitiker werdet',
#  'mdl köbberling',
#  'illegal eingereiste',
#  'deutschland 🇩🇪',
#  'daniel cohn-bendit',
#  'rassistische ideologie',
#  'wand gestanden',
#  'gehirn prothesen',
#  'dummes gelaber',
#  'abgefuckten altparteien',
#  'spd politiker',
#  'dreck verrecken',
#  'axel stoll',
#  'abgefuckte hühnerscheisse',
#  'servicezeit wdr',
#  'schmoddrigen schwarzen',
#  'alten schmoddrigen',
#  'lieber hundert',
#  'hundert stimmen',
#  'religiöse fanatikerin',
#  'linken anarchisten',
#  'hetzlichendank abklatschen',
#  'twitter-support melden',
#  'afrikanische herrenrasse…',
#  'ernst cran',
#  'deutsches mädchen',
#  'merkel co.',
#  'matteo salvini',
#  'hallo frau',
#  'horst mahler',
#  'sozial gleichgestellte',
#  'euelections ep',
#  'gleichgestellte akzeptieren',
#  'tages folge',
#  'medien presse',
#  'alias ekelwilfred',
#  'richtigen orten',
#  'rebeccas verschwinden',
#  'dran denken',
#  'vasall merkels',
#  'wahre worte',
#  'drecks pack',
#  'mündliche weisung',
#  'warnschuß ersetzt',
#  'grenzdienst gilt',
#  'absatz bezeichneten',
#  'bezeichneten personen',
#  'grenzdienst übertragen',
#  'mehrfach geld',
#  'garnicht erst',
#  'mitgeführten beförderungsmittel',
#  'ja nix',
#  'make rape',
#  'herrn jesus',
#  'wer denkt',
#  'fragt mal',
#  'raus raus',
#  'neues deutschland',
#  'entziehen versuchen',
#  'etwa mitgeführten',
#  'volk steht',
#  'müssen zurück',
#  'jetzige regierung',
#  'flüchtlinge mehr',
#  'europa deutschland',
#  'sz faz',
#  'islamisierung europas',
#  'rape legal',
#  'grenzen schließen',
#  'wählt afd',
#  'wiederholten weisung',
#  'is schon',
#  'brutal vergewaltigt',
#  'armlänge abstand',
#  'prof. schachtschneider',
#  'genannten vollzugsbeamten',
#  'grenzdienst schußwaffen',
#  'personen gebrauchen',
#  'denen sowas',
#  'kriminelle asylbewerber',
#  'jan böhmermann',
#  'dummen deutschen',
#  'tolle frau',
#  "sieht 's",
#  'gute frau',
#  'regierung mal',
#  'aufs maul',
#  'deutschen volke',
#  'islamischen staates',
#  'straße leben',
#  'dummes deutschland',
#  'mehr hören',
#  'millionen flüchtlingen',
#  'vollkommen recht',
#  'sollen flüchtlinge',
#  'sowas gibt',
#  'denen einfach',
#  'herr bosbach',
#  'danke herr',
#  'illegale einwanderer',
#  'deutsche rentner',
#  'teilen teilen',
#  'mehr tragbar',
#  'kim jong',
#  'realität verloren',
#  'radio gehört',
#  'liebe leute',
#  'gibt genug',
#  'leute geht',
#  'polizei lässt',
#  'macht ne',
#  'deutschland schafft',
#  'ddr zeiten',
#  'wandern fälle',
#  'angst macht',
#  'glauben ab',
#  'flüchtlinge bekommen',
#  'schnauze voll',
#  'walter lübcke',
#  'wurde heute',
#  'mal schauen',
#  'cdu spd',
#  'ach ja',
#  'mal ne',
#  'nix mehr',
#  'hartz iv',
#  'mal schön',
#  'gute besserung',
#  'ne frage',
#  'freie meinungsäußerung',
#  'for future',
#  'kopf schütteln',
#  'recht geben',
#  'nacht deutschland',
#  'cdu csu',
#  'deutsche politiker',
#  'donald trump',
#  'muslimische invasoren',
#  'grün wählt',
#  'euwahl ibizagate',
#  'größte oppositionspartei',
#  'österreichische regierung',
#  "'wir brauchen",
#  'multikulti vielfalt',
#  'via  freiheit',
#  'islamischen gesellschaft',
#  'scheinheilgsten partei',
#  'schmoddrigen hose',
#  'volk verraten',
#  'a. h.',
#  'falsche propheten',
#  'jahre grundgesetz',
#  'marktwirtschaft statt',
#  'statt sozialismus',
#  'europa afd',
#  'zwei sturmgewehre',
#  'typ kalaschnikow',
#  'hans-georg maaßen',
#  'tim k.',
#  'deutsches maedchen',
#  'prophetin greta',
#  'schönes wochenende',
#  'land leben',
#  'sitzen gebliebene',
#  'islamischen welt',
#  'dieter nuhr',
#  'spd verseuchte',
#  'derart strunzdumme',
#  'manila strotzt',
#  'wer immer',
#  'hürde islamisten',
#  'islamisten herde',
#  'oh oh',
#  'z. b.',
#  'syrische familie',
#  'afd bundestag',
#  'medien feiern',
#  'migranten juden',
#  'j. asylbewerber',
#  'krieg gedient',
#  'arsch treten',
#  'abschieben abschieben',
#  '\u2066\u2069 \u2066\u2069',
#  'wähle afd',
#  'frohe pfingsten',
#  'heilige geist',
#  'wählen dürfen',
#  'innenminister kickl',
#  'ör medien',
#  'deutschen lügenpresse',
#  'linksgrüner ökopolitik',
#  'standardeinstellung speichert',
#  'anmelden telefonanbieter',
#  'gestapo bezeichnen',
#  'telefonanbieter dürfen',
#  'dürfen überhaupt',
#  'mehr speichern',
#  ' geld warum',
#  'richtigen tatort',
#  'internet gestapo',
#  '-playlist hinzugefügt',
#  'afd politiker',
#  'absolut unfähig',
#  'kommt davon',
#  'sagen beim',
#  'nowehrmuc jaxxon',
#  'erfolg löschung/sperrung',
#  'löschung/sperrung klatschen',
#  'islam heute',
#  'claudi roth',
#  'kinder kümmern',
#  'wessen brot',
#  'd. cdu',
#  'nazi medien',
#  'drogenszene hennigsdorf/oranienburg',
#  'noafd fckafd',
#  'cohn-bendit fordert',
#  'toleranz fanatiker',
#  'frank thelen',
#  'gt verbot',
#  'via  welt news',
#  'neue sed',
#  'einfach geht',
#  'bitte melden',
#  'offene grenzen',
#  'angela schaller',
#  'us-präsident donald',
#  'strafe gestellt',
#  'snapchat drogenszene',
#  'nächsten leben',
#  'linken grünen',
#  'deutschland bundestag',
#  'gt gt',
#  'capitol alias',
#  'neue reihe',
#  'amp holt',
#  'amp presse',
#  'findet endlich',
#  'anal ritter',
#  'hetzlichendank ab',
#  'geht eh',
#  'sichere drittstaaten',
#  'zeit spötter',
#  'heute show',
#  'niedrig gesinnte',
#  'hervorrufen niedrig',
#  'spaltungen hervorrufen',
#  'begierden leben',
#  'gottlosen begierden',
#  'eigenen gottlosen',
#  'lieben erinnert',
#  'asylanten bekommen',
#  'judas //',
#  'schon lese',
#  'knast stecken',
#  'deutschen patrioten',
#  'daumen hoch',
#  'neuen facharbeiter',
#  'seit untergebildet',
#  'rechte ecke',
#  'herr putin',
#  'köpfe einschlagen',
#  'schreiben darf',
#  'land gekämpft',
#  'mehr wählbar',
#  'iv empfänger',
#  'heile welt',
#  'schöne heile',
#  'mal interessieren',
#  "gab 's",
#  "hakim 's",
#  'wirklich angst',
#  'eigenen leute',
#  'zurück geschickt',
#  'zurück lassen',
#  'krieg zurück',
#  'volk gegenüber',
#  'medien verschweigen',
#  'affen seit',
#  'hallo freunde',
#  'reicht langsam',
#  'anetta kahane',
#  'klingt komisch',
#  'refugees welcome',
#  'liebe menschen',
#  'deutsche polizei',
#  'alen r.',
#  'alte schachtel',
#  'deutschland afd',
#  'frauen kinder',
#  'christlichen land',
#  'islamisierung findet',
#  'ärzte ingenieure',
#  'deutschland zerstört',
#  'afd cdu',
#  'pegida afd',
#  'macht merkel',
#  'eil meldung',
#  'antonio stiftung',
#  'pack gehört',
#  'kulturelle bereicherung',
#  'fatima roth',
#  'zurück schicken',
#  'bescheuerten gutmenschen',
#  'lassen anstatt',
#  'sofort ausweisen',
#  'ganzen scheiß',
#  'wand stellen',
#  'orbán viktor',
#  'präsident zeman',
#  'alleinstehende männer',
#  'na sowas',
#  'nahost abholen',
#  'altes mädchen',
#  'warum warum',
#  'professor schachtschneider',
#  'namens merkel',
#  'wählen gehen',
#  'till schweiger',
#  'flüchtlinge schießen',
#  'seid ja',
#  'bundes uzwg',
#  'öffentlicher gewalt',
#  'ausübung öffentlicher',
#  'unmittelbaren zwang',
#  'gutes gelingen',
#  'mal klartext',
#  'felix baumgartner',
#  'frei rum',
#  'mehr hinzuzufügen',
#  'leider wahr',
#  'wort deutsch',
#  'wort melden',
#  'schwanz ab',
#  'wort lügenpresse',
#  'wozu brauchen',
#  'wehrlose menschen',
#  'bitte lesen',
#  'frau maischberger',
#  'klar denken',
#  'voller härte',
#  'menschen gehören',
#  'deutscher staatsbürger',
#  'sowas schon',
#  'davon mal',
#  'flaschen sammeln',
#  'tag kommen',
#  'fette gabriel',
#  'land aufgebaut',
#  'geld wäre',
#  'deutschland kaputt',
#  'bestimmt schon',
#  'frauen vergewaltigen',
#  'unserer kanzlerin',
#  'iss ja',
#  'armen traumatisierten',
#  'nazis usw',
#  'teppich gekehrt',
#  'tatsächlich jemand',
#  'her gekommen',
#  'merkel endlich',
#  'mehr verarschen',
#  'sowas macht',
#  'wer sowas',
#  'kam heute',
#  'einfach unfassbar',
#  'muslimischen ländern',
#  'bürgerwehren bilden',
#  'wahres dran',
#  'mal drüber',
#  'frau m.',
#  'neue zähne',
#  'jong merkel',
#  'nix passiert',
#  'eh nix',
#  'welt gesetzt',
#  'bekommt angst',
#  'freies deutschland',
#  'männer geben',
#  'nazi beschimpft',
#  'ja erstmal',
#  'mal sowas',
#  'grenzen schützen',
#  'demokratie gibt',
#  'neuen freunde',
#  'sagen müssen',
#  'soviel essen',
#  'her kommt',
#  'thema meinungsfreiheit',
#  'beim scheißen',
#  'wahlen kommen',
#  'grüne fdp',
#  'asylanten sollen',
#  'gut deutsch',
#  'selber mal',
#  'wahren nazis',
#  'jahr hätte',
#  'islamismus geprägt',
#  'chaos streit',
#  'arabische welt',
#  'inklusive fast',
#  'menschen gelöst',
#  'vorhandenen wohlstandskokon',
#  'wohlstandskokon zurückzieht',
#  'zurückzieht handelt',
#  'merkel zerstört',
#  'kurze beine',
#  'hochkriminellen brandstiftern',
#  'verlogenen wahrheitsunterdrückern',
#  'wahrheitsunterdrückern a.',
#  'verfassungsfeindlichen vereinigung',
#  'groß weeden',
#  'fur babies',
#  'mehrere frauen',
#  'ja merkel',
#  'is klar',
#  'kristin kaufmann',
#  'heutigen verhältnisse',
#  'verhältnisse bestritten',
#  'flüchtlinge sollen',
#  'ironie off',
#  'mal recht',
#  'is kämpfer',
#  'warum geht',
#  'hallo leute',
#  'mehr nachkommen',
#  'abgelehnte asylbewerber',
#  'nächste bürgerkrieg',
#  'innere bereitschaft',
#  'deutscher politiker',
#  'schlaf gebracht',
#  'no go',
#  'herrn orban',
#  'mehr herr',
#  'arbeits -plätzen',
#  'wasserkopf- arbeits',
#  'afd schon',
#  'welt hinaus',
#  'integrationssoftware neu',
#  'neu programmieren',
#  'kriminelle asylanten',
#  'lese gerade',
#  'irakische armee',
#  'bildung etc',
#  'spd afd',
#  'madame le',
#  'bravo marine',
#  'tolle rede',
#  'millionen flüchtlinge',
#  'refugeesnotwelcome refugeesgohome',
#  'afd gibt',
#  'lieber horst',
#  'neuen asylanten',
#  'asylanten flüchtlinge',
#  'flüchtlinge asylanten',
#  'hilfe brauchen',
#  'neue asylanten',
#  'millionen muslime',
#  'all incl',
#  'faz zeit',
#  'zeit nzz',
#  'arme deutsche',
#  'wirschaffendas merkel',
#  'dank merkel',
#  'mehr asylanten',
#  'islamistischen extremismus',
#  'arabischen ländern',
#  'is gut',
#  'stimmung kippt',
#  'extremismus arabischen',
#  'arabischen antisemitismus',
#  'antisemitismus nationale',
#  'ethnische konflikte',
#  'völker sowie',
#  'deutsche täter',
#  'jahren fordern',
#  'bundeswehr soldaten',
#  'neu aleppo',
#  'heribert prantl',
#  'schön reden',
#  'arsch offen',
#  'republik deutschland',
#  'ab dafür',
#  "'s schon",
#  'hooton plan',
#  'todestrafe fur',
#  'bitte unterstützen',
#  'na ja',
#  'straße gehen',
#  'deutsche geschichte',
#  'la la',
#  'hc strache',
#  'land verlassen',
#  'stimmt ja',
#  'grüne linke',
#  'sollten mal',
#  'unserer politiker',
#  'deutsch lernen',
#  'ard zdf',
#  'wahre gesicht',
#  'problem gelöst',
#  'allahu akbar',
#  'sagen darf',
#  'sexuell missbraucht',
#  'oh nein',
#  'fake news',
#  'ernst gemeint',
#  'ganz fest',
#  'schaut mal',
#  'punkt gebracht',
#  'ja ja',
#  'stärkste kraft',
#  'jungen männer',
#  'sigmar gabriel',
#  'berliner polizei',
#  'jesus christus',
#  'denen geht',
#  'deutsche steuerzahler',
#  'mundtot gemacht',
#  'nächsten wahlen',
#  'erika steinbach',
#  'frei erfunden',
#  'krieg erklärt',
#  'zukunft europas',
#  'merkel geht',
#  'wisst schon',
#  'gehen dürfen',
#  'heutigen tage',
#  'gehört sofort',
#  'ecke gestellt',
#  'klare aussage',
#  'kopftuch tragen',
#  'heiße luft',
#  'absolut recht',
#  'staat bezahlt',
#  'dumme menschen',
#  'mehr flüchtlinge',
#  'medien berichten',
#  'auswärtigen amt',
#  'leider schon',
#  'schon traurig',
#  'einfach ignorieren',
#  'steckt dahinter',
#  'gelobte land',
#  'fragen warum',
#  'politische islam',
#  'andrea nahles',
#  'lässt grüßen',
#  'müssen erst',
#  'eigene meinung',
#  'vielen dank',
#  "'die polizei",
#  'daneben benimmt',
#  'de grenze',
#  'wer betrügt',
#  'stimme gibt',
#  'hach ja',
#  'dr. merkel',
#  'behorden daten',
#  'syrien afghanistan',
#  'öffentlichen ordnung',
#  'ja mehrere',
#  'deutsche gesetz',
#  'illegalen einwanderern',
#  'tut endlich',
#  'jährige mädchen',
#  'geld gestrichen',
#  'bleiben darf',
#  'frau schwesig',
#  'ne jährige',
#  'abartigen kreaturen',
#  'kriminelle vereinigung',
#  'ruhig schlafen',
#  'merkel merkt',
#  'türkisch-griechischen grenze',
#  'müssten mal',
#  'schläft wacht',
#  'danke liebe',
#  'mal rein',
#  'afd-fraktion ltmv',
#  'christlicher kirchen',
#  'syrische flüchtlinge',
#  'flugzeug regierung',
#  'rechter hetzer',
#  'kriminellen flüchtlingen',
#  'islam seit',
#  'frans timmermans',
#  'mitleid mehr',
#  'frag mal',
#  'beiden geholfen',
#  'dumm dümmer',
#  'passender spender',
#  'eigenen identität',
#  'sonntag wählen',
#  'bereits angekommen',
#  'lange reden',
#  'kaum beachtet',
#  'unserer identität',
#  'endlich wurde',
#  'weiß jemand',
#  'schlaf erwacht',
#  'kontrollieren bestehe',
#  'dinge laufen',
#  'monatelangen schlaf',
#  'trojanische pferd',
#  'balken biegen',
#  'seit merkel',
#  'muslimischen invasoren',
#  'dumm verkaufen',
#  'scharf gemacht',
#  'verschleierten frauen',
#  'friedensnobelpreis bekommen',
#  'böse enden',
#  'invasion ausgesetzt',
#  'dämliche frage',
#  'deutschen widerstand',
#  'görlitzistschlaugörlitzwähltblau 🇩🇪',
#  'echt leid',
#  'handelt endlich',
#  'verfassungsmäßige ordnung',
#  'staatsgewalt geht',
#  'sozialer bundesstaat',
#  'party richtig',
#  'importieren islamistischen',
#  'souveräne staaten',
#  'schlechter witz',
#  'europa gemacht',
#  'bezahlte jobs',
#  'dr. titel',
#  'europa guanyin',
#  'guanyin einwanderung',
#  'milanovic sagte',
#  'bulgarien rumänien',
#  'paar kinder',
#  'merkel handelt',
#  'höchsten rang',
#  'sache kämpfen',
#  'erster mann',
#  'orban gibt',
#  'artikel gibt',
#  'islamischen bewegungen',
#  'syrien kamen',
#  'lehrt hass',
#  'mädchen fördert',
#  'minderjähriger mädchen',
#  'vergewaltigung minderjähriger',
#  'buchen verbieten',
#  'islamische bewegung',
#  'islamische religion',
#  'islamischen terroristen',
#  'mutiger schritt',
#  'islamischen terrorismus',
#  'ltmv mv',
#  'starten migranten',
#  'bundesweit starten',
#  'frau claudia',
#  'scharia ersetzen',
#  'wegen hochverrat',
#  'tag immer',
#  'gute amp',
#  'uwe junge',
#  'nicole höchst',
#  'köbberling spd',
#  'spd wählt',
#  'hoffentlich bekommt',
#  'morgen 🇩🇪',
#  'afd gewählt',
#  'wählt wählt',
#  'dankespd afd',
#  'wer hilft',
#  'ökonom sinn',
#  'kluger kopf',
#  'spd macht',
#  'asyl erhalten',
#  'deutsche rechtsstaat',
#  'afd pegida',
#  'prozent spd',
#  'ep meuthen',
#  'wer grün',
#  'lange gewänder',
#  'bewusste unterstützung',
#  'deutschland sicherheit',
#  'globalen erwärmung',
#  'europa skandieren',
#  'tunesien verfrachtet',
#  'flüchtlinge wurden',
#  'mann mann',
#  'deutschlandweitem klimanotstand',
#  'fordern ausrufung',
#  'demonstranten fordern',
#  'clans seit',
#  'sicherheit merkelland',
#  'grün wählen',
#  'gewänder trägt',
#  'freien völker',
#  'islamisierung unserer',
#  'welt news',
#  'geniale propaganda',
#  'brauchen eben',
#  'nächstes dran',
#  'spd gruene',
#  'euwahl steht',
#  'steuerzahler alimentiert',
#  'gauland vorsitzender',
#  'frau harderkühnel',
#  'twitter gesperrt',
#  'schädigung deutschlands',
#  '-jähriges mädchen',
#  "'s klima",
#  'görlitzer park',
#  'och gottchen',
#  'schwachsinn gehört',
#  'bessermenschen freuen',
#  'naiven bessermenschen',
#  'polizei trägt',
#  'willkommen wilkommen',
#  'nordafrikanern vergewaltigt',
#  'zwei nordafrikanern',
#  'hambacher fest',
#  'heimatländer geschickt',
#  'gläubige herr',
#  'islamischen zuckerfest',
#  'maas eigentlich',
#  'katrin göring-eckardt',
#  'fanatismus musikinstrumente',
#  'kriminelle clans',
#  'geld fordert',
#  'offener brief',
#  "'s lega",
#  "salvini 's",
#  'frohe ostern',
#  'bmw enteignen',
#  'gerade gelesen',
#  'warum gilt',
#  'lebende migranten',
#  'mutter vater',
#  'bischof koch',
#  'psychisch kranker',
#  'enkeln erklären',
#  'metoo aufschrei',
#  'berliner bischof',
#  'matthäus hfa',
#  'viele verführen.',
#  'zahl auftreten',
#  'dame brennt',
#  'berlin o.',
#  'deutschen grünen',
#  'via gez',
#  'öffentlich-rechtlichen sender',
#  'anteil nichtdeutscher',
#  'einzelfall kommt',
#  'immer träumte',
#  "bacho 'gestern",
#  'pferdestall geboren',
#  'sawsan chebli',
#  'islamischen staat',
#  'wann hört',
#  'sitzt ja',
#  'multi-kulti-augen denen',
#  'bestimmten einwanderungsgruppen',
#  'europäischen großstädte',
#  'politiker europäischer',
#  'wirtschaftlichen probleme',
#  'deutschlands sorgen',
#  'spürbar wahrnehmen',
#  'überfremdung spürbar',
#  'heutigen probleme',
#  'überfremdung etc',
#  'wirtschaftliche last',
#  'holen lohnt',
#  'identisch hohe',
#  'eigene boot',
#  'funken wahrheit',
#  'maut geben',
#  'min völkerwanderung',
#  'video min',
#  'intelligente sparpolitik']

# %%
np.savetxt("bigram_keywords_tf_idf_with_news_without_stopwords.csv", result_list, delimiter =",",fmt ='% s')
